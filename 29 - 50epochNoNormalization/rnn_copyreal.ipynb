# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - learning rate de a 0.005  0.0001

# %%
filepath = '29 - 50epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 512
num_classes = 7
num_epochs = 50
batch_size = 8
learning_rate = 0.0001
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([8, 769024]) , Labels shape: torch.Size([8])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/110, loss = 2.1335
# epoch 1 / 50, step 2/110, loss = 2.2298
# epoch 1 / 50, step 3/110, loss = 1.9392
# epoch 1 / 50, step 4/110, loss = 2.0999
# epoch 1 / 50, step 5/110, loss = 2.1074
# epoch 1 / 50, step 6/110, loss = 2.0821
# epoch 1 / 50, step 7/110, loss = 2.1087
# epoch 1 / 50, step 8/110, loss = 2.0171
# epoch 1 / 50, step 9/110, loss = 2.3583
# epoch 1 / 50, step 10/110, loss = 1.8617
# epoch 1 / 50, step 11/110, loss = 1.9418
# epoch 1 / 50, step 12/110, loss = 2.1388
# epoch 1 / 50, step 13/110, loss = 1.8227
# epoch 1 / 50, step 14/110, loss = 1.9596
# epoch 1 / 50, step 15/110, loss = 2.1519
# epoch 1 / 50, step 16/110, loss = 2.0783
# epoch 1 / 50, step 17/110, loss = 2.1052
# epoch 1 / 50, step 18/110, loss = 2.0509
# epoch 1 / 50, step 19/110, loss = 2.1061
# epoch 1 / 50, step 20/110, loss = 2.0638
# epoch 1 / 50, step 21/110, loss = 2.1197
# epoch 1 / 50, step 22/110, loss = 1.9127
# epoch 1 / 50, step 23/110, loss = 2.1032
# epoch 1 / 50, step 24/110, loss = 2.1045
# epoch 1 / 50, step 25/110, loss = 2.1589
# epoch 1 / 50, step 26/110, loss = 1.9970
# epoch 1 / 50, step 27/110, loss = 2.1647
# epoch 1 / 50, step 28/110, loss = 1.8975
# epoch 1 / 50, step 29/110, loss = 1.9633
# epoch 1 / 50, step 30/110, loss = 2.1188
# epoch 1 / 50, step 31/110, loss = 2.1413
# epoch 1 / 50, step 32/110, loss = 1.9289
# epoch 1 / 50, step 33/110, loss = 2.0736
# epoch 1 / 50, step 34/110, loss = 2.0827
# epoch 1 / 50, step 35/110, loss = 1.8353
# epoch 1 / 50, step 36/110, loss = 2.0572
# epoch 1 / 50, step 37/110, loss = 1.7484
# epoch 1 / 50, step 38/110, loss = 1.9716
# epoch 1 / 50, step 39/110, loss = 2.1534
# epoch 1 / 50, step 40/110, loss = 2.1422
# epoch 1 / 50, step 41/110, loss = 1.9678
# epoch 1 / 50, step 42/110, loss = 2.1629
# epoch 1 / 50, step 43/110, loss = 2.1403
# epoch 1 / 50, step 44/110, loss = 1.8603
# epoch 1 / 50, step 45/110, loss = 2.1642
# epoch 1 / 50, step 46/110, loss = 1.8300
# epoch 1 / 50, step 47/110, loss = 2.0437
# epoch 1 / 50, step 48/110, loss = 2.1540
# epoch 1 / 50, step 49/110, loss = 2.0776
# epoch 1 / 50, step 50/110, loss = 2.0364
# epoch 1 / 50, step 51/110, loss = 2.1931
# epoch 1 / 50, step 52/110, loss = 2.2929
# epoch 1 / 50, step 53/110, loss = 2.0093
# epoch 1 / 50, step 54/110, loss = 1.8813
# epoch 1 / 50, step 55/110, loss = 1.9615
# epoch 1 / 50, step 56/110, loss = 1.9454
# epoch 1 / 50, step 57/110, loss = 2.0658
# epoch 1 / 50, step 58/110, loss = 2.0153
# epoch 1 / 50, step 59/110, loss = 1.9634
# epoch 1 / 50, step 60/110, loss = 2.1888
# epoch 1 / 50, step 61/110, loss = 2.0318
# epoch 1 / 50, step 62/110, loss = 2.2434
# epoch 1 / 50, step 63/110, loss = 1.9140
# epoch 1 / 50, step 64/110, loss = 2.1038
# epoch 1 / 50, step 65/110, loss = 1.8645
# epoch 1 / 50, step 66/110, loss = 2.0341
# epoch 1 / 50, step 67/110, loss = 2.0121
# epoch 1 / 50, step 68/110, loss = 2.0013
# epoch 1 / 50, step 69/110, loss = 1.8125
# epoch 1 / 50, step 70/110, loss = 2.1544
# epoch 1 / 50, step 71/110, loss = 2.2517
# epoch 1 / 50, step 72/110, loss = 1.9707
# epoch 1 / 50, step 73/110, loss = 2.1145
# epoch 1 / 50, step 74/110, loss = 1.8889
# epoch 1 / 50, step 75/110, loss = 2.1025
# epoch 1 / 50, step 76/110, loss = 2.3320
# epoch 1 / 50, step 77/110, loss = 2.0563
# epoch 1 / 50, step 78/110, loss = 1.9939
# epoch 1 / 50, step 79/110, loss = 1.8974
# epoch 1 / 50, step 80/110, loss = 2.1832
# epoch 1 / 50, step 81/110, loss = 2.0454
# epoch 1 / 50, step 82/110, loss = 2.2355
# epoch 1 / 50, step 83/110, loss = 2.3346
# epoch 1 / 50, step 84/110, loss = 2.2697
# epoch 1 / 50, step 85/110, loss = 2.2393
# epoch 1 / 50, step 86/110, loss = 1.8396
# epoch 1 / 50, step 87/110, loss = 1.8277
# epoch 1 / 50, step 88/110, loss = 2.1084
# epoch 1 / 50, step 89/110, loss = 2.0954
# epoch 1 / 50, step 90/110, loss = 2.0473
# epoch 1 / 50, step 91/110, loss = 1.8418
# epoch 1 / 50, step 92/110, loss = 2.0487
# epoch 1 / 50, step 93/110, loss = 2.3949
# epoch 1 / 50, step 94/110, loss = 1.8830
# epoch 1 / 50, step 95/110, loss = 2.2867
# epoch 1 / 50, step 96/110, loss = 2.1166
# epoch 1 / 50, step 97/110, loss = 2.0243
# epoch 1 / 50, step 98/110, loss = 2.2376
# epoch 1 / 50, step 99/110, loss = 1.9390
# epoch 1 / 50, step 100/110, loss = 1.8050
# epoch 1 / 50, step 101/110, loss = 1.8086
# epoch 1 / 50, step 102/110, loss = 1.6446
# epoch 1 / 50, step 103/110, loss = 2.1167
# epoch 1 / 50, step 104/110, loss = 1.8381
# epoch 1 / 50, step 105/110, loss = 1.7637
# epoch 1 / 50, step 106/110, loss = 2.1486
# epoch 1 / 50, step 107/110, loss = 1.8767
# epoch 1 / 50, step 108/110, loss = 1.8625
# epoch 1 / 50, step 109/110, loss = 1.9357
# epoch 1 / 50, step 110/110, loss = 1.9013
# epoch 1 / 50, step 1/28, loss = 1.9430
# epoch 1 / 50, step 2/28, loss = 2.0307
# epoch 1 / 50, step 3/28, loss = 1.9698
# epoch 1 / 50, step 4/28, loss = 2.1116
# epoch 1 / 50, step 5/28, loss = 2.0005
# epoch 1 / 50, step 6/28, loss = 1.9880
# epoch 1 / 50, step 7/28, loss = 1.9365
# epoch 1 / 50, step 8/28, loss = 1.9317
# epoch 1 / 50, step 9/28, loss = 2.0321
# epoch 1 / 50, step 10/28, loss = 2.0241
# epoch 1 / 50, step 11/28, loss = 2.0161
# epoch 1 / 50, step 12/28, loss = 1.9678
# epoch 1 / 50, step 13/28, loss = 2.0632
# epoch 1 / 50, step 14/28, loss = 1.9761
# epoch 1 / 50, step 15/28, loss = 1.8517
# epoch 1 / 50, step 16/28, loss = 2.0197
# epoch 1 / 50, step 17/28, loss = 2.0206
# epoch 1 / 50, step 18/28, loss = 1.9743
# epoch 1 / 50, step 19/28, loss = 1.9467
# epoch 1 / 50, step 20/28, loss = 1.8931
# epoch 1 / 50, step 21/28, loss = 1.8831
# epoch 1 / 50, step 22/28, loss = 1.9676
# epoch 1 / 50, step 23/28, loss = 1.8791
# epoch 1 / 50, step 24/28, loss = 1.9797
# epoch 1 / 50, step 25/28, loss = 1.9675
# epoch 1 / 50, step 26/28, loss = 2.1282
# epoch 1 / 50, step 27/28, loss = 1.8878
# epoch 1 / 50, step 28/28, loss = 1.8591
# epoch 2 / 50, step 1/110, loss = 1.6937
# epoch 2 / 50, step 2/110, loss = 1.9775
# epoch 2 / 50, step 3/110, loss = 2.2183
# epoch 2 / 50, step 4/110, loss = 2.0127
# epoch 2 / 50, step 5/110, loss = 1.8739
# epoch 2 / 50, step 6/110, loss = 2.0005
# epoch 2 / 50, step 7/110, loss = 2.1112
# epoch 2 / 50, step 8/110, loss = 1.9546
# epoch 2 / 50, step 9/110, loss = 1.6675
# epoch 2 / 50, step 10/110, loss = 2.0019
# epoch 2 / 50, step 11/110, loss = 1.9965
# epoch 2 / 50, step 12/110, loss = 2.0891
# epoch 2 / 50, step 13/110, loss = 2.0018
# epoch 2 / 50, step 14/110, loss = 1.8116
# epoch 2 / 50, step 15/110, loss = 1.6688
# epoch 2 / 50, step 16/110, loss = 2.0500
# epoch 2 / 50, step 17/110, loss = 2.0440
# epoch 2 / 50, step 18/110, loss = 1.9966
# epoch 2 / 50, step 19/110, loss = 2.0855
# epoch 2 / 50, step 20/110, loss = 1.7894
# epoch 2 / 50, step 21/110, loss = 2.0957
# epoch 2 / 50, step 22/110, loss = 2.0429
# epoch 2 / 50, step 23/110, loss = 1.8940
# epoch 2 / 50, step 24/110, loss = 2.0171
# epoch 2 / 50, step 25/110, loss = 2.0865
# epoch 2 / 50, step 26/110, loss = 2.2000
# epoch 2 / 50, step 27/110, loss = 1.7962
# epoch 2 / 50, step 28/110, loss = 2.1678
# epoch 2 / 50, step 29/110, loss = 1.8817
# epoch 2 / 50, step 30/110, loss = 1.9639
# epoch 2 / 50, step 31/110, loss = 2.0547
# epoch 2 / 50, step 32/110, loss = 2.0993
# epoch 2 / 50, step 33/110, loss = 1.7627
# epoch 2 / 50, step 34/110, loss = 1.7735
# epoch 2 / 50, step 35/110, loss = 1.9454
# epoch 2 / 50, step 36/110, loss = 2.0735
# epoch 2 / 50, step 37/110, loss = 2.2016
# epoch 2 / 50, step 38/110, loss = 2.0176
# epoch 2 / 50, step 39/110, loss = 1.9919
# epoch 2 / 50, step 40/110, loss = 1.9655
# epoch 2 / 50, step 41/110, loss = 1.8089
# epoch 2 / 50, step 42/110, loss = 1.7640
# epoch 2 / 50, step 43/110, loss = 1.9143
# epoch 2 / 50, step 44/110, loss = 1.9780
# epoch 2 / 50, step 45/110, loss = 1.9483
# epoch 2 / 50, step 46/110, loss = 2.0939
# epoch 2 / 50, step 47/110, loss = 1.8904
# epoch 2 / 50, step 48/110, loss = 1.9702
# epoch 2 / 50, step 49/110, loss = 1.6697
# epoch 2 / 50, step 50/110, loss = 2.0403
# epoch 2 / 50, step 51/110, loss = 1.7985
# epoch 2 / 50, step 52/110, loss = 1.9423
# epoch 2 / 50, step 53/110, loss = 1.6709
# epoch 2 / 50, step 54/110, loss = 1.6146
# epoch 2 / 50, step 55/110, loss = 2.1463
# epoch 2 / 50, step 56/110, loss = 1.9005
# epoch 2 / 50, step 57/110, loss = 2.0646
# epoch 2 / 50, step 58/110, loss = 2.0219
# epoch 2 / 50, step 59/110, loss = 1.7259
# epoch 2 / 50, step 60/110, loss = 2.1532
# epoch 2 / 50, step 61/110, loss = 1.6845
# epoch 2 / 50, step 62/110, loss = 2.0978
# epoch 2 / 50, step 63/110, loss = 1.9472
# epoch 2 / 50, step 64/110, loss = 1.9446
# epoch 2 / 50, step 65/110, loss = 1.7933
# epoch 2 / 50, step 66/110, loss = 2.2427
# epoch 2 / 50, step 67/110, loss = 2.1530
# epoch 2 / 50, step 68/110, loss = 1.8748
# epoch 2 / 50, step 69/110, loss = 1.9773
# epoch 2 / 50, step 70/110, loss = 2.1146
# epoch 2 / 50, step 71/110, loss = 1.8529
# epoch 2 / 50, step 72/110, loss = 2.3574
# epoch 2 / 50, step 73/110, loss = 1.7378
# epoch 2 / 50, step 74/110, loss = 1.8437
# epoch 2 / 50, step 75/110, loss = 2.2437
# epoch 2 / 50, step 76/110, loss = 1.9510
# epoch 2 / 50, step 77/110, loss = 2.0944
# epoch 2 / 50, step 78/110, loss = 1.7518
# epoch 2 / 50, step 79/110, loss = 1.7330
# epoch 2 / 50, step 80/110, loss = 1.9688
# epoch 2 / 50, step 81/110, loss = 1.6153
# epoch 2 / 50, step 82/110, loss = 2.2109
# epoch 2 / 50, step 83/110, loss = 2.0931
# epoch 2 / 50, step 84/110, loss = 1.9779
# epoch 2 / 50, step 85/110, loss = 2.1188
# epoch 2 / 50, step 86/110, loss = 2.1570
# epoch 2 / 50, step 87/110, loss = 2.2983
# epoch 2 / 50, step 88/110, loss = 1.6880
# epoch 2 / 50, step 89/110, loss = 1.9441
# epoch 2 / 50, step 90/110, loss = 1.9917
# epoch 2 / 50, step 91/110, loss = 1.8022
# epoch 2 / 50, step 92/110, loss = 1.9000
# epoch 2 / 50, step 93/110, loss = 2.0646
# epoch 2 / 50, step 94/110, loss = 2.1448
# epoch 2 / 50, step 95/110, loss = 2.1001
# epoch 2 / 50, step 96/110, loss = 1.9797
# epoch 2 / 50, step 97/110, loss = 2.1204
# epoch 2 / 50, step 98/110, loss = 1.6724
# epoch 2 / 50, step 99/110, loss = 1.9359
# epoch 2 / 50, step 100/110, loss = 1.9077
# epoch 2 / 50, step 101/110, loss = 2.1366
# epoch 2 / 50, step 102/110, loss = 1.9727
# epoch 2 / 50, step 103/110, loss = 1.8917
# epoch 2 / 50, step 104/110, loss = 1.7845
# epoch 2 / 50, step 105/110, loss = 1.7099
# epoch 2 / 50, step 106/110, loss = 1.7875
# epoch 2 / 50, step 107/110, loss = 2.1662
# epoch 2 / 50, step 108/110, loss = 1.7720
# epoch 2 / 50, step 109/110, loss = 1.9217
# epoch 2 / 50, step 110/110, loss = 1.7931
# epoch 2 / 50, step 1/28, loss = 1.9786
# epoch 2 / 50, step 2/28, loss = 2.0498
# epoch 2 / 50, step 3/28, loss = 1.9912
# epoch 2 / 50, step 4/28, loss = 2.0087
# epoch 2 / 50, step 5/28, loss = 2.0057
# epoch 2 / 50, step 6/28, loss = 1.9099
# epoch 2 / 50, step 7/28, loss = 1.8243
# epoch 2 / 50, step 8/28, loss = 2.0700
# epoch 2 / 50, step 9/28, loss = 2.1252
# epoch 2 / 50, step 10/28, loss = 2.0058
# epoch 2 / 50, step 11/28, loss = 1.9396
# epoch 2 / 50, step 12/28, loss = 1.6942
# epoch 2 / 50, step 13/28, loss = 2.1883
# epoch 2 / 50, step 14/28, loss = 1.8325
# epoch 2 / 50, step 15/28, loss = 1.7716
# epoch 2 / 50, step 16/28, loss = 2.0353
# epoch 2 / 50, step 17/28, loss = 2.1287
# epoch 2 / 50, step 18/28, loss = 2.1273
# epoch 2 / 50, step 19/28, loss = 1.9667
# epoch 2 / 50, step 20/28, loss = 1.8079
# epoch 2 / 50, step 21/28, loss = 1.9012
# epoch 2 / 50, step 22/28, loss = 2.0029
# epoch 2 / 50, step 23/28, loss = 1.8480
# epoch 2 / 50, step 24/28, loss = 1.9488
# epoch 2 / 50, step 25/28, loss = 2.0960
# epoch 2 / 50, step 26/28, loss = 2.1033
# epoch 2 / 50, step 27/28, loss = 2.0237
# epoch 2 / 50, step 28/28, loss = 1.9086
# epoch 3 / 50, step 1/110, loss = 1.8037
# epoch 3 / 50, step 2/110, loss = 1.7161
# epoch 3 / 50, step 3/110, loss = 1.7545
# epoch 3 / 50, step 4/110, loss = 1.7750
# epoch 3 / 50, step 5/110, loss = 1.6190
# epoch 3 / 50, step 6/110, loss = 1.8840
# epoch 3 / 50, step 7/110, loss = 2.0778
# epoch 3 / 50, step 8/110, loss = 2.2275
# epoch 3 / 50, step 9/110, loss = 1.6885
# epoch 3 / 50, step 10/110, loss = 1.9628
# epoch 3 / 50, step 11/110, loss = 1.8399
# epoch 3 / 50, step 12/110, loss = 1.7619
# epoch 3 / 50, step 13/110, loss = 1.9586
# epoch 3 / 50, step 14/110, loss = 2.0505
# epoch 3 / 50, step 15/110, loss = 1.9558
# epoch 3 / 50, step 16/110, loss = 1.5638
# epoch 3 / 50, step 17/110, loss = 1.8851
# epoch 3 / 50, step 18/110, loss = 1.7104
# epoch 3 / 50, step 19/110, loss = 1.8487
# epoch 3 / 50, step 20/110, loss = 1.7600
# epoch 3 / 50, step 21/110, loss = 2.0226
# epoch 3 / 50, step 22/110, loss = 1.6607
# epoch 3 / 50, step 23/110, loss = 1.9933
# epoch 3 / 50, step 24/110, loss = 1.7740
# epoch 3 / 50, step 25/110, loss = 1.7807
# epoch 3 / 50, step 26/110, loss = 1.8194
# epoch 3 / 50, step 27/110, loss = 2.1543
# epoch 3 / 50, step 28/110, loss = 2.1244
# epoch 3 / 50, step 29/110, loss = 1.8843
# epoch 3 / 50, step 30/110, loss = 2.2193
# epoch 3 / 50, step 31/110, loss = 1.8764
# epoch 3 / 50, step 32/110, loss = 1.8481
# epoch 3 / 50, step 33/110, loss = 2.0976
# epoch 3 / 50, step 34/110, loss = 1.9739
# epoch 3 / 50, step 35/110, loss = 1.9256
# epoch 3 / 50, step 36/110, loss = 1.5507
# epoch 3 / 50, step 37/110, loss = 1.8367
# epoch 3 / 50, step 38/110, loss = 2.0894
# epoch 3 / 50, step 39/110, loss = 2.0512
# epoch 3 / 50, step 40/110, loss = 2.1018
# epoch 3 / 50, step 41/110, loss = 1.7668
# epoch 3 / 50, step 42/110, loss = 2.0164
# epoch 3 / 50, step 43/110, loss = 2.0502
# epoch 3 / 50, step 44/110, loss = 2.0583
# epoch 3 / 50, step 45/110, loss = 1.9248
# epoch 3 / 50, step 46/110, loss = 1.9787
# epoch 3 / 50, step 47/110, loss = 1.7029
# epoch 3 / 50, step 48/110, loss = 1.9878
# epoch 3 / 50, step 49/110, loss = 2.0543
# epoch 3 / 50, step 50/110, loss = 2.1756
# epoch 3 / 50, step 51/110, loss = 2.1616
# epoch 3 / 50, step 52/110, loss = 1.8392
# epoch 3 / 50, step 53/110, loss = 2.1195
# epoch 3 / 50, step 54/110, loss = 1.7594
# epoch 3 / 50, step 55/110, loss = 1.5614
# epoch 3 / 50, step 56/110, loss = 1.7846
# epoch 3 / 50, step 57/110, loss = 1.9862
# epoch 3 / 50, step 58/110, loss = 1.8617
# epoch 3 / 50, step 59/110, loss = 2.2802
# epoch 3 / 50, step 60/110, loss = 1.5725
# epoch 3 / 50, step 61/110, loss = 2.1009
# epoch 3 / 50, step 62/110, loss = 1.7864
# epoch 3 / 50, step 63/110, loss = 1.7667
# epoch 3 / 50, step 64/110, loss = 1.9025
# epoch 3 / 50, step 65/110, loss = 2.2590
# epoch 3 / 50, step 66/110, loss = 1.7709
# epoch 3 / 50, step 67/110, loss = 2.1153
# epoch 3 / 50, step 68/110, loss = 1.8145
# epoch 3 / 50, step 69/110, loss = 2.0033
# epoch 3 / 50, step 70/110, loss = 1.8513
# epoch 3 / 50, step 71/110, loss = 1.7374
# epoch 3 / 50, step 72/110, loss = 1.8031
# epoch 3 / 50, step 73/110, loss = 1.9521
# epoch 3 / 50, step 74/110, loss = 1.8179
# epoch 3 / 50, step 75/110, loss = 1.4506
# epoch 3 / 50, step 76/110, loss = 1.7504
# epoch 3 / 50, step 77/110, loss = 2.0127
# epoch 3 / 50, step 78/110, loss = 2.0620
# epoch 3 / 50, step 79/110, loss = 2.1377
# epoch 3 / 50, step 80/110, loss = 1.8223
# epoch 3 / 50, step 81/110, loss = 1.9955
# epoch 3 / 50, step 82/110, loss = 2.0131
# epoch 3 / 50, step 83/110, loss = 1.9816
# epoch 3 / 50, step 84/110, loss = 2.1107
# epoch 3 / 50, step 85/110, loss = 1.8332
# epoch 3 / 50, step 86/110, loss = 2.1025
# epoch 3 / 50, step 87/110, loss = 2.0696
# epoch 3 / 50, step 88/110, loss = 1.6953
# epoch 3 / 50, step 89/110, loss = 2.4115
# epoch 3 / 50, step 90/110, loss = 2.3237
# epoch 3 / 50, step 91/110, loss = 1.8719
# epoch 3 / 50, step 92/110, loss = 1.8513
# epoch 3 / 50, step 93/110, loss = 1.8503
# epoch 3 / 50, step 94/110, loss = 1.9484
# epoch 3 / 50, step 95/110, loss = 2.1332
# epoch 3 / 50, step 96/110, loss = 2.1869
# epoch 3 / 50, step 97/110, loss = 2.2044
# epoch 3 / 50, step 98/110, loss = 1.4598
# epoch 3 / 50, step 99/110, loss = 1.7785
# epoch 3 / 50, step 100/110, loss = 1.7964
# epoch 3 / 50, step 101/110, loss = 1.9365
# epoch 3 / 50, step 102/110, loss = 1.9257
# epoch 3 / 50, step 103/110, loss = 1.8226
# epoch 3 / 50, step 104/110, loss = 1.8650
# epoch 3 / 50, step 105/110, loss = 1.8755
# epoch 3 / 50, step 106/110, loss = 1.7409
# epoch 3 / 50, step 107/110, loss = 1.9016
# epoch 3 / 50, step 108/110, loss = 2.1130
# epoch 3 / 50, step 109/110, loss = 1.8790
# epoch 3 / 50, step 110/110, loss = 1.7583
# epoch 3 / 50, step 1/28, loss = 1.9566
# epoch 3 / 50, step 2/28, loss = 2.0801
# epoch 3 / 50, step 3/28, loss = 2.0194
# epoch 3 / 50, step 4/28, loss = 2.1612
# epoch 3 / 50, step 5/28, loss = 1.8718
# epoch 3 / 50, step 6/28, loss = 1.8662
# epoch 3 / 50, step 7/28, loss = 1.8821
# epoch 3 / 50, step 8/28, loss = 1.9017
# epoch 3 / 50, step 9/28, loss = 1.9712
# epoch 3 / 50, step 10/28, loss = 1.8206
# epoch 3 / 50, step 11/28, loss = 2.0666
# epoch 3 / 50, step 12/28, loss = 1.8948
# epoch 3 / 50, step 13/28, loss = 2.0636
# epoch 3 / 50, step 14/28, loss = 1.9625
# epoch 3 / 50, step 15/28, loss = 1.7664
# epoch 3 / 50, step 16/28, loss = 2.0710
# epoch 3 / 50, step 17/28, loss = 2.0992
# epoch 3 / 50, step 18/28, loss = 2.0184
# epoch 3 / 50, step 19/28, loss = 1.8283
# epoch 3 / 50, step 20/28, loss = 1.7703
# epoch 3 / 50, step 21/28, loss = 1.8434
# epoch 3 / 50, step 22/28, loss = 1.9136
# epoch 3 / 50, step 23/28, loss = 1.9469
# epoch 3 / 50, step 24/28, loss = 1.9108
# epoch 3 / 50, step 25/28, loss = 2.0530
# epoch 3 / 50, step 26/28, loss = 2.1066
# epoch 3 / 50, step 27/28, loss = 1.9051
# epoch 3 / 50, step 28/28, loss = 2.0254
# epoch 4 / 50, step 1/110, loss = 1.7740
# epoch 4 / 50, step 2/110, loss = 1.8176
# epoch 4 / 50, step 3/110, loss = 1.8958
# epoch 4 / 50, step 4/110, loss = 1.7450
# epoch 4 / 50, step 5/110, loss = 1.9110
# epoch 4 / 50, step 6/110, loss = 1.7343
# epoch 4 / 50, step 7/110, loss = 2.0176
# epoch 4 / 50, step 8/110, loss = 2.0119
# epoch 4 / 50, step 9/110, loss = 2.0134
# epoch 4 / 50, step 10/110, loss = 2.0048
# epoch 4 / 50, step 11/110, loss = 1.8669
# epoch 4 / 50, step 12/110, loss = 1.7386
# epoch 4 / 50, step 13/110, loss = 1.9876
# epoch 4 / 50, step 14/110, loss = 1.8661
# epoch 4 / 50, step 15/110, loss = 1.8030
# epoch 4 / 50, step 16/110, loss = 1.7294
# epoch 4 / 50, step 17/110, loss = 1.7013
# epoch 4 / 50, step 18/110, loss = 1.6973
# epoch 4 / 50, step 19/110, loss = 1.9000
# epoch 4 / 50, step 20/110, loss = 1.7324
# epoch 4 / 50, step 21/110, loss = 1.9650
# epoch 4 / 50, step 22/110, loss = 1.8202
# epoch 4 / 50, step 23/110, loss = 1.8834
# epoch 4 / 50, step 24/110, loss = 1.8953
# epoch 4 / 50, step 25/110, loss = 2.0026
# epoch 4 / 50, step 26/110, loss = 1.8723
# epoch 4 / 50, step 27/110, loss = 1.9332
# epoch 4 / 50, step 28/110, loss = 2.1338
# epoch 4 / 50, step 29/110, loss = 1.7564
# epoch 4 / 50, step 30/110, loss = 2.0801
# epoch 4 / 50, step 31/110, loss = 1.9217
# epoch 4 / 50, step 32/110, loss = 1.9724
# epoch 4 / 50, step 33/110, loss = 1.8917
# epoch 4 / 50, step 34/110, loss = 1.6759
# epoch 4 / 50, step 35/110, loss = 1.8088
# epoch 4 / 50, step 36/110, loss = 1.6854
# epoch 4 / 50, step 37/110, loss = 1.8526
# epoch 4 / 50, step 38/110, loss = 1.9383
# epoch 4 / 50, step 39/110, loss = 1.8347
# epoch 4 / 50, step 40/110, loss = 1.8466
# epoch 4 / 50, step 41/110, loss = 1.9048
# epoch 4 / 50, step 42/110, loss = 2.2118
# epoch 4 / 50, step 43/110, loss = 1.9200
# epoch 4 / 50, step 44/110, loss = 1.8317
# epoch 4 / 50, step 45/110, loss = 2.0676
# epoch 4 / 50, step 46/110, loss = 1.9960
# epoch 4 / 50, step 47/110, loss = 1.7712
# epoch 4 / 50, step 48/110, loss = 1.6332
# epoch 4 / 50, step 49/110, loss = 1.8694
# epoch 4 / 50, step 50/110, loss = 1.9038
# epoch 4 / 50, step 51/110, loss = 1.9858
# epoch 4 / 50, step 52/110, loss = 2.0239
# epoch 4 / 50, step 53/110, loss = 2.1625
# epoch 4 / 50, step 54/110, loss = 2.1117
# epoch 4 / 50, step 55/110, loss = 1.8375
# epoch 4 / 50, step 56/110, loss = 1.7666
# epoch 4 / 50, step 57/110, loss = 1.8741
# epoch 4 / 50, step 58/110, loss = 1.8694
# epoch 4 / 50, step 59/110, loss = 1.8238
# epoch 4 / 50, step 60/110, loss = 1.9663
# epoch 4 / 50, step 61/110, loss = 2.0931
# epoch 4 / 50, step 62/110, loss = 2.1345
# epoch 4 / 50, step 63/110, loss = 1.7095
# epoch 4 / 50, step 64/110, loss = 1.9455
# epoch 4 / 50, step 65/110, loss = 1.9455
# epoch 4 / 50, step 66/110, loss = 1.9754
# epoch 4 / 50, step 67/110, loss = 1.8499
# epoch 4 / 50, step 68/110, loss = 2.0643
# epoch 4 / 50, step 69/110, loss = 1.6352
# epoch 4 / 50, step 70/110, loss = 1.9403
# epoch 4 / 50, step 71/110, loss = 2.0833
# epoch 4 / 50, step 72/110, loss = 2.0373
# epoch 4 / 50, step 73/110, loss = 1.9864
# epoch 4 / 50, step 74/110, loss = 2.1518
# epoch 4 / 50, step 75/110, loss = 1.7180
# epoch 4 / 50, step 76/110, loss = 1.7169
# epoch 4 / 50, step 77/110, loss = 1.7660
# epoch 4 / 50, step 78/110, loss = 1.7470
# epoch 4 / 50, step 79/110, loss = 2.0284
# epoch 4 / 50, step 80/110, loss = 2.0124
# epoch 4 / 50, step 81/110, loss = 2.0678
# epoch 4 / 50, step 82/110, loss = 1.9405
# epoch 4 / 50, step 83/110, loss = 1.9238
# epoch 4 / 50, step 84/110, loss = 1.8991
# epoch 4 / 50, step 85/110, loss = 1.8472
# epoch 4 / 50, step 86/110, loss = 1.7638
# epoch 4 / 50, step 87/110, loss = 2.0463
# epoch 4 / 50, step 88/110, loss = 1.9143
# epoch 4 / 50, step 89/110, loss = 2.2546
# epoch 4 / 50, step 90/110, loss = 2.2014
# epoch 4 / 50, step 91/110, loss = 2.1740
# epoch 4 / 50, step 92/110, loss = 1.6181
# epoch 4 / 50, step 93/110, loss = 2.0913
# epoch 4 / 50, step 94/110, loss = 1.8477
# epoch 4 / 50, step 95/110, loss = 2.0290
# epoch 4 / 50, step 96/110, loss = 1.6076
# epoch 4 / 50, step 97/110, loss = 1.7849
# epoch 4 / 50, step 98/110, loss = 1.8587
# epoch 4 / 50, step 99/110, loss = 2.0319
# epoch 4 / 50, step 100/110, loss = 1.7413
# epoch 4 / 50, step 101/110, loss = 2.2327
# epoch 4 / 50, step 102/110, loss = 1.8520
# epoch 4 / 50, step 103/110, loss = 2.2210
# epoch 4 / 50, step 104/110, loss = 2.1862
# epoch 4 / 50, step 105/110, loss = 1.8469
# epoch 4 / 50, step 106/110, loss = 2.0929
# epoch 4 / 50, step 107/110, loss = 2.0568
# epoch 4 / 50, step 108/110, loss = 1.7683
# epoch 4 / 50, step 109/110, loss = 1.8824
# epoch 4 / 50, step 110/110, loss = 1.8375
# epoch 4 / 50, step 1/28, loss = 2.0205
# epoch 4 / 50, step 2/28, loss = 2.0922
# epoch 4 / 50, step 3/28, loss = 2.0480
# epoch 4 / 50, step 4/28, loss = 2.0550
# epoch 4 / 50, step 5/28, loss = 2.1016
# epoch 4 / 50, step 6/28, loss = 1.8932
# epoch 4 / 50, step 7/28, loss = 1.8660
# epoch 4 / 50, step 8/28, loss = 1.9935
# epoch 4 / 50, step 9/28, loss = 1.9702
# epoch 4 / 50, step 10/28, loss = 1.8952
# epoch 4 / 50, step 11/28, loss = 1.9041
# epoch 4 / 50, step 12/28, loss = 1.7761
# epoch 4 / 50, step 13/28, loss = 2.1333
# epoch 4 / 50, step 14/28, loss = 1.9005
# epoch 4 / 50, step 15/28, loss = 1.6452
# epoch 4 / 50, step 16/28, loss = 1.9496
# epoch 4 / 50, step 17/28, loss = 2.1047
# epoch 4 / 50, step 18/28, loss = 2.0747
# epoch 4 / 50, step 19/28, loss = 1.8141
# epoch 4 / 50, step 20/28, loss = 1.8086
# epoch 4 / 50, step 21/28, loss = 1.9150
# epoch 4 / 50, step 22/28, loss = 1.9596
# epoch 4 / 50, step 23/28, loss = 1.9071
# epoch 4 / 50, step 24/28, loss = 1.9777
# epoch 4 / 50, step 25/28, loss = 1.9147
# epoch 4 / 50, step 26/28, loss = 2.0494
# epoch 4 / 50, step 27/28, loss = 1.9364
# epoch 4 / 50, step 28/28, loss = 2.0439
# epoch 5 / 50, step 1/110, loss = 1.9118
# epoch 5 / 50, step 2/110, loss = 2.0660
# epoch 5 / 50, step 3/110, loss = 2.2441
# epoch 5 / 50, step 4/110, loss = 1.9238
# epoch 5 / 50, step 5/110, loss = 1.8488
# epoch 5 / 50, step 6/110, loss = 1.7491
# epoch 5 / 50, step 7/110, loss = 1.7312
# epoch 5 / 50, step 8/110, loss = 1.8427
# epoch 5 / 50, step 9/110, loss = 2.0619
# epoch 5 / 50, step 10/110, loss = 1.7915
# epoch 5 / 50, step 11/110, loss = 1.9427
# epoch 5 / 50, step 12/110, loss = 2.0238
# epoch 5 / 50, step 13/110, loss = 1.4487
# epoch 5 / 50, step 14/110, loss = 1.6326
# epoch 5 / 50, step 15/110, loss = 1.8293
# epoch 5 / 50, step 16/110, loss = 1.9537
# epoch 5 / 50, step 17/110, loss = 1.8824
# epoch 5 / 50, step 18/110, loss = 1.7484
# epoch 5 / 50, step 19/110, loss = 1.9927
# epoch 5 / 50, step 20/110, loss = 1.8692
# epoch 5 / 50, step 21/110, loss = 1.9586
# epoch 5 / 50, step 22/110, loss = 2.0206
# epoch 5 / 50, step 23/110, loss = 1.8746
# epoch 5 / 50, step 24/110, loss = 1.5640
# epoch 5 / 50, step 25/110, loss = 1.8383
# epoch 5 / 50, step 26/110, loss = 1.9011
# epoch 5 / 50, step 27/110, loss = 2.1128
# epoch 5 / 50, step 28/110, loss = 1.5802
# epoch 5 / 50, step 29/110, loss = 1.6898
# epoch 5 / 50, step 30/110, loss = 1.7353
# epoch 5 / 50, step 31/110, loss = 1.6238
# epoch 5 / 50, step 32/110, loss = 1.9888
# epoch 5 / 50, step 33/110, loss = 1.7524
# epoch 5 / 50, step 34/110, loss = 1.3810
# epoch 5 / 50, step 35/110, loss = 1.7653
# epoch 5 / 50, step 36/110, loss = 1.9414
# epoch 5 / 50, step 37/110, loss = 1.9261
# epoch 5 / 50, step 38/110, loss = 1.8226
# epoch 5 / 50, step 39/110, loss = 1.9277
# epoch 5 / 50, step 40/110, loss = 1.9432
# epoch 5 / 50, step 41/110, loss = 1.8809
# epoch 5 / 50, step 42/110, loss = 1.9997
# epoch 5 / 50, step 43/110, loss = 1.5645
# epoch 5 / 50, step 44/110, loss = 2.0289
# epoch 5 / 50, step 45/110, loss = 1.6530
# epoch 5 / 50, step 46/110, loss = 2.0082
# epoch 5 / 50, step 47/110, loss = 2.1464
# epoch 5 / 50, step 48/110, loss = 1.9381
# epoch 5 / 50, step 49/110, loss = 1.9136
# epoch 5 / 50, step 50/110, loss = 1.7677
# epoch 5 / 50, step 51/110, loss = 2.1384
# epoch 5 / 50, step 52/110, loss = 1.9057
# epoch 5 / 50, step 53/110, loss = 1.8032
# epoch 5 / 50, step 54/110, loss = 2.1839
# epoch 5 / 50, step 55/110, loss = 1.7707
# epoch 5 / 50, step 56/110, loss = 1.9594
# epoch 5 / 50, step 57/110, loss = 1.8701
# epoch 5 / 50, step 58/110, loss = 1.8810
# epoch 5 / 50, step 59/110, loss = 1.9923
# epoch 5 / 50, step 60/110, loss = 1.8949
# epoch 5 / 50, step 61/110, loss = 1.7409
# epoch 5 / 50, step 62/110, loss = 1.6494
# epoch 5 / 50, step 63/110, loss = 1.7772
# epoch 5 / 50, step 64/110, loss = 1.6026
# epoch 5 / 50, step 65/110, loss = 2.1437
# epoch 5 / 50, step 66/110, loss = 2.0241
# epoch 5 / 50, step 67/110, loss = 1.6467
# epoch 5 / 50, step 68/110, loss = 1.9047
# epoch 5 / 50, step 69/110, loss = 1.8358
# epoch 5 / 50, step 70/110, loss = 1.8606
# epoch 5 / 50, step 71/110, loss = 1.9589
# epoch 5 / 50, step 72/110, loss = 1.9107
# epoch 5 / 50, step 73/110, loss = 1.7574
# epoch 5 / 50, step 74/110, loss = 1.7463
# epoch 5 / 50, step 75/110, loss = 1.8924
# epoch 5 / 50, step 76/110, loss = 1.7335
# epoch 5 / 50, step 77/110, loss = 1.9604
# epoch 5 / 50, step 78/110, loss = 1.5532
# epoch 5 / 50, step 79/110, loss = 1.9265
# epoch 5 / 50, step 80/110, loss = 1.8009
# epoch 5 / 50, step 81/110, loss = 1.7560
# epoch 5 / 50, step 82/110, loss = 1.9371
# epoch 5 / 50, step 83/110, loss = 2.0481
# epoch 5 / 50, step 84/110, loss = 1.7647
# epoch 5 / 50, step 85/110, loss = 1.6458
# epoch 5 / 50, step 86/110, loss = 1.8462
# epoch 5 / 50, step 87/110, loss = 1.7520
# epoch 5 / 50, step 88/110, loss = 1.7920
# epoch 5 / 50, step 89/110, loss = 1.8508
# epoch 5 / 50, step 90/110, loss = 2.1838
# epoch 5 / 50, step 91/110, loss = 1.7021
# epoch 5 / 50, step 92/110, loss = 1.6309
# epoch 5 / 50, step 93/110, loss = 2.1096
# epoch 5 / 50, step 94/110, loss = 2.1957
# epoch 5 / 50, step 95/110, loss = 1.9725
# epoch 5 / 50, step 96/110, loss = 1.7701
# epoch 5 / 50, step 97/110, loss = 1.8727
# epoch 5 / 50, step 98/110, loss = 1.7156
# epoch 5 / 50, step 99/110, loss = 1.4664
# epoch 5 / 50, step 100/110, loss = 1.5654
# epoch 5 / 50, step 101/110, loss = 2.0735
# epoch 5 / 50, step 102/110, loss = 2.0235
# epoch 5 / 50, step 103/110, loss = 1.6331
# epoch 5 / 50, step 104/110, loss = 1.7984
# epoch 5 / 50, step 105/110, loss = 1.8233
# epoch 5 / 50, step 106/110, loss = 1.7267
# epoch 5 / 50, step 107/110, loss = 1.6775
# epoch 5 / 50, step 108/110, loss = 1.7396
# epoch 5 / 50, step 109/110, loss = 2.1852
# epoch 5 / 50, step 110/110, loss = 1.7492
# epoch 5 / 50, step 1/28, loss = 2.1133
# epoch 5 / 50, step 2/28, loss = 2.0862
# epoch 5 / 50, step 3/28, loss = 2.0011
# epoch 5 / 50, step 4/28, loss = 2.2030
# epoch 5 / 50, step 5/28, loss = 2.2277
# epoch 5 / 50, step 6/28, loss = 2.0252
# epoch 5 / 50, step 7/28, loss = 1.8062
# epoch 5 / 50, step 8/28, loss = 1.9827
# epoch 5 / 50, step 9/28, loss = 2.1422
# epoch 5 / 50, step 10/28, loss = 1.9242
# epoch 5 / 50, step 11/28, loss = 1.8612
# epoch 5 / 50, step 12/28, loss = 1.7226
# epoch 5 / 50, step 13/28, loss = 2.1531
# epoch 5 / 50, step 14/28, loss = 1.9478
# epoch 5 / 50, step 15/28, loss = 1.5819
# epoch 5 / 50, step 16/28, loss = 2.2101
# epoch 5 / 50, step 17/28, loss = 2.0867
# epoch 5 / 50, step 18/28, loss = 2.0388
# epoch 5 / 50, step 19/28, loss = 2.0383
# epoch 5 / 50, step 20/28, loss = 1.8992
# epoch 5 / 50, step 21/28, loss = 1.8533
# epoch 5 / 50, step 22/28, loss = 2.1980
# epoch 5 / 50, step 23/28, loss = 1.9304
# epoch 5 / 50, step 24/28, loss = 2.0780
# epoch 5 / 50, step 25/28, loss = 1.9742
# epoch 5 / 50, step 26/28, loss = 2.2536
# epoch 5 / 50, step 27/28, loss = 2.1161
# epoch 5 / 50, step 28/28, loss = 1.9957
# epoch 6 / 50, step 1/110, loss = 1.9319
# epoch 6 / 50, step 2/110, loss = 1.8429
# epoch 6 / 50, step 3/110, loss = 2.2203
# epoch 6 / 50, step 4/110, loss = 1.8455
# epoch 6 / 50, step 5/110, loss = 2.0273
# epoch 6 / 50, step 6/110, loss = 2.0805
# epoch 6 / 50, step 7/110, loss = 1.6985
# epoch 6 / 50, step 8/110, loss = 2.3376
# epoch 6 / 50, step 9/110, loss = 1.6429
# epoch 6 / 50, step 10/110, loss = 1.8373
# epoch 6 / 50, step 11/110, loss = 1.6147
# epoch 6 / 50, step 12/110, loss = 1.6846
# epoch 6 / 50, step 13/110, loss = 1.9214
# epoch 6 / 50, step 14/110, loss = 1.7287
# epoch 6 / 50, step 15/110, loss = 1.8565
# epoch 6 / 50, step 16/110, loss = 1.8444
# epoch 6 / 50, step 17/110, loss = 1.9189
# epoch 6 / 50, step 18/110, loss = 1.7192
# epoch 6 / 50, step 19/110, loss = 1.8023
# epoch 6 / 50, step 20/110, loss = 1.6738
# epoch 6 / 50, step 21/110, loss = 1.5261
# epoch 6 / 50, step 22/110, loss = 1.8001
# epoch 6 / 50, step 23/110, loss = 2.0259
# epoch 6 / 50, step 24/110, loss = 1.6841
# epoch 6 / 50, step 25/110, loss = 2.1084
# epoch 6 / 50, step 26/110, loss = 1.9766
# epoch 6 / 50, step 27/110, loss = 1.8640
# epoch 6 / 50, step 28/110, loss = 1.5967
# epoch 6 / 50, step 29/110, loss = 1.9850
# epoch 6 / 50, step 30/110, loss = 1.5907
# epoch 6 / 50, step 31/110, loss = 1.5298
# epoch 6 / 50, step 32/110, loss = 2.0668
# epoch 6 / 50, step 33/110, loss = 1.9433
# epoch 6 / 50, step 34/110, loss = 2.0975
# epoch 6 / 50, step 35/110, loss = 1.7895
# epoch 6 / 50, step 36/110, loss = 1.8599
# epoch 6 / 50, step 37/110, loss = 1.5982
# epoch 6 / 50, step 38/110, loss = 1.6966
# epoch 6 / 50, step 39/110, loss = 1.8244
# epoch 6 / 50, step 40/110, loss = 1.6002
# epoch 6 / 50, step 41/110, loss = 1.8813
# epoch 6 / 50, step 42/110, loss = 1.8510
# epoch 6 / 50, step 43/110, loss = 1.6322
# epoch 6 / 50, step 44/110, loss = 1.9770
# epoch 6 / 50, step 45/110, loss = 1.7932
# epoch 6 / 50, step 46/110, loss = 1.7843
# epoch 6 / 50, step 47/110, loss = 1.7567
# epoch 6 / 50, step 48/110, loss = 2.1522
# epoch 6 / 50, step 49/110, loss = 1.5111
# epoch 6 / 50, step 50/110, loss = 2.1641
# epoch 6 / 50, step 51/110, loss = 1.6182
# epoch 6 / 50, step 52/110, loss = 1.7225
# epoch 6 / 50, step 53/110, loss = 1.8296
# epoch 6 / 50, step 54/110, loss = 2.2244
# epoch 6 / 50, step 55/110, loss = 2.1227
# epoch 6 / 50, step 56/110, loss = 2.0232
# epoch 6 / 50, step 57/110, loss = 1.8826
# epoch 6 / 50, step 58/110, loss = 1.8677
# epoch 6 / 50, step 59/110, loss = 1.6049
# epoch 6 / 50, step 60/110, loss = 1.9372
# epoch 6 / 50, step 61/110, loss = 2.4003
# epoch 6 / 50, step 62/110, loss = 1.7677
# epoch 6 / 50, step 63/110, loss = 1.9136
# epoch 6 / 50, step 64/110, loss = 1.5853
# epoch 6 / 50, step 65/110, loss = 1.9816
# epoch 6 / 50, step 66/110, loss = 1.6335
# epoch 6 / 50, step 67/110, loss = 1.8056
# epoch 6 / 50, step 68/110, loss = 2.1424
# epoch 6 / 50, step 69/110, loss = 1.8698
# epoch 6 / 50, step 70/110, loss = 1.8778
# epoch 6 / 50, step 71/110, loss = 1.7658
# epoch 6 / 50, step 72/110, loss = 1.8866
# epoch 6 / 50, step 73/110, loss = 1.9946
# epoch 6 / 50, step 74/110, loss = 2.1124
# epoch 6 / 50, step 75/110, loss = 1.7329
# epoch 6 / 50, step 76/110, loss = 1.6178
# epoch 6 / 50, step 77/110, loss = 2.0278
# epoch 6 / 50, step 78/110, loss = 1.7222
# epoch 6 / 50, step 79/110, loss = 1.8028
# epoch 6 / 50, step 80/110, loss = 1.9184
# epoch 6 / 50, step 81/110, loss = 1.7735
# epoch 6 / 50, step 82/110, loss = 2.1872
# epoch 6 / 50, step 83/110, loss = 1.7876
# epoch 6 / 50, step 84/110, loss = 1.8655
# epoch 6 / 50, step 85/110, loss = 1.9779
# epoch 6 / 50, step 86/110, loss = 1.7704
# epoch 6 / 50, step 87/110, loss = 1.6956
# epoch 6 / 50, step 88/110, loss = 1.9758
# epoch 6 / 50, step 89/110, loss = 1.7384
# epoch 6 / 50, step 90/110, loss = 1.9702
# epoch 6 / 50, step 91/110, loss = 1.7807
# epoch 6 / 50, step 92/110, loss = 2.1445
# epoch 6 / 50, step 93/110, loss = 1.9653
# epoch 6 / 50, step 94/110, loss = 2.0785
# epoch 6 / 50, step 95/110, loss = 1.6617
# epoch 6 / 50, step 96/110, loss = 1.7535
# epoch 6 / 50, step 97/110, loss = 1.7022
# epoch 6 / 50, step 98/110, loss = 1.9417
# epoch 6 / 50, step 99/110, loss = 1.6807
# epoch 6 / 50, step 100/110, loss = 2.0530
# epoch 6 / 50, step 101/110, loss = 1.8428
# epoch 6 / 50, step 102/110, loss = 1.9674
# epoch 6 / 50, step 103/110, loss = 1.7848
# epoch 6 / 50, step 104/110, loss = 1.8892
# epoch 6 / 50, step 105/110, loss = 1.8190
# epoch 6 / 50, step 106/110, loss = 1.6793
# epoch 6 / 50, step 107/110, loss = 1.6460
# epoch 6 / 50, step 108/110, loss = 1.6144
# epoch 6 / 50, step 109/110, loss = 1.5082
# epoch 6 / 50, step 110/110, loss = 1.9870
# epoch 6 / 50, step 1/28, loss = 2.0360
# epoch 6 / 50, step 2/28, loss = 2.0496
# epoch 6 / 50, step 3/28, loss = 2.1545
# epoch 6 / 50, step 4/28, loss = 2.1376
# epoch 6 / 50, step 5/28, loss = 2.1087
# epoch 6 / 50, step 6/28, loss = 1.9699
# epoch 6 / 50, step 7/28, loss = 1.9611
# epoch 6 / 50, step 8/28, loss = 1.9730
# epoch 6 / 50, step 9/28, loss = 2.0269
# epoch 6 / 50, step 10/28, loss = 1.7489
# epoch 6 / 50, step 11/28, loss = 1.9907
# epoch 6 / 50, step 12/28, loss = 1.9235
# epoch 6 / 50, step 13/28, loss = 1.8372
# epoch 6 / 50, step 14/28, loss = 2.0694
# epoch 6 / 50, step 15/28, loss = 1.6636
# epoch 6 / 50, step 16/28, loss = 2.0717
# epoch 6 / 50, step 17/28, loss = 1.9971
# epoch 6 / 50, step 18/28, loss = 1.9727
# epoch 6 / 50, step 19/28, loss = 1.8499
# epoch 6 / 50, step 20/28, loss = 1.8820
# epoch 6 / 50, step 21/28, loss = 1.6706
# epoch 6 / 50, step 22/28, loss = 1.8790
# epoch 6 / 50, step 23/28, loss = 1.9555
# epoch 6 / 50, step 24/28, loss = 2.0243
# epoch 6 / 50, step 25/28, loss = 1.9791
# epoch 6 / 50, step 26/28, loss = 2.2217
# epoch 6 / 50, step 27/28, loss = 1.9326
# epoch 6 / 50, step 28/28, loss = 1.9402
# epoch 7 / 50, step 1/110, loss = 1.6292
# epoch 7 / 50, step 2/110, loss = 1.6410
# epoch 7 / 50, step 3/110, loss = 1.6351
# epoch 7 / 50, step 4/110, loss = 2.0052
# epoch 7 / 50, step 5/110, loss = 1.7141
# epoch 7 / 50, step 6/110, loss = 1.8173
# epoch 7 / 50, step 7/110, loss = 1.6476
# epoch 7 / 50, step 8/110, loss = 1.6369
# epoch 7 / 50, step 9/110, loss = 1.5796
# epoch 7 / 50, step 10/110, loss = 1.7392
# epoch 7 / 50, step 11/110, loss = 1.9077
# epoch 7 / 50, step 12/110, loss = 2.0517
# epoch 7 / 50, step 13/110, loss = 1.6492
# epoch 7 / 50, step 14/110, loss = 1.7890
# epoch 7 / 50, step 15/110, loss = 1.5996
# epoch 7 / 50, step 16/110, loss = 1.7954
# epoch 7 / 50, step 17/110, loss = 1.6579
# epoch 7 / 50, step 18/110, loss = 1.8460
# epoch 7 / 50, step 19/110, loss = 1.7757
# epoch 7 / 50, step 20/110, loss = 1.6443
# epoch 7 / 50, step 21/110, loss = 1.7923
# epoch 7 / 50, step 22/110, loss = 2.1632
# epoch 7 / 50, step 23/110, loss = 1.4317
# epoch 7 / 50, step 24/110, loss = 1.7364
# epoch 7 / 50, step 25/110, loss = 2.0449
# epoch 7 / 50, step 26/110, loss = 1.8012
# epoch 7 / 50, step 27/110, loss = 1.9782
# epoch 7 / 50, step 28/110, loss = 2.0333
# epoch 7 / 50, step 29/110, loss = 1.6472
# epoch 7 / 50, step 30/110, loss = 1.8624
# epoch 7 / 50, step 31/110, loss = 1.7503
# epoch 7 / 50, step 32/110, loss = 1.7636
# epoch 7 / 50, step 33/110, loss = 1.3569
# epoch 7 / 50, step 34/110, loss = 1.8822
# epoch 7 / 50, step 35/110, loss = 1.8536
# epoch 7 / 50, step 36/110, loss = 1.7136
# epoch 7 / 50, step 37/110, loss = 1.5791
# epoch 7 / 50, step 38/110, loss = 1.9841
# epoch 7 / 50, step 39/110, loss = 1.4264
# epoch 7 / 50, step 40/110, loss = 1.8263
# epoch 7 / 50, step 41/110, loss = 2.0155
# epoch 7 / 50, step 42/110, loss = 1.5990
# epoch 7 / 50, step 43/110, loss = 1.7832
# epoch 7 / 50, step 44/110, loss = 1.9251
# epoch 7 / 50, step 45/110, loss = 1.7710
# epoch 7 / 50, step 46/110, loss = 2.1105
# epoch 7 / 50, step 47/110, loss = 1.7492
# epoch 7 / 50, step 48/110, loss = 1.9827
# epoch 7 / 50, step 49/110, loss = 1.6718
# epoch 7 / 50, step 50/110, loss = 1.6844
# epoch 7 / 50, step 51/110, loss = 1.8510
# epoch 7 / 50, step 52/110, loss = 2.1554
# epoch 7 / 50, step 53/110, loss = 1.6237
# epoch 7 / 50, step 54/110, loss = 1.4762
# epoch 7 / 50, step 55/110, loss = 1.6995
# epoch 7 / 50, step 56/110, loss = 1.7608
# epoch 7 / 50, step 57/110, loss = 1.9098
# epoch 7 / 50, step 58/110, loss = 1.8009
# epoch 7 / 50, step 59/110, loss = 1.7220
# epoch 7 / 50, step 60/110, loss = 1.4261
# epoch 7 / 50, step 61/110, loss = 2.0814
# epoch 7 / 50, step 62/110, loss = 1.7723
# epoch 7 / 50, step 63/110, loss = 1.8035
# epoch 7 / 50, step 64/110, loss = 1.8847
# epoch 7 / 50, step 65/110, loss = 1.6354
# epoch 7 / 50, step 66/110, loss = 1.8840
# epoch 7 / 50, step 67/110, loss = 1.7826
# epoch 7 / 50, step 68/110, loss = 1.8201
# epoch 7 / 50, step 69/110, loss = 1.7962
# epoch 7 / 50, step 70/110, loss = 1.7142
# epoch 7 / 50, step 71/110, loss = 1.5403
# epoch 7 / 50, step 72/110, loss = 2.3481
# epoch 7 / 50, step 73/110, loss = 1.6777
# epoch 7 / 50, step 74/110, loss = 2.0572
# epoch 7 / 50, step 75/110, loss = 1.7726
# epoch 7 / 50, step 76/110, loss = 1.8598
# epoch 7 / 50, step 77/110, loss = 1.8539
# epoch 7 / 50, step 78/110, loss = 2.0566
# epoch 7 / 50, step 79/110, loss = 1.4921
# epoch 7 / 50, step 80/110, loss = 2.0031
# epoch 7 / 50, step 81/110, loss = 1.8412
# epoch 7 / 50, step 82/110, loss = 1.7054
# epoch 7 / 50, step 83/110, loss = 1.4280
# epoch 7 / 50, step 84/110, loss = 1.8838
# epoch 7 / 50, step 85/110, loss = 1.5929
# epoch 7 / 50, step 86/110, loss = 1.8173
# epoch 7 / 50, step 87/110, loss = 2.0474
# epoch 7 / 50, step 88/110, loss = 2.0568
# epoch 7 / 50, step 89/110, loss = 2.2695
# epoch 7 / 50, step 90/110, loss = 2.2939
# epoch 7 / 50, step 91/110, loss = 2.0014
# epoch 7 / 50, step 92/110, loss = 1.7724
# epoch 7 / 50, step 93/110, loss = 2.0138
# epoch 7 / 50, step 94/110, loss = 1.8783
# epoch 7 / 50, step 95/110, loss = 2.0735
# epoch 7 / 50, step 96/110, loss = 1.7376
# epoch 7 / 50, step 97/110, loss = 1.7054
# epoch 7 / 50, step 98/110, loss = 2.0487
# epoch 7 / 50, step 99/110, loss = 2.0183
# epoch 7 / 50, step 100/110, loss = 2.0331
# epoch 7 / 50, step 101/110, loss = 1.8945
# epoch 7 / 50, step 102/110, loss = 2.1942
# epoch 7 / 50, step 103/110, loss = 2.0350
# epoch 7 / 50, step 104/110, loss = 1.8096
# epoch 7 / 50, step 105/110, loss = 2.0751
# epoch 7 / 50, step 106/110, loss = 1.8289
# epoch 7 / 50, step 107/110, loss = 1.6950
# epoch 7 / 50, step 108/110, loss = 1.8647
# epoch 7 / 50, step 109/110, loss = 1.6587
# epoch 7 / 50, step 110/110, loss = 2.0911
# epoch 7 / 50, step 1/28, loss = 1.9553
# epoch 7 / 50, step 2/28, loss = 2.0468
# epoch 7 / 50, step 3/28, loss = 2.0719
# epoch 7 / 50, step 4/28, loss = 2.0859
# epoch 7 / 50, step 5/28, loss = 2.1161
# epoch 7 / 50, step 6/28, loss = 1.7700
# epoch 7 / 50, step 7/28, loss = 2.0040
# epoch 7 / 50, step 8/28, loss = 2.0303
# epoch 7 / 50, step 9/28, loss = 1.9050
# epoch 7 / 50, step 10/28, loss = 1.9393
# epoch 7 / 50, step 11/28, loss = 2.1264
# epoch 7 / 50, step 12/28, loss = 2.0442
# epoch 7 / 50, step 13/28, loss = 1.9435
# epoch 7 / 50, step 14/28, loss = 2.2337
# epoch 7 / 50, step 15/28, loss = 1.7853
# epoch 7 / 50, step 16/28, loss = 1.7824
# epoch 7 / 50, step 17/28, loss = 2.0863
# epoch 7 / 50, step 18/28, loss = 1.9928
# epoch 7 / 50, step 19/28, loss = 1.8472
# epoch 7 / 50, step 20/28, loss = 2.1122
# epoch 7 / 50, step 21/28, loss = 1.8167
# epoch 7 / 50, step 22/28, loss = 1.9002
# epoch 7 / 50, step 23/28, loss = 1.8585
# epoch 7 / 50, step 24/28, loss = 2.0667
# epoch 7 / 50, step 25/28, loss = 2.0805
# epoch 7 / 50, step 26/28, loss = 2.1683
# epoch 7 / 50, step 27/28, loss = 1.8349
# epoch 7 / 50, step 28/28, loss = 1.9246
# epoch 8 / 50, step 1/110, loss = 1.8491
# epoch 8 / 50, step 2/110, loss = 1.6886
# epoch 8 / 50, step 3/110, loss = 1.6694
# epoch 8 / 50, step 4/110, loss = 1.7197
# epoch 8 / 50, step 5/110, loss = 1.7436
# epoch 8 / 50, step 6/110, loss = 1.9054
# epoch 8 / 50, step 7/110, loss = 1.7403
# epoch 8 / 50, step 8/110, loss = 1.8019
# epoch 8 / 50, step 9/110, loss = 1.9464
# epoch 8 / 50, step 10/110, loss = 1.4473
# epoch 8 / 50, step 11/110, loss = 2.0781
# epoch 8 / 50, step 12/110, loss = 1.5850
# epoch 8 / 50, step 13/110, loss = 1.7931
# epoch 8 / 50, step 14/110, loss = 1.7591
# epoch 8 / 50, step 15/110, loss = 2.0087
# epoch 8 / 50, step 16/110, loss = 1.4689
# epoch 8 / 50, step 17/110, loss = 1.7844
# epoch 8 / 50, step 18/110, loss = 2.1725
# epoch 8 / 50, step 19/110, loss = 1.7038
# epoch 8 / 50, step 20/110, loss = 1.9777
# epoch 8 / 50, step 21/110, loss = 1.5973
# epoch 8 / 50, step 22/110, loss = 1.8162
# epoch 8 / 50, step 23/110, loss = 1.7064
# epoch 8 / 50, step 24/110, loss = 1.3875
# epoch 8 / 50, step 25/110, loss = 1.8951
# epoch 8 / 50, step 26/110, loss = 1.5487
# epoch 8 / 50, step 27/110, loss = 1.9198
# epoch 8 / 50, step 28/110, loss = 1.7491
# epoch 8 / 50, step 29/110, loss = 1.9912
# epoch 8 / 50, step 30/110, loss = 1.6845
# epoch 8 / 50, step 31/110, loss = 1.5253
# epoch 8 / 50, step 32/110, loss = 2.0058
# epoch 8 / 50, step 33/110, loss = 1.8959
# epoch 8 / 50, step 34/110, loss = 1.7849
# epoch 8 / 50, step 35/110, loss = 1.5330
# epoch 8 / 50, step 36/110, loss = 1.8736
# epoch 8 / 50, step 37/110, loss = 1.5688
# epoch 8 / 50, step 38/110, loss = 1.8932
# epoch 8 / 50, step 39/110, loss = 1.7138
# epoch 8 / 50, step 40/110, loss = 1.4719
# epoch 8 / 50, step 41/110, loss = 1.7929
# epoch 8 / 50, step 42/110, loss = 2.0660
# epoch 8 / 50, step 43/110, loss = 1.7113
# epoch 8 / 50, step 44/110, loss = 1.2924
# epoch 8 / 50, step 45/110, loss = 1.7896
# epoch 8 / 50, step 46/110, loss = 1.6309
# epoch 8 / 50, step 47/110, loss = 1.8937
# epoch 8 / 50, step 48/110, loss = 1.5494
# epoch 8 / 50, step 49/110, loss = 2.2270
# epoch 8 / 50, step 50/110, loss = 1.8565
# epoch 8 / 50, step 51/110, loss = 1.9922
# epoch 8 / 50, step 52/110, loss = 1.5484
# epoch 8 / 50, step 53/110, loss = 1.5540
# epoch 8 / 50, step 54/110, loss = 2.0512
# epoch 8 / 50, step 55/110, loss = 1.8014
# epoch 8 / 50, step 56/110, loss = 1.8934
# epoch 8 / 50, step 57/110, loss = 1.5218
# epoch 8 / 50, step 58/110, loss = 1.9895
# epoch 8 / 50, step 59/110, loss = 1.9164
# epoch 8 / 50, step 60/110, loss = 2.0432
# epoch 8 / 50, step 61/110, loss = 1.8159
# epoch 8 / 50, step 62/110, loss = 1.8866
# epoch 8 / 50, step 63/110, loss = 1.7066
# epoch 8 / 50, step 64/110, loss = 1.7599
# epoch 8 / 50, step 65/110, loss = 1.6458
# epoch 8 / 50, step 66/110, loss = 1.8930
# epoch 8 / 50, step 67/110, loss = 1.6055
# epoch 8 / 50, step 68/110, loss = 2.0333
# epoch 8 / 50, step 69/110, loss = 1.9658
# epoch 8 / 50, step 70/110, loss = 2.0628
# epoch 8 / 50, step 71/110, loss = 1.9044
# epoch 8 / 50, step 72/110, loss = 1.7291
# epoch 8 / 50, step 73/110, loss = 1.8802
# epoch 8 / 50, step 74/110, loss = 1.8144
# epoch 8 / 50, step 75/110, loss = 1.5549
# epoch 8 / 50, step 76/110, loss = 1.8700
# epoch 8 / 50, step 77/110, loss = 1.8621
# epoch 8 / 50, step 78/110, loss = 1.8711
# epoch 8 / 50, step 79/110, loss = 1.8682
# epoch 8 / 50, step 80/110, loss = 1.5671
# epoch 8 / 50, step 81/110, loss = 1.4194
# epoch 8 / 50, step 82/110, loss = 1.7338
# epoch 8 / 50, step 83/110, loss = 1.9050
# epoch 8 / 50, step 84/110, loss = 1.6713
# epoch 8 / 50, step 85/110, loss = 1.6197
# epoch 8 / 50, step 86/110, loss = 2.0599
# epoch 8 / 50, step 87/110, loss = 1.5597
# epoch 8 / 50, step 88/110, loss = 1.7881
# epoch 8 / 50, step 89/110, loss = 1.8835
# epoch 8 / 50, step 90/110, loss = 2.0608
# epoch 8 / 50, step 91/110, loss = 1.7787
# epoch 8 / 50, step 92/110, loss = 1.9242
# epoch 8 / 50, step 93/110, loss = 1.5972
# epoch 8 / 50, step 94/110, loss = 1.6463
# epoch 8 / 50, step 95/110, loss = 1.7541
# epoch 8 / 50, step 96/110, loss = 2.1267
# epoch 8 / 50, step 97/110, loss = 1.9965
# epoch 8 / 50, step 98/110, loss = 1.9555
# epoch 8 / 50, step 99/110, loss = 1.6819
# epoch 8 / 50, step 100/110, loss = 2.0276
# epoch 8 / 50, step 101/110, loss = 2.1736
# epoch 8 / 50, step 102/110, loss = 1.8250
# epoch 8 / 50, step 103/110, loss = 1.9841
# epoch 8 / 50, step 104/110, loss = 1.3410
# epoch 8 / 50, step 105/110, loss = 1.9746
# epoch 8 / 50, step 106/110, loss = 1.7938
# epoch 8 / 50, step 107/110, loss = 1.8347
# epoch 8 / 50, step 108/110, loss = 1.8346
# epoch 8 / 50, step 109/110, loss = 1.8940
# epoch 8 / 50, step 110/110, loss = 2.1472
# epoch 8 / 50, step 1/28, loss = 1.9627
# epoch 8 / 50, step 2/28, loss = 2.1165
# epoch 8 / 50, step 3/28, loss = 2.1368
# epoch 8 / 50, step 4/28, loss = 2.0113
# epoch 8 / 50, step 5/28, loss = 2.0149
# epoch 8 / 50, step 6/28, loss = 1.8428
# epoch 8 / 50, step 7/28, loss = 1.8260
# epoch 8 / 50, step 8/28, loss = 2.0199
# epoch 8 / 50, step 9/28, loss = 2.0041
# epoch 8 / 50, step 10/28, loss = 2.0075
# epoch 8 / 50, step 11/28, loss = 2.0935
# epoch 8 / 50, step 12/28, loss = 1.8829
# epoch 8 / 50, step 13/28, loss = 2.0434
# epoch 8 / 50, step 14/28, loss = 1.9300
# epoch 8 / 50, step 15/28, loss = 1.7913
# epoch 8 / 50, step 16/28, loss = 1.9008
# epoch 8 / 50, step 17/28, loss = 2.1092
# epoch 8 / 50, step 18/28, loss = 2.1941
# epoch 8 / 50, step 19/28, loss = 1.8010
# epoch 8 / 50, step 20/28, loss = 1.8771
# epoch 8 / 50, step 21/28, loss = 1.9236
# epoch 8 / 50, step 22/28, loss = 1.9763
# epoch 8 / 50, step 23/28, loss = 1.9436
# epoch 8 / 50, step 24/28, loss = 2.1176
# epoch 8 / 50, step 25/28, loss = 2.0563
# epoch 8 / 50, step 26/28, loss = 2.0757
# epoch 8 / 50, step 27/28, loss = 2.0952
# epoch 8 / 50, step 28/28, loss = 1.9525
# epoch 9 / 50, step 1/110, loss = 1.6801
# epoch 9 / 50, step 2/110, loss = 2.0289
# epoch 9 / 50, step 3/110, loss = 1.9978
# epoch 9 / 50, step 4/110, loss = 1.9489
# epoch 9 / 50, step 5/110, loss = 1.6753
# epoch 9 / 50, step 6/110, loss = 1.9981
# epoch 9 / 50, step 7/110, loss = 2.0989
# epoch 9 / 50, step 8/110, loss = 1.6392
# epoch 9 / 50, step 9/110, loss = 1.7180
# epoch 9 / 50, step 10/110, loss = 1.9781
# epoch 9 / 50, step 11/110, loss = 1.8743
# epoch 9 / 50, step 12/110, loss = 1.7944
# epoch 9 / 50, step 13/110, loss = 1.7605
# epoch 9 / 50, step 14/110, loss = 1.4173
# epoch 9 / 50, step 15/110, loss = 2.0540
# epoch 9 / 50, step 16/110, loss = 1.5722
# epoch 9 / 50, step 17/110, loss = 1.5144
# epoch 9 / 50, step 18/110, loss = 2.0266
# epoch 9 / 50, step 19/110, loss = 1.8430
# epoch 9 / 50, step 20/110, loss = 2.1630
# epoch 9 / 50, step 21/110, loss = 1.7641
# epoch 9 / 50, step 22/110, loss = 1.9164
# epoch 9 / 50, step 23/110, loss = 1.7803
# epoch 9 / 50, step 24/110, loss = 1.5459
# epoch 9 / 50, step 25/110, loss = 1.6570
# epoch 9 / 50, step 26/110, loss = 1.7000
# epoch 9 / 50, step 27/110, loss = 1.4515
# epoch 9 / 50, step 28/110, loss = 1.4410
# epoch 9 / 50, step 29/110, loss = 1.5916
# epoch 9 / 50, step 30/110, loss = 1.8322
# epoch 9 / 50, step 31/110, loss = 1.6377
# epoch 9 / 50, step 32/110, loss = 1.6470
# epoch 9 / 50, step 33/110, loss = 1.7959
# epoch 9 / 50, step 34/110, loss = 1.7954
# epoch 9 / 50, step 35/110, loss = 1.8341
# epoch 9 / 50, step 36/110, loss = 1.5728
# epoch 9 / 50, step 37/110, loss = 1.8281
# epoch 9 / 50, step 38/110, loss = 1.7638
# epoch 9 / 50, step 39/110, loss = 1.9146
# epoch 9 / 50, step 40/110, loss = 2.0597
# epoch 9 / 50, step 41/110, loss = 1.6885
# epoch 9 / 50, step 42/110, loss = 1.6522
# epoch 9 / 50, step 43/110, loss = 1.9155
# epoch 9 / 50, step 44/110, loss = 1.6989
# epoch 9 / 50, step 45/110, loss = 1.7485
# epoch 9 / 50, step 46/110, loss = 1.8186
# epoch 9 / 50, step 47/110, loss = 1.8219
# epoch 9 / 50, step 48/110, loss = 1.7326
# epoch 9 / 50, step 49/110, loss = 1.3674
# epoch 9 / 50, step 50/110, loss = 1.6822
# epoch 9 / 50, step 51/110, loss = 2.0549
# epoch 9 / 50, step 52/110, loss = 1.7435
# epoch 9 / 50, step 53/110, loss = 1.8790
# epoch 9 / 50, step 54/110, loss = 1.5493
# epoch 9 / 50, step 55/110, loss = 1.7918
# epoch 9 / 50, step 56/110, loss = 1.5997
# epoch 9 / 50, step 57/110, loss = 1.4299
# epoch 9 / 50, step 58/110, loss = 1.5219
# epoch 9 / 50, step 59/110, loss = 1.9124
# epoch 9 / 50, step 60/110, loss = 2.1016
# epoch 9 / 50, step 61/110, loss = 1.6525
# epoch 9 / 50, step 62/110, loss = 1.5585
# epoch 9 / 50, step 63/110, loss = 1.8916
# epoch 9 / 50, step 64/110, loss = 1.6166
# epoch 9 / 50, step 65/110, loss = 1.5866
# epoch 9 / 50, step 66/110, loss = 1.9278
# epoch 9 / 50, step 67/110, loss = 1.9021
# epoch 9 / 50, step 68/110, loss = 1.7941
# epoch 9 / 50, step 69/110, loss = 1.7732
# epoch 9 / 50, step 70/110, loss = 1.7498
# epoch 9 / 50, step 71/110, loss = 1.9189
# epoch 9 / 50, step 72/110, loss = 1.8792
# epoch 9 / 50, step 73/110, loss = 1.5995
# ...
# epoch 48 / 50, step 32/110, loss = 1.8957
# epoch 48 / 50, step 33/110, loss = 1.3088
# epoch 48 / 50, step 34/110, loss = 1.1624
# epoch 48 / 50, step 35/110, loss = 1.4199
# epoch 48 / 50, step 36/110, loss = 1.3283
# epoch 48 / 50, step 37/110, loss = 1.2464
# epoch 48 / 50, step 38/110, loss = 1.5702
# epoch 48 / 50, step 39/110, loss = 1.5004
# epoch 48 / 50, step 40/110, loss = 0.7510
# epoch 48 / 50, step 41/110, loss = 1.2139
# epoch 48 / 50, step 42/110, loss = 2.0618
# epoch 48 / 50, step 43/110, loss = 2.0676
# epoch 48 / 50, step 44/110, loss = 1.1484
# epoch 48 / 50, step 45/110, loss = 1.4790
# epoch 48 / 50, step 46/110, loss = 2.2600
# epoch 48 / 50, step 47/110, loss = 1.0267
# epoch 48 / 50, step 48/110, loss = 1.7329
# epoch 48 / 50, step 49/110, loss = 1.5254
# epoch 48 / 50, step 50/110, loss = 1.8425
# epoch 48 / 50, step 51/110, loss = 1.4564
# epoch 48 / 50, step 52/110, loss = 1.8537
# epoch 48 / 50, step 53/110, loss = 1.6702
# epoch 48 / 50, step 54/110, loss = 1.7072
# epoch 48 / 50, step 55/110, loss = 0.7582
# epoch 48 / 50, step 56/110, loss = 1.4016
# epoch 48 / 50, step 57/110, loss = 1.0286
# epoch 48 / 50, step 58/110, loss = 1.6359
# epoch 48 / 50, step 59/110, loss = 1.7365
# epoch 48 / 50, step 60/110, loss = 1.6261
# epoch 48 / 50, step 61/110, loss = 1.7565
# epoch 48 / 50, step 62/110, loss = 1.9522
# epoch 48 / 50, step 63/110, loss = 1.5570
# epoch 48 / 50, step 64/110, loss = 1.9985
# epoch 48 / 50, step 65/110, loss = 1.2459
# epoch 48 / 50, step 66/110, loss = 1.5220
# epoch 48 / 50, step 67/110, loss = 1.2973
# epoch 48 / 50, step 68/110, loss = 1.4941
# epoch 48 / 50, step 69/110, loss = 1.2409
# epoch 48 / 50, step 70/110, loss = 1.8515
# epoch 48 / 50, step 71/110, loss = 1.2448
# epoch 48 / 50, step 72/110, loss = 1.2461
# epoch 48 / 50, step 73/110, loss = 1.7737
# epoch 48 / 50, step 74/110, loss = 1.1767
# epoch 48 / 50, step 75/110, loss = 1.1945
# epoch 48 / 50, step 76/110, loss = 1.0390
# epoch 48 / 50, step 77/110, loss = 1.8307
# epoch 48 / 50, step 78/110, loss = 1.7795
# epoch 48 / 50, step 79/110, loss = 1.5378
# epoch 48 / 50, step 80/110, loss = 1.9091
# epoch 48 / 50, step 81/110, loss = 1.5916
# epoch 48 / 50, step 82/110, loss = 1.1544
# epoch 48 / 50, step 83/110, loss = 1.4007
# epoch 48 / 50, step 84/110, loss = 1.7616
# epoch 48 / 50, step 85/110, loss = 1.6537
# epoch 48 / 50, step 86/110, loss = 2.1468
# epoch 48 / 50, step 87/110, loss = 1.8737
# epoch 48 / 50, step 88/110, loss = 1.3641
# epoch 48 / 50, step 89/110, loss = 1.6240
# epoch 48 / 50, step 90/110, loss = 1.6418
# epoch 48 / 50, step 91/110, loss = 1.4964
# epoch 48 / 50, step 92/110, loss = 1.8054
# epoch 48 / 50, step 93/110, loss = 1.2264
# epoch 48 / 50, step 94/110, loss = 0.8020
# epoch 48 / 50, step 95/110, loss = 1.2821
# epoch 48 / 50, step 96/110, loss = 1.1317
# epoch 48 / 50, step 97/110, loss = 1.7791
# epoch 48 / 50, step 98/110, loss = 1.1759
# epoch 48 / 50, step 99/110, loss = 1.3072
# epoch 48 / 50, step 100/110, loss = 1.5499
# epoch 48 / 50, step 101/110, loss = 1.8650
# epoch 48 / 50, step 102/110, loss = 0.9450
# epoch 48 / 50, step 103/110, loss = 1.6603
# epoch 48 / 50, step 104/110, loss = 1.4537
# epoch 48 / 50, step 105/110, loss = 1.0676
# epoch 48 / 50, step 106/110, loss = 1.2579
# epoch 48 / 50, step 107/110, loss = 1.6982
# epoch 48 / 50, step 108/110, loss = 1.5423
# epoch 48 / 50, step 109/110, loss = 1.7127
# epoch 48 / 50, step 110/110, loss = 1.0339
# epoch 48 / 50, step 1/28, loss = 2.2942
# epoch 48 / 50, step 2/28, loss = 2.5546
# epoch 48 / 50, step 3/28, loss = 2.6710
# epoch 48 / 50, step 4/28, loss = 2.3008
# epoch 48 / 50, step 5/28, loss = 2.3786
# epoch 48 / 50, step 6/28, loss = 2.0955
# epoch 48 / 50, step 7/28, loss = 1.8227
# epoch 48 / 50, step 8/28, loss = 2.1813
# epoch 48 / 50, step 9/28, loss = 2.5505
# epoch 48 / 50, step 10/28, loss = 2.3633
# epoch 48 / 50, step 11/28, loss = 1.5893
# epoch 48 / 50, step 12/28, loss = 1.6761
# epoch 48 / 50, step 13/28, loss = 2.1469
# epoch 48 / 50, step 14/28, loss = 2.4583
# epoch 48 / 50, step 15/28, loss = 1.8677
# epoch 48 / 50, step 16/28, loss = 2.1274
# epoch 48 / 50, step 17/28, loss = 1.8320
# epoch 48 / 50, step 18/28, loss = 1.7814
# epoch 48 / 50, step 19/28, loss = 1.9231
# epoch 48 / 50, step 20/28, loss = 1.9028
# epoch 48 / 50, step 21/28, loss = 1.3179
# epoch 48 / 50, step 22/28, loss = 2.5890
# epoch 48 / 50, step 23/28, loss = 2.0691
# epoch 48 / 50, step 24/28, loss = 2.2985
# epoch 48 / 50, step 25/28, loss = 2.0511
# epoch 48 / 50, step 26/28, loss = 2.1980
# epoch 48 / 50, step 27/28, loss = 2.3842
# epoch 48 / 50, step 28/28, loss = 2.5081
# epoch 49 / 50, step 1/110, loss = 1.7404
# epoch 49 / 50, step 2/110, loss = 1.7655
# epoch 49 / 50, step 3/110, loss = 1.3447
# epoch 49 / 50, step 4/110, loss = 2.1202
# epoch 49 / 50, step 5/110, loss = 1.9242
# epoch 49 / 50, step 6/110, loss = 1.4349
# epoch 49 / 50, step 7/110, loss = 1.3770
# epoch 49 / 50, step 8/110, loss = 1.5295
# epoch 49 / 50, step 9/110, loss = 1.6224
# epoch 49 / 50, step 10/110, loss = 1.2687
# epoch 49 / 50, step 11/110, loss = 2.2432
# epoch 49 / 50, step 12/110, loss = 1.4670
# epoch 49 / 50, step 13/110, loss = 1.2259
# epoch 49 / 50, step 14/110, loss = 1.6483
# epoch 49 / 50, step 15/110, loss = 1.1497
# epoch 49 / 50, step 16/110, loss = 1.5756
# epoch 49 / 50, step 17/110, loss = 1.3649
# epoch 49 / 50, step 18/110, loss = 1.5277
# epoch 49 / 50, step 19/110, loss = 1.4414
# epoch 49 / 50, step 20/110, loss = 1.2359
# epoch 49 / 50, step 21/110, loss = 1.7083
# epoch 49 / 50, step 22/110, loss = 0.7853
# epoch 49 / 50, step 23/110, loss = 1.0991
# epoch 49 / 50, step 24/110, loss = 1.1807
# epoch 49 / 50, step 25/110, loss = 1.6113
# epoch 49 / 50, step 26/110, loss = 1.1927
# epoch 49 / 50, step 27/110, loss = 1.5456
# epoch 49 / 50, step 28/110, loss = 2.0435
# epoch 49 / 50, step 29/110, loss = 1.4334
# epoch 49 / 50, step 30/110, loss = 1.7473
# epoch 49 / 50, step 31/110, loss = 1.4117
# epoch 49 / 50, step 32/110, loss = 1.6406
# epoch 49 / 50, step 33/110, loss = 1.4926
# epoch 49 / 50, step 34/110, loss = 0.9040
# epoch 49 / 50, step 35/110, loss = 1.5691
# epoch 49 / 50, step 36/110, loss = 1.6881
# epoch 49 / 50, step 37/110, loss = 1.6440
# epoch 49 / 50, step 38/110, loss = 1.8015
# epoch 49 / 50, step 39/110, loss = 1.2308
# epoch 49 / 50, step 40/110, loss = 2.0866
# epoch 49 / 50, step 41/110, loss = 1.3773
# epoch 49 / 50, step 42/110, loss = 1.4518
# epoch 49 / 50, step 43/110, loss = 1.1473
# epoch 49 / 50, step 44/110, loss = 1.1902
# epoch 49 / 50, step 45/110, loss = 1.3494
# epoch 49 / 50, step 46/110, loss = 1.3992
# epoch 49 / 50, step 47/110, loss = 2.1774
# epoch 49 / 50, step 48/110, loss = 1.3973
# epoch 49 / 50, step 49/110, loss = 1.9254
# epoch 49 / 50, step 50/110, loss = 1.6074
# epoch 49 / 50, step 51/110, loss = 1.5530
# epoch 49 / 50, step 52/110, loss = 1.3578
# epoch 49 / 50, step 53/110, loss = 1.4453
# epoch 49 / 50, step 54/110, loss = 1.6925
# epoch 49 / 50, step 55/110, loss = 1.1056
# epoch 49 / 50, step 56/110, loss = 1.8894
# epoch 49 / 50, step 57/110, loss = 1.3595
# epoch 49 / 50, step 58/110, loss = 1.2600
# epoch 49 / 50, step 59/110, loss = 2.2362
# epoch 49 / 50, step 60/110, loss = 1.7197
# epoch 49 / 50, step 61/110, loss = 1.0296
# epoch 49 / 50, step 62/110, loss = 1.7637
# epoch 49 / 50, step 63/110, loss = 1.9751
# epoch 49 / 50, step 64/110, loss = 1.6691
# epoch 49 / 50, step 65/110, loss = 1.6130
# epoch 49 / 50, step 66/110, loss = 1.9264
# epoch 49 / 50, step 67/110, loss = 1.7343
# epoch 49 / 50, step 68/110, loss = 1.3573
# epoch 49 / 50, step 69/110, loss = 1.1270
# epoch 49 / 50, step 70/110, loss = 1.1783
# epoch 49 / 50, step 71/110, loss = 2.0450
# epoch 49 / 50, step 72/110, loss = 1.6017
# epoch 49 / 50, step 73/110, loss = 1.0077
# epoch 49 / 50, step 74/110, loss = 1.5460
# epoch 49 / 50, step 75/110, loss = 1.9268
# epoch 49 / 50, step 76/110, loss = 1.8993
# epoch 49 / 50, step 77/110, loss = 1.4454
# epoch 49 / 50, step 78/110, loss = 1.2089
# epoch 49 / 50, step 79/110, loss = 0.9504
# epoch 49 / 50, step 80/110, loss = 1.1038
# epoch 49 / 50, step 81/110, loss = 1.9741
# epoch 49 / 50, step 82/110, loss = 1.6994
# epoch 49 / 50, step 83/110, loss = 1.5289
# epoch 49 / 50, step 84/110, loss = 1.5746
# epoch 49 / 50, step 85/110, loss = 1.8947
# epoch 49 / 50, step 86/110, loss = 1.2296
# epoch 49 / 50, step 87/110, loss = 1.8251
# epoch 49 / 50, step 88/110, loss = 1.8908
# epoch 49 / 50, step 89/110, loss = 1.4642
# epoch 49 / 50, step 90/110, loss = 1.6683
# epoch 49 / 50, step 91/110, loss = 1.5278
# epoch 49 / 50, step 92/110, loss = 1.7030
# epoch 49 / 50, step 93/110, loss = 1.4592
# epoch 49 / 50, step 94/110, loss = 1.6575
# epoch 49 / 50, step 95/110, loss = 1.7504
# epoch 49 / 50, step 96/110, loss = 1.7336
# epoch 49 / 50, step 97/110, loss = 1.1694
# epoch 49 / 50, step 98/110, loss = 1.5489
# epoch 49 / 50, step 99/110, loss = 1.5769
# epoch 49 / 50, step 100/110, loss = 1.6436
# epoch 49 / 50, step 101/110, loss = 1.1190
# epoch 49 / 50, step 102/110, loss = 1.7208
# epoch 49 / 50, step 103/110, loss = 1.4550
# epoch 49 / 50, step 104/110, loss = 1.6257
# epoch 49 / 50, step 105/110, loss = 1.8210
# epoch 49 / 50, step 106/110, loss = 1.5260
# epoch 49 / 50, step 107/110, loss = 1.6858
# epoch 49 / 50, step 108/110, loss = 1.4393
# epoch 49 / 50, step 109/110, loss = 1.7978
# epoch 49 / 50, step 110/110, loss = 0.9946
# epoch 49 / 50, step 1/28, loss = 2.3766
# epoch 49 / 50, step 2/28, loss = 2.6194
# epoch 49 / 50, step 3/28, loss = 2.1335
# epoch 49 / 50, step 4/28, loss = 2.3405
# epoch 49 / 50, step 5/28, loss = 2.4902
# epoch 49 / 50, step 6/28, loss = 2.1569
# epoch 49 / 50, step 7/28, loss = 2.0562
# epoch 49 / 50, step 8/28, loss = 2.5641
# epoch 49 / 50, step 9/28, loss = 2.5637
# epoch 49 / 50, step 10/28, loss = 2.4498
# epoch 49 / 50, step 11/28, loss = 1.8640
# epoch 49 / 50, step 12/28, loss = 1.5567
# epoch 49 / 50, step 13/28, loss = 2.3460
# epoch 49 / 50, step 14/28, loss = 2.2875
# epoch 49 / 50, step 15/28, loss = 1.7629
# epoch 49 / 50, step 16/28, loss = 2.2575
# epoch 49 / 50, step 17/28, loss = 2.0485
# epoch 49 / 50, step 18/28, loss = 1.8305
# epoch 49 / 50, step 19/28, loss = 2.0800
# epoch 49 / 50, step 20/28, loss = 2.4327
# epoch 49 / 50, step 21/28, loss = 1.5798
# epoch 49 / 50, step 22/28, loss = 2.6680
# epoch 49 / 50, step 23/28, loss = 2.2969
# epoch 49 / 50, step 24/28, loss = 2.3941
# epoch 49 / 50, step 25/28, loss = 2.1619
# epoch 49 / 50, step 26/28, loss = 2.3310
# epoch 49 / 50, step 27/28, loss = 2.3549
# epoch 49 / 50, step 28/28, loss = 1.8802
# epoch 50 / 50, step 1/110, loss = 2.0536
# epoch 50 / 50, step 2/110, loss = 1.9761
# epoch 50 / 50, step 3/110, loss = 1.7100
# epoch 50 / 50, step 4/110, loss = 1.5134
# epoch 50 / 50, step 5/110, loss = 1.3678
# epoch 50 / 50, step 6/110, loss = 1.3286
# epoch 50 / 50, step 7/110, loss = 1.3161
# epoch 50 / 50, step 8/110, loss = 1.2507
# epoch 50 / 50, step 9/110, loss = 1.5676
# epoch 50 / 50, step 10/110, loss = 1.4809
# epoch 50 / 50, step 11/110, loss = 2.0165
# epoch 50 / 50, step 12/110, loss = 1.6821
# epoch 50 / 50, step 13/110, loss = 1.3295
# epoch 50 / 50, step 14/110, loss = 1.4661
# epoch 50 / 50, step 15/110, loss = 1.3321
# epoch 50 / 50, step 16/110, loss = 1.2543
# epoch 50 / 50, step 17/110, loss = 1.0020
# epoch 50 / 50, step 18/110, loss = 1.5066
# epoch 50 / 50, step 19/110, loss = 1.0305
# epoch 50 / 50, step 20/110, loss = 0.9454
# epoch 50 / 50, step 21/110, loss = 1.5034
# epoch 50 / 50, step 22/110, loss = 1.4137
# epoch 50 / 50, step 23/110, loss = 1.2826
# epoch 50 / 50, step 24/110, loss = 1.6345
# epoch 50 / 50, step 25/110, loss = 1.8505
# epoch 50 / 50, step 26/110, loss = 1.3523
# epoch 50 / 50, step 27/110, loss = 0.9690
# epoch 50 / 50, step 28/110, loss = 1.3602
# epoch 50 / 50, step 29/110, loss = 1.3794
# epoch 50 / 50, step 30/110, loss = 1.8221
# epoch 50 / 50, step 31/110, loss = 1.3883
# epoch 50 / 50, step 32/110, loss = 1.0409
# epoch 50 / 50, step 33/110, loss = 1.2559
# epoch 50 / 50, step 34/110, loss = 1.3369
# epoch 50 / 50, step 35/110, loss = 1.3914
# epoch 50 / 50, step 36/110, loss = 1.6486
# epoch 50 / 50, step 37/110, loss = 1.3032
# epoch 50 / 50, step 38/110, loss = 1.0141
# epoch 50 / 50, step 39/110, loss = 1.5456
# epoch 50 / 50, step 40/110, loss = 2.0422
# epoch 50 / 50, step 41/110, loss = 2.1703
# epoch 50 / 50, step 42/110, loss = 1.2503
# epoch 50 / 50, step 43/110, loss = 1.9242
# epoch 50 / 50, step 44/110, loss = 1.3813
# epoch 50 / 50, step 45/110, loss = 1.8058
# epoch 50 / 50, step 46/110, loss = 1.8588
# epoch 50 / 50, step 47/110, loss = 1.0159
# epoch 50 / 50, step 48/110, loss = 1.8906
# epoch 50 / 50, step 49/110, loss = 1.5698
# epoch 50 / 50, step 50/110, loss = 1.8437
# epoch 50 / 50, step 51/110, loss = 1.5377
# epoch 50 / 50, step 52/110, loss = 1.6571
# epoch 50 / 50, step 53/110, loss = 1.7463
# epoch 50 / 50, step 54/110, loss = 1.7561
# epoch 50 / 50, step 55/110, loss = 1.3810
# epoch 50 / 50, step 56/110, loss = 1.2478
# epoch 50 / 50, step 57/110, loss = 1.7175
# epoch 50 / 50, step 58/110, loss = 1.0274
# epoch 50 / 50, step 59/110, loss = 1.5892
# epoch 50 / 50, step 60/110, loss = 1.3577
# epoch 50 / 50, step 61/110, loss = 1.3925
# epoch 50 / 50, step 62/110, loss = 1.3965
# epoch 50 / 50, step 63/110, loss = 1.7955
# epoch 50 / 50, step 64/110, loss = 1.5263
# epoch 50 / 50, step 65/110, loss = 1.8228
# epoch 50 / 50, step 66/110, loss = 1.3605
# epoch 50 / 50, step 67/110, loss = 1.8411
# epoch 50 / 50, step 68/110, loss = 0.8597
# epoch 50 / 50, step 69/110, loss = 1.6761
# epoch 50 / 50, step 70/110, loss = 0.9550
# epoch 50 / 50, step 71/110, loss = 1.9311
# epoch 50 / 50, step 72/110, loss = 1.2127
# epoch 50 / 50, step 73/110, loss = 1.3054
# epoch 50 / 50, step 74/110, loss = 1.2109
# epoch 50 / 50, step 75/110, loss = 1.0973
# epoch 50 / 50, step 76/110, loss = 0.9235
# epoch 50 / 50, step 77/110, loss = 1.3608
# epoch 50 / 50, step 78/110, loss = 1.2084
# epoch 50 / 50, step 79/110, loss = 1.5388
# epoch 50 / 50, step 80/110, loss = 1.2642
# epoch 50 / 50, step 81/110, loss = 1.2028
# epoch 50 / 50, step 82/110, loss = 1.3358
# epoch 50 / 50, step 83/110, loss = 1.4275
# epoch 50 / 50, step 84/110, loss = 1.5345
# epoch 50 / 50, step 85/110, loss = 1.0766
# epoch 50 / 50, step 86/110, loss = 1.5251
# epoch 50 / 50, step 87/110, loss = 1.3959
# epoch 50 / 50, step 88/110, loss = 1.5909
# epoch 50 / 50, step 89/110, loss = 1.8090
# epoch 50 / 50, step 90/110, loss = 1.1151
# epoch 50 / 50, step 91/110, loss = 2.1417
# epoch 50 / 50, step 92/110, loss = 1.3441
# epoch 50 / 50, step 93/110, loss = 1.7711
# epoch 50 / 50, step 94/110, loss = 1.4717
# epoch 50 / 50, step 95/110, loss = 1.4717
# epoch 50 / 50, step 96/110, loss = 1.5853
# epoch 50 / 50, step 97/110, loss = 2.4240
# epoch 50 / 50, step 98/110, loss = 1.8817
# epoch 50 / 50, step 99/110, loss = 1.2956
# epoch 50 / 50, step 100/110, loss = 1.4775
# epoch 50 / 50, step 101/110, loss = 1.5392
# epoch 50 / 50, step 102/110, loss = 1.5504
# epoch 50 / 50, step 103/110, loss = 1.4403
# epoch 50 / 50, step 104/110, loss = 1.3054
# epoch 50 / 50, step 105/110, loss = 1.5932
# epoch 50 / 50, step 106/110, loss = 2.6695
# epoch 50 / 50, step 107/110, loss = 1.5395
# epoch 50 / 50, step 108/110, loss = 1.8137
# epoch 50 / 50, step 109/110, loss = 1.8965
# epoch 50 / 50, step 110/110, loss = 1.5479
# epoch 50 / 50, step 1/28, loss = 2.2442
# epoch 50 / 50, step 2/28, loss = 2.6112
# epoch 50 / 50, step 3/28, loss = 2.2277
# epoch 50 / 50, step 4/28, loss = 2.4542
# epoch 50 / 50, step 5/28, loss = 2.1097
# epoch 50 / 50, step 6/28, loss = 1.5737
# epoch 50 / 50, step 7/28, loss = 1.9326
# epoch 50 / 50, step 8/28, loss = 2.3987
# epoch 50 / 50, step 9/28, loss = 2.5402
# epoch 50 / 50, step 10/28, loss = 2.6401
# epoch 50 / 50, step 11/28, loss = 1.8215
# epoch 50 / 50, step 12/28, loss = 1.7121
# epoch 50 / 50, step 13/28, loss = 2.0319
# epoch 50 / 50, step 14/28, loss = 2.6206
# epoch 50 / 50, step 15/28, loss = 1.7558
# epoch 50 / 50, step 16/28, loss = 2.3800
# epoch 50 / 50, step 17/28, loss = 2.0422
# epoch 50 / 50, step 18/28, loss = 1.7188
# epoch 50 / 50, step 19/28, loss = 2.0248
# epoch 50 / 50, step 20/28, loss = 2.2688
# epoch 50 / 50, step 21/28, loss = 1.4912
# epoch 50 / 50, step 22/28, loss = 2.8850
# epoch 50 / 50, step 23/28, loss = 2.4747
# epoch 50 / 50, step 24/28, loss = 2.3971
# epoch 50 / 50, step 25/28, loss = 2.7715
# epoch 50 / 50, step 26/28, loss = 2.5312
# epoch 50 / 50, step 27/28, loss = 3.0076
# epoch 50 / 50, step 28/28, loss = 1.8857

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 42.97142857142857 and the test accuaracy is 17.80821917808219
#  the maximum accuracy of the test was 22.374429223744293 at the epoch 13
#  the maximum accuracy of the train was 45.25714285714286 at the epoch 45
# the accuracy of the training at the best validation accuracy 22.374429223744293 is 36.57142857142857

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
