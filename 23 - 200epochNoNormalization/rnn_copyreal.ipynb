# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:  -epochs100a200

# %%
filepath = '23 - 200epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 200
batch_size = 16
learning_rate = 0.0005
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([16, 769024]) , Labels shape: torch.Size([16])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 200, step 1/55, loss = 2.2437
# epoch 1 / 200, step 2/55, loss = 1.9692
# epoch 1 / 200, step 3/55, loss = 2.1158
# epoch 1 / 200, step 4/55, loss = 1.9787
# epoch 1 / 200, step 5/55, loss = 2.0486
# epoch 1 / 200, step 6/55, loss = 2.2300
# epoch 1 / 200, step 7/55, loss = 1.9510
# epoch 1 / 200, step 8/55, loss = 1.9776
# epoch 1 / 200, step 9/55, loss = 1.8606
# epoch 1 / 200, step 10/55, loss = 1.9286
# epoch 1 / 200, step 11/55, loss = 2.1087
# epoch 1 / 200, step 12/55, loss = 2.0388
# epoch 1 / 200, step 13/55, loss = 2.1575
# epoch 1 / 200, step 14/55, loss = 1.8748
# epoch 1 / 200, step 15/55, loss = 2.1792
# epoch 1 / 200, step 16/55, loss = 2.2269
# epoch 1 / 200, step 17/55, loss = 2.1762
# epoch 1 / 200, step 18/55, loss = 2.0951
# epoch 1 / 200, step 19/55, loss = 2.1683
# epoch 1 / 200, step 20/55, loss = 2.0458
# epoch 1 / 200, step 21/55, loss = 2.0149
# epoch 1 / 200, step 22/55, loss = 1.8797
# epoch 1 / 200, step 23/55, loss = 2.1316
# epoch 1 / 200, step 24/55, loss = 2.0662
# epoch 1 / 200, step 25/55, loss = 1.9852
# epoch 1 / 200, step 26/55, loss = 2.2376
# epoch 1 / 200, step 27/55, loss = 2.0908
# epoch 1 / 200, step 28/55, loss = 2.0635
# epoch 1 / 200, step 29/55, loss = 1.9164
# epoch 1 / 200, step 30/55, loss = 2.1527
# epoch 1 / 200, step 31/55, loss = 1.9242
# epoch 1 / 200, step 32/55, loss = 2.0986
# epoch 1 / 200, step 33/55, loss = 1.8768
# epoch 1 / 200, step 34/55, loss = 2.1287
# epoch 1 / 200, step 35/55, loss = 1.9615
# epoch 1 / 200, step 36/55, loss = 1.9627
# epoch 1 / 200, step 37/55, loss = 2.0550
# epoch 1 / 200, step 38/55, loss = 2.0676
# epoch 1 / 200, step 39/55, loss = 2.0677
# epoch 1 / 200, step 40/55, loss = 1.9945
# epoch 1 / 200, step 41/55, loss = 1.8563
# epoch 1 / 200, step 42/55, loss = 1.9288
# epoch 1 / 200, step 43/55, loss = 2.1297
# epoch 1 / 200, step 44/55, loss = 1.9624
# epoch 1 / 200, step 45/55, loss = 1.9355
# epoch 1 / 200, step 46/55, loss = 2.0986
# epoch 1 / 200, step 47/55, loss = 2.0833
# epoch 1 / 200, step 48/55, loss = 2.1536
# epoch 1 / 200, step 49/55, loss = 2.3714
# epoch 1 / 200, step 50/55, loss = 2.0799
# epoch 1 / 200, step 51/55, loss = 1.8797
# epoch 1 / 200, step 52/55, loss = 1.8832
# epoch 1 / 200, step 53/55, loss = 1.9458
# epoch 1 / 200, step 54/55, loss = 2.0409
# epoch 1 / 200, step 55/55, loss = 1.9570
# epoch 1 / 200, step 1/14, loss = 1.9488
# epoch 1 / 200, step 2/14, loss = 2.0076
# epoch 1 / 200, step 3/14, loss = 2.0814
# epoch 1 / 200, step 4/14, loss = 2.0670
# epoch 1 / 200, step 5/14, loss = 2.0084
# epoch 1 / 200, step 6/14, loss = 1.8783
# epoch 1 / 200, step 7/14, loss = 1.9517
# epoch 1 / 200, step 8/14, loss = 1.8534
# epoch 1 / 200, step 9/14, loss = 1.9738
# epoch 1 / 200, step 10/14, loss = 2.0246
# epoch 1 / 200, step 11/14, loss = 1.8996
# epoch 1 / 200, step 12/14, loss = 2.0087
# epoch 1 / 200, step 13/14, loss = 2.0492
# epoch 1 / 200, step 14/14, loss = 1.8429
# epoch 2 / 200, step 1/55, loss = 1.8951
# epoch 2 / 200, step 2/55, loss = 1.8392
# epoch 2 / 200, step 3/55, loss = 1.9328
# epoch 2 / 200, step 4/55, loss = 1.9208
# epoch 2 / 200, step 5/55, loss = 1.9051
# epoch 2 / 200, step 6/55, loss = 2.0130
# epoch 2 / 200, step 7/55, loss = 2.0317
# epoch 2 / 200, step 8/55, loss = 2.0849
# epoch 2 / 200, step 9/55, loss = 2.2367
# epoch 2 / 200, step 10/55, loss = 1.9755
# epoch 2 / 200, step 11/55, loss = 1.9407
# epoch 2 / 200, step 12/55, loss = 1.9242
# epoch 2 / 200, step 13/55, loss = 1.8958
# epoch 2 / 200, step 14/55, loss = 2.0400
# epoch 2 / 200, step 15/55, loss = 1.8988
# epoch 2 / 200, step 16/55, loss = 1.9995
# epoch 2 / 200, step 17/55, loss = 2.1778
# epoch 2 / 200, step 18/55, loss = 1.9383
# epoch 2 / 200, step 19/55, loss = 2.0644
# epoch 2 / 200, step 20/55, loss = 1.9374
# epoch 2 / 200, step 21/55, loss = 2.0935
# epoch 2 / 200, step 22/55, loss = 1.7901
# epoch 2 / 200, step 23/55, loss = 1.8824
# epoch 2 / 200, step 24/55, loss = 2.1631
# epoch 2 / 200, step 25/55, loss = 2.0408
# epoch 2 / 200, step 26/55, loss = 2.0065
# epoch 2 / 200, step 27/55, loss = 2.0275
# epoch 2 / 200, step 28/55, loss = 2.0729
# epoch 2 / 200, step 29/55, loss = 1.9540
# epoch 2 / 200, step 30/55, loss = 1.8843
# epoch 2 / 200, step 31/55, loss = 1.9748
# epoch 2 / 200, step 32/55, loss = 1.9457
# epoch 2 / 200, step 33/55, loss = 1.9965
# epoch 2 / 200, step 34/55, loss = 1.9269
# epoch 2 / 200, step 35/55, loss = 1.9708
# epoch 2 / 200, step 36/55, loss = 2.2314
# epoch 2 / 200, step 37/55, loss = 2.0600
# epoch 2 / 200, step 38/55, loss = 1.9051
# epoch 2 / 200, step 39/55, loss = 2.0289
# epoch 2 / 200, step 40/55, loss = 2.1410
# epoch 2 / 200, step 41/55, loss = 1.9801
# epoch 2 / 200, step 42/55, loss = 1.7327
# epoch 2 / 200, step 43/55, loss = 1.8153
# epoch 2 / 200, step 44/55, loss = 1.9902
# epoch 2 / 200, step 45/55, loss = 2.0047
# epoch 2 / 200, step 46/55, loss = 2.1283
# epoch 2 / 200, step 47/55, loss = 2.1728
# epoch 2 / 200, step 48/55, loss = 2.0941
# epoch 2 / 200, step 49/55, loss = 1.8688
# epoch 2 / 200, step 50/55, loss = 2.0426
# epoch 2 / 200, step 51/55, loss = 2.1218
# epoch 2 / 200, step 52/55, loss = 2.0416
# epoch 2 / 200, step 53/55, loss = 1.9523
# epoch 2 / 200, step 54/55, loss = 1.9632
# epoch 2 / 200, step 55/55, loss = 1.9035
# epoch 2 / 200, step 1/14, loss = 1.9639
# epoch 2 / 200, step 2/14, loss = 1.9391
# epoch 2 / 200, step 3/14, loss = 2.0737
# epoch 2 / 200, step 4/14, loss = 1.9893
# epoch 2 / 200, step 5/14, loss = 1.9599
# epoch 2 / 200, step 6/14, loss = 1.8661
# epoch 2 / 200, step 7/14, loss = 1.9371
# epoch 2 / 200, step 8/14, loss = 1.8619
# epoch 2 / 200, step 9/14, loss = 1.9772
# epoch 2 / 200, step 10/14, loss = 2.0051
# epoch 2 / 200, step 11/14, loss = 1.8953
# epoch 2 / 200, step 12/14, loss = 1.9918
# epoch 2 / 200, step 13/14, loss = 1.9965
# epoch 2 / 200, step 14/14, loss = 1.9035
# epoch 3 / 200, step 1/55, loss = 1.8940
# epoch 3 / 200, step 2/55, loss = 2.0076
# epoch 3 / 200, step 3/55, loss = 2.1288
# epoch 3 / 200, step 4/55, loss = 2.0876
# epoch 3 / 200, step 5/55, loss = 1.9559
# epoch 3 / 200, step 6/55, loss = 1.8687
# epoch 3 / 200, step 7/55, loss = 1.9412
# epoch 3 / 200, step 8/55, loss = 1.7761
# epoch 3 / 200, step 9/55, loss = 2.1673
# epoch 3 / 200, step 10/55, loss = 1.9914
# epoch 3 / 200, step 11/55, loss = 1.8883
# epoch 3 / 200, step 12/55, loss = 1.9597
# epoch 3 / 200, step 13/55, loss = 1.9276
# epoch 3 / 200, step 14/55, loss = 1.9927
# epoch 3 / 200, step 15/55, loss = 1.9774
# epoch 3 / 200, step 16/55, loss = 1.9821
# epoch 3 / 200, step 17/55, loss = 1.7985
# epoch 3 / 200, step 18/55, loss = 1.9242
# epoch 3 / 200, step 19/55, loss = 2.1352
# epoch 3 / 200, step 20/55, loss = 1.9835
# epoch 3 / 200, step 21/55, loss = 2.1012
# epoch 3 / 200, step 22/55, loss = 2.1549
# epoch 3 / 200, step 23/55, loss = 2.1332
# epoch 3 / 200, step 24/55, loss = 1.9917
# epoch 3 / 200, step 25/55, loss = 1.8965
# epoch 3 / 200, step 26/55, loss = 1.9922
# epoch 3 / 200, step 27/55, loss = 1.9744
# epoch 3 / 200, step 28/55, loss = 1.8795
# epoch 3 / 200, step 29/55, loss = 2.1337
# epoch 3 / 200, step 30/55, loss = 1.9231
# epoch 3 / 200, step 31/55, loss = 1.9639
# epoch 3 / 200, step 32/55, loss = 2.0213
# epoch 3 / 200, step 33/55, loss = 2.0528
# epoch 3 / 200, step 34/55, loss = 2.0394
# epoch 3 / 200, step 35/55, loss = 1.9151
# epoch 3 / 200, step 36/55, loss = 2.0413
# epoch 3 / 200, step 37/55, loss = 2.0212
# epoch 3 / 200, step 38/55, loss = 1.9887
# epoch 3 / 200, step 39/55, loss = 2.0966
# epoch 3 / 200, step 40/55, loss = 1.8815
# epoch 3 / 200, step 41/55, loss = 2.0461
# epoch 3 / 200, step 42/55, loss = 2.2004
# epoch 3 / 200, step 43/55, loss = 2.0606
# epoch 3 / 200, step 44/55, loss = 2.1066
# epoch 3 / 200, step 45/55, loss = 1.9584
# epoch 3 / 200, step 46/55, loss = 2.0827
# epoch 3 / 200, step 47/55, loss = 2.2777
# epoch 3 / 200, step 48/55, loss = 2.0579
# epoch 3 / 200, step 49/55, loss = 1.9522
# epoch 3 / 200, step 50/55, loss = 2.2482
# epoch 3 / 200, step 51/55, loss = 2.2281
# epoch 3 / 200, step 52/55, loss = 2.1061
# epoch 3 / 200, step 53/55, loss = 1.9752
# epoch 3 / 200, step 54/55, loss = 1.8976
# epoch 3 / 200, step 55/55, loss = 1.8331
# epoch 3 / 200, step 1/14, loss = 1.9724
# epoch 3 / 200, step 2/14, loss = 1.8793
# epoch 3 / 200, step 3/14, loss = 2.0347
# epoch 3 / 200, step 4/14, loss = 1.9948
# epoch 3 / 200, step 5/14, loss = 1.9279
# epoch 3 / 200, step 6/14, loss = 1.8575
# epoch 3 / 200, step 7/14, loss = 1.9427
# epoch 3 / 200, step 8/14, loss = 1.9293
# epoch 3 / 200, step 9/14, loss = 1.9430
# epoch 3 / 200, step 10/14, loss = 1.9350
# epoch 3 / 200, step 11/14, loss = 1.9005
# epoch 3 / 200, step 12/14, loss = 1.9225
# epoch 3 / 200, step 13/14, loss = 1.9627
# epoch 3 / 200, step 14/14, loss = 1.9790
# epoch 4 / 200, step 1/55, loss = 1.9752
# epoch 4 / 200, step 2/55, loss = 1.9711
# epoch 4 / 200, step 3/55, loss = 1.9823
# epoch 4 / 200, step 4/55, loss = 1.8832
# epoch 4 / 200, step 5/55, loss = 1.9488
# epoch 4 / 200, step 6/55, loss = 1.9630
# epoch 4 / 200, step 7/55, loss = 2.1082
# epoch 4 / 200, step 8/55, loss = 2.0465
# epoch 4 / 200, step 9/55, loss = 1.9757
# epoch 4 / 200, step 10/55, loss = 1.8547
# epoch 4 / 200, step 11/55, loss = 2.0404
# epoch 4 / 200, step 12/55, loss = 1.9500
# epoch 4 / 200, step 13/55, loss = 2.0427
# epoch 4 / 200, step 14/55, loss = 1.8101
# epoch 4 / 200, step 15/55, loss = 1.9727
# epoch 4 / 200, step 16/55, loss = 1.8960
# epoch 4 / 200, step 17/55, loss = 1.9292
# epoch 4 / 200, step 18/55, loss = 2.1598
# epoch 4 / 200, step 19/55, loss = 2.0834
# epoch 4 / 200, step 20/55, loss = 2.0161
# epoch 4 / 200, step 21/55, loss = 2.0370
# epoch 4 / 200, step 22/55, loss = 1.8033
# epoch 4 / 200, step 23/55, loss = 1.8921
# epoch 4 / 200, step 24/55, loss = 2.0831
# epoch 4 / 200, step 25/55, loss = 1.9549
# epoch 4 / 200, step 26/55, loss = 1.7976
# epoch 4 / 200, step 27/55, loss = 1.9689
# epoch 4 / 200, step 28/55, loss = 2.1233
# epoch 4 / 200, step 29/55, loss = 2.1150
# epoch 4 / 200, step 30/55, loss = 2.0945
# epoch 4 / 200, step 31/55, loss = 1.9319
# epoch 4 / 200, step 32/55, loss = 1.8973
# epoch 4 / 200, step 33/55, loss = 2.0021
# epoch 4 / 200, step 34/55, loss = 1.8075
# epoch 4 / 200, step 35/55, loss = 1.7483
# epoch 4 / 200, step 36/55, loss = 2.0406
# epoch 4 / 200, step 37/55, loss = 1.9804
# epoch 4 / 200, step 38/55, loss = 1.9996
# epoch 4 / 200, step 39/55, loss = 2.0045
# epoch 4 / 200, step 40/55, loss = 2.0555
# epoch 4 / 200, step 41/55, loss = 1.9420
# epoch 4 / 200, step 42/55, loss = 2.1472
# epoch 4 / 200, step 43/55, loss = 2.0201
# epoch 4 / 200, step 44/55, loss = 2.0883
# epoch 4 / 200, step 45/55, loss = 2.0697
# epoch 4 / 200, step 46/55, loss = 2.0744
# epoch 4 / 200, step 47/55, loss = 2.0478
# epoch 4 / 200, step 48/55, loss = 1.9546
# epoch 4 / 200, step 49/55, loss = 2.0141
# epoch 4 / 200, step 50/55, loss = 2.0575
# epoch 4 / 200, step 51/55, loss = 1.9932
# epoch 4 / 200, step 52/55, loss = 1.9340
# epoch 4 / 200, step 53/55, loss = 2.0150
# epoch 4 / 200, step 54/55, loss = 1.9195
# epoch 4 / 200, step 55/55, loss = 1.9381
# epoch 4 / 200, step 1/14, loss = 1.9793
# epoch 4 / 200, step 2/14, loss = 1.9942
# epoch 4 / 200, step 3/14, loss = 1.9706
# epoch 4 / 200, step 4/14, loss = 1.9204
# epoch 4 / 200, step 5/14, loss = 1.9231
# epoch 4 / 200, step 6/14, loss = 1.8635
# epoch 4 / 200, step 7/14, loss = 1.9789
# epoch 4 / 200, step 8/14, loss = 1.9341
# epoch 4 / 200, step 9/14, loss = 1.8491
# epoch 4 / 200, step 10/14, loss = 1.8795
# epoch 4 / 200, step 11/14, loss = 1.9184
# epoch 4 / 200, step 12/14, loss = 1.9546
# epoch 4 / 200, step 13/14, loss = 2.0236
# epoch 4 / 200, step 14/14, loss = 2.0147
# epoch 5 / 200, step 1/55, loss = 1.9051
# epoch 5 / 200, step 2/55, loss = 2.0210
# epoch 5 / 200, step 3/55, loss = 1.9296
# epoch 5 / 200, step 4/55, loss = 1.9659
# epoch 5 / 200, step 5/55, loss = 2.0539
# epoch 5 / 200, step 6/55, loss = 2.0493
# epoch 5 / 200, step 7/55, loss = 1.9416
# epoch 5 / 200, step 8/55, loss = 2.0265
# epoch 5 / 200, step 9/55, loss = 2.0983
# epoch 5 / 200, step 10/55, loss = 2.0206
# epoch 5 / 200, step 11/55, loss = 2.0418
# epoch 5 / 200, step 12/55, loss = 2.0942
# epoch 5 / 200, step 13/55, loss = 1.9624
# epoch 5 / 200, step 14/55, loss = 2.0077
# epoch 5 / 200, step 15/55, loss = 2.2727
# epoch 5 / 200, step 16/55, loss = 1.7812
# epoch 5 / 200, step 17/55, loss = 2.0683
# epoch 5 / 200, step 18/55, loss = 2.3051
# epoch 5 / 200, step 19/55, loss = 2.0850
# epoch 5 / 200, step 20/55, loss = 2.1184
# epoch 5 / 200, step 21/55, loss = 2.0391
# epoch 5 / 200, step 22/55, loss = 2.0634
# epoch 5 / 200, step 23/55, loss = 1.9347
# epoch 5 / 200, step 24/55, loss = 1.9182
# epoch 5 / 200, step 25/55, loss = 1.9989
# epoch 5 / 200, step 26/55, loss = 1.9831
# epoch 5 / 200, step 27/55, loss = 1.9075
# epoch 5 / 200, step 28/55, loss = 2.0686
# epoch 5 / 200, step 29/55, loss = 2.0153
# epoch 5 / 200, step 30/55, loss = 1.9961
# epoch 5 / 200, step 31/55, loss = 2.0060
# epoch 5 / 200, step 32/55, loss = 1.9872
# epoch 5 / 200, step 33/55, loss = 1.7816
# epoch 5 / 200, step 34/55, loss = 1.9517
# epoch 5 / 200, step 35/55, loss = 1.9894
# epoch 5 / 200, step 36/55, loss = 1.9072
# epoch 5 / 200, step 37/55, loss = 2.0071
# epoch 5 / 200, step 38/55, loss = 1.9139
# epoch 5 / 200, step 39/55, loss = 2.1276
# epoch 5 / 200, step 40/55, loss = 1.9654
# epoch 5 / 200, step 41/55, loss = 2.0717
# epoch 5 / 200, step 42/55, loss = 2.0621
# epoch 5 / 200, step 43/55, loss = 1.8605
# epoch 5 / 200, step 44/55, loss = 1.9554
# epoch 5 / 200, step 45/55, loss = 2.1282
# epoch 5 / 200, step 46/55, loss = 1.9274
# epoch 5 / 200, step 47/55, loss = 1.9829
# epoch 5 / 200, step 48/55, loss = 1.8240
# epoch 5 / 200, step 49/55, loss = 2.1006
# epoch 5 / 200, step 50/55, loss = 1.8385
# epoch 5 / 200, step 51/55, loss = 1.9534
# epoch 5 / 200, step 52/55, loss = 2.1812
# epoch 5 / 200, step 53/55, loss = 2.1806
# epoch 5 / 200, step 54/55, loss = 2.0120
# epoch 5 / 200, step 55/55, loss = 2.0686
# epoch 5 / 200, step 1/14, loss = 2.0539
# epoch 5 / 200, step 2/14, loss = 1.9795
# epoch 5 / 200, step 3/14, loss = 2.0830
# epoch 5 / 200, step 4/14, loss = 1.9509
# epoch 5 / 200, step 5/14, loss = 1.9146
# epoch 5 / 200, step 6/14, loss = 1.8596
# epoch 5 / 200, step 7/14, loss = 1.9556
# epoch 5 / 200, step 8/14, loss = 2.0394
# epoch 5 / 200, step 9/14, loss = 1.8902
# epoch 5 / 200, step 10/14, loss = 1.8943
# epoch 5 / 200, step 11/14, loss = 1.8767
# epoch 5 / 200, step 12/14, loss = 1.9250
# epoch 5 / 200, step 13/14, loss = 2.0072
# epoch 5 / 200, step 14/14, loss = 2.0141
# epoch 6 / 200, step 1/55, loss = 2.0317
# epoch 6 / 200, step 2/55, loss = 2.1361
# epoch 6 / 200, step 3/55, loss = 1.9913
# epoch 6 / 200, step 4/55, loss = 1.9507
# epoch 6 / 200, step 5/55, loss = 2.0141
# epoch 6 / 200, step 6/55, loss = 1.9884
# epoch 6 / 200, step 7/55, loss = 1.9579
# epoch 6 / 200, step 8/55, loss = 2.0483
# epoch 6 / 200, step 9/55, loss = 1.8762
# epoch 6 / 200, step 10/55, loss = 1.8720
# epoch 6 / 200, step 11/55, loss = 1.9997
# epoch 6 / 200, step 12/55, loss = 1.9297
# epoch 6 / 200, step 13/55, loss = 2.0236
# epoch 6 / 200, step 14/55, loss = 2.1088
# epoch 6 / 200, step 15/55, loss = 1.9750
# epoch 6 / 200, step 16/55, loss = 1.9532
# epoch 6 / 200, step 17/55, loss = 1.8857
# epoch 6 / 200, step 18/55, loss = 2.1749
# epoch 6 / 200, step 19/55, loss = 2.0398
# epoch 6 / 200, step 20/55, loss = 2.0651
# epoch 6 / 200, step 21/55, loss = 1.9757
# epoch 6 / 200, step 22/55, loss = 1.8957
# epoch 6 / 200, step 23/55, loss = 2.1603
# epoch 6 / 200, step 24/55, loss = 1.9016
# epoch 6 / 200, step 25/55, loss = 2.0569
# epoch 6 / 200, step 26/55, loss = 1.9504
# epoch 6 / 200, step 27/55, loss = 1.9061
# epoch 6 / 200, step 28/55, loss = 2.0086
# epoch 6 / 200, step 29/55, loss = 1.9660
# epoch 6 / 200, step 30/55, loss = 2.0868
# epoch 6 / 200, step 31/55, loss = 1.9479
# epoch 6 / 200, step 32/55, loss = 2.0251
# epoch 6 / 200, step 33/55, loss = 1.8367
# epoch 6 / 200, step 34/55, loss = 2.0234
# epoch 6 / 200, step 35/55, loss = 1.9772
# epoch 6 / 200, step 36/55, loss = 1.7106
# epoch 6 / 200, step 37/55, loss = 1.9693
# epoch 6 / 200, step 38/55, loss = 1.8133
# epoch 6 / 200, step 39/55, loss = 2.1102
# epoch 6 / 200, step 40/55, loss = 1.9131
# epoch 6 / 200, step 41/55, loss = 1.9818
# epoch 6 / 200, step 42/55, loss = 1.8362
# epoch 6 / 200, step 43/55, loss = 1.9304
# epoch 6 / 200, step 44/55, loss = 2.0075
# epoch 6 / 200, step 45/55, loss = 1.9792
# epoch 6 / 200, step 46/55, loss = 2.0407
# epoch 6 / 200, step 47/55, loss = 1.9459
# epoch 6 / 200, step 48/55, loss = 1.9089
# epoch 6 / 200, step 49/55, loss = 2.0317
# epoch 6 / 200, step 50/55, loss = 2.1012
# epoch 6 / 200, step 51/55, loss = 2.0536
# epoch 6 / 200, step 52/55, loss = 1.9252
# epoch 6 / 200, step 53/55, loss = 1.7821
# epoch 6 / 200, step 54/55, loss = 2.0099
# epoch 6 / 200, step 55/55, loss = 1.9781
# epoch 6 / 200, step 1/14, loss = 2.0001
# epoch 6 / 200, step 2/14, loss = 1.9449
# epoch 6 / 200, step 3/14, loss = 2.0165
# epoch 6 / 200, step 4/14, loss = 1.9400
# epoch 6 / 200, step 5/14, loss = 1.9365
# epoch 6 / 200, step 6/14, loss = 1.8780
# epoch 6 / 200, step 7/14, loss = 1.9335
# epoch 6 / 200, step 8/14, loss = 1.9162
# epoch 6 / 200, step 9/14, loss = 1.8800
# epoch 6 / 200, step 10/14, loss = 1.9193
# epoch 6 / 200, step 11/14, loss = 1.8933
# epoch 6 / 200, step 12/14, loss = 1.9917
# epoch 6 / 200, step 13/14, loss = 2.0245
# epoch 6 / 200, step 14/14, loss = 1.9836
# epoch 7 / 200, step 1/55, loss = 2.1362
# epoch 7 / 200, step 2/55, loss = 2.0678
# epoch 7 / 200, step 3/55, loss = 1.9976
# epoch 7 / 200, step 4/55, loss = 1.9476
# epoch 7 / 200, step 5/55, loss = 1.7904
# epoch 7 / 200, step 6/55, loss = 1.8939
# epoch 7 / 200, step 7/55, loss = 2.1158
# epoch 7 / 200, step 8/55, loss = 2.0065
# epoch 7 / 200, step 9/55, loss = 1.9390
# epoch 7 / 200, step 10/55, loss = 1.9136
# epoch 7 / 200, step 11/55, loss = 2.1899
# epoch 7 / 200, step 12/55, loss = 1.9301
# epoch 7 / 200, step 13/55, loss = 2.0708
# epoch 7 / 200, step 14/55, loss = 1.9090
# epoch 7 / 200, step 15/55, loss = 1.9902
# epoch 7 / 200, step 16/55, loss = 1.9644
# epoch 7 / 200, step 17/55, loss = 2.1026
# epoch 7 / 200, step 18/55, loss = 2.0367
# epoch 7 / 200, step 19/55, loss = 1.8658
# epoch 7 / 200, step 20/55, loss = 1.7486
# epoch 7 / 200, step 21/55, loss = 1.9188
# epoch 7 / 200, step 22/55, loss = 1.8199
# epoch 7 / 200, step 23/55, loss = 2.0442
# epoch 7 / 200, step 24/55, loss = 2.0466
# epoch 7 / 200, step 25/55, loss = 2.0028
# epoch 7 / 200, step 26/55, loss = 1.8561
# epoch 7 / 200, step 27/55, loss = 2.0248
# epoch 7 / 200, step 28/55, loss = 1.9409
# epoch 7 / 200, step 29/55, loss = 1.9080
# epoch 7 / 200, step 30/55, loss = 2.0028
# epoch 7 / 200, step 31/55, loss = 1.9362
# epoch 7 / 200, step 32/55, loss = 1.9495
# epoch 7 / 200, step 33/55, loss = 1.7826
# epoch 7 / 200, step 34/55, loss = 1.9147
# epoch 7 / 200, step 35/55, loss = 1.8086
# epoch 7 / 200, step 36/55, loss = 1.9267
# epoch 7 / 200, step 37/55, loss = 2.2534
# epoch 7 / 200, step 38/55, loss = 1.9346
# epoch 7 / 200, step 39/55, loss = 2.0363
# epoch 7 / 200, step 40/55, loss = 2.0004
# epoch 7 / 200, step 41/55, loss = 2.0693
# epoch 7 / 200, step 42/55, loss = 1.8824
# epoch 7 / 200, step 43/55, loss = 1.8577
# epoch 7 / 200, step 44/55, loss = 1.9378
# epoch 7 / 200, step 45/55, loss = 1.7889
# epoch 7 / 200, step 46/55, loss = 1.8985
# epoch 7 / 200, step 47/55, loss = 1.9045
# epoch 7 / 200, step 48/55, loss = 1.8086
# epoch 7 / 200, step 49/55, loss = 1.8662
# epoch 7 / 200, step 50/55, loss = 1.9414
# epoch 7 / 200, step 51/55, loss = 1.9797
# epoch 7 / 200, step 52/55, loss = 1.9090
# epoch 7 / 200, step 53/55, loss = 1.9587
# epoch 7 / 200, step 54/55, loss = 1.8673
# epoch 7 / 200, step 55/55, loss = 1.9221
# epoch 7 / 200, step 1/14, loss = 1.9956
# epoch 7 / 200, step 2/14, loss = 1.9712
# epoch 7 / 200, step 3/14, loss = 2.0151
# epoch 7 / 200, step 4/14, loss = 1.9772
# epoch 7 / 200, step 5/14, loss = 1.9231
# epoch 7 / 200, step 6/14, loss = 1.8705
# epoch 7 / 200, step 7/14, loss = 1.9654
# epoch 7 / 200, step 8/14, loss = 1.9355
# epoch 7 / 200, step 9/14, loss = 1.9586
# epoch 7 / 200, step 10/14, loss = 1.9434
# epoch 7 / 200, step 11/14, loss = 1.8385
# epoch 7 / 200, step 12/14, loss = 1.9951
# epoch 7 / 200, step 13/14, loss = 2.0296
# epoch 7 / 200, step 14/14, loss = 1.9492
# epoch 8 / 200, step 1/55, loss = 1.8290
# epoch 8 / 200, step 2/55, loss = 1.8387
# epoch 8 / 200, step 3/55, loss = 1.9447
# epoch 8 / 200, step 4/55, loss = 1.8493
# epoch 8 / 200, step 5/55, loss = 2.0062
# epoch 8 / 200, step 6/55, loss = 1.8961
# epoch 8 / 200, step 7/55, loss = 2.1624
# epoch 8 / 200, step 8/55, loss = 1.9323
# epoch 8 / 200, step 9/55, loss = 2.0974
# epoch 8 / 200, step 10/55, loss = 1.7568
# epoch 8 / 200, step 11/55, loss = 1.9368
# epoch 8 / 200, step 12/55, loss = 1.9057
# epoch 8 / 200, step 13/55, loss = 1.9999
# epoch 8 / 200, step 14/55, loss = 1.8792
# epoch 8 / 200, step 15/55, loss = 1.9470
# epoch 8 / 200, step 16/55, loss = 1.8891
# epoch 8 / 200, step 17/55, loss = 1.9999
# epoch 8 / 200, step 18/55, loss = 1.8617
# epoch 8 / 200, step 19/55, loss = 1.9271
# epoch 8 / 200, step 20/55, loss = 1.9856
# epoch 8 / 200, step 21/55, loss = 2.0323
# epoch 8 / 200, step 22/55, loss = 1.9494
# epoch 8 / 200, step 23/55, loss = 1.8350
# epoch 8 / 200, step 24/55, loss = 1.8908
# epoch 8 / 200, step 25/55, loss = 1.9953
# epoch 8 / 200, step 26/55, loss = 1.9653
# epoch 8 / 200, step 27/55, loss = 1.7666
# epoch 8 / 200, step 28/55, loss = 1.8169
# epoch 8 / 200, step 29/55, loss = 1.9073
# epoch 8 / 200, step 30/55, loss = 2.0947
# epoch 8 / 200, step 31/55, loss = 1.9766
# epoch 8 / 200, step 32/55, loss = 2.0021
# epoch 8 / 200, step 33/55, loss = 1.8897
# epoch 8 / 200, step 34/55, loss = 2.0758
# epoch 8 / 200, step 35/55, loss = 1.9812
# epoch 8 / 200, step 36/55, loss = 2.0360
# epoch 8 / 200, step 37/55, loss = 1.9308
# epoch 8 / 200, step 38/55, loss = 1.9316
# epoch 8 / 200, step 39/55, loss = 1.9950
# epoch 8 / 200, step 40/55, loss = 1.9588
# epoch 8 / 200, step 41/55, loss = 1.9374
# epoch 8 / 200, step 42/55, loss = 2.0866
# epoch 8 / 200, step 43/55, loss = 1.8582
# epoch 8 / 200, step 44/55, loss = 1.8223
# epoch 8 / 200, step 45/55, loss = 2.0882
# epoch 8 / 200, step 46/55, loss = 1.8616
# epoch 8 / 200, step 47/55, loss = 1.9834
# epoch 8 / 200, step 48/55, loss = 2.0437
# epoch 8 / 200, step 49/55, loss = 1.9950
# epoch 8 / 200, step 50/55, loss = 1.9386
# epoch 8 / 200, step 51/55, loss = 1.8838
# epoch 8 / 200, step 52/55, loss = 1.9769
# epoch 8 / 200, step 53/55, loss = 1.8535
# epoch 8 / 200, step 54/55, loss = 2.0167
# epoch 8 / 200, step 55/55, loss = 1.9373
# epoch 8 / 200, step 1/14, loss = 1.9831
# epoch 8 / 200, step 2/14, loss = 1.9205
# epoch 8 / 200, step 3/14, loss = 2.0582
# epoch 8 / 200, step 4/14, loss = 2.0275
# epoch 8 / 200, step 5/14, loss = 1.9874
# epoch 8 / 200, step 6/14, loss = 1.8630
# epoch 8 / 200, step 7/14, loss = 1.9212
# epoch 8 / 200, step 8/14, loss = 1.9573
# epoch 8 / 200, step 9/14, loss = 1.9134
# epoch 8 / 200, step 10/14, loss = 1.9962
# epoch 8 / 200, step 11/14, loss = 1.9068
# epoch 8 / 200, step 12/14, loss = 1.9189
# epoch 8 / 200, step 13/14, loss = 1.9296
# epoch 8 / 200, step 14/14, loss = 1.9711
# epoch 9 / 200, step 1/55, loss = 2.0672
# epoch 9 / 200, step 2/55, loss = 2.0054
# epoch 9 / 200, step 3/55, loss = 1.8611
# epoch 9 / 200, step 4/55, loss = 1.9344
# epoch 9 / 200, step 5/55, loss = 1.9100
# epoch 9 / 200, step 6/55, loss = 1.9779
# epoch 9 / 200, step 7/55, loss = 1.7709
# epoch 9 / 200, step 8/55, loss = 2.0076
# epoch 9 / 200, step 9/55, loss = 1.8566
# epoch 9 / 200, step 10/55, loss = 1.9892
# epoch 9 / 200, step 11/55, loss = 2.0024
# epoch 9 / 200, step 12/55, loss = 2.0106
# epoch 9 / 200, step 13/55, loss = 1.8994
# epoch 9 / 200, step 14/55, loss = 2.0000
# epoch 9 / 200, step 15/55, loss = 2.1298
# epoch 9 / 200, step 16/55, loss = 2.0472
# epoch 9 / 200, step 17/55, loss = 1.8862
# epoch 9 / 200, step 18/55, loss = 2.1271
# epoch 9 / 200, step 19/55, loss = 1.8571
# epoch 9 / 200, step 20/55, loss = 1.9587
# epoch 9 / 200, step 21/55, loss = 1.9147
# epoch 9 / 200, step 22/55, loss = 2.1816
# epoch 9 / 200, step 23/55, loss = 1.8974
# epoch 9 / 200, step 24/55, loss = 1.8007
# epoch 9 / 200, step 25/55, loss = 1.8522
# epoch 9 / 200, step 26/55, loss = 1.8510
# epoch 9 / 200, step 27/55, loss = 1.7701
# epoch 9 / 200, step 28/55, loss = 2.0182
# epoch 9 / 200, step 29/55, loss = 1.8682
# epoch 9 / 200, step 30/55, loss = 1.9015
# epoch 9 / 200, step 31/55, loss = 1.9169
# epoch 9 / 200, step 32/55, loss = 1.8320
# epoch 9 / 200, step 33/55, loss = 1.8502
# epoch 9 / 200, step 34/55, loss = 2.2092
# epoch 9 / 200, step 35/55, loss = 1.8594
# epoch 9 / 200, step 36/55, loss = 1.9969
# epoch 9 / 200, step 37/55, loss = 2.0240
# epoch 9 / 200, step 38/55, loss = 2.1285
# epoch 9 / 200, step 39/55, loss = 2.1318
# epoch 9 / 200, step 40/55, loss = 1.8348
# epoch 9 / 200, step 41/55, loss = 1.9363
# epoch 9 / 200, step 42/55, loss = 2.0862
# epoch 9 / 200, step 43/55, loss = 1.8870
# epoch 9 / 200, step 44/55, loss = 1.9847
# epoch 9 / 200, step 45/55, loss = 2.0759
# epoch 9 / 200, step 46/55, loss = 1.9084
# epoch 9 / 200, step 47/55, loss = 1.7896
# epoch 9 / 200, step 48/55, loss = 1.8011
# epoch 9 / 200, step 49/55, loss = 1.9534
# epoch 9 / 200, step 50/55, loss = 1.9317
# epoch 9 / 200, step 51/55, loss = 2.0654
# epoch 9 / 200, step 52/55, loss = 1.8829
# epoch 9 / 200, step 53/55, loss = 1.9837
# epoch 9 / 200, step 54/55, loss = 1.9044
# epoch 9 / 200, step 55/55, loss = 1.8536
# epoch 9 / 200, step 1/14, loss = 2.0014
# epoch 9 / 200, step 2/14, loss = 1.9831
# epoch 9 / 200, step 3/14, loss = 2.0171
# epoch 9 / 200, step 4/14, loss = 1.9642
# epoch 9 / 200, step 5/14, loss = 1.9434
# epoch 9 / 200, step 6/14, loss = 1.8774
# epoch 9 / 200, step 7/14, loss = 1.9806
# epoch 9 / 200, step 8/14, loss = 1.9911
# epoch 9 / 200, step 9/14, loss = 1.8744
# epoch 9 / 200, step 10/14, loss = 1.9036
# epoch 9 / 200, step 11/14, loss = 1.8865
# epoch 9 / 200, step 12/14, loss = 1.9188
# epoch 9 / 200, step 13/14, loss = 1.9814
# epoch 9 / 200, step 14/14, loss = 1.9506
# epoch 10 / 200, step 1/55, loss = 1.9168
# epoch 10 / 200, step 2/55, loss = 1.7955
# epoch 10 / 200, step 3/55, loss = 1.9998
# epoch 10 / 200, step 4/55, loss = 1.9912
# epoch 10 / 200, step 5/55, loss = 2.0544
# epoch 10 / 200, step 6/55, loss = 2.0210
# epoch 10 / 200, step 7/55, loss = 1.8516
# epoch 10 / 200, step 8/55, loss = 2.0180
# epoch 10 / 200, step 9/55, loss = 1.9246
# epoch 10 / 200, step 10/55, loss = 2.0190
# epoch 10 / 200, step 11/55, loss = 2.0518
# epoch 10 / 200, step 12/55, loss = 2.0581
# epoch 10 / 200, step 13/55, loss = 1.9902
# epoch 10 / 200, step 14/55, loss = 1.8358
# epoch 10 / 200, step 15/55, loss = 1.8295
# epoch 10 / 200, step 16/55, loss = 1.8465
# epoch 10 / 200, step 17/55, loss = 2.1172
# epoch 10 / 200, step 18/55, loss = 1.7833
# epoch 10 / 200, step 19/55, loss = 1.8332
# epoch 10 / 200, step 20/55, loss = 1.9566
# epoch 10 / 200, step 21/55, loss = 2.0260
# epoch 10 / 200, step 22/55, loss = 1.9813
# epoch 10 / 200, step 23/55, loss = 1.9142
# epoch 10 / 200, step 24/55, loss = 2.0024
# epoch 10 / 200, step 25/55, loss = 2.1054
# epoch 10 / 200, step 26/55, loss = 1.8692
# epoch 10 / 200, step 27/55, loss = 1.7915
# epoch 10 / 200, step 28/55, loss = 2.0196
# epoch 10 / 200, step 29/55, loss = 1.8092
# epoch 10 / 200, step 30/55, loss = 1.9616
# epoch 10 / 200, step 31/55, loss = 1.9740
# epoch 10 / 200, step 32/55, loss = 1.9424
# epoch 10 / 200, step 33/55, loss = 1.9659
# epoch 10 / 200, step 34/55, loss = 1.8480
# epoch 10 / 200, step 35/55, loss = 1.9755
# epoch 10 / 200, step 36/55, loss = 1.9956
# epoch 10 / 200, step 37/55, loss = 1.7993
# epoch 10 / 200, step 38/55, loss = 1.9577
# epoch 10 / 200, step 39/55, loss = 1.9988
# epoch 10 / 200, step 40/55, loss = 1.9399
# epoch 10 / 200, step 41/55, loss = 1.9486
# epoch 10 / 200, step 42/55, loss = 1.9613
# epoch 10 / 200, step 43/55, loss = 2.0160
# epoch 10 / 200, step 44/55, loss = 2.0348
# epoch 10 / 200, step 45/55, loss = 1.8379
# epoch 10 / 200, step 46/55, loss = 1.8232
# epoch 10 / 200, step 47/55, loss = 1.9110
# epoch 10 / 200, step 48/55, loss = 1.9390
# epoch 10 / 200, step 49/55, loss = 2.1529
# epoch 10 / 200, step 50/55, loss = 1.7582
# epoch 10 / 200, step 51/55, loss = 1.8047
# epoch 10 / 200, step 52/55, loss = 2.0478
# epoch 10 / 200, step 53/55, loss = 1.9452
# epoch 10 / 200, step 54/55, loss = 1.9391
# epoch 10 / 200, step 55/55, loss = 1.8629
# epoch 10 / 200, step 1/14, loss = 2.0304
# epoch 10 / 200, step 2/14, loss = 1.9794
# epoch 10 / 200, step 3/14, loss = 2.0149
# epoch 10 / 200, step 4/14, loss = 1.8909
# epoch 10 / 200, step 5/14, loss = 1.9745
# epoch 10 / 200, step 6/14, loss = 1.8204
# epoch 10 / 200, step 7/14, loss = 2.0255
# epoch 10 / 200, step 8/14, loss = 1.9272
# epoch 10 / 200, step 9/14, loss = 1.9782
# epoch 10 / 200, step 10/14, loss = 1.9259
# epoch 10 / 200, step 11/14, loss = 1.9182
# epoch 10 / 200, step 12/14, loss = 2.0022
# epoch 10 / 200, step 13/14, loss = 2.1084
# epoch 10 / 200, step 14/14, loss = 1.9473
# epoch 11 / 200, step 1/55, loss = 1.9413
# epoch 11 / 200, step 2/55, loss = 2.0538
# epoch 11 / 200, step 3/55, loss = 1.9751
# epoch 11 / 200, step 4/55, loss = 2.1222
# epoch 11 / 200, step 5/55, loss = 2.0381
# epoch 11 / 200, step 6/55, loss = 1.8550
# epoch 11 / 200, step 7/55, loss = 1.7633
# epoch 11 / 200, step 8/55, loss = 1.8950
# epoch 11 / 200, step 9/55, loss = 2.1576
# epoch 11 / 200, step 10/55, loss = 1.8998
# epoch 11 / 200, step 11/55, loss = 1.8729
# epoch 11 / 200, step 12/55, loss = 1.9002
# epoch 11 / 200, step 13/55, loss = 2.1119
# epoch 11 / 200, step 14/55, loss = 2.0029
# epoch 11 / 200, step 15/55, loss = 2.1168
# epoch 11 / 200, step 16/55, loss = 1.9219
# epoch 11 / 200, step 17/55, loss = 1.8566
# epoch 11 / 200, step 18/55, loss = 1.9533
# epoch 11 / 200, step 19/55, loss = 2.0466
# epoch 11 / 200, step 20/55, loss = 1.8705
# epoch 11 / 200, step 21/55, loss = 1.9536
# epoch 11 / 200, step 22/55, loss = 2.0970
# epoch 11 / 200, step 23/55, loss = 2.0976
# epoch 11 / 200, step 24/55, loss = 2.0063
# epoch 11 / 200, step 25/55, loss = 1.9973
# epoch 11 / 200, step 26/55, loss = 1.9855
# epoch 11 / 200, step 27/55, loss = 1.8178
# epoch 11 / 200, step 28/55, loss = 1.8305
# epoch 11 / 200, step 29/55, loss = 1.9981
# epoch 11 / 200, step 30/55, loss = 1.9585
# epoch 11 / 200, step 31/55, loss = 2.0997
# epoch 11 / 200, step 32/55, loss = 1.8637
# epoch 11 / 200, step 33/55, loss = 2.0454
# epoch 11 / 200, step 34/55, loss = 1.9872
# epoch 11 / 200, step 35/55, loss = 1.8287
# epoch 11 / 200, step 36/55, loss = 1.8396
# epoch 11 / 200, step 37/55, loss = 1.9449
# epoch 11 / 200, step 38/55, loss = 1.9315
# epoch 11 / 200, step 39/55, loss = 1.7585
# epoch 11 / 200, step 40/55, loss = 1.8741
# epoch 11 / 200, step 41/55, loss = 1.9782
# epoch 11 / 200, step 42/55, loss = 1.9614
# epoch 11 / 200, step 43/55, loss = 1.7739
# epoch 11 / 200, step 44/55, loss = 2.0831
# epoch 11 / 200, step 45/55, loss = 2.0687
# epoch 11 / 200, step 46/55, loss = 2.0372
# epoch 11 / 200, step 47/55, loss = 1.8565
# epoch 11 / 200, step 48/55, loss = 2.0010
# epoch 11 / 200, step 49/55, loss = 1.9302
# epoch 11 / 200, step 50/55, loss = 2.0547
# epoch 11 / 200, step 51/55, loss = 2.0447
# epoch 11 / 200, step 52/55, loss = 1.9944
# epoch 11 / 200, step 53/55, loss = 1.9786
# epoch 11 / 200, step 54/55, loss = 2.0076
# epoch 11 / 200, step 55/55, loss = 1.8845
# epoch 11 / 200, step 1/14, loss = 2.0050
# epoch 11 / 200, step 2/14, loss = 1.9387
# epoch 11 / 200, step 3/14, loss = 2.0195
# epoch 11 / 200, step 4/14, loss = 1.9499
# epoch 11 / 200, step 5/14, loss = 1.9439
# epoch 11 / 200, step 6/14, loss = 1.8888
# epoch 11 / 200, step 7/14, loss = 1.9415
# epoch 11 / 200, step 8/14, loss = 1.8988
# epoch 11 / 200, step 9/14, loss = 1.9454
# epoch 11 / 200, step 10/14, loss = 1.9459
# epoch 11 / 200, step 11/14, loss = 1.9090
# epoch 11 / 200, step 12/14, loss = 1.9587
# epoch 11 / 200, step 13/14, loss = 2.0162
# epoch 11 / 200, step 14/14, loss = 1.9558
# epoch 12 / 200, step 1/55, loss = 2.0209
# epoch 12 / 200, step 2/55, loss = 2.0854
# epoch 12 / 200, step 3/55, loss = 1.9187
# epoch 12 / 200, step 4/55, loss = 2.0718
# epoch 12 / 200, step 5/55, loss = 2.0669
# epoch 12 / 200, step 6/55, loss = 1.9781
# epoch 12 / 200, step 7/55, loss = 2.0352
# epoch 12 / 200, step 8/55, loss = 1.8798
# epoch 12 / 200, step 9/55, loss = 1.7943
# epoch 12 / 200, step 10/55, loss = 1.9205
# epoch 12 / 200, step 11/55, loss = 1.9588
# epoch 12 / 200, step 12/55, loss = 1.8804
# epoch 12 / 200, step 13/55, loss = 1.9405
# epoch 12 / 200, step 14/55, loss = 2.0759
# epoch 12 / 200, step 15/55, loss = 1.9268
# epoch 12 / 200, step 16/55, loss = 1.7618
# epoch 12 / 200, step 17/55, loss = 1.9059
# epoch 12 / 200, step 18/55, loss = 1.8167
# epoch 12 / 200, step 19/55, loss = 1.9435
# epoch 12 / 200, step 20/55, loss = 1.9581
# epoch 12 / 200, step 21/55, loss = 1.9828
# epoch 12 / 200, step 22/55, loss = 2.0137
# epoch 12 / 200, step 23/55, loss = 1.9281
# epoch 12 / 200, step 24/55, loss = 1.8098
# epoch 12 / 200, step 25/55, loss = 2.0585
# epoch 12 / 200, step 26/55, loss = 1.9410
# epoch 12 / 200, step 27/55, loss = 1.9620
# epoch 12 / 200, step 28/55, loss = 1.8446
# epoch 12 / 200, step 29/55, loss = 1.8750
# epoch 12 / 200, step 30/55, loss = 1.8592
# epoch 12 / 200, step 31/55, loss = 1.8843
# epoch 12 / 200, step 32/55, loss = 1.9911
# epoch 12 / 200, step 33/55, loss = 1.7976
# epoch 12 / 200, step 34/55, loss = 1.9005
# epoch 12 / 200, step 35/55, loss = 1.7504
# epoch 12 / 200, step 36/55, loss = 2.0560
# epoch 12 / 200, step 37/55, loss = 1.9630
# epoch 12 / 200, step 38/55, loss = 1.8337
# epoch 12 / 200, step 39/55, loss = 1.8742
# epoch 12 / 200, step 40/55, loss = 2.0772
# epoch 12 / 200, step 41/55, loss = 1.9610
# epoch 12 / 200, step 42/55, loss = 1.9614
# epoch 12 / 200, step 43/55, loss = 1.8971
# epoch 12 / 200, step 44/55, loss = 2.1309
# epoch 12 / 200, step 45/55, loss = 1.9192
# epoch 12 / 200, step 46/55, loss = 1.8882
# epoch 12 / 200, step 47/55, loss = 1.9466
# epoch 12 / 200, step 48/55, loss = 1.9228
# epoch 12 / 200, step 49/55, loss = 1.9420
# epoch 12 / 200, step 50/55, loss = 2.1357
# epoch 12 / 200, step 51/55, loss = 1.8765
# epoch 12 / 200, step 52/55, loss = 1.9093
# epoch 12 / 200, step 53/55, loss = 1.9347
# epoch 12 / 200, step 54/55, loss = 2.0516
# epoch 12 / 200, step 55/55, loss = 1.7752
# epoch 12 / 200, step 1/14, loss = 1.9139
# epoch 12 / 200, step 2/14, loss = 1.9186
# epoch 12 / 200, step 3/14, loss = 1.9552
# epoch 12 / 200, step 4/14, loss = 1.9991
# epoch 12 / 200, step 5/14, loss = 1.9573
# epoch 12 / 200, step 6/14, loss = 1.8306
# epoch 12 / 200, step 7/14, loss = 1.9378
# epoch 12 / 200, step 8/14, loss = 1.8542
# epoch 12 / 200, step 9/14, loss = 1.9718
# epoch 12 / 200, step 10/14, loss = 2.0309
# epoch 12 / 200, step 11/14, loss = 1.8742
# epoch 12 / 200, step 12/14, loss = 1.9804
# epoch 12 / 200, step 13/14, loss = 2.0024
# epoch 12 / 200, step 14/14, loss = 1.9180
# epoch 13 / 200, step 1/55, loss = 1.9910
# epoch 13 / 200, step 2/55, loss = 1.9541
# epoch 13 / 200, step 3/55, loss = 1.9489
# epoch 13 / 200, step 4/55, loss = 1.9855
# epoch 13 / 200, step 5/55, loss = 1.7744
# epoch 13 / 200, step 6/55, loss = 2.0247
# epoch 13 / 200, step 7/55, loss = 2.0677
# epoch 13 / 200, step 8/55, loss = 1.9343
# epoch 13 / 200, step 9/55, loss = 1.9903
# epoch 13 / 200, step 10/55, loss = 1.8250
# epoch 13 / 200, step 11/55, loss = 2.1793
# epoch 13 / 200, step 12/55, loss = 1.8603
# epoch 13 / 200, step 13/55, loss = 1.8492
# epoch 13 / 200, step 14/55, loss = 1.9902
# epoch 13 / 200, step 15/55, loss = 1.8915
# epoch 13 / 200, step 16/55, loss = 2.1760
# epoch 13 / 200, step 17/55, loss = 1.9342
# epoch 13 / 200, step 18/55, loss = 1.8715
# epoch 13 / 200, step 19/55, loss = 2.0033
# epoch 13 / 200, step 20/55, loss = 1.9097
# epoch 13 / 200, step 21/55, loss = 1.9578
# epoch 13 / 200, step 22/55, loss = 2.0344
# epoch 13 / 200, step 23/55, loss = 2.0140
# epoch 13 / 200, step 24/55, loss = 2.0080
# epoch 13 / 200, step 25/55, loss = 1.9521
# epoch 13 / 200, step 26/55, loss = 1.8831
# epoch 13 / 200, step 27/55, loss = 1.7731
# epoch 13 / 200, step 28/55, loss = 1.9750
# epoch 13 / 200, step 29/55, loss = 1.8782
# epoch 13 / 200, step 30/55, loss = 1.9159
# epoch 13 / 200, step 31/55, loss = 2.1258
# epoch 13 / 200, step 32/55, loss = 1.8542
# epoch 13 / 200, step 33/55, loss = 1.9278
# epoch 13 / 200, step 34/55, loss = 1.9669
# epoch 13 / 200, step 35/55, loss = 2.0376
# epoch 13 / 200, step 36/55, loss = 1.8667
# epoch 13 / 200, step 37/55, loss = 1.9460
# epoch 13 / 200, step 38/55, loss = 1.8449
# epoch 13 / 200, step 39/55, loss = 1.8197
# epoch 13 / 200, step 40/55, loss = 1.8886
# epoch 13 / 200, step 41/55, loss = 1.8875
# epoch 13 / 200, step 42/55, loss = 1.9356
# epoch 13 / 200, step 43/55, loss = 2.0600
# epoch 13 / 200, step 44/55, loss = 1.9965
# epoch 13 / 200, step 45/55, loss = 2.1493
# epoch 13 / 200, step 46/55, loss = 2.0311
# epoch 13 / 200, step 47/55, loss = 1.9018
# epoch 13 / 200, step 48/55, loss = 1.9557
# epoch 13 / 200, step 49/55, loss = 2.0465
# epoch 13 / 200, step 50/55, loss = 2.0027
# epoch 13 / 200, step 51/55, loss = 1.9731
# epoch 13 / 200, step 52/55, loss = 1.9986
# epoch 13 / 200, step 53/55, loss = 2.0263
# epoch 13 / 200, step 54/55, loss = 1.9452
# epoch 13 / 200, step 55/55, loss = 2.0048
# epoch 13 / 200, step 1/14, loss = 1.9757
# epoch 13 / 200, step 2/14, loss = 2.0154
# epoch 13 / 200, step 3/14, loss = 2.0988
# epoch 13 / 200, step 4/14, loss = 2.0056
# epoch 13 / 200, step 5/14, loss = 1.9049
# epoch 13 / 200, step 6/14, loss = 1.7369
# epoch 13 / 200, step 7/14, loss = 1.9483
# epoch 13 / 200, step 8/14, loss = 1.9393
# epoch 13 / 200, step 9/14, loss = 1.8486
# epoch 13 / 200, step 10/14, loss = 2.0917
# epoch 13 / 200, step 11/14, loss = 1.8983
# epoch 13 / 200, step 12/14, loss = 1.9748
# epoch 13 / 200, step 13/14, loss = 2.0335
# epoch 13 / 200, step 14/14, loss = 1.9593
# epoch 14 / 200, step 1/55, loss = 1.9081
# epoch 14 / 200, step 2/55, loss = 1.8054
# epoch 14 / 200, step 3/55, loss = 2.0853
# epoch 14 / 200, step 4/55, loss = 1.8863
# epoch 14 / 200, step 5/55, loss = 1.9187
# epoch 14 / 200, step 6/55, loss = 1.9222
# epoch 14 / 200, step 7/55, loss = 1.8251
# epoch 14 / 200, step 8/55, loss = 1.8467
# epoch 14 / 200, step 9/55, loss = 1.9560
# epoch 14 / 200, step 10/55, loss = 1.8512
# epoch 14 / 200, step 11/55, loss = 2.0353
# epoch 14 / 200, step 12/55, loss = 1.9304
# epoch 14 / 200, step 13/55, loss = 2.0753
# epoch 14 / 200, step 14/55, loss = 2.0127
# epoch 14 / 200, step 15/55, loss = 2.0004
# epoch 14 / 200, step 16/55, loss = 1.8754
# epoch 14 / 200, step 17/55, loss = 1.9074
# epoch 14 / 200, step 18/55, loss = 1.9141
# epoch 14 / 200, step 19/55, loss = 1.7812
# epoch 14 / 200, step 20/55, loss = 1.7709
# epoch 14 / 200, step 21/55, loss = 1.9510
# epoch 14 / 200, step 22/55, loss = 1.9392
# epoch 14 / 200, step 23/55, loss = 2.0024
# epoch 14 / 200, step 24/55, loss = 2.1160
# epoch 14 / 200, step 25/55, loss = 1.9764
# epoch 14 / 200, step 26/55, loss = 2.0793
# epoch 14 / 200, step 27/55, loss = 2.0437
# epoch 14 / 200, step 28/55, loss = 1.7858
# epoch 14 / 200, step 29/55, loss = 1.9521
# epoch 14 / 200, step 30/55, loss = 1.9387
# epoch 14 / 200, step 31/55, loss = 1.6814
# epoch 14 / 200, step 32/55, loss = 2.0162
# epoch 14 / 200, step 33/55, loss = 1.8052
# epoch 14 / 200, step 34/55, loss = 1.9388
# epoch 14 / 200, step 35/55, loss = 1.8590
# epoch 14 / 200, step 36/55, loss = 1.8933
# epoch 14 / 200, step 37/55, loss = 1.9046
# epoch 14 / 200, step 38/55, loss = 1.9472
# epoch 14 / 200, step 39/55, loss = 1.9754
# epoch 14 / 200, step 40/55, loss = 1.9328
# epoch 14 / 200, step 41/55, loss = 1.9416
# epoch 14 / 200, step 42/55, loss = 1.9934
# epoch 14 / 200, step 43/55, loss = 1.9846
# epoch 14 / 200, step 44/55, loss = 1.9143
# epoch 14 / 200, step 45/55, loss = 1.9587
# epoch 14 / 200, step 46/55, loss = 1.9298
# epoch 14 / 200, step 47/55, loss = 1.9468
# epoch 14 / 200, step 48/55, loss = 1.8892
# epoch 14 / 200, step 49/55, loss = 2.0971
# epoch 14 / 200, step 50/55, loss = 1.9620
# epoch 14 / 200, step 51/55, loss = 1.8841
# epoch 14 / 200, step 52/55, loss = 2.0050
# epoch 14 / 200, step 53/55, loss = 1.9313
# epoch 14 / 200, step 54/55, loss = 1.8461
# epoch 14 / 200, step 55/55, loss = 1.8929
# epoch 14 / 200, step 1/14, loss = 1.9286
# epoch 14 / 200, step 2/14, loss = 1.9474
# epoch 14 / 200, step 3/14, loss = 2.0241
# epoch 14 / 200, step 4/14, loss = 1.9979
# epoch 14 / 200, step 5/14, loss = 1.9492
# epoch 14 / 200, step 6/14, loss = 1.7897
# epoch 14 / 200, step 7/14, loss = 1.9289
# epoch 14 / 200, step 8/14, loss = 1.9020
# epoch 14 / 200, step 9/14, loss = 1.9214
# epoch 14 / 200, step 10/14, loss = 2.0311
# epoch 14 / 200, step 11/14, loss = 1.8862
# epoch 14 / 200, step 12/14, loss = 1.9339
# epoch 14 / 200, step 13/14, loss = 1.9763
# epoch 14 / 200, step 14/14, loss = 1.9591
# epoch 15 / 200, step 1/55, loss = 2.0638
# epoch 15 / 200, step 2/55, loss = 1.9043
# epoch 15 / 200, step 3/55, loss = 1.9928
# epoch 15 / 200, step 4/55, loss = 2.0054
# epoch 15 / 200, step 5/55, loss = 2.0538
# epoch 15 / 200, step 6/55, loss = 1.9126
# epoch 15 / 200, step 7/55, loss = 2.0430
# epoch 15 / 200, step 8/55, loss = 1.8613
# epoch 15 / 200, step 9/55, loss = 1.9863
# epoch 15 / 200, step 10/55, loss = 1.8637
# epoch 15 / 200, step 11/55, loss = 1.9529
# epoch 15 / 200, step 12/55, loss = 1.8990
# epoch 15 / 200, step 13/55, loss = 1.8555
# epoch 15 / 200, step 14/55, loss = 1.8204
# epoch 15 / 200, step 15/55, loss = 2.0553
# epoch 15 / 200, step 16/55, loss = 2.1626
# epoch 15 / 200, step 17/55, loss = 1.9320
# epoch 15 / 200, step 18/55, loss = 2.0196
# epoch 15 / 200, step 19/55, loss = 2.1145
# epoch 15 / 200, step 20/55, loss = 1.8428
# epoch 15 / 200, step 21/55, loss = 1.8673
# epoch 15 / 200, step 22/55, loss = 1.9405
# epoch 15 / 200, step 23/55, loss = 2.0503
# epoch 15 / 200, step 24/55, loss = 1.8756
# epoch 15 / 200, step 25/55, loss = 1.7509
# epoch 15 / 200, step 26/55, loss = 2.1027
# epoch 15 / 200, step 27/55, loss = 1.8447
# epoch 15 / 200, step 28/55, loss = 2.0177
# epoch 15 / 200, step 29/55, loss = 2.0040
# epoch 15 / 200, step 30/55, loss = 1.9554
# epoch 15 / 200, step 31/55, loss = 2.0698
# epoch 15 / 200, step 32/55, loss = 2.0759
# epoch 15 / 200, step 33/55, loss = 1.7892
# epoch 15 / 200, step 34/55, loss = 2.0124
# epoch 15 / 200, step 35/55, loss = 1.9493
# epoch 15 / 200, step 36/55, loss = 1.9451
# epoch 15 / 200, step 37/55, loss = 1.9136
# epoch 15 / 200, step 38/55, loss = 1.9554
# epoch 15 / 200, step 39/55, loss = 1.9512
# epoch 15 / 200, step 40/55, loss = 2.1248
# epoch 15 / 200, step 41/55, loss = 1.9474
# epoch 15 / 200, step 42/55, loss = 2.0236
# epoch 15 / 200, step 43/55, loss = 1.8684
# epoch 15 / 200, step 44/55, loss = 2.0327
# epoch 15 / 200, step 45/55, loss = 1.9214
# epoch 15 / 200, step 46/55, loss = 1.7975
# epoch 15 / 200, step 47/55, loss = 2.1121
# epoch 15 / 200, step 48/55, loss = 1.9492
# epoch 15 / 200, step 49/55, loss = 1.9818
# epoch 15 / 200, step 50/55, loss = 1.8507
# epoch 15 / 200, step 51/55, loss = 2.1399
# epoch 15 / 200, step 52/55, loss = 1.9852
# epoch 15 / 200, step 53/55, loss = 2.0092
# epoch 15 / 200, step 54/55, loss = 1.9638
# epoch 15 / 200, step 55/55, loss = 1.9707
# epoch 15 / 200, step 1/14, loss = 1.9575
# epoch 15 / 200, step 2/14, loss = 1.9603
# epoch 15 / 200, step 3/14, loss = 1.9870
# epoch 15 / 200, step 4/14, loss = 1.9326
# epoch 15 / 200, step 5/14, loss = 2.0075
# epoch 15 / 200, step 6/14, loss = 1.8225
# epoch 15 / 200, step 7/14, loss = 1.9366
# epoch 15 / 200, step 8/14, loss = 1.8974
# epoch 15 / 200, step 9/14, loss = 2.0223
# epoch 15 / 200, step 10/14, loss = 1.9753
# epoch 15 / 200, step 11/14, loss = 1.9795
# epoch 15 / 200, step 12/14, loss = 1.9806
# epoch 15 / 200, step 13/14, loss = 2.0195
# epoch 15 / 200, step 14/14, loss = 1.9787
# epoch 16 / 200, step 1/55, loss = 2.0409
# epoch 16 / 200, step 2/55, loss = 1.8808
# epoch 16 / 200, step 3/55, loss = 1.9592
# epoch 16 / 200, step 4/55, loss = 2.0105
# epoch 16 / 200, step 5/55, loss = 1.9745
# epoch 16 / 200, step 6/55, loss = 1.9928
# epoch 16 / 200, step 7/55, loss = 1.9711
# epoch 16 / 200, step 8/55, loss = 2.0074
# epoch 16 / 200, step 9/55, loss = 1.8025
# epoch 16 / 200, step 10/55, loss = 1.8983
# epoch 16 / 200, step 11/55, loss = 1.8386
# epoch 16 / 200, step 12/55, loss = 1.8325
# epoch 16 / 200, step 13/55, loss = 1.8841
# epoch 16 / 200, step 14/55, loss = 1.8420
# epoch 16 / 200, step 15/55, loss = 2.0622
# epoch 16 / 200, step 16/55, loss = 1.8721
# epoch 16 / 200, step 17/55, loss = 1.9158
# epoch 16 / 200, step 18/55, loss = 1.9853
# epoch 16 / 200, step 19/55, loss = 1.9637
# epoch 16 / 200, step 20/55, loss = 1.9591
# epoch 16 / 200, step 21/55, loss = 2.0063
# epoch 16 / 200, step 22/55, loss = 2.0378
# epoch 16 / 200, step 23/55, loss = 1.9614
# epoch 16 / 200, step 24/55, loss = 1.8854
# epoch 16 / 200, step 25/55, loss = 2.0190
# epoch 16 / 200, step 26/55, loss = 1.7971
# epoch 16 / 200, step 27/55, loss = 1.9990
# epoch 16 / 200, step 28/55, loss = 2.1127
# epoch 16 / 200, step 29/55, loss = 2.0136
# epoch 16 / 200, step 30/55, loss = 2.0485
# epoch 16 / 200, step 31/55, loss = 2.0207
# epoch 16 / 200, step 32/55, loss = 2.0684
# epoch 16 / 200, step 33/55, loss = 1.9276
# epoch 16 / 200, step 34/55, loss = 2.0151
# epoch 16 / 200, step 35/55, loss = 1.8897
# epoch 16 / 200, step 36/55, loss = 1.8490
# epoch 16 / 200, step 37/55, loss = 2.1158
# epoch 16 / 200, step 38/55, loss = 1.8415
# epoch 16 / 200, step 39/55, loss = 1.9859
# epoch 16 / 200, step 40/55, loss = 1.9484
# epoch 16 / 200, step 41/55, loss = 2.0438
# epoch 16 / 200, step 42/55, loss = 1.8600
# epoch 16 / 200, step 43/55, loss = 1.9676
# epoch 16 / 200, step 44/55, loss = 1.9068
# epoch 16 / 200, step 45/55, loss = 1.9356
# epoch 16 / 200, step 46/55, loss = 1.9708
# epoch 16 / 200, step 47/55, loss = 2.1024
# epoch 16 / 200, step 48/55, loss = 1.7996
# epoch 16 / 200, step 49/55, loss = 1.8506
# epoch 16 / 200, step 50/55, loss = 2.0033
# epoch 16 / 200, step 51/55, loss = 1.9749
# epoch 16 / 200, step 52/55, loss = 1.7451
# epoch 16 / 200, step 53/55, loss = 2.0974
# epoch 16 / 200, step 54/55, loss = 1.9286
# epoch 16 / 200, step 55/55, loss = 1.8083
# epoch 16 / 200, step 1/14, loss = 1.9899
# epoch 16 / 200, step 2/14, loss = 1.9918
# epoch 16 / 200, step 3/14, loss = 2.0348
# epoch 16 / 200, step 4/14, loss = 1.9226
# epoch 16 / 200, step 5/14, loss = 1.9405
# epoch 16 / 200, step 6/14, loss = 1.8220
# epoch 16 / 200, step 7/14, loss = 1.9738
# epoch 16 / 200, step 8/14, loss = 1.9186
# epoch 16 / 200, step 9/14, loss = 1.9245
# epoch 16 / 200, step 10/14, loss = 1.9835
# epoch 16 / 200, step 11/14, loss = 1.9198
# epoch 16 / 200, step 12/14, loss = 1.9776
# epoch 16 / 200, step 13/14, loss = 2.0690
# epoch 16 / 200, step 14/14, loss = 1.9669
# epoch 17 / 200, step 1/55, loss = 1.9418
# epoch 17 / 200, step 2/55, loss = 2.0531
# epoch 17 / 200, step 3/55, loss = 1.9529
# epoch 17 / 200, step 4/55, loss = 1.8590
# epoch 17 / 200, step 5/55, loss = 1.7927
# epoch 17 / 200, step 6/55, loss = 1.9629
# epoch 17 / 200, step 7/55, loss = 1.9224
# epoch 17 / 200, step 8/55, loss = 1.9158
# epoch 17 / 200, step 9/55, loss = 2.0019
# epoch 17 / 200, step 10/55, loss = 1.9787
# epoch 17 / 200, step 11/55, loss = 1.8550
# epoch 17 / 200, step 12/55, loss = 1.8153
# epoch 17 / 200, step 13/55, loss = 2.0258
# epoch 17 / 200, step 14/55, loss = 2.0242
# epoch 17 / 200, step 15/55, loss = 2.0454
# epoch 17 / 200, step 16/55, loss = 2.0105
# epoch 17 / 200, step 17/55, loss = 2.0224
# epoch 17 / 200, step 18/55, loss = 2.0888
# epoch 17 / 200, step 19/55, loss = 1.8104
# epoch 17 / 200, step 20/55, loss = 1.9391
# epoch 17 / 200, step 21/55, loss = 1.9847
# epoch 17 / 200, step 22/55, loss = 2.0498
# epoch 17 / 200, step 23/55, loss = 2.0161
# epoch 17 / 200, step 24/55, loss = 2.0915
# epoch 17 / 200, step 25/55, loss = 1.9590
# epoch 17 / 200, step 26/55, loss = 2.1027
# epoch 17 / 200, step 27/55, loss = 2.0348
# epoch 17 / 200, step 28/55, loss = 1.8769
# epoch 17 / 200, step 29/55, loss = 1.8939
# epoch 17 / 200, step 30/55, loss = 1.9007
# epoch 17 / 200, step 31/55, loss = 1.9872
# epoch 17 / 200, step 32/55, loss = 1.8503
# epoch 17 / 200, step 33/55, loss = 1.8116
# epoch 17 / 200, step 34/55, loss = 1.9592
# epoch 17 / 200, step 35/55, loss = 2.0458
# epoch 17 / 200, step 36/55, loss = 1.8948
# epoch 17 / 200, step 37/55, loss = 1.8407
# epoch 17 / 200, step 38/55, loss = 1.9359
# epoch 17 / 200, step 39/55, loss = 2.0943
# epoch 17 / 200, step 40/55, loss = 1.9756
# epoch 17 / 200, step 41/55, loss = 2.0657
# epoch 17 / 200, step 42/55, loss = 2.0026
# epoch 17 / 200, step 43/55, loss = 2.0920
# epoch 17 / 200, step 44/55, loss = 1.8767
# epoch 17 / 200, step 45/55, loss = 2.0037
# epoch 17 / 200, step 46/55, loss = 2.0186
# epoch 17 / 200, step 47/55, loss = 1.9087
# epoch 17 / 200, step 48/55, loss = 1.8540
# epoch 17 / 200, step 49/55, loss = 1.9981
# epoch 17 / 200, step 50/55, loss = 2.1269
# epoch 17 / 200, step 51/55, loss = 1.8971
# epoch 17 / 200, step 52/55, loss = 2.1241
# epoch 17 / 200, step 53/55, loss = 1.9936
# epoch 17 / 200, step 54/55, loss = 1.9923
# epoch 17 / 200, step 55/55, loss = 1.9726
# epoch 17 / 200, step 1/14, loss = 1.9376
# epoch 17 / 200, step 2/14, loss = 1.9740
# epoch 17 / 200, step 3/14, loss = 1.9290
# epoch 17 / 200, step 4/14, loss = 2.0103
# epoch 17 / 200, step 5/14, loss = 1.9358
# ...
# epoch 195 / 200, step 41/55, loss = 1.9203
# epoch 195 / 200, step 42/55, loss = 1.9203
# epoch 195 / 200, step 43/55, loss = 2.0140
# epoch 195 / 200, step 44/55, loss = 1.9628
# epoch 195 / 200, step 45/55, loss = 1.9721
# epoch 195 / 200, step 46/55, loss = 1.8831
# epoch 195 / 200, step 47/55, loss = 2.0122
# epoch 195 / 200, step 48/55, loss = 1.9062
# epoch 195 / 200, step 49/55, loss = 1.8561
# epoch 195 / 200, step 50/55, loss = 1.9383
# epoch 195 / 200, step 51/55, loss = 1.9508
# epoch 195 / 200, step 52/55, loss = 1.9610
# epoch 195 / 200, step 53/55, loss = 1.8137
# epoch 195 / 200, step 54/55, loss = 1.9952
# epoch 195 / 200, step 55/55, loss = 1.9064
# epoch 195 / 200, step 1/14, loss = 1.9745
# epoch 195 / 200, step 2/14, loss = 1.9534
# epoch 195 / 200, step 3/14, loss = 1.9893
# epoch 195 / 200, step 4/14, loss = 1.9564
# epoch 195 / 200, step 5/14, loss = 1.9824
# epoch 195 / 200, step 6/14, loss = 1.8994
# epoch 195 / 200, step 7/14, loss = 1.9482
# epoch 195 / 200, step 8/14, loss = 1.9344
# epoch 195 / 200, step 9/14, loss = 1.9968
# epoch 195 / 200, step 10/14, loss = 1.9514
# epoch 195 / 200, step 11/14, loss = 1.9162
# epoch 195 / 200, step 12/14, loss = 1.9920
# epoch 195 / 200, step 13/14, loss = 2.0021
# epoch 195 / 200, step 14/14, loss = 1.9434
# epoch 196 / 200, step 1/55, loss = 1.7247
# epoch 196 / 200, step 2/55, loss = 1.8933
# epoch 196 / 200, step 3/55, loss = 1.9831
# epoch 196 / 200, step 4/55, loss = 1.9522
# epoch 196 / 200, step 5/55, loss = 1.9865
# epoch 196 / 200, step 6/55, loss = 1.9313
# epoch 196 / 200, step 7/55, loss = 1.9085
# epoch 196 / 200, step 8/55, loss = 2.0374
# epoch 196 / 200, step 9/55, loss = 1.9544
# epoch 196 / 200, step 10/55, loss = 1.8476
# epoch 196 / 200, step 11/55, loss = 1.8858
# epoch 196 / 200, step 12/55, loss = 1.9776
# epoch 196 / 200, step 13/55, loss = 1.9443
# epoch 196 / 200, step 14/55, loss = 1.7200
# epoch 196 / 200, step 15/55, loss = 1.9866
# epoch 196 / 200, step 16/55, loss = 1.9808
# epoch 196 / 200, step 17/55, loss = 1.9888
# epoch 196 / 200, step 18/55, loss = 1.8596
# epoch 196 / 200, step 19/55, loss = 2.0413
# epoch 196 / 200, step 20/55, loss = 1.9000
# epoch 196 / 200, step 21/55, loss = 2.0869
# epoch 196 / 200, step 22/55, loss = 2.0220
# epoch 196 / 200, step 23/55, loss = 1.9587
# epoch 196 / 200, step 24/55, loss = 1.9566
# epoch 196 / 200, step 25/55, loss = 1.8848
# epoch 196 / 200, step 26/55, loss = 1.8303
# epoch 196 / 200, step 27/55, loss = 1.9768
# epoch 196 / 200, step 28/55, loss = 1.7662
# epoch 196 / 200, step 29/55, loss = 2.0560
# epoch 196 / 200, step 30/55, loss = 1.9150
# epoch 196 / 200, step 31/55, loss = 1.8732
# epoch 196 / 200, step 32/55, loss = 1.9178
# epoch 196 / 200, step 33/55, loss = 1.9755
# epoch 196 / 200, step 34/55, loss = 1.8604
# epoch 196 / 200, step 35/55, loss = 1.9846
# epoch 196 / 200, step 36/55, loss = 1.8520
# epoch 196 / 200, step 37/55, loss = 1.8410
# epoch 196 / 200, step 38/55, loss = 1.8259
# epoch 196 / 200, step 39/55, loss = 1.8148
# epoch 196 / 200, step 40/55, loss = 1.9723
# epoch 196 / 200, step 41/55, loss = 1.9573
# epoch 196 / 200, step 42/55, loss = 1.8656
# epoch 196 / 200, step 43/55, loss = 1.8887
# epoch 196 / 200, step 44/55, loss = 1.9979
# epoch 196 / 200, step 45/55, loss = 1.9965
# epoch 196 / 200, step 46/55, loss = 2.0505
# epoch 196 / 200, step 47/55, loss = 1.9262
# epoch 196 / 200, step 48/55, loss = 2.0937
# epoch 196 / 200, step 49/55, loss = 2.0086
# epoch 196 / 200, step 50/55, loss = 1.8081
# epoch 196 / 200, step 51/55, loss = 1.9784
# epoch 196 / 200, step 52/55, loss = 1.8424
# epoch 196 / 200, step 53/55, loss = 1.8937
# epoch 196 / 200, step 54/55, loss = 1.9443
# epoch 196 / 200, step 55/55, loss = 1.9442
# epoch 196 / 200, step 1/14, loss = 1.9679
# epoch 196 / 200, step 2/14, loss = 1.9328
# epoch 196 / 200, step 3/14, loss = 2.0693
# epoch 196 / 200, step 4/14, loss = 1.9615
# epoch 196 / 200, step 5/14, loss = 1.9659
# epoch 196 / 200, step 6/14, loss = 1.8077
# epoch 196 / 200, step 7/14, loss = 1.9540
# epoch 196 / 200, step 8/14, loss = 1.9144
# epoch 196 / 200, step 9/14, loss = 1.9471
# epoch 196 / 200, step 10/14, loss = 2.0098
# epoch 196 / 200, step 11/14, loss = 1.9444
# epoch 196 / 200, step 12/14, loss = 1.9762
# epoch 196 / 200, step 13/14, loss = 2.0168
# epoch 196 / 200, step 14/14, loss = 1.9412
# epoch 197 / 200, step 1/55, loss = 1.9134
# epoch 197 / 200, step 2/55, loss = 1.9088
# epoch 197 / 200, step 3/55, loss = 1.9582
# epoch 197 / 200, step 4/55, loss = 1.9493
# epoch 197 / 200, step 5/55, loss = 2.0196
# epoch 197 / 200, step 6/55, loss = 1.8906
# epoch 197 / 200, step 7/55, loss = 1.9264
# epoch 197 / 200, step 8/55, loss = 1.8720
# epoch 197 / 200, step 9/55, loss = 1.8714
# epoch 197 / 200, step 10/55, loss = 1.9491
# epoch 197 / 200, step 11/55, loss = 1.9381
# epoch 197 / 200, step 12/55, loss = 1.9588
# epoch 197 / 200, step 13/55, loss = 1.9615
# epoch 197 / 200, step 14/55, loss = 1.9285
# epoch 197 / 200, step 15/55, loss = 1.9197
# epoch 197 / 200, step 16/55, loss = 1.8794
# epoch 197 / 200, step 17/55, loss = 1.9459
# epoch 197 / 200, step 18/55, loss = 1.8777
# epoch 197 / 200, step 19/55, loss = 1.9032
# epoch 197 / 200, step 20/55, loss = 2.0172
# epoch 197 / 200, step 21/55, loss = 2.0866
# epoch 197 / 200, step 22/55, loss = 1.9204
# epoch 197 / 200, step 23/55, loss = 1.7387
# epoch 197 / 200, step 24/55, loss = 1.9226
# epoch 197 / 200, step 25/55, loss = 1.9438
# epoch 197 / 200, step 26/55, loss = 1.9704
# epoch 197 / 200, step 27/55, loss = 1.9546
# epoch 197 / 200, step 28/55, loss = 1.8683
# epoch 197 / 200, step 29/55, loss = 1.9231
# epoch 197 / 200, step 30/55, loss = 1.8193
# epoch 197 / 200, step 31/55, loss = 2.0007
# epoch 197 / 200, step 32/55, loss = 1.9337
# epoch 197 / 200, step 33/55, loss = 2.0128
# epoch 197 / 200, step 34/55, loss = 1.9558
# epoch 197 / 200, step 35/55, loss = 1.9432
# epoch 197 / 200, step 36/55, loss = 1.9436
# epoch 197 / 200, step 37/55, loss = 1.9081
# epoch 197 / 200, step 38/55, loss = 1.9255
# epoch 197 / 200, step 39/55, loss = 1.8496
# epoch 197 / 200, step 40/55, loss = 1.8357
# epoch 197 / 200, step 41/55, loss = 1.8380
# epoch 197 / 200, step 42/55, loss = 1.9731
# epoch 197 / 200, step 43/55, loss = 1.9207
# epoch 197 / 200, step 44/55, loss = 1.9791
# epoch 197 / 200, step 45/55, loss = 1.8850
# epoch 197 / 200, step 46/55, loss = 1.8925
# epoch 197 / 200, step 47/55, loss = 2.0321
# epoch 197 / 200, step 48/55, loss = 1.8382
# epoch 197 / 200, step 49/55, loss = 1.9165
# epoch 197 / 200, step 50/55, loss = 2.0582
# epoch 197 / 200, step 51/55, loss = 1.8846
# epoch 197 / 200, step 52/55, loss = 1.7999
# epoch 197 / 200, step 53/55, loss = 1.9673
# epoch 197 / 200, step 54/55, loss = 1.8556
# epoch 197 / 200, step 55/55, loss = 1.9678
# epoch 197 / 200, step 1/14, loss = 1.9671
# epoch 197 / 200, step 2/14, loss = 1.9721
# epoch 197 / 200, step 3/14, loss = 2.0469
# epoch 197 / 200, step 4/14, loss = 1.9538
# epoch 197 / 200, step 5/14, loss = 1.9670
# epoch 197 / 200, step 6/14, loss = 1.7931
# epoch 197 / 200, step 7/14, loss = 1.9718
# epoch 197 / 200, step 8/14, loss = 1.9239
# epoch 197 / 200, step 9/14, loss = 1.9105
# epoch 197 / 200, step 10/14, loss = 2.0060
# epoch 197 / 200, step 11/14, loss = 1.9143
# epoch 197 / 200, step 12/14, loss = 1.9771
# epoch 197 / 200, step 13/14, loss = 2.0381
# epoch 197 / 200, step 14/14, loss = 1.9273
# epoch 198 / 200, step 1/55, loss = 1.8188
# epoch 198 / 200, step 2/55, loss = 2.0491
# epoch 198 / 200, step 3/55, loss = 1.9000
# epoch 198 / 200, step 4/55, loss = 1.9057
# epoch 198 / 200, step 5/55, loss = 1.8999
# epoch 198 / 200, step 6/55, loss = 1.9434
# epoch 198 / 200, step 7/55, loss = 1.9116
# epoch 198 / 200, step 8/55, loss = 2.1180
# epoch 198 / 200, step 9/55, loss = 1.9148
# epoch 198 / 200, step 10/55, loss = 2.1237
# epoch 198 / 200, step 11/55, loss = 1.9910
# epoch 198 / 200, step 12/55, loss = 2.0489
# epoch 198 / 200, step 13/55, loss = 1.8565
# epoch 198 / 200, step 14/55, loss = 2.0360
# epoch 198 / 200, step 15/55, loss = 1.9323
# epoch 198 / 200, step 16/55, loss = 2.1221
# epoch 198 / 200, step 17/55, loss = 1.8115
# epoch 198 / 200, step 18/55, loss = 1.9536
# epoch 198 / 200, step 19/55, loss = 1.8205
# epoch 198 / 200, step 20/55, loss = 1.9193
# epoch 198 / 200, step 21/55, loss = 1.9711
# epoch 198 / 200, step 22/55, loss = 1.8705
# epoch 198 / 200, step 23/55, loss = 2.0292
# epoch 198 / 200, step 24/55, loss = 1.8593
# epoch 198 / 200, step 25/55, loss = 2.0611
# epoch 198 / 200, step 26/55, loss = 1.9322
# epoch 198 / 200, step 27/55, loss = 1.9527
# epoch 198 / 200, step 28/55, loss = 1.9119
# epoch 198 / 200, step 29/55, loss = 1.8395
# epoch 198 / 200, step 30/55, loss = 1.8553
# epoch 198 / 200, step 31/55, loss = 1.8330
# epoch 198 / 200, step 32/55, loss = 2.0089
# epoch 198 / 200, step 33/55, loss = 1.8355
# epoch 198 / 200, step 34/55, loss = 1.8699
# epoch 198 / 200, step 35/55, loss = 2.0158
# epoch 198 / 200, step 36/55, loss = 1.8564
# epoch 198 / 200, step 37/55, loss = 1.9149
# epoch 198 / 200, step 38/55, loss = 1.8930
# epoch 198 / 200, step 39/55, loss = 1.8904
# epoch 198 / 200, step 40/55, loss = 1.8847
# epoch 198 / 200, step 41/55, loss = 1.9499
# epoch 198 / 200, step 42/55, loss = 1.7756
# epoch 198 / 200, step 43/55, loss = 1.8108
# epoch 198 / 200, step 44/55, loss = 1.8227
# epoch 198 / 200, step 45/55, loss = 1.9960
# epoch 198 / 200, step 46/55, loss = 1.9171
# epoch 198 / 200, step 47/55, loss = 1.9264
# epoch 198 / 200, step 48/55, loss = 1.9103
# epoch 198 / 200, step 49/55, loss = 1.9620
# epoch 198 / 200, step 50/55, loss = 1.8803
# epoch 198 / 200, step 51/55, loss = 1.9130
# epoch 198 / 200, step 52/55, loss = 1.9807
# epoch 198 / 200, step 53/55, loss = 1.8295
# epoch 198 / 200, step 54/55, loss = 1.8711
# epoch 198 / 200, step 55/55, loss = 2.0239
# epoch 198 / 200, step 1/14, loss = 1.9545
# epoch 198 / 200, step 2/14, loss = 1.9514
# epoch 198 / 200, step 3/14, loss = 2.0506
# epoch 198 / 200, step 4/14, loss = 1.9893
# epoch 198 / 200, step 5/14, loss = 1.9821
# epoch 198 / 200, step 6/14, loss = 1.7993
# epoch 198 / 200, step 7/14, loss = 1.9701
# epoch 198 / 200, step 8/14, loss = 1.8938
# epoch 198 / 200, step 9/14, loss = 1.9677
# epoch 198 / 200, step 10/14, loss = 2.0317
# epoch 198 / 200, step 11/14, loss = 1.9202
# epoch 198 / 200, step 12/14, loss = 2.0015
# epoch 198 / 200, step 13/14, loss = 2.0417
# epoch 198 / 200, step 14/14, loss = 1.9242
# epoch 199 / 200, step 1/55, loss = 2.0136
# epoch 199 / 200, step 2/55, loss = 1.9578
# epoch 199 / 200, step 3/55, loss = 1.8731
# epoch 199 / 200, step 4/55, loss = 2.0976
# epoch 199 / 200, step 5/55, loss = 1.9156
# epoch 199 / 200, step 6/55, loss = 1.9414
# epoch 199 / 200, step 7/55, loss = 1.9400
# epoch 199 / 200, step 8/55, loss = 1.9055
# epoch 199 / 200, step 9/55, loss = 1.7745
# epoch 199 / 200, step 10/55, loss = 1.9353
# epoch 199 / 200, step 11/55, loss = 1.8408
# epoch 199 / 200, step 12/55, loss = 1.9747
# epoch 199 / 200, step 13/55, loss = 1.8995
# epoch 199 / 200, step 14/55, loss = 1.9788
# epoch 199 / 200, step 15/55, loss = 2.0235
# epoch 199 / 200, step 16/55, loss = 2.0133
# epoch 199 / 200, step 17/55, loss = 1.8687
# epoch 199 / 200, step 18/55, loss = 1.8046
# epoch 199 / 200, step 19/55, loss = 1.8633
# epoch 199 / 200, step 20/55, loss = 2.0257
# epoch 199 / 200, step 21/55, loss = 1.8071
# epoch 199 / 200, step 22/55, loss = 1.9910
# epoch 199 / 200, step 23/55, loss = 1.9542
# epoch 199 / 200, step 24/55, loss = 1.9599
# epoch 199 / 200, step 25/55, loss = 1.9028
# epoch 199 / 200, step 26/55, loss = 1.9390
# epoch 199 / 200, step 27/55, loss = 1.8117
# epoch 199 / 200, step 28/55, loss = 1.8681
# epoch 199 / 200, step 29/55, loss = 1.8744
# epoch 199 / 200, step 30/55, loss = 1.8880
# epoch 199 / 200, step 31/55, loss = 1.8624
# epoch 199 / 200, step 32/55, loss = 1.8899
# epoch 199 / 200, step 33/55, loss = 1.9674
# epoch 199 / 200, step 34/55, loss = 2.0787
# epoch 199 / 200, step 35/55, loss = 1.8584
# epoch 199 / 200, step 36/55, loss = 2.1311
# epoch 199 / 200, step 37/55, loss = 1.8979
# epoch 199 / 200, step 38/55, loss = 1.9456
# epoch 199 / 200, step 39/55, loss = 1.9207
# epoch 199 / 200, step 40/55, loss = 1.9832
# epoch 199 / 200, step 41/55, loss = 1.7971
# epoch 199 / 200, step 42/55, loss = 2.0687
# epoch 199 / 200, step 43/55, loss = 1.8151
# epoch 199 / 200, step 44/55, loss = 2.0391
# epoch 199 / 200, step 45/55, loss = 1.9299
# epoch 199 / 200, step 46/55, loss = 1.7788
# epoch 199 / 200, step 47/55, loss = 2.0195
# epoch 199 / 200, step 48/55, loss = 1.8258
# epoch 199 / 200, step 49/55, loss = 1.9106
# epoch 199 / 200, step 50/55, loss = 1.9033
# epoch 199 / 200, step 51/55, loss = 1.8929
# epoch 199 / 200, step 52/55, loss = 1.8404
# epoch 199 / 200, step 53/55, loss = 2.0100
# epoch 199 / 200, step 54/55, loss = 1.8955
# epoch 199 / 200, step 55/55, loss = 1.9668
# epoch 199 / 200, step 1/14, loss = 1.9633
# epoch 199 / 200, step 2/14, loss = 1.9596
# epoch 199 / 200, step 3/14, loss = 2.0399
# epoch 199 / 200, step 4/14, loss = 1.9614
# epoch 199 / 200, step 5/14, loss = 1.9455
# epoch 199 / 200, step 6/14, loss = 1.8491
# epoch 199 / 200, step 7/14, loss = 1.9578
# epoch 199 / 200, step 8/14, loss = 1.9463
# epoch 199 / 200, step 9/14, loss = 1.9085
# epoch 199 / 200, step 10/14, loss = 1.9768
# epoch 199 / 200, step 11/14, loss = 1.9056
# epoch 199 / 200, step 12/14, loss = 1.9445
# epoch 199 / 200, step 13/14, loss = 2.0070
# epoch 199 / 200, step 14/14, loss = 1.9316
# epoch 200 / 200, step 1/55, loss = 1.8761
# epoch 200 / 200, step 2/55, loss = 1.9125
# epoch 200 / 200, step 3/55, loss = 1.9163
# epoch 200 / 200, step 4/55, loss = 1.9682
# epoch 200 / 200, step 5/55, loss = 1.8172
# epoch 200 / 200, step 6/55, loss = 1.9648
# epoch 200 / 200, step 7/55, loss = 1.9805
# epoch 200 / 200, step 8/55, loss = 1.9611
# epoch 200 / 200, step 9/55, loss = 2.0142
# epoch 200 / 200, step 10/55, loss = 2.0148
# epoch 200 / 200, step 11/55, loss = 1.9312
# epoch 200 / 200, step 12/55, loss = 1.9596
# epoch 200 / 200, step 13/55, loss = 1.8603
# epoch 200 / 200, step 14/55, loss = 1.8023
# epoch 200 / 200, step 15/55, loss = 1.9518
# epoch 200 / 200, step 16/55, loss = 1.8967
# epoch 200 / 200, step 17/55, loss = 1.8842
# epoch 200 / 200, step 18/55, loss = 1.7356
# epoch 200 / 200, step 19/55, loss = 2.0158
# epoch 200 / 200, step 20/55, loss = 1.8417
# epoch 200 / 200, step 21/55, loss = 2.0797
# epoch 200 / 200, step 22/55, loss = 1.9185
# epoch 200 / 200, step 23/55, loss = 1.9529
# epoch 200 / 200, step 24/55, loss = 1.9973
# epoch 200 / 200, step 25/55, loss = 1.8680
# epoch 200 / 200, step 26/55, loss = 2.0414
# epoch 200 / 200, step 27/55, loss = 1.9509
# epoch 200 / 200, step 28/55, loss = 1.8392
# epoch 200 / 200, step 29/55, loss = 1.8806
# epoch 200 / 200, step 30/55, loss = 1.9255
# epoch 200 / 200, step 31/55, loss = 1.8923
# epoch 200 / 200, step 32/55, loss = 1.8371
# epoch 200 / 200, step 33/55, loss = 1.8976
# epoch 200 / 200, step 34/55, loss = 1.8650
# epoch 200 / 200, step 35/55, loss = 1.8041
# epoch 200 / 200, step 36/55, loss = 1.9530
# epoch 200 / 200, step 37/55, loss = 1.9245
# epoch 200 / 200, step 38/55, loss = 2.0381
# epoch 200 / 200, step 39/55, loss = 1.9404
# epoch 200 / 200, step 40/55, loss = 1.9146
# epoch 200 / 200, step 41/55, loss = 1.9040
# epoch 200 / 200, step 42/55, loss = 1.9035
# epoch 200 / 200, step 43/55, loss = 1.7869
# epoch 200 / 200, step 44/55, loss = 1.9336
# epoch 200 / 200, step 45/55, loss = 1.9712
# epoch 200 / 200, step 46/55, loss = 1.8942
# epoch 200 / 200, step 47/55, loss = 1.9657
# epoch 200 / 200, step 48/55, loss = 2.0794
# epoch 200 / 200, step 49/55, loss = 1.9204
# epoch 200 / 200, step 50/55, loss = 1.9467
# epoch 200 / 200, step 51/55, loss = 1.9628
# epoch 200 / 200, step 52/55, loss = 1.9141
# epoch 200 / 200, step 53/55, loss = 1.9032
# epoch 200 / 200, step 54/55, loss = 1.9168
# epoch 200 / 200, step 55/55, loss = 1.9882
# epoch 200 / 200, step 1/14, loss = 1.9732
# epoch 200 / 200, step 2/14, loss = 1.9376
# epoch 200 / 200, step 3/14, loss = 2.0509
# epoch 200 / 200, step 4/14, loss = 1.9572
# epoch 200 / 200, step 5/14, loss = 1.9926
# epoch 200 / 200, step 6/14, loss = 1.8106
# epoch 200 / 200, step 7/14, loss = 1.9570
# epoch 200 / 200, step 8/14, loss = 1.9177
# epoch 200 / 200, step 9/14, loss = 1.9662
# epoch 200 / 200, step 10/14, loss = 1.9987
# epoch 200 / 200, step 11/14, loss = 1.9361
# epoch 200 / 200, step 12/14, loss = 1.9846
# epoch 200 / 200, step 13/14, loss = 2.0190
# epoch 200 / 200, step 14/14, loss = 1.9386

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 200 epochs the trainning accuracy is 19.885714285714286 and the test accuaracy is 17.35159817351598
#  the maximum accuracy of the test was 21.91780821917808 at the epoch 107
#  the maximum accuracy of the train was 22.17142857142857 at the epoch 95
# the accuracy of the training at the best validation accuracy 21.91780821917808 is 20.571428571428573

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
