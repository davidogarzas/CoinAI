# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Batch size 32 a 16
# - leanring 0.0001 a 0.00025

# %%
filepath = '21 - 100epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 100
batch_size = 16
learning_rate = 0.00025
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([16, 769024]) , Labels shape: torch.Size([16])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 100, step 1/55, loss = 2.2437
# epoch 1 / 100, step 2/55, loss = 1.9465
# epoch 1 / 100, step 3/55, loss = 2.0785
# epoch 1 / 100, step 4/55, loss = 1.9633
# epoch 1 / 100, step 5/55, loss = 1.9567
# epoch 1 / 100, step 6/55, loss = 2.1674
# epoch 1 / 100, step 7/55, loss = 1.9738
# epoch 1 / 100, step 8/55, loss = 1.9721
# epoch 1 / 100, step 9/55, loss = 2.0967
# epoch 1 / 100, step 10/55, loss = 2.0230
# epoch 1 / 100, step 11/55, loss = 2.0841
# epoch 1 / 100, step 12/55, loss = 2.1541
# epoch 1 / 100, step 13/55, loss = 2.0652
# epoch 1 / 100, step 14/55, loss = 1.8580
# epoch 1 / 100, step 15/55, loss = 2.0570
# epoch 1 / 100, step 16/55, loss = 2.3391
# epoch 1 / 100, step 17/55, loss = 2.0855
# epoch 1 / 100, step 18/55, loss = 1.9933
# epoch 1 / 100, step 19/55, loss = 2.2526
# epoch 1 / 100, step 20/55, loss = 1.9200
# epoch 1 / 100, step 21/55, loss = 1.9163
# epoch 1 / 100, step 22/55, loss = 2.0176
# epoch 1 / 100, step 23/55, loss = 2.1352
# epoch 1 / 100, step 24/55, loss = 1.8751
# epoch 1 / 100, step 25/55, loss = 1.8931
# epoch 1 / 100, step 26/55, loss = 2.1597
# epoch 1 / 100, step 27/55, loss = 2.0311
# epoch 1 / 100, step 28/55, loss = 1.9910
# epoch 1 / 100, step 29/55, loss = 1.8976
# epoch 1 / 100, step 30/55, loss = 2.1929
# epoch 1 / 100, step 31/55, loss = 2.1496
# epoch 1 / 100, step 32/55, loss = 2.0261
# epoch 1 / 100, step 33/55, loss = 1.9677
# epoch 1 / 100, step 34/55, loss = 2.0935
# epoch 1 / 100, step 35/55, loss = 2.0138
# epoch 1 / 100, step 36/55, loss = 2.0143
# epoch 1 / 100, step 37/55, loss = 1.9313
# epoch 1 / 100, step 38/55, loss = 2.0162
# epoch 1 / 100, step 39/55, loss = 2.0104
# epoch 1 / 100, step 40/55, loss = 2.0298
# epoch 1 / 100, step 41/55, loss = 2.0019
# epoch 1 / 100, step 42/55, loss = 1.8927
# epoch 1 / 100, step 43/55, loss = 1.8799
# epoch 1 / 100, step 44/55, loss = 2.1124
# epoch 1 / 100, step 45/55, loss = 2.1457
# epoch 1 / 100, step 46/55, loss = 2.1405
# epoch 1 / 100, step 47/55, loss = 2.0211
# epoch 1 / 100, step 48/55, loss = 2.1429
# epoch 1 / 100, step 49/55, loss = 2.0833
# epoch 1 / 100, step 50/55, loss = 2.0572
# epoch 1 / 100, step 51/55, loss = 2.0733
# epoch 1 / 100, step 52/55, loss = 1.9323
# epoch 1 / 100, step 53/55, loss = 1.9539
# epoch 1 / 100, step 54/55, loss = 2.2463
# epoch 1 / 100, step 55/55, loss = 1.9283
# epoch 1 / 100, step 1/14, loss = 1.9746
# epoch 1 / 100, step 2/14, loss = 2.0409
# epoch 1 / 100, step 3/14, loss = 2.0430
# epoch 1 / 100, step 4/14, loss = 1.9756
# epoch 1 / 100, step 5/14, loss = 1.8857
# epoch 1 / 100, step 6/14, loss = 1.9576
# epoch 1 / 100, step 7/14, loss = 1.9311
# epoch 1 / 100, step 8/14, loss = 1.9287
# epoch 1 / 100, step 9/14, loss = 1.9121
# epoch 1 / 100, step 10/14, loss = 1.9754
# epoch 1 / 100, step 11/14, loss = 1.9687
# epoch 1 / 100, step 12/14, loss = 1.9881
# epoch 1 / 100, step 13/14, loss = 2.0445
# epoch 1 / 100, step 14/14, loss = 1.8641
# epoch 2 / 100, step 1/55, loss = 1.9925
# epoch 2 / 100, step 2/55, loss = 2.1013
# epoch 2 / 100, step 3/55, loss = 1.9847
# epoch 2 / 100, step 4/55, loss = 1.9343
# epoch 2 / 100, step 5/55, loss = 1.9022
# epoch 2 / 100, step 6/55, loss = 2.0547
# epoch 2 / 100, step 7/55, loss = 1.8603
# epoch 2 / 100, step 8/55, loss = 2.0256
# epoch 2 / 100, step 9/55, loss = 2.0712
# epoch 2 / 100, step 10/55, loss = 2.0568
# epoch 2 / 100, step 11/55, loss = 1.9945
# epoch 2 / 100, step 12/55, loss = 1.8201
# epoch 2 / 100, step 13/55, loss = 2.0144
# epoch 2 / 100, step 14/55, loss = 2.1162
# epoch 2 / 100, step 15/55, loss = 1.8729
# epoch 2 / 100, step 16/55, loss = 1.9137
# epoch 2 / 100, step 17/55, loss = 2.1482
# epoch 2 / 100, step 18/55, loss = 2.0443
# epoch 2 / 100, step 19/55, loss = 2.0435
# epoch 2 / 100, step 20/55, loss = 1.8709
# epoch 2 / 100, step 21/55, loss = 2.0519
# epoch 2 / 100, step 22/55, loss = 1.7478
# epoch 2 / 100, step 23/55, loss = 1.9885
# epoch 2 / 100, step 24/55, loss = 2.0334
# epoch 2 / 100, step 25/55, loss = 2.1000
# epoch 2 / 100, step 26/55, loss = 1.9774
# epoch 2 / 100, step 27/55, loss = 2.0363
# epoch 2 / 100, step 28/55, loss = 1.9915
# epoch 2 / 100, step 29/55, loss = 1.9484
# epoch 2 / 100, step 30/55, loss = 1.8774
# epoch 2 / 100, step 31/55, loss = 1.9618
# epoch 2 / 100, step 32/55, loss = 1.8769
# epoch 2 / 100, step 33/55, loss = 2.0211
# epoch 2 / 100, step 34/55, loss = 1.8188
# epoch 2 / 100, step 35/55, loss = 2.0424
# epoch 2 / 100, step 36/55, loss = 2.0849
# epoch 2 / 100, step 37/55, loss = 2.0188
# epoch 2 / 100, step 38/55, loss = 2.0471
# epoch 2 / 100, step 39/55, loss = 2.0066
# epoch 2 / 100, step 40/55, loss = 2.0482
# epoch 2 / 100, step 41/55, loss = 1.9294
# epoch 2 / 100, step 42/55, loss = 2.0957
# epoch 2 / 100, step 43/55, loss = 1.7982
# epoch 2 / 100, step 44/55, loss = 2.0505
# epoch 2 / 100, step 45/55, loss = 2.1012
# epoch 2 / 100, step 46/55, loss = 1.9221
# epoch 2 / 100, step 47/55, loss = 2.0557
# epoch 2 / 100, step 48/55, loss = 2.1448
# epoch 2 / 100, step 49/55, loss = 1.8277
# epoch 2 / 100, step 50/55, loss = 2.0467
# epoch 2 / 100, step 51/55, loss = 1.9480
# epoch 2 / 100, step 52/55, loss = 2.0230
# epoch 2 / 100, step 53/55, loss = 2.0187
# epoch 2 / 100, step 54/55, loss = 1.9468
# epoch 2 / 100, step 55/55, loss = 1.8191
# epoch 2 / 100, step 1/14, loss = 1.9304
# epoch 2 / 100, step 2/14, loss = 2.0048
# epoch 2 / 100, step 3/14, loss = 2.1180
# epoch 2 / 100, step 4/14, loss = 2.0253
# epoch 2 / 100, step 5/14, loss = 1.9106
# epoch 2 / 100, step 6/14, loss = 1.8567
# epoch 2 / 100, step 7/14, loss = 1.9403
# epoch 2 / 100, step 8/14, loss = 1.8618
# epoch 2 / 100, step 9/14, loss = 1.9158
# epoch 2 / 100, step 10/14, loss = 1.9969
# epoch 2 / 100, step 11/14, loss = 1.8517
# epoch 2 / 100, step 12/14, loss = 1.9826
# epoch 2 / 100, step 13/14, loss = 2.0096
# epoch 2 / 100, step 14/14, loss = 1.8982
# epoch 3 / 100, step 1/55, loss = 2.0055
# epoch 3 / 100, step 2/55, loss = 1.9150
# epoch 3 / 100, step 3/55, loss = 2.1576
# epoch 3 / 100, step 4/55, loss = 1.8570
# epoch 3 / 100, step 5/55, loss = 1.9580
# epoch 3 / 100, step 6/55, loss = 1.9255
# epoch 3 / 100, step 7/55, loss = 1.9579
# epoch 3 / 100, step 8/55, loss = 1.9374
# epoch 3 / 100, step 9/55, loss = 2.1024
# epoch 3 / 100, step 10/55, loss = 2.0993
# epoch 3 / 100, step 11/55, loss = 1.8767
# epoch 3 / 100, step 12/55, loss = 1.9151
# epoch 3 / 100, step 13/55, loss = 1.9811
# epoch 3 / 100, step 14/55, loss = 2.0099
# epoch 3 / 100, step 15/55, loss = 2.2277
# epoch 3 / 100, step 16/55, loss = 1.9440
# epoch 3 / 100, step 17/55, loss = 1.7376
# epoch 3 / 100, step 18/55, loss = 2.0679
# epoch 3 / 100, step 19/55, loss = 2.0823
# epoch 3 / 100, step 20/55, loss = 2.0985
# epoch 3 / 100, step 21/55, loss = 2.0318
# epoch 3 / 100, step 22/55, loss = 2.0354
# epoch 3 / 100, step 23/55, loss = 2.1631
# epoch 3 / 100, step 24/55, loss = 1.9949
# epoch 3 / 100, step 25/55, loss = 1.9475
# epoch 3 / 100, step 26/55, loss = 1.9738
# epoch 3 / 100, step 27/55, loss = 2.1779
# epoch 3 / 100, step 28/55, loss = 2.0234
# epoch 3 / 100, step 29/55, loss = 2.0517
# epoch 3 / 100, step 30/55, loss = 1.9181
# epoch 3 / 100, step 31/55, loss = 2.0460
# epoch 3 / 100, step 32/55, loss = 2.1570
# epoch 3 / 100, step 33/55, loss = 1.9937
# epoch 3 / 100, step 34/55, loss = 1.9827
# epoch 3 / 100, step 35/55, loss = 1.9795
# epoch 3 / 100, step 36/55, loss = 2.0055
# epoch 3 / 100, step 37/55, loss = 2.0057
# epoch 3 / 100, step 38/55, loss = 2.1127
# epoch 3 / 100, step 39/55, loss = 2.1335
# epoch 3 / 100, step 40/55, loss = 1.9328
# epoch 3 / 100, step 41/55, loss = 1.9363
# epoch 3 / 100, step 42/55, loss = 1.9514
# epoch 3 / 100, step 43/55, loss = 2.0996
# epoch 3 / 100, step 44/55, loss = 2.0099
# epoch 3 / 100, step 45/55, loss = 2.0174
# epoch 3 / 100, step 46/55, loss = 1.9131
# epoch 3 / 100, step 47/55, loss = 2.1582
# epoch 3 / 100, step 48/55, loss = 2.0253
# epoch 3 / 100, step 49/55, loss = 2.0470
# epoch 3 / 100, step 50/55, loss = 2.1259
# epoch 3 / 100, step 51/55, loss = 2.2041
# epoch 3 / 100, step 52/55, loss = 2.0176
# epoch 3 / 100, step 53/55, loss = 1.9393
# epoch 3 / 100, step 54/55, loss = 1.9977
# epoch 3 / 100, step 55/55, loss = 1.7577
# epoch 3 / 100, step 1/14, loss = 1.9081
# epoch 3 / 100, step 2/14, loss = 1.9667
# epoch 3 / 100, step 3/14, loss = 2.1040
# epoch 3 / 100, step 4/14, loss = 1.9826
# epoch 3 / 100, step 5/14, loss = 1.9045
# epoch 3 / 100, step 6/14, loss = 1.8865
# epoch 3 / 100, step 7/14, loss = 1.9296
# epoch 3 / 100, step 8/14, loss = 1.8600
# epoch 3 / 100, step 9/14, loss = 1.9040
# epoch 3 / 100, step 10/14, loss = 2.1005
# epoch 3 / 100, step 11/14, loss = 1.9260
# epoch 3 / 100, step 12/14, loss = 1.9828
# epoch 3 / 100, step 13/14, loss = 1.9737
# epoch 3 / 100, step 14/14, loss = 1.8814
# epoch 4 / 100, step 1/55, loss = 1.9318
# epoch 4 / 100, step 2/55, loss = 1.9815
# epoch 4 / 100, step 3/55, loss = 1.8507
# epoch 4 / 100, step 4/55, loss = 2.0114
# epoch 4 / 100, step 5/55, loss = 1.9814
# epoch 4 / 100, step 6/55, loss = 2.1348
# epoch 4 / 100, step 7/55, loss = 2.0943
# epoch 4 / 100, step 8/55, loss = 2.1060
# epoch 4 / 100, step 9/55, loss = 1.9266
# epoch 4 / 100, step 10/55, loss = 1.7845
# epoch 4 / 100, step 11/55, loss = 2.0563
# epoch 4 / 100, step 12/55, loss = 2.0121
# epoch 4 / 100, step 13/55, loss = 1.9083
# epoch 4 / 100, step 14/55, loss = 1.9439
# epoch 4 / 100, step 15/55, loss = 1.9572
# epoch 4 / 100, step 16/55, loss = 1.9571
# epoch 4 / 100, step 17/55, loss = 1.6830
# epoch 4 / 100, step 18/55, loss = 2.0679
# epoch 4 / 100, step 19/55, loss = 2.0815
# epoch 4 / 100, step 20/55, loss = 1.9974
# epoch 4 / 100, step 21/55, loss = 1.9330
# epoch 4 / 100, step 22/55, loss = 1.8488
# epoch 4 / 100, step 23/55, loss = 1.9701
# epoch 4 / 100, step 24/55, loss = 1.8548
# epoch 4 / 100, step 25/55, loss = 1.7860
# epoch 4 / 100, step 26/55, loss = 2.2203
# epoch 4 / 100, step 27/55, loss = 2.0941
# epoch 4 / 100, step 28/55, loss = 2.1006
# epoch 4 / 100, step 29/55, loss = 1.9048
# epoch 4 / 100, step 30/55, loss = 2.0245
# epoch 4 / 100, step 31/55, loss = 1.9201
# epoch 4 / 100, step 32/55, loss = 1.9832
# epoch 4 / 100, step 33/55, loss = 1.9787
# epoch 4 / 100, step 34/55, loss = 1.8096
# epoch 4 / 100, step 35/55, loss = 1.7793
# epoch 4 / 100, step 36/55, loss = 1.9303
# epoch 4 / 100, step 37/55, loss = 1.8949
# epoch 4 / 100, step 38/55, loss = 1.9476
# epoch 4 / 100, step 39/55, loss = 1.9672
# epoch 4 / 100, step 40/55, loss = 1.9412
# epoch 4 / 100, step 41/55, loss = 2.0718
# epoch 4 / 100, step 42/55, loss = 2.2036
# epoch 4 / 100, step 43/55, loss = 1.8205
# epoch 4 / 100, step 44/55, loss = 1.8585
# epoch 4 / 100, step 45/55, loss = 1.9523
# epoch 4 / 100, step 46/55, loss = 2.0791
# epoch 4 / 100, step 47/55, loss = 1.9169
# epoch 4 / 100, step 48/55, loss = 2.0067
# epoch 4 / 100, step 49/55, loss = 1.9860
# epoch 4 / 100, step 50/55, loss = 2.0332
# epoch 4 / 100, step 51/55, loss = 2.1075
# epoch 4 / 100, step 52/55, loss = 2.1353
# epoch 4 / 100, step 53/55, loss = 1.9068
# epoch 4 / 100, step 54/55, loss = 1.9026
# epoch 4 / 100, step 55/55, loss = 1.8051
# epoch 4 / 100, step 1/14, loss = 1.9622
# epoch 4 / 100, step 2/14, loss = 1.9459
# epoch 4 / 100, step 3/14, loss = 2.0902
# epoch 4 / 100, step 4/14, loss = 1.9645
# epoch 4 / 100, step 5/14, loss = 1.9531
# epoch 4 / 100, step 6/14, loss = 1.8371
# epoch 4 / 100, step 7/14, loss = 1.9559
# epoch 4 / 100, step 8/14, loss = 1.8671
# epoch 4 / 100, step 9/14, loss = 1.9161
# epoch 4 / 100, step 10/14, loss = 2.0235
# epoch 4 / 100, step 11/14, loss = 1.9571
# epoch 4 / 100, step 12/14, loss = 1.9784
# epoch 4 / 100, step 13/14, loss = 1.9883
# epoch 4 / 100, step 14/14, loss = 1.8741
# epoch 5 / 100, step 1/55, loss = 1.9770
# epoch 5 / 100, step 2/55, loss = 1.9531
# epoch 5 / 100, step 3/55, loss = 1.9286
# epoch 5 / 100, step 4/55, loss = 1.8302
# epoch 5 / 100, step 5/55, loss = 1.9875
# epoch 5 / 100, step 6/55, loss = 2.0891
# epoch 5 / 100, step 7/55, loss = 1.8697
# epoch 5 / 100, step 8/55, loss = 1.9553
# epoch 5 / 100, step 9/55, loss = 2.1757
# epoch 5 / 100, step 10/55, loss = 1.7069
# epoch 5 / 100, step 11/55, loss = 1.9109
# epoch 5 / 100, step 12/55, loss = 1.9116
# epoch 5 / 100, step 13/55, loss = 1.9535
# epoch 5 / 100, step 14/55, loss = 2.0304
# epoch 5 / 100, step 15/55, loss = 2.0573
# epoch 5 / 100, step 16/55, loss = 1.8148
# epoch 5 / 100, step 17/55, loss = 1.8860
# epoch 5 / 100, step 18/55, loss = 2.0628
# epoch 5 / 100, step 19/55, loss = 2.2093
# epoch 5 / 100, step 20/55, loss = 2.0863
# epoch 5 / 100, step 21/55, loss = 1.9380
# epoch 5 / 100, step 22/55, loss = 1.8154
# epoch 5 / 100, step 23/55, loss = 2.1568
# epoch 5 / 100, step 24/55, loss = 2.0883
# epoch 5 / 100, step 25/55, loss = 2.0112
# epoch 5 / 100, step 26/55, loss = 1.8949
# epoch 5 / 100, step 27/55, loss = 1.8546
# epoch 5 / 100, step 28/55, loss = 1.9353
# epoch 5 / 100, step 29/55, loss = 1.9842
# epoch 5 / 100, step 30/55, loss = 2.0263
# epoch 5 / 100, step 31/55, loss = 1.9798
# epoch 5 / 100, step 32/55, loss = 1.7932
# epoch 5 / 100, step 33/55, loss = 1.7887
# epoch 5 / 100, step 34/55, loss = 1.9591
# epoch 5 / 100, step 35/55, loss = 1.8978
# epoch 5 / 100, step 36/55, loss = 1.9601
# epoch 5 / 100, step 37/55, loss = 1.9262
# epoch 5 / 100, step 38/55, loss = 1.9803
# epoch 5 / 100, step 39/55, loss = 2.0806
# epoch 5 / 100, step 40/55, loss = 1.9355
# epoch 5 / 100, step 41/55, loss = 2.0555
# epoch 5 / 100, step 42/55, loss = 2.0935
# epoch 5 / 100, step 43/55, loss = 2.0458
# epoch 5 / 100, step 44/55, loss = 2.0631
# epoch 5 / 100, step 45/55, loss = 2.0104
# epoch 5 / 100, step 46/55, loss = 1.8656
# epoch 5 / 100, step 47/55, loss = 1.9018
# epoch 5 / 100, step 48/55, loss = 1.9337
# epoch 5 / 100, step 49/55, loss = 1.9890
# epoch 5 / 100, step 50/55, loss = 2.0462
# epoch 5 / 100, step 51/55, loss = 2.0510
# epoch 5 / 100, step 52/55, loss = 2.1406
# epoch 5 / 100, step 53/55, loss = 1.9161
# epoch 5 / 100, step 54/55, loss = 1.9233
# epoch 5 / 100, step 55/55, loss = 2.0391
# epoch 5 / 100, step 1/14, loss = 1.9641
# epoch 5 / 100, step 2/14, loss = 1.9467
# epoch 5 / 100, step 3/14, loss = 2.0571
# epoch 5 / 100, step 4/14, loss = 1.9456
# epoch 5 / 100, step 5/14, loss = 1.9345
# epoch 5 / 100, step 6/14, loss = 1.8552
# epoch 5 / 100, step 7/14, loss = 1.8943
# epoch 5 / 100, step 8/14, loss = 1.9506
# epoch 5 / 100, step 9/14, loss = 1.8835
# epoch 5 / 100, step 10/14, loss = 1.9951
# epoch 5 / 100, step 11/14, loss = 1.9206
# epoch 5 / 100, step 12/14, loss = 1.9931
# epoch 5 / 100, step 13/14, loss = 2.0206
# epoch 5 / 100, step 14/14, loss = 1.8874
# epoch 6 / 100, step 1/55, loss = 2.1904
# epoch 6 / 100, step 2/55, loss = 2.0016
# epoch 6 / 100, step 3/55, loss = 1.9385
# epoch 6 / 100, step 4/55, loss = 1.8719
# epoch 6 / 100, step 5/55, loss = 1.8299
# epoch 6 / 100, step 6/55, loss = 1.8283
# epoch 6 / 100, step 7/55, loss = 1.7222
# epoch 6 / 100, step 8/55, loss = 1.9364
# epoch 6 / 100, step 9/55, loss = 2.0757
# epoch 6 / 100, step 10/55, loss = 1.9350
# epoch 6 / 100, step 11/55, loss = 2.1425
# epoch 6 / 100, step 12/55, loss = 2.0384
# epoch 6 / 100, step 13/55, loss = 1.9420
# epoch 6 / 100, step 14/55, loss = 2.0190
# epoch 6 / 100, step 15/55, loss = 1.8312
# epoch 6 / 100, step 16/55, loss = 1.8909
# epoch 6 / 100, step 17/55, loss = 1.8784
# epoch 6 / 100, step 18/55, loss = 2.0106
# epoch 6 / 100, step 19/55, loss = 1.9591
# epoch 6 / 100, step 20/55, loss = 2.0129
# epoch 6 / 100, step 21/55, loss = 1.9539
# epoch 6 / 100, step 22/55, loss = 1.8555
# epoch 6 / 100, step 23/55, loss = 2.2197
# epoch 6 / 100, step 24/55, loss = 1.9258
# epoch 6 / 100, step 25/55, loss = 2.0367
# epoch 6 / 100, step 26/55, loss = 1.8608
# epoch 6 / 100, step 27/55, loss = 1.7859
# epoch 6 / 100, step 28/55, loss = 1.9362
# epoch 6 / 100, step 29/55, loss = 1.9757
# epoch 6 / 100, step 30/55, loss = 2.0380
# epoch 6 / 100, step 31/55, loss = 1.8353
# epoch 6 / 100, step 32/55, loss = 1.9657
# epoch 6 / 100, step 33/55, loss = 1.8393
# epoch 6 / 100, step 34/55, loss = 1.9315
# epoch 6 / 100, step 35/55, loss = 2.0794
# epoch 6 / 100, step 36/55, loss = 1.8740
# epoch 6 / 100, step 37/55, loss = 2.0137
# epoch 6 / 100, step 38/55, loss = 1.9089
# epoch 6 / 100, step 39/55, loss = 1.9147
# epoch 6 / 100, step 40/55, loss = 1.9725
# epoch 6 / 100, step 41/55, loss = 2.0130
# epoch 6 / 100, step 42/55, loss = 1.8361
# epoch 6 / 100, step 43/55, loss = 1.8001
# epoch 6 / 100, step 44/55, loss = 2.1065
# epoch 6 / 100, step 45/55, loss = 2.0971
# epoch 6 / 100, step 46/55, loss = 2.3330
# epoch 6 / 100, step 47/55, loss = 2.1054
# epoch 6 / 100, step 48/55, loss = 1.7923
# epoch 6 / 100, step 49/55, loss = 2.0654
# epoch 6 / 100, step 50/55, loss = 2.0930
# epoch 6 / 100, step 51/55, loss = 2.0191
# epoch 6 / 100, step 52/55, loss = 2.0588
# epoch 6 / 100, step 53/55, loss = 1.8464
# epoch 6 / 100, step 54/55, loss = 2.1685
# epoch 6 / 100, step 55/55, loss = 1.9035
# epoch 6 / 100, step 1/14, loss = 1.9520
# epoch 6 / 100, step 2/14, loss = 1.9503
# epoch 6 / 100, step 3/14, loss = 2.0517
# epoch 6 / 100, step 4/14, loss = 1.9009
# epoch 6 / 100, step 5/14, loss = 1.9743
# epoch 6 / 100, step 6/14, loss = 1.8759
# epoch 6 / 100, step 7/14, loss = 1.9272
# epoch 6 / 100, step 8/14, loss = 1.9627
# epoch 6 / 100, step 9/14, loss = 1.9488
# epoch 6 / 100, step 10/14, loss = 1.9520
# epoch 6 / 100, step 11/14, loss = 1.9333
# epoch 6 / 100, step 12/14, loss = 1.9732
# epoch 6 / 100, step 13/14, loss = 1.9764
# epoch 6 / 100, step 14/14, loss = 1.8664
# epoch 7 / 100, step 1/55, loss = 1.9173
# epoch 7 / 100, step 2/55, loss = 1.9372
# epoch 7 / 100, step 3/55, loss = 1.7702
# epoch 7 / 100, step 4/55, loss = 1.9428
# epoch 7 / 100, step 5/55, loss = 1.8478
# epoch 7 / 100, step 6/55, loss = 1.8588
# epoch 7 / 100, step 7/55, loss = 2.0515
# epoch 7 / 100, step 8/55, loss = 1.9378
# epoch 7 / 100, step 9/55, loss = 1.9791
# epoch 7 / 100, step 10/55, loss = 1.8599
# epoch 7 / 100, step 11/55, loss = 1.9588
# epoch 7 / 100, step 12/55, loss = 2.0466
# epoch 7 / 100, step 13/55, loss = 2.0664
# epoch 7 / 100, step 14/55, loss = 1.8802
# epoch 7 / 100, step 15/55, loss = 1.8067
# epoch 7 / 100, step 16/55, loss = 2.1376
# epoch 7 / 100, step 17/55, loss = 2.0095
# epoch 7 / 100, step 18/55, loss = 1.8339
# epoch 7 / 100, step 19/55, loss = 1.9144
# epoch 7 / 100, step 20/55, loss = 1.6760
# epoch 7 / 100, step 21/55, loss = 1.8757
# epoch 7 / 100, step 22/55, loss = 1.9287
# epoch 7 / 100, step 23/55, loss = 2.0329
# epoch 7 / 100, step 24/55, loss = 2.0488
# epoch 7 / 100, step 25/55, loss = 1.9636
# epoch 7 / 100, step 26/55, loss = 1.7944
# epoch 7 / 100, step 27/55, loss = 1.9197
# epoch 7 / 100, step 28/55, loss = 2.1346
# epoch 7 / 100, step 29/55, loss = 2.0209
# epoch 7 / 100, step 30/55, loss = 1.9290
# epoch 7 / 100, step 31/55, loss = 2.1060
# epoch 7 / 100, step 32/55, loss = 1.9597
# epoch 7 / 100, step 33/55, loss = 1.8487
# epoch 7 / 100, step 34/55, loss = 1.8627
# epoch 7 / 100, step 35/55, loss = 1.8945
# epoch 7 / 100, step 36/55, loss = 1.9761
# epoch 7 / 100, step 37/55, loss = 2.0432
# epoch 7 / 100, step 38/55, loss = 1.9070
# epoch 7 / 100, step 39/55, loss = 1.8278
# epoch 7 / 100, step 40/55, loss = 1.8935
# epoch 7 / 100, step 41/55, loss = 1.9522
# epoch 7 / 100, step 42/55, loss = 2.0473
# epoch 7 / 100, step 43/55, loss = 1.8050
# epoch 7 / 100, step 44/55, loss = 1.9627
# epoch 7 / 100, step 45/55, loss = 1.7990
# epoch 7 / 100, step 46/55, loss = 1.9035
# epoch 7 / 100, step 47/55, loss = 1.9245
# epoch 7 / 100, step 48/55, loss = 1.8927
# epoch 7 / 100, step 49/55, loss = 2.0657
# epoch 7 / 100, step 50/55, loss = 1.9495
# epoch 7 / 100, step 51/55, loss = 1.9821
# epoch 7 / 100, step 52/55, loss = 1.9233
# epoch 7 / 100, step 53/55, loss = 1.9588
# epoch 7 / 100, step 54/55, loss = 2.0490
# epoch 7 / 100, step 55/55, loss = 2.0853
# epoch 7 / 100, step 1/14, loss = 1.9138
# epoch 7 / 100, step 2/14, loss = 1.9817
# epoch 7 / 100, step 3/14, loss = 1.9974
# epoch 7 / 100, step 4/14, loss = 1.9360
# epoch 7 / 100, step 5/14, loss = 1.8862
# epoch 7 / 100, step 6/14, loss = 1.8550
# epoch 7 / 100, step 7/14, loss = 1.8750
# epoch 7 / 100, step 8/14, loss = 1.9284
# epoch 7 / 100, step 9/14, loss = 1.9462
# epoch 7 / 100, step 10/14, loss = 1.9777
# epoch 7 / 100, step 11/14, loss = 1.9752
# epoch 7 / 100, step 12/14, loss = 1.9560
# epoch 7 / 100, step 13/14, loss = 2.0143
# epoch 7 / 100, step 14/14, loss = 1.8916
# epoch 8 / 100, step 1/55, loss = 1.7906
# epoch 8 / 100, step 2/55, loss = 2.0191
# epoch 8 / 100, step 3/55, loss = 1.9761
# epoch 8 / 100, step 4/55, loss = 1.7735
# epoch 8 / 100, step 5/55, loss = 1.8139
# epoch 8 / 100, step 6/55, loss = 1.9738
# epoch 8 / 100, step 7/55, loss = 1.7900
# epoch 8 / 100, step 8/55, loss = 1.8761
# epoch 8 / 100, step 9/55, loss = 2.0993
# epoch 8 / 100, step 10/55, loss = 1.8884
# epoch 8 / 100, step 11/55, loss = 1.9407
# epoch 8 / 100, step 12/55, loss = 2.0290
# epoch 8 / 100, step 13/55, loss = 1.8865
# epoch 8 / 100, step 14/55, loss = 1.9640
# epoch 8 / 100, step 15/55, loss = 1.8015
# epoch 8 / 100, step 16/55, loss = 1.8100
# epoch 8 / 100, step 17/55, loss = 1.9307
# epoch 8 / 100, step 18/55, loss = 1.8410
# epoch 8 / 100, step 19/55, loss = 1.8807
# epoch 8 / 100, step 20/55, loss = 2.0996
# epoch 8 / 100, step 21/55, loss = 1.9215
# epoch 8 / 100, step 22/55, loss = 2.0510
# epoch 8 / 100, step 23/55, loss = 1.9847
# epoch 8 / 100, step 24/55, loss = 1.8464
# epoch 8 / 100, step 25/55, loss = 2.0100
# epoch 8 / 100, step 26/55, loss = 2.0859
# epoch 8 / 100, step 27/55, loss = 1.9734
# epoch 8 / 100, step 28/55, loss = 1.9203
# epoch 8 / 100, step 29/55, loss = 2.0953
# epoch 8 / 100, step 30/55, loss = 2.0698
# epoch 8 / 100, step 31/55, loss = 1.7743
# epoch 8 / 100, step 32/55, loss = 1.9918
# epoch 8 / 100, step 33/55, loss = 1.9351
# epoch 8 / 100, step 34/55, loss = 2.0318
# epoch 8 / 100, step 35/55, loss = 1.8999
# epoch 8 / 100, step 36/55, loss = 1.9366
# epoch 8 / 100, step 37/55, loss = 1.9426
# epoch 8 / 100, step 38/55, loss = 1.9022
# epoch 8 / 100, step 39/55, loss = 2.1238
# epoch 8 / 100, step 40/55, loss = 1.9605
# epoch 8 / 100, step 41/55, loss = 2.0231
# epoch 8 / 100, step 42/55, loss = 1.8744
# epoch 8 / 100, step 43/55, loss = 1.9471
# epoch 8 / 100, step 44/55, loss = 1.9134
# epoch 8 / 100, step 45/55, loss = 1.8922
# epoch 8 / 100, step 46/55, loss = 1.9654
# epoch 8 / 100, step 47/55, loss = 1.9406
# epoch 8 / 100, step 48/55, loss = 2.1112
# epoch 8 / 100, step 49/55, loss = 1.8662
# epoch 8 / 100, step 50/55, loss = 1.8960
# epoch 8 / 100, step 51/55, loss = 2.0255
# epoch 8 / 100, step 52/55, loss = 1.8544
# epoch 8 / 100, step 53/55, loss = 1.8993
# epoch 8 / 100, step 54/55, loss = 2.0437
# epoch 8 / 100, step 55/55, loss = 1.7997
# epoch 8 / 100, step 1/14, loss = 1.9272
# epoch 8 / 100, step 2/14, loss = 1.9787
# epoch 8 / 100, step 3/14, loss = 1.9987
# epoch 8 / 100, step 4/14, loss = 1.9868
# epoch 8 / 100, step 5/14, loss = 1.9021
# epoch 8 / 100, step 6/14, loss = 1.8328
# epoch 8 / 100, step 7/14, loss = 1.8678
# epoch 8 / 100, step 8/14, loss = 1.8962
# epoch 8 / 100, step 9/14, loss = 1.9651
# epoch 8 / 100, step 10/14, loss = 1.9912
# epoch 8 / 100, step 11/14, loss = 1.9560
# epoch 8 / 100, step 12/14, loss = 1.9443
# epoch 8 / 100, step 13/14, loss = 1.9884
# epoch 8 / 100, step 14/14, loss = 1.8520
# epoch 9 / 100, step 1/55, loss = 1.9565
# epoch 9 / 100, step 2/55, loss = 1.9965
# epoch 9 / 100, step 3/55, loss = 1.9176
# epoch 9 / 100, step 4/55, loss = 2.0321
# epoch 9 / 100, step 5/55, loss = 1.7641
# epoch 9 / 100, step 6/55, loss = 1.7070
# epoch 9 / 100, step 7/55, loss = 1.7383
# epoch 9 / 100, step 8/55, loss = 1.9753
# epoch 9 / 100, step 9/55, loss = 1.8797
# epoch 9 / 100, step 10/55, loss = 1.9995
# epoch 9 / 100, step 11/55, loss = 1.9357
# epoch 9 / 100, step 12/55, loss = 1.8520
# epoch 9 / 100, step 13/55, loss = 1.8530
# epoch 9 / 100, step 14/55, loss = 1.9219
# epoch 9 / 100, step 15/55, loss = 2.1601
# epoch 9 / 100, step 16/55, loss = 1.9180
# epoch 9 / 100, step 17/55, loss = 1.8734
# epoch 9 / 100, step 18/55, loss = 1.9766
# epoch 9 / 100, step 19/55, loss = 1.9472
# epoch 9 / 100, step 20/55, loss = 2.2005
# epoch 9 / 100, step 21/55, loss = 1.9483
# epoch 9 / 100, step 22/55, loss = 2.0463
# epoch 9 / 100, step 23/55, loss = 2.0139
# epoch 9 / 100, step 24/55, loss = 2.0610
# epoch 9 / 100, step 25/55, loss = 1.7769
# epoch 9 / 100, step 26/55, loss = 2.0100
# epoch 9 / 100, step 27/55, loss = 1.8312
# epoch 9 / 100, step 28/55, loss = 2.0722
# epoch 9 / 100, step 29/55, loss = 1.8609
# epoch 9 / 100, step 30/55, loss = 1.8216
# epoch 9 / 100, step 31/55, loss = 1.8684
# epoch 9 / 100, step 32/55, loss = 1.9140
# epoch 9 / 100, step 33/55, loss = 1.8986
# epoch 9 / 100, step 34/55, loss = 2.1808
# epoch 9 / 100, step 35/55, loss = 1.9254
# epoch 9 / 100, step 36/55, loss = 1.9426
# epoch 9 / 100, step 37/55, loss = 2.0165
# epoch 9 / 100, step 38/55, loss = 1.9432
# epoch 9 / 100, step 39/55, loss = 2.1008
# epoch 9 / 100, step 40/55, loss = 2.0670
# epoch 9 / 100, step 41/55, loss = 1.8393
# epoch 9 / 100, step 42/55, loss = 2.0184
# epoch 9 / 100, step 43/55, loss = 2.0230
# epoch 9 / 100, step 44/55, loss = 1.9491
# epoch 9 / 100, step 45/55, loss = 1.8500
# epoch 9 / 100, step 46/55, loss = 1.9174
# epoch 9 / 100, step 47/55, loss = 1.7556
# epoch 9 / 100, step 48/55, loss = 1.8831
# epoch 9 / 100, step 49/55, loss = 2.0642
# epoch 9 / 100, step 50/55, loss = 2.1450
# epoch 9 / 100, step 51/55, loss = 2.0251
# epoch 9 / 100, step 52/55, loss = 1.8701
# epoch 9 / 100, step 53/55, loss = 1.9758
# epoch 9 / 100, step 54/55, loss = 1.8872
# epoch 9 / 100, step 55/55, loss = 1.7201
# epoch 9 / 100, step 1/14, loss = 1.8982
# epoch 9 / 100, step 2/14, loss = 1.9909
# epoch 9 / 100, step 3/14, loss = 1.9481
# epoch 9 / 100, step 4/14, loss = 1.9378
# epoch 9 / 100, step 5/14, loss = 1.9477
# epoch 9 / 100, step 6/14, loss = 1.8558
# epoch 9 / 100, step 7/14, loss = 1.8921
# epoch 9 / 100, step 8/14, loss = 1.9027
# epoch 9 / 100, step 9/14, loss = 1.9467
# epoch 9 / 100, step 10/14, loss = 1.9569
# epoch 9 / 100, step 11/14, loss = 1.9670
# epoch 9 / 100, step 12/14, loss = 1.9488
# epoch 9 / 100, step 13/14, loss = 1.9850
# epoch 9 / 100, step 14/14, loss = 1.9050
# epoch 10 / 100, step 1/55, loss = 1.9590
# epoch 10 / 100, step 2/55, loss = 1.8830
# epoch 10 / 100, step 3/55, loss = 1.9592
# epoch 10 / 100, step 4/55, loss = 2.0057
# epoch 10 / 100, step 5/55, loss = 1.8467
# epoch 10 / 100, step 6/55, loss = 2.0762
# epoch 10 / 100, step 7/55, loss = 1.9167
# epoch 10 / 100, step 8/55, loss = 1.9341
# epoch 10 / 100, step 9/55, loss = 2.0677
# epoch 10 / 100, step 10/55, loss = 1.8599
# epoch 10 / 100, step 11/55, loss = 2.0337
# epoch 10 / 100, step 12/55, loss = 2.0435
# epoch 10 / 100, step 13/55, loss = 1.9662
# epoch 10 / 100, step 14/55, loss = 1.9609
# epoch 10 / 100, step 15/55, loss = 1.8927
# epoch 10 / 100, step 16/55, loss = 1.9944
# epoch 10 / 100, step 17/55, loss = 1.8358
# epoch 10 / 100, step 18/55, loss = 1.8977
# epoch 10 / 100, step 19/55, loss = 1.9324
# epoch 10 / 100, step 20/55, loss = 1.9018
# epoch 10 / 100, step 21/55, loss = 1.9625
# epoch 10 / 100, step 22/55, loss = 1.8847
# epoch 10 / 100, step 23/55, loss = 2.0281
# epoch 10 / 100, step 24/55, loss = 1.8407
# epoch 10 / 100, step 25/55, loss = 1.9698
# epoch 10 / 100, step 26/55, loss = 1.9413
# epoch 10 / 100, step 27/55, loss = 1.9834
# epoch 10 / 100, step 28/55, loss = 1.8241
# epoch 10 / 100, step 29/55, loss = 2.0087
# epoch 10 / 100, step 30/55, loss = 1.9910
# epoch 10 / 100, step 31/55, loss = 1.8552
# epoch 10 / 100, step 32/55, loss = 2.0239
# epoch 10 / 100, step 33/55, loss = 1.8812
# epoch 10 / 100, step 34/55, loss = 2.1573
# epoch 10 / 100, step 35/55, loss = 1.9967
# epoch 10 / 100, step 36/55, loss = 1.7608
# epoch 10 / 100, step 37/55, loss = 1.7600
# epoch 10 / 100, step 38/55, loss = 2.0108
# epoch 10 / 100, step 39/55, loss = 1.8739
# epoch 10 / 100, step 40/55, loss = 1.9299
# epoch 10 / 100, step 41/55, loss = 1.8046
# epoch 10 / 100, step 42/55, loss = 1.8232
# epoch 10 / 100, step 43/55, loss = 1.9863
# epoch 10 / 100, step 44/55, loss = 2.0669
# epoch 10 / 100, step 45/55, loss = 1.9520
# epoch 10 / 100, step 46/55, loss = 1.8824
# epoch 10 / 100, step 47/55, loss = 1.8212
# epoch 10 / 100, step 48/55, loss = 1.8174
# epoch 10 / 100, step 49/55, loss = 1.9175
# epoch 10 / 100, step 50/55, loss = 1.8366
# epoch 10 / 100, step 51/55, loss = 2.0007
# epoch 10 / 100, step 52/55, loss = 1.9286
# epoch 10 / 100, step 53/55, loss = 1.9689
# epoch 10 / 100, step 54/55, loss = 1.9765
# epoch 10 / 100, step 55/55, loss = 1.8723
# epoch 10 / 100, step 1/14, loss = 1.9274
# epoch 10 / 100, step 2/14, loss = 1.9768
# epoch 10 / 100, step 3/14, loss = 2.0429
# epoch 10 / 100, step 4/14, loss = 1.9671
# epoch 10 / 100, step 5/14, loss = 1.9499
# epoch 10 / 100, step 6/14, loss = 1.8292
# epoch 10 / 100, step 7/14, loss = 1.8495
# epoch 10 / 100, step 8/14, loss = 1.9176
# epoch 10 / 100, step 9/14, loss = 1.9680
# epoch 10 / 100, step 10/14, loss = 2.0175
# epoch 10 / 100, step 11/14, loss = 1.9671
# epoch 10 / 100, step 12/14, loss = 1.9879
# epoch 10 / 100, step 13/14, loss = 1.9680
# epoch 10 / 100, step 14/14, loss = 1.9195
# epoch 11 / 100, step 1/55, loss = 1.8399
# epoch 11 / 100, step 2/55, loss = 1.9625
# epoch 11 / 100, step 3/55, loss = 1.6716
# epoch 11 / 100, step 4/55, loss = 1.7317
# epoch 11 / 100, step 5/55, loss = 2.1067
# epoch 11 / 100, step 6/55, loss = 1.9927
# epoch 11 / 100, step 7/55, loss = 1.7857
# epoch 11 / 100, step 8/55, loss = 1.8467
# epoch 11 / 100, step 9/55, loss = 1.9146
# epoch 11 / 100, step 10/55, loss = 1.8432
# epoch 11 / 100, step 11/55, loss = 1.8968
# epoch 11 / 100, step 12/55, loss = 2.0561
# epoch 11 / 100, step 13/55, loss = 2.1037
# epoch 11 / 100, step 14/55, loss = 1.9435
# epoch 11 / 100, step 15/55, loss = 2.0055
# epoch 11 / 100, step 16/55, loss = 1.9311
# epoch 11 / 100, step 17/55, loss = 1.8969
# epoch 11 / 100, step 18/55, loss = 1.9078
# epoch 11 / 100, step 19/55, loss = 1.9268
# epoch 11 / 100, step 20/55, loss = 1.9673
# epoch 11 / 100, step 21/55, loss = 2.0994
# epoch 11 / 100, step 22/55, loss = 2.0866
# epoch 11 / 100, step 23/55, loss = 1.9974
# epoch 11 / 100, step 24/55, loss = 1.9471
# epoch 11 / 100, step 25/55, loss = 1.9068
# epoch 11 / 100, step 26/55, loss = 1.9172
# epoch 11 / 100, step 27/55, loss = 1.9185
# epoch 11 / 100, step 28/55, loss = 1.9660
# epoch 11 / 100, step 29/55, loss = 1.9623
# epoch 11 / 100, step 30/55, loss = 1.8135
# epoch 11 / 100, step 31/55, loss = 1.9861
# epoch 11 / 100, step 32/55, loss = 1.7212
# epoch 11 / 100, step 33/55, loss = 1.9805
# epoch 11 / 100, step 34/55, loss = 1.8742
# epoch 11 / 100, step 35/55, loss = 1.8077
# epoch 11 / 100, step 36/55, loss = 1.7287
# epoch 11 / 100, step 37/55, loss = 1.7691
# epoch 11 / 100, step 38/55, loss = 1.8896
# epoch 11 / 100, step 39/55, loss = 1.9519
# epoch 11 / 100, step 40/55, loss = 1.8303
# epoch 11 / 100, step 41/55, loss = 1.9253
# epoch 11 / 100, step 42/55, loss = 2.0516
# epoch 11 / 100, step 43/55, loss = 1.6844
# epoch 11 / 100, step 44/55, loss = 1.9597
# epoch 11 / 100, step 45/55, loss = 1.9852
# epoch 11 / 100, step 46/55, loss = 2.0305
# epoch 11 / 100, step 47/55, loss = 1.9784
# epoch 11 / 100, step 48/55, loss = 1.8579
# epoch 11 / 100, step 49/55, loss = 1.9457
# epoch 11 / 100, step 50/55, loss = 1.8752
# epoch 11 / 100, step 51/55, loss = 2.0157
# epoch 11 / 100, step 52/55, loss = 1.9397
# epoch 11 / 100, step 53/55, loss = 1.8142
# epoch 11 / 100, step 54/55, loss = 1.9304
# epoch 11 / 100, step 55/55, loss = 1.7125
# epoch 11 / 100, step 1/14, loss = 1.9170
# epoch 11 / 100, step 2/14, loss = 1.9877
# epoch 11 / 100, step 3/14, loss = 1.9808
# epoch 11 / 100, step 4/14, loss = 1.9438
# epoch 11 / 100, step 5/14, loss = 1.9597
# epoch 11 / 100, step 6/14, loss = 1.8889
# epoch 11 / 100, step 7/14, loss = 1.9193
# epoch 11 / 100, step 8/14, loss = 1.9190
# epoch 11 / 100, step 9/14, loss = 1.9831
# epoch 11 / 100, step 10/14, loss = 1.9189
# epoch 11 / 100, step 11/14, loss = 1.9205
# epoch 11 / 100, step 12/14, loss = 1.9882
# epoch 11 / 100, step 13/14, loss = 1.9553
# epoch 11 / 100, step 14/14, loss = 1.8967
# epoch 12 / 100, step 1/55, loss = 1.6940
# epoch 12 / 100, step 2/55, loss = 1.9822
# epoch 12 / 100, step 3/55, loss = 1.9999
# epoch 12 / 100, step 4/55, loss = 2.1037
# epoch 12 / 100, step 5/55, loss = 1.9509
# epoch 12 / 100, step 6/55, loss = 1.8402
# epoch 12 / 100, step 7/55, loss = 1.8315
# epoch 12 / 100, step 8/55, loss = 2.0067
# epoch 12 / 100, step 9/55, loss = 1.7413
# epoch 12 / 100, step 10/55, loss = 1.8286
# epoch 12 / 100, step 11/55, loss = 1.9517
# epoch 12 / 100, step 12/55, loss = 2.0393
# epoch 12 / 100, step 13/55, loss = 1.8700
# epoch 12 / 100, step 14/55, loss = 1.9485
# epoch 12 / 100, step 15/55, loss = 1.8908
# epoch 12 / 100, step 16/55, loss = 1.8309
# epoch 12 / 100, step 17/55, loss = 1.9625
# epoch 12 / 100, step 18/55, loss = 1.7795
# epoch 12 / 100, step 19/55, loss = 2.0289
# epoch 12 / 100, step 20/55, loss = 1.9628
# epoch 12 / 100, step 21/55, loss = 1.9009
# epoch 12 / 100, step 22/55, loss = 2.0343
# epoch 12 / 100, step 23/55, loss = 2.0533
# epoch 12 / 100, step 24/55, loss = 1.9886
# epoch 12 / 100, step 25/55, loss = 1.9128
# epoch 12 / 100, step 26/55, loss = 1.7771
# epoch 12 / 100, step 27/55, loss = 1.9462
# epoch 12 / 100, step 28/55, loss = 1.8994
# epoch 12 / 100, step 29/55, loss = 1.9312
# epoch 12 / 100, step 30/55, loss = 1.8480
# epoch 12 / 100, step 31/55, loss = 2.0218
# epoch 12 / 100, step 32/55, loss = 2.0285
# epoch 12 / 100, step 33/55, loss = 1.8429
# epoch 12 / 100, step 34/55, loss = 1.8726
# epoch 12 / 100, step 35/55, loss = 1.9711
# epoch 12 / 100, step 36/55, loss = 1.8713
# epoch 12 / 100, step 37/55, loss = 1.8626
# epoch 12 / 100, step 38/55, loss = 1.7374
# epoch 12 / 100, step 39/55, loss = 1.8430
# epoch 12 / 100, step 40/55, loss = 1.9094
# epoch 12 / 100, step 41/55, loss = 1.9423
# epoch 12 / 100, step 42/55, loss = 1.7925
# epoch 12 / 100, step 43/55, loss = 1.9587
# epoch 12 / 100, step 44/55, loss = 2.0183
# epoch 12 / 100, step 45/55, loss = 1.9121
# epoch 12 / 100, step 46/55, loss = 1.9443
# epoch 12 / 100, step 47/55, loss = 2.0566
# epoch 12 / 100, step 48/55, loss = 1.8823
# epoch 12 / 100, step 49/55, loss = 2.0019
# epoch 12 / 100, step 50/55, loss = 1.9848
# epoch 12 / 100, step 51/55, loss = 1.8672
# epoch 12 / 100, step 52/55, loss = 2.0654
# epoch 12 / 100, step 53/55, loss = 1.9990
# epoch 12 / 100, step 54/55, loss = 1.9661
# epoch 12 / 100, step 55/55, loss = 1.9436
# epoch 12 / 100, step 1/14, loss = 1.9036
# epoch 12 / 100, step 2/14, loss = 1.9671
# epoch 12 / 100, step 3/14, loss = 1.9658
# epoch 12 / 100, step 4/14, loss = 2.0155
# epoch 12 / 100, step 5/14, loss = 1.9766
# epoch 12 / 100, step 6/14, loss = 1.8922
# epoch 12 / 100, step 7/14, loss = 1.8925
# epoch 12 / 100, step 8/14, loss = 1.8731
# epoch 12 / 100, step 9/14, loss = 1.9435
# epoch 12 / 100, step 10/14, loss = 1.9792
# epoch 12 / 100, step 11/14, loss = 1.9066
# epoch 12 / 100, step 12/14, loss = 1.9949
# epoch 12 / 100, step 13/14, loss = 1.9420
# epoch 12 / 100, step 14/14, loss = 1.8786
# epoch 13 / 100, step 1/55, loss = 1.8400
# epoch 13 / 100, step 2/55, loss = 1.8663
# epoch 13 / 100, step 3/55, loss = 1.9197
# epoch 13 / 100, step 4/55, loss = 2.0941
# epoch 13 / 100, step 5/55, loss = 1.8290
# epoch 13 / 100, step 6/55, loss = 1.8107
# epoch 13 / 100, step 7/55, loss = 1.9158
# epoch 13 / 100, step 8/55, loss = 1.9358
# epoch 13 / 100, step 9/55, loss = 1.9335
# epoch 13 / 100, step 10/55, loss = 1.7619
# epoch 13 / 100, step 11/55, loss = 1.9554
# epoch 13 / 100, step 12/55, loss = 1.8090
# epoch 13 / 100, step 13/55, loss = 1.9825
# epoch 13 / 100, step 14/55, loss = 1.9884
# epoch 13 / 100, step 15/55, loss = 1.8424
# epoch 13 / 100, step 16/55, loss = 1.9844
# epoch 13 / 100, step 17/55, loss = 2.0331
# epoch 13 / 100, step 18/55, loss = 1.8092
# epoch 13 / 100, step 19/55, loss = 1.9604
# epoch 13 / 100, step 20/55, loss = 1.8373
# epoch 13 / 100, step 21/55, loss = 1.8074
# epoch 13 / 100, step 22/55, loss = 1.9284
# epoch 13 / 100, step 23/55, loss = 1.9083
# epoch 13 / 100, step 24/55, loss = 1.8879
# epoch 13 / 100, step 25/55, loss = 1.8905
# epoch 13 / 100, step 26/55, loss = 1.7688
# epoch 13 / 100, step 27/55, loss = 1.8814
# epoch 13 / 100, step 28/55, loss = 1.8275
# epoch 13 / 100, step 29/55, loss = 1.8332
# epoch 13 / 100, step 30/55, loss = 1.9555
# epoch 13 / 100, step 31/55, loss = 2.1353
# epoch 13 / 100, step 32/55, loss = 1.8557
# epoch 13 / 100, step 33/55, loss = 2.0256
# epoch 13 / 100, step 34/55, loss = 2.1037
# epoch 13 / 100, step 35/55, loss = 2.1625
# epoch 13 / 100, step 36/55, loss = 1.9891
# epoch 13 / 100, step 37/55, loss = 1.8417
# epoch 13 / 100, step 38/55, loss = 1.8477
# epoch 13 / 100, step 39/55, loss = 2.0120
# epoch 13 / 100, step 40/55, loss = 1.9343
# epoch 13 / 100, step 41/55, loss = 1.8778
# epoch 13 / 100, step 42/55, loss = 2.0490
# epoch 13 / 100, step 43/55, loss = 1.8605
# epoch 13 / 100, step 44/55, loss = 1.8792
# epoch 13 / 100, step 45/55, loss = 1.9124
# epoch 13 / 100, step 46/55, loss = 1.8703
# epoch 13 / 100, step 47/55, loss = 1.8989
# epoch 13 / 100, step 48/55, loss = 1.8170
# epoch 13 / 100, step 49/55, loss = 2.0764
# epoch 13 / 100, step 50/55, loss = 2.0577
# epoch 13 / 100, step 51/55, loss = 1.8930
# epoch 13 / 100, step 52/55, loss = 1.9586
# epoch 13 / 100, step 53/55, loss = 2.1148
# epoch 13 / 100, step 54/55, loss = 2.0573
# epoch 13 / 100, step 55/55, loss = 1.6914
# epoch 13 / 100, step 1/14, loss = 1.9696
# epoch 13 / 100, step 2/14, loss = 1.9725
# epoch 13 / 100, step 3/14, loss = 2.0326
# epoch 13 / 100, step 4/14, loss = 1.9876
# epoch 13 / 100, step 5/14, loss = 1.9189
# epoch 13 / 100, step 6/14, loss = 1.8878
# epoch 13 / 100, step 7/14, loss = 1.9001
# epoch 13 / 100, step 8/14, loss = 1.8731
# epoch 13 / 100, step 9/14, loss = 1.8993
# epoch 13 / 100, step 10/14, loss = 2.0422
# epoch 13 / 100, step 11/14, loss = 1.9736
# epoch 13 / 100, step 12/14, loss = 1.9776
# epoch 13 / 100, step 13/14, loss = 1.9489
# epoch 13 / 100, step 14/14, loss = 1.9138
# epoch 14 / 100, step 1/55, loss = 1.9578
# epoch 14 / 100, step 2/55, loss = 2.0086
# epoch 14 / 100, step 3/55, loss = 1.9654
# epoch 14 / 100, step 4/55, loss = 1.8370
# epoch 14 / 100, step 5/55, loss = 2.0204
# epoch 14 / 100, step 6/55, loss = 1.9771
# epoch 14 / 100, step 7/55, loss = 1.9623
# epoch 14 / 100, step 8/55, loss = 2.0117
# epoch 14 / 100, step 9/55, loss = 1.8259
# epoch 14 / 100, step 10/55, loss = 1.7628
# epoch 14 / 100, step 11/55, loss = 2.0024
# epoch 14 / 100, step 12/55, loss = 1.9398
# epoch 14 / 100, step 13/55, loss = 1.9548
# epoch 14 / 100, step 14/55, loss = 2.0067
# epoch 14 / 100, step 15/55, loss = 1.8644
# epoch 14 / 100, step 16/55, loss = 1.8592
# epoch 14 / 100, step 17/55, loss = 1.8484
# epoch 14 / 100, step 18/55, loss = 2.0430
# epoch 14 / 100, step 19/55, loss = 1.8941
# epoch 14 / 100, step 20/55, loss = 1.7906
# epoch 14 / 100, step 21/55, loss = 1.8821
# epoch 14 / 100, step 22/55, loss = 1.7776
# epoch 14 / 100, step 23/55, loss = 2.0155
# epoch 14 / 100, step 24/55, loss = 1.8435
# epoch 14 / 100, step 25/55, loss = 2.0064
# epoch 14 / 100, step 26/55, loss = 1.8298
# epoch 14 / 100, step 27/55, loss = 1.9335
# epoch 14 / 100, step 28/55, loss = 2.0453
# epoch 14 / 100, step 29/55, loss = 2.0376
# epoch 14 / 100, step 30/55, loss = 1.8693
# epoch 14 / 100, step 31/55, loss = 1.7156
# epoch 14 / 100, step 32/55, loss = 1.8862
# epoch 14 / 100, step 33/55, loss = 1.8155
# epoch 14 / 100, step 34/55, loss = 1.7430
# epoch 14 / 100, step 35/55, loss = 1.9925
# epoch 14 / 100, step 36/55, loss = 1.7675
# epoch 14 / 100, step 37/55, loss = 1.8683
# epoch 14 / 100, step 38/55, loss = 2.0765
# epoch 14 / 100, step 39/55, loss = 1.9417
# epoch 14 / 100, step 40/55, loss = 1.8420
# epoch 14 / 100, step 41/55, loss = 2.0063
# epoch 14 / 100, step 42/55, loss = 1.9911
# epoch 14 / 100, step 43/55, loss = 2.0149
# epoch 14 / 100, step 44/55, loss = 1.9607
# epoch 14 / 100, step 45/55, loss = 2.0021
# epoch 14 / 100, step 46/55, loss = 1.8542
# epoch 14 / 100, step 47/55, loss = 1.9248
# epoch 14 / 100, step 48/55, loss = 1.9868
# epoch 14 / 100, step 49/55, loss = 1.9705
# epoch 14 / 100, step 50/55, loss = 2.0785
# epoch 14 / 100, step 51/55, loss = 2.0354
# epoch 14 / 100, step 52/55, loss = 1.9369
# epoch 14 / 100, step 53/55, loss = 2.0205
# epoch 14 / 100, step 54/55, loss = 1.8488
# epoch 14 / 100, step 55/55, loss = 1.9626
# epoch 14 / 100, step 1/14, loss = 1.9862
# epoch 14 / 100, step 2/14, loss = 1.9794
# epoch 14 / 100, step 3/14, loss = 2.0221
# epoch 14 / 100, step 4/14, loss = 2.0353
# epoch 14 / 100, step 5/14, loss = 1.9596
# epoch 14 / 100, step 6/14, loss = 1.7944
# epoch 14 / 100, step 7/14, loss = 1.9314
# epoch 14 / 100, step 8/14, loss = 1.8458
# epoch 14 / 100, step 9/14, loss = 1.9380
# epoch 14 / 100, step 10/14, loss = 2.0323
# epoch 14 / 100, step 11/14, loss = 1.9394
# epoch 14 / 100, step 12/14, loss = 1.9677
# epoch 14 / 100, step 13/14, loss = 2.0172
# epoch 14 / 100, step 14/14, loss = 1.8984
# epoch 15 / 100, step 1/55, loss = 1.9787
# epoch 15 / 100, step 2/55, loss = 1.8727
# epoch 15 / 100, step 3/55, loss = 2.0022
# epoch 15 / 100, step 4/55, loss = 1.8387
# epoch 15 / 100, step 5/55, loss = 1.9233
# epoch 15 / 100, step 6/55, loss = 1.9448
# epoch 15 / 100, step 7/55, loss = 1.9255
# epoch 15 / 100, step 8/55, loss = 1.8889
# epoch 15 / 100, step 9/55, loss = 1.9776
# epoch 15 / 100, step 10/55, loss = 1.7595
# epoch 15 / 100, step 11/55, loss = 1.8995
# epoch 15 / 100, step 12/55, loss = 1.8584
# epoch 15 / 100, step 13/55, loss = 1.9553
# epoch 15 / 100, step 14/55, loss = 1.7397
# epoch 15 / 100, step 15/55, loss = 1.8489
# epoch 15 / 100, step 16/55, loss = 1.9605
# epoch 15 / 100, step 17/55, loss = 2.0703
# epoch 15 / 100, step 18/55, loss = 2.0209
# epoch 15 / 100, step 19/55, loss = 2.0299
# epoch 15 / 100, step 20/55, loss = 1.8363
# epoch 15 / 100, step 21/55, loss = 1.7791
# epoch 15 / 100, step 22/55, loss = 2.0121
# epoch 15 / 100, step 23/55, loss = 1.9746
# epoch 15 / 100, step 24/55, loss = 1.7229
# epoch 15 / 100, step 25/55, loss = 1.6587
# epoch 15 / 100, step 26/55, loss = 1.9448
# epoch 15 / 100, step 27/55, loss = 1.8931
# epoch 15 / 100, step 28/55, loss = 1.9061
# epoch 15 / 100, step 29/55, loss = 1.9405
# epoch 15 / 100, step 30/55, loss = 2.0054
# epoch 15 / 100, step 31/55, loss = 2.1163
# epoch 15 / 100, step 32/55, loss = 2.0109
# epoch 15 / 100, step 33/55, loss = 1.7086
# epoch 15 / 100, step 34/55, loss = 1.8289
# epoch 15 / 100, step 35/55, loss = 2.0930
# epoch 15 / 100, step 36/55, loss = 1.8734
# epoch 15 / 100, step 37/55, loss = 1.9507
# epoch 15 / 100, step 38/55, loss = 1.9910
# epoch 15 / 100, step 39/55, loss = 1.7808
# epoch 15 / 100, step 40/55, loss = 2.2208
# epoch 15 / 100, step 41/55, loss = 1.6569
# epoch 15 / 100, step 42/55, loss = 1.9138
# epoch 15 / 100, step 43/55, loss = 1.9662
# epoch 15 / 100, step 44/55, loss = 1.8364
# epoch 15 / 100, step 45/55, loss = 1.9441
# epoch 15 / 100, step 46/55, loss = 1.8429
# epoch 15 / 100, step 47/55, loss = 2.0677
# epoch 15 / 100, step 48/55, loss = 1.9710
# epoch 15 / 100, step 49/55, loss = 1.7995
# epoch 15 / 100, step 50/55, loss = 1.6928
# epoch 15 / 100, step 51/55, loss = 1.9542
# epoch 15 / 100, step 52/55, loss = 1.9618
# epoch 15 / 100, step 53/55, loss = 1.8909
# epoch 15 / 100, step 54/55, loss = 1.8930
# epoch 15 / 100, step 55/55, loss = 1.8205
# epoch 15 / 100, step 1/14, loss = 1.9652
# epoch 15 / 100, step 2/14, loss = 1.9563
# epoch 15 / 100, step 3/14, loss = 1.9992
# epoch 15 / 100, step 4/14, loss = 2.0495
# epoch 15 / 100, step 5/14, loss = 1.9739
# epoch 15 / 100, step 6/14, loss = 1.8590
# epoch 15 / 100, step 7/14, loss = 1.8786
# epoch 15 / 100, step 8/14, loss = 1.8433
# epoch 15 / 100, step 9/14, loss = 2.0071
# epoch 15 / 100, step 10/14, loss = 2.0028
# epoch 15 / 100, step 11/14, loss = 1.9634
# epoch 15 / 100, step 12/14, loss = 1.9387
# epoch 15 / 100, step 13/14, loss = 1.9897
# epoch 15 / 100, step 14/14, loss = 1.8885
# epoch 16 / 100, step 1/55, loss = 1.9781
# epoch 16 / 100, step 2/55, loss = 2.1504
# epoch 16 / 100, step 3/55, loss = 1.8825
# epoch 16 / 100, step 4/55, loss = 1.9963
# epoch 16 / 100, step 5/55, loss = 1.9867
# epoch 16 / 100, step 6/55, loss = 1.9425
# epoch 16 / 100, step 7/55, loss = 2.0170
# epoch 16 / 100, step 8/55, loss = 1.8961
# epoch 16 / 100, step 9/55, loss = 1.6284
# epoch 16 / 100, step 10/55, loss = 1.7711
# epoch 16 / 100, step 11/55, loss = 1.8619
# epoch 16 / 100, step 12/55, loss = 1.9349
# epoch 16 / 100, step 13/55, loss = 1.8832
# epoch 16 / 100, step 14/55, loss = 1.7468
# epoch 16 / 100, step 15/55, loss = 1.8492
# epoch 16 / 100, step 16/55, loss = 1.9057
# epoch 16 / 100, step 17/55, loss = 1.7805
# epoch 16 / 100, step 18/55, loss = 1.8423
# epoch 16 / 100, step 19/55, loss = 1.9005
# epoch 16 / 100, step 20/55, loss = 1.9372
# epoch 16 / 100, step 21/55, loss = 1.9657
# epoch 16 / 100, step 22/55, loss = 1.9332
# epoch 16 / 100, step 23/55, loss = 1.9361
# epoch 16 / 100, step 24/55, loss = 1.7220
# epoch 16 / 100, step 25/55, loss = 1.8549
# epoch 16 / 100, step 26/55, loss = 1.7207
# epoch 16 / 100, step 27/55, loss = 1.9212
# epoch 16 / 100, step 28/55, loss = 1.9549
# epoch 16 / 100, step 29/55, loss = 1.9461
# epoch 16 / 100, step 30/55, loss = 2.0010
# epoch 16 / 100, step 31/55, loss = 1.8947
# epoch 16 / 100, step 32/55, loss = 1.7534
# epoch 16 / 100, step 33/55, loss = 1.9924
# epoch 16 / 100, step 34/55, loss = 1.8948
# epoch 16 / 100, step 35/55, loss = 1.8820
# epoch 16 / 100, step 36/55, loss = 2.0143
# epoch 16 / 100, step 37/55, loss = 1.8877
# epoch 16 / 100, step 38/55, loss = 1.8317
# epoch 16 / 100, step 39/55, loss = 1.8159
# epoch 16 / 100, step 40/55, loss = 1.8982
# epoch 16 / 100, step 41/55, loss = 2.0891
# epoch 16 / 100, step 42/55, loss = 1.7988
# epoch 16 / 100, step 43/55, loss = 1.8716
# epoch 16 / 100, step 44/55, loss = 1.9484
# epoch 16 / 100, step 45/55, loss = 2.0279
# epoch 16 / 100, step 46/55, loss = 2.0487
# epoch 16 / 100, step 47/55, loss = 1.9627
# epoch 16 / 100, step 48/55, loss = 1.8171
# epoch 16 / 100, step 49/55, loss = 1.9017
# epoch 16 / 100, step 50/55, loss = 1.8961
# epoch 16 / 100, step 51/55, loss = 2.1807
# epoch 16 / 100, step 52/55, loss = 2.0191
# epoch 16 / 100, step 53/55, loss = 1.9070
# epoch 16 / 100, step 54/55, loss = 1.9033
# epoch 16 / 100, step 55/55, loss = 2.0015
# epoch 16 / 100, step 1/14, loss = 1.9363
# epoch 16 / 100, step 2/14, loss = 1.9677
# epoch 16 / 100, step 3/14, loss = 1.9976
# epoch 16 / 100, step 4/14, loss = 2.0395
# epoch 16 / 100, step 5/14, loss = 1.9295
# epoch 16 / 100, step 6/14, loss = 1.8795
# epoch 16 / 100, step 7/14, loss = 1.9637
# epoch 16 / 100, step 8/14, loss = 1.8263
# epoch 16 / 100, step 9/14, loss = 1.9993
# epoch 16 / 100, step 10/14, loss = 2.0149
# epoch 16 / 100, step 11/14, loss = 1.9440
# epoch 16 / 100, step 12/14, loss = 1.9740
# epoch 16 / 100, step 13/14, loss = 1.9977
# epoch 16 / 100, step 14/14, loss = 1.9372
# epoch 17 / 100, step 1/55, loss = 1.8403
# epoch 17 / 100, step 2/55, loss = 1.9078
# epoch 17 / 100, step 3/55, loss = 2.0171
# epoch 17 / 100, step 4/55, loss = 1.7758
# epoch 17 / 100, step 5/55, loss = 1.8027
# epoch 17 / 100, step 6/55, loss = 1.9874
# epoch 17 / 100, step 7/55, loss = 1.8462
# epoch 17 / 100, step 8/55, loss = 1.7870
# epoch 17 / 100, step 9/55, loss = 1.9851
# epoch 17 / 100, step 10/55, loss = 2.0627
# epoch 17 / 100, step 11/55, loss = 1.7246
# epoch 17 / 100, step 12/55, loss = 1.8143
# epoch 17 / 100, step 13/55, loss = 1.8487
# epoch 17 / 100, step 14/55, loss = 2.0098
# epoch 17 / 100, step 15/55, loss = 1.9521
# epoch 17 / 100, step 16/55, loss = 1.9502
# epoch 17 / 100, step 17/55, loss = 2.0268
# epoch 17 / 100, step 18/55, loss = 2.1834
# epoch 17 / 100, step 19/55, loss = 1.8984
# epoch 17 / 100, step 20/55, loss = 1.9839
# epoch 17 / 100, step 21/55, loss = 1.8458
# epoch 17 / 100, step 22/55, loss = 2.0593
# epoch 17 / 100, step 23/55, loss = 1.7899
# epoch 17 / 100, step 24/55, loss = 2.0996
# epoch 17 / 100, step 25/55, loss = 1.6796
# epoch 17 / 100, step 26/55, loss = 1.9532
# epoch 17 / 100, step 27/55, loss = 1.9589
# epoch 17 / 100, step 28/55, loss = 1.8458
# epoch 17 / 100, step 29/55, loss = 1.7634
# epoch 17 / 100, step 30/55, loss = 1.9609
# epoch 17 / 100, step 31/55, loss = 1.9759
# epoch 17 / 100, step 32/55, loss = 1.7582
# epoch 17 / 100, step 33/55, loss = 1.7746
# epoch 17 / 100, step 34/55, loss = 1.9838
# epoch 17 / 100, step 35/55, loss = 1.9482
# epoch 17 / 100, step 36/55, loss = 1.8847
# epoch 17 / 100, step 37/55, loss = 1.9249
# epoch 17 / 100, step 38/55, loss = 1.9738
# epoch 17 / 100, step 39/55, loss = 1.9154
# epoch 17 / 100, step 40/55, loss = 1.9444
# epoch 17 / 100, step 41/55, loss = 1.9474
# epoch 17 / 100, step 42/55, loss = 1.9945
# epoch 17 / 100, step 43/55, loss = 2.0124
# epoch 17 / 100, step 44/55, loss = 1.9908
# epoch 17 / 100, step 45/55, loss = 2.0029
# epoch 17 / 100, step 46/55, loss = 1.8402
# epoch 17 / 100, step 47/55, loss = 1.9630
# epoch 17 / 100, step 48/55, loss = 1.9600
# epoch 17 / 100, step 49/55, loss = 1.9671
# epoch 17 / 100, step 50/55, loss = 2.1126
# epoch 17 / 100, step 51/55, loss = 1.9003
# epoch 17 / 100, step 52/55, loss = 2.0299
# epoch 17 / 100, step 53/55, loss = 1.9400
# epoch 17 / 100, step 54/55, loss = 2.1546
# epoch 17 / 100, step 55/55, loss = 1.9055
# epoch 17 / 100, step 1/14, loss = 1.9159
# epoch 17 / 100, step 2/14, loss = 1.9348
# epoch 17 / 100, step 3/14, loss = 1.9795
# epoch 17 / 100, step 4/14, loss = 2.0504
# epoch 17 / 100, step 5/14, loss = 1.8855
# ...
# epoch 95 / 100, step 34/55, loss = 1.9678
# epoch 95 / 100, step 35/55, loss = 1.8627
# epoch 95 / 100, step 36/55, loss = 1.8428
# epoch 95 / 100, step 37/55, loss = 1.8639
# epoch 95 / 100, step 38/55, loss = 2.0249
# epoch 95 / 100, step 39/55, loss = 1.7864
# epoch 95 / 100, step 40/55, loss = 1.8775
# epoch 95 / 100, step 41/55, loss = 2.2843
# epoch 95 / 100, step 42/55, loss = 1.9338
# epoch 95 / 100, step 43/55, loss = 1.7929
# epoch 95 / 100, step 44/55, loss = 1.7411
# epoch 95 / 100, step 45/55, loss = 1.9144
# epoch 95 / 100, step 46/55, loss = 1.8965
# epoch 95 / 100, step 47/55, loss = 1.9540
# epoch 95 / 100, step 48/55, loss = 1.9752
# epoch 95 / 100, step 49/55, loss = 1.8780
# epoch 95 / 100, step 50/55, loss = 1.8283
# epoch 95 / 100, step 51/55, loss = 1.9251
# epoch 95 / 100, step 52/55, loss = 2.0642
# epoch 95 / 100, step 53/55, loss = 1.9630
# epoch 95 / 100, step 54/55, loss = 1.8653
# epoch 95 / 100, step 55/55, loss = 1.7686
# epoch 95 / 100, step 1/14, loss = 1.9358
# epoch 95 / 100, step 2/14, loss = 1.9334
# epoch 95 / 100, step 3/14, loss = 1.9541
# epoch 95 / 100, step 4/14, loss = 1.9761
# epoch 95 / 100, step 5/14, loss = 1.8864
# epoch 95 / 100, step 6/14, loss = 1.9800
# epoch 95 / 100, step 7/14, loss = 2.0811
# epoch 95 / 100, step 8/14, loss = 1.8951
# epoch 95 / 100, step 9/14, loss = 1.9765
# epoch 95 / 100, step 10/14, loss = 1.9986
# epoch 95 / 100, step 11/14, loss = 1.9717
# epoch 95 / 100, step 12/14, loss = 1.9798
# epoch 95 / 100, step 13/14, loss = 2.0285
# epoch 95 / 100, step 14/14, loss = 1.9684
# epoch 96 / 100, step 1/55, loss = 1.8446
# epoch 96 / 100, step 2/55, loss = 1.6337
# epoch 96 / 100, step 3/55, loss = 1.8248
# epoch 96 / 100, step 4/55, loss = 1.9210
# epoch 96 / 100, step 5/55, loss = 1.7972
# epoch 96 / 100, step 6/55, loss = 1.9441
# epoch 96 / 100, step 7/55, loss = 1.8312
# epoch 96 / 100, step 8/55, loss = 2.2486
# epoch 96 / 100, step 9/55, loss = 1.8411
# epoch 96 / 100, step 10/55, loss = 2.0282
# epoch 96 / 100, step 11/55, loss = 1.8996
# epoch 96 / 100, step 12/55, loss = 1.7264
# epoch 96 / 100, step 13/55, loss = 1.6212
# epoch 96 / 100, step 14/55, loss = 2.0326
# epoch 96 / 100, step 15/55, loss = 1.8882
# epoch 96 / 100, step 16/55, loss = 1.6353
# epoch 96 / 100, step 17/55, loss = 1.9673
# epoch 96 / 100, step 18/55, loss = 1.7483
# epoch 96 / 100, step 19/55, loss = 1.8361
# epoch 96 / 100, step 20/55, loss = 1.8141
# epoch 96 / 100, step 21/55, loss = 1.8474
# epoch 96 / 100, step 22/55, loss = 1.8606
# epoch 96 / 100, step 23/55, loss = 1.8280
# epoch 96 / 100, step 24/55, loss = 1.7053
# epoch 96 / 100, step 25/55, loss = 1.9242
# epoch 96 / 100, step 26/55, loss = 1.7453
# epoch 96 / 100, step 27/55, loss = 1.9640
# epoch 96 / 100, step 28/55, loss = 1.8895
# epoch 96 / 100, step 29/55, loss = 1.8205
# epoch 96 / 100, step 30/55, loss = 2.0036
# epoch 96 / 100, step 31/55, loss = 1.8427
# epoch 96 / 100, step 32/55, loss = 1.7347
# epoch 96 / 100, step 33/55, loss = 1.9000
# epoch 96 / 100, step 34/55, loss = 1.9268
# epoch 96 / 100, step 35/55, loss = 1.8859
# epoch 96 / 100, step 36/55, loss = 2.0042
# epoch 96 / 100, step 37/55, loss = 1.8697
# epoch 96 / 100, step 38/55, loss = 2.0091
# epoch 96 / 100, step 39/55, loss = 1.9555
# epoch 96 / 100, step 40/55, loss = 1.8414
# epoch 96 / 100, step 41/55, loss = 1.8878
# epoch 96 / 100, step 42/55, loss = 1.8248
# epoch 96 / 100, step 43/55, loss = 1.8402
# epoch 96 / 100, step 44/55, loss = 1.7887
# epoch 96 / 100, step 45/55, loss = 1.6543
# epoch 96 / 100, step 46/55, loss = 1.9036
# epoch 96 / 100, step 47/55, loss = 1.9127
# epoch 96 / 100, step 48/55, loss = 1.8788
# epoch 96 / 100, step 49/55, loss = 1.9023
# epoch 96 / 100, step 50/55, loss = 1.8127
# epoch 96 / 100, step 51/55, loss = 1.7278
# epoch 96 / 100, step 52/55, loss = 1.7239
# epoch 96 / 100, step 53/55, loss = 1.8269
# epoch 96 / 100, step 54/55, loss = 1.7166
# epoch 96 / 100, step 55/55, loss = 1.7801
# epoch 96 / 100, step 1/14, loss = 1.9340
# epoch 96 / 100, step 2/14, loss = 1.9563
# epoch 96 / 100, step 3/14, loss = 1.8695
# epoch 96 / 100, step 4/14, loss = 2.0021
# epoch 96 / 100, step 5/14, loss = 1.9371
# epoch 96 / 100, step 6/14, loss = 1.9592
# epoch 96 / 100, step 7/14, loss = 2.0184
# epoch 96 / 100, step 8/14, loss = 1.8522
# epoch 96 / 100, step 9/14, loss = 1.9602
# epoch 96 / 100, step 10/14, loss = 2.0172
# epoch 96 / 100, step 11/14, loss = 1.9648
# epoch 96 / 100, step 12/14, loss = 2.0082
# epoch 96 / 100, step 13/14, loss = 2.0475
# epoch 96 / 100, step 14/14, loss = 1.9175
# epoch 97 / 100, step 1/55, loss = 1.7931
# epoch 97 / 100, step 2/55, loss = 1.9826
# epoch 97 / 100, step 3/55, loss = 1.7769
# epoch 97 / 100, step 4/55, loss = 1.7588
# epoch 97 / 100, step 5/55, loss = 1.8152
# epoch 97 / 100, step 6/55, loss = 1.8936
# epoch 97 / 100, step 7/55, loss = 2.0595
# epoch 97 / 100, step 8/55, loss = 1.9302
# epoch 97 / 100, step 9/55, loss = 1.8007
# epoch 97 / 100, step 10/55, loss = 1.8045
# epoch 97 / 100, step 11/55, loss = 1.8606
# epoch 97 / 100, step 12/55, loss = 1.8995
# epoch 97 / 100, step 13/55, loss = 1.7595
# epoch 97 / 100, step 14/55, loss = 1.8898
# epoch 97 / 100, step 15/55, loss = 1.8538
# epoch 97 / 100, step 16/55, loss = 1.9749
# epoch 97 / 100, step 17/55, loss = 1.8257
# epoch 97 / 100, step 18/55, loss = 1.8087
# epoch 97 / 100, step 19/55, loss = 1.9502
# epoch 97 / 100, step 20/55, loss = 1.8584
# epoch 97 / 100, step 21/55, loss = 2.2244
# epoch 97 / 100, step 22/55, loss = 1.8526
# epoch 97 / 100, step 23/55, loss = 1.7389
# epoch 97 / 100, step 24/55, loss = 1.9223
# epoch 97 / 100, step 25/55, loss = 1.7735
# epoch 97 / 100, step 26/55, loss = 1.8001
# epoch 97 / 100, step 27/55, loss = 1.9702
# epoch 97 / 100, step 28/55, loss = 1.7282
# epoch 97 / 100, step 29/55, loss = 1.9528
# epoch 97 / 100, step 30/55, loss = 1.8351
# epoch 97 / 100, step 31/55, loss = 1.9246
# epoch 97 / 100, step 32/55, loss = 1.8527
# epoch 97 / 100, step 33/55, loss = 1.9168
# epoch 97 / 100, step 34/55, loss = 2.0077
# epoch 97 / 100, step 35/55, loss = 1.9008
# epoch 97 / 100, step 36/55, loss = 1.8602
# epoch 97 / 100, step 37/55, loss = 1.8698
# epoch 97 / 100, step 38/55, loss = 1.8256
# epoch 97 / 100, step 39/55, loss = 2.0940
# epoch 97 / 100, step 40/55, loss = 1.8961
# epoch 97 / 100, step 41/55, loss = 1.7768
# epoch 97 / 100, step 42/55, loss = 1.9340
# epoch 97 / 100, step 43/55, loss = 1.9572
# epoch 97 / 100, step 44/55, loss = 1.8555
# epoch 97 / 100, step 45/55, loss = 1.8885
# epoch 97 / 100, step 46/55, loss = 1.9607
# epoch 97 / 100, step 47/55, loss = 2.0521
# epoch 97 / 100, step 48/55, loss = 1.7953
# epoch 97 / 100, step 49/55, loss = 1.8460
# epoch 97 / 100, step 50/55, loss = 1.7746
# epoch 97 / 100, step 51/55, loss = 1.8720
# epoch 97 / 100, step 52/55, loss = 1.7389
# epoch 97 / 100, step 53/55, loss = 1.7743
# epoch 97 / 100, step 54/55, loss = 1.8560
# epoch 97 / 100, step 55/55, loss = 1.8043
# epoch 97 / 100, step 1/14, loss = 1.9564
# epoch 97 / 100, step 2/14, loss = 1.9433
# epoch 97 / 100, step 3/14, loss = 1.9968
# epoch 97 / 100, step 4/14, loss = 1.9488
# epoch 97 / 100, step 5/14, loss = 1.9035
# epoch 97 / 100, step 6/14, loss = 1.9160
# epoch 97 / 100, step 7/14, loss = 1.9987
# epoch 97 / 100, step 8/14, loss = 1.8647
# epoch 97 / 100, step 9/14, loss = 1.9625
# epoch 97 / 100, step 10/14, loss = 2.1445
# epoch 97 / 100, step 11/14, loss = 1.9920
# epoch 97 / 100, step 12/14, loss = 2.0836
# epoch 97 / 100, step 13/14, loss = 2.0127
# epoch 97 / 100, step 14/14, loss = 1.8712
# epoch 98 / 100, step 1/55, loss = 1.7709
# epoch 98 / 100, step 2/55, loss = 1.9079
# epoch 98 / 100, step 3/55, loss = 1.8736
# epoch 98 / 100, step 4/55, loss = 1.8418
# epoch 98 / 100, step 5/55, loss = 1.8458
# epoch 98 / 100, step 6/55, loss = 2.0395
# epoch 98 / 100, step 7/55, loss = 1.9992
# epoch 98 / 100, step 8/55, loss = 1.9205
# epoch 98 / 100, step 9/55, loss = 1.8536
# epoch 98 / 100, step 10/55, loss = 2.0215
# epoch 98 / 100, step 11/55, loss = 1.8320
# epoch 98 / 100, step 12/55, loss = 1.9917
# epoch 98 / 100, step 13/55, loss = 1.6909
# epoch 98 / 100, step 14/55, loss = 1.9685
# epoch 98 / 100, step 15/55, loss = 1.8631
# epoch 98 / 100, step 16/55, loss = 1.8154
# epoch 98 / 100, step 17/55, loss = 1.9073
# epoch 98 / 100, step 18/55, loss = 1.7809
# epoch 98 / 100, step 19/55, loss = 1.8372
# epoch 98 / 100, step 20/55, loss = 2.0314
# epoch 98 / 100, step 21/55, loss = 1.8132
# epoch 98 / 100, step 22/55, loss = 1.9022
# epoch 98 / 100, step 23/55, loss = 1.8178
# epoch 98 / 100, step 24/55, loss = 1.7823
# epoch 98 / 100, step 25/55, loss = 1.9051
# epoch 98 / 100, step 26/55, loss = 1.8914
# epoch 98 / 100, step 27/55, loss = 1.9648
# epoch 98 / 100, step 28/55, loss = 1.9591
# epoch 98 / 100, step 29/55, loss = 1.7199
# epoch 98 / 100, step 30/55, loss = 1.6876
# epoch 98 / 100, step 31/55, loss = 2.0331
# epoch 98 / 100, step 32/55, loss = 1.8607
# epoch 98 / 100, step 33/55, loss = 1.8442
# epoch 98 / 100, step 34/55, loss = 1.8808
# epoch 98 / 100, step 35/55, loss = 1.7712
# epoch 98 / 100, step 36/55, loss = 1.7417
# epoch 98 / 100, step 37/55, loss = 1.8845
# epoch 98 / 100, step 38/55, loss = 1.6783
# epoch 98 / 100, step 39/55, loss = 1.8829
# epoch 98 / 100, step 40/55, loss = 1.8692
# epoch 98 / 100, step 41/55, loss = 2.1010
# epoch 98 / 100, step 42/55, loss = 1.9027
# epoch 98 / 100, step 43/55, loss = 2.0182
# epoch 98 / 100, step 44/55, loss = 1.6061
# epoch 98 / 100, step 45/55, loss = 1.7428
# epoch 98 / 100, step 46/55, loss = 1.8221
# epoch 98 / 100, step 47/55, loss = 1.8448
# epoch 98 / 100, step 48/55, loss = 2.0993
# epoch 98 / 100, step 49/55, loss = 1.9154
# epoch 98 / 100, step 50/55, loss = 1.7028
# epoch 98 / 100, step 51/55, loss = 1.9139
# epoch 98 / 100, step 52/55, loss = 1.8524
# epoch 98 / 100, step 53/55, loss = 1.9596
# epoch 98 / 100, step 54/55, loss = 1.8262
# epoch 98 / 100, step 55/55, loss = 1.8660
# epoch 98 / 100, step 1/14, loss = 1.9687
# epoch 98 / 100, step 2/14, loss = 1.9835
# epoch 98 / 100, step 3/14, loss = 1.9981
# epoch 98 / 100, step 4/14, loss = 2.0491
# epoch 98 / 100, step 5/14, loss = 1.9116
# epoch 98 / 100, step 6/14, loss = 1.9567
# epoch 98 / 100, step 7/14, loss = 2.0830
# epoch 98 / 100, step 8/14, loss = 1.8752
# epoch 98 / 100, step 9/14, loss = 1.9676
# epoch 98 / 100, step 10/14, loss = 2.0895
# epoch 98 / 100, step 11/14, loss = 1.9517
# epoch 98 / 100, step 12/14, loss = 2.0603
# epoch 98 / 100, step 13/14, loss = 2.0438
# epoch 98 / 100, step 14/14, loss = 1.9427
# epoch 99 / 100, step 1/55, loss = 1.8687
# epoch 99 / 100, step 2/55, loss = 1.8700
# epoch 99 / 100, step 3/55, loss = 1.7137
# epoch 99 / 100, step 4/55, loss = 1.8007
# epoch 99 / 100, step 5/55, loss = 1.7365
# epoch 99 / 100, step 6/55, loss = 1.7592
# epoch 99 / 100, step 7/55, loss = 2.0079
# epoch 99 / 100, step 8/55, loss = 1.7800
# epoch 99 / 100, step 9/55, loss = 1.9181
# epoch 99 / 100, step 10/55, loss = 1.8061
# epoch 99 / 100, step 11/55, loss = 1.8795
# epoch 99 / 100, step 12/55, loss = 2.0255
# epoch 99 / 100, step 13/55, loss = 1.8000
# epoch 99 / 100, step 14/55, loss = 1.6925
# epoch 99 / 100, step 15/55, loss = 1.8709
# epoch 99 / 100, step 16/55, loss = 1.7388
# epoch 99 / 100, step 17/55, loss = 1.8655
# epoch 99 / 100, step 18/55, loss = 1.7494
# epoch 99 / 100, step 19/55, loss = 1.6718
# epoch 99 / 100, step 20/55, loss = 1.8713
# epoch 99 / 100, step 21/55, loss = 1.8065
# epoch 99 / 100, step 22/55, loss = 2.0897
# epoch 99 / 100, step 23/55, loss = 2.0221
# epoch 99 / 100, step 24/55, loss = 2.2043
# epoch 99 / 100, step 25/55, loss = 1.7695
# epoch 99 / 100, step 26/55, loss = 1.9591
# epoch 99 / 100, step 27/55, loss = 1.9183
# epoch 99 / 100, step 28/55, loss = 1.8304
# epoch 99 / 100, step 29/55, loss = 1.6226
# epoch 99 / 100, step 30/55, loss = 1.7727
# epoch 99 / 100, step 31/55, loss = 1.9687
# epoch 99 / 100, step 32/55, loss = 1.7241
# epoch 99 / 100, step 33/55, loss = 1.9495
# epoch 99 / 100, step 34/55, loss = 2.0204
# epoch 99 / 100, step 35/55, loss = 1.9024
# epoch 99 / 100, step 36/55, loss = 1.7830
# epoch 99 / 100, step 37/55, loss = 1.9958
# epoch 99 / 100, step 38/55, loss = 1.9045
# epoch 99 / 100, step 39/55, loss = 1.7990
# epoch 99 / 100, step 40/55, loss = 1.8508
# epoch 99 / 100, step 41/55, loss = 1.9050
# epoch 99 / 100, step 42/55, loss = 1.9480
# epoch 99 / 100, step 43/55, loss = 1.6321
# epoch 99 / 100, step 44/55, loss = 1.8111
# epoch 99 / 100, step 45/55, loss = 1.9930
# epoch 99 / 100, step 46/55, loss = 1.7980
# epoch 99 / 100, step 47/55, loss = 1.7494
# epoch 99 / 100, step 48/55, loss = 1.9112
# epoch 99 / 100, step 49/55, loss = 2.0625
# epoch 99 / 100, step 50/55, loss = 1.8255
# epoch 99 / 100, step 51/55, loss = 1.8659
# epoch 99 / 100, step 52/55, loss = 1.9738
# epoch 99 / 100, step 53/55, loss = 1.9583
# epoch 99 / 100, step 54/55, loss = 1.9759
# epoch 99 / 100, step 55/55, loss = 1.9045
# epoch 99 / 100, step 1/14, loss = 2.0089
# epoch 99 / 100, step 2/14, loss = 2.0160
# epoch 99 / 100, step 3/14, loss = 1.9695
# epoch 99 / 100, step 4/14, loss = 1.9954
# epoch 99 / 100, step 5/14, loss = 1.8708
# epoch 99 / 100, step 6/14, loss = 2.0141
# epoch 99 / 100, step 7/14, loss = 2.0650
# epoch 99 / 100, step 8/14, loss = 1.8741
# epoch 99 / 100, step 9/14, loss = 1.9862
# epoch 99 / 100, step 10/14, loss = 2.1184
# epoch 99 / 100, step 11/14, loss = 1.9932
# epoch 99 / 100, step 12/14, loss = 1.9980
# epoch 99 / 100, step 13/14, loss = 2.0282
# epoch 99 / 100, step 14/14, loss = 1.9269
# epoch 100 / 100, step 1/55, loss = 1.9109
# epoch 100 / 100, step 2/55, loss = 1.9108
# epoch 100 / 100, step 3/55, loss = 1.9269
# epoch 100 / 100, step 4/55, loss = 1.7951
# epoch 100 / 100, step 5/55, loss = 1.8035
# epoch 100 / 100, step 6/55, loss = 1.8068
# epoch 100 / 100, step 7/55, loss = 1.9421
# epoch 100 / 100, step 8/55, loss = 1.8887
# epoch 100 / 100, step 9/55, loss = 1.6795
# epoch 100 / 100, step 10/55, loss = 1.7880
# epoch 100 / 100, step 11/55, loss = 1.7496
# epoch 100 / 100, step 12/55, loss = 1.9792
# epoch 100 / 100, step 13/55, loss = 1.7459
# epoch 100 / 100, step 14/55, loss = 1.7987
# epoch 100 / 100, step 15/55, loss = 1.8334
# epoch 100 / 100, step 16/55, loss = 1.7442
# epoch 100 / 100, step 17/55, loss = 1.7402
# epoch 100 / 100, step 18/55, loss = 2.0050
# epoch 100 / 100, step 19/55, loss = 1.8362
# epoch 100 / 100, step 20/55, loss = 1.9529
# epoch 100 / 100, step 21/55, loss = 1.9399
# epoch 100 / 100, step 22/55, loss = 2.0286
# epoch 100 / 100, step 23/55, loss = 1.9096
# epoch 100 / 100, step 24/55, loss = 1.9167
# epoch 100 / 100, step 25/55, loss = 1.9650
# epoch 100 / 100, step 26/55, loss = 1.9205
# epoch 100 / 100, step 27/55, loss = 1.8375
# epoch 100 / 100, step 28/55, loss = 1.9075
# epoch 100 / 100, step 29/55, loss = 1.8973
# epoch 100 / 100, step 30/55, loss = 1.8312
# epoch 100 / 100, step 31/55, loss = 1.7836
# epoch 100 / 100, step 32/55, loss = 1.6600
# epoch 100 / 100, step 33/55, loss = 1.7409
# epoch 100 / 100, step 34/55, loss = 1.8307
# epoch 100 / 100, step 35/55, loss = 1.7683
# epoch 100 / 100, step 36/55, loss = 2.1755
# epoch 100 / 100, step 37/55, loss = 1.8277
# epoch 100 / 100, step 38/55, loss = 1.7570
# epoch 100 / 100, step 39/55, loss = 1.8646
# epoch 100 / 100, step 40/55, loss = 1.8150
# epoch 100 / 100, step 41/55, loss = 1.8585
# epoch 100 / 100, step 42/55, loss = 1.9388
# epoch 100 / 100, step 43/55, loss = 1.8008
# epoch 100 / 100, step 44/55, loss = 2.0020
# epoch 100 / 100, step 45/55, loss = 2.0871
# epoch 100 / 100, step 46/55, loss = 1.7842
# epoch 100 / 100, step 47/55, loss = 1.6725
# epoch 100 / 100, step 48/55, loss = 1.9507
# epoch 100 / 100, step 49/55, loss = 1.8874
# epoch 100 / 100, step 50/55, loss = 1.8982
# epoch 100 / 100, step 51/55, loss = 2.0200
# epoch 100 / 100, step 52/55, loss = 2.0578
# epoch 100 / 100, step 53/55, loss = 1.8446
# epoch 100 / 100, step 54/55, loss = 1.9815
# epoch 100 / 100, step 55/55, loss = 1.5615
# epoch 100 / 100, step 1/14, loss = 1.9610
# epoch 100 / 100, step 2/14, loss = 1.9482
# epoch 100 / 100, step 3/14, loss = 1.9253
# epoch 100 / 100, step 4/14, loss = 2.0176
# epoch 100 / 100, step 5/14, loss = 1.8764
# epoch 100 / 100, step 6/14, loss = 2.0024
# epoch 100 / 100, step 7/14, loss = 2.0270
# epoch 100 / 100, step 8/14, loss = 1.8396
# epoch 100 / 100, step 9/14, loss = 1.9567
# epoch 100 / 100, step 10/14, loss = 2.1965
# epoch 100 / 100, step 11/14, loss = 2.0095
# epoch 100 / 100, step 12/14, loss = 2.0307
# epoch 100 / 100, step 13/14, loss = 2.0333
# epoch 100 / 100, step 14/14, loss = 1.9089

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 100 epochs the trainning accuracy is 24.228571428571428 and the test accuaracy is 14.155251141552512
#  the maximum accuracy of the test was 20.54794520547945 at the epoch 29
#  the maximum accuracy of the train was 28.571428571428573 at the epoch 95
# the accuracy of the training at the best validation accuracy 20.54794520547945 is 23.771428571428572

# %%
# Copy the 
shutil.copyfile('./rnn.ipynb', './' + results_dir + 'rnn.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
