# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - hidden_size de 256 a 512
# - epochs de 100 a 50

# %%
filepath = '27 - 50epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 512
num_classes = 7
num_epochs = 50
batch_size = 8
learning_rate = 0.001
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([8, 769024]) , Labels shape: torch.Size([8])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/110, loss = 2.1335
# epoch 1 / 50, step 2/110, loss = 2.0807
# epoch 1 / 50, step 3/110, loss = 2.1579
# epoch 1 / 50, step 4/110, loss = 2.1203
# epoch 1 / 50, step 5/110, loss = 2.1089
# epoch 1 / 50, step 6/110, loss = 1.9460
# epoch 1 / 50, step 7/110, loss = 2.2102
# epoch 1 / 50, step 8/110, loss = 2.1435
# epoch 1 / 50, step 9/110, loss = 1.9987
# epoch 1 / 50, step 10/110, loss = 2.4568
# epoch 1 / 50, step 11/110, loss = 2.5938
# epoch 1 / 50, step 12/110, loss = 2.2731
# epoch 1 / 50, step 13/110, loss = 2.1960
# epoch 1 / 50, step 14/110, loss = 2.0235
# epoch 1 / 50, step 15/110, loss = 2.2807
# epoch 1 / 50, step 16/110, loss = 2.2132
# epoch 1 / 50, step 17/110, loss = 2.0137
# epoch 1 / 50, step 18/110, loss = 2.3568
# epoch 1 / 50, step 19/110, loss = 1.7790
# epoch 1 / 50, step 20/110, loss = 2.1964
# epoch 1 / 50, step 21/110, loss = 2.1852
# epoch 1 / 50, step 22/110, loss = 1.9235
# epoch 1 / 50, step 23/110, loss = 2.2932
# epoch 1 / 50, step 24/110, loss = 2.5190
# epoch 1 / 50, step 25/110, loss = 2.4850
# epoch 1 / 50, step 26/110, loss = 1.6545
# epoch 1 / 50, step 27/110, loss = 2.1760
# epoch 1 / 50, step 28/110, loss = 2.1883
# epoch 1 / 50, step 29/110, loss = 2.1968
# epoch 1 / 50, step 30/110, loss = 1.9725
# epoch 1 / 50, step 31/110, loss = 2.0335
# epoch 1 / 50, step 32/110, loss = 2.3635
# epoch 1 / 50, step 33/110, loss = 2.4879
# epoch 1 / 50, step 34/110, loss = 1.9657
# epoch 1 / 50, step 35/110, loss = 2.2046
# epoch 1 / 50, step 36/110, loss = 1.9367
# epoch 1 / 50, step 37/110, loss = 2.3427
# epoch 1 / 50, step 38/110, loss = 2.0824
# epoch 1 / 50, step 39/110, loss = 2.2138
# epoch 1 / 50, step 40/110, loss = 2.6154
# epoch 1 / 50, step 41/110, loss = 2.6027
# epoch 1 / 50, step 42/110, loss = 2.3819
# epoch 1 / 50, step 43/110, loss = 2.4526
# epoch 1 / 50, step 44/110, loss = 2.0705
# epoch 1 / 50, step 45/110, loss = 1.9984
# epoch 1 / 50, step 46/110, loss = 2.2865
# epoch 1 / 50, step 47/110, loss = 2.1146
# epoch 1 / 50, step 48/110, loss = 2.3122
# epoch 1 / 50, step 49/110, loss = 2.1139
# epoch 1 / 50, step 50/110, loss = 2.1780
# epoch 1 / 50, step 51/110, loss = 2.0967
# epoch 1 / 50, step 52/110, loss = 2.4248
# epoch 1 / 50, step 53/110, loss = 1.8337
# epoch 1 / 50, step 54/110, loss = 2.0097
# epoch 1 / 50, step 55/110, loss = 2.3381
# epoch 1 / 50, step 56/110, loss = 1.8028
# epoch 1 / 50, step 57/110, loss = 2.5116
# epoch 1 / 50, step 58/110, loss = 2.3209
# epoch 1 / 50, step 59/110, loss = 1.7799
# epoch 1 / 50, step 60/110, loss = 2.1035
# epoch 1 / 50, step 61/110, loss = 2.3562
# epoch 1 / 50, step 62/110, loss = 1.8968
# epoch 1 / 50, step 63/110, loss = 2.3719
# epoch 1 / 50, step 64/110, loss = 2.0156
# epoch 1 / 50, step 65/110, loss = 2.3651
# epoch 1 / 50, step 66/110, loss = 1.8447
# epoch 1 / 50, step 67/110, loss = 1.8823
# epoch 1 / 50, step 68/110, loss = 2.2256
# epoch 1 / 50, step 69/110, loss = 2.0973
# epoch 1 / 50, step 70/110, loss = 2.0882
# epoch 1 / 50, step 71/110, loss = 2.4818
# epoch 1 / 50, step 72/110, loss = 2.1321
# epoch 1 / 50, step 73/110, loss = 1.9988
# epoch 1 / 50, step 74/110, loss = 2.3584
# epoch 1 / 50, step 75/110, loss = 2.1900
# epoch 1 / 50, step 76/110, loss = 2.8746
# epoch 1 / 50, step 77/110, loss = 1.9688
# epoch 1 / 50, step 78/110, loss = 2.1023
# epoch 1 / 50, step 79/110, loss = 2.2654
# epoch 1 / 50, step 80/110, loss = 1.9711
# epoch 1 / 50, step 81/110, loss = 2.0158
# epoch 1 / 50, step 82/110, loss = 2.4897
# epoch 1 / 50, step 83/110, loss = 2.1805
# epoch 1 / 50, step 84/110, loss = 1.8287
# epoch 1 / 50, step 85/110, loss = 2.3307
# epoch 1 / 50, step 86/110, loss = 2.4787
# epoch 1 / 50, step 87/110, loss = 2.1811
# epoch 1 / 50, step 88/110, loss = 2.3407
# epoch 1 / 50, step 89/110, loss = 1.9744
# epoch 1 / 50, step 90/110, loss = 1.6192
# epoch 1 / 50, step 91/110, loss = 2.3090
# epoch 1 / 50, step 92/110, loss = 2.3103
# epoch 1 / 50, step 93/110, loss = 2.4667
# epoch 1 / 50, step 94/110, loss = 1.8783
# epoch 1 / 50, step 95/110, loss = 2.1140
# epoch 1 / 50, step 96/110, loss = 2.3021
# epoch 1 / 50, step 97/110, loss = 2.2990
# epoch 1 / 50, step 98/110, loss = 1.8085
# epoch 1 / 50, step 99/110, loss = 1.9844
# epoch 1 / 50, step 100/110, loss = 2.0179
# epoch 1 / 50, step 101/110, loss = 2.1588
# epoch 1 / 50, step 102/110, loss = 2.0380
# epoch 1 / 50, step 103/110, loss = 2.1258
# epoch 1 / 50, step 104/110, loss = 2.4071
# epoch 1 / 50, step 105/110, loss = 2.3261
# epoch 1 / 50, step 106/110, loss = 1.9933
# epoch 1 / 50, step 107/110, loss = 2.4921
# epoch 1 / 50, step 108/110, loss = 1.6430
# epoch 1 / 50, step 109/110, loss = 2.5213
# epoch 1 / 50, step 110/110, loss = 2.4851
# epoch 1 / 50, step 1/28, loss = 2.1603
# epoch 1 / 50, step 2/28, loss = 2.4061
# epoch 1 / 50, step 3/28, loss = 2.0463
# epoch 1 / 50, step 4/28, loss = 2.0739
# epoch 1 / 50, step 5/28, loss = 2.0134
# epoch 1 / 50, step 6/28, loss = 2.3176
# epoch 1 / 50, step 7/28, loss = 1.9067
# epoch 1 / 50, step 8/28, loss = 1.8592
# epoch 1 / 50, step 9/28, loss = 2.0658
# epoch 1 / 50, step 10/28, loss = 2.0538
# epoch 1 / 50, step 11/28, loss = 2.1591
# epoch 1 / 50, step 12/28, loss = 2.1622
# epoch 1 / 50, step 13/28, loss = 2.2326
# epoch 1 / 50, step 14/28, loss = 1.9799
# epoch 1 / 50, step 15/28, loss = 2.0770
# epoch 1 / 50, step 16/28, loss = 2.1299
# epoch 1 / 50, step 17/28, loss = 2.1827
# epoch 1 / 50, step 18/28, loss = 2.2569
# epoch 1 / 50, step 19/28, loss = 2.1683
# epoch 1 / 50, step 20/28, loss = 1.6043
# epoch 1 / 50, step 21/28, loss = 2.2042
# epoch 1 / 50, step 22/28, loss = 1.9192
# epoch 1 / 50, step 23/28, loss = 2.0989
# epoch 1 / 50, step 24/28, loss = 2.2775
# epoch 1 / 50, step 25/28, loss = 2.2358
# epoch 1 / 50, step 26/28, loss = 2.2064
# epoch 1 / 50, step 27/28, loss = 1.9941
# epoch 1 / 50, step 28/28, loss = 2.1704
# epoch 2 / 50, step 1/110, loss = 2.4726
# epoch 2 / 50, step 2/110, loss = 1.9776
# epoch 2 / 50, step 3/110, loss = 1.5962
# epoch 2 / 50, step 4/110, loss = 2.1160
# epoch 2 / 50, step 5/110, loss = 2.0507
# epoch 2 / 50, step 6/110, loss = 2.0849
# epoch 2 / 50, step 7/110, loss = 2.0981
# epoch 2 / 50, step 8/110, loss = 2.7089
# epoch 2 / 50, step 9/110, loss = 2.1942
# epoch 2 / 50, step 10/110, loss = 2.1396
# epoch 2 / 50, step 11/110, loss = 1.9994
# epoch 2 / 50, step 12/110, loss = 2.0304
# epoch 2 / 50, step 13/110, loss = 2.3205
# epoch 2 / 50, step 14/110, loss = 2.3611
# epoch 2 / 50, step 15/110, loss = 2.4545
# epoch 2 / 50, step 16/110, loss = 2.4887
# epoch 2 / 50, step 17/110, loss = 1.8705
# epoch 2 / 50, step 18/110, loss = 2.2043
# epoch 2 / 50, step 19/110, loss = 2.2478
# epoch 2 / 50, step 20/110, loss = 2.2019
# epoch 2 / 50, step 21/110, loss = 1.8785
# epoch 2 / 50, step 22/110, loss = 1.9157
# epoch 2 / 50, step 23/110, loss = 2.1843
# epoch 2 / 50, step 24/110, loss = 2.4106
# epoch 2 / 50, step 25/110, loss = 2.1707
# epoch 2 / 50, step 26/110, loss = 2.2525
# epoch 2 / 50, step 27/110, loss = 1.9774
# epoch 2 / 50, step 28/110, loss = 2.1302
# epoch 2 / 50, step 29/110, loss = 2.1946
# epoch 2 / 50, step 30/110, loss = 1.9698
# epoch 2 / 50, step 31/110, loss = 2.3871
# epoch 2 / 50, step 32/110, loss = 2.0103
# epoch 2 / 50, step 33/110, loss = 2.2896
# epoch 2 / 50, step 34/110, loss = 2.1401
# epoch 2 / 50, step 35/110, loss = 2.5611
# epoch 2 / 50, step 36/110, loss = 2.4066
# epoch 2 / 50, step 37/110, loss = 2.3252
# epoch 2 / 50, step 38/110, loss = 2.5890
# epoch 2 / 50, step 39/110, loss = 2.2922
# epoch 2 / 50, step 40/110, loss = 1.8712
# epoch 2 / 50, step 41/110, loss = 1.7976
# epoch 2 / 50, step 42/110, loss = 2.0964
# epoch 2 / 50, step 43/110, loss = 2.1080
# epoch 2 / 50, step 44/110, loss = 1.9321
# epoch 2 / 50, step 45/110, loss = 1.9307
# epoch 2 / 50, step 46/110, loss = 2.0700
# epoch 2 / 50, step 47/110, loss = 2.3538
# epoch 2 / 50, step 48/110, loss = 2.0158
# epoch 2 / 50, step 49/110, loss = 2.0857
# epoch 2 / 50, step 50/110, loss = 1.9240
# epoch 2 / 50, step 51/110, loss = 1.7337
# epoch 2 / 50, step 52/110, loss = 2.2084
# epoch 2 / 50, step 53/110, loss = 2.2325
# epoch 2 / 50, step 54/110, loss = 2.3386
# epoch 2 / 50, step 55/110, loss = 1.9326
# epoch 2 / 50, step 56/110, loss = 2.0436
# epoch 2 / 50, step 57/110, loss = 2.2565
# epoch 2 / 50, step 58/110, loss = 1.9664
# epoch 2 / 50, step 59/110, loss = 1.9047
# epoch 2 / 50, step 60/110, loss = 2.0659
# epoch 2 / 50, step 61/110, loss = 1.7244
# epoch 2 / 50, step 62/110, loss = 2.4928
# epoch 2 / 50, step 63/110, loss = 2.2956
# epoch 2 / 50, step 64/110, loss = 2.5040
# epoch 2 / 50, step 65/110, loss = 1.9535
# epoch 2 / 50, step 66/110, loss = 2.1537
# epoch 2 / 50, step 67/110, loss = 2.1349
# epoch 2 / 50, step 68/110, loss = 1.9236
# epoch 2 / 50, step 69/110, loss = 2.3950
# epoch 2 / 50, step 70/110, loss = 1.7215
# epoch 2 / 50, step 71/110, loss = 2.0154
# epoch 2 / 50, step 72/110, loss = 2.4240
# epoch 2 / 50, step 73/110, loss = 2.3641
# epoch 2 / 50, step 74/110, loss = 2.2687
# epoch 2 / 50, step 75/110, loss = 1.9731
# epoch 2 / 50, step 76/110, loss = 2.2327
# epoch 2 / 50, step 77/110, loss = 1.8492
# epoch 2 / 50, step 78/110, loss = 2.0840
# epoch 2 / 50, step 79/110, loss = 1.9550
# epoch 2 / 50, step 80/110, loss = 2.3236
# epoch 2 / 50, step 81/110, loss = 1.9921
# epoch 2 / 50, step 82/110, loss = 1.9116
# epoch 2 / 50, step 83/110, loss = 1.9339
# epoch 2 / 50, step 84/110, loss = 1.8963
# epoch 2 / 50, step 85/110, loss = 1.9656
# epoch 2 / 50, step 86/110, loss = 1.9094
# epoch 2 / 50, step 87/110, loss = 2.4469
# epoch 2 / 50, step 88/110, loss = 1.7026
# epoch 2 / 50, step 89/110, loss = 2.4402
# epoch 2 / 50, step 90/110, loss = 1.9674
# epoch 2 / 50, step 91/110, loss = 1.9304
# epoch 2 / 50, step 92/110, loss = 1.8093
# epoch 2 / 50, step 93/110, loss = 2.7278
# epoch 2 / 50, step 94/110, loss = 2.3004
# epoch 2 / 50, step 95/110, loss = 2.1299
# epoch 2 / 50, step 96/110, loss = 2.1108
# epoch 2 / 50, step 97/110, loss = 2.4478
# epoch 2 / 50, step 98/110, loss = 2.2137
# epoch 2 / 50, step 99/110, loss = 2.2688
# epoch 2 / 50, step 100/110, loss = 2.1699
# epoch 2 / 50, step 101/110, loss = 1.9924
# epoch 2 / 50, step 102/110, loss = 1.8262
# epoch 2 / 50, step 103/110, loss = 2.2199
# epoch 2 / 50, step 104/110, loss = 2.1048
# epoch 2 / 50, step 105/110, loss = 2.2680
# epoch 2 / 50, step 106/110, loss = 1.8593
# epoch 2 / 50, step 107/110, loss = 2.2989
# epoch 2 / 50, step 108/110, loss = 2.0745
# epoch 2 / 50, step 109/110, loss = 1.9533
# epoch 2 / 50, step 110/110, loss = 2.1664
# epoch 2 / 50, step 1/28, loss = 1.8931
# epoch 2 / 50, step 2/28, loss = 1.9531
# epoch 2 / 50, step 3/28, loss = 2.0589
# epoch 2 / 50, step 4/28, loss = 1.8836
# epoch 2 / 50, step 5/28, loss = 2.1255
# epoch 2 / 50, step 6/28, loss = 1.8675
# epoch 2 / 50, step 7/28, loss = 1.9919
# epoch 2 / 50, step 8/28, loss = 2.0740
# epoch 2 / 50, step 9/28, loss = 1.7987
# epoch 2 / 50, step 10/28, loss = 2.0513
# epoch 2 / 50, step 11/28, loss = 1.9467
# epoch 2 / 50, step 12/28, loss = 1.9217
# epoch 2 / 50, step 13/28, loss = 1.9635
# epoch 2 / 50, step 14/28, loss = 1.9822
# epoch 2 / 50, step 15/28, loss = 1.9362
# epoch 2 / 50, step 16/28, loss = 1.8107
# epoch 2 / 50, step 17/28, loss = 1.9820
# epoch 2 / 50, step 18/28, loss = 2.0492
# epoch 2 / 50, step 19/28, loss = 2.0401
# epoch 2 / 50, step 20/28, loss = 2.0246
# epoch 2 / 50, step 21/28, loss = 1.9923
# epoch 2 / 50, step 22/28, loss = 1.8577
# epoch 2 / 50, step 23/28, loss = 1.9340
# epoch 2 / 50, step 24/28, loss = 2.1496
# epoch 2 / 50, step 25/28, loss = 2.0162
# epoch 2 / 50, step 26/28, loss = 2.0870
# epoch 2 / 50, step 27/28, loss = 1.8906
# epoch 2 / 50, step 28/28, loss = 2.0007
# epoch 3 / 50, step 1/110, loss = 2.0377
# epoch 3 / 50, step 2/110, loss = 2.4285
# epoch 3 / 50, step 3/110, loss = 1.9147
# epoch 3 / 50, step 4/110, loss = 2.2710
# epoch 3 / 50, step 5/110, loss = 1.9733
# epoch 3 / 50, step 6/110, loss = 2.3435
# epoch 3 / 50, step 7/110, loss = 2.3663
# epoch 3 / 50, step 8/110, loss = 2.1925
# epoch 3 / 50, step 9/110, loss = 1.9283
# epoch 3 / 50, step 10/110, loss = 2.5374
# epoch 3 / 50, step 11/110, loss = 2.0888
# epoch 3 / 50, step 12/110, loss = 1.9695
# epoch 3 / 50, step 13/110, loss = 2.1520
# epoch 3 / 50, step 14/110, loss = 2.0184
# epoch 3 / 50, step 15/110, loss = 1.9571
# epoch 3 / 50, step 16/110, loss = 2.3098
# epoch 3 / 50, step 17/110, loss = 2.0848
# epoch 3 / 50, step 18/110, loss = 2.6734
# epoch 3 / 50, step 19/110, loss = 1.8668
# epoch 3 / 50, step 20/110, loss = 1.9472
# epoch 3 / 50, step 21/110, loss = 1.6630
# epoch 3 / 50, step 22/110, loss = 2.4263
# epoch 3 / 50, step 23/110, loss = 2.5025
# epoch 3 / 50, step 24/110, loss = 1.9429
# epoch 3 / 50, step 25/110, loss = 1.9185
# epoch 3 / 50, step 26/110, loss = 2.1469
# epoch 3 / 50, step 27/110, loss = 1.8982
# epoch 3 / 50, step 28/110, loss = 2.1357
# epoch 3 / 50, step 29/110, loss = 1.7765
# epoch 3 / 50, step 30/110, loss = 2.2136
# epoch 3 / 50, step 31/110, loss = 1.9400
# epoch 3 / 50, step 32/110, loss = 2.1195
# epoch 3 / 50, step 33/110, loss = 1.9248
# epoch 3 / 50, step 34/110, loss = 1.9784
# epoch 3 / 50, step 35/110, loss = 2.5032
# epoch 3 / 50, step 36/110, loss = 1.6166
# epoch 3 / 50, step 37/110, loss = 1.8631
# epoch 3 / 50, step 38/110, loss = 2.2701
# epoch 3 / 50, step 39/110, loss = 2.0381
# epoch 3 / 50, step 40/110, loss = 2.2044
# epoch 3 / 50, step 41/110, loss = 1.7920
# epoch 3 / 50, step 42/110, loss = 2.1382
# epoch 3 / 50, step 43/110, loss = 1.8017
# epoch 3 / 50, step 44/110, loss = 2.2888
# epoch 3 / 50, step 45/110, loss = 1.6709
# epoch 3 / 50, step 46/110, loss = 2.1474
# epoch 3 / 50, step 47/110, loss = 1.9736
# epoch 3 / 50, step 48/110, loss = 1.9449
# epoch 3 / 50, step 49/110, loss = 2.0762
# epoch 3 / 50, step 50/110, loss = 2.4628
# epoch 3 / 50, step 51/110, loss = 2.5184
# epoch 3 / 50, step 52/110, loss = 2.1495
# epoch 3 / 50, step 53/110, loss = 1.6922
# epoch 3 / 50, step 54/110, loss = 1.8545
# epoch 3 / 50, step 55/110, loss = 1.6596
# epoch 3 / 50, step 56/110, loss = 1.7808
# epoch 3 / 50, step 57/110, loss = 1.9350
# epoch 3 / 50, step 58/110, loss = 2.2619
# epoch 3 / 50, step 59/110, loss = 2.5283
# epoch 3 / 50, step 60/110, loss = 2.3385
# epoch 3 / 50, step 61/110, loss = 2.0747
# epoch 3 / 50, step 62/110, loss = 2.0126
# epoch 3 / 50, step 63/110, loss = 2.0969
# epoch 3 / 50, step 64/110, loss = 1.7796
# epoch 3 / 50, step 65/110, loss = 2.3317
# epoch 3 / 50, step 66/110, loss = 1.8399
# epoch 3 / 50, step 67/110, loss = 1.8264
# epoch 3 / 50, step 68/110, loss = 1.6073
# epoch 3 / 50, step 69/110, loss = 2.1619
# epoch 3 / 50, step 70/110, loss = 1.8436
# epoch 3 / 50, step 71/110, loss = 1.6706
# epoch 3 / 50, step 72/110, loss = 1.9800
# epoch 3 / 50, step 73/110, loss = 2.0898
# epoch 3 / 50, step 74/110, loss = 1.8309
# epoch 3 / 50, step 75/110, loss = 2.0099
# epoch 3 / 50, step 76/110, loss = 2.5214
# epoch 3 / 50, step 77/110, loss = 2.3682
# epoch 3 / 50, step 78/110, loss = 2.0609
# epoch 3 / 50, step 79/110, loss = 2.2936
# epoch 3 / 50, step 80/110, loss = 2.0929
# epoch 3 / 50, step 81/110, loss = 2.2824
# epoch 3 / 50, step 82/110, loss = 1.9862
# epoch 3 / 50, step 83/110, loss = 1.9287
# epoch 3 / 50, step 84/110, loss = 2.3056
# epoch 3 / 50, step 85/110, loss = 2.1819
# epoch 3 / 50, step 86/110, loss = 2.0509
# epoch 3 / 50, step 87/110, loss = 1.9472
# epoch 3 / 50, step 88/110, loss = 1.8919
# epoch 3 / 50, step 89/110, loss = 2.1618
# epoch 3 / 50, step 90/110, loss = 1.8656
# epoch 3 / 50, step 91/110, loss = 2.2097
# epoch 3 / 50, step 92/110, loss = 2.1798
# epoch 3 / 50, step 93/110, loss = 2.3219
# epoch 3 / 50, step 94/110, loss = 2.1990
# epoch 3 / 50, step 95/110, loss = 1.8057
# epoch 3 / 50, step 96/110, loss = 2.3819
# epoch 3 / 50, step 97/110, loss = 2.1538
# epoch 3 / 50, step 98/110, loss = 2.2489
# epoch 3 / 50, step 99/110, loss = 2.3307
# epoch 3 / 50, step 100/110, loss = 2.0366
# epoch 3 / 50, step 101/110, loss = 2.2209
# epoch 3 / 50, step 102/110, loss = 2.0029
# epoch 3 / 50, step 103/110, loss = 2.2579
# epoch 3 / 50, step 104/110, loss = 1.8486
# epoch 3 / 50, step 105/110, loss = 1.9701
# epoch 3 / 50, step 106/110, loss = 1.7844
# epoch 3 / 50, step 107/110, loss = 2.1140
# epoch 3 / 50, step 108/110, loss = 2.3001
# epoch 3 / 50, step 109/110, loss = 2.1277
# epoch 3 / 50, step 110/110, loss = 1.9721
# epoch 3 / 50, step 1/28, loss = 2.2346
# epoch 3 / 50, step 2/28, loss = 2.3863
# epoch 3 / 50, step 3/28, loss = 2.1375
# epoch 3 / 50, step 4/28, loss = 2.5825
# epoch 3 / 50, step 5/28, loss = 2.0201
# epoch 3 / 50, step 6/28, loss = 2.3807
# epoch 3 / 50, step 7/28, loss = 1.8208
# epoch 3 / 50, step 8/28, loss = 1.7335
# epoch 3 / 50, step 9/28, loss = 2.1840
# epoch 3 / 50, step 10/28, loss = 1.8862
# epoch 3 / 50, step 11/28, loss = 2.1172
# epoch 3 / 50, step 12/28, loss = 1.9744
# epoch 3 / 50, step 13/28, loss = 2.1583
# epoch 3 / 50, step 14/28, loss = 2.4306
# epoch 3 / 50, step 15/28, loss = 1.7581
# epoch 3 / 50, step 16/28, loss = 2.5035
# epoch 3 / 50, step 17/28, loss = 1.9915
# epoch 3 / 50, step 18/28, loss = 1.9175
# epoch 3 / 50, step 19/28, loss = 2.3135
# epoch 3 / 50, step 20/28, loss = 1.5404
# epoch 3 / 50, step 21/28, loss = 2.0740
# epoch 3 / 50, step 22/28, loss = 2.1901
# epoch 3 / 50, step 23/28, loss = 2.2623
# epoch 3 / 50, step 24/28, loss = 2.2033
# epoch 3 / 50, step 25/28, loss = 2.4033
# epoch 3 / 50, step 26/28, loss = 2.6511
# epoch 3 / 50, step 27/28, loss = 2.3483
# epoch 3 / 50, step 28/28, loss = 1.6508
# epoch 4 / 50, step 1/110, loss = 2.2199
# epoch 4 / 50, step 2/110, loss = 1.7196
# epoch 4 / 50, step 3/110, loss = 2.0664
# epoch 4 / 50, step 4/110, loss = 1.6327
# epoch 4 / 50, step 5/110, loss = 1.7931
# epoch 4 / 50, step 6/110, loss = 2.0214
# epoch 4 / 50, step 7/110, loss = 2.1474
# epoch 4 / 50, step 8/110, loss = 2.2272
# epoch 4 / 50, step 9/110, loss = 2.5644
# epoch 4 / 50, step 10/110, loss = 2.3400
# epoch 4 / 50, step 11/110, loss = 2.0886
# epoch 4 / 50, step 12/110, loss = 2.3134
# epoch 4 / 50, step 13/110, loss = 2.0382
# epoch 4 / 50, step 14/110, loss = 2.5980
# epoch 4 / 50, step 15/110, loss = 2.4823
# epoch 4 / 50, step 16/110, loss = 2.1815
# epoch 4 / 50, step 17/110, loss = 2.5474
# epoch 4 / 50, step 18/110, loss = 2.3932
# epoch 4 / 50, step 19/110, loss = 2.0509
# epoch 4 / 50, step 20/110, loss = 1.8035
# epoch 4 / 50, step 21/110, loss = 1.7917
# epoch 4 / 50, step 22/110, loss = 2.1651
# epoch 4 / 50, step 23/110, loss = 1.9568
# epoch 4 / 50, step 24/110, loss = 2.4268
# epoch 4 / 50, step 25/110, loss = 2.2263
# epoch 4 / 50, step 26/110, loss = 2.1288
# epoch 4 / 50, step 27/110, loss = 2.1663
# epoch 4 / 50, step 28/110, loss = 2.1600
# epoch 4 / 50, step 29/110, loss = 2.2753
# epoch 4 / 50, step 30/110, loss = 2.3502
# epoch 4 / 50, step 31/110, loss = 2.3559
# epoch 4 / 50, step 32/110, loss = 2.6214
# epoch 4 / 50, step 33/110, loss = 2.2155
# epoch 4 / 50, step 34/110, loss = 2.2929
# epoch 4 / 50, step 35/110, loss = 1.9018
# epoch 4 / 50, step 36/110, loss = 1.9278
# epoch 4 / 50, step 37/110, loss = 2.1927
# epoch 4 / 50, step 38/110, loss = 2.4153
# epoch 4 / 50, step 39/110, loss = 2.0364
# epoch 4 / 50, step 40/110, loss = 2.4161
# epoch 4 / 50, step 41/110, loss = 2.2541
# epoch 4 / 50, step 42/110, loss = 2.2212
# epoch 4 / 50, step 43/110, loss = 1.8982
# epoch 4 / 50, step 44/110, loss = 1.9839
# epoch 4 / 50, step 45/110, loss = 2.1969
# epoch 4 / 50, step 46/110, loss = 2.2569
# epoch 4 / 50, step 47/110, loss = 2.1489
# epoch 4 / 50, step 48/110, loss = 1.6519
# epoch 4 / 50, step 49/110, loss = 1.8433
# epoch 4 / 50, step 50/110, loss = 2.4709
# epoch 4 / 50, step 51/110, loss = 2.0499
# epoch 4 / 50, step 52/110, loss = 2.2366
# epoch 4 / 50, step 53/110, loss = 1.9700
# epoch 4 / 50, step 54/110, loss = 2.0712
# epoch 4 / 50, step 55/110, loss = 2.3045
# epoch 4 / 50, step 56/110, loss = 1.9220
# epoch 4 / 50, step 57/110, loss = 2.2243
# epoch 4 / 50, step 58/110, loss = 2.4257
# epoch 4 / 50, step 59/110, loss = 1.8700
# epoch 4 / 50, step 60/110, loss = 2.4139
# epoch 4 / 50, step 61/110, loss = 2.0586
# epoch 4 / 50, step 62/110, loss = 2.0810
# epoch 4 / 50, step 63/110, loss = 1.8601
# epoch 4 / 50, step 64/110, loss = 1.8565
# epoch 4 / 50, step 65/110, loss = 1.8505
# epoch 4 / 50, step 66/110, loss = 1.9123
# epoch 4 / 50, step 67/110, loss = 2.3459
# epoch 4 / 50, step 68/110, loss = 2.0514
# epoch 4 / 50, step 69/110, loss = 2.0205
# epoch 4 / 50, step 70/110, loss = 2.4749
# epoch 4 / 50, step 71/110, loss = 1.8817
# epoch 4 / 50, step 72/110, loss = 2.2941
# epoch 4 / 50, step 73/110, loss = 1.5041
# epoch 4 / 50, step 74/110, loss = 2.3428
# epoch 4 / 50, step 75/110, loss = 1.8737
# epoch 4 / 50, step 76/110, loss = 2.3483
# epoch 4 / 50, step 77/110, loss = 1.9702
# epoch 4 / 50, step 78/110, loss = 2.0322
# epoch 4 / 50, step 79/110, loss = 2.2897
# epoch 4 / 50, step 80/110, loss = 2.3528
# epoch 4 / 50, step 81/110, loss = 1.8363
# epoch 4 / 50, step 82/110, loss = 2.0975
# epoch 4 / 50, step 83/110, loss = 2.0726
# epoch 4 / 50, step 84/110, loss = 2.5716
# epoch 4 / 50, step 85/110, loss = 2.0083
# epoch 4 / 50, step 86/110, loss = 1.7376
# epoch 4 / 50, step 87/110, loss = 2.1322
# epoch 4 / 50, step 88/110, loss = 2.1101
# epoch 4 / 50, step 89/110, loss = 1.9073
# epoch 4 / 50, step 90/110, loss = 2.3022
# epoch 4 / 50, step 91/110, loss = 2.3221
# epoch 4 / 50, step 92/110, loss = 1.9196
# epoch 4 / 50, step 93/110, loss = 2.3758
# epoch 4 / 50, step 94/110, loss = 2.1572
# epoch 4 / 50, step 95/110, loss = 2.0589
# epoch 4 / 50, step 96/110, loss = 1.9823
# epoch 4 / 50, step 97/110, loss = 1.9659
# epoch 4 / 50, step 98/110, loss = 2.1533
# epoch 4 / 50, step 99/110, loss = 1.8222
# epoch 4 / 50, step 100/110, loss = 2.5476
# epoch 4 / 50, step 101/110, loss = 1.8676
# epoch 4 / 50, step 102/110, loss = 2.0635
# epoch 4 / 50, step 103/110, loss = 2.2747
# epoch 4 / 50, step 104/110, loss = 1.9335
# epoch 4 / 50, step 105/110, loss = 1.7018
# epoch 4 / 50, step 106/110, loss = 2.3198
# epoch 4 / 50, step 107/110, loss = 1.8875
# epoch 4 / 50, step 108/110, loss = 1.9788
# epoch 4 / 50, step 109/110, loss = 2.2846
# epoch 4 / 50, step 110/110, loss = 2.9474
# epoch 4 / 50, step 1/28, loss = 2.0883
# epoch 4 / 50, step 2/28, loss = 2.3700
# epoch 4 / 50, step 3/28, loss = 2.6445
# epoch 4 / 50, step 4/28, loss = 2.0447
# epoch 4 / 50, step 5/28, loss = 2.0002
# epoch 4 / 50, step 6/28, loss = 2.0031
# epoch 4 / 50, step 7/28, loss = 2.0766
# epoch 4 / 50, step 8/28, loss = 2.1690
# epoch 4 / 50, step 9/28, loss = 2.3131
# epoch 4 / 50, step 10/28, loss = 2.2416
# epoch 4 / 50, step 11/28, loss = 2.3992
# epoch 4 / 50, step 12/28, loss = 1.9558
# epoch 4 / 50, step 13/28, loss = 2.5695
# epoch 4 / 50, step 14/28, loss = 2.1108
# epoch 4 / 50, step 15/28, loss = 2.0477
# epoch 4 / 50, step 16/28, loss = 2.1847
# epoch 4 / 50, step 17/28, loss = 2.2689
# epoch 4 / 50, step 18/28, loss = 2.7505
# epoch 4 / 50, step 19/28, loss = 2.3754
# epoch 4 / 50, step 20/28, loss = 1.6381
# epoch 4 / 50, step 21/28, loss = 2.1536
# epoch 4 / 50, step 22/28, loss = 1.9701
# epoch 4 / 50, step 23/28, loss = 2.0822
# epoch 4 / 50, step 24/28, loss = 2.5616
# epoch 4 / 50, step 25/28, loss = 2.7294
# epoch 4 / 50, step 26/28, loss = 2.1758
# epoch 4 / 50, step 27/28, loss = 2.2528
# epoch 4 / 50, step 28/28, loss = 1.9282
# epoch 5 / 50, step 1/110, loss = 2.2518
# epoch 5 / 50, step 2/110, loss = 1.8499
# epoch 5 / 50, step 3/110, loss = 2.3411
# epoch 5 / 50, step 4/110, loss = 1.8970
# epoch 5 / 50, step 5/110, loss = 2.0432
# epoch 5 / 50, step 6/110, loss = 2.0809
# epoch 5 / 50, step 7/110, loss = 1.7742
# epoch 5 / 50, step 8/110, loss = 1.9607
# epoch 5 / 50, step 9/110, loss = 2.4182
# epoch 5 / 50, step 10/110, loss = 1.8131
# epoch 5 / 50, step 11/110, loss = 2.1395
# epoch 5 / 50, step 12/110, loss = 2.3507
# epoch 5 / 50, step 13/110, loss = 1.7176
# epoch 5 / 50, step 14/110, loss = 2.0198
# epoch 5 / 50, step 15/110, loss = 2.2082
# epoch 5 / 50, step 16/110, loss = 1.8986
# epoch 5 / 50, step 17/110, loss = 1.8556
# epoch 5 / 50, step 18/110, loss = 2.3852
# epoch 5 / 50, step 19/110, loss = 2.5114
# epoch 5 / 50, step 20/110, loss = 1.9517
# epoch 5 / 50, step 21/110, loss = 1.8627
# epoch 5 / 50, step 22/110, loss = 2.2883
# epoch 5 / 50, step 23/110, loss = 2.1896
# epoch 5 / 50, step 24/110, loss = 2.5422
# epoch 5 / 50, step 25/110, loss = 1.9624
# epoch 5 / 50, step 26/110, loss = 2.1400
# epoch 5 / 50, step 27/110, loss = 2.1166
# epoch 5 / 50, step 28/110, loss = 2.0556
# epoch 5 / 50, step 29/110, loss = 1.9654
# epoch 5 / 50, step 30/110, loss = 2.1528
# epoch 5 / 50, step 31/110, loss = 1.7922
# epoch 5 / 50, step 32/110, loss = 2.3948
# epoch 5 / 50, step 33/110, loss = 1.8164
# epoch 5 / 50, step 34/110, loss = 1.7528
# epoch 5 / 50, step 35/110, loss = 2.0781
# epoch 5 / 50, step 36/110, loss = 2.3185
# epoch 5 / 50, step 37/110, loss = 2.1632
# epoch 5 / 50, step 38/110, loss = 2.0896
# epoch 5 / 50, step 39/110, loss = 2.2669
# epoch 5 / 50, step 40/110, loss = 2.0314
# epoch 5 / 50, step 41/110, loss = 2.3796
# epoch 5 / 50, step 42/110, loss = 2.2670
# epoch 5 / 50, step 43/110, loss = 1.8931
# epoch 5 / 50, step 44/110, loss = 2.0290
# epoch 5 / 50, step 45/110, loss = 2.3587
# epoch 5 / 50, step 46/110, loss = 2.3390
# epoch 5 / 50, step 47/110, loss = 2.5262
# epoch 5 / 50, step 48/110, loss = 2.6976
# epoch 5 / 50, step 49/110, loss = 1.7797
# epoch 5 / 50, step 50/110, loss = 2.0884
# epoch 5 / 50, step 51/110, loss = 2.7382
# epoch 5 / 50, step 52/110, loss = 2.4304
# epoch 5 / 50, step 53/110, loss = 2.3485
# epoch 5 / 50, step 54/110, loss = 2.2581
# epoch 5 / 50, step 55/110, loss = 2.3868
# epoch 5 / 50, step 56/110, loss = 2.2787
# epoch 5 / 50, step 57/110, loss = 1.9805
# epoch 5 / 50, step 58/110, loss = 2.1400
# epoch 5 / 50, step 59/110, loss = 2.4266
# epoch 5 / 50, step 60/110, loss = 2.0635
# epoch 5 / 50, step 61/110, loss = 2.3664
# epoch 5 / 50, step 62/110, loss = 2.2889
# epoch 5 / 50, step 63/110, loss = 2.0588
# epoch 5 / 50, step 64/110, loss = 1.9331
# epoch 5 / 50, step 65/110, loss = 2.1016
# epoch 5 / 50, step 66/110, loss = 2.3520
# epoch 5 / 50, step 67/110, loss = 1.5284
# epoch 5 / 50, step 68/110, loss = 2.4166
# epoch 5 / 50, step 69/110, loss = 2.0175
# epoch 5 / 50, step 70/110, loss = 2.2229
# epoch 5 / 50, step 71/110, loss = 2.2609
# epoch 5 / 50, step 72/110, loss = 1.8483
# epoch 5 / 50, step 73/110, loss = 2.3741
# epoch 5 / 50, step 74/110, loss = 2.4036
# epoch 5 / 50, step 75/110, loss = 1.9298
# epoch 5 / 50, step 76/110, loss = 2.1508
# epoch 5 / 50, step 77/110, loss = 1.8869
# epoch 5 / 50, step 78/110, loss = 2.0253
# epoch 5 / 50, step 79/110, loss = 2.3569
# epoch 5 / 50, step 80/110, loss = 2.2338
# epoch 5 / 50, step 81/110, loss = 1.8573
# epoch 5 / 50, step 82/110, loss = 2.0351
# epoch 5 / 50, step 83/110, loss = 2.4290
# epoch 5 / 50, step 84/110, loss = 2.7400
# epoch 5 / 50, step 85/110, loss = 1.7713
# epoch 5 / 50, step 86/110, loss = 1.8231
# epoch 5 / 50, step 87/110, loss = 2.2872
# epoch 5 / 50, step 88/110, loss = 1.9983
# epoch 5 / 50, step 89/110, loss = 1.6435
# epoch 5 / 50, step 90/110, loss = 2.1953
# epoch 5 / 50, step 91/110, loss = 2.2235
# epoch 5 / 50, step 92/110, loss = 2.3710
# epoch 5 / 50, step 93/110, loss = 2.2410
# epoch 5 / 50, step 94/110, loss = 2.0374
# epoch 5 / 50, step 95/110, loss = 2.3022
# epoch 5 / 50, step 96/110, loss = 2.1794
# epoch 5 / 50, step 97/110, loss = 2.1408
# epoch 5 / 50, step 98/110, loss = 2.0903
# epoch 5 / 50, step 99/110, loss = 1.9701
# epoch 5 / 50, step 100/110, loss = 2.1493
# epoch 5 / 50, step 101/110, loss = 2.2670
# epoch 5 / 50, step 102/110, loss = 1.9221
# epoch 5 / 50, step 103/110, loss = 2.0601
# epoch 5 / 50, step 104/110, loss = 2.0996
# epoch 5 / 50, step 105/110, loss = 2.0280
# epoch 5 / 50, step 106/110, loss = 1.9404
# epoch 5 / 50, step 107/110, loss = 1.8288
# epoch 5 / 50, step 108/110, loss = 2.1011
# epoch 5 / 50, step 109/110, loss = 1.9852
# epoch 5 / 50, step 110/110, loss = 1.8433
# epoch 5 / 50, step 1/28, loss = 2.1939
# epoch 5 / 50, step 2/28, loss = 2.1716
# epoch 5 / 50, step 3/28, loss = 1.7002
# epoch 5 / 50, step 4/28, loss = 2.3268
# epoch 5 / 50, step 5/28, loss = 2.3031
# epoch 5 / 50, step 6/28, loss = 2.2712
# epoch 5 / 50, step 7/28, loss = 1.7948
# epoch 5 / 50, step 8/28, loss = 1.8936
# epoch 5 / 50, step 9/28, loss = 2.1040
# epoch 5 / 50, step 10/28, loss = 2.0336
# epoch 5 / 50, step 11/28, loss = 1.8421
# epoch 5 / 50, step 12/28, loss = 1.7206
# epoch 5 / 50, step 13/28, loss = 2.0102
# epoch 5 / 50, step 14/28, loss = 2.1079
# epoch 5 / 50, step 15/28, loss = 1.7085
# epoch 5 / 50, step 16/28, loss = 2.3428
# epoch 5 / 50, step 17/28, loss = 2.0636
# epoch 5 / 50, step 18/28, loss = 1.8799
# epoch 5 / 50, step 19/28, loss = 2.3297
# epoch 5 / 50, step 20/28, loss = 1.9383
# epoch 5 / 50, step 21/28, loss = 2.1473
# epoch 5 / 50, step 22/28, loss = 2.3187
# epoch 5 / 50, step 23/28, loss = 2.0918
# epoch 5 / 50, step 24/28, loss = 2.1334
# epoch 5 / 50, step 25/28, loss = 1.9409
# epoch 5 / 50, step 26/28, loss = 2.4447
# epoch 5 / 50, step 27/28, loss = 2.2714
# epoch 5 / 50, step 28/28, loss = 1.7711
# epoch 6 / 50, step 1/110, loss = 1.9351
# epoch 6 / 50, step 2/110, loss = 2.2650
# epoch 6 / 50, step 3/110, loss = 2.3194
# epoch 6 / 50, step 4/110, loss = 2.6629
# epoch 6 / 50, step 5/110, loss = 1.8399
# epoch 6 / 50, step 6/110, loss = 2.1972
# epoch 6 / 50, step 7/110, loss = 1.5603
# epoch 6 / 50, step 8/110, loss = 2.2438
# epoch 6 / 50, step 9/110, loss = 1.9622
# epoch 6 / 50, step 10/110, loss = 2.0247
# epoch 6 / 50, step 11/110, loss = 1.9719
# epoch 6 / 50, step 12/110, loss = 1.9751
# epoch 6 / 50, step 13/110, loss = 2.2451
# epoch 6 / 50, step 14/110, loss = 2.0117
# epoch 6 / 50, step 15/110, loss = 1.9314
# epoch 6 / 50, step 16/110, loss = 2.2454
# epoch 6 / 50, step 17/110, loss = 1.8207
# epoch 6 / 50, step 18/110, loss = 1.8213
# epoch 6 / 50, step 19/110, loss = 2.2407
# epoch 6 / 50, step 20/110, loss = 2.1586
# epoch 6 / 50, step 21/110, loss = 2.0295
# epoch 6 / 50, step 22/110, loss = 2.2374
# epoch 6 / 50, step 23/110, loss = 2.0263
# epoch 6 / 50, step 24/110, loss = 2.4786
# epoch 6 / 50, step 25/110, loss = 2.2266
# epoch 6 / 50, step 26/110, loss = 1.9411
# epoch 6 / 50, step 27/110, loss = 1.8644
# epoch 6 / 50, step 28/110, loss = 2.2549
# epoch 6 / 50, step 29/110, loss = 1.8090
# epoch 6 / 50, step 30/110, loss = 2.2203
# epoch 6 / 50, step 31/110, loss = 1.8158
# epoch 6 / 50, step 32/110, loss = 2.2298
# epoch 6 / 50, step 33/110, loss = 2.3557
# epoch 6 / 50, step 34/110, loss = 2.1860
# epoch 6 / 50, step 35/110, loss = 2.4396
# epoch 6 / 50, step 36/110, loss = 2.0520
# epoch 6 / 50, step 37/110, loss = 1.8305
# epoch 6 / 50, step 38/110, loss = 1.7666
# epoch 6 / 50, step 39/110, loss = 1.8878
# epoch 6 / 50, step 40/110, loss = 1.7046
# epoch 6 / 50, step 41/110, loss = 2.0203
# epoch 6 / 50, step 42/110, loss = 1.9896
# epoch 6 / 50, step 43/110, loss = 1.8676
# epoch 6 / 50, step 44/110, loss = 2.0639
# epoch 6 / 50, step 45/110, loss = 1.8927
# epoch 6 / 50, step 46/110, loss = 1.9449
# epoch 6 / 50, step 47/110, loss = 2.0239
# epoch 6 / 50, step 48/110, loss = 2.2523
# epoch 6 / 50, step 49/110, loss = 1.9382
# epoch 6 / 50, step 50/110, loss = 2.1195
# epoch 6 / 50, step 51/110, loss = 2.1541
# epoch 6 / 50, step 52/110, loss = 1.9431
# epoch 6 / 50, step 53/110, loss = 2.2881
# epoch 6 / 50, step 54/110, loss = 2.0836
# epoch 6 / 50, step 55/110, loss = 2.4339
# epoch 6 / 50, step 56/110, loss = 2.4146
# epoch 6 / 50, step 57/110, loss = 2.0387
# epoch 6 / 50, step 58/110, loss = 2.0921
# epoch 6 / 50, step 59/110, loss = 2.0628
# epoch 6 / 50, step 60/110, loss = 2.2281
# epoch 6 / 50, step 61/110, loss = 1.9851
# epoch 6 / 50, step 62/110, loss = 2.1281
# epoch 6 / 50, step 63/110, loss = 2.1827
# epoch 6 / 50, step 64/110, loss = 1.9376
# epoch 6 / 50, step 65/110, loss = 2.1698
# epoch 6 / 50, step 66/110, loss = 2.2329
# epoch 6 / 50, step 67/110, loss = 2.2967
# epoch 6 / 50, step 68/110, loss = 1.8702
# epoch 6 / 50, step 69/110, loss = 2.1060
# epoch 6 / 50, step 70/110, loss = 2.3788
# epoch 6 / 50, step 71/110, loss = 1.9143
# epoch 6 / 50, step 72/110, loss = 2.2545
# epoch 6 / 50, step 73/110, loss = 1.7320
# epoch 6 / 50, step 74/110, loss = 2.2669
# epoch 6 / 50, step 75/110, loss = 1.9313
# epoch 6 / 50, step 76/110, loss = 1.8079
# epoch 6 / 50, step 77/110, loss = 2.2787
# epoch 6 / 50, step 78/110, loss = 1.9892
# epoch 6 / 50, step 79/110, loss = 1.7773
# epoch 6 / 50, step 80/110, loss = 2.3479
# epoch 6 / 50, step 81/110, loss = 2.0773
# epoch 6 / 50, step 82/110, loss = 1.9245
# epoch 6 / 50, step 83/110, loss = 2.0152
# epoch 6 / 50, step 84/110, loss = 1.8199
# epoch 6 / 50, step 85/110, loss = 2.2051
# epoch 6 / 50, step 86/110, loss = 1.8363
# epoch 6 / 50, step 87/110, loss = 1.9858
# epoch 6 / 50, step 88/110, loss = 2.2889
# epoch 6 / 50, step 89/110, loss = 1.9998
# epoch 6 / 50, step 90/110, loss = 2.2645
# epoch 6 / 50, step 91/110, loss = 2.2259
# epoch 6 / 50, step 92/110, loss = 2.0524
# epoch 6 / 50, step 93/110, loss = 1.9394
# epoch 6 / 50, step 94/110, loss = 2.3173
# epoch 6 / 50, step 95/110, loss = 2.0799
# epoch 6 / 50, step 96/110, loss = 1.7370
# epoch 6 / 50, step 97/110, loss = 2.2281
# epoch 6 / 50, step 98/110, loss = 2.2948
# epoch 6 / 50, step 99/110, loss = 2.2456
# epoch 6 / 50, step 100/110, loss = 2.2452
# epoch 6 / 50, step 101/110, loss = 1.9870
# epoch 6 / 50, step 102/110, loss = 2.1125
# epoch 6 / 50, step 103/110, loss = 2.1430
# epoch 6 / 50, step 104/110, loss = 2.0036
# epoch 6 / 50, step 105/110, loss = 2.2654
# epoch 6 / 50, step 106/110, loss = 2.1309
# epoch 6 / 50, step 107/110, loss = 1.8997
# epoch 6 / 50, step 108/110, loss = 1.5008
# epoch 6 / 50, step 109/110, loss = 1.9281
# epoch 6 / 50, step 110/110, loss = 2.0373
# epoch 6 / 50, step 1/28, loss = 2.1430
# epoch 6 / 50, step 2/28, loss = 2.2101
# epoch 6 / 50, step 3/28, loss = 1.8924
# epoch 6 / 50, step 4/28, loss = 2.1063
# epoch 6 / 50, step 5/28, loss = 2.0620
# epoch 6 / 50, step 6/28, loss = 2.2427
# epoch 6 / 50, step 7/28, loss = 1.7712
# epoch 6 / 50, step 8/28, loss = 1.8678
# epoch 6 / 50, step 9/28, loss = 2.1836
# epoch 6 / 50, step 10/28, loss = 1.8579
# epoch 6 / 50, step 11/28, loss = 1.8883
# epoch 6 / 50, step 12/28, loss = 1.6562
# epoch 6 / 50, step 13/28, loss = 2.1652
# epoch 6 / 50, step 14/28, loss = 1.9238
# epoch 6 / 50, step 15/28, loss = 1.7442
# epoch 6 / 50, step 16/28, loss = 2.3733
# epoch 6 / 50, step 17/28, loss = 2.0555
# epoch 6 / 50, step 18/28, loss = 2.0773
# epoch 6 / 50, step 19/28, loss = 2.2707
# epoch 6 / 50, step 20/28, loss = 1.6584
# epoch 6 / 50, step 21/28, loss = 2.0009
# epoch 6 / 50, step 22/28, loss = 2.1644
# epoch 6 / 50, step 23/28, loss = 1.9119
# epoch 6 / 50, step 24/28, loss = 2.1008
# epoch 6 / 50, step 25/28, loss = 2.0071
# epoch 6 / 50, step 26/28, loss = 2.2731
# epoch 6 / 50, step 27/28, loss = 2.2250
# epoch 6 / 50, step 28/28, loss = 1.6909
# epoch 7 / 50, step 1/110, loss = 1.8124
# epoch 7 / 50, step 2/110, loss = 2.2337
# epoch 7 / 50, step 3/110, loss = 2.2000
# epoch 7 / 50, step 4/110, loss = 2.2114
# epoch 7 / 50, step 5/110, loss = 1.8876
# epoch 7 / 50, step 6/110, loss = 1.6907
# epoch 7 / 50, step 7/110, loss = 2.0225
# epoch 7 / 50, step 8/110, loss = 2.1847
# epoch 7 / 50, step 9/110, loss = 1.4336
# epoch 7 / 50, step 10/110, loss = 2.1231
# epoch 7 / 50, step 11/110, loss = 2.5934
# epoch 7 / 50, step 12/110, loss = 2.1773
# epoch 7 / 50, step 13/110, loss = 2.0387
# epoch 7 / 50, step 14/110, loss = 2.2367
# epoch 7 / 50, step 15/110, loss = 1.9059
# epoch 7 / 50, step 16/110, loss = 1.7926
# epoch 7 / 50, step 17/110, loss = 2.1253
# epoch 7 / 50, step 18/110, loss = 2.5037
# epoch 7 / 50, step 19/110, loss = 2.3059
# epoch 7 / 50, step 20/110, loss = 2.2408
# epoch 7 / 50, step 21/110, loss = 2.0180
# epoch 7 / 50, step 22/110, loss = 2.3392
# epoch 7 / 50, step 23/110, loss = 2.2634
# epoch 7 / 50, step 24/110, loss = 1.8966
# epoch 7 / 50, step 25/110, loss = 1.9829
# epoch 7 / 50, step 26/110, loss = 1.9469
# epoch 7 / 50, step 27/110, loss = 2.0478
# epoch 7 / 50, step 28/110, loss = 2.3496
# epoch 7 / 50, step 29/110, loss = 1.9214
# epoch 7 / 50, step 30/110, loss = 2.0746
# epoch 7 / 50, step 31/110, loss = 2.2310
# epoch 7 / 50, step 32/110, loss = 2.1046
# epoch 7 / 50, step 33/110, loss = 2.1784
# epoch 7 / 50, step 34/110, loss = 2.0202
# epoch 7 / 50, step 35/110, loss = 2.0917
# epoch 7 / 50, step 36/110, loss = 2.2141
# epoch 7 / 50, step 37/110, loss = 1.9526
# epoch 7 / 50, step 38/110, loss = 2.1973
# epoch 7 / 50, step 39/110, loss = 1.7418
# epoch 7 / 50, step 40/110, loss = 2.2261
# epoch 7 / 50, step 41/110, loss = 1.9907
# epoch 7 / 50, step 42/110, loss = 1.9937
# epoch 7 / 50, step 43/110, loss = 2.2310
# epoch 7 / 50, step 44/110, loss = 1.9059
# epoch 7 / 50, step 45/110, loss = 1.9584
# epoch 7 / 50, step 46/110, loss = 2.7461
# epoch 7 / 50, step 47/110, loss = 2.0380
# epoch 7 / 50, step 48/110, loss = 2.4153
# epoch 7 / 50, step 49/110, loss = 2.1823
# epoch 7 / 50, step 50/110, loss = 2.1096
# epoch 7 / 50, step 51/110, loss = 2.0199
# epoch 7 / 50, step 52/110, loss = 2.5565
# epoch 7 / 50, step 53/110, loss = 1.7213
# epoch 7 / 50, step 54/110, loss = 1.7493
# epoch 7 / 50, step 55/110, loss = 2.1556
# epoch 7 / 50, step 56/110, loss = 1.6706
# epoch 7 / 50, step 57/110, loss = 1.8687
# epoch 7 / 50, step 58/110, loss = 1.9476
# epoch 7 / 50, step 59/110, loss = 2.6144
# epoch 7 / 50, step 60/110, loss = 2.2625
# epoch 7 / 50, step 61/110, loss = 2.8821
# epoch 7 / 50, step 62/110, loss = 1.6705
# epoch 7 / 50, step 63/110, loss = 2.4393
# epoch 7 / 50, step 64/110, loss = 1.8977
# epoch 7 / 50, step 65/110, loss = 2.0430
# epoch 7 / 50, step 66/110, loss = 1.8945
# epoch 7 / 50, step 67/110, loss = 2.0494
# epoch 7 / 50, step 68/110, loss = 2.1146
# epoch 7 / 50, step 69/110, loss = 2.6390
# epoch 7 / 50, step 70/110, loss = 2.2800
# epoch 7 / 50, step 71/110, loss = 1.9847
# epoch 7 / 50, step 72/110, loss = 2.5036
# epoch 7 / 50, step 73/110, loss = 2.0675
# epoch 7 / 50, step 74/110, loss = 2.5537
# epoch 7 / 50, step 75/110, loss = 1.7146
# epoch 7 / 50, step 76/110, loss = 2.1402
# epoch 7 / 50, step 77/110, loss = 2.2159
# epoch 7 / 50, step 78/110, loss = 2.1402
# epoch 7 / 50, step 79/110, loss = 2.0006
# epoch 7 / 50, step 80/110, loss = 2.3724
# epoch 7 / 50, step 81/110, loss = 2.2595
# epoch 7 / 50, step 82/110, loss = 1.7825
# epoch 7 / 50, step 83/110, loss = 1.9434
# epoch 7 / 50, step 84/110, loss = 1.9459
# epoch 7 / 50, step 85/110, loss = 2.1842
# epoch 7 / 50, step 86/110, loss = 2.0853
# epoch 7 / 50, step 87/110, loss = 3.0388
# epoch 7 / 50, step 88/110, loss = 2.1395
# epoch 7 / 50, step 89/110, loss = 2.2692
# epoch 7 / 50, step 90/110, loss = 2.0334
# epoch 7 / 50, step 91/110, loss = 1.9475
# epoch 7 / 50, step 92/110, loss = 2.1314
# epoch 7 / 50, step 93/110, loss = 2.2030
# epoch 7 / 50, step 94/110, loss = 2.4144
# epoch 7 / 50, step 95/110, loss = 2.2544
# epoch 7 / 50, step 96/110, loss = 2.0454
# epoch 7 / 50, step 97/110, loss = 1.7735
# epoch 7 / 50, step 98/110, loss = 2.1865
# epoch 7 / 50, step 99/110, loss = 1.8508
# epoch 7 / 50, step 100/110, loss = 2.3866
# epoch 7 / 50, step 101/110, loss = 2.0403
# epoch 7 / 50, step 102/110, loss = 2.3085
# epoch 7 / 50, step 103/110, loss = 2.1119
# epoch 7 / 50, step 104/110, loss = 1.8846
# epoch 7 / 50, step 105/110, loss = 2.4177
# epoch 7 / 50, step 106/110, loss = 2.2799
# epoch 7 / 50, step 107/110, loss = 2.3848
# epoch 7 / 50, step 108/110, loss = 1.8833
# epoch 7 / 50, step 109/110, loss = 2.1116
# epoch 7 / 50, step 110/110, loss = 2.5213
# epoch 7 / 50, step 1/28, loss = 2.1548
# epoch 7 / 50, step 2/28, loss = 2.1970
# epoch 7 / 50, step 3/28, loss = 1.6840
# epoch 7 / 50, step 4/28, loss = 2.1336
# epoch 7 / 50, step 5/28, loss = 2.0729
# epoch 7 / 50, step 6/28, loss = 2.2254
# epoch 7 / 50, step 7/28, loss = 1.8611
# epoch 7 / 50, step 8/28, loss = 1.8605
# epoch 7 / 50, step 9/28, loss = 2.0025
# epoch 7 / 50, step 10/28, loss = 2.1005
# epoch 7 / 50, step 11/28, loss = 2.0047
# epoch 7 / 50, step 12/28, loss = 2.0304
# epoch 7 / 50, step 13/28, loss = 2.0515
# epoch 7 / 50, step 14/28, loss = 1.9358
# epoch 7 / 50, step 15/28, loss = 1.9817
# epoch 7 / 50, step 16/28, loss = 2.1310
# epoch 7 / 50, step 17/28, loss = 2.1281
# epoch 7 / 50, step 18/28, loss = 2.0252
# epoch 7 / 50, step 19/28, loss = 2.1023
# epoch 7 / 50, step 20/28, loss = 1.8703
# epoch 7 / 50, step 21/28, loss = 2.2021
# epoch 7 / 50, step 22/28, loss = 2.1370
# epoch 7 / 50, step 23/28, loss = 2.1003
# epoch 7 / 50, step 24/28, loss = 2.0375
# epoch 7 / 50, step 25/28, loss = 1.9766
# epoch 7 / 50, step 26/28, loss = 2.2795
# epoch 7 / 50, step 27/28, loss = 2.0483
# epoch 7 / 50, step 28/28, loss = 2.0955
# epoch 8 / 50, step 1/110, loss = 1.9784
# epoch 8 / 50, step 2/110, loss = 2.1011
# epoch 8 / 50, step 3/110, loss = 1.8720
# epoch 8 / 50, step 4/110, loss = 1.7896
# epoch 8 / 50, step 5/110, loss = 2.4876
# epoch 8 / 50, step 6/110, loss = 2.2389
# epoch 8 / 50, step 7/110, loss = 2.1857
# epoch 8 / 50, step 8/110, loss = 2.0778
# epoch 8 / 50, step 9/110, loss = 1.9321
# epoch 8 / 50, step 10/110, loss = 1.9376
# epoch 8 / 50, step 11/110, loss = 2.6322
# epoch 8 / 50, step 12/110, loss = 2.2770
# epoch 8 / 50, step 13/110, loss = 2.1435
# epoch 8 / 50, step 14/110, loss = 1.8759
# epoch 8 / 50, step 15/110, loss = 2.1061
# epoch 8 / 50, step 16/110, loss = 2.1257
# epoch 8 / 50, step 17/110, loss = 2.2782
# epoch 8 / 50, step 18/110, loss = 2.1299
# epoch 8 / 50, step 19/110, loss = 2.0044
# epoch 8 / 50, step 20/110, loss = 2.5395
# epoch 8 / 50, step 21/110, loss = 1.8481
# epoch 8 / 50, step 22/110, loss = 2.2497
# epoch 8 / 50, step 23/110, loss = 2.2748
# epoch 8 / 50, step 24/110, loss = 1.8727
# epoch 8 / 50, step 25/110, loss = 1.9359
# epoch 8 / 50, step 26/110, loss = 2.1667
# epoch 8 / 50, step 27/110, loss = 1.9825
# epoch 8 / 50, step 28/110, loss = 2.5619
# epoch 8 / 50, step 29/110, loss = 2.2197
# epoch 8 / 50, step 30/110, loss = 2.0198
# epoch 8 / 50, step 31/110, loss = 2.1215
# epoch 8 / 50, step 32/110, loss = 1.9624
# epoch 8 / 50, step 33/110, loss = 2.0176
# epoch 8 / 50, step 34/110, loss = 2.1500
# epoch 8 / 50, step 35/110, loss = 2.1600
# epoch 8 / 50, step 36/110, loss = 1.9860
# epoch 8 / 50, step 37/110, loss = 2.1462
# epoch 8 / 50, step 38/110, loss = 2.2763
# epoch 8 / 50, step 39/110, loss = 1.6275
# epoch 8 / 50, step 40/110, loss = 2.1582
# epoch 8 / 50, step 41/110, loss = 2.0160
# epoch 8 / 50, step 42/110, loss = 1.8687
# epoch 8 / 50, step 43/110, loss = 2.0900
# epoch 8 / 50, step 44/110, loss = 2.3961
# epoch 8 / 50, step 45/110, loss = 2.2356
# epoch 8 / 50, step 46/110, loss = 2.5427
# epoch 8 / 50, step 47/110, loss = 2.0376
# epoch 8 / 50, step 48/110, loss = 1.7175
# epoch 8 / 50, step 49/110, loss = 2.5542
# epoch 8 / 50, step 50/110, loss = 2.2802
# epoch 8 / 50, step 51/110, loss = 2.0675
# epoch 8 / 50, step 52/110, loss = 2.0243
# epoch 8 / 50, step 53/110, loss = 1.9483
# epoch 8 / 50, step 54/110, loss = 2.5345
# epoch 8 / 50, step 55/110, loss = 2.2530
# epoch 8 / 50, step 56/110, loss = 1.7852
# epoch 8 / 50, step 57/110, loss = 2.1896
# epoch 8 / 50, step 58/110, loss = 1.9414
# epoch 8 / 50, step 59/110, loss = 2.1067
# epoch 8 / 50, step 60/110, loss = 1.8153
# epoch 8 / 50, step 61/110, loss = 1.8868
# epoch 8 / 50, step 62/110, loss = 2.2390
# epoch 8 / 50, step 63/110, loss = 2.1522
# epoch 8 / 50, step 64/110, loss = 2.1817
# epoch 8 / 50, step 65/110, loss = 2.1338
# epoch 8 / 50, step 66/110, loss = 1.9560
# epoch 8 / 50, step 67/110, loss = 1.9215
# epoch 8 / 50, step 68/110, loss = 1.7455
# epoch 8 / 50, step 69/110, loss = 1.8520
# epoch 8 / 50, step 70/110, loss = 2.0115
# epoch 8 / 50, step 71/110, loss = 2.1189
# epoch 8 / 50, step 72/110, loss = 1.8448
# epoch 8 / 50, step 73/110, loss = 1.6286
# epoch 8 / 50, step 74/110, loss = 1.6656
# epoch 8 / 50, step 75/110, loss = 2.0351
# epoch 8 / 50, step 76/110, loss = 1.9709
# epoch 8 / 50, step 77/110, loss = 2.2837
# epoch 8 / 50, step 78/110, loss = 2.1617
# epoch 8 / 50, step 79/110, loss = 1.9448
# epoch 8 / 50, step 80/110, loss = 2.2301
# epoch 8 / 50, step 81/110, loss = 2.0823
# epoch 8 / 50, step 82/110, loss = 1.8104
# epoch 8 / 50, step 83/110, loss = 1.9648
# epoch 8 / 50, step 84/110, loss = 2.1413
# epoch 8 / 50, step 85/110, loss = 2.0455
# epoch 8 / 50, step 86/110, loss = 2.0777
# epoch 8 / 50, step 87/110, loss = 2.2045
# epoch 8 / 50, step 88/110, loss = 2.2923
# epoch 8 / 50, step 89/110, loss = 2.2285
# epoch 8 / 50, step 90/110, loss = 1.9667
# epoch 8 / 50, step 91/110, loss = 2.2084
# epoch 8 / 50, step 92/110, loss = 2.2938
# epoch 8 / 50, step 93/110, loss = 2.1810
# epoch 8 / 50, step 94/110, loss = 2.3762
# epoch 8 / 50, step 95/110, loss = 2.4665
# epoch 8 / 50, step 96/110, loss = 1.9476
# epoch 8 / 50, step 97/110, loss = 2.3596
# epoch 8 / 50, step 98/110, loss = 2.1825
# epoch 8 / 50, step 99/110, loss = 2.3491
# epoch 8 / 50, step 100/110, loss = 2.2207
# epoch 8 / 50, step 101/110, loss = 1.9984
# epoch 8 / 50, step 102/110, loss = 1.9081
# epoch 8 / 50, step 103/110, loss = 1.9089
# epoch 8 / 50, step 104/110, loss = 2.5753
# epoch 8 / 50, step 105/110, loss = 1.9468
# epoch 8 / 50, step 106/110, loss = 2.3171
# epoch 8 / 50, step 107/110, loss = 1.9526
# epoch 8 / 50, step 108/110, loss = 2.4115
# epoch 8 / 50, step 109/110, loss = 2.2543
# epoch 8 / 50, step 110/110, loss = 2.0422
# epoch 8 / 50, step 1/28, loss = 1.9492
# epoch 8 / 50, step 2/28, loss = 1.9588
# epoch 8 / 50, step 3/28, loss = 1.9507
# epoch 8 / 50, step 4/28, loss = 1.9982
# epoch 8 / 50, step 5/28, loss = 2.2320
# epoch 8 / 50, step 6/28, loss = 1.9722
# epoch 8 / 50, step 7/28, loss = 2.0910
# epoch 8 / 50, step 8/28, loss = 2.1870
# epoch 8 / 50, step 9/28, loss = 1.7992
# epoch 8 / 50, step 10/28, loss = 2.1301
# epoch 8 / 50, step 11/28, loss = 1.9087
# epoch 8 / 50, step 12/28, loss = 1.9999
# epoch 8 / 50, step 13/28, loss = 1.8848
# epoch 8 / 50, step 14/28, loss = 2.1430
# epoch 8 / 50, step 15/28, loss = 1.9729
# epoch 8 / 50, step 16/28, loss = 1.8474
# epoch 8 / 50, step 17/28, loss = 1.9799
# epoch 8 / 50, step 18/28, loss = 1.9155
# epoch 8 / 50, step 19/28, loss = 2.1009
# epoch 8 / 50, step 20/28, loss = 2.2524
# epoch 8 / 50, step 21/28, loss = 2.0309
# epoch 8 / 50, step 22/28, loss = 1.9195
# epoch 8 / 50, step 23/28, loss = 2.0753
# epoch 8 / 50, step 24/28, loss = 2.1326
# epoch 8 / 50, step 25/28, loss = 1.9404
# epoch 8 / 50, step 26/28, loss = 2.2970
# epoch 8 / 50, step 27/28, loss = 1.8493
# epoch 8 / 50, step 28/28, loss = 2.0826
# epoch 9 / 50, step 1/110, loss = 1.9863
# epoch 9 / 50, step 2/110, loss = 2.1442
# epoch 9 / 50, step 3/110, loss = 2.1776
# epoch 9 / 50, step 4/110, loss = 2.1460
# epoch 9 / 50, step 5/110, loss = 2.0097
# epoch 9 / 50, step 6/110, loss = 2.2825
# epoch 9 / 50, step 7/110, loss = 2.4611
# epoch 9 / 50, step 8/110, loss = 1.9978
# epoch 9 / 50, step 9/110, loss = 2.3667
# epoch 9 / 50, step 10/110, loss = 2.1226
# epoch 9 / 50, step 11/110, loss = 1.8225
# epoch 9 / 50, step 12/110, loss = 2.0256
# epoch 9 / 50, step 13/110, loss = 2.0347
# epoch 9 / 50, step 14/110, loss = 1.7834
# epoch 9 / 50, step 15/110, loss = 2.0928
# epoch 9 / 50, step 16/110, loss = 2.3055
# epoch 9 / 50, step 17/110, loss = 2.0921
# epoch 9 / 50, step 18/110, loss = 2.0343
# epoch 9 / 50, step 19/110, loss = 1.9927
# epoch 9 / 50, step 20/110, loss = 2.5196
# epoch 9 / 50, step 21/110, loss = 1.8390
# epoch 9 / 50, step 22/110, loss = 2.2894
# epoch 9 / 50, step 23/110, loss = 1.9807
# epoch 9 / 50, step 24/110, loss = 2.0337
# epoch 9 / 50, step 25/110, loss = 2.3450
# epoch 9 / 50, step 26/110, loss = 2.3888
# epoch 9 / 50, step 27/110, loss = 2.0012
# epoch 9 / 50, step 28/110, loss = 1.9043
# epoch 9 / 50, step 29/110, loss = 2.1036
# epoch 9 / 50, step 30/110, loss = 2.1312
# epoch 9 / 50, step 31/110, loss = 1.7766
# epoch 9 / 50, step 32/110, loss = 2.3367
# epoch 9 / 50, step 33/110, loss = 2.1166
# epoch 9 / 50, step 34/110, loss = 2.1412
# epoch 9 / 50, step 35/110, loss = 1.7278
# epoch 9 / 50, step 36/110, loss = 1.7980
# epoch 9 / 50, step 37/110, loss = 2.0735
# epoch 9 / 50, step 38/110, loss = 2.1371
# epoch 9 / 50, step 39/110, loss = 2.3552
# epoch 9 / 50, step 40/110, loss = 2.0906
# epoch 9 / 50, step 41/110, loss = 2.0698
# epoch 9 / 50, step 42/110, loss = 1.8614
# epoch 9 / 50, step 43/110, loss = 2.0228
# epoch 9 / 50, step 44/110, loss = 2.0284
# epoch 9 / 50, step 45/110, loss = 2.2617
# epoch 9 / 50, step 46/110, loss = 2.3592
# epoch 9 / 50, step 47/110, loss = 2.0053
# epoch 9 / 50, step 48/110, loss = 2.2027
# epoch 9 / 50, step 49/110, loss = 2.1028
# epoch 9 / 50, step 50/110, loss = 1.9028
# epoch 9 / 50, step 51/110, loss = 2.2735
# epoch 9 / 50, step 52/110, loss = 1.8641
# epoch 9 / 50, step 53/110, loss = 2.3302
# epoch 9 / 50, step 54/110, loss = 1.6432
# epoch 9 / 50, step 55/110, loss = 1.8732
# epoch 9 / 50, step 56/110, loss = 2.0083
# epoch 9 / 50, step 57/110, loss = 2.0330
# epoch 9 / 50, step 58/110, loss = 2.0943
# epoch 9 / 50, step 59/110, loss = 1.9503
# epoch 9 / 50, step 60/110, loss = 1.8190
# epoch 9 / 50, step 61/110, loss = 1.8516
# epoch 9 / 50, step 62/110, loss = 1.7056
# epoch 9 / 50, step 63/110, loss = 2.0928
# epoch 9 / 50, step 64/110, loss = 2.2792
# epoch 9 / 50, step 65/110, loss = 2.1568
# epoch 9 / 50, step 66/110, loss = 2.2379
# epoch 9 / 50, step 67/110, loss = 2.0623
# epoch 9 / 50, step 68/110, loss = 1.7487
# epoch 9 / 50, step 69/110, loss = 2.6534
# epoch 9 / 50, step 70/110, loss = 1.7754
# epoch 9 / 50, step 71/110, loss = 2.0975
# epoch 9 / 50, step 72/110, loss = 2.1383
# epoch 9 / 50, step 73/110, loss = 2.0581
# ...
# epoch 48 / 50, step 32/110, loss = 2.0582
# epoch 48 / 50, step 33/110, loss = 1.8861
# epoch 48 / 50, step 34/110, loss = 1.6989
# epoch 48 / 50, step 35/110, loss = 1.8320
# epoch 48 / 50, step 36/110, loss = 1.7100
# epoch 48 / 50, step 37/110, loss = 2.0001
# epoch 48 / 50, step 38/110, loss = 2.0384
# epoch 48 / 50, step 39/110, loss = 2.3552
# epoch 48 / 50, step 40/110, loss = 2.1567
# epoch 48 / 50, step 41/110, loss = 2.2249
# epoch 48 / 50, step 42/110, loss = 2.4830
# epoch 48 / 50, step 43/110, loss = 2.0367
# epoch 48 / 50, step 44/110, loss = 1.7811
# epoch 48 / 50, step 45/110, loss = 1.8775
# epoch 48 / 50, step 46/110, loss = 2.0569
# epoch 48 / 50, step 47/110, loss = 2.2980
# epoch 48 / 50, step 48/110, loss = 2.5382
# epoch 48 / 50, step 49/110, loss = 2.1070
# epoch 48 / 50, step 50/110, loss = 2.1165
# epoch 48 / 50, step 51/110, loss = 2.5628
# epoch 48 / 50, step 52/110, loss = 2.1178
# epoch 48 / 50, step 53/110, loss = 1.8723
# epoch 48 / 50, step 54/110, loss = 2.1525
# epoch 48 / 50, step 55/110, loss = 2.1202
# epoch 48 / 50, step 56/110, loss = 2.0481
# epoch 48 / 50, step 57/110, loss = 2.1643
# epoch 48 / 50, step 58/110, loss = 2.1209
# epoch 48 / 50, step 59/110, loss = 2.1784
# epoch 48 / 50, step 60/110, loss = 2.1760
# epoch 48 / 50, step 61/110, loss = 2.0731
# epoch 48 / 50, step 62/110, loss = 1.9466
# epoch 48 / 50, step 63/110, loss = 2.2805
# epoch 48 / 50, step 64/110, loss = 2.3227
# epoch 48 / 50, step 65/110, loss = 1.9259
# epoch 48 / 50, step 66/110, loss = 1.9679
# epoch 48 / 50, step 67/110, loss = 2.0290
# epoch 48 / 50, step 68/110, loss = 2.5499
# epoch 48 / 50, step 69/110, loss = 2.0863
# epoch 48 / 50, step 70/110, loss = 2.2211
# epoch 48 / 50, step 71/110, loss = 2.0734
# epoch 48 / 50, step 72/110, loss = 1.6706
# epoch 48 / 50, step 73/110, loss = 2.3037
# epoch 48 / 50, step 74/110, loss = 1.7499
# epoch 48 / 50, step 75/110, loss = 2.1476
# epoch 48 / 50, step 76/110, loss = 1.8926
# epoch 48 / 50, step 77/110, loss = 2.5118
# epoch 48 / 50, step 78/110, loss = 2.0781
# epoch 48 / 50, step 79/110, loss = 2.0287
# epoch 48 / 50, step 80/110, loss = 1.9062
# epoch 48 / 50, step 81/110, loss = 2.2724
# epoch 48 / 50, step 82/110, loss = 2.0045
# epoch 48 / 50, step 83/110, loss = 1.8647
# epoch 48 / 50, step 84/110, loss = 2.3899
# epoch 48 / 50, step 85/110, loss = 2.1080
# epoch 48 / 50, step 86/110, loss = 2.0995
# epoch 48 / 50, step 87/110, loss = 2.2561
# epoch 48 / 50, step 88/110, loss = 1.9968
# epoch 48 / 50, step 89/110, loss = 2.1943
# epoch 48 / 50, step 90/110, loss = 2.0781
# epoch 48 / 50, step 91/110, loss = 1.8602
# epoch 48 / 50, step 92/110, loss = 2.2045
# epoch 48 / 50, step 93/110, loss = 2.4557
# epoch 48 / 50, step 94/110, loss = 1.8606
# epoch 48 / 50, step 95/110, loss = 2.0435
# epoch 48 / 50, step 96/110, loss = 2.2924
# epoch 48 / 50, step 97/110, loss = 2.3233
# epoch 48 / 50, step 98/110, loss = 1.8693
# epoch 48 / 50, step 99/110, loss = 1.9838
# epoch 48 / 50, step 100/110, loss = 2.1486
# epoch 48 / 50, step 101/110, loss = 2.1264
# epoch 48 / 50, step 102/110, loss = 2.1234
# epoch 48 / 50, step 103/110, loss = 2.3205
# epoch 48 / 50, step 104/110, loss = 1.7034
# epoch 48 / 50, step 105/110, loss = 2.2003
# epoch 48 / 50, step 106/110, loss = 2.0529
# epoch 48 / 50, step 107/110, loss = 2.1974
# epoch 48 / 50, step 108/110, loss = 2.1214
# epoch 48 / 50, step 109/110, loss = 2.3532
# epoch 48 / 50, step 110/110, loss = 2.5194
# epoch 48 / 50, step 1/28, loss = 1.8775
# epoch 48 / 50, step 2/28, loss = 1.9003
# epoch 48 / 50, step 3/28, loss = 1.9587
# epoch 48 / 50, step 4/28, loss = 2.0546
# epoch 48 / 50, step 5/28, loss = 2.1330
# epoch 48 / 50, step 6/28, loss = 1.8243
# epoch 48 / 50, step 7/28, loss = 1.9291
# epoch 48 / 50, step 8/28, loss = 2.1025
# epoch 48 / 50, step 9/28, loss = 1.8658
# epoch 48 / 50, step 10/28, loss = 2.0418
# epoch 48 / 50, step 11/28, loss = 1.8668
# epoch 48 / 50, step 12/28, loss = 1.7175
# epoch 48 / 50, step 13/28, loss = 1.9073
# epoch 48 / 50, step 14/28, loss = 2.1507
# epoch 48 / 50, step 15/28, loss = 1.7135
# epoch 48 / 50, step 16/28, loss = 1.9086
# epoch 48 / 50, step 17/28, loss = 1.8980
# epoch 48 / 50, step 18/28, loss = 1.9278
# epoch 48 / 50, step 19/28, loss = 2.1582
# epoch 48 / 50, step 20/28, loss = 2.0373
# epoch 48 / 50, step 21/28, loss = 1.9443
# epoch 48 / 50, step 22/28, loss = 1.9525
# epoch 48 / 50, step 23/28, loss = 1.9791
# epoch 48 / 50, step 24/28, loss = 2.1419
# epoch 48 / 50, step 25/28, loss = 2.0627
# epoch 48 / 50, step 26/28, loss = 2.2549
# epoch 48 / 50, step 27/28, loss = 1.9673
# epoch 48 / 50, step 28/28, loss = 1.7335
# epoch 49 / 50, step 1/110, loss = 1.9593
# epoch 49 / 50, step 2/110, loss = 1.8636
# epoch 49 / 50, step 3/110, loss = 1.8208
# epoch 49 / 50, step 4/110, loss = 2.0376
# epoch 49 / 50, step 5/110, loss = 2.6903
# epoch 49 / 50, step 6/110, loss = 2.0585
# epoch 49 / 50, step 7/110, loss = 2.0201
# epoch 49 / 50, step 8/110, loss = 2.5768
# epoch 49 / 50, step 9/110, loss = 1.9934
# epoch 49 / 50, step 10/110, loss = 1.8860
# epoch 49 / 50, step 11/110, loss = 2.2199
# epoch 49 / 50, step 12/110, loss = 2.0209
# epoch 49 / 50, step 13/110, loss = 2.2071
# epoch 49 / 50, step 14/110, loss = 1.8048
# epoch 49 / 50, step 15/110, loss = 2.0158
# epoch 49 / 50, step 16/110, loss = 1.9037
# epoch 49 / 50, step 17/110, loss = 1.9126
# epoch 49 / 50, step 18/110, loss = 1.7809
# epoch 49 / 50, step 19/110, loss = 2.2267
# epoch 49 / 50, step 20/110, loss = 2.0062
# epoch 49 / 50, step 21/110, loss = 1.9503
# epoch 49 / 50, step 22/110, loss = 2.0175
# epoch 49 / 50, step 23/110, loss = 1.7664
# epoch 49 / 50, step 24/110, loss = 2.4167
# epoch 49 / 50, step 25/110, loss = 1.8477
# epoch 49 / 50, step 26/110, loss = 1.7118
# epoch 49 / 50, step 27/110, loss = 2.2730
# epoch 49 / 50, step 28/110, loss = 1.9507
# epoch 49 / 50, step 29/110, loss = 1.6672
# epoch 49 / 50, step 30/110, loss = 1.8504
# epoch 49 / 50, step 31/110, loss = 2.1367
# epoch 49 / 50, step 32/110, loss = 2.0067
# epoch 49 / 50, step 33/110, loss = 2.2346
# epoch 49 / 50, step 34/110, loss = 2.1036
# epoch 49 / 50, step 35/110, loss = 2.4871
# epoch 49 / 50, step 36/110, loss = 2.5091
# epoch 49 / 50, step 37/110, loss = 2.2484
# epoch 49 / 50, step 38/110, loss = 2.5071
# epoch 49 / 50, step 39/110, loss = 1.5348
# epoch 49 / 50, step 40/110, loss = 2.1092
# epoch 49 / 50, step 41/110, loss = 1.9155
# epoch 49 / 50, step 42/110, loss = 2.0835
# epoch 49 / 50, step 43/110, loss = 2.0866
# epoch 49 / 50, step 44/110, loss = 1.4907
# epoch 49 / 50, step 45/110, loss = 2.1599
# epoch 49 / 50, step 46/110, loss = 2.0254
# epoch 49 / 50, step 47/110, loss = 2.5070
# epoch 49 / 50, step 48/110, loss = 2.4308
# epoch 49 / 50, step 49/110, loss = 2.0107
# epoch 49 / 50, step 50/110, loss = 2.5252
# epoch 49 / 50, step 51/110, loss = 1.8030
# epoch 49 / 50, step 52/110, loss = 2.4040
# epoch 49 / 50, step 53/110, loss = 1.9699
# epoch 49 / 50, step 54/110, loss = 2.1101
# epoch 49 / 50, step 55/110, loss = 2.0053
# epoch 49 / 50, step 56/110, loss = 2.1694
# epoch 49 / 50, step 57/110, loss = 2.1323
# epoch 49 / 50, step 58/110, loss = 2.0852
# epoch 49 / 50, step 59/110, loss = 2.2125
# epoch 49 / 50, step 60/110, loss = 2.0900
# epoch 49 / 50, step 61/110, loss = 1.8911
# epoch 49 / 50, step 62/110, loss = 2.3584
# epoch 49 / 50, step 63/110, loss = 2.3923
# epoch 49 / 50, step 64/110, loss = 1.9749
# epoch 49 / 50, step 65/110, loss = 2.3609
# epoch 49 / 50, step 66/110, loss = 2.0637
# epoch 49 / 50, step 67/110, loss = 1.8321
# epoch 49 / 50, step 68/110, loss = 2.2407
# epoch 49 / 50, step 69/110, loss = 1.7507
# epoch 49 / 50, step 70/110, loss = 1.7839
# epoch 49 / 50, step 71/110, loss = 2.0075
# epoch 49 / 50, step 72/110, loss = 2.4236
# epoch 49 / 50, step 73/110, loss = 1.7445
# epoch 49 / 50, step 74/110, loss = 2.5316
# epoch 49 / 50, step 75/110, loss = 2.6080
# epoch 49 / 50, step 76/110, loss = 2.0974
# epoch 49 / 50, step 77/110, loss = 1.9432
# epoch 49 / 50, step 78/110, loss = 2.1451
# epoch 49 / 50, step 79/110, loss = 1.9379
# epoch 49 / 50, step 80/110, loss = 2.0473
# epoch 49 / 50, step 81/110, loss = 2.0687
# epoch 49 / 50, step 82/110, loss = 1.9310
# epoch 49 / 50, step 83/110, loss = 2.1343
# epoch 49 / 50, step 84/110, loss = 2.1942
# epoch 49 / 50, step 85/110, loss = 2.2388
# epoch 49 / 50, step 86/110, loss = 2.2367
# epoch 49 / 50, step 87/110, loss = 2.0895
# epoch 49 / 50, step 88/110, loss = 1.7933
# epoch 49 / 50, step 89/110, loss = 2.0013
# epoch 49 / 50, step 90/110, loss = 2.4746
# epoch 49 / 50, step 91/110, loss = 1.8541
# epoch 49 / 50, step 92/110, loss = 1.9826
# epoch 49 / 50, step 93/110, loss = 2.5395
# epoch 49 / 50, step 94/110, loss = 2.0284
# epoch 49 / 50, step 95/110, loss = 1.8511
# epoch 49 / 50, step 96/110, loss = 2.1669
# epoch 49 / 50, step 97/110, loss = 1.7162
# epoch 49 / 50, step 98/110, loss = 2.1376
# epoch 49 / 50, step 99/110, loss = 2.0053
# epoch 49 / 50, step 100/110, loss = 1.8771
# epoch 49 / 50, step 101/110, loss = 2.2558
# epoch 49 / 50, step 102/110, loss = 1.9820
# epoch 49 / 50, step 103/110, loss = 2.0172
# epoch 49 / 50, step 104/110, loss = 2.2367
# epoch 49 / 50, step 105/110, loss = 1.9137
# epoch 49 / 50, step 106/110, loss = 2.0751
# epoch 49 / 50, step 107/110, loss = 2.2474
# epoch 49 / 50, step 108/110, loss = 2.0197
# epoch 49 / 50, step 109/110, loss = 2.1655
# epoch 49 / 50, step 110/110, loss = 1.8749
# epoch 49 / 50, step 1/28, loss = 2.0006
# epoch 49 / 50, step 2/28, loss = 2.0863
# epoch 49 / 50, step 3/28, loss = 1.9899
# epoch 49 / 50, step 4/28, loss = 2.0282
# epoch 49 / 50, step 5/28, loss = 2.1803
# epoch 49 / 50, step 6/28, loss = 2.1091
# epoch 49 / 50, step 7/28, loss = 1.9024
# epoch 49 / 50, step 8/28, loss = 1.9805
# epoch 49 / 50, step 9/28, loss = 1.9323
# epoch 49 / 50, step 10/28, loss = 1.9256
# epoch 49 / 50, step 11/28, loss = 1.8437
# epoch 49 / 50, step 12/28, loss = 1.7895
# epoch 49 / 50, step 13/28, loss = 1.9831
# epoch 49 / 50, step 14/28, loss = 2.0629
# epoch 49 / 50, step 15/28, loss = 1.7960
# epoch 49 / 50, step 16/28, loss = 2.0762
# epoch 49 / 50, step 17/28, loss = 1.9547
# epoch 49 / 50, step 18/28, loss = 1.9372
# epoch 49 / 50, step 19/28, loss = 2.1939
# epoch 49 / 50, step 20/28, loss = 1.8849
# epoch 49 / 50, step 21/28, loss = 1.9494
# epoch 49 / 50, step 22/28, loss = 1.9392
# epoch 49 / 50, step 23/28, loss = 1.9703
# epoch 49 / 50, step 24/28, loss = 2.1621
# epoch 49 / 50, step 25/28, loss = 1.9635
# epoch 49 / 50, step 26/28, loss = 2.2650
# epoch 49 / 50, step 27/28, loss = 1.9830
# epoch 49 / 50, step 28/28, loss = 1.8252
# epoch 50 / 50, step 1/110, loss = 2.3128
# epoch 50 / 50, step 2/110, loss = 2.0873
# epoch 50 / 50, step 3/110, loss = 1.7841
# epoch 50 / 50, step 4/110, loss = 1.8851
# epoch 50 / 50, step 5/110, loss = 1.8952
# epoch 50 / 50, step 6/110, loss = 2.1158
# epoch 50 / 50, step 7/110, loss = 1.7575
# epoch 50 / 50, step 8/110, loss = 2.2228
# epoch 50 / 50, step 9/110, loss = 1.9840
# epoch 50 / 50, step 10/110, loss = 2.0131
# epoch 50 / 50, step 11/110, loss = 2.0134
# epoch 50 / 50, step 12/110, loss = 1.8337
# epoch 50 / 50, step 13/110, loss = 2.0626
# epoch 50 / 50, step 14/110, loss = 2.3331
# epoch 50 / 50, step 15/110, loss = 2.1011
# epoch 50 / 50, step 16/110, loss = 2.1965
# epoch 50 / 50, step 17/110, loss = 2.1490
# epoch 50 / 50, step 18/110, loss = 2.0513
# epoch 50 / 50, step 19/110, loss = 1.7310
# epoch 50 / 50, step 20/110, loss = 2.0058
# epoch 50 / 50, step 21/110, loss = 1.7706
# epoch 50 / 50, step 22/110, loss = 2.1169
# epoch 50 / 50, step 23/110, loss = 2.0621
# epoch 50 / 50, step 24/110, loss = 1.7301
# epoch 50 / 50, step 25/110, loss = 2.0230
# epoch 50 / 50, step 26/110, loss = 2.1548
# epoch 50 / 50, step 27/110, loss = 1.9221
# epoch 50 / 50, step 28/110, loss = 2.0858
# epoch 50 / 50, step 29/110, loss = 2.2088
# epoch 50 / 50, step 30/110, loss = 2.5124
# epoch 50 / 50, step 31/110, loss = 1.8919
# epoch 50 / 50, step 32/110, loss = 1.4142
# epoch 50 / 50, step 33/110, loss = 2.0499
# epoch 50 / 50, step 34/110, loss = 2.1399
# epoch 50 / 50, step 35/110, loss = 1.5964
# epoch 50 / 50, step 36/110, loss = 1.7726
# epoch 50 / 50, step 37/110, loss = 2.0792
# epoch 50 / 50, step 38/110, loss = 2.2480
# epoch 50 / 50, step 39/110, loss = 2.5210
# epoch 50 / 50, step 40/110, loss = 2.1742
# epoch 50 / 50, step 41/110, loss = 2.3442
# epoch 50 / 50, step 42/110, loss = 2.0751
# epoch 50 / 50, step 43/110, loss = 2.3357
# epoch 50 / 50, step 44/110, loss = 2.3122
# epoch 50 / 50, step 45/110, loss = 2.0576
# epoch 50 / 50, step 46/110, loss = 2.2395
# epoch 50 / 50, step 47/110, loss = 1.9603
# epoch 50 / 50, step 48/110, loss = 2.3485
# epoch 50 / 50, step 49/110, loss = 1.9486
# epoch 50 / 50, step 50/110, loss = 2.0707
# epoch 50 / 50, step 51/110, loss = 2.1870
# epoch 50 / 50, step 52/110, loss = 1.9004
# epoch 50 / 50, step 53/110, loss = 2.2261
# epoch 50 / 50, step 54/110, loss = 2.0414
# epoch 50 / 50, step 55/110, loss = 2.2418
# epoch 50 / 50, step 56/110, loss = 1.9800
# epoch 50 / 50, step 57/110, loss = 2.1112
# epoch 50 / 50, step 58/110, loss = 2.1140
# epoch 50 / 50, step 59/110, loss = 1.5927
# epoch 50 / 50, step 60/110, loss = 1.8166
# epoch 50 / 50, step 61/110, loss = 2.2738
# epoch 50 / 50, step 62/110, loss = 2.3598
# epoch 50 / 50, step 63/110, loss = 2.1260
# epoch 50 / 50, step 64/110, loss = 2.1438
# epoch 50 / 50, step 65/110, loss = 2.1989
# epoch 50 / 50, step 66/110, loss = 1.9492
# epoch 50 / 50, step 67/110, loss = 1.8363
# epoch 50 / 50, step 68/110, loss = 1.9104
# epoch 50 / 50, step 69/110, loss = 2.0958
# epoch 50 / 50, step 70/110, loss = 2.0540
# epoch 50 / 50, step 71/110, loss = 2.1775
# epoch 50 / 50, step 72/110, loss = 2.2537
# epoch 50 / 50, step 73/110, loss = 2.0959
# epoch 50 / 50, step 74/110, loss = 2.2804
# epoch 50 / 50, step 75/110, loss = 1.9276
# epoch 50 / 50, step 76/110, loss = 1.8662
# epoch 50 / 50, step 77/110, loss = 1.8774
# epoch 50 / 50, step 78/110, loss = 1.9128
# epoch 50 / 50, step 79/110, loss = 2.2789
# epoch 50 / 50, step 80/110, loss = 2.1688
# epoch 50 / 50, step 81/110, loss = 1.9920
# epoch 50 / 50, step 82/110, loss = 1.9567
# epoch 50 / 50, step 83/110, loss = 2.1069
# epoch 50 / 50, step 84/110, loss = 2.0567
# epoch 50 / 50, step 85/110, loss = 1.8571
# epoch 50 / 50, step 86/110, loss = 2.1909
# epoch 50 / 50, step 87/110, loss = 2.0593
# epoch 50 / 50, step 88/110, loss = 2.2620
# epoch 50 / 50, step 89/110, loss = 2.2856
# epoch 50 / 50, step 90/110, loss = 1.7567
# epoch 50 / 50, step 91/110, loss = 2.6618
# epoch 50 / 50, step 92/110, loss = 2.4627
# epoch 50 / 50, step 93/110, loss = 2.0137
# epoch 50 / 50, step 94/110, loss = 1.9922
# epoch 50 / 50, step 95/110, loss = 1.7787
# epoch 50 / 50, step 96/110, loss = 1.7007
# epoch 50 / 50, step 97/110, loss = 2.1205
# epoch 50 / 50, step 98/110, loss = 2.2465
# epoch 50 / 50, step 99/110, loss = 1.9779
# epoch 50 / 50, step 100/110, loss = 1.7972
# epoch 50 / 50, step 101/110, loss = 2.1654
# epoch 50 / 50, step 102/110, loss = 2.3503
# epoch 50 / 50, step 103/110, loss = 1.9681
# epoch 50 / 50, step 104/110, loss = 2.1178
# epoch 50 / 50, step 105/110, loss = 2.2487
# epoch 50 / 50, step 106/110, loss = 2.3340
# epoch 50 / 50, step 107/110, loss = 2.2714
# epoch 50 / 50, step 108/110, loss = 2.1146
# epoch 50 / 50, step 109/110, loss = 2.2480
# epoch 50 / 50, step 110/110, loss = 2.3308
# epoch 50 / 50, step 1/28, loss = 1.9006
# epoch 50 / 50, step 2/28, loss = 1.9517
# epoch 50 / 50, step 3/28, loss = 2.0480
# epoch 50 / 50, step 4/28, loss = 1.9186
# epoch 50 / 50, step 5/28, loss = 2.0888
# epoch 50 / 50, step 6/28, loss = 1.7655
# epoch 50 / 50, step 7/28, loss = 2.2023
# epoch 50 / 50, step 8/28, loss = 2.2777
# epoch 50 / 50, step 9/28, loss = 1.8098
# epoch 50 / 50, step 10/28, loss = 2.3957
# epoch 50 / 50, step 11/28, loss = 2.1715
# epoch 50 / 50, step 12/28, loss = 2.2113
# epoch 50 / 50, step 13/28, loss = 2.0172
# epoch 50 / 50, step 14/28, loss = 2.1001
# epoch 50 / 50, step 15/28, loss = 2.1773
# epoch 50 / 50, step 16/28, loss = 1.6391
# epoch 50 / 50, step 17/28, loss = 2.1074
# epoch 50 / 50, step 18/28, loss = 2.2241
# epoch 50 / 50, step 19/28, loss = 2.0122
# epoch 50 / 50, step 20/28, loss = 2.2972
# epoch 50 / 50, step 21/28, loss = 2.1769
# epoch 50 / 50, step 22/28, loss = 1.8644
# epoch 50 / 50, step 23/28, loss = 2.1534
# epoch 50 / 50, step 24/28, loss = 2.1965
# epoch 50 / 50, step 25/28, loss = 2.2066
# epoch 50 / 50, step 26/28, loss = 2.1339
# epoch 50 / 50, step 27/28, loss = 1.7872
# epoch 50 / 50, step 28/28, loss = 2.3134

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 14.857142857142858 and the test accuaracy is 13.698630136986301
#  the maximum accuracy of the test was 17.80821917808219 at the epoch 1
#  the maximum accuracy of the train was 17.6 at the epoch 13
# the accuracy of the training at the best validation accuracy 17.80821917808219 is 16.0

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
