# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Increase hidden size from 64 to 128

# %%
filepath = '8 - 50epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5. -496. -352. ... 1040.  912.  640.]
# X[0]: [-496. -352. -192. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 50
batch_size = 16
learning_rate = 0.0001
num_layers = 2

input_size = 512 
sequence_length = 1502  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [-480. -608. -608. ... -224. -320. -288.]
# After normalization X_train[0]: [-480. -608. -608. ... -224. -320. -288.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [-480. -608. -608. ... -224. -320. -288.]
# y_train[0]: 6.0
# X_test[0]: [ 160.   96. -448. ...  288.   32.  192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([-480., -608., -608.,  ..., -224., -320., -288.]), tensor(6))
# (tensor([ 160.,   96., -448.,  ...,  288.,   32.,  192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([16, 769024]) , Labels shape: torch.Size([16])
# Input range after standardization: Min = -1037400.0, Max = 1023000.0
# tensor([-480., -192.,  384.,  ..., -576., -480., -384.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6])

# %%
# Create Model

# Model 
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        # x -> (batch_size, seq, input_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(p=0.5)  # Inside LSTM clas

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0,c0))

        # Dropout on output of LSTM
        out = self.dropout(out)

        # out: batch_size, seq_length, hidden_size
        # out (N, 6008, 128)
        # : all samples in batch, -1 last time step, : all features in hidden size

        out = out[:, -1, :] 
        
        # out (N, 128)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(512, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 2,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/55, loss = 1.9525
# epoch 1 / 50, step 2/55, loss = 1.9571
# epoch 1 / 50, step 3/55, loss = 1.9675
# epoch 1 / 50, step 4/55, loss = 1.9827
# epoch 1 / 50, step 5/55, loss = 1.9466
# epoch 1 / 50, step 6/55, loss = 1.9145
# epoch 1 / 50, step 7/55, loss = 1.9252
# epoch 1 / 50, step 8/55, loss = 1.9584
# epoch 1 / 50, step 9/55, loss = 1.9777
# epoch 1 / 50, step 10/55, loss = 1.9660
# epoch 1 / 50, step 11/55, loss = 1.9496
# epoch 1 / 50, step 12/55, loss = 1.9926
# epoch 1 / 50, step 13/55, loss = 1.9574
# epoch 1 / 50, step 14/55, loss = 1.9115
# epoch 1 / 50, step 15/55, loss = 1.9392
# epoch 1 / 50, step 16/55, loss = 1.9809
# epoch 1 / 50, step 17/55, loss = 1.9723
# epoch 1 / 50, step 18/55, loss = 1.9575
# epoch 1 / 50, step 19/55, loss = 1.9767
# epoch 1 / 50, step 20/55, loss = 1.9358
# epoch 1 / 50, step 21/55, loss = 1.9922
# epoch 1 / 50, step 22/55, loss = 1.9367
# epoch 1 / 50, step 23/55, loss = 1.9499
# epoch 1 / 50, step 24/55, loss = 1.8852
# epoch 1 / 50, step 25/55, loss = 1.9491
# epoch 1 / 50, step 26/55, loss = 1.9731
# epoch 1 / 50, step 27/55, loss = 1.9458
# epoch 1 / 50, step 28/55, loss = 1.9720
# epoch 1 / 50, step 29/55, loss = 1.9602
# epoch 1 / 50, step 30/55, loss = 1.9618
# epoch 1 / 50, step 31/55, loss = 1.9819
# epoch 1 / 50, step 32/55, loss = 1.9371
# epoch 1 / 50, step 33/55, loss = 1.9854
# epoch 1 / 50, step 34/55, loss = 1.9239
# epoch 1 / 50, step 35/55, loss = 1.9824
# epoch 1 / 50, step 36/55, loss = 1.9316
# epoch 1 / 50, step 37/55, loss = 1.9395
# epoch 1 / 50, step 38/55, loss = 1.9799
# epoch 1 / 50, step 39/55, loss = 1.9263
# epoch 1 / 50, step 40/55, loss = 1.9642
# epoch 1 / 50, step 41/55, loss = 1.9566
# epoch 1 / 50, step 42/55, loss = 1.9534
# epoch 1 / 50, step 43/55, loss = 2.0058
# epoch 1 / 50, step 44/55, loss = 1.9547
# epoch 1 / 50, step 45/55, loss = 1.9566
# epoch 1 / 50, step 46/55, loss = 1.9252
# epoch 1 / 50, step 47/55, loss = 1.9815
# epoch 1 / 50, step 48/55, loss = 1.9439
# epoch 1 / 50, step 49/55, loss = 1.9371
# epoch 1 / 50, step 50/55, loss = 1.9407
# epoch 1 / 50, step 51/55, loss = 2.0048
# epoch 1 / 50, step 52/55, loss = 1.9697
# epoch 1 / 50, step 53/55, loss = 1.9504
# epoch 1 / 50, step 54/55, loss = 1.9562
# epoch 1 / 50, step 55/55, loss = 1.9527
# epoch 1 / 50, step 1/14, loss = 1.9250
# epoch 1 / 50, step 2/14, loss = 1.9307
# epoch 1 / 50, step 3/14, loss = 1.9232
# epoch 1 / 50, step 4/14, loss = 1.9595
# epoch 1 / 50, step 5/14, loss = 1.9714
# epoch 1 / 50, step 6/14, loss = 1.9652
# epoch 1 / 50, step 7/14, loss = 1.9152
# epoch 1 / 50, step 8/14, loss = 1.9715
# epoch 1 / 50, step 9/14, loss = 1.9666
# epoch 1 / 50, step 10/14, loss = 1.9575
# epoch 1 / 50, step 11/14, loss = 1.9431
# epoch 1 / 50, step 12/14, loss = 1.9277
# epoch 1 / 50, step 13/14, loss = 1.9201
# epoch 1 / 50, step 14/14, loss = 1.9600
# epoch 2 / 50, step 1/55, loss = 1.9502
# epoch 2 / 50, step 2/55, loss = 1.9606
# epoch 2 / 50, step 3/55, loss = 1.9211
# epoch 2 / 50, step 4/55, loss = 1.9797
# epoch 2 / 50, step 5/55, loss = 1.9052
# epoch 2 / 50, step 6/55, loss = 1.9968
# epoch 2 / 50, step 7/55, loss = 1.9500
# epoch 2 / 50, step 8/55, loss = 1.9420
# epoch 2 / 50, step 9/55, loss = 1.9718
# epoch 2 / 50, step 10/55, loss = 1.9026
# epoch 2 / 50, step 11/55, loss = 1.9395
# epoch 2 / 50, step 12/55, loss = 1.9525
# epoch 2 / 50, step 13/55, loss = 1.9550
# epoch 2 / 50, step 14/55, loss = 1.9524
# epoch 2 / 50, step 15/55, loss = 1.9738
# epoch 2 / 50, step 16/55, loss = 2.0309
# epoch 2 / 50, step 17/55, loss = 1.9724
# epoch 2 / 50, step 18/55, loss = 1.9393
# epoch 2 / 50, step 19/55, loss = 1.9386
# epoch 2 / 50, step 20/55, loss = 1.9458
# epoch 2 / 50, step 21/55, loss = 1.9457
# epoch 2 / 50, step 22/55, loss = 1.9058
# epoch 2 / 50, step 23/55, loss = 1.9067
# epoch 2 / 50, step 24/55, loss = 1.9181
# epoch 2 / 50, step 25/55, loss = 1.9457
# epoch 2 / 50, step 26/55, loss = 1.9547
# epoch 2 / 50, step 27/55, loss = 1.8996
# epoch 2 / 50, step 28/55, loss = 1.9113
# epoch 2 / 50, step 29/55, loss = 1.9293
# epoch 2 / 50, step 30/55, loss = 1.8958
# epoch 2 / 50, step 31/55, loss = 1.9625
# epoch 2 / 50, step 32/55, loss = 1.9664
# epoch 2 / 50, step 33/55, loss = 1.9223
# epoch 2 / 50, step 34/55, loss = 1.9248
# epoch 2 / 50, step 35/55, loss = 1.9216
# epoch 2 / 50, step 36/55, loss = 1.9502
# epoch 2 / 50, step 37/55, loss = 1.9638
# epoch 2 / 50, step 38/55, loss = 1.9310
# epoch 2 / 50, step 39/55, loss = 1.9390
# epoch 2 / 50, step 40/55, loss = 1.9393
# epoch 2 / 50, step 41/55, loss = 1.9458
# epoch 2 / 50, step 42/55, loss = 1.9611
# epoch 2 / 50, step 43/55, loss = 1.9616
# epoch 2 / 50, step 44/55, loss = 1.9021
# epoch 2 / 50, step 45/55, loss = 1.9701
# epoch 2 / 50, step 46/55, loss = 1.9268
# epoch 2 / 50, step 47/55, loss = 1.9599
# epoch 2 / 50, step 48/55, loss = 1.9765
# epoch 2 / 50, step 49/55, loss = 1.9328
# epoch 2 / 50, step 50/55, loss = 1.9412
# epoch 2 / 50, step 51/55, loss = 1.9507
# epoch 2 / 50, step 52/55, loss = 1.9117
# epoch 2 / 50, step 53/55, loss = 1.9445
# epoch 2 / 50, step 54/55, loss = 1.9496
# epoch 2 / 50, step 55/55, loss = 1.9465
# epoch 2 / 50, step 1/14, loss = 1.9206
# epoch 2 / 50, step 2/14, loss = 1.9251
# epoch 2 / 50, step 3/14, loss = 1.9253
# epoch 2 / 50, step 4/14, loss = 1.9615
# epoch 2 / 50, step 5/14, loss = 1.9736
# epoch 2 / 50, step 6/14, loss = 1.9563
# epoch 2 / 50, step 7/14, loss = 1.9137
# epoch 2 / 50, step 8/14, loss = 1.9739
# epoch 2 / 50, step 9/14, loss = 1.9619
# epoch 2 / 50, step 10/14, loss = 1.9561
# epoch 2 / 50, step 11/14, loss = 1.9390
# epoch 2 / 50, step 12/14, loss = 1.9245
# epoch 2 / 50, step 13/14, loss = 1.9209
# epoch 2 / 50, step 14/14, loss = 1.9594
# epoch 3 / 50, step 1/55, loss = 1.9146
# epoch 3 / 50, step 2/55, loss = 1.9191
# epoch 3 / 50, step 3/55, loss = 1.9281
# epoch 3 / 50, step 4/55, loss = 1.9205
# epoch 3 / 50, step 5/55, loss = 1.9125
# epoch 3 / 50, step 6/55, loss = 1.9830
# epoch 3 / 50, step 7/55, loss = 1.9458
# epoch 3 / 50, step 8/55, loss = 1.9357
# epoch 3 / 50, step 9/55, loss = 1.8948
# epoch 3 / 50, step 10/55, loss = 1.9017
# epoch 3 / 50, step 11/55, loss = 1.9630
# epoch 3 / 50, step 12/55, loss = 1.9550
# epoch 3 / 50, step 13/55, loss = 1.9443
# epoch 3 / 50, step 14/55, loss = 1.9711
# epoch 3 / 50, step 15/55, loss = 1.8872
# epoch 3 / 50, step 16/55, loss = 1.9441
# epoch 3 / 50, step 17/55, loss = 1.9430
# epoch 3 / 50, step 18/55, loss = 1.9315
# epoch 3 / 50, step 19/55, loss = 1.8686
# epoch 3 / 50, step 20/55, loss = 1.8805
# epoch 3 / 50, step 21/55, loss = 1.9796
# epoch 3 / 50, step 22/55, loss = 1.9210
# epoch 3 / 50, step 23/55, loss = 1.9382
# epoch 3 / 50, step 24/55, loss = 1.9449
# epoch 3 / 50, step 25/55, loss = 1.9215
# epoch 3 / 50, step 26/55, loss = 1.9595
# epoch 3 / 50, step 27/55, loss = 1.9547
# epoch 3 / 50, step 28/55, loss = 1.9166
# epoch 3 / 50, step 29/55, loss = 1.9531
# epoch 3 / 50, step 30/55, loss = 1.8887
# epoch 3 / 50, step 31/55, loss = 1.9198
# epoch 3 / 50, step 32/55, loss = 1.9807
# epoch 3 / 50, step 33/55, loss = 1.9294
# epoch 3 / 50, step 34/55, loss = 1.9314
# epoch 3 / 50, step 35/55, loss = 1.9292
# epoch 3 / 50, step 36/55, loss = 1.8863
# epoch 3 / 50, step 37/55, loss = 1.9234
# epoch 3 / 50, step 38/55, loss = 1.9036
# epoch 3 / 50, step 39/55, loss = 1.9422
# epoch 3 / 50, step 40/55, loss = 1.9465
# epoch 3 / 50, step 41/55, loss = 1.9222
# epoch 3 / 50, step 42/55, loss = 1.9432
# epoch 3 / 50, step 43/55, loss = 1.9415
# epoch 3 / 50, step 44/55, loss = 1.9646
# epoch 3 / 50, step 45/55, loss = 1.9480
# epoch 3 / 50, step 46/55, loss = 1.8873
# epoch 3 / 50, step 47/55, loss = 1.9325
# epoch 3 / 50, step 48/55, loss = 1.9735
# epoch 3 / 50, step 49/55, loss = 1.8754
# epoch 3 / 50, step 50/55, loss = 1.9462
# epoch 3 / 50, step 51/55, loss = 1.9259
# epoch 3 / 50, step 52/55, loss = 1.9160
# epoch 3 / 50, step 53/55, loss = 1.9434
# epoch 3 / 50, step 54/55, loss = 1.9567
# epoch 3 / 50, step 55/55, loss = 1.9653
# epoch 3 / 50, step 1/14, loss = 1.9245
# epoch 3 / 50, step 2/14, loss = 1.9275
# epoch 3 / 50, step 3/14, loss = 1.9239
# epoch 3 / 50, step 4/14, loss = 1.9616
# epoch 3 / 50, step 5/14, loss = 1.9687
# epoch 3 / 50, step 6/14, loss = 1.9507
# epoch 3 / 50, step 7/14, loss = 1.9136
# epoch 3 / 50, step 8/14, loss = 1.9691
# epoch 3 / 50, step 9/14, loss = 1.9597
# epoch 3 / 50, step 10/14, loss = 1.9568
# epoch 3 / 50, step 11/14, loss = 1.9349
# epoch 3 / 50, step 12/14, loss = 1.9250
# epoch 3 / 50, step 13/14, loss = 1.9228
# epoch 3 / 50, step 14/14, loss = 1.9545
# epoch 4 / 50, step 1/55, loss = 1.9048
# epoch 4 / 50, step 2/55, loss = 1.9268
# epoch 4 / 50, step 3/55, loss = 1.9358
# epoch 4 / 50, step 4/55, loss = 1.9350
# epoch 4 / 50, step 5/55, loss = 1.8906
# epoch 4 / 50, step 6/55, loss = 1.9273
# epoch 4 / 50, step 7/55, loss = 1.9799
# epoch 4 / 50, step 8/55, loss = 1.9350
# epoch 4 / 50, step 9/55, loss = 1.9840
# epoch 4 / 50, step 10/55, loss = 1.9665
# epoch 4 / 50, step 11/55, loss = 1.9582
# epoch 4 / 50, step 12/55, loss = 1.9550
# epoch 4 / 50, step 13/55, loss = 1.9081
# epoch 4 / 50, step 14/55, loss = 1.9967
# epoch 4 / 50, step 15/55, loss = 1.9609
# epoch 4 / 50, step 16/55, loss = 1.9416
# epoch 4 / 50, step 17/55, loss = 1.9089
# epoch 4 / 50, step 18/55, loss = 1.9424
# epoch 4 / 50, step 19/55, loss = 1.8991
# epoch 4 / 50, step 20/55, loss = 1.9231
# epoch 4 / 50, step 21/55, loss = 1.9650
# epoch 4 / 50, step 22/55, loss = 1.9520
# epoch 4 / 50, step 23/55, loss = 1.9205
# epoch 4 / 50, step 24/55, loss = 1.9501
# epoch 4 / 50, step 25/55, loss = 1.9216
# epoch 4 / 50, step 26/55, loss = 1.9100
# epoch 4 / 50, step 27/55, loss = 1.9445
# epoch 4 / 50, step 28/55, loss = 1.9053
# epoch 4 / 50, step 29/55, loss = 1.9221
# epoch 4 / 50, step 30/55, loss = 1.9475
# epoch 4 / 50, step 31/55, loss = 1.9573
# epoch 4 / 50, step 32/55, loss = 1.9376
# epoch 4 / 50, step 33/55, loss = 1.9001
# epoch 4 / 50, step 34/55, loss = 1.9177
# epoch 4 / 50, step 35/55, loss = 1.9038
# epoch 4 / 50, step 36/55, loss = 1.9425
# epoch 4 / 50, step 37/55, loss = 1.9274
# epoch 4 / 50, step 38/55, loss = 1.9072
# epoch 4 / 50, step 39/55, loss = 1.9422
# epoch 4 / 50, step 40/55, loss = 1.9285
# epoch 4 / 50, step 41/55, loss = 1.9438
# epoch 4 / 50, step 42/55, loss = 1.8996
# epoch 4 / 50, step 43/55, loss = 1.9135
# epoch 4 / 50, step 44/55, loss = 1.9599
# epoch 4 / 50, step 45/55, loss = 1.9716
# epoch 4 / 50, step 46/55, loss = 1.9224
# epoch 4 / 50, step 47/55, loss = 1.9458
# epoch 4 / 50, step 48/55, loss = 1.9283
# epoch 4 / 50, step 49/55, loss = 1.9326
# epoch 4 / 50, step 50/55, loss = 1.9443
# epoch 4 / 50, step 51/55, loss = 1.8910
# epoch 4 / 50, step 52/55, loss = 1.9596
# epoch 4 / 50, step 53/55, loss = 1.9267
# epoch 4 / 50, step 54/55, loss = 1.9419
# epoch 4 / 50, step 55/55, loss = 1.9140
# epoch 4 / 50, step 1/14, loss = 1.9247
# epoch 4 / 50, step 2/14, loss = 1.9289
# epoch 4 / 50, step 3/14, loss = 1.9218
# epoch 4 / 50, step 4/14, loss = 1.9598
# epoch 4 / 50, step 5/14, loss = 1.9690
# epoch 4 / 50, step 6/14, loss = 1.9485
# epoch 4 / 50, step 7/14, loss = 1.9131
# epoch 4 / 50, step 8/14, loss = 1.9659
# epoch 4 / 50, step 9/14, loss = 1.9576
# epoch 4 / 50, step 10/14, loss = 1.9553
# epoch 4 / 50, step 11/14, loss = 1.9327
# epoch 4 / 50, step 12/14, loss = 1.9246
# epoch 4 / 50, step 13/14, loss = 1.9223
# epoch 4 / 50, step 14/14, loss = 1.9540
# epoch 5 / 50, step 1/55, loss = 1.9455
# epoch 5 / 50, step 2/55, loss = 1.8962
# epoch 5 / 50, step 3/55, loss = 1.9152
# epoch 5 / 50, step 4/55, loss = 1.9807
# epoch 5 / 50, step 5/55, loss = 1.9504
# epoch 5 / 50, step 6/55, loss = 1.9544
# epoch 5 / 50, step 7/55, loss = 1.9612
# epoch 5 / 50, step 8/55, loss = 1.9122
# epoch 5 / 50, step 9/55, loss = 1.8966
# epoch 5 / 50, step 10/55, loss = 1.9278
# epoch 5 / 50, step 11/55, loss = 1.9424
# epoch 5 / 50, step 12/55, loss = 1.9134
# epoch 5 / 50, step 13/55, loss = 1.9325
# epoch 5 / 50, step 14/55, loss = 1.9014
# epoch 5 / 50, step 15/55, loss = 1.9189
# epoch 5 / 50, step 16/55, loss = 1.8606
# epoch 5 / 50, step 17/55, loss = 1.9483
# epoch 5 / 50, step 18/55, loss = 1.9354
# epoch 5 / 50, step 19/55, loss = 1.9319
# epoch 5 / 50, step 20/55, loss = 1.9172
# epoch 5 / 50, step 21/55, loss = 1.9195
# epoch 5 / 50, step 22/55, loss = 1.9191
# epoch 5 / 50, step 23/55, loss = 1.9619
# epoch 5 / 50, step 24/55, loss = 1.9235
# epoch 5 / 50, step 25/55, loss = 1.9307
# epoch 5 / 50, step 26/55, loss = 1.9323
# epoch 5 / 50, step 27/55, loss = 1.9000
# epoch 5 / 50, step 28/55, loss = 1.9331
# epoch 5 / 50, step 29/55, loss = 1.9670
# epoch 5 / 50, step 30/55, loss = 1.9344
# epoch 5 / 50, step 31/55, loss = 1.9638
# epoch 5 / 50, step 32/55, loss = 1.9467
# epoch 5 / 50, step 33/55, loss = 1.9502
# epoch 5 / 50, step 34/55, loss = 1.9718
# epoch 5 / 50, step 35/55, loss = 1.9046
# epoch 5 / 50, step 36/55, loss = 1.9611
# epoch 5 / 50, step 37/55, loss = 1.9349
# epoch 5 / 50, step 38/55, loss = 1.8934
# epoch 5 / 50, step 39/55, loss = 1.9017
# epoch 5 / 50, step 40/55, loss = 1.8872
# epoch 5 / 50, step 41/55, loss = 1.9662
# epoch 5 / 50, step 42/55, loss = 1.9473
# epoch 5 / 50, step 43/55, loss = 1.9334
# epoch 5 / 50, step 44/55, loss = 1.9378
# epoch 5 / 50, step 45/55, loss = 1.9207
# epoch 5 / 50, step 46/55, loss = 1.8983
# epoch 5 / 50, step 47/55, loss = 1.9550
# epoch 5 / 50, step 48/55, loss = 1.8934
# epoch 5 / 50, step 49/55, loss = 1.9228
# epoch 5 / 50, step 50/55, loss = 1.9111
# epoch 5 / 50, step 51/55, loss = 1.9367
# epoch 5 / 50, step 52/55, loss = 1.9037
# epoch 5 / 50, step 53/55, loss = 1.9167
# epoch 5 / 50, step 54/55, loss = 1.9435
# epoch 5 / 50, step 55/55, loss = 1.9148
# epoch 5 / 50, step 1/14, loss = 1.9222
# epoch 5 / 50, step 2/14, loss = 1.9312
# epoch 5 / 50, step 3/14, loss = 1.9241
# epoch 5 / 50, step 4/14, loss = 1.9610
# epoch 5 / 50, step 5/14, loss = 1.9622
# epoch 5 / 50, step 6/14, loss = 1.9485
# epoch 5 / 50, step 7/14, loss = 1.9151
# epoch 5 / 50, step 8/14, loss = 1.9681
# epoch 5 / 50, step 9/14, loss = 1.9566
# epoch 5 / 50, step 10/14, loss = 1.9546
# epoch 5 / 50, step 11/14, loss = 1.9317
# epoch 5 / 50, step 12/14, loss = 1.9226
# epoch 5 / 50, step 13/14, loss = 1.9236
# epoch 5 / 50, step 14/14, loss = 1.9526
# epoch 6 / 50, step 1/55, loss = 1.9040
# epoch 6 / 50, step 2/55, loss = 1.9357
# epoch 6 / 50, step 3/55, loss = 1.8769
# epoch 6 / 50, step 4/55, loss = 1.9560
# epoch 6 / 50, step 5/55, loss = 1.9184
# epoch 6 / 50, step 6/55, loss = 1.9363
# epoch 6 / 50, step 7/55, loss = 1.9511
# epoch 6 / 50, step 8/55, loss = 1.9187
# epoch 6 / 50, step 9/55, loss = 1.8998
# epoch 6 / 50, step 10/55, loss = 1.8994
# epoch 6 / 50, step 11/55, loss = 1.9496
# epoch 6 / 50, step 12/55, loss = 1.9294
# epoch 6 / 50, step 13/55, loss = 1.8738
# epoch 6 / 50, step 14/55, loss = 1.9401
# epoch 6 / 50, step 15/55, loss = 1.9507
# epoch 6 / 50, step 16/55, loss = 1.9441
# epoch 6 / 50, step 17/55, loss = 1.9140
# epoch 6 / 50, step 18/55, loss = 1.9103
# epoch 6 / 50, step 19/55, loss = 1.9671
# epoch 6 / 50, step 20/55, loss = 1.8853
# epoch 6 / 50, step 21/55, loss = 1.9245
# epoch 6 / 50, step 22/55, loss = 1.9584
# epoch 6 / 50, step 23/55, loss = 1.9054
# epoch 6 / 50, step 24/55, loss = 1.9031
# epoch 6 / 50, step 25/55, loss = 1.9094
# epoch 6 / 50, step 26/55, loss = 1.8746
# epoch 6 / 50, step 27/55, loss = 1.9055
# epoch 6 / 50, step 28/55, loss = 1.9153
# epoch 6 / 50, step 29/55, loss = 1.9524
# epoch 6 / 50, step 30/55, loss = 1.9761
# epoch 6 / 50, step 31/55, loss = 1.9763
# epoch 6 / 50, step 32/55, loss = 1.9234
# epoch 6 / 50, step 33/55, loss = 1.9363
# epoch 6 / 50, step 34/55, loss = 1.9377
# epoch 6 / 50, step 35/55, loss = 1.9044
# epoch 6 / 50, step 36/55, loss = 1.9059
# epoch 6 / 50, step 37/55, loss = 1.8940
# epoch 6 / 50, step 38/55, loss = 1.9151
# epoch 6 / 50, step 39/55, loss = 1.9465
# epoch 6 / 50, step 40/55, loss = 1.9142
# epoch 6 / 50, step 41/55, loss = 1.9195
# epoch 6 / 50, step 42/55, loss = 1.9026
# epoch 6 / 50, step 43/55, loss = 1.9226
# epoch 6 / 50, step 44/55, loss = 1.9374
# epoch 6 / 50, step 45/55, loss = 1.9410
# epoch 6 / 50, step 46/55, loss = 1.9701
# epoch 6 / 50, step 47/55, loss = 1.8661
# epoch 6 / 50, step 48/55, loss = 1.9425
# epoch 6 / 50, step 49/55, loss = 1.9030
# epoch 6 / 50, step 50/55, loss = 1.9384
# epoch 6 / 50, step 51/55, loss = 1.9214
# epoch 6 / 50, step 52/55, loss = 1.9215
# epoch 6 / 50, step 53/55, loss = 1.9042
# epoch 6 / 50, step 54/55, loss = 1.8767
# epoch 6 / 50, step 55/55, loss = 1.9478
# epoch 6 / 50, step 1/14, loss = 1.9209
# epoch 6 / 50, step 2/14, loss = 1.9273
# epoch 6 / 50, step 3/14, loss = 1.9272
# epoch 6 / 50, step 4/14, loss = 1.9586
# epoch 6 / 50, step 5/14, loss = 1.9614
# epoch 6 / 50, step 6/14, loss = 1.9386
# epoch 6 / 50, step 7/14, loss = 1.9200
# epoch 6 / 50, step 8/14, loss = 1.9638
# epoch 6 / 50, step 9/14, loss = 1.9556
# epoch 6 / 50, step 10/14, loss = 1.9499
# epoch 6 / 50, step 11/14, loss = 1.9263
# epoch 6 / 50, step 12/14, loss = 1.9230
# epoch 6 / 50, step 13/14, loss = 1.9224
# epoch 6 / 50, step 14/14, loss = 1.9537
# epoch 7 / 50, step 1/55, loss = 1.9466
# epoch 7 / 50, step 2/55, loss = 1.9332
# epoch 7 / 50, step 3/55, loss = 1.9396
# epoch 7 / 50, step 4/55, loss = 1.9250
# epoch 7 / 50, step 5/55, loss = 1.9292
# epoch 7 / 50, step 6/55, loss = 1.9439
# epoch 7 / 50, step 7/55, loss = 1.9137
# epoch 7 / 50, step 8/55, loss = 1.9308
# epoch 7 / 50, step 9/55, loss = 1.8913
# epoch 7 / 50, step 10/55, loss = 1.9367
# epoch 7 / 50, step 11/55, loss = 1.8889
# epoch 7 / 50, step 12/55, loss = 1.9239
# epoch 7 / 50, step 13/55, loss = 1.9011
# epoch 7 / 50, step 14/55, loss = 1.9343
# epoch 7 / 50, step 15/55, loss = 1.8690
# epoch 7 / 50, step 16/55, loss = 1.9267
# epoch 7 / 50, step 17/55, loss = 1.8864
# epoch 7 / 50, step 18/55, loss = 1.9369
# epoch 7 / 50, step 19/55, loss = 1.9168
# epoch 7 / 50, step 20/55, loss = 1.9000
# epoch 7 / 50, step 21/55, loss = 1.9125
# epoch 7 / 50, step 22/55, loss = 1.8737
# epoch 7 / 50, step 23/55, loss = 1.8892
# epoch 7 / 50, step 24/55, loss = 1.8944
# epoch 7 / 50, step 25/55, loss = 1.9403
# epoch 7 / 50, step 26/55, loss = 1.9057
# epoch 7 / 50, step 27/55, loss = 1.8861
# epoch 7 / 50, step 28/55, loss = 1.9254
# epoch 7 / 50, step 29/55, loss = 1.9321
# epoch 7 / 50, step 30/55, loss = 1.9096
# epoch 7 / 50, step 31/55, loss = 1.9190
# epoch 7 / 50, step 32/55, loss = 1.9225
# epoch 7 / 50, step 33/55, loss = 1.8935
# epoch 7 / 50, step 34/55, loss = 1.9374
# epoch 7 / 50, step 35/55, loss = 1.9266
# epoch 7 / 50, step 36/55, loss = 1.9031
# epoch 7 / 50, step 37/55, loss = 1.8765
# epoch 7 / 50, step 38/55, loss = 1.9539
# epoch 7 / 50, step 39/55, loss = 1.9152
# epoch 7 / 50, step 40/55, loss = 1.9079
# epoch 7 / 50, step 41/55, loss = 1.8865
# epoch 7 / 50, step 42/55, loss = 1.9384
# epoch 7 / 50, step 43/55, loss = 1.9064
# epoch 7 / 50, step 44/55, loss = 1.8983
# epoch 7 / 50, step 45/55, loss = 1.8929
# epoch 7 / 50, step 46/55, loss = 1.9377
# epoch 7 / 50, step 47/55, loss = 1.8857
# epoch 7 / 50, step 48/55, loss = 1.9247
# epoch 7 / 50, step 49/55, loss = 1.9256
# epoch 7 / 50, step 50/55, loss = 1.8912
# epoch 7 / 50, step 51/55, loss = 1.8626
# epoch 7 / 50, step 52/55, loss = 1.8974
# epoch 7 / 50, step 53/55, loss = 1.9173
# epoch 7 / 50, step 54/55, loss = 1.9340
# epoch 7 / 50, step 55/55, loss = 1.9027
# epoch 7 / 50, step 1/14, loss = 1.9245
# epoch 7 / 50, step 2/14, loss = 1.9330
# epoch 7 / 50, step 3/14, loss = 1.9322
# epoch 7 / 50, step 4/14, loss = 1.9536
# epoch 7 / 50, step 5/14, loss = 1.9584
# epoch 7 / 50, step 6/14, loss = 1.9324
# epoch 7 / 50, step 7/14, loss = 1.9197
# epoch 7 / 50, step 8/14, loss = 1.9588
# epoch 7 / 50, step 9/14, loss = 1.9507
# epoch 7 / 50, step 10/14, loss = 1.9505
# epoch 7 / 50, step 11/14, loss = 1.9237
# epoch 7 / 50, step 12/14, loss = 1.9246
# epoch 7 / 50, step 13/14, loss = 1.9203
# epoch 7 / 50, step 14/14, loss = 1.9480
# epoch 8 / 50, step 1/55, loss = 1.9441
# epoch 8 / 50, step 2/55, loss = 1.8784
# epoch 8 / 50, step 3/55, loss = 1.8931
# epoch 8 / 50, step 4/55, loss = 1.9291
# epoch 8 / 50, step 5/55, loss = 1.9127
# epoch 8 / 50, step 6/55, loss = 1.9050
# epoch 8 / 50, step 7/55, loss = 1.8975
# epoch 8 / 50, step 8/55, loss = 1.8996
# epoch 8 / 50, step 9/55, loss = 1.8666
# epoch 8 / 50, step 10/55, loss = 1.9079
# epoch 8 / 50, step 11/55, loss = 1.9276
# epoch 8 / 50, step 12/55, loss = 1.9300
# epoch 8 / 50, step 13/55, loss = 1.8705
# epoch 8 / 50, step 14/55, loss = 1.9294
# epoch 8 / 50, step 15/55, loss = 1.8770
# epoch 8 / 50, step 16/55, loss = 1.9140
# epoch 8 / 50, step 17/55, loss = 1.9414
# epoch 8 / 50, step 18/55, loss = 1.9009
# epoch 8 / 50, step 19/55, loss = 1.9292
# epoch 8 / 50, step 20/55, loss = 1.9460
# epoch 8 / 50, step 21/55, loss = 1.9431
# epoch 8 / 50, step 22/55, loss = 1.9000
# epoch 8 / 50, step 23/55, loss = 1.8734
# epoch 8 / 50, step 24/55, loss = 1.8952
# epoch 8 / 50, step 25/55, loss = 1.9079
# epoch 8 / 50, step 26/55, loss = 1.9316
# epoch 8 / 50, step 27/55, loss = 1.9153
# epoch 8 / 50, step 28/55, loss = 1.9057
# epoch 8 / 50, step 29/55, loss = 1.8728
# epoch 8 / 50, step 30/55, loss = 1.9186
# epoch 8 / 50, step 31/55, loss = 1.8817
# epoch 8 / 50, step 32/55, loss = 1.9169
# epoch 8 / 50, step 33/55, loss = 1.9213
# epoch 8 / 50, step 34/55, loss = 1.9251
# epoch 8 / 50, step 35/55, loss = 1.9216
# epoch 8 / 50, step 36/55, loss = 1.8675
# epoch 8 / 50, step 37/55, loss = 1.8849
# epoch 8 / 50, step 38/55, loss = 1.9055
# epoch 8 / 50, step 39/55, loss = 1.8933
# epoch 8 / 50, step 40/55, loss = 1.9080
# epoch 8 / 50, step 41/55, loss = 1.9257
# epoch 8 / 50, step 42/55, loss = 1.8714
# epoch 8 / 50, step 43/55, loss = 1.9015
# epoch 8 / 50, step 44/55, loss = 1.9260
# epoch 8 / 50, step 45/55, loss = 1.9127
# epoch 8 / 50, step 46/55, loss = 1.8925
# epoch 8 / 50, step 47/55, loss = 1.9687
# epoch 8 / 50, step 48/55, loss = 1.8998
# epoch 8 / 50, step 49/55, loss = 1.8814
# epoch 8 / 50, step 50/55, loss = 1.8706
# epoch 8 / 50, step 51/55, loss = 1.9103
# epoch 8 / 50, step 52/55, loss = 1.9267
# epoch 8 / 50, step 53/55, loss = 1.9261
# epoch 8 / 50, step 54/55, loss = 1.9575
# epoch 8 / 50, step 55/55, loss = 1.9558
# epoch 8 / 50, step 1/14, loss = 1.9250
# epoch 8 / 50, step 2/14, loss = 1.9284
# epoch 8 / 50, step 3/14, loss = 1.9318
# epoch 8 / 50, step 4/14, loss = 1.9530
# epoch 8 / 50, step 5/14, loss = 1.9572
# epoch 8 / 50, step 6/14, loss = 1.9214
# epoch 8 / 50, step 7/14, loss = 1.9201
# epoch 8 / 50, step 8/14, loss = 1.9619
# epoch 8 / 50, step 9/14, loss = 1.9512
# epoch 8 / 50, step 10/14, loss = 1.9506
# epoch 8 / 50, step 11/14, loss = 1.9161
# epoch 8 / 50, step 12/14, loss = 1.9269
# epoch 8 / 50, step 13/14, loss = 1.9162
# epoch 8 / 50, step 14/14, loss = 1.9474
# epoch 9 / 50, step 1/55, loss = 1.9148
# epoch 9 / 50, step 2/55, loss = 1.8863
# epoch 9 / 50, step 3/55, loss = 1.8700
# epoch 9 / 50, step 4/55, loss = 1.8989
# epoch 9 / 50, step 5/55, loss = 1.8934
# epoch 9 / 50, step 6/55, loss = 1.8970
# epoch 9 / 50, step 7/55, loss = 1.8878
# epoch 9 / 50, step 8/55, loss = 1.9115
# epoch 9 / 50, step 9/55, loss = 1.9032
# epoch 9 / 50, step 10/55, loss = 1.9440
# epoch 9 / 50, step 11/55, loss = 1.9545
# epoch 9 / 50, step 12/55, loss = 1.8746
# epoch 9 / 50, step 13/55, loss = 1.8945
# epoch 9 / 50, step 14/55, loss = 1.8943
# epoch 9 / 50, step 15/55, loss = 1.8953
# epoch 9 / 50, step 16/55, loss = 1.9160
# epoch 9 / 50, step 17/55, loss = 1.9410
# epoch 9 / 50, step 18/55, loss = 1.8941
# epoch 9 / 50, step 19/55, loss = 1.9069
# epoch 9 / 50, step 20/55, loss = 1.9279
# epoch 9 / 50, step 21/55, loss = 1.9023
# epoch 9 / 50, step 22/55, loss = 1.9435
# epoch 9 / 50, step 23/55, loss = 1.8625
# epoch 9 / 50, step 24/55, loss = 1.9046
# epoch 9 / 50, step 25/55, loss = 1.9390
# epoch 9 / 50, step 26/55, loss = 1.9275
# epoch 9 / 50, step 27/55, loss = 1.9331
# epoch 9 / 50, step 28/55, loss = 1.9569
# epoch 9 / 50, step 29/55, loss = 1.9022
# epoch 9 / 50, step 30/55, loss = 1.9466
# epoch 9 / 50, step 31/55, loss = 1.8834
# epoch 9 / 50, step 32/55, loss = 1.9048
# epoch 9 / 50, step 33/55, loss = 1.8925
# epoch 9 / 50, step 34/55, loss = 1.8982
# epoch 9 / 50, step 35/55, loss = 1.8616
# epoch 9 / 50, step 36/55, loss = 1.9221
# epoch 9 / 50, step 37/55, loss = 1.8602
# epoch 9 / 50, step 38/55, loss = 1.9062
# epoch 9 / 50, step 39/55, loss = 1.9553
# epoch 9 / 50, step 40/55, loss = 1.8798
# epoch 9 / 50, step 41/55, loss = 1.8940
# epoch 9 / 50, step 42/55, loss = 1.8377
# epoch 9 / 50, step 43/55, loss = 1.9452
# epoch 9 / 50, step 44/55, loss = 1.9112
# epoch 9 / 50, step 45/55, loss = 1.8400
# epoch 9 / 50, step 46/55, loss = 1.9263
# epoch 9 / 50, step 47/55, loss = 1.9146
# epoch 9 / 50, step 48/55, loss = 1.8655
# epoch 9 / 50, step 49/55, loss = 1.8912
# epoch 9 / 50, step 50/55, loss = 1.9016
# epoch 9 / 50, step 51/55, loss = 1.9448
# epoch 9 / 50, step 52/55, loss = 1.9099
# epoch 9 / 50, step 53/55, loss = 1.9465
# epoch 9 / 50, step 54/55, loss = 1.8927
# epoch 9 / 50, step 55/55, loss = 1.9106
# epoch 9 / 50, step 1/14, loss = 1.9228
# epoch 9 / 50, step 2/14, loss = 1.9295
# epoch 9 / 50, step 3/14, loss = 1.9340
# epoch 9 / 50, step 4/14, loss = 1.9561
# epoch 9 / 50, step 5/14, loss = 1.9541
# epoch 9 / 50, step 6/14, loss = 1.9099
# epoch 9 / 50, step 7/14, loss = 1.9213
# epoch 9 / 50, step 8/14, loss = 1.9520
# epoch 9 / 50, step 9/14, loss = 1.9479
# epoch 9 / 50, step 10/14, loss = 1.9446
# epoch 9 / 50, step 11/14, loss = 1.9094
# epoch 9 / 50, step 12/14, loss = 1.9276
# epoch 9 / 50, step 13/14, loss = 1.9190
# epoch 9 / 50, step 14/14, loss = 1.9397
# epoch 10 / 50, step 1/55, loss = 1.8260
# epoch 10 / 50, step 2/55, loss = 1.8769
# epoch 10 / 50, step 3/55, loss = 1.9078
# epoch 10 / 50, step 4/55, loss = 1.8622
# epoch 10 / 50, step 5/55, loss = 1.9038
# epoch 10 / 50, step 6/55, loss = 1.8914
# epoch 10 / 50, step 7/55, loss = 1.8817
# epoch 10 / 50, step 8/55, loss = 1.8468
# epoch 10 / 50, step 9/55, loss = 1.8919
# epoch 10 / 50, step 10/55, loss = 1.9125
# epoch 10 / 50, step 11/55, loss = 1.9290
# epoch 10 / 50, step 12/55, loss = 1.8800
# epoch 10 / 50, step 13/55, loss = 1.9156
# epoch 10 / 50, step 14/55, loss = 1.8723
# epoch 10 / 50, step 15/55, loss = 1.9053
# epoch 10 / 50, step 16/55, loss = 1.9130
# epoch 10 / 50, step 17/55, loss = 1.8738
# epoch 10 / 50, step 18/55, loss = 1.9271
# epoch 10 / 50, step 19/55, loss = 1.8809
# epoch 10 / 50, step 20/55, loss = 1.8995
# epoch 10 / 50, step 21/55, loss = 1.9067
# epoch 10 / 50, step 22/55, loss = 1.9167
# epoch 10 / 50, step 23/55, loss = 1.8262
# epoch 10 / 50, step 24/55, loss = 1.8845
# epoch 10 / 50, step 25/55, loss = 1.9306
# epoch 10 / 50, step 26/55, loss = 1.8543
# epoch 10 / 50, step 27/55, loss = 1.9515
# epoch 10 / 50, step 28/55, loss = 1.8959
# epoch 10 / 50, step 29/55, loss = 1.8760
# epoch 10 / 50, step 30/55, loss = 1.8995
# epoch 10 / 50, step 31/55, loss = 1.8809
# epoch 10 / 50, step 32/55, loss = 1.8993
# epoch 10 / 50, step 33/55, loss = 1.9080
# epoch 10 / 50, step 34/55, loss = 1.8798
# epoch 10 / 50, step 35/55, loss = 1.9370
# epoch 10 / 50, step 36/55, loss = 1.8978
# epoch 10 / 50, step 37/55, loss = 1.9223
# epoch 10 / 50, step 38/55, loss = 1.8836
# epoch 10 / 50, step 39/55, loss = 1.8971
# epoch 10 / 50, step 40/55, loss = 1.8640
# epoch 10 / 50, step 41/55, loss = 1.8670
# epoch 10 / 50, step 42/55, loss = 1.8950
# epoch 10 / 50, step 43/55, loss = 1.8820
# epoch 10 / 50, step 44/55, loss = 1.9031
# epoch 10 / 50, step 45/55, loss = 1.8661
# epoch 10 / 50, step 46/55, loss = 1.8401
# epoch 10 / 50, step 47/55, loss = 1.9098
# epoch 10 / 50, step 48/55, loss = 1.9077
# epoch 10 / 50, step 49/55, loss = 1.9132
# epoch 10 / 50, step 50/55, loss = 1.9350
# epoch 10 / 50, step 51/55, loss = 1.8860
# epoch 10 / 50, step 52/55, loss = 1.9039
# epoch 10 / 50, step 53/55, loss = 1.8699
# epoch 10 / 50, step 54/55, loss = 1.8956
# epoch 10 / 50, step 55/55, loss = 1.9549
# epoch 10 / 50, step 1/14, loss = 1.9252
# epoch 10 / 50, step 2/14, loss = 1.9278
# epoch 10 / 50, step 3/14, loss = 1.9389
# epoch 10 / 50, step 4/14, loss = 1.9554
# epoch 10 / 50, step 5/14, loss = 1.9561
# epoch 10 / 50, step 6/14, loss = 1.9020
# epoch 10 / 50, step 7/14, loss = 1.9219
# epoch 10 / 50, step 8/14, loss = 1.9524
# epoch 10 / 50, step 9/14, loss = 1.9517
# epoch 10 / 50, step 10/14, loss = 1.9438
# epoch 10 / 50, step 11/14, loss = 1.9039
# epoch 10 / 50, step 12/14, loss = 1.9272
# epoch 10 / 50, step 13/14, loss = 1.9164
# epoch 10 / 50, step 14/14, loss = 1.9334
# epoch 11 / 50, step 1/55, loss = 1.9052
# epoch 11 / 50, step 2/55, loss = 1.9071
# epoch 11 / 50, step 3/55, loss = 1.8781
# epoch 11 / 50, step 4/55, loss = 1.9262
# epoch 11 / 50, step 5/55, loss = 1.8655
# epoch 11 / 50, step 6/55, loss = 1.8692
# epoch 11 / 50, step 7/55, loss = 1.9400
# epoch 11 / 50, step 8/55, loss = 1.8592
# epoch 11 / 50, step 9/55, loss = 1.9195
# epoch 11 / 50, step 10/55, loss = 1.9441
# epoch 11 / 50, step 11/55, loss = 1.8778
# epoch 11 / 50, step 12/55, loss = 1.8931
# epoch 11 / 50, step 13/55, loss = 1.8806
# epoch 11 / 50, step 14/55, loss = 1.8831
# epoch 11 / 50, step 15/55, loss = 1.9259
# epoch 11 / 50, step 16/55, loss = 1.8769
# epoch 11 / 50, step 17/55, loss = 1.9178
# epoch 11 / 50, step 18/55, loss = 1.8434
# epoch 11 / 50, step 19/55, loss = 1.8992
# epoch 11 / 50, step 20/55, loss = 1.8943
# epoch 11 / 50, step 21/55, loss = 1.8739
# epoch 11 / 50, step 22/55, loss = 1.9282
# epoch 11 / 50, step 23/55, loss = 1.9248
# epoch 11 / 50, step 24/55, loss = 1.8638
# epoch 11 / 50, step 25/55, loss = 1.8614
# epoch 11 / 50, step 26/55, loss = 1.9046
# epoch 11 / 50, step 27/55, loss = 1.8218
# epoch 11 / 50, step 28/55, loss = 1.8610
# epoch 11 / 50, step 29/55, loss = 1.9542
# epoch 11 / 50, step 30/55, loss = 1.8865
# epoch 11 / 50, step 31/55, loss = 1.9203
# epoch 11 / 50, step 32/55, loss = 1.8952
# epoch 11 / 50, step 33/55, loss = 1.8662
# epoch 11 / 50, step 34/55, loss = 1.8320
# epoch 11 / 50, step 35/55, loss = 1.8807
# epoch 11 / 50, step 36/55, loss = 1.9050
# epoch 11 / 50, step 37/55, loss = 1.9479
# epoch 11 / 50, step 38/55, loss = 1.7772
# epoch 11 / 50, step 39/55, loss = 1.8958
# epoch 11 / 50, step 40/55, loss = 1.8824
# epoch 11 / 50, step 41/55, loss = 1.8417
# epoch 11 / 50, step 42/55, loss = 1.7898
# epoch 11 / 50, step 43/55, loss = 1.8246
# epoch 11 / 50, step 44/55, loss = 1.9143
# epoch 11 / 50, step 45/55, loss = 1.9326
# epoch 11 / 50, step 46/55, loss = 1.8949
# epoch 11 / 50, step 47/55, loss = 1.9655
# epoch 11 / 50, step 48/55, loss = 1.8636
# epoch 11 / 50, step 49/55, loss = 1.8554
# epoch 11 / 50, step 50/55, loss = 1.9103
# epoch 11 / 50, step 51/55, loss = 1.8934
# epoch 11 / 50, step 52/55, loss = 1.8592
# epoch 11 / 50, step 53/55, loss = 1.8677
# epoch 11 / 50, step 54/55, loss = 1.8626
# epoch 11 / 50, step 55/55, loss = 1.8684
# epoch 11 / 50, step 1/14, loss = 1.9245
# epoch 11 / 50, step 2/14, loss = 1.9253
# epoch 11 / 50, step 3/14, loss = 1.9425
# epoch 11 / 50, step 4/14, loss = 1.9517
# epoch 11 / 50, step 5/14, loss = 1.9508
# epoch 11 / 50, step 6/14, loss = 1.8934
# epoch 11 / 50, step 7/14, loss = 1.9267
# epoch 11 / 50, step 8/14, loss = 1.9488
# epoch 11 / 50, step 9/14, loss = 1.9467
# epoch 11 / 50, step 10/14, loss = 1.9444
# epoch 11 / 50, step 11/14, loss = 1.8997
# epoch 11 / 50, step 12/14, loss = 1.9267
# epoch 11 / 50, step 13/14, loss = 1.9194
# epoch 11 / 50, step 14/14, loss = 1.9339
# epoch 12 / 50, step 1/55, loss = 1.8106
# epoch 12 / 50, step 2/55, loss = 1.8787
# epoch 12 / 50, step 3/55, loss = 1.8622
# epoch 12 / 50, step 4/55, loss = 1.8341
# epoch 12 / 50, step 5/55, loss = 1.8376
# epoch 12 / 50, step 6/55, loss = 1.8911
# epoch 12 / 50, step 7/55, loss = 1.8806
# epoch 12 / 50, step 8/55, loss = 1.8605
# epoch 12 / 50, step 9/55, loss = 1.8706
# epoch 12 / 50, step 10/55, loss = 1.9241
# epoch 12 / 50, step 11/55, loss = 1.8442
# epoch 12 / 50, step 12/55, loss = 1.8370
# epoch 12 / 50, step 13/55, loss = 1.8209
# epoch 12 / 50, step 14/55, loss = 1.9199
# epoch 12 / 50, step 15/55, loss = 1.8673
# epoch 12 / 50, step 16/55, loss = 1.8427
# epoch 12 / 50, step 17/55, loss = 1.8335
# epoch 12 / 50, step 18/55, loss = 1.8113
# epoch 12 / 50, step 19/55, loss = 1.8554
# epoch 12 / 50, step 20/55, loss = 1.8762
# epoch 12 / 50, step 21/55, loss = 1.8768
# epoch 12 / 50, step 22/55, loss = 1.8403
# epoch 12 / 50, step 23/55, loss = 1.8923
# epoch 12 / 50, step 24/55, loss = 1.9047
# epoch 12 / 50, step 25/55, loss = 1.9088
# epoch 12 / 50, step 26/55, loss = 1.9046
# epoch 12 / 50, step 27/55, loss = 1.8591
# epoch 12 / 50, step 28/55, loss = 1.9065
# epoch 12 / 50, step 29/55, loss = 1.8593
# epoch 12 / 50, step 30/55, loss = 1.9298
# epoch 12 / 50, step 31/55, loss = 1.8685
# epoch 12 / 50, step 32/55, loss = 1.8928
# epoch 12 / 50, step 33/55, loss = 1.8756
# epoch 12 / 50, step 34/55, loss = 1.8266
# epoch 12 / 50, step 35/55, loss = 1.9240
# epoch 12 / 50, step 36/55, loss = 1.9111
# epoch 12 / 50, step 37/55, loss = 1.9403
# epoch 12 / 50, step 38/55, loss = 1.8449
# epoch 12 / 50, step 39/55, loss = 1.8912
# epoch 12 / 50, step 40/55, loss = 1.8857
# epoch 12 / 50, step 41/55, loss = 1.8673
# epoch 12 / 50, step 42/55, loss = 1.8828
# epoch 12 / 50, step 43/55, loss = 1.9181
# epoch 12 / 50, step 44/55, loss = 1.8664
# epoch 12 / 50, step 45/55, loss = 1.8529
# epoch 12 / 50, step 46/55, loss = 1.8383
# epoch 12 / 50, step 47/55, loss = 1.8502
# epoch 12 / 50, step 48/55, loss = 1.8839
# epoch 12 / 50, step 49/55, loss = 1.8843
# epoch 12 / 50, step 50/55, loss = 1.8933
# epoch 12 / 50, step 51/55, loss = 1.8224
# epoch 12 / 50, step 52/55, loss = 1.8607
# epoch 12 / 50, step 53/55, loss = 1.8790
# epoch 12 / 50, step 54/55, loss = 1.9273
# epoch 12 / 50, step 55/55, loss = 1.8679
# epoch 12 / 50, step 1/14, loss = 1.9178
# epoch 12 / 50, step 2/14, loss = 1.9196
# epoch 12 / 50, step 3/14, loss = 1.9542
# epoch 12 / 50, step 4/14, loss = 1.9512
# epoch 12 / 50, step 5/14, loss = 1.9497
# epoch 12 / 50, step 6/14, loss = 1.8809
# epoch 12 / 50, step 7/14, loss = 1.9275
# epoch 12 / 50, step 8/14, loss = 1.9385
# epoch 12 / 50, step 9/14, loss = 1.9427
# epoch 12 / 50, step 10/14, loss = 1.9416
# epoch 12 / 50, step 11/14, loss = 1.8937
# epoch 12 / 50, step 12/14, loss = 1.9371
# epoch 12 / 50, step 13/14, loss = 1.9176
# epoch 12 / 50, step 14/14, loss = 1.9259
# epoch 13 / 50, step 1/55, loss = 1.8568
# epoch 13 / 50, step 2/55, loss = 1.8905
# epoch 13 / 50, step 3/55, loss = 1.8391
# epoch 13 / 50, step 4/55, loss = 1.8413
# epoch 13 / 50, step 5/55, loss = 1.8185
# epoch 13 / 50, step 6/55, loss = 1.9069
# epoch 13 / 50, step 7/55, loss = 1.8717
# epoch 13 / 50, step 8/55, loss = 1.8945
# epoch 13 / 50, step 9/55, loss = 1.8820
# epoch 13 / 50, step 10/55, loss = 1.8535
# epoch 13 / 50, step 11/55, loss = 1.8512
# epoch 13 / 50, step 12/55, loss = 1.8435
# epoch 13 / 50, step 13/55, loss = 1.8190
# epoch 13 / 50, step 14/55, loss = 1.9090
# epoch 13 / 50, step 15/55, loss = 1.8252
# epoch 13 / 50, step 16/55, loss = 1.8698
# epoch 13 / 50, step 17/55, loss = 1.8815
# epoch 13 / 50, step 18/55, loss = 1.8546
# epoch 13 / 50, step 19/55, loss = 1.8823
# epoch 13 / 50, step 20/55, loss = 1.8517
# epoch 13 / 50, step 21/55, loss = 1.8531
# epoch 13 / 50, step 22/55, loss = 1.9304
# epoch 13 / 50, step 23/55, loss = 1.8677
# epoch 13 / 50, step 24/55, loss = 1.9075
# epoch 13 / 50, step 25/55, loss = 1.8701
# epoch 13 / 50, step 26/55, loss = 1.9133
# epoch 13 / 50, step 27/55, loss = 1.8651
# epoch 13 / 50, step 28/55, loss = 1.8233
# epoch 13 / 50, step 29/55, loss = 1.8647
# epoch 13 / 50, step 30/55, loss = 1.8799
# epoch 13 / 50, step 31/55, loss = 1.7527
# epoch 13 / 50, step 32/55, loss = 1.8820
# epoch 13 / 50, step 33/55, loss = 1.8516
# epoch 13 / 50, step 34/55, loss = 1.9001
# epoch 13 / 50, step 35/55, loss = 1.8584
# epoch 13 / 50, step 36/55, loss = 1.8717
# epoch 13 / 50, step 37/55, loss = 1.8625
# epoch 13 / 50, step 38/55, loss = 1.9391
# epoch 13 / 50, step 39/55, loss = 1.8604
# epoch 13 / 50, step 40/55, loss = 1.8210
# epoch 13 / 50, step 41/55, loss = 1.9673
# epoch 13 / 50, step 42/55, loss = 1.8769
# epoch 13 / 50, step 43/55, loss = 1.8826
# epoch 13 / 50, step 44/55, loss = 1.7560
# epoch 13 / 50, step 45/55, loss = 1.8521
# epoch 13 / 50, step 46/55, loss = 1.7903
# epoch 13 / 50, step 47/55, loss = 1.8351
# epoch 13 / 50, step 48/55, loss = 1.8823
# epoch 13 / 50, step 49/55, loss = 1.9186
# epoch 13 / 50, step 50/55, loss = 1.8972
# epoch 13 / 50, step 51/55, loss = 1.7990
# epoch 13 / 50, step 52/55, loss = 1.8975
# epoch 13 / 50, step 53/55, loss = 1.9252
# epoch 13 / 50, step 54/55, loss = 1.8292
# epoch 13 / 50, step 55/55, loss = 1.9131
# epoch 13 / 50, step 1/14, loss = 1.9160
# epoch 13 / 50, step 2/14, loss = 1.9176
# epoch 13 / 50, step 3/14, loss = 1.9581
# epoch 13 / 50, step 4/14, loss = 1.9496
# epoch 13 / 50, step 5/14, loss = 1.9522
# epoch 13 / 50, step 6/14, loss = 1.8589
# epoch 13 / 50, step 7/14, loss = 1.9336
# epoch 13 / 50, step 8/14, loss = 1.9263
# epoch 13 / 50, step 9/14, loss = 1.9284
# epoch 13 / 50, step 10/14, loss = 1.9457
# epoch 13 / 50, step 11/14, loss = 1.8907
# epoch 13 / 50, step 12/14, loss = 1.9383
# epoch 13 / 50, step 13/14, loss = 1.9250
# epoch 13 / 50, step 14/14, loss = 1.9287
# epoch 14 / 50, step 1/55, loss = 1.8352
# epoch 14 / 50, step 2/55, loss = 1.8592
# epoch 14 / 50, step 3/55, loss = 1.8499
# epoch 14 / 50, step 4/55, loss = 1.8416
# epoch 14 / 50, step 5/55, loss = 1.9159
# epoch 14 / 50, step 6/55, loss = 1.8711
# epoch 14 / 50, step 7/55, loss = 1.8433
# epoch 14 / 50, step 8/55, loss = 1.8180
# epoch 14 / 50, step 9/55, loss = 1.8631
# epoch 14 / 50, step 10/55, loss = 1.8117
# epoch 14 / 50, step 11/55, loss = 1.8798
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 42
#      40 # Backward
#      41 optimizer.zero_grad()
# ---> 42 loss.backward()
#      43 optimizer.step()
#      45 # For Epoch Graph
#
# File c:\Users\Lenovo\anaconda3\envs\pytorch\Lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\Lenovo\anaconda3\envs\pytorch\Lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\Lenovo\anaconda3\envs\pytorch\Lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 81.37142857142857 and the test accuaracy is 30.136986301369863
#  the maximum accuracy of the test was 33.333333333333336 at the epoch 47
#  the maximum accuracy of the train was 81.37142857142857 at the epoch 49
# the accuracy of the training at the best validation accuracy 33.333333333333336 is 79.08571428571429

# %%
# Copy the 
shutil.copyfile('./rnn.ipynb', './' + results_dir + 'rnn.ipynb')
# Out:
# './8 - 50epochNoNormalization/rnn.ipynb'
