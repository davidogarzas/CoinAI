# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - batch size 16 a 8
# - epochs 200 a 100

# %%
filepath = '25 - 100epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 100
batch_size = 8
learning_rate = 0.001
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([8, 769024]) , Labels shape: torch.Size([8])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 100, step 1/110, loss = 2.0003
# epoch 1 / 100, step 2/110, loss = 1.8753
# epoch 1 / 100, step 3/110, loss = 1.9730
# epoch 1 / 100, step 4/110, loss = 2.5224
# epoch 1 / 100, step 5/110, loss = 2.0534
# epoch 1 / 100, step 6/110, loss = 2.1032
# epoch 1 / 100, step 7/110, loss = 1.8610
# epoch 1 / 100, step 8/110, loss = 2.3742
# epoch 1 / 100, step 9/110, loss = 1.7928
# epoch 1 / 100, step 10/110, loss = 2.1317
# epoch 1 / 100, step 11/110, loss = 1.9865
# epoch 1 / 100, step 12/110, loss = 2.1729
# epoch 1 / 100, step 13/110, loss = 2.1107
# epoch 1 / 100, step 14/110, loss = 2.0774
# epoch 1 / 100, step 15/110, loss = 2.2421
# epoch 1 / 100, step 16/110, loss = 1.8434
# epoch 1 / 100, step 17/110, loss = 1.9016
# epoch 1 / 100, step 18/110, loss = 1.5909
# epoch 1 / 100, step 19/110, loss = 2.1776
# epoch 1 / 100, step 20/110, loss = 1.7949
# epoch 1 / 100, step 21/110, loss = 2.1310
# epoch 1 / 100, step 22/110, loss = 2.1696
# epoch 1 / 100, step 23/110, loss = 1.7419
# epoch 1 / 100, step 24/110, loss = 2.0057
# epoch 1 / 100, step 25/110, loss = 2.1707
# epoch 1 / 100, step 26/110, loss = 1.6202
# epoch 1 / 100, step 27/110, loss = 2.2194
# epoch 1 / 100, step 28/110, loss = 2.2935
# epoch 1 / 100, step 29/110, loss = 2.1079
# epoch 1 / 100, step 30/110, loss = 2.2423
# epoch 1 / 100, step 31/110, loss = 2.1290
# epoch 1 / 100, step 32/110, loss = 1.7860
# epoch 1 / 100, step 33/110, loss = 2.2333
# epoch 1 / 100, step 34/110, loss = 2.0584
# epoch 1 / 100, step 35/110, loss = 2.0832
# epoch 1 / 100, step 36/110, loss = 2.3397
# epoch 1 / 100, step 37/110, loss = 2.2209
# epoch 1 / 100, step 38/110, loss = 2.0898
# epoch 1 / 100, step 39/110, loss = 2.0927
# epoch 1 / 100, step 40/110, loss = 2.0947
# epoch 1 / 100, step 41/110, loss = 1.8107
# epoch 1 / 100, step 42/110, loss = 1.9992
# epoch 1 / 100, step 43/110, loss = 1.6987
# epoch 1 / 100, step 44/110, loss = 1.9186
# epoch 1 / 100, step 45/110, loss = 2.3154
# epoch 1 / 100, step 46/110, loss = 2.1527
# epoch 1 / 100, step 47/110, loss = 1.7705
# epoch 1 / 100, step 48/110, loss = 2.1328
# epoch 1 / 100, step 49/110, loss = 2.0401
# epoch 1 / 100, step 50/110, loss = 2.4812
# epoch 1 / 100, step 51/110, loss = 1.9450
# epoch 1 / 100, step 52/110, loss = 2.4388
# epoch 1 / 100, step 53/110, loss = 1.8406
# epoch 1 / 100, step 54/110, loss = 1.6938
# epoch 1 / 100, step 55/110, loss = 1.6807
# epoch 1 / 100, step 56/110, loss = 2.1479
# epoch 1 / 100, step 57/110, loss = 2.1549
# epoch 1 / 100, step 58/110, loss = 1.5325
# epoch 1 / 100, step 59/110, loss = 2.2348
# epoch 1 / 100, step 60/110, loss = 2.2218
# epoch 1 / 100, step 61/110, loss = 2.1155
# epoch 1 / 100, step 62/110, loss = 1.7115
# epoch 1 / 100, step 63/110, loss = 2.2496
# epoch 1 / 100, step 64/110, loss = 1.9811
# epoch 1 / 100, step 65/110, loss = 2.2892
# epoch 1 / 100, step 66/110, loss = 1.8987
# epoch 1 / 100, step 67/110, loss = 2.0514
# epoch 1 / 100, step 68/110, loss = 1.9430
# epoch 1 / 100, step 69/110, loss = 2.1198
# epoch 1 / 100, step 70/110, loss = 2.0042
# epoch 1 / 100, step 71/110, loss = 1.8278
# epoch 1 / 100, step 72/110, loss = 1.9386
# epoch 1 / 100, step 73/110, loss = 1.9566
# epoch 1 / 100, step 74/110, loss = 1.8596
# epoch 1 / 100, step 75/110, loss = 2.3195
# epoch 1 / 100, step 76/110, loss = 2.2718
# epoch 1 / 100, step 77/110, loss = 2.1750
# epoch 1 / 100, step 78/110, loss = 1.9111
# epoch 1 / 100, step 79/110, loss = 2.2288
# epoch 1 / 100, step 80/110, loss = 1.9831
# epoch 1 / 100, step 81/110, loss = 1.9964
# epoch 1 / 100, step 82/110, loss = 1.8553
# epoch 1 / 100, step 83/110, loss = 1.9790
# epoch 1 / 100, step 84/110, loss = 1.8082
# epoch 1 / 100, step 85/110, loss = 2.0744
# epoch 1 / 100, step 86/110, loss = 2.0635
# epoch 1 / 100, step 87/110, loss = 1.8258
# epoch 1 / 100, step 88/110, loss = 1.7419
# epoch 1 / 100, step 89/110, loss = 1.8751
# epoch 1 / 100, step 90/110, loss = 1.9925
# epoch 1 / 100, step 91/110, loss = 2.0885
# epoch 1 / 100, step 92/110, loss = 1.4433
# epoch 1 / 100, step 93/110, loss = 2.0232
# epoch 1 / 100, step 94/110, loss = 2.4807
# epoch 1 / 100, step 95/110, loss = 2.1235
# epoch 1 / 100, step 96/110, loss = 1.6686
# epoch 1 / 100, step 97/110, loss = 2.0829
# epoch 1 / 100, step 98/110, loss = 2.2482
# epoch 1 / 100, step 99/110, loss = 2.0441
# epoch 1 / 100, step 100/110, loss = 2.2430
# epoch 1 / 100, step 101/110, loss = 2.0627
# epoch 1 / 100, step 102/110, loss = 1.8247
# epoch 1 / 100, step 103/110, loss = 2.2742
# epoch 1 / 100, step 104/110, loss = 1.9061
# epoch 1 / 100, step 105/110, loss = 1.7510
# epoch 1 / 100, step 106/110, loss = 1.6107
# epoch 1 / 100, step 107/110, loss = 1.8272
# epoch 1 / 100, step 108/110, loss = 1.9016
# epoch 1 / 100, step 109/110, loss = 2.1034
# epoch 1 / 100, step 110/110, loss = 1.7960
# epoch 1 / 100, step 1/28, loss = 1.9947
# epoch 1 / 100, step 2/28, loss = 2.0015
# epoch 1 / 100, step 3/28, loss = 1.9716
# epoch 1 / 100, step 4/28, loss = 1.8786
# epoch 1 / 100, step 5/28, loss = 2.4145
# epoch 1 / 100, step 6/28, loss = 2.0549
# epoch 1 / 100, step 7/28, loss = 2.1100
# epoch 1 / 100, step 8/28, loss = 2.2404
# epoch 1 / 100, step 9/28, loss = 1.9648
# epoch 1 / 100, step 10/28, loss = 1.9254
# epoch 1 / 100, step 11/28, loss = 1.8443
# epoch 1 / 100, step 12/28, loss = 1.7870
# epoch 1 / 100, step 13/28, loss = 1.9804
# epoch 1 / 100, step 14/28, loss = 2.1034
# epoch 1 / 100, step 15/28, loss = 1.8527
# epoch 1 / 100, step 16/28, loss = 1.9862
# epoch 1 / 100, step 17/28, loss = 1.9472
# epoch 1 / 100, step 18/28, loss = 2.0101
# epoch 1 / 100, step 19/28, loss = 2.2619
# epoch 1 / 100, step 20/28, loss = 2.1708
# epoch 1 / 100, step 21/28, loss = 1.9071
# epoch 1 / 100, step 22/28, loss = 1.9497
# epoch 1 / 100, step 23/28, loss = 1.8992
# epoch 1 / 100, step 24/28, loss = 2.1775
# epoch 1 / 100, step 25/28, loss = 1.8680
# epoch 1 / 100, step 26/28, loss = 2.1631
# epoch 1 / 100, step 27/28, loss = 1.8574
# epoch 1 / 100, step 28/28, loss = 1.9568
# epoch 2 / 100, step 1/110, loss = 1.9416
# epoch 2 / 100, step 2/110, loss = 2.5125
# epoch 2 / 100, step 3/110, loss = 2.3409
# epoch 2 / 100, step 4/110, loss = 1.8077
# epoch 2 / 100, step 5/110, loss = 2.1155
# epoch 2 / 100, step 6/110, loss = 2.0580
# epoch 2 / 100, step 7/110, loss = 2.0555
# epoch 2 / 100, step 8/110, loss = 1.7436
# epoch 2 / 100, step 9/110, loss = 1.7954
# epoch 2 / 100, step 10/110, loss = 1.9061
# epoch 2 / 100, step 11/110, loss = 2.4435
# epoch 2 / 100, step 12/110, loss = 2.2958
# epoch 2 / 100, step 13/110, loss = 1.7617
# epoch 2 / 100, step 14/110, loss = 2.1244
# epoch 2 / 100, step 15/110, loss = 2.1629
# epoch 2 / 100, step 16/110, loss = 2.4654
# epoch 2 / 100, step 17/110, loss = 1.8304
# epoch 2 / 100, step 18/110, loss = 2.2734
# epoch 2 / 100, step 19/110, loss = 1.8170
# epoch 2 / 100, step 20/110, loss = 2.0922
# epoch 2 / 100, step 21/110, loss = 1.9729
# epoch 2 / 100, step 22/110, loss = 1.9030
# epoch 2 / 100, step 23/110, loss = 2.2065
# epoch 2 / 100, step 24/110, loss = 1.8129
# epoch 2 / 100, step 25/110, loss = 2.2031
# epoch 2 / 100, step 26/110, loss = 1.8040
# epoch 2 / 100, step 27/110, loss = 1.9337
# epoch 2 / 100, step 28/110, loss = 2.2977
# epoch 2 / 100, step 29/110, loss = 2.2753
# epoch 2 / 100, step 30/110, loss = 2.2456
# epoch 2 / 100, step 31/110, loss = 1.9548
# epoch 2 / 100, step 32/110, loss = 1.8052
# epoch 2 / 100, step 33/110, loss = 1.9008
# epoch 2 / 100, step 34/110, loss = 1.7596
# epoch 2 / 100, step 35/110, loss = 2.0603
# epoch 2 / 100, step 36/110, loss = 2.0284
# epoch 2 / 100, step 37/110, loss = 2.2094
# epoch 2 / 100, step 38/110, loss = 1.7883
# epoch 2 / 100, step 39/110, loss = 2.0338
# epoch 2 / 100, step 40/110, loss = 2.2439
# epoch 2 / 100, step 41/110, loss = 1.7353
# epoch 2 / 100, step 42/110, loss = 2.1858
# epoch 2 / 100, step 43/110, loss = 1.9931
# epoch 2 / 100, step 44/110, loss = 2.0189
# epoch 2 / 100, step 45/110, loss = 1.8293
# epoch 2 / 100, step 46/110, loss = 2.1618
# epoch 2 / 100, step 47/110, loss = 1.8732
# epoch 2 / 100, step 48/110, loss = 1.8168
# epoch 2 / 100, step 49/110, loss = 2.0319
# epoch 2 / 100, step 50/110, loss = 2.2067
# epoch 2 / 100, step 51/110, loss = 1.9649
# epoch 2 / 100, step 52/110, loss = 2.1359
# epoch 2 / 100, step 53/110, loss = 1.7670
# epoch 2 / 100, step 54/110, loss = 2.2024
# epoch 2 / 100, step 55/110, loss = 1.8430
# epoch 2 / 100, step 56/110, loss = 1.9852
# epoch 2 / 100, step 57/110, loss = 1.7778
# epoch 2 / 100, step 58/110, loss = 2.0305
# epoch 2 / 100, step 59/110, loss = 2.1260
# epoch 2 / 100, step 60/110, loss = 2.3951
# epoch 2 / 100, step 61/110, loss = 1.8148
# epoch 2 / 100, step 62/110, loss = 1.7391
# epoch 2 / 100, step 63/110, loss = 1.9236
# epoch 2 / 100, step 64/110, loss = 1.8417
# epoch 2 / 100, step 65/110, loss = 2.0454
# epoch 2 / 100, step 66/110, loss = 2.0071
# epoch 2 / 100, step 67/110, loss = 2.1922
# epoch 2 / 100, step 68/110, loss = 1.9266
# epoch 2 / 100, step 69/110, loss = 2.4119
# epoch 2 / 100, step 70/110, loss = 2.0788
# epoch 2 / 100, step 71/110, loss = 2.2844
# epoch 2 / 100, step 72/110, loss = 2.0687
# epoch 2 / 100, step 73/110, loss = 1.7658
# epoch 2 / 100, step 74/110, loss = 1.8869
# epoch 2 / 100, step 75/110, loss = 2.0456
# epoch 2 / 100, step 76/110, loss = 2.2233
# epoch 2 / 100, step 77/110, loss = 1.9797
# epoch 2 / 100, step 78/110, loss = 2.2255
# epoch 2 / 100, step 79/110, loss = 1.8356
# epoch 2 / 100, step 80/110, loss = 1.9576
# epoch 2 / 100, step 81/110, loss = 1.9722
# epoch 2 / 100, step 82/110, loss = 2.1677
# epoch 2 / 100, step 83/110, loss = 2.0122
# epoch 2 / 100, step 84/110, loss = 1.8464
# epoch 2 / 100, step 85/110, loss = 1.9758
# epoch 2 / 100, step 86/110, loss = 2.0666
# epoch 2 / 100, step 87/110, loss = 2.0836
# epoch 2 / 100, step 88/110, loss = 1.8565
# epoch 2 / 100, step 89/110, loss = 1.9946
# epoch 2 / 100, step 90/110, loss = 1.9049
# epoch 2 / 100, step 91/110, loss = 1.9756
# epoch 2 / 100, step 92/110, loss = 1.9287
# epoch 2 / 100, step 93/110, loss = 1.8800
# epoch 2 / 100, step 94/110, loss = 2.1969
# epoch 2 / 100, step 95/110, loss = 1.7906
# epoch 2 / 100, step 96/110, loss = 1.8738
# epoch 2 / 100, step 97/110, loss = 1.9939
# epoch 2 / 100, step 98/110, loss = 1.7639
# epoch 2 / 100, step 99/110, loss = 2.1478
# epoch 2 / 100, step 100/110, loss = 1.9018
# epoch 2 / 100, step 101/110, loss = 2.0999
# epoch 2 / 100, step 102/110, loss = 1.6692
# epoch 2 / 100, step 103/110, loss = 2.2356
# epoch 2 / 100, step 104/110, loss = 1.9636
# epoch 2 / 100, step 105/110, loss = 2.0307
# epoch 2 / 100, step 106/110, loss = 1.9089
# epoch 2 / 100, step 107/110, loss = 1.9977
# epoch 2 / 100, step 108/110, loss = 2.1012
# epoch 2 / 100, step 109/110, loss = 1.8996
# epoch 2 / 100, step 110/110, loss = 1.6674
# epoch 2 / 100, step 1/28, loss = 1.9186
# epoch 2 / 100, step 2/28, loss = 1.9539
# epoch 2 / 100, step 3/28, loss = 1.9909
# epoch 2 / 100, step 4/28, loss = 2.0020
# epoch 2 / 100, step 5/28, loss = 2.1528
# epoch 2 / 100, step 6/28, loss = 1.9824
# epoch 2 / 100, step 7/28, loss = 1.9522
# epoch 2 / 100, step 8/28, loss = 2.0588
# epoch 2 / 100, step 9/28, loss = 1.8001
# epoch 2 / 100, step 10/28, loss = 1.8559
# epoch 2 / 100, step 11/28, loss = 1.8243
# epoch 2 / 100, step 12/28, loss = 1.8455
# epoch 2 / 100, step 13/28, loss = 1.8901
# epoch 2 / 100, step 14/28, loss = 2.1009
# epoch 2 / 100, step 15/28, loss = 1.8330
# epoch 2 / 100, step 16/28, loss = 1.9734
# epoch 2 / 100, step 17/28, loss = 1.8969
# epoch 2 / 100, step 18/28, loss = 1.8937
# epoch 2 / 100, step 19/28, loss = 2.0686
# epoch 2 / 100, step 20/28, loss = 2.0509
# epoch 2 / 100, step 21/28, loss = 1.8517
# epoch 2 / 100, step 22/28, loss = 1.9642
# epoch 2 / 100, step 23/28, loss = 1.9364
# epoch 2 / 100, step 24/28, loss = 2.0441
# epoch 2 / 100, step 25/28, loss = 1.9313
# epoch 2 / 100, step 26/28, loss = 2.2050
# epoch 2 / 100, step 27/28, loss = 1.9369
# epoch 2 / 100, step 28/28, loss = 1.8232
# epoch 3 / 100, step 1/110, loss = 2.0128
# epoch 3 / 100, step 2/110, loss = 2.0102
# epoch 3 / 100, step 3/110, loss = 1.8643
# epoch 3 / 100, step 4/110, loss = 1.9081
# epoch 3 / 100, step 5/110, loss = 2.0085
# epoch 3 / 100, step 6/110, loss = 2.0439
# epoch 3 / 100, step 7/110, loss = 2.0008
# epoch 3 / 100, step 8/110, loss = 1.9398
# epoch 3 / 100, step 9/110, loss = 2.0393
# epoch 3 / 100, step 10/110, loss = 1.9400
# epoch 3 / 100, step 11/110, loss = 1.8724
# epoch 3 / 100, step 12/110, loss = 2.3003
# epoch 3 / 100, step 13/110, loss = 1.9463
# epoch 3 / 100, step 14/110, loss = 2.0804
# epoch 3 / 100, step 15/110, loss = 2.0841
# epoch 3 / 100, step 16/110, loss = 1.8548
# epoch 3 / 100, step 17/110, loss = 2.1516
# epoch 3 / 100, step 18/110, loss = 1.8554
# epoch 3 / 100, step 19/110, loss = 2.1037
# epoch 3 / 100, step 20/110, loss = 1.8698
# epoch 3 / 100, step 21/110, loss = 1.7727
# epoch 3 / 100, step 22/110, loss = 1.9497
# epoch 3 / 100, step 23/110, loss = 1.8965
# epoch 3 / 100, step 24/110, loss = 2.3177
# epoch 3 / 100, step 25/110, loss = 1.9583
# epoch 3 / 100, step 26/110, loss = 1.6280
# epoch 3 / 100, step 27/110, loss = 1.9672
# epoch 3 / 100, step 28/110, loss = 1.9230
# epoch 3 / 100, step 29/110, loss = 1.9854
# epoch 3 / 100, step 30/110, loss = 2.1384
# epoch 3 / 100, step 31/110, loss = 1.7042
# epoch 3 / 100, step 32/110, loss = 2.2601
# epoch 3 / 100, step 33/110, loss = 1.8872
# epoch 3 / 100, step 34/110, loss = 1.8220
# epoch 3 / 100, step 35/110, loss = 2.0545
# epoch 3 / 100, step 36/110, loss = 2.4010
# epoch 3 / 100, step 37/110, loss = 2.3730
# epoch 3 / 100, step 38/110, loss = 2.0373
# epoch 3 / 100, step 39/110, loss = 2.0186
# epoch 3 / 100, step 40/110, loss = 1.8086
# epoch 3 / 100, step 41/110, loss = 2.1042
# epoch 3 / 100, step 42/110, loss = 1.7571
# epoch 3 / 100, step 43/110, loss = 1.8008
# epoch 3 / 100, step 44/110, loss = 2.0685
# epoch 3 / 100, step 45/110, loss = 2.0646
# epoch 3 / 100, step 46/110, loss = 2.0974
# epoch 3 / 100, step 47/110, loss = 1.7472
# epoch 3 / 100, step 48/110, loss = 1.7609
# epoch 3 / 100, step 49/110, loss = 1.8169
# epoch 3 / 100, step 50/110, loss = 1.7593
# epoch 3 / 100, step 51/110, loss = 2.0165
# epoch 3 / 100, step 52/110, loss = 2.0712
# epoch 3 / 100, step 53/110, loss = 1.9474
# epoch 3 / 100, step 54/110, loss = 2.4632
# epoch 3 / 100, step 55/110, loss = 2.0051
# epoch 3 / 100, step 56/110, loss = 1.7506
# epoch 3 / 100, step 57/110, loss = 1.6090
# epoch 3 / 100, step 58/110, loss = 1.9544
# epoch 3 / 100, step 59/110, loss = 2.2159
# epoch 3 / 100, step 60/110, loss = 1.9420
# epoch 3 / 100, step 61/110, loss = 1.6511
# epoch 3 / 100, step 62/110, loss = 2.0937
# epoch 3 / 100, step 63/110, loss = 1.9899
# epoch 3 / 100, step 64/110, loss = 1.7948
# epoch 3 / 100, step 65/110, loss = 1.9311
# epoch 3 / 100, step 66/110, loss = 2.0493
# epoch 3 / 100, step 67/110, loss = 2.2163
# epoch 3 / 100, step 68/110, loss = 2.2639
# epoch 3 / 100, step 69/110, loss = 1.9048
# epoch 3 / 100, step 70/110, loss = 2.1128
# epoch 3 / 100, step 71/110, loss = 2.2874
# epoch 3 / 100, step 72/110, loss = 2.1160
# epoch 3 / 100, step 73/110, loss = 2.2534
# epoch 3 / 100, step 74/110, loss = 1.8843
# epoch 3 / 100, step 75/110, loss = 2.0387
# epoch 3 / 100, step 76/110, loss = 1.8718
# epoch 3 / 100, step 77/110, loss = 2.0251
# epoch 3 / 100, step 78/110, loss = 2.1079
# epoch 3 / 100, step 79/110, loss = 1.8119
# epoch 3 / 100, step 80/110, loss = 2.1416
# epoch 3 / 100, step 81/110, loss = 1.8853
# epoch 3 / 100, step 82/110, loss = 2.2279
# epoch 3 / 100, step 83/110, loss = 1.8264
# epoch 3 / 100, step 84/110, loss = 2.0718
# epoch 3 / 100, step 85/110, loss = 1.9564
# epoch 3 / 100, step 86/110, loss = 1.7597
# epoch 3 / 100, step 87/110, loss = 1.8759
# epoch 3 / 100, step 88/110, loss = 1.8242
# epoch 3 / 100, step 89/110, loss = 2.0179
# epoch 3 / 100, step 90/110, loss = 1.9348
# epoch 3 / 100, step 91/110, loss = 2.2618
# epoch 3 / 100, step 92/110, loss = 2.2337
# epoch 3 / 100, step 93/110, loss = 2.1432
# epoch 3 / 100, step 94/110, loss = 2.1933
# epoch 3 / 100, step 95/110, loss = 2.2227
# epoch 3 / 100, step 96/110, loss = 2.0269
# epoch 3 / 100, step 97/110, loss = 2.1010
# epoch 3 / 100, step 98/110, loss = 2.1303
# epoch 3 / 100, step 99/110, loss = 2.1793
# epoch 3 / 100, step 100/110, loss = 2.1142
# epoch 3 / 100, step 101/110, loss = 1.6753
# epoch 3 / 100, step 102/110, loss = 2.0814
# epoch 3 / 100, step 103/110, loss = 2.1943
# epoch 3 / 100, step 104/110, loss = 1.7381
# epoch 3 / 100, step 105/110, loss = 2.3724
# epoch 3 / 100, step 106/110, loss = 1.7061
# epoch 3 / 100, step 107/110, loss = 1.9744
# epoch 3 / 100, step 108/110, loss = 2.2039
# epoch 3 / 100, step 109/110, loss = 1.7423
# epoch 3 / 100, step 110/110, loss = 2.8675
# epoch 3 / 100, step 1/28, loss = 1.9819
# epoch 3 / 100, step 2/28, loss = 2.1050
# epoch 3 / 100, step 3/28, loss = 2.3506
# epoch 3 / 100, step 4/28, loss = 2.2481
# epoch 3 / 100, step 5/28, loss = 2.0448
# epoch 3 / 100, step 6/28, loss = 2.0660
# epoch 3 / 100, step 7/28, loss = 2.0339
# epoch 3 / 100, step 8/28, loss = 2.0247
# epoch 3 / 100, step 9/28, loss = 1.8967
# epoch 3 / 100, step 10/28, loss = 1.8154
# epoch 3 / 100, step 11/28, loss = 2.0018
# epoch 3 / 100, step 12/28, loss = 2.0122
# epoch 3 / 100, step 13/28, loss = 1.9599
# epoch 3 / 100, step 14/28, loss = 2.3771
# epoch 3 / 100, step 15/28, loss = 1.8525
# epoch 3 / 100, step 16/28, loss = 2.0989
# epoch 3 / 100, step 17/28, loss = 1.8615
# epoch 3 / 100, step 18/28, loss = 1.9161
# epoch 3 / 100, step 19/28, loss = 2.1326
# epoch 3 / 100, step 20/28, loss = 1.8703
# epoch 3 / 100, step 21/28, loss = 1.9353
# epoch 3 / 100, step 22/28, loss = 1.8684
# epoch 3 / 100, step 23/28, loss = 2.0412
# epoch 3 / 100, step 24/28, loss = 2.1922
# epoch 3 / 100, step 25/28, loss = 2.2733
# epoch 3 / 100, step 26/28, loss = 2.3797
# epoch 3 / 100, step 27/28, loss = 1.9772
# epoch 3 / 100, step 28/28, loss = 1.7618
# epoch 4 / 100, step 1/110, loss = 2.1386
# epoch 4 / 100, step 2/110, loss = 2.3240
# epoch 4 / 100, step 3/110, loss = 1.6156
# epoch 4 / 100, step 4/110, loss = 1.8945
# epoch 4 / 100, step 5/110, loss = 1.8836
# epoch 4 / 100, step 6/110, loss = 2.0036
# epoch 4 / 100, step 7/110, loss = 1.7512
# epoch 4 / 100, step 8/110, loss = 2.1022
# epoch 4 / 100, step 9/110, loss = 2.1221
# epoch 4 / 100, step 10/110, loss = 2.1467
# epoch 4 / 100, step 11/110, loss = 2.0308
# epoch 4 / 100, step 12/110, loss = 1.8983
# epoch 4 / 100, step 13/110, loss = 2.1268
# epoch 4 / 100, step 14/110, loss = 2.1389
# epoch 4 / 100, step 15/110, loss = 2.1695
# epoch 4 / 100, step 16/110, loss = 2.0242
# epoch 4 / 100, step 17/110, loss = 1.5934
# epoch 4 / 100, step 18/110, loss = 1.7589
# epoch 4 / 100, step 19/110, loss = 2.3220
# epoch 4 / 100, step 20/110, loss = 2.1564
# epoch 4 / 100, step 21/110, loss = 2.0450
# epoch 4 / 100, step 22/110, loss = 1.9810
# epoch 4 / 100, step 23/110, loss = 2.0084
# epoch 4 / 100, step 24/110, loss = 1.7583
# epoch 4 / 100, step 25/110, loss = 1.9065
# epoch 4 / 100, step 26/110, loss = 2.0462
# epoch 4 / 100, step 27/110, loss = 1.9226
# epoch 4 / 100, step 28/110, loss = 2.0657
# epoch 4 / 100, step 29/110, loss = 2.1506
# epoch 4 / 100, step 30/110, loss = 2.3283
# epoch 4 / 100, step 31/110, loss = 2.1430
# epoch 4 / 100, step 32/110, loss = 1.9039
# epoch 4 / 100, step 33/110, loss = 1.8837
# epoch 4 / 100, step 34/110, loss = 2.0266
# epoch 4 / 100, step 35/110, loss = 2.1733
# epoch 4 / 100, step 36/110, loss = 1.9572
# epoch 4 / 100, step 37/110, loss = 2.0469
# epoch 4 / 100, step 38/110, loss = 1.8274
# epoch 4 / 100, step 39/110, loss = 2.0257
# epoch 4 / 100, step 40/110, loss = 2.1763
# epoch 4 / 100, step 41/110, loss = 2.1598
# epoch 4 / 100, step 42/110, loss = 1.9875
# epoch 4 / 100, step 43/110, loss = 2.1241
# epoch 4 / 100, step 44/110, loss = 2.1222
# epoch 4 / 100, step 45/110, loss = 1.9305
# epoch 4 / 100, step 46/110, loss = 1.9189
# epoch 4 / 100, step 47/110, loss = 2.1212
# epoch 4 / 100, step 48/110, loss = 2.0400
# epoch 4 / 100, step 49/110, loss = 2.0486
# epoch 4 / 100, step 50/110, loss = 2.0866
# epoch 4 / 100, step 51/110, loss = 1.6679
# epoch 4 / 100, step 52/110, loss = 2.0451
# epoch 4 / 100, step 53/110, loss = 1.8999
# epoch 4 / 100, step 54/110, loss = 1.9511
# epoch 4 / 100, step 55/110, loss = 2.0557
# epoch 4 / 100, step 56/110, loss = 2.1000
# epoch 4 / 100, step 57/110, loss = 1.9688
# epoch 4 / 100, step 58/110, loss = 1.9119
# epoch 4 / 100, step 59/110, loss = 2.1650
# epoch 4 / 100, step 60/110, loss = 1.9058
# epoch 4 / 100, step 61/110, loss = 1.9834
# epoch 4 / 100, step 62/110, loss = 1.7326
# epoch 4 / 100, step 63/110, loss = 1.9996
# epoch 4 / 100, step 64/110, loss = 2.2667
# epoch 4 / 100, step 65/110, loss = 2.1495
# epoch 4 / 100, step 66/110, loss = 1.8255
# epoch 4 / 100, step 67/110, loss = 1.7933
# epoch 4 / 100, step 68/110, loss = 2.0897
# epoch 4 / 100, step 69/110, loss = 1.7105
# epoch 4 / 100, step 70/110, loss = 1.6386
# epoch 4 / 100, step 71/110, loss = 2.1714
# epoch 4 / 100, step 72/110, loss = 1.9470
# epoch 4 / 100, step 73/110, loss = 1.8482
# epoch 4 / 100, step 74/110, loss = 1.8364
# epoch 4 / 100, step 75/110, loss = 2.0089
# epoch 4 / 100, step 76/110, loss = 2.0970
# epoch 4 / 100, step 77/110, loss = 2.0318
# epoch 4 / 100, step 78/110, loss = 2.2245
# epoch 4 / 100, step 79/110, loss = 1.9758
# epoch 4 / 100, step 80/110, loss = 2.1503
# epoch 4 / 100, step 81/110, loss = 1.7273
# epoch 4 / 100, step 82/110, loss = 2.1783
# epoch 4 / 100, step 83/110, loss = 2.0068
# epoch 4 / 100, step 84/110, loss = 2.0824
# epoch 4 / 100, step 85/110, loss = 1.9821
# epoch 4 / 100, step 86/110, loss = 1.8815
# epoch 4 / 100, step 87/110, loss = 2.1013
# epoch 4 / 100, step 88/110, loss = 1.7548
# epoch 4 / 100, step 89/110, loss = 2.0811
# epoch 4 / 100, step 90/110, loss = 1.7872
# epoch 4 / 100, step 91/110, loss = 2.0278
# epoch 4 / 100, step 92/110, loss = 2.0901
# epoch 4 / 100, step 93/110, loss = 1.8606
# epoch 4 / 100, step 94/110, loss = 2.1567
# epoch 4 / 100, step 95/110, loss = 1.8737
# epoch 4 / 100, step 96/110, loss = 2.4365
# epoch 4 / 100, step 97/110, loss = 2.1675
# epoch 4 / 100, step 98/110, loss = 1.8685
# epoch 4 / 100, step 99/110, loss = 1.9637
# epoch 4 / 100, step 100/110, loss = 2.0953
# epoch 4 / 100, step 101/110, loss = 1.9804
# epoch 4 / 100, step 102/110, loss = 1.9245
# epoch 4 / 100, step 103/110, loss = 1.9585
# epoch 4 / 100, step 104/110, loss = 1.9657
# epoch 4 / 100, step 105/110, loss = 1.7699
# epoch 4 / 100, step 106/110, loss = 2.0804
# epoch 4 / 100, step 107/110, loss = 2.1481
# epoch 4 / 100, step 108/110, loss = 1.9506
# epoch 4 / 100, step 109/110, loss = 2.0637
# epoch 4 / 100, step 110/110, loss = 2.1695
# epoch 4 / 100, step 1/28, loss = 1.9495
# epoch 4 / 100, step 2/28, loss = 1.9869
# epoch 4 / 100, step 3/28, loss = 2.0924
# epoch 4 / 100, step 4/28, loss = 1.9690
# epoch 4 / 100, step 5/28, loss = 1.7502
# epoch 4 / 100, step 6/28, loss = 1.9270
# epoch 4 / 100, step 7/28, loss = 1.9725
# epoch 4 / 100, step 8/28, loss = 1.9791
# epoch 4 / 100, step 9/28, loss = 1.9554
# epoch 4 / 100, step 10/28, loss = 1.9572
# epoch 4 / 100, step 11/28, loss = 2.0269
# epoch 4 / 100, step 12/28, loss = 2.0107
# epoch 4 / 100, step 13/28, loss = 2.0097
# epoch 4 / 100, step 14/28, loss = 1.9907
# epoch 4 / 100, step 15/28, loss = 1.9856
# epoch 4 / 100, step 16/28, loss = 1.9577
# epoch 4 / 100, step 17/28, loss = 1.9579
# epoch 4 / 100, step 18/28, loss = 2.0129
# epoch 4 / 100, step 19/28, loss = 1.9161
# epoch 4 / 100, step 20/28, loss = 1.8451
# epoch 4 / 100, step 21/28, loss = 1.9548
# epoch 4 / 100, step 22/28, loss = 1.8879
# epoch 4 / 100, step 23/28, loss = 1.9994
# epoch 4 / 100, step 24/28, loss = 1.9637
# epoch 4 / 100, step 25/28, loss = 2.0671
# epoch 4 / 100, step 26/28, loss = 2.0329
# epoch 4 / 100, step 27/28, loss = 1.9601
# epoch 4 / 100, step 28/28, loss = 1.9070
# epoch 5 / 100, step 1/110, loss = 1.8538
# epoch 5 / 100, step 2/110, loss = 2.0306
# epoch 5 / 100, step 3/110, loss = 2.0712
# epoch 5 / 100, step 4/110, loss = 1.8427
# epoch 5 / 100, step 5/110, loss = 2.0877
# epoch 5 / 100, step 6/110, loss = 2.0070
# epoch 5 / 100, step 7/110, loss = 2.0074
# epoch 5 / 100, step 8/110, loss = 1.8652
# epoch 5 / 100, step 9/110, loss = 2.1079
# epoch 5 / 100, step 10/110, loss = 1.9277
# epoch 5 / 100, step 11/110, loss = 2.2592
# epoch 5 / 100, step 12/110, loss = 1.9937
# epoch 5 / 100, step 13/110, loss = 1.9558
# epoch 5 / 100, step 14/110, loss = 1.7387
# epoch 5 / 100, step 15/110, loss = 2.0685
# epoch 5 / 100, step 16/110, loss = 1.8900
# epoch 5 / 100, step 17/110, loss = 1.9348
# epoch 5 / 100, step 18/110, loss = 1.9856
# epoch 5 / 100, step 19/110, loss = 1.8210
# epoch 5 / 100, step 20/110, loss = 2.2051
# epoch 5 / 100, step 21/110, loss = 2.1786
# epoch 5 / 100, step 22/110, loss = 1.7317
# epoch 5 / 100, step 23/110, loss = 1.8812
# epoch 5 / 100, step 24/110, loss = 2.1310
# epoch 5 / 100, step 25/110, loss = 1.9571
# epoch 5 / 100, step 26/110, loss = 2.3383
# epoch 5 / 100, step 27/110, loss = 2.2354
# epoch 5 / 100, step 28/110, loss = 2.1931
# epoch 5 / 100, step 29/110, loss = 2.3112
# epoch 5 / 100, step 30/110, loss = 1.9919
# epoch 5 / 100, step 31/110, loss = 2.0310
# epoch 5 / 100, step 32/110, loss = 1.8472
# epoch 5 / 100, step 33/110, loss = 1.7529
# epoch 5 / 100, step 34/110, loss = 1.9270
# epoch 5 / 100, step 35/110, loss = 2.2560
# epoch 5 / 100, step 36/110, loss = 2.1670
# epoch 5 / 100, step 37/110, loss = 2.2561
# epoch 5 / 100, step 38/110, loss = 1.9174
# epoch 5 / 100, step 39/110, loss = 2.1223
# epoch 5 / 100, step 40/110, loss = 2.1285
# epoch 5 / 100, step 41/110, loss = 1.9723
# epoch 5 / 100, step 42/110, loss = 2.1220
# epoch 5 / 100, step 43/110, loss = 2.1859
# epoch 5 / 100, step 44/110, loss = 1.7827
# epoch 5 / 100, step 45/110, loss = 1.7807
# epoch 5 / 100, step 46/110, loss = 1.9841
# epoch 5 / 100, step 47/110, loss = 1.9361
# epoch 5 / 100, step 48/110, loss = 2.0486
# epoch 5 / 100, step 49/110, loss = 1.9092
# epoch 5 / 100, step 50/110, loss = 1.9567
# epoch 5 / 100, step 51/110, loss = 1.8466
# epoch 5 / 100, step 52/110, loss = 2.1232
# epoch 5 / 100, step 53/110, loss = 1.9720
# epoch 5 / 100, step 54/110, loss = 2.0169
# epoch 5 / 100, step 55/110, loss = 1.9447
# epoch 5 / 100, step 56/110, loss = 2.1156
# epoch 5 / 100, step 57/110, loss = 2.1659
# epoch 5 / 100, step 58/110, loss = 1.7972
# epoch 5 / 100, step 59/110, loss = 2.1027
# epoch 5 / 100, step 60/110, loss = 2.1064
# epoch 5 / 100, step 61/110, loss = 1.8938
# epoch 5 / 100, step 62/110, loss = 1.9067
# epoch 5 / 100, step 63/110, loss = 2.1097
# epoch 5 / 100, step 64/110, loss = 2.0209
# epoch 5 / 100, step 65/110, loss = 1.8662
# epoch 5 / 100, step 66/110, loss = 1.9654
# epoch 5 / 100, step 67/110, loss = 2.0360
# epoch 5 / 100, step 68/110, loss = 1.9392
# epoch 5 / 100, step 69/110, loss = 2.0777
# epoch 5 / 100, step 70/110, loss = 1.7653
# epoch 5 / 100, step 71/110, loss = 1.8329
# epoch 5 / 100, step 72/110, loss = 1.8338
# epoch 5 / 100, step 73/110, loss = 2.2525
# epoch 5 / 100, step 74/110, loss = 1.7486
# epoch 5 / 100, step 75/110, loss = 2.0953
# epoch 5 / 100, step 76/110, loss = 2.0057
# epoch 5 / 100, step 77/110, loss = 1.9067
# epoch 5 / 100, step 78/110, loss = 1.9425
# epoch 5 / 100, step 79/110, loss = 2.0539
# epoch 5 / 100, step 80/110, loss = 1.8858
# epoch 5 / 100, step 81/110, loss = 2.0065
# epoch 5 / 100, step 82/110, loss = 2.2544
# epoch 5 / 100, step 83/110, loss = 1.9162
# epoch 5 / 100, step 84/110, loss = 2.3108
# epoch 5 / 100, step 85/110, loss = 1.9668
# epoch 5 / 100, step 86/110, loss = 1.9163
# epoch 5 / 100, step 87/110, loss = 2.0287
# epoch 5 / 100, step 88/110, loss = 1.9597
# epoch 5 / 100, step 89/110, loss = 1.9700
# epoch 5 / 100, step 90/110, loss = 1.9102
# epoch 5 / 100, step 91/110, loss = 1.8471
# epoch 5 / 100, step 92/110, loss = 1.9850
# epoch 5 / 100, step 93/110, loss = 1.9470
# epoch 5 / 100, step 94/110, loss = 1.9302
# epoch 5 / 100, step 95/110, loss = 1.8412
# epoch 5 / 100, step 96/110, loss = 1.8108
# epoch 5 / 100, step 97/110, loss = 2.0142
# epoch 5 / 100, step 98/110, loss = 1.9767
# epoch 5 / 100, step 99/110, loss = 2.0611
# epoch 5 / 100, step 100/110, loss = 1.9407
# epoch 5 / 100, step 101/110, loss = 2.1660
# epoch 5 / 100, step 102/110, loss = 2.1004
# epoch 5 / 100, step 103/110, loss = 1.8483
# epoch 5 / 100, step 104/110, loss = 2.2515
# epoch 5 / 100, step 105/110, loss = 2.1073
# epoch 5 / 100, step 106/110, loss = 2.3129
# epoch 5 / 100, step 107/110, loss = 2.1375
# epoch 5 / 100, step 108/110, loss = 2.1689
# epoch 5 / 100, step 109/110, loss = 1.8710
# epoch 5 / 100, step 110/110, loss = 1.9922
# epoch 5 / 100, step 1/28, loss = 2.0267
# epoch 5 / 100, step 2/28, loss = 2.0706
# epoch 5 / 100, step 3/28, loss = 2.0160
# epoch 5 / 100, step 4/28, loss = 2.0046
# epoch 5 / 100, step 5/28, loss = 1.9344
# epoch 5 / 100, step 6/28, loss = 2.1396
# epoch 5 / 100, step 7/28, loss = 1.9059
# epoch 5 / 100, step 8/28, loss = 1.9148
# epoch 5 / 100, step 9/28, loss = 1.9993
# epoch 5 / 100, step 10/28, loss = 1.8006
# epoch 5 / 100, step 11/28, loss = 1.8959
# epoch 5 / 100, step 12/28, loss = 1.8266
# epoch 5 / 100, step 13/28, loss = 2.0118
# epoch 5 / 100, step 14/28, loss = 1.9653
# epoch 5 / 100, step 15/28, loss = 1.8552
# epoch 5 / 100, step 16/28, loss = 2.1925
# epoch 5 / 100, step 17/28, loss = 1.9383
# epoch 5 / 100, step 18/28, loss = 1.9079
# epoch 5 / 100, step 19/28, loss = 2.0276
# epoch 5 / 100, step 20/28, loss = 1.7675
# epoch 5 / 100, step 21/28, loss = 1.8618
# epoch 5 / 100, step 22/28, loss = 1.9599
# epoch 5 / 100, step 23/28, loss = 1.9551
# epoch 5 / 100, step 24/28, loss = 1.9636
# epoch 5 / 100, step 25/28, loss = 1.8930
# epoch 5 / 100, step 26/28, loss = 2.1204
# epoch 5 / 100, step 27/28, loss = 2.0062
# epoch 5 / 100, step 28/28, loss = 1.7855
# epoch 6 / 100, step 1/110, loss = 2.1061
# epoch 6 / 100, step 2/110, loss = 2.0485
# epoch 6 / 100, step 3/110, loss = 1.9600
# epoch 6 / 100, step 4/110, loss = 2.0855
# epoch 6 / 100, step 5/110, loss = 1.9394
# epoch 6 / 100, step 6/110, loss = 2.0176
# epoch 6 / 100, step 7/110, loss = 1.8633
# epoch 6 / 100, step 8/110, loss = 1.9458
# epoch 6 / 100, step 9/110, loss = 1.9245
# epoch 6 / 100, step 10/110, loss = 1.9095
# epoch 6 / 100, step 11/110, loss = 2.0708
# epoch 6 / 100, step 12/110, loss = 2.0063
# epoch 6 / 100, step 13/110, loss = 1.7239
# epoch 6 / 100, step 14/110, loss = 2.0066
# epoch 6 / 100, step 15/110, loss = 2.2591
# epoch 6 / 100, step 16/110, loss = 1.8347
# epoch 6 / 100, step 17/110, loss = 1.9557
# epoch 6 / 100, step 18/110, loss = 1.9232
# epoch 6 / 100, step 19/110, loss = 1.8084
# epoch 6 / 100, step 20/110, loss = 1.9455
# epoch 6 / 100, step 21/110, loss = 2.2430
# epoch 6 / 100, step 22/110, loss = 2.5440
# epoch 6 / 100, step 23/110, loss = 1.9521
# epoch 6 / 100, step 24/110, loss = 2.0793
# epoch 6 / 100, step 25/110, loss = 2.2064
# epoch 6 / 100, step 26/110, loss = 1.9256
# epoch 6 / 100, step 27/110, loss = 1.9131
# epoch 6 / 100, step 28/110, loss = 2.0593
# epoch 6 / 100, step 29/110, loss = 1.6793
# epoch 6 / 100, step 30/110, loss = 1.9059
# epoch 6 / 100, step 31/110, loss = 1.9601
# epoch 6 / 100, step 32/110, loss = 2.0973
# epoch 6 / 100, step 33/110, loss = 1.9600
# epoch 6 / 100, step 34/110, loss = 1.9408
# epoch 6 / 100, step 35/110, loss = 1.9692
# epoch 6 / 100, step 36/110, loss = 2.1114
# epoch 6 / 100, step 37/110, loss = 2.0992
# epoch 6 / 100, step 38/110, loss = 1.9908
# epoch 6 / 100, step 39/110, loss = 1.9358
# epoch 6 / 100, step 40/110, loss = 1.9764
# epoch 6 / 100, step 41/110, loss = 2.1197
# epoch 6 / 100, step 42/110, loss = 1.7643
# epoch 6 / 100, step 43/110, loss = 1.8316
# epoch 6 / 100, step 44/110, loss = 1.6909
# epoch 6 / 100, step 45/110, loss = 2.0133
# epoch 6 / 100, step 46/110, loss = 2.3776
# epoch 6 / 100, step 47/110, loss = 2.1670
# epoch 6 / 100, step 48/110, loss = 1.8899
# epoch 6 / 100, step 49/110, loss = 2.4669
# epoch 6 / 100, step 50/110, loss = 1.9995
# epoch 6 / 100, step 51/110, loss = 2.0515
# epoch 6 / 100, step 52/110, loss = 1.9931
# epoch 6 / 100, step 53/110, loss = 2.0894
# epoch 6 / 100, step 54/110, loss = 1.8963
# epoch 6 / 100, step 55/110, loss = 1.9717
# epoch 6 / 100, step 56/110, loss = 1.7077
# epoch 6 / 100, step 57/110, loss = 2.0263
# epoch 6 / 100, step 58/110, loss = 2.0004
# epoch 6 / 100, step 59/110, loss = 2.0723
# epoch 6 / 100, step 60/110, loss = 2.2548
# epoch 6 / 100, step 61/110, loss = 2.2635
# epoch 6 / 100, step 62/110, loss = 2.0507
# epoch 6 / 100, step 63/110, loss = 1.9021
# epoch 6 / 100, step 64/110, loss = 1.9726
# epoch 6 / 100, step 65/110, loss = 1.9304
# epoch 6 / 100, step 66/110, loss = 2.0053
# epoch 6 / 100, step 67/110, loss = 2.0223
# epoch 6 / 100, step 68/110, loss = 2.1184
# epoch 6 / 100, step 69/110, loss = 2.0303
# epoch 6 / 100, step 70/110, loss = 1.9294
# epoch 6 / 100, step 71/110, loss = 1.7519
# epoch 6 / 100, step 72/110, loss = 1.8211
# epoch 6 / 100, step 73/110, loss = 1.9715
# epoch 6 / 100, step 74/110, loss = 2.1834
# epoch 6 / 100, step 75/110, loss = 2.0030
# epoch 6 / 100, step 76/110, loss = 2.1611
# epoch 6 / 100, step 77/110, loss = 1.8978
# epoch 6 / 100, step 78/110, loss = 1.9261
# epoch 6 / 100, step 79/110, loss = 1.9626
# epoch 6 / 100, step 80/110, loss = 2.0189
# epoch 6 / 100, step 81/110, loss = 1.9872
# epoch 6 / 100, step 82/110, loss = 1.9829
# epoch 6 / 100, step 83/110, loss = 2.0399
# epoch 6 / 100, step 84/110, loss = 2.0552
# epoch 6 / 100, step 85/110, loss = 1.9832
# epoch 6 / 100, step 86/110, loss = 1.9163
# epoch 6 / 100, step 87/110, loss = 1.9938
# epoch 6 / 100, step 88/110, loss = 1.7892
# epoch 6 / 100, step 89/110, loss = 1.9110
# epoch 6 / 100, step 90/110, loss = 1.7327
# epoch 6 / 100, step 91/110, loss = 2.1806
# epoch 6 / 100, step 92/110, loss = 2.2449
# epoch 6 / 100, step 93/110, loss = 1.9524
# epoch 6 / 100, step 94/110, loss = 2.1399
# epoch 6 / 100, step 95/110, loss = 1.9907
# epoch 6 / 100, step 96/110, loss = 2.1628
# epoch 6 / 100, step 97/110, loss = 1.9254
# epoch 6 / 100, step 98/110, loss = 2.2248
# epoch 6 / 100, step 99/110, loss = 1.9183
# epoch 6 / 100, step 100/110, loss = 2.1816
# epoch 6 / 100, step 101/110, loss = 2.0084
# epoch 6 / 100, step 102/110, loss = 1.7693
# epoch 6 / 100, step 103/110, loss = 1.9287
# epoch 6 / 100, step 104/110, loss = 1.9193
# epoch 6 / 100, step 105/110, loss = 2.2113
# epoch 6 / 100, step 106/110, loss = 1.9451
# epoch 6 / 100, step 107/110, loss = 1.9770
# epoch 6 / 100, step 108/110, loss = 2.0520
# epoch 6 / 100, step 109/110, loss = 1.9275
# epoch 6 / 100, step 110/110, loss = 1.8774
# epoch 6 / 100, step 1/28, loss = 2.0245
# epoch 6 / 100, step 2/28, loss = 2.0335
# epoch 6 / 100, step 3/28, loss = 1.8828
# epoch 6 / 100, step 4/28, loss = 2.1270
# epoch 6 / 100, step 5/28, loss = 1.8570
# epoch 6 / 100, step 6/28, loss = 2.0836
# epoch 6 / 100, step 7/28, loss = 1.9024
# epoch 6 / 100, step 8/28, loss = 1.8152
# epoch 6 / 100, step 9/28, loss = 1.9302
# epoch 6 / 100, step 10/28, loss = 1.9228
# epoch 6 / 100, step 11/28, loss = 2.0054
# epoch 6 / 100, step 12/28, loss = 2.0550
# epoch 6 / 100, step 13/28, loss = 1.9271
# epoch 6 / 100, step 14/28, loss = 2.0711
# epoch 6 / 100, step 15/28, loss = 1.9280
# epoch 6 / 100, step 16/28, loss = 2.0742
# epoch 6 / 100, step 17/28, loss = 1.9260
# epoch 6 / 100, step 18/28, loss = 1.8452
# epoch 6 / 100, step 19/28, loss = 1.9572
# epoch 6 / 100, step 20/28, loss = 1.8289
# epoch 6 / 100, step 21/28, loss = 1.9815
# epoch 6 / 100, step 22/28, loss = 1.9971
# epoch 6 / 100, step 23/28, loss = 2.0891
# epoch 6 / 100, step 24/28, loss = 1.8918
# epoch 6 / 100, step 25/28, loss = 2.0116
# epoch 6 / 100, step 26/28, loss = 2.2125
# epoch 6 / 100, step 27/28, loss = 1.9919
# epoch 6 / 100, step 28/28, loss = 1.9195
# epoch 7 / 100, step 1/110, loss = 2.0632
# epoch 7 / 100, step 2/110, loss = 2.0255
# epoch 7 / 100, step 3/110, loss = 1.9835
# epoch 7 / 100, step 4/110, loss = 2.0324
# epoch 7 / 100, step 5/110, loss = 2.1150
# epoch 7 / 100, step 6/110, loss = 2.0260
# epoch 7 / 100, step 7/110, loss = 1.9493
# epoch 7 / 100, step 8/110, loss = 2.0559
# epoch 7 / 100, step 9/110, loss = 1.9313
# epoch 7 / 100, step 10/110, loss = 1.8950
# epoch 7 / 100, step 11/110, loss = 2.0148
# epoch 7 / 100, step 12/110, loss = 2.1578
# epoch 7 / 100, step 13/110, loss = 2.0417
# epoch 7 / 100, step 14/110, loss = 1.9385
# epoch 7 / 100, step 15/110, loss = 1.9838
# epoch 7 / 100, step 16/110, loss = 2.0699
# epoch 7 / 100, step 17/110, loss = 2.1920
# epoch 7 / 100, step 18/110, loss = 2.1706
# epoch 7 / 100, step 19/110, loss = 1.9356
# epoch 7 / 100, step 20/110, loss = 1.9659
# epoch 7 / 100, step 21/110, loss = 2.1654
# epoch 7 / 100, step 22/110, loss = 2.1004
# epoch 7 / 100, step 23/110, loss = 1.7821
# epoch 7 / 100, step 24/110, loss = 2.3467
# epoch 7 / 100, step 25/110, loss = 1.9251
# epoch 7 / 100, step 26/110, loss = 2.2766
# epoch 7 / 100, step 27/110, loss = 2.1426
# epoch 7 / 100, step 28/110, loss = 2.0123
# epoch 7 / 100, step 29/110, loss = 1.8911
# epoch 7 / 100, step 30/110, loss = 1.8765
# epoch 7 / 100, step 31/110, loss = 2.0265
# epoch 7 / 100, step 32/110, loss = 2.0816
# epoch 7 / 100, step 33/110, loss = 2.0304
# epoch 7 / 100, step 34/110, loss = 1.9365
# epoch 7 / 100, step 35/110, loss = 1.9379
# epoch 7 / 100, step 36/110, loss = 2.1047
# epoch 7 / 100, step 37/110, loss = 2.2250
# epoch 7 / 100, step 38/110, loss = 1.8367
# epoch 7 / 100, step 39/110, loss = 2.0484
# epoch 7 / 100, step 40/110, loss = 1.8077
# epoch 7 / 100, step 41/110, loss = 1.9357
# epoch 7 / 100, step 42/110, loss = 2.0130
# epoch 7 / 100, step 43/110, loss = 1.8461
# epoch 7 / 100, step 44/110, loss = 2.0226
# epoch 7 / 100, step 45/110, loss = 2.0163
# epoch 7 / 100, step 46/110, loss = 1.9100
# epoch 7 / 100, step 47/110, loss = 1.9396
# epoch 7 / 100, step 48/110, loss = 1.8512
# epoch 7 / 100, step 49/110, loss = 2.3584
# epoch 7 / 100, step 50/110, loss = 1.9999
# epoch 7 / 100, step 51/110, loss = 2.0560
# epoch 7 / 100, step 52/110, loss = 1.8139
# epoch 7 / 100, step 53/110, loss = 1.7176
# epoch 7 / 100, step 54/110, loss = 2.2620
# epoch 7 / 100, step 55/110, loss = 1.8096
# epoch 7 / 100, step 56/110, loss = 1.7789
# epoch 7 / 100, step 57/110, loss = 1.8885
# epoch 7 / 100, step 58/110, loss = 1.9689
# epoch 7 / 100, step 59/110, loss = 1.9615
# epoch 7 / 100, step 60/110, loss = 2.1098
# epoch 7 / 100, step 61/110, loss = 1.9746
# epoch 7 / 100, step 62/110, loss = 2.0289
# epoch 7 / 100, step 63/110, loss = 1.8650
# epoch 7 / 100, step 64/110, loss = 1.8951
# epoch 7 / 100, step 65/110, loss = 1.9585
# epoch 7 / 100, step 66/110, loss = 1.8361
# epoch 7 / 100, step 67/110, loss = 2.1921
# epoch 7 / 100, step 68/110, loss = 1.9058
# epoch 7 / 100, step 69/110, loss = 1.9207
# epoch 7 / 100, step 70/110, loss = 1.9719
# epoch 7 / 100, step 71/110, loss = 1.8701
# epoch 7 / 100, step 72/110, loss = 1.7216
# epoch 7 / 100, step 73/110, loss = 2.0292
# epoch 7 / 100, step 74/110, loss = 1.7867
# epoch 7 / 100, step 75/110, loss = 1.7072
# epoch 7 / 100, step 76/110, loss = 1.9635
# epoch 7 / 100, step 77/110, loss = 1.9881
# epoch 7 / 100, step 78/110, loss = 1.6522
# epoch 7 / 100, step 79/110, loss = 2.0756
# epoch 7 / 100, step 80/110, loss = 2.2833
# epoch 7 / 100, step 81/110, loss = 1.8258
# epoch 7 / 100, step 82/110, loss = 2.0219
# epoch 7 / 100, step 83/110, loss = 2.0472
# epoch 7 / 100, step 84/110, loss = 1.9866
# epoch 7 / 100, step 85/110, loss = 1.9733
# epoch 7 / 100, step 86/110, loss = 1.9864
# epoch 7 / 100, step 87/110, loss = 2.1536
# epoch 7 / 100, step 88/110, loss = 1.7160
# epoch 7 / 100, step 89/110, loss = 2.0177
# epoch 7 / 100, step 90/110, loss = 1.9900
# epoch 7 / 100, step 91/110, loss = 2.0347
# epoch 7 / 100, step 92/110, loss = 1.8554
# epoch 7 / 100, step 93/110, loss = 1.8390
# epoch 7 / 100, step 94/110, loss = 2.0662
# epoch 7 / 100, step 95/110, loss = 1.6272
# epoch 7 / 100, step 96/110, loss = 2.1288
# epoch 7 / 100, step 97/110, loss = 2.2932
# epoch 7 / 100, step 98/110, loss = 1.8640
# epoch 7 / 100, step 99/110, loss = 2.1225
# epoch 7 / 100, step 100/110, loss = 1.9861
# epoch 7 / 100, step 101/110, loss = 1.9523
# epoch 7 / 100, step 102/110, loss = 1.9717
# epoch 7 / 100, step 103/110, loss = 1.8189
# epoch 7 / 100, step 104/110, loss = 1.9774
# epoch 7 / 100, step 105/110, loss = 2.0056
# epoch 7 / 100, step 106/110, loss = 2.0747
# epoch 7 / 100, step 107/110, loss = 2.1119
# epoch 7 / 100, step 108/110, loss = 2.1405
# epoch 7 / 100, step 109/110, loss = 2.2532
# epoch 7 / 100, step 110/110, loss = 1.8100
# epoch 7 / 100, step 1/28, loss = 1.9512
# epoch 7 / 100, step 2/28, loss = 2.0323
# epoch 7 / 100, step 3/28, loss = 2.0324
# epoch 7 / 100, step 4/28, loss = 1.9055
# epoch 7 / 100, step 5/28, loss = 2.0462
# epoch 7 / 100, step 6/28, loss = 2.0364
# epoch 7 / 100, step 7/28, loss = 1.9458
# epoch 7 / 100, step 8/28, loss = 2.0177
# epoch 7 / 100, step 9/28, loss = 1.9417
# epoch 7 / 100, step 10/28, loss = 1.8347
# epoch 7 / 100, step 11/28, loss = 1.8764
# epoch 7 / 100, step 12/28, loss = 1.8089
# epoch 7 / 100, step 13/28, loss = 2.0113
# epoch 7 / 100, step 14/28, loss = 1.9900
# epoch 7 / 100, step 15/28, loss = 1.8668
# epoch 7 / 100, step 16/28, loss = 2.0492
# epoch 7 / 100, step 17/28, loss = 1.9253
# epoch 7 / 100, step 18/28, loss = 1.9956
# epoch 7 / 100, step 19/28, loss = 2.0984
# epoch 7 / 100, step 20/28, loss = 1.8416
# epoch 7 / 100, step 21/28, loss = 1.8586
# epoch 7 / 100, step 22/28, loss = 1.8755
# epoch 7 / 100, step 23/28, loss = 1.8918
# epoch 7 / 100, step 24/28, loss = 2.0618
# epoch 7 / 100, step 25/28, loss = 1.9675
# epoch 7 / 100, step 26/28, loss = 2.1543
# epoch 7 / 100, step 27/28, loss = 1.9128
# epoch 7 / 100, step 28/28, loss = 1.8174
# epoch 8 / 100, step 1/110, loss = 1.9920
# epoch 8 / 100, step 2/110, loss = 1.6255
# epoch 8 / 100, step 3/110, loss = 1.8767
# epoch 8 / 100, step 4/110, loss = 1.9130
# epoch 8 / 100, step 5/110, loss = 2.0321
# epoch 8 / 100, step 6/110, loss = 1.9586
# epoch 8 / 100, step 7/110, loss = 1.7591
# epoch 8 / 100, step 8/110, loss = 1.9825
# epoch 8 / 100, step 9/110, loss = 2.0615
# epoch 8 / 100, step 10/110, loss = 1.7690
# epoch 8 / 100, step 11/110, loss = 2.2339
# epoch 8 / 100, step 12/110, loss = 1.9179
# epoch 8 / 100, step 13/110, loss = 2.0077
# epoch 8 / 100, step 14/110, loss = 2.2394
# epoch 8 / 100, step 15/110, loss = 1.9979
# epoch 8 / 100, step 16/110, loss = 1.9675
# epoch 8 / 100, step 17/110, loss = 2.0642
# epoch 8 / 100, step 18/110, loss = 1.8778
# epoch 8 / 100, step 19/110, loss = 1.9205
# epoch 8 / 100, step 20/110, loss = 1.8010
# epoch 8 / 100, step 21/110, loss = 2.0637
# epoch 8 / 100, step 22/110, loss = 1.9903
# epoch 8 / 100, step 23/110, loss = 2.0066
# epoch 8 / 100, step 24/110, loss = 2.1099
# epoch 8 / 100, step 25/110, loss = 1.9601
# epoch 8 / 100, step 26/110, loss = 1.8606
# epoch 8 / 100, step 27/110, loss = 1.7213
# epoch 8 / 100, step 28/110, loss = 1.9457
# epoch 8 / 100, step 29/110, loss = 1.8188
# epoch 8 / 100, step 30/110, loss = 2.2283
# epoch 8 / 100, step 31/110, loss = 1.8061
# epoch 8 / 100, step 32/110, loss = 2.0987
# epoch 8 / 100, step 33/110, loss = 2.0021
# epoch 8 / 100, step 34/110, loss = 2.2260
# epoch 8 / 100, step 35/110, loss = 1.8630
# epoch 8 / 100, step 36/110, loss = 1.8672
# epoch 8 / 100, step 37/110, loss = 1.9431
# epoch 8 / 100, step 38/110, loss = 2.2275
# epoch 8 / 100, step 39/110, loss = 1.8947
# epoch 8 / 100, step 40/110, loss = 1.9350
# epoch 8 / 100, step 41/110, loss = 1.9685
# epoch 8 / 100, step 42/110, loss = 2.1559
# epoch 8 / 100, step 43/110, loss = 2.1542
# epoch 8 / 100, step 44/110, loss = 2.1123
# epoch 8 / 100, step 45/110, loss = 1.8753
# epoch 8 / 100, step 46/110, loss = 2.0524
# epoch 8 / 100, step 47/110, loss = 2.0066
# epoch 8 / 100, step 48/110, loss = 1.9809
# epoch 8 / 100, step 49/110, loss = 1.9319
# epoch 8 / 100, step 50/110, loss = 2.0349
# epoch 8 / 100, step 51/110, loss = 1.9217
# epoch 8 / 100, step 52/110, loss = 1.9669
# epoch 8 / 100, step 53/110, loss = 1.9555
# epoch 8 / 100, step 54/110, loss = 1.7159
# epoch 8 / 100, step 55/110, loss = 1.9205
# epoch 8 / 100, step 56/110, loss = 1.6603
# epoch 8 / 100, step 57/110, loss = 1.8940
# epoch 8 / 100, step 58/110, loss = 1.9603
# epoch 8 / 100, step 59/110, loss = 1.9653
# epoch 8 / 100, step 60/110, loss = 2.1431
# epoch 8 / 100, step 61/110, loss = 1.8595
# epoch 8 / 100, step 62/110, loss = 2.1150
# epoch 8 / 100, step 63/110, loss = 1.9201
# epoch 8 / 100, step 64/110, loss = 2.2645
# epoch 8 / 100, step 65/110, loss = 1.8961
# epoch 8 / 100, step 66/110, loss = 1.7033
# epoch 8 / 100, step 67/110, loss = 2.1114
# epoch 8 / 100, step 68/110, loss = 2.1135
# epoch 8 / 100, step 69/110, loss = 2.2897
# epoch 8 / 100, step 70/110, loss = 1.8158
# epoch 8 / 100, step 71/110, loss = 1.9405
# epoch 8 / 100, step 72/110, loss = 2.3355
# epoch 8 / 100, step 73/110, loss = 2.1026
# epoch 8 / 100, step 74/110, loss = 2.1139
# epoch 8 / 100, step 75/110, loss = 2.0693
# epoch 8 / 100, step 76/110, loss = 2.1637
# epoch 8 / 100, step 77/110, loss = 2.0285
# epoch 8 / 100, step 78/110, loss = 1.9775
# epoch 8 / 100, step 79/110, loss = 1.9350
# epoch 8 / 100, step 80/110, loss = 2.1329
# epoch 8 / 100, step 81/110, loss = 1.9741
# epoch 8 / 100, step 82/110, loss = 1.8315
# epoch 8 / 100, step 83/110, loss = 2.0381
# epoch 8 / 100, step 84/110, loss = 1.9366
# epoch 8 / 100, step 85/110, loss = 1.9027
# epoch 8 / 100, step 86/110, loss = 1.9906
# epoch 8 / 100, step 87/110, loss = 1.9203
# epoch 8 / 100, step 88/110, loss = 2.0386
# epoch 8 / 100, step 89/110, loss = 1.9156
# epoch 8 / 100, step 90/110, loss = 2.2744
# epoch 8 / 100, step 91/110, loss = 1.8758
# epoch 8 / 100, step 92/110, loss = 1.9721
# epoch 8 / 100, step 93/110, loss = 1.9015
# epoch 8 / 100, step 94/110, loss = 2.0339
# epoch 8 / 100, step 95/110, loss = 2.0333
# epoch 8 / 100, step 96/110, loss = 2.1820
# epoch 8 / 100, step 97/110, loss = 1.8624
# epoch 8 / 100, step 98/110, loss = 1.9999
# epoch 8 / 100, step 99/110, loss = 1.9191
# epoch 8 / 100, step 100/110, loss = 1.9353
# epoch 8 / 100, step 101/110, loss = 2.0719
# epoch 8 / 100, step 102/110, loss = 1.9674
# epoch 8 / 100, step 103/110, loss = 2.1921
# epoch 8 / 100, step 104/110, loss = 2.0166
# epoch 8 / 100, step 105/110, loss = 1.9739
# epoch 8 / 100, step 106/110, loss = 1.9774
# epoch 8 / 100, step 107/110, loss = 1.9064
# epoch 8 / 100, step 108/110, loss = 2.0064
# epoch 8 / 100, step 109/110, loss = 1.8170
# epoch 8 / 100, step 110/110, loss = 1.9046
# epoch 8 / 100, step 1/28, loss = 1.9216
# epoch 8 / 100, step 2/28, loss = 1.8833
# epoch 8 / 100, step 3/28, loss = 1.8593
# epoch 8 / 100, step 4/28, loss = 1.8826
# epoch 8 / 100, step 5/28, loss = 1.9598
# epoch 8 / 100, step 6/28, loss = 1.8324
# epoch 8 / 100, step 7/28, loss = 1.9364
# epoch 8 / 100, step 8/28, loss = 2.0407
# epoch 8 / 100, step 9/28, loss = 1.9196
# epoch 8 / 100, step 10/28, loss = 2.0508
# epoch 8 / 100, step 11/28, loss = 1.9199
# epoch 8 / 100, step 12/28, loss = 1.7992
# epoch 8 / 100, step 13/28, loss = 1.9808
# epoch 8 / 100, step 14/28, loss = 1.8730
# epoch 8 / 100, step 15/28, loss = 1.8807
# epoch 8 / 100, step 16/28, loss = 1.9160
# epoch 8 / 100, step 17/28, loss = 1.9894
# epoch 8 / 100, step 18/28, loss = 2.0535
# epoch 8 / 100, step 19/28, loss = 2.0024
# epoch 8 / 100, step 20/28, loss = 2.0143
# epoch 8 / 100, step 21/28, loss = 1.9727
# epoch 8 / 100, step 22/28, loss = 2.0003
# epoch 8 / 100, step 23/28, loss = 1.9191
# epoch 8 / 100, step 24/28, loss = 1.9640
# epoch 8 / 100, step 25/28, loss = 1.9441
# epoch 8 / 100, step 26/28, loss = 2.0620
# epoch 8 / 100, step 27/28, loss = 1.9657
# epoch 8 / 100, step 28/28, loss = 1.8946
# epoch 9 / 100, step 1/110, loss = 1.8913
# epoch 9 / 100, step 2/110, loss = 1.9837
# epoch 9 / 100, step 3/110, loss = 1.7283
# epoch 9 / 100, step 4/110, loss = 1.7974
# epoch 9 / 100, step 5/110, loss = 1.8658
# epoch 9 / 100, step 6/110, loss = 1.8170
# epoch 9 / 100, step 7/110, loss = 1.7646
# epoch 9 / 100, step 8/110, loss = 2.1230
# epoch 9 / 100, step 9/110, loss = 1.9346
# epoch 9 / 100, step 10/110, loss = 1.9236
# epoch 9 / 100, step 11/110, loss = 1.7005
# epoch 9 / 100, step 12/110, loss = 2.1972
# epoch 9 / 100, step 13/110, loss = 2.1352
# epoch 9 / 100, step 14/110, loss = 1.7119
# epoch 9 / 100, step 15/110, loss = 1.9410
# epoch 9 / 100, step 16/110, loss = 2.0573
# epoch 9 / 100, step 17/110, loss = 1.8023
# epoch 9 / 100, step 18/110, loss = 1.9500
# epoch 9 / 100, step 19/110, loss = 2.0220
# epoch 9 / 100, step 20/110, loss = 1.8183
# epoch 9 / 100, step 21/110, loss = 1.9668
# epoch 9 / 100, step 22/110, loss = 2.1252
# epoch 9 / 100, step 23/110, loss = 2.0300
# epoch 9 / 100, step 24/110, loss = 2.0831
# epoch 9 / 100, step 25/110, loss = 1.8308
# epoch 9 / 100, step 26/110, loss = 1.9404
# epoch 9 / 100, step 27/110, loss = 2.0503
# epoch 9 / 100, step 28/110, loss = 1.8171
# epoch 9 / 100, step 29/110, loss = 1.9709
# epoch 9 / 100, step 30/110, loss = 2.1111
# epoch 9 / 100, step 31/110, loss = 1.9951
# epoch 9 / 100, step 32/110, loss = 2.0930
# epoch 9 / 100, step 33/110, loss = 2.0039
# epoch 9 / 100, step 34/110, loss = 2.0626
# epoch 9 / 100, step 35/110, loss = 2.0050
# epoch 9 / 100, step 36/110, loss = 2.1640
# epoch 9 / 100, step 37/110, loss = 2.1997
# epoch 9 / 100, step 38/110, loss = 2.1219
# epoch 9 / 100, step 39/110, loss = 2.1674
# epoch 9 / 100, step 40/110, loss = 1.8635
# epoch 9 / 100, step 41/110, loss = 1.6767
# epoch 9 / 100, step 42/110, loss = 1.9260
# epoch 9 / 100, step 43/110, loss = 2.2317
# epoch 9 / 100, step 44/110, loss = 1.8376
# epoch 9 / 100, step 45/110, loss = 1.9513
# ...
# epoch 98 / 100, step 44/110, loss = 1.8728
# epoch 98 / 100, step 45/110, loss = 1.7749
# epoch 98 / 100, step 46/110, loss = 2.0330
# epoch 98 / 100, step 47/110, loss = 2.0322
# epoch 98 / 100, step 48/110, loss = 1.8471
# epoch 98 / 100, step 49/110, loss = 2.0692
# epoch 98 / 100, step 50/110, loss = 1.8718
# epoch 98 / 100, step 51/110, loss = 2.0167
# epoch 98 / 100, step 52/110, loss = 2.0559
# epoch 98 / 100, step 53/110, loss = 1.9780
# epoch 98 / 100, step 54/110, loss = 2.0831
# epoch 98 / 100, step 55/110, loss = 1.8985
# epoch 98 / 100, step 56/110, loss = 2.0330
# epoch 98 / 100, step 57/110, loss = 1.8821
# epoch 98 / 100, step 58/110, loss = 1.9533
# epoch 98 / 100, step 59/110, loss = 1.8530
# epoch 98 / 100, step 60/110, loss = 1.9496
# epoch 98 / 100, step 61/110, loss = 1.9833
# epoch 98 / 100, step 62/110, loss = 1.8799
# epoch 98 / 100, step 63/110, loss = 2.0360
# epoch 98 / 100, step 64/110, loss = 2.2525
# epoch 98 / 100, step 65/110, loss = 1.9041
# epoch 98 / 100, step 66/110, loss = 1.9704
# epoch 98 / 100, step 67/110, loss = 2.1175
# epoch 98 / 100, step 68/110, loss = 1.7860
# epoch 98 / 100, step 69/110, loss = 1.9614
# epoch 98 / 100, step 70/110, loss = 1.8556
# epoch 98 / 100, step 71/110, loss = 1.8600
# epoch 98 / 100, step 72/110, loss = 1.8498
# epoch 98 / 100, step 73/110, loss = 2.0579
# epoch 98 / 100, step 74/110, loss = 2.0050
# epoch 98 / 100, step 75/110, loss = 1.8752
# epoch 98 / 100, step 76/110, loss = 1.9274
# epoch 98 / 100, step 77/110, loss = 1.8527
# epoch 98 / 100, step 78/110, loss = 2.0287
# epoch 98 / 100, step 79/110, loss = 1.8073
# epoch 98 / 100, step 80/110, loss = 2.0853
# epoch 98 / 100, step 81/110, loss = 1.9684
# epoch 98 / 100, step 82/110, loss = 2.0911
# epoch 98 / 100, step 83/110, loss = 1.9095
# epoch 98 / 100, step 84/110, loss = 1.9673
# epoch 98 / 100, step 85/110, loss = 1.8613
# epoch 98 / 100, step 86/110, loss = 1.9142
# epoch 98 / 100, step 87/110, loss = 1.9924
# epoch 98 / 100, step 88/110, loss = 1.9173
# epoch 98 / 100, step 89/110, loss = 1.8975
# epoch 98 / 100, step 90/110, loss = 1.9024
# epoch 98 / 100, step 91/110, loss = 1.8058
# epoch 98 / 100, step 92/110, loss = 1.9836
# epoch 98 / 100, step 93/110, loss = 1.9227
# epoch 98 / 100, step 94/110, loss = 1.7770
# epoch 98 / 100, step 95/110, loss = 1.9801
# epoch 98 / 100, step 96/110, loss = 1.7882
# epoch 98 / 100, step 97/110, loss = 2.0396
# epoch 98 / 100, step 98/110, loss = 1.9732
# epoch 98 / 100, step 99/110, loss = 1.8878
# epoch 98 / 100, step 100/110, loss = 1.8867
# epoch 98 / 100, step 101/110, loss = 2.1620
# epoch 98 / 100, step 102/110, loss = 1.9703
# epoch 98 / 100, step 103/110, loss = 2.0822
# epoch 98 / 100, step 104/110, loss = 1.6626
# epoch 98 / 100, step 105/110, loss = 1.8768
# epoch 98 / 100, step 106/110, loss = 1.9947
# epoch 98 / 100, step 107/110, loss = 2.0426
# epoch 98 / 100, step 108/110, loss = 1.9775
# epoch 98 / 100, step 109/110, loss = 1.8476
# epoch 98 / 100, step 110/110, loss = 1.8457
# epoch 98 / 100, step 1/28, loss = 1.9343
# epoch 98 / 100, step 2/28, loss = 1.9612
# epoch 98 / 100, step 3/28, loss = 1.9623
# epoch 98 / 100, step 4/28, loss = 1.9142
# epoch 98 / 100, step 5/28, loss = 2.0073
# epoch 98 / 100, step 6/28, loss = 1.9542
# epoch 98 / 100, step 7/28, loss = 1.9052
# epoch 98 / 100, step 8/28, loss = 1.9986
# epoch 98 / 100, step 9/28, loss = 1.9352
# epoch 98 / 100, step 10/28, loss = 1.9431
# epoch 98 / 100, step 11/28, loss = 1.8613
# epoch 98 / 100, step 12/28, loss = 1.7588
# epoch 98 / 100, step 13/28, loss = 1.9797
# epoch 98 / 100, step 14/28, loss = 1.9388
# epoch 98 / 100, step 15/28, loss = 1.8232
# epoch 98 / 100, step 16/28, loss = 1.9986
# epoch 98 / 100, step 17/28, loss = 1.9361
# epoch 98 / 100, step 18/28, loss = 1.9798
# epoch 98 / 100, step 19/28, loss = 2.0712
# epoch 98 / 100, step 20/28, loss = 1.9048
# epoch 98 / 100, step 21/28, loss = 1.9003
# epoch 98 / 100, step 22/28, loss = 1.9375
# epoch 98 / 100, step 23/28, loss = 1.9119
# epoch 98 / 100, step 24/28, loss = 2.0347
# epoch 98 / 100, step 25/28, loss = 1.9336
# epoch 98 / 100, step 26/28, loss = 2.1101
# epoch 98 / 100, step 27/28, loss = 1.9659
# epoch 98 / 100, step 28/28, loss = 1.8086
# epoch 99 / 100, step 1/110, loss = 2.0583
# epoch 99 / 100, step 2/110, loss = 1.9692
# epoch 99 / 100, step 3/110, loss = 1.9375
# epoch 99 / 100, step 4/110, loss = 2.0146
# epoch 99 / 100, step 5/110, loss = 1.8286
# epoch 99 / 100, step 6/110, loss = 2.1313
# epoch 99 / 100, step 7/110, loss = 1.8469
# epoch 99 / 100, step 8/110, loss = 1.8785
# epoch 99 / 100, step 9/110, loss = 1.7396
# epoch 99 / 100, step 10/110, loss = 1.8872
# epoch 99 / 100, step 11/110, loss = 1.9402
# epoch 99 / 100, step 12/110, loss = 1.9706
# epoch 99 / 100, step 13/110, loss = 2.1889
# epoch 99 / 100, step 14/110, loss = 1.9016
# epoch 99 / 100, step 15/110, loss = 1.7589
# epoch 99 / 100, step 16/110, loss = 1.9203
# epoch 99 / 100, step 17/110, loss = 2.0366
# epoch 99 / 100, step 18/110, loss = 2.0409
# epoch 99 / 100, step 19/110, loss = 2.1425
# epoch 99 / 100, step 20/110, loss = 1.8979
# epoch 99 / 100, step 21/110, loss = 1.8461
# epoch 99 / 100, step 22/110, loss = 2.0419
# epoch 99 / 100, step 23/110, loss = 2.0853
# epoch 99 / 100, step 24/110, loss = 2.0699
# epoch 99 / 100, step 25/110, loss = 1.9016
# epoch 99 / 100, step 26/110, loss = 1.6692
# epoch 99 / 100, step 27/110, loss = 1.7595
# epoch 99 / 100, step 28/110, loss = 1.9765
# epoch 99 / 100, step 29/110, loss = 1.9762
# epoch 99 / 100, step 30/110, loss = 1.9427
# epoch 99 / 100, step 31/110, loss = 1.9934
# epoch 99 / 100, step 32/110, loss = 1.6322
# epoch 99 / 100, step 33/110, loss = 2.2857
# epoch 99 / 100, step 34/110, loss = 1.9656
# epoch 99 / 100, step 35/110, loss = 2.1673
# epoch 99 / 100, step 36/110, loss = 1.7839
# epoch 99 / 100, step 37/110, loss = 2.1532
# epoch 99 / 100, step 38/110, loss = 1.7570
# epoch 99 / 100, step 39/110, loss = 1.9623
# epoch 99 / 100, step 40/110, loss = 2.0354
# epoch 99 / 100, step 41/110, loss = 2.2395
# epoch 99 / 100, step 42/110, loss = 1.8697
# epoch 99 / 100, step 43/110, loss = 1.8993
# epoch 99 / 100, step 44/110, loss = 2.2627
# epoch 99 / 100, step 45/110, loss = 1.9028
# epoch 99 / 100, step 46/110, loss = 2.0553
# epoch 99 / 100, step 47/110, loss = 2.0584
# epoch 99 / 100, step 48/110, loss = 1.8405
# epoch 99 / 100, step 49/110, loss = 1.8422
# epoch 99 / 100, step 50/110, loss = 1.9073
# epoch 99 / 100, step 51/110, loss = 1.9463
# epoch 99 / 100, step 52/110, loss = 1.9291
# epoch 99 / 100, step 53/110, loss = 1.9876
# epoch 99 / 100, step 54/110, loss = 1.8739
# epoch 99 / 100, step 55/110, loss = 2.0297
# epoch 99 / 100, step 56/110, loss = 2.0952
# epoch 99 / 100, step 57/110, loss = 1.9047
# epoch 99 / 100, step 58/110, loss = 1.7052
# epoch 99 / 100, step 59/110, loss = 2.0607
# epoch 99 / 100, step 60/110, loss = 1.8599
# epoch 99 / 100, step 61/110, loss = 1.9787
# epoch 99 / 100, step 62/110, loss = 1.7350
# epoch 99 / 100, step 63/110, loss = 1.8776
# epoch 99 / 100, step 64/110, loss = 1.9446
# epoch 99 / 100, step 65/110, loss = 2.1281
# epoch 99 / 100, step 66/110, loss = 1.8226
# epoch 99 / 100, step 67/110, loss = 2.0912
# epoch 99 / 100, step 68/110, loss = 2.1458
# epoch 99 / 100, step 69/110, loss = 2.0465
# epoch 99 / 100, step 70/110, loss = 1.9802
# epoch 99 / 100, step 71/110, loss = 2.1078
# epoch 99 / 100, step 72/110, loss = 1.7924
# epoch 99 / 100, step 73/110, loss = 2.1967
# epoch 99 / 100, step 74/110, loss = 1.9100
# epoch 99 / 100, step 75/110, loss = 1.9899
# epoch 99 / 100, step 76/110, loss = 1.9834
# epoch 99 / 100, step 77/110, loss = 2.0238
# epoch 99 / 100, step 78/110, loss = 1.9171
# epoch 99 / 100, step 79/110, loss = 2.0918
# epoch 99 / 100, step 80/110, loss = 2.0425
# epoch 99 / 100, step 81/110, loss = 1.9429
# epoch 99 / 100, step 82/110, loss = 2.0944
# epoch 99 / 100, step 83/110, loss = 1.8941
# epoch 99 / 100, step 84/110, loss = 2.1001
# epoch 99 / 100, step 85/110, loss = 1.8992
# epoch 99 / 100, step 86/110, loss = 2.0811
# epoch 99 / 100, step 87/110, loss = 1.9232
# epoch 99 / 100, step 88/110, loss = 1.7824
# epoch 99 / 100, step 89/110, loss = 2.0113
# epoch 99 / 100, step 90/110, loss = 1.8892
# epoch 99 / 100, step 91/110, loss = 1.8822
# epoch 99 / 100, step 92/110, loss = 2.1207
# epoch 99 / 100, step 93/110, loss = 2.0662
# epoch 99 / 100, step 94/110, loss = 1.8737
# epoch 99 / 100, step 95/110, loss = 1.7949
# epoch 99 / 100, step 96/110, loss = 1.9370
# epoch 99 / 100, step 97/110, loss = 1.9630
# epoch 99 / 100, step 98/110, loss = 1.9420
# epoch 99 / 100, step 99/110, loss = 1.8499
# epoch 99 / 100, step 100/110, loss = 2.0604
# epoch 99 / 100, step 101/110, loss = 1.8640
# epoch 99 / 100, step 102/110, loss = 1.9491
# epoch 99 / 100, step 103/110, loss = 1.8402
# epoch 99 / 100, step 104/110, loss = 2.0892
# epoch 99 / 100, step 105/110, loss = 2.0746
# epoch 99 / 100, step 106/110, loss = 2.1791
# epoch 99 / 100, step 107/110, loss = 1.9619
# epoch 99 / 100, step 108/110, loss = 1.9957
# epoch 99 / 100, step 109/110, loss = 1.9196
# epoch 99 / 100, step 110/110, loss = 1.8675
# epoch 99 / 100, step 1/28, loss = 1.9687
# epoch 99 / 100, step 2/28, loss = 2.0030
# epoch 99 / 100, step 3/28, loss = 1.9760
# epoch 99 / 100, step 4/28, loss = 1.9943
# epoch 99 / 100, step 5/28, loss = 2.0538
# epoch 99 / 100, step 6/28, loss = 2.0134
# epoch 99 / 100, step 7/28, loss = 1.9330
# epoch 99 / 100, step 8/28, loss = 1.9766
# epoch 99 / 100, step 9/28, loss = 1.8672
# epoch 99 / 100, step 10/28, loss = 2.0015
# epoch 99 / 100, step 11/28, loss = 1.8958
# epoch 99 / 100, step 12/28, loss = 1.9097
# epoch 99 / 100, step 13/28, loss = 1.9283
# epoch 99 / 100, step 14/28, loss = 2.0113
# epoch 99 / 100, step 15/28, loss = 1.8905
# epoch 99 / 100, step 16/28, loss = 1.9542
# epoch 99 / 100, step 17/28, loss = 1.9611
# epoch 99 / 100, step 18/28, loss = 1.9209
# epoch 99 / 100, step 19/28, loss = 2.0562
# epoch 99 / 100, step 20/28, loss = 1.9744
# epoch 99 / 100, step 21/28, loss = 1.9909
# epoch 99 / 100, step 22/28, loss = 1.9421
# epoch 99 / 100, step 23/28, loss = 1.9991
# epoch 99 / 100, step 24/28, loss = 2.0923
# epoch 99 / 100, step 25/28, loss = 1.9364
# epoch 99 / 100, step 26/28, loss = 2.1936
# epoch 99 / 100, step 27/28, loss = 1.9633
# epoch 99 / 100, step 28/28, loss = 1.9490
# epoch 100 / 100, step 1/110, loss = 2.0337
# epoch 100 / 100, step 2/110, loss = 2.1005
# epoch 100 / 100, step 3/110, loss = 1.8767
# epoch 100 / 100, step 4/110, loss = 2.1012
# epoch 100 / 100, step 5/110, loss = 1.9298
# epoch 100 / 100, step 6/110, loss = 1.8861
# epoch 100 / 100, step 7/110, loss = 2.0817
# epoch 100 / 100, step 8/110, loss = 2.1689
# epoch 100 / 100, step 9/110, loss = 1.9818
# epoch 100 / 100, step 10/110, loss = 1.8668
# epoch 100 / 100, step 11/110, loss = 1.9553
# epoch 100 / 100, step 12/110, loss = 2.0557
# epoch 100 / 100, step 13/110, loss = 1.9125
# epoch 100 / 100, step 14/110, loss = 1.8664
# epoch 100 / 100, step 15/110, loss = 1.9049
# epoch 100 / 100, step 16/110, loss = 1.9141
# epoch 100 / 100, step 17/110, loss = 1.9669
# epoch 100 / 100, step 18/110, loss = 1.8490
# epoch 100 / 100, step 19/110, loss = 1.6695
# epoch 100 / 100, step 20/110, loss = 2.0345
# epoch 100 / 100, step 21/110, loss = 2.0013
# epoch 100 / 100, step 22/110, loss = 2.0249
# epoch 100 / 100, step 23/110, loss = 1.8433
# epoch 100 / 100, step 24/110, loss = 2.2425
# epoch 100 / 100, step 25/110, loss = 2.0548
# epoch 100 / 100, step 26/110, loss = 1.8301
# epoch 100 / 100, step 27/110, loss = 1.9154
# epoch 100 / 100, step 28/110, loss = 1.8903
# epoch 100 / 100, step 29/110, loss = 1.9207
# epoch 100 / 100, step 30/110, loss = 1.8103
# epoch 100 / 100, step 31/110, loss = 1.8768
# epoch 100 / 100, step 32/110, loss = 1.9481
# epoch 100 / 100, step 33/110, loss = 1.8739
# epoch 100 / 100, step 34/110, loss = 1.9147
# epoch 100 / 100, step 35/110, loss = 2.0734
# epoch 100 / 100, step 36/110, loss = 2.0165
# epoch 100 / 100, step 37/110, loss = 1.9972
# epoch 100 / 100, step 38/110, loss = 2.2535
# epoch 100 / 100, step 39/110, loss = 1.9064
# epoch 100 / 100, step 40/110, loss = 2.1895
# epoch 100 / 100, step 41/110, loss = 1.9405
# epoch 100 / 100, step 42/110, loss = 2.0891
# epoch 100 / 100, step 43/110, loss = 2.0285
# epoch 100 / 100, step 44/110, loss = 1.9323
# epoch 100 / 100, step 45/110, loss = 2.0910
# epoch 100 / 100, step 46/110, loss = 1.9141
# epoch 100 / 100, step 47/110, loss = 2.0004
# epoch 100 / 100, step 48/110, loss = 1.8724
# epoch 100 / 100, step 49/110, loss = 1.9856
# epoch 100 / 100, step 50/110, loss = 2.1193
# epoch 100 / 100, step 51/110, loss = 1.9105
# epoch 100 / 100, step 52/110, loss = 2.0470
# epoch 100 / 100, step 53/110, loss = 1.9366
# epoch 100 / 100, step 54/110, loss = 1.9306
# epoch 100 / 100, step 55/110, loss = 2.0134
# epoch 100 / 100, step 56/110, loss = 1.9804
# epoch 100 / 100, step 57/110, loss = 1.9910
# epoch 100 / 100, step 58/110, loss = 1.8497
# epoch 100 / 100, step 59/110, loss = 1.9951
# epoch 100 / 100, step 60/110, loss = 1.9798
# epoch 100 / 100, step 61/110, loss = 1.7405
# epoch 100 / 100, step 62/110, loss = 2.0039
# epoch 100 / 100, step 63/110, loss = 2.0431
# epoch 100 / 100, step 64/110, loss = 1.8695
# epoch 100 / 100, step 65/110, loss = 2.1030
# epoch 100 / 100, step 66/110, loss = 1.9083
# epoch 100 / 100, step 67/110, loss = 1.8502
# epoch 100 / 100, step 68/110, loss = 2.0225
# epoch 100 / 100, step 69/110, loss = 1.9974
# epoch 100 / 100, step 70/110, loss = 1.7948
# epoch 100 / 100, step 71/110, loss = 1.8870
# epoch 100 / 100, step 72/110, loss = 2.2924
# epoch 100 / 100, step 73/110, loss = 1.9856
# epoch 100 / 100, step 74/110, loss = 2.0718
# epoch 100 / 100, step 75/110, loss = 1.9245
# epoch 100 / 100, step 76/110, loss = 1.9432
# epoch 100 / 100, step 77/110, loss = 2.0974
# epoch 100 / 100, step 78/110, loss = 2.0431
# epoch 100 / 100, step 79/110, loss = 2.0153
# epoch 100 / 100, step 80/110, loss = 1.9464
# epoch 100 / 100, step 81/110, loss = 1.9412
# epoch 100 / 100, step 82/110, loss = 1.9925
# epoch 100 / 100, step 83/110, loss = 1.9269
# epoch 100 / 100, step 84/110, loss = 1.8443
# epoch 100 / 100, step 85/110, loss = 2.0690
# epoch 100 / 100, step 86/110, loss = 1.8858
# epoch 100 / 100, step 87/110, loss = 1.8505
# epoch 100 / 100, step 88/110, loss = 1.8761
# epoch 100 / 100, step 89/110, loss = 1.9659
# epoch 100 / 100, step 90/110, loss = 2.0379
# epoch 100 / 100, step 91/110, loss = 1.9200
# epoch 100 / 100, step 92/110, loss = 2.1014
# epoch 100 / 100, step 93/110, loss = 1.9923
# epoch 100 / 100, step 94/110, loss = 1.9644
# epoch 100 / 100, step 95/110, loss = 1.8099
# epoch 100 / 100, step 96/110, loss = 1.9097
# epoch 100 / 100, step 97/110, loss = 1.8878
# epoch 100 / 100, step 98/110, loss = 1.9614
# epoch 100 / 100, step 99/110, loss = 1.7286
# epoch 100 / 100, step 100/110, loss = 1.9508
# epoch 100 / 100, step 101/110, loss = 2.0105
# epoch 100 / 100, step 102/110, loss = 1.9634
# epoch 100 / 100, step 103/110, loss = 1.9850
# epoch 100 / 100, step 104/110, loss = 2.1192
# epoch 100 / 100, step 105/110, loss = 2.2069
# epoch 100 / 100, step 106/110, loss = 1.8575
# epoch 100 / 100, step 107/110, loss = 1.9226
# epoch 100 / 100, step 108/110, loss = 2.4352
# epoch 100 / 100, step 109/110, loss = 1.8005
# epoch 100 / 100, step 110/110, loss = 2.2443
# epoch 100 / 100, step 1/28, loss = 1.9411
# epoch 100 / 100, step 2/28, loss = 2.0100
# epoch 100 / 100, step 3/28, loss = 2.1392
# epoch 100 / 100, step 4/28, loss = 1.9289
# epoch 100 / 100, step 5/28, loss = 2.1180
# epoch 100 / 100, step 6/28, loss = 2.0542
# epoch 100 / 100, step 7/28, loss = 2.0087
# epoch 100 / 100, step 8/28, loss = 2.0939
# epoch 100 / 100, step 9/28, loss = 1.9190
# epoch 100 / 100, step 10/28, loss = 1.8114
# epoch 100 / 100, step 11/28, loss = 1.8368
# epoch 100 / 100, step 12/28, loss = 1.8201
# epoch 100 / 100, step 13/28, loss = 1.9642
# epoch 100 / 100, step 14/28, loss = 2.0851
# epoch 100 / 100, step 15/28, loss = 1.8598
# epoch 100 / 100, step 16/28, loss = 2.0292
# epoch 100 / 100, step 17/28, loss = 1.8944
# epoch 100 / 100, step 18/28, loss = 1.9185
# epoch 100 / 100, step 19/28, loss = 2.1310
# epoch 100 / 100, step 20/28, loss = 1.9643
# epoch 100 / 100, step 21/28, loss = 1.8266
# epoch 100 / 100, step 22/28, loss = 1.8467
# epoch 100 / 100, step 23/28, loss = 1.8854
# epoch 100 / 100, step 24/28, loss = 2.1074
# epoch 100 / 100, step 25/28, loss = 1.9345
# epoch 100 / 100, step 26/28, loss = 2.2038
# epoch 100 / 100, step 27/28, loss = 1.9115
# epoch 100 / 100, step 28/28, loss = 1.8259

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 100 epochs the trainning accuracy is 14.971428571428572 and the test accuaracy is 15.525114155251142
#  the maximum accuracy of the test was 18.264840182648403 at the epoch 35
#  the maximum accuracy of the train was 19.314285714285713 at the epoch 25
# the accuracy of the training at the best validation accuracy 18.264840182648403 is 15.542857142857143

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
