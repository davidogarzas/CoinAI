# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Different normalization method

# %%
filepath = 'David/Tests/13'
script_dir = os.path.dirname('lstm.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs

# Turns negative values to 0
X[X < 0] = 0

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 50
batch_size = 32
learning_rate = 0.0001
num_layers = 2

input_size = 512 
sequence_length = 1502  
#input_size = 4 
#sequence_length = 28

# %%
# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Find the global minimum and maximum
global_min = np.min(X_train)
global_max = np.max(X_train)

# Apply normalization
X_train = (X_train - global_min) / (global_max - global_min)
X_test = (X_test - global_min) / (global_max - global_min)

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [7.6299475e-05 4.5779685e-05 0.0000000e+00 ... 1.3733906e-04 1.5259895e-05
#  9.1559370e-05]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([7.6299e-05, 4.5780e-05, 0.0000e+00,  ..., 1.3734e-04, 1.5260e-05,
#         9.1559e-05]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([32, 769024]) , Labels shape: torch.Size([32])
# Input range after standardization: Min = 0.0, Max = 0.4878397583961487
# tensor([0.0000, 0.0000, 0.0002,  ..., 0.0000, 0.0000, 0.0000])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6, 5, 6, 6, 3, 2, 3, 4, 3,
#         0, 4, 2, 5, 3, 6, 2, 1])

# %%
# Create Model

# Model 
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        # x -> (batch_size, seq, input_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(p=0.5)  # Inside LSTM clas

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0,c0))

        # Dropout on output of LSTM
        out = self.dropout(out)

        # out: batch_size, seq_length, hidden_size
        # out (N, 6008, 128)
        # : all samples in batch, -1 last time step, : all features in hidden size

        out = out[:, -1, :] 
        
        # out (N, 128)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(512, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 5,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/28, loss = 1.9416
# epoch 1 / 50, step 2/28, loss = 1.9739
# epoch 1 / 50, step 3/28, loss = 1.9322
# epoch 1 / 50, step 4/28, loss = 1.9553
# epoch 1 / 50, step 5/28, loss = 1.9578
# epoch 1 / 50, step 6/28, loss = 1.9446
# epoch 1 / 50, step 7/28, loss = 1.9324
# epoch 1 / 50, step 8/28, loss = 1.9499
# epoch 1 / 50, step 9/28, loss = 1.9485
# epoch 1 / 50, step 10/28, loss = 1.9501
# epoch 1 / 50, step 11/28, loss = 1.9609
# epoch 1 / 50, step 12/28, loss = 1.9324
# epoch 1 / 50, step 13/28, loss = 1.9468
# epoch 1 / 50, step 14/28, loss = 1.9378
# epoch 1 / 50, step 15/28, loss = 1.9492
# epoch 1 / 50, step 16/28, loss = 1.9505
# epoch 1 / 50, step 17/28, loss = 1.9695
# epoch 1 / 50, step 18/28, loss = 1.9663
# epoch 1 / 50, step 19/28, loss = 1.9687
# epoch 1 / 50, step 20/28, loss = 1.9420
# epoch 1 / 50, step 21/28, loss = 1.9527
# epoch 1 / 50, step 22/28, loss = 1.9656
# epoch 1 / 50, step 23/28, loss = 1.9495
# epoch 1 / 50, step 24/28, loss = 1.9453
# epoch 1 / 50, step 25/28, loss = 1.9255
# epoch 1 / 50, step 26/28, loss = 1.9754
# epoch 1 / 50, step 27/28, loss = 1.9525
# epoch 1 / 50, step 28/28, loss = 1.9574
# epoch 1 / 50, step 1/7, loss = 1.9365
# epoch 1 / 50, step 2/7, loss = 1.9495
# epoch 1 / 50, step 3/7, loss = 1.9465
# epoch 1 / 50, step 4/7, loss = 1.9447
# epoch 1 / 50, step 5/7, loss = 1.9631
# epoch 1 / 50, step 6/7, loss = 1.9387
# epoch 1 / 50, step 7/7, loss = 1.9333
# epoch 2 / 50, step 1/28, loss = 1.9594
# epoch 2 / 50, step 2/28, loss = 1.9602
# epoch 2 / 50, step 3/28, loss = 1.9349
# epoch 2 / 50, step 4/28, loss = 1.9505
# epoch 2 / 50, step 5/28, loss = 1.9539
# epoch 2 / 50, step 6/28, loss = 1.9574
# epoch 2 / 50, step 7/28, loss = 1.9450
# epoch 2 / 50, step 8/28, loss = 1.9674
# epoch 2 / 50, step 9/28, loss = 1.9418
# epoch 2 / 50, step 10/28, loss = 1.9490
# epoch 2 / 50, step 11/28, loss = 1.9266
# epoch 2 / 50, step 12/28, loss = 1.9274
# epoch 2 / 50, step 13/28, loss = 1.9490
# epoch 2 / 50, step 14/28, loss = 1.9420
# epoch 2 / 50, step 15/28, loss = 1.9415
# epoch 2 / 50, step 16/28, loss = 1.9260
# epoch 2 / 50, step 17/28, loss = 1.9557
# epoch 2 / 50, step 18/28, loss = 1.9610
# epoch 2 / 50, step 19/28, loss = 1.9472
# epoch 2 / 50, step 20/28, loss = 1.9367
# epoch 2 / 50, step 21/28, loss = 1.9418
# epoch 2 / 50, step 22/28, loss = 1.9794
# epoch 2 / 50, step 23/28, loss = 1.9510
# epoch 2 / 50, step 24/28, loss = 1.9768
# epoch 2 / 50, step 25/28, loss = 1.9529
# epoch 2 / 50, step 26/28, loss = 1.9382
# epoch 2 / 50, step 27/28, loss = 1.9375
# epoch 2 / 50, step 28/28, loss = 1.9343
# epoch 2 / 50, step 1/7, loss = 1.9363
# epoch 2 / 50, step 2/7, loss = 1.9498
# epoch 2 / 50, step 3/7, loss = 1.9415
# epoch 2 / 50, step 4/7, loss = 1.9428
# epoch 2 / 50, step 5/7, loss = 1.9613
# epoch 2 / 50, step 6/7, loss = 1.9371
# epoch 2 / 50, step 7/7, loss = 1.9324
# epoch 3 / 50, step 1/28, loss = 1.9415
# epoch 3 / 50, step 2/28, loss = 1.9482
# epoch 3 / 50, step 3/28, loss = 1.9357
# epoch 3 / 50, step 4/28, loss = 1.9595
# epoch 3 / 50, step 5/28, loss = 1.9585
# epoch 3 / 50, step 6/28, loss = 1.9428
# epoch 3 / 50, step 7/28, loss = 1.9381
# epoch 3 / 50, step 8/28, loss = 1.9545
# epoch 3 / 50, step 9/28, loss = 1.9574
# epoch 3 / 50, step 10/28, loss = 1.9441
# epoch 3 / 50, step 11/28, loss = 1.9428
# epoch 3 / 50, step 12/28, loss = 1.9302
# epoch 3 / 50, step 13/28, loss = 1.9454
# epoch 3 / 50, step 14/28, loss = 1.9674
# epoch 3 / 50, step 15/28, loss = 1.9350
# epoch 3 / 50, step 16/28, loss = 1.9486
# epoch 3 / 50, step 17/28, loss = 1.9361
# epoch 3 / 50, step 18/28, loss = 1.9480
# epoch 3 / 50, step 19/28, loss = 1.9475
# epoch 3 / 50, step 20/28, loss = 1.9429
# epoch 3 / 50, step 21/28, loss = 1.9486
# epoch 3 / 50, step 22/28, loss = 1.9469
# epoch 3 / 50, step 23/28, loss = 1.9433
# epoch 3 / 50, step 24/28, loss = 1.9481
# epoch 3 / 50, step 25/28, loss = 1.9419
# epoch 3 / 50, step 26/28, loss = 1.9377
# epoch 3 / 50, step 27/28, loss = 1.9461
# epoch 3 / 50, step 28/28, loss = 1.9647
# epoch 3 / 50, step 1/7, loss = 1.9377
# epoch 3 / 50, step 2/7, loss = 1.9512
# epoch 3 / 50, step 3/7, loss = 1.9360
# epoch 3 / 50, step 4/7, loss = 1.9422
# epoch 3 / 50, step 5/7, loss = 1.9586
# epoch 3 / 50, step 6/7, loss = 1.9348
# epoch 3 / 50, step 7/7, loss = 1.9318
# epoch 4 / 50, step 1/28, loss = 1.9602
# epoch 4 / 50, step 2/28, loss = 1.9432
# epoch 4 / 50, step 3/28, loss = 1.9525
# epoch 4 / 50, step 4/28, loss = 1.9697
# epoch 4 / 50, step 5/28, loss = 1.9529
# epoch 4 / 50, step 6/28, loss = 1.9541
# epoch 4 / 50, step 7/28, loss = 1.9653
# epoch 4 / 50, step 8/28, loss = 1.9413
# epoch 4 / 50, step 9/28, loss = 1.9221
# epoch 4 / 50, step 10/28, loss = 1.9494
# epoch 4 / 50, step 11/28, loss = 1.9558
# epoch 4 / 50, step 12/28, loss = 1.9350
# epoch 4 / 50, step 13/28, loss = 1.9641
# epoch 4 / 50, step 14/28, loss = 1.9555
# epoch 4 / 50, step 15/28, loss = 1.9570
# epoch 4 / 50, step 16/28, loss = 1.9303
# epoch 4 / 50, step 17/28, loss = 1.9441
# epoch 4 / 50, step 18/28, loss = 1.9328
# epoch 4 / 50, step 19/28, loss = 1.9303
# epoch 4 / 50, step 20/28, loss = 1.9380
# epoch 4 / 50, step 21/28, loss = 1.9255
# epoch 4 / 50, step 22/28, loss = 1.9416
# epoch 4 / 50, step 23/28, loss = 1.9253
# epoch 4 / 50, step 24/28, loss = 1.9438
# epoch 4 / 50, step 25/28, loss = 1.9479
# epoch 4 / 50, step 26/28, loss = 1.9625
# epoch 4 / 50, step 27/28, loss = 1.9169
# epoch 4 / 50, step 28/28, loss = 1.8980
# epoch 4 / 50, step 1/7, loss = 1.9389
# epoch 4 / 50, step 2/7, loss = 1.9520
# epoch 4 / 50, step 3/7, loss = 1.9303
# epoch 4 / 50, step 4/7, loss = 1.9411
# epoch 4 / 50, step 5/7, loss = 1.9556
# epoch 4 / 50, step 6/7, loss = 1.9339
# epoch 4 / 50, step 7/7, loss = 1.9322
# epoch 5 / 50, step 1/28, loss = 1.9440
# epoch 5 / 50, step 2/28, loss = 1.9377
# epoch 5 / 50, step 3/28, loss = 1.9696
# epoch 5 / 50, step 4/28, loss = 1.9298
# epoch 5 / 50, step 5/28, loss = 1.9291
# epoch 5 / 50, step 6/28, loss = 1.9463
# epoch 5 / 50, step 7/28, loss = 1.9497
# epoch 5 / 50, step 8/28, loss = 1.9511
# epoch 5 / 50, step 9/28, loss = 1.9362
# epoch 5 / 50, step 10/28, loss = 1.9287
# epoch 5 / 50, step 11/28, loss = 1.9424
# epoch 5 / 50, step 12/28, loss = 1.9622
# epoch 5 / 50, step 13/28, loss = 1.9431
# epoch 5 / 50, step 14/28, loss = 1.9323
# epoch 5 / 50, step 15/28, loss = 1.9372
# epoch 5 / 50, step 16/28, loss = 1.9350
# epoch 5 / 50, step 17/28, loss = 1.9413
# epoch 5 / 50, step 18/28, loss = 1.9604
# epoch 5 / 50, step 19/28, loss = 1.9569
# epoch 5 / 50, step 20/28, loss = 1.9449
# epoch 5 / 50, step 21/28, loss = 1.9349
# epoch 5 / 50, step 22/28, loss = 1.9354
# epoch 5 / 50, step 23/28, loss = 1.9546
# epoch 5 / 50, step 24/28, loss = 1.9267
# epoch 5 / 50, step 25/28, loss = 1.9498
# epoch 5 / 50, step 26/28, loss = 1.9320
# epoch 5 / 50, step 27/28, loss = 1.9131
# epoch 5 / 50, step 28/28, loss = 1.9544
# epoch 5 / 50, step 1/7, loss = 1.9391
# epoch 5 / 50, step 2/7, loss = 1.9553
# epoch 5 / 50, step 3/7, loss = 1.9237
# epoch 5 / 50, step 4/7, loss = 1.9394
# epoch 5 / 50, step 5/7, loss = 1.9552
# epoch 5 / 50, step 6/7, loss = 1.9317
# epoch 5 / 50, step 7/7, loss = 1.9309
# epoch 6 / 50, step 1/28, loss = 1.9358
# epoch 6 / 50, step 2/28, loss = 1.9270
# epoch 6 / 50, step 3/28, loss = 1.9604
# epoch 6 / 50, step 4/28, loss = 1.9351
# epoch 6 / 50, step 5/28, loss = 1.9351
# epoch 6 / 50, step 6/28, loss = 1.9371
# epoch 6 / 50, step 7/28, loss = 1.9390
# epoch 6 / 50, step 8/28, loss = 1.9252
# epoch 6 / 50, step 9/28, loss = 1.9429
# epoch 6 / 50, step 10/28, loss = 1.9453
# epoch 6 / 50, step 11/28, loss = 1.9515
# epoch 6 / 50, step 12/28, loss = 1.9427
# epoch 6 / 50, step 13/28, loss = 1.9597
# epoch 6 / 50, step 14/28, loss = 1.9244
# epoch 6 / 50, step 15/28, loss = 1.9151
# epoch 6 / 50, step 16/28, loss = 1.9445
# epoch 6 / 50, step 17/28, loss = 1.9589
# epoch 6 / 50, step 18/28, loss = 1.9243
# epoch 6 / 50, step 19/28, loss = 1.9255
# epoch 6 / 50, step 20/28, loss = 1.9540
# epoch 6 / 50, step 21/28, loss = 1.9501
# epoch 6 / 50, step 22/28, loss = 1.9075
# epoch 6 / 50, step 23/28, loss = 1.9389
# epoch 6 / 50, step 24/28, loss = 1.9301
# epoch 6 / 50, step 25/28, loss = 1.9565
# epoch 6 / 50, step 26/28, loss = 1.9366
# epoch 6 / 50, step 27/28, loss = 1.9339
# epoch 6 / 50, step 28/28, loss = 1.9223
# epoch 6 / 50, step 1/7, loss = 1.9409
# epoch 6 / 50, step 2/7, loss = 1.9597
# epoch 6 / 50, step 3/7, loss = 1.9146
# epoch 6 / 50, step 4/7, loss = 1.9381
# epoch 6 / 50, step 5/7, loss = 1.9536
# epoch 6 / 50, step 6/7, loss = 1.9299
# epoch 6 / 50, step 7/7, loss = 1.9308
# epoch 7 / 50, step 1/28, loss = 1.9306
# epoch 7 / 50, step 2/28, loss = 1.9270
# epoch 7 / 50, step 3/28, loss = 1.9575
# epoch 7 / 50, step 4/28, loss = 1.9535
# epoch 7 / 50, step 5/28, loss = 1.9346
# epoch 7 / 50, step 6/28, loss = 1.9412
# epoch 7 / 50, step 7/28, loss = 1.9461
# epoch 7 / 50, step 8/28, loss = 1.9380
# epoch 7 / 50, step 9/28, loss = 1.9554
# epoch 7 / 50, step 10/28, loss = 1.9229
# epoch 7 / 50, step 11/28, loss = 1.9364
# epoch 7 / 50, step 12/28, loss = 1.9496
# epoch 7 / 50, step 13/28, loss = 1.9387
# epoch 7 / 50, step 14/28, loss = 1.9490
# epoch 7 / 50, step 15/28, loss = 1.9286
# epoch 7 / 50, step 16/28, loss = 1.9625
# epoch 7 / 50, step 17/28, loss = 1.9377
# epoch 7 / 50, step 18/28, loss = 1.8991
# epoch 7 / 50, step 19/28, loss = 1.8984
# epoch 7 / 50, step 20/28, loss = 1.9179
# epoch 7 / 50, step 21/28, loss = 1.9506
# epoch 7 / 50, step 22/28, loss = 1.9267
# epoch 7 / 50, step 23/28, loss = 1.9285
# epoch 7 / 50, step 24/28, loss = 1.9446
# epoch 7 / 50, step 25/28, loss = 1.9376
# epoch 7 / 50, step 26/28, loss = 1.9437
# epoch 7 / 50, step 27/28, loss = 1.9834
# epoch 7 / 50, step 28/28, loss = 1.9161
# epoch 7 / 50, step 1/7, loss = 1.9433
# epoch 7 / 50, step 2/7, loss = 1.9646
# epoch 7 / 50, step 3/7, loss = 1.9057
# epoch 7 / 50, step 4/7, loss = 1.9370
# epoch 7 / 50, step 5/7, loss = 1.9527
# epoch 7 / 50, step 6/7, loss = 1.9293
# epoch 7 / 50, step 7/7, loss = 1.9324
# epoch 8 / 50, step 1/28, loss = 1.9404
# epoch 8 / 50, step 2/28, loss = 1.9200
# epoch 8 / 50, step 3/28, loss = 1.9216
# epoch 8 / 50, step 4/28, loss = 1.9505
# epoch 8 / 50, step 5/28, loss = 1.9406
# epoch 8 / 50, step 6/28, loss = 1.9224
# epoch 8 / 50, step 7/28, loss = 1.9270
# epoch 8 / 50, step 8/28, loss = 1.9436
# epoch 8 / 50, step 9/28, loss = 1.9292
# epoch 8 / 50, step 10/28, loss = 1.9073
# epoch 8 / 50, step 11/28, loss = 1.9645
# epoch 8 / 50, step 12/28, loss = 1.9339
# epoch 8 / 50, step 13/28, loss = 1.9294
# epoch 8 / 50, step 14/28, loss = 1.9247
# epoch 8 / 50, step 15/28, loss = 1.9920
# epoch 8 / 50, step 16/28, loss = 1.9176
# epoch 8 / 50, step 17/28, loss = 1.9371
# epoch 8 / 50, step 18/28, loss = 1.9871
# epoch 8 / 50, step 19/28, loss = 1.9217
# epoch 8 / 50, step 20/28, loss = 1.9206
# epoch 8 / 50, step 21/28, loss = 1.9089
# epoch 8 / 50, step 22/28, loss = 1.9336
# epoch 8 / 50, step 23/28, loss = 1.9490
# epoch 8 / 50, step 24/28, loss = 1.8951
# epoch 8 / 50, step 25/28, loss = 1.9683
# epoch 8 / 50, step 26/28, loss = 1.9167
# epoch 8 / 50, step 27/28, loss = 1.9485
# epoch 8 / 50, step 28/28, loss = 1.9571
# epoch 8 / 50, step 1/7, loss = 1.9470
# epoch 8 / 50, step 2/7, loss = 1.9665
# epoch 8 / 50, step 3/7, loss = 1.9010
# epoch 8 / 50, step 4/7, loss = 1.9380
# epoch 8 / 50, step 5/7, loss = 1.9517
# epoch 8 / 50, step 6/7, loss = 1.9296
# epoch 8 / 50, step 7/7, loss = 1.9340
# epoch 9 / 50, step 1/28, loss = 1.9406
# epoch 9 / 50, step 2/28, loss = 1.9594
# epoch 9 / 50, step 3/28, loss = 1.8891
# epoch 9 / 50, step 4/28, loss = 1.9115
# epoch 9 / 50, step 5/28, loss = 1.9045
# epoch 9 / 50, step 6/28, loss = 1.9592
# epoch 9 / 50, step 7/28, loss = 1.9687
# epoch 9 / 50, step 8/28, loss = 1.9449
# epoch 9 / 50, step 9/28, loss = 1.9368
# epoch 9 / 50, step 10/28, loss = 1.9533
# epoch 9 / 50, step 11/28, loss = 1.9271
# epoch 9 / 50, step 12/28, loss = 1.9108
# epoch 9 / 50, step 13/28, loss = 1.8626
# epoch 9 / 50, step 14/28, loss = 1.9090
# epoch 9 / 50, step 15/28, loss = 1.9324
# epoch 9 / 50, step 16/28, loss = 1.9680
# epoch 9 / 50, step 17/28, loss = 1.9146
# epoch 9 / 50, step 18/28, loss = 1.9288
# epoch 9 / 50, step 19/28, loss = 1.9576
# epoch 9 / 50, step 20/28, loss = 1.9295
# epoch 9 / 50, step 21/28, loss = 1.9490
# epoch 9 / 50, step 22/28, loss = 1.8980
# epoch 9 / 50, step 23/28, loss = 1.9248
# epoch 9 / 50, step 24/28, loss = 1.9909
# epoch 9 / 50, step 25/28, loss = 1.9690
# epoch 9 / 50, step 26/28, loss = 1.9041
# epoch 9 / 50, step 27/28, loss = 1.9248
# epoch 9 / 50, step 28/28, loss = 2.0350
# epoch 9 / 50, step 1/7, loss = 1.9516
# epoch 9 / 50, step 2/7, loss = 1.9701
# epoch 9 / 50, step 3/7, loss = 1.8954
# epoch 9 / 50, step 4/7, loss = 1.9399
# epoch 9 / 50, step 5/7, loss = 1.9509
# epoch 9 / 50, step 6/7, loss = 1.9293
# epoch 9 / 50, step 7/7, loss = 1.9360
# epoch 10 / 50, step 1/28, loss = 1.9494
# epoch 10 / 50, step 2/28, loss = 1.9650
# epoch 10 / 50, step 3/28, loss = 1.9279
# epoch 10 / 50, step 4/28, loss = 1.9212
# epoch 10 / 50, step 5/28, loss = 1.9518
# epoch 10 / 50, step 6/28, loss = 1.9293
# epoch 10 / 50, step 7/28, loss = 1.9054
# epoch 10 / 50, step 8/28, loss = 1.9201
# epoch 10 / 50, step 9/28, loss = 1.9479
# epoch 10 / 50, step 10/28, loss = 1.9797
# epoch 10 / 50, step 11/28, loss = 1.9363
# epoch 10 / 50, step 12/28, loss = 1.9163
# epoch 10 / 50, step 13/28, loss = 1.9400
# epoch 10 / 50, step 14/28, loss = 1.9658
# epoch 10 / 50, step 15/28, loss = 1.9483
# epoch 10 / 50, step 16/28, loss = 1.9751
# epoch 10 / 50, step 17/28, loss = 1.9261
# epoch 10 / 50, step 18/28, loss = 1.9482
# epoch 10 / 50, step 19/28, loss = 1.9217
# epoch 10 / 50, step 20/28, loss = 1.9166
# epoch 10 / 50, step 21/28, loss = 1.9104
# epoch 10 / 50, step 22/28, loss = 1.9517
# epoch 10 / 50, step 23/28, loss = 1.9561
# epoch 10 / 50, step 24/28, loss = 1.9326
# epoch 10 / 50, step 25/28, loss = 1.9364
# epoch 10 / 50, step 26/28, loss = 1.9325
# epoch 10 / 50, step 27/28, loss = 1.9218
# epoch 10 / 50, step 28/28, loss = 1.8748
# epoch 10 / 50, step 1/7, loss = 1.9463
# epoch 10 / 50, step 2/7, loss = 1.9662
# epoch 10 / 50, step 3/7, loss = 1.9015
# epoch 10 / 50, step 4/7, loss = 1.9369
# epoch 10 / 50, step 5/7, loss = 1.9530
# epoch 10 / 50, step 6/7, loss = 1.9318
# epoch 10 / 50, step 7/7, loss = 1.9344
# epoch 11 / 50, step 1/28, loss = 1.9394
# epoch 11 / 50, step 2/28, loss = 1.9140
# epoch 11 / 50, step 3/28, loss = 1.9170
# epoch 11 / 50, step 4/28, loss = 1.9231
# epoch 11 / 50, step 5/28, loss = 1.9129
# epoch 11 / 50, step 6/28, loss = 1.9287
# epoch 11 / 50, step 7/28, loss = 1.9077
# epoch 11 / 50, step 8/28, loss = 1.9281
# epoch 11 / 50, step 9/28, loss = 1.9264
# epoch 11 / 50, step 10/28, loss = 1.9617
# epoch 11 / 50, step 11/28, loss = 1.9089
# epoch 11 / 50, step 12/28, loss = 1.9150
# epoch 11 / 50, step 13/28, loss = 1.9033
# epoch 11 / 50, step 14/28, loss = 1.9653
# epoch 11 / 50, step 15/28, loss = 1.9568
# epoch 11 / 50, step 16/28, loss = 1.9222
# epoch 11 / 50, step 17/28, loss = 1.9246
# epoch 11 / 50, step 18/28, loss = 1.9182
# epoch 11 / 50, step 19/28, loss = 1.9376
# epoch 11 / 50, step 20/28, loss = 1.9174
# epoch 11 / 50, step 21/28, loss = 1.9214
# epoch 11 / 50, step 22/28, loss = 1.9297
# epoch 11 / 50, step 23/28, loss = 1.9446
# epoch 11 / 50, step 24/28, loss = 1.9404
# epoch 11 / 50, step 25/28, loss = 1.9860
# epoch 11 / 50, step 26/28, loss = 1.9714
# epoch 11 / 50, step 27/28, loss = 1.9712
# epoch 11 / 50, step 28/28, loss = 1.9754
# epoch 11 / 50, step 1/7, loss = 1.9501
# epoch 11 / 50, step 2/7, loss = 1.9713
# epoch 11 / 50, step 3/7, loss = 1.8937
# epoch 11 / 50, step 4/7, loss = 1.9380
# epoch 11 / 50, step 5/7, loss = 1.9534
# epoch 11 / 50, step 6/7, loss = 1.9311
# epoch 11 / 50, step 7/7, loss = 1.9363
# epoch 12 / 50, step 1/28, loss = 1.9206
# epoch 12 / 50, step 2/28, loss = 1.9252
# epoch 12 / 50, step 3/28, loss = 1.9373
# epoch 12 / 50, step 4/28, loss = 1.9056
# epoch 12 / 50, step 5/28, loss = 1.9359
# epoch 12 / 50, step 6/28, loss = 1.9567
# epoch 12 / 50, step 7/28, loss = 1.9562
# epoch 12 / 50, step 8/28, loss = 1.9234
# epoch 12 / 50, step 9/28, loss = 1.9573
# epoch 12 / 50, step 10/28, loss = 1.9453
# epoch 12 / 50, step 11/28, loss = 1.9380
# epoch 12 / 50, step 12/28, loss = 1.9404
# epoch 12 / 50, step 13/28, loss = 1.9326
# epoch 12 / 50, step 14/28, loss = 1.9427
# epoch 12 / 50, step 15/28, loss = 1.9166
# epoch 12 / 50, step 16/28, loss = 1.9398
# epoch 12 / 50, step 17/28, loss = 1.9281
# epoch 12 / 50, step 18/28, loss = 1.9426
# epoch 12 / 50, step 19/28, loss = 1.9365
# epoch 12 / 50, step 20/28, loss = 1.9501
# epoch 12 / 50, step 21/28, loss = 1.8966
# epoch 12 / 50, step 22/28, loss = 1.9041
# epoch 12 / 50, step 23/28, loss = 1.9464
# epoch 12 / 50, step 24/28, loss = 1.9022
# epoch 12 / 50, step 25/28, loss = 1.9000
# epoch 12 / 50, step 26/28, loss = 1.9716
# epoch 12 / 50, step 27/28, loss = 1.9412
# epoch 12 / 50, step 28/28, loss = 1.9172
# epoch 12 / 50, step 1/7, loss = 1.9485
# epoch 12 / 50, step 2/7, loss = 1.9678
# epoch 12 / 50, step 3/7, loss = 1.8977
# epoch 12 / 50, step 4/7, loss = 1.9376
# epoch 12 / 50, step 5/7, loss = 1.9517
# epoch 12 / 50, step 6/7, loss = 1.9315
# epoch 12 / 50, step 7/7, loss = 1.9360
# epoch 13 / 50, step 1/28, loss = 1.9019
# epoch 13 / 50, step 2/28, loss = 1.9440
# epoch 13 / 50, step 3/28, loss = 1.9070
# epoch 13 / 50, step 4/28, loss = 1.9718
# epoch 13 / 50, step 5/28, loss = 1.9001
# epoch 13 / 50, step 6/28, loss = 1.9093
# epoch 13 / 50, step 7/28, loss = 1.9500
# epoch 13 / 50, step 8/28, loss = 1.9033
# epoch 13 / 50, step 9/28, loss = 1.9880
# epoch 13 / 50, step 10/28, loss = 1.9519
# epoch 13 / 50, step 11/28, loss = 1.9264
# epoch 13 / 50, step 12/28, loss = 1.9341
# epoch 13 / 50, step 13/28, loss = 1.9477
# epoch 13 / 50, step 14/28, loss = 1.9409
# epoch 13 / 50, step 15/28, loss = 1.9397
# epoch 13 / 50, step 16/28, loss = 1.9315
# epoch 13 / 50, step 17/28, loss = 1.9705
# epoch 13 / 50, step 18/28, loss = 1.9036
# epoch 13 / 50, step 19/28, loss = 1.8676
# epoch 13 / 50, step 20/28, loss = 1.9493
# epoch 13 / 50, step 21/28, loss = 1.9474
# epoch 13 / 50, step 22/28, loss = 1.9044
# epoch 13 / 50, step 23/28, loss = 1.9466
# epoch 13 / 50, step 24/28, loss = 1.9362
# epoch 13 / 50, step 25/28, loss = 1.9420
# epoch 13 / 50, step 26/28, loss = 1.9104
# epoch 13 / 50, step 27/28, loss = 1.9298
# epoch 13 / 50, step 28/28, loss = 1.9053
# epoch 13 / 50, step 1/7, loss = 1.9503
# epoch 13 / 50, step 2/7, loss = 1.9711
# epoch 13 / 50, step 3/7, loss = 1.8951
# epoch 13 / 50, step 4/7, loss = 1.9383
# epoch 13 / 50, step 5/7, loss = 1.9519
# epoch 13 / 50, step 6/7, loss = 1.9318
# epoch 13 / 50, step 7/7, loss = 1.9365
# epoch 14 / 50, step 1/28, loss = 1.9747
# epoch 14 / 50, step 2/28, loss = 1.9028
# epoch 14 / 50, step 3/28, loss = 1.9577
# epoch 14 / 50, step 4/28, loss = 1.9422
# epoch 14 / 50, step 5/28, loss = 1.9111
# epoch 14 / 50, step 6/28, loss = 1.9255
# epoch 14 / 50, step 7/28, loss = 1.8751
# epoch 14 / 50, step 8/28, loss = 1.9580
# epoch 14 / 50, step 9/28, loss = 1.8862
# epoch 14 / 50, step 10/28, loss = 1.9460
# epoch 14 / 50, step 11/28, loss = 1.9313
# epoch 14 / 50, step 12/28, loss = 1.9307
# epoch 14 / 50, step 13/28, loss = 1.9271
# epoch 14 / 50, step 14/28, loss = 1.9534
# epoch 14 / 50, step 15/28, loss = 1.9031
# epoch 14 / 50, step 16/28, loss = 1.8959
# epoch 14 / 50, step 17/28, loss = 1.9312
# epoch 14 / 50, step 18/28, loss = 1.9219
# epoch 14 / 50, step 19/28, loss = 1.9947
# epoch 14 / 50, step 20/28, loss = 1.9833
# epoch 14 / 50, step 21/28, loss = 1.9622
# epoch 14 / 50, step 22/28, loss = 1.9374
# epoch 14 / 50, step 23/28, loss = 1.9635
# epoch 14 / 50, step 24/28, loss = 1.9531
# epoch 14 / 50, step 25/28, loss = 1.8662
# epoch 14 / 50, step 26/28, loss = 1.9515
# epoch 14 / 50, step 27/28, loss = 1.9542
# epoch 14 / 50, step 28/28, loss = 2.0043
# epoch 14 / 50, step 1/7, loss = 1.9483
# epoch 14 / 50, step 2/7, loss = 1.9723
# epoch 14 / 50, step 3/7, loss = 1.8947
# epoch 14 / 50, step 4/7, loss = 1.9364
# epoch 14 / 50, step 5/7, loss = 1.9548
# epoch 14 / 50, step 6/7, loss = 1.9330
# epoch 14 / 50, step 7/7, loss = 1.9360
# epoch 15 / 50, step 1/28, loss = 1.9234
# epoch 15 / 50, step 2/28, loss = 1.9448
# epoch 15 / 50, step 3/28, loss = 1.9134
# epoch 15 / 50, step 4/28, loss = 1.9741
# epoch 15 / 50, step 5/28, loss = 1.9530
# epoch 15 / 50, step 6/28, loss = 1.9179
# epoch 15 / 50, step 7/28, loss = 1.9207
# epoch 15 / 50, step 8/28, loss = 1.8870
# epoch 15 / 50, step 9/28, loss = 1.9218
# epoch 15 / 50, step 10/28, loss = 1.9468
# epoch 15 / 50, step 11/28, loss = 1.9683
# epoch 15 / 50, step 12/28, loss = 1.9115
# epoch 15 / 50, step 13/28, loss = 1.9238
# epoch 15 / 50, step 14/28, loss = 1.9379
# epoch 15 / 50, step 15/28, loss = 1.9846
# epoch 15 / 50, step 16/28, loss = 1.9840
# epoch 15 / 50, step 17/28, loss = 1.9723
# epoch 15 / 50, step 18/28, loss = 1.9215
# epoch 15 / 50, step 19/28, loss = 1.9422
# epoch 15 / 50, step 20/28, loss = 1.9324
# epoch 15 / 50, step 21/28, loss = 1.9513
# epoch 15 / 50, step 22/28, loss = 1.9564
# epoch 15 / 50, step 23/28, loss = 1.9594
# epoch 15 / 50, step 24/28, loss = 1.9177
# epoch 15 / 50, step 25/28, loss = 1.9183
# epoch 15 / 50, step 26/28, loss = 1.8642
# epoch 15 / 50, step 27/28, loss = 1.9020
# epoch 15 / 50, step 28/28, loss = 1.9861
# epoch 15 / 50, step 1/7, loss = 1.9471
# epoch 15 / 50, step 2/7, loss = 1.9663
# epoch 15 / 50, step 3/7, loss = 1.9009
# epoch 15 / 50, step 4/7, loss = 1.9372
# epoch 15 / 50, step 5/7, loss = 1.9520
# epoch 15 / 50, step 6/7, loss = 1.9331
# epoch 15 / 50, step 7/7, loss = 1.9353
# epoch 16 / 50, step 1/28, loss = 1.9336
# epoch 16 / 50, step 2/28, loss = 1.9352
# epoch 16 / 50, step 3/28, loss = 1.9725
# epoch 16 / 50, step 4/28, loss = 1.9628
# epoch 16 / 50, step 5/28, loss = 1.9342
# epoch 16 / 50, step 6/28, loss = 1.8906
# epoch 16 / 50, step 7/28, loss = 1.9270
# epoch 16 / 50, step 8/28, loss = 1.9070
# epoch 16 / 50, step 9/28, loss = 1.9414
# epoch 16 / 50, step 10/28, loss = 1.9235
# epoch 16 / 50, step 11/28, loss = 1.9078
# epoch 16 / 50, step 12/28, loss = 1.9465
# epoch 16 / 50, step 13/28, loss = 1.9053
# epoch 16 / 50, step 14/28, loss = 1.9458
# epoch 16 / 50, step 15/28, loss = 1.9232
# epoch 16 / 50, step 16/28, loss = 1.9457
# epoch 16 / 50, step 17/28, loss = 1.9712
# epoch 16 / 50, step 18/28, loss = 1.9055
# epoch 16 / 50, step 19/28, loss = 1.9560
# epoch 16 / 50, step 20/28, loss = 1.9174
# epoch 16 / 50, step 21/28, loss = 1.9494
# epoch 16 / 50, step 22/28, loss = 1.9693
# epoch 16 / 50, step 23/28, loss = 1.9547
# epoch 16 / 50, step 24/28, loss = 1.9123
# epoch 16 / 50, step 25/28, loss = 1.9133
# epoch 16 / 50, step 26/28, loss = 1.9349
# epoch 16 / 50, step 27/28, loss = 1.9175
# epoch 16 / 50, step 28/28, loss = 1.9989
# epoch 16 / 50, step 1/7, loss = 1.9482
# epoch 16 / 50, step 2/7, loss = 1.9680
# epoch 16 / 50, step 3/7, loss = 1.8979
# epoch 16 / 50, step 4/7, loss = 1.9371
# epoch 16 / 50, step 5/7, loss = 1.9517
# epoch 16 / 50, step 6/7, loss = 1.9339
# epoch 16 / 50, step 7/7, loss = 1.9366
# epoch 17 / 50, step 1/28, loss = 1.9505
# epoch 17 / 50, step 2/28, loss = 1.9146
# epoch 17 / 50, step 3/28, loss = 1.9671
# epoch 17 / 50, step 4/28, loss = 1.9989
# epoch 17 / 50, step 5/28, loss = 1.9447
# epoch 17 / 50, step 6/28, loss = 1.9312
# epoch 17 / 50, step 7/28, loss = 1.9293
# epoch 17 / 50, step 8/28, loss = 1.9450
# epoch 17 / 50, step 9/28, loss = 1.9424
# epoch 17 / 50, step 10/28, loss = 1.9541
# epoch 17 / 50, step 11/28, loss = 1.9391
# epoch 17 / 50, step 12/28, loss = 1.9154
# epoch 17 / 50, step 13/28, loss = 1.8910
# epoch 17 / 50, step 14/28, loss = 1.9015
# epoch 17 / 50, step 15/28, loss = 1.9347
# epoch 17 / 50, step 16/28, loss = 1.9798
# epoch 17 / 50, step 17/28, loss = 1.8990
# epoch 17 / 50, step 18/28, loss = 1.9458
# epoch 17 / 50, step 19/28, loss = 1.9397
# epoch 17 / 50, step 20/28, loss = 1.9301
# epoch 17 / 50, step 21/28, loss = 1.9269
# epoch 17 / 50, step 22/28, loss = 1.9245
# epoch 17 / 50, step 23/28, loss = 1.9031
# epoch 17 / 50, step 24/28, loss = 1.9194
# epoch 17 / 50, step 25/28, loss = 1.9723
# epoch 17 / 50, step 26/28, loss = 1.9687
# epoch 17 / 50, step 27/28, loss = 1.9086
# epoch 17 / 50, step 28/28, loss = 1.8902
# epoch 17 / 50, step 1/7, loss = 1.9469
# epoch 17 / 50, step 2/7, loss = 1.9664
# epoch 17 / 50, step 3/7, loss = 1.8997
# epoch 17 / 50, step 4/7, loss = 1.9367
# epoch 17 / 50, step 5/7, loss = 1.9519
# epoch 17 / 50, step 6/7, loss = 1.9327
# epoch 17 / 50, step 7/7, loss = 1.9357
# epoch 18 / 50, step 1/28, loss = 1.9347
# epoch 18 / 50, step 2/28, loss = 1.9275
# epoch 18 / 50, step 3/28, loss = 1.9353
# epoch 18 / 50, step 4/28, loss = 1.9350
# epoch 18 / 50, step 5/28, loss = 1.9272
# epoch 18 / 50, step 6/28, loss = 1.9100
# epoch 18 / 50, step 7/28, loss = 1.9344
# epoch 18 / 50, step 8/28, loss = 1.9195
# epoch 18 / 50, step 9/28, loss = 1.9718
# epoch 18 / 50, step 10/28, loss = 1.8901
# epoch 18 / 50, step 11/28, loss = 1.8966
# epoch 18 / 50, step 12/28, loss = 1.9372
# epoch 18 / 50, step 13/28, loss = 1.9086
# epoch 18 / 50, step 14/28, loss = 1.9725
# epoch 18 / 50, step 15/28, loss = 1.9373
# epoch 18 / 50, step 16/28, loss = 1.9074
# epoch 18 / 50, step 17/28, loss = 1.9472
# epoch 18 / 50, step 18/28, loss = 1.8960
# epoch 18 / 50, step 19/28, loss = 1.9292
# epoch 18 / 50, step 20/28, loss = 1.9850
# epoch 18 / 50, step 21/28, loss = 1.9223
# epoch 18 / 50, step 22/28, loss = 1.9485
# epoch 18 / 50, step 23/28, loss = 1.9333
# epoch 18 / 50, step 24/28, loss = 1.9802
# epoch 18 / 50, step 25/28, loss = 1.9951
# epoch 18 / 50, step 26/28, loss = 1.8773
# epoch 18 / 50, step 27/28, loss = 1.9721
# epoch 18 / 50, step 28/28, loss = 1.8674
# epoch 18 / 50, step 1/7, loss = 1.9478
# epoch 18 / 50, step 2/7, loss = 1.9710
# epoch 18 / 50, step 3/7, loss = 1.8950
# epoch 18 / 50, step 4/7, loss = 1.9368
# epoch 18 / 50, step 5/7, loss = 1.9535
# epoch 18 / 50, step 6/7, loss = 1.9328
# epoch 18 / 50, step 7/7, loss = 1.9356
# epoch 19 / 50, step 1/28, loss = 1.9036
# epoch 19 / 50, step 2/28, loss = 1.9318
# epoch 19 / 50, step 3/28, loss = 1.9241
# epoch 19 / 50, step 4/28, loss = 1.8964
# epoch 19 / 50, step 5/28, loss = 1.9208
# epoch 19 / 50, step 6/28, loss = 1.8955
# epoch 19 / 50, step 7/28, loss = 1.9213
# epoch 19 / 50, step 8/28, loss = 1.9526
# epoch 19 / 50, step 9/28, loss = 1.9751
# epoch 19 / 50, step 10/28, loss = 1.9525
# epoch 19 / 50, step 11/28, loss = 1.9582
# epoch 19 / 50, step 12/28, loss = 1.9697
# epoch 19 / 50, step 13/28, loss = 1.9363
# epoch 19 / 50, step 14/28, loss = 1.9533
# epoch 19 / 50, step 15/28, loss = 1.9778
# epoch 19 / 50, step 16/28, loss = 1.9300
# epoch 19 / 50, step 17/28, loss = 1.9551
# epoch 19 / 50, step 18/28, loss = 1.9375
# epoch 19 / 50, step 19/28, loss = 1.9331
# epoch 19 / 50, step 20/28, loss = 1.9273
# epoch 19 / 50, step 21/28, loss = 1.9604
# epoch 19 / 50, step 22/28, loss = 1.8984
# epoch 19 / 50, step 23/28, loss = 1.9301
# epoch 19 / 50, step 24/28, loss = 1.9202
# epoch 19 / 50, step 25/28, loss = 1.9092
# epoch 19 / 50, step 26/28, loss = 1.9690
# epoch 19 / 50, step 27/28, loss = 1.9127
# epoch 19 / 50, step 28/28, loss = 1.8992
# epoch 19 / 50, step 1/7, loss = 1.9499
# epoch 19 / 50, step 2/7, loss = 1.9696
# epoch 19 / 50, step 3/7, loss = 1.8953
# epoch 19 / 50, step 4/7, loss = 1.9377
# epoch 19 / 50, step 5/7, loss = 1.9514
# epoch 19 / 50, step 6/7, loss = 1.9331
# epoch 19 / 50, step 7/7, loss = 1.9374
# epoch 20 / 50, step 1/28, loss = 1.9508
# epoch 20 / 50, step 2/28, loss = 1.9545
# epoch 20 / 50, step 3/28, loss = 1.9138
# epoch 20 / 50, step 4/28, loss = 1.9533
# epoch 20 / 50, step 5/28, loss = 1.9840
# epoch 20 / 50, step 6/28, loss = 1.9562
# epoch 20 / 50, step 7/28, loss = 1.9346
# epoch 20 / 50, step 8/28, loss = 1.9294
# epoch 20 / 50, step 9/28, loss = 1.9109
# epoch 20 / 50, step 10/28, loss = 1.9526
# epoch 20 / 50, step 11/28, loss = 1.9120
# epoch 20 / 50, step 12/28, loss = 1.9790
# epoch 20 / 50, step 13/28, loss = 1.9488
# epoch 20 / 50, step 14/28, loss = 1.9111
# epoch 20 / 50, step 15/28, loss = 1.9069
# epoch 20 / 50, step 16/28, loss = 1.9008
# epoch 20 / 50, step 17/28, loss = 1.9389
# epoch 20 / 50, step 18/28, loss = 1.9253
# epoch 20 / 50, step 19/28, loss = 1.9316
# epoch 20 / 50, step 20/28, loss = 1.8957
# epoch 20 / 50, step 21/28, loss = 1.9359
# epoch 20 / 50, step 22/28, loss = 1.8799
# epoch 20 / 50, step 23/28, loss = 1.9932
# epoch 20 / 50, step 24/28, loss = 1.9590
# epoch 20 / 50, step 25/28, loss = 1.9648
# epoch 20 / 50, step 26/28, loss = 1.9189
# epoch 20 / 50, step 27/28, loss = 1.9798
# epoch 20 / 50, step 28/28, loss = 1.9722
# epoch 20 / 50, step 1/7, loss = 1.9477
# epoch 20 / 50, step 2/7, loss = 1.9703
# epoch 20 / 50, step 3/7, loss = 1.8958
# epoch 20 / 50, step 4/7, loss = 1.9359
# epoch 20 / 50, step 5/7, loss = 1.9537
# epoch 20 / 50, step 6/7, loss = 1.9347
# epoch 20 / 50, step 7/7, loss = 1.9369
# epoch 21 / 50, step 1/28, loss = 1.9577
# epoch 21 / 50, step 2/28, loss = 1.9647
# epoch 21 / 50, step 3/28, loss = 1.9386
# epoch 21 / 50, step 4/28, loss = 1.9691
# epoch 21 / 50, step 5/28, loss = 1.9631
# epoch 21 / 50, step 6/28, loss = 1.9278
# epoch 21 / 50, step 7/28, loss = 1.9342
# epoch 21 / 50, step 8/28, loss = 1.9398
# epoch 21 / 50, step 9/28, loss = 1.9531
# epoch 21 / 50, step 10/28, loss = 1.9531
# epoch 21 / 50, step 11/28, loss = 1.9578
# epoch 21 / 50, step 12/28, loss = 1.9140
# epoch 21 / 50, step 13/28, loss = 1.9380
# epoch 21 / 50, step 14/28, loss = 1.9281
# epoch 21 / 50, step 15/28, loss = 1.9357
# epoch 21 / 50, step 16/28, loss = 1.8863
# epoch 21 / 50, step 17/28, loss = 1.9180
# epoch 21 / 50, step 18/28, loss = 1.9623
# epoch 21 / 50, step 19/28, loss = 1.8910
# epoch 21 / 50, step 20/28, loss = 1.9005
# epoch 21 / 50, step 21/28, loss = 1.9484
# epoch 21 / 50, step 22/28, loss = 1.9506
# epoch 21 / 50, step 23/28, loss = 1.8882
# epoch 21 / 50, step 24/28, loss = 1.9105
# epoch 21 / 50, step 25/28, loss = 1.9137
# epoch 21 / 50, step 26/28, loss = 1.8803
# epoch 21 / 50, step 27/28, loss = 1.9878
# epoch 21 / 50, step 28/28, loss = 1.9790
# epoch 21 / 50, step 1/7, loss = 1.9453
# epoch 21 / 50, step 2/7, loss = 1.9684
# epoch 21 / 50, step 3/7, loss = 1.8989
# epoch 21 / 50, step 4/7, loss = 1.9360
# epoch 21 / 50, step 5/7, loss = 1.9540
# epoch 21 / 50, step 6/7, loss = 1.9327
# epoch 21 / 50, step 7/7, loss = 1.9341
# epoch 22 / 50, step 1/28, loss = 1.9548
# epoch 22 / 50, step 2/28, loss = 1.9258
# epoch 22 / 50, step 3/28, loss = 1.9357
# epoch 22 / 50, step 4/28, loss = 1.9348
# epoch 22 / 50, step 5/28, loss = 1.9526
# epoch 22 / 50, step 6/28, loss = 1.9163
# epoch 22 / 50, step 7/28, loss = 1.9582
# epoch 22 / 50, step 8/28, loss = 1.9240
# epoch 22 / 50, step 9/28, loss = 1.9026
# epoch 22 / 50, step 10/28, loss = 1.8950
# epoch 22 / 50, step 11/28, loss = 1.9398
# epoch 22 / 50, step 12/28, loss = 1.9110
# epoch 22 / 50, step 13/28, loss = 1.9409
# epoch 22 / 50, step 14/28, loss = 1.9586
# epoch 22 / 50, step 15/28, loss = 1.9304
# epoch 22 / 50, step 16/28, loss = 1.9326
# epoch 22 / 50, step 17/28, loss = 1.9817
# epoch 22 / 50, step 18/28, loss = 1.9718
# epoch 22 / 50, step 19/28, loss = 1.9408
# epoch 22 / 50, step 20/28, loss = 1.9471
# epoch 22 / 50, step 21/28, loss = 1.9487
# epoch 22 / 50, step 22/28, loss = 1.9514
# epoch 22 / 50, step 23/28, loss = 1.9368
# epoch 22 / 50, step 24/28, loss = 1.9235
# epoch 22 / 50, step 25/28, loss = 1.9485
# epoch 22 / 50, step 26/28, loss = 1.9353
# epoch 22 / 50, step 27/28, loss = 1.9336
# epoch 22 / 50, step 28/28, loss = 1.9423
# epoch 22 / 50, step 1/7, loss = 1.9476
# epoch 22 / 50, step 2/7, loss = 1.9689
# epoch 22 / 50, step 3/7, loss = 1.8980
# epoch 22 / 50, step 4/7, loss = 1.9366
# epoch 22 / 50, step 5/7, loss = 1.9525
# epoch 22 / 50, step 6/7, loss = 1.9335
# epoch 22 / 50, step 7/7, loss = 1.9362
# epoch 23 / 50, step 1/28, loss = 1.9130
# epoch 23 / 50, step 2/28, loss = 1.9504
# epoch 23 / 50, step 3/28, loss = 1.9137
# epoch 23 / 50, step 4/28, loss = 1.9428
# epoch 23 / 50, step 5/28, loss = 1.9581
# epoch 23 / 50, step 6/28, loss = 1.9129
# epoch 23 / 50, step 7/28, loss = 1.9063
# epoch 23 / 50, step 8/28, loss = 1.9374
# epoch 23 / 50, step 9/28, loss = 1.8613
# epoch 23 / 50, step 10/28, loss = 1.8764
# epoch 23 / 50, step 11/28, loss = 1.9669
# epoch 23 / 50, step 12/28, loss = 1.9795
# epoch 23 / 50, step 13/28, loss = 1.9351
# epoch 23 / 50, step 14/28, loss = 1.9566
# epoch 23 / 50, step 15/28, loss = 1.9837
# epoch 23 / 50, step 16/28, loss = 1.9205
# epoch 23 / 50, step 17/28, loss = 1.9494
# epoch 23 / 50, step 18/28, loss = 2.0300
# epoch 23 / 50, step 19/28, loss = 1.9500
# epoch 23 / 50, step 20/28, loss = 1.9318
# epoch 23 / 50, step 21/28, loss = 1.9368
# epoch 23 / 50, step 22/28, loss = 1.9081
# epoch 23 / 50, step 23/28, loss = 1.9305
# epoch 23 / 50, step 24/28, loss = 1.9315
# epoch 23 / 50, step 25/28, loss = 1.9097
# epoch 23 / 50, step 26/28, loss = 1.9215
# epoch 23 / 50, step 27/28, loss = 1.8948
# epoch 23 / 50, step 28/28, loss = 1.9598
# epoch 23 / 50, step 1/7, loss = 1.9467
# epoch 23 / 50, step 2/7, loss = 1.9687
# epoch 23 / 50, step 3/7, loss = 1.8982
# epoch 23 / 50, step 4/7, loss = 1.9365
# epoch 23 / 50, step 5/7, loss = 1.9522
# epoch 23 / 50, step 6/7, loss = 1.9331
# epoch 23 / 50, step 7/7, loss = 1.9356
# epoch 24 / 50, step 1/28, loss = 1.9348
# epoch 24 / 50, step 2/28, loss = 1.9410
# epoch 24 / 50, step 3/28, loss = 1.9368
# epoch 24 / 50, step 4/28, loss = 1.9406
# epoch 24 / 50, step 5/28, loss = 1.9669
# epoch 24 / 50, step 6/28, loss = 1.9733
# epoch 24 / 50, step 7/28, loss = 1.9718
# epoch 24 / 50, step 8/28, loss = 1.9536
# epoch 24 / 50, step 9/28, loss = 1.9065
# epoch 24 / 50, step 10/28, loss = 1.9551
# epoch 24 / 50, step 11/28, loss = 1.9117
# epoch 24 / 50, step 12/28, loss = 1.9202
# epoch 24 / 50, step 13/28, loss = 1.9405
# epoch 24 / 50, step 14/28, loss = 1.9622
# epoch 24 / 50, step 15/28, loss = 1.9207
# epoch 24 / 50, step 16/28, loss = 1.9400
# epoch 24 / 50, step 17/28, loss = 1.9423
# epoch 24 / 50, step 18/28, loss = 1.9228
# epoch 24 / 50, step 19/28, loss = 1.8816
# epoch 24 / 50, step 20/28, loss = 1.9341
# epoch 24 / 50, step 21/28, loss = 1.9138
# epoch 24 / 50, step 22/28, loss = 1.9415
# epoch 24 / 50, step 23/28, loss = 1.9488
# epoch 24 / 50, step 24/28, loss = 1.8941
# epoch 24 / 50, step 25/28, loss = 1.9127
# epoch 24 / 50, step 26/28, loss = 1.9478
# epoch 24 / 50, step 27/28, loss = 1.9304
# epoch 24 / 50, step 28/28, loss = 1.8603
# epoch 24 / 50, step 1/7, loss = 1.9476
# epoch 24 / 50, step 2/7, loss = 1.9696
# epoch 24 / 50, step 3/7, loss = 1.8978
# epoch 24 / 50, step 4/7, loss = 1.9370
# epoch 24 / 50, step 5/7, loss = 1.9518
# epoch 24 / 50, step 6/7, loss = 1.9330
# epoch 24 / 50, step 7/7, loss = 1.9358
# epoch 25 / 50, step 1/28, loss = 1.9161
# epoch 25 / 50, step 2/28, loss = 1.9281
# epoch 25 / 50, step 3/28, loss = 1.9469
# epoch 25 / 50, step 4/28, loss = 1.9397
# epoch 25 / 50, step 5/28, loss = 1.9566
# epoch 25 / 50, step 6/28, loss = 1.9123
# epoch 25 / 50, step 7/28, loss = 1.9149
# epoch 25 / 50, step 8/28, loss = 1.9965
# epoch 25 / 50, step 9/28, loss = 1.9305
# epoch 25 / 50, step 10/28, loss = 1.9202
# epoch 25 / 50, step 11/28, loss = 1.9280
# epoch 25 / 50, step 12/28, loss = 1.9774
# epoch 25 / 50, step 13/28, loss = 1.9258
# epoch 25 / 50, step 14/28, loss = 1.9253
# epoch 25 / 50, step 15/28, loss = 1.9302
# epoch 25 / 50, step 16/28, loss = 1.9460
# epoch 25 / 50, step 17/28, loss = 1.9695
# epoch 25 / 50, step 18/28, loss = 1.9504
# epoch 25 / 50, step 19/28, loss = 1.9345
# epoch 25 / 50, step 20/28, loss = 1.8677
# epoch 25 / 50, step 21/28, loss = 1.9074
# epoch 25 / 50, step 22/28, loss = 1.9193
# epoch 25 / 50, step 23/28, loss = 1.9172
# epoch 25 / 50, step 24/28, loss = 1.9407
# epoch 25 / 50, step 25/28, loss = 1.9255
# epoch 25 / 50, step 26/28, loss = 1.9282
# epoch 25 / 50, step 27/28, loss = 1.9236
# epoch 25 / 50, step 28/28, loss = 2.0055
# epoch 25 / 50, step 1/7, loss = 1.9491
# epoch 25 / 50, step 2/7, loss = 1.9730
# epoch 25 / 50, step 3/7, loss = 1.8946
# epoch 25 / 50, step 4/7, loss = 1.9375
# epoch 25 / 50, step 5/7, loss = 1.9526
# epoch 25 / 50, step 6/7, loss = 1.9334
# epoch 25 / 50, step 7/7, loss = 1.9361
# epoch 26 / 50, step 1/28, loss = 1.8974
# epoch 26 / 50, step 2/28, loss = 1.9711
# epoch 26 / 50, step 3/28, loss = 1.9521
# epoch 26 / 50, step 4/28, loss = 1.9617
# epoch 26 / 50, step 5/28, loss = 1.9660
# epoch 26 / 50, step 6/28, loss = 1.9547
# epoch 26 / 50, step 7/28, loss = 1.9391
# epoch 26 / 50, step 8/28, loss = 1.9366
# epoch 26 / 50, step 9/28, loss = 1.8985
# epoch 26 / 50, step 10/28, loss = 1.9831
# epoch 26 / 50, step 11/28, loss = 1.9516
# epoch 26 / 50, step 12/28, loss = 1.9278
# epoch 26 / 50, step 13/28, loss = 1.9008
# epoch 26 / 50, step 14/28, loss = 1.9215
# epoch 26 / 50, step 15/28, loss = 1.9193
# epoch 26 / 50, step 16/28, loss = 1.9132
# epoch 26 / 50, step 17/28, loss = 1.9601
# epoch 26 / 50, step 18/28, loss = 1.9367
# epoch 26 / 50, step 19/28, loss = 1.9420
# epoch 26 / 50, step 20/28, loss = 1.9000
# epoch 26 / 50, step 21/28, loss = 1.9246
# epoch 26 / 50, step 22/28, loss = 1.9182
# epoch 26 / 50, step 23/28, loss = 1.9197
# epoch 26 / 50, step 24/28, loss = 1.9178
# epoch 26 / 50, step 25/28, loss = 1.9942
# epoch 26 / 50, step 26/28, loss = 1.9101
# epoch 26 / 50, step 27/28, loss = 1.9257
# epoch 26 / 50, step 28/28, loss = 1.8623
# epoch 26 / 50, step 1/7, loss = 1.9507
# epoch 26 / 50, step 2/7, loss = 1.9721
# epoch 26 / 50, step 3/7, loss = 1.8942
# epoch 26 / 50, step 4/7, loss = 1.9384
# epoch 26 / 50, step 5/7, loss = 1.9505
# epoch 26 / 50, step 6/7, loss = 1.9333
# epoch 26 / 50, step 7/7, loss = 1.9375
# epoch 27 / 50, step 1/28, loss = 1.9918
# epoch 27 / 50, step 2/28, loss = 1.9189
# epoch 27 / 50, step 3/28, loss = 1.9008
# epoch 27 / 50, step 4/28, loss = 1.9232
# epoch 27 / 50, step 5/28, loss = 1.9267
# epoch 27 / 50, step 6/28, loss = 1.9448
# epoch 27 / 50, step 7/28, loss = 1.9299
# epoch 27 / 50, step 8/28, loss = 1.9013
# epoch 27 / 50, step 9/28, loss = 1.9611
# epoch 27 / 50, step 10/28, loss = 1.9971
# epoch 27 / 50, step 11/28, loss = 1.9270
# epoch 27 / 50, step 12/28, loss = 1.9242
# epoch 27 / 50, step 13/28, loss = 1.9307
# epoch 27 / 50, step 14/28, loss = 1.9485
# epoch 27 / 50, step 15/28, loss = 1.8938
# epoch 27 / 50, step 16/28, loss = 1.9255
# epoch 27 / 50, step 17/28, loss = 1.9216
# epoch 27 / 50, step 18/28, loss = 1.9723
# epoch 27 / 50, step 19/28, loss = 1.9201
# epoch 27 / 50, step 20/28, loss = 1.9115
# epoch 27 / 50, step 21/28, loss = 1.9553
# epoch 27 / 50, step 22/28, loss = 1.9615
# epoch 27 / 50, step 23/28, loss = 1.9170
# epoch 27 / 50, step 24/28, loss = 1.9171
# epoch 27 / 50, step 25/28, loss = 1.9269
# epoch 27 / 50, step 26/28, loss = 1.9430
# epoch 27 / 50, step 27/28, loss = 1.9289
# epoch 27 / 50, step 28/28, loss = 1.9313
# epoch 27 / 50, step 1/7, loss = 1.9516
# epoch 27 / 50, step 2/7, loss = 1.9730
# epoch 27 / 50, step 3/7, loss = 1.8922
# epoch 27 / 50, step 4/7, loss = 1.9382
# epoch 27 / 50, step 5/7, loss = 1.9514
# epoch 27 / 50, step 6/7, loss = 1.9338
# epoch 27 / 50, step 7/7, loss = 1.9385
# epoch 28 / 50, step 1/28, loss = 1.8915
# epoch 28 / 50, step 2/28, loss = 1.9116
# epoch 28 / 50, step 3/28, loss = 1.9484
# epoch 28 / 50, step 4/28, loss = 1.9642
# epoch 28 / 50, step 5/28, loss = 1.9105
# epoch 28 / 50, step 6/28, loss = 1.8653
# epoch 28 / 50, step 7/28, loss = 1.9167
# epoch 28 / 50, step 8/28, loss = 1.9782
# epoch 28 / 50, step 9/28, loss = 1.9724
# epoch 28 / 50, step 10/28, loss = 1.9463
# epoch 28 / 50, step 11/28, loss = 1.9371
# epoch 28 / 50, step 12/28, loss = 1.9900
# epoch 28 / 50, step 13/28, loss = 1.9518
# epoch 28 / 50, step 14/28, loss = 1.9398
# epoch 28 / 50, step 15/28, loss = 1.9259
# epoch 28 / 50, step 16/28, loss = 1.9000
# epoch 28 / 50, step 17/28, loss = 1.9494
# epoch 28 / 50, step 18/28, loss = 1.9666
# epoch 28 / 50, step 19/28, loss = 1.9307
# epoch 28 / 50, step 20/28, loss = 1.9720
# epoch 28 / 50, step 21/28, loss = 1.9579
# epoch 28 / 50, step 22/28, loss = 1.9405
# epoch 28 / 50, step 23/28, loss = 1.8961
# epoch 28 / 50, step 24/28, loss = 1.8735
# epoch 28 / 50, step 25/28, loss = 1.9022
# epoch 28 / 50, step 26/28, loss = 1.9345
# epoch 28 / 50, step 27/28, loss = 1.9308
# epoch 28 / 50, step 28/28, loss = 1.9398
# epoch 28 / 50, step 1/7, loss = 1.9519
# epoch 28 / 50, step 2/7, loss = 1.9705
# epoch 28 / 50, step 3/7, loss = 1.8946
# epoch 28 / 50, step 4/7, loss = 1.9388
# epoch 28 / 50, step 5/7, loss = 1.9508
# epoch 28 / 50, step 6/7, loss = 1.9337
# epoch 28 / 50, step 7/7, loss = 1.9381
# epoch 29 / 50, step 1/28, loss = 1.9504
# epoch 29 / 50, step 2/28, loss = 1.9388
# epoch 29 / 50, step 3/28, loss = 1.9622
# epoch 29 / 50, step 4/28, loss = 1.9177
# epoch 29 / 50, step 5/28, loss = 1.9393
# epoch 29 / 50, step 6/28, loss = 1.9720
# epoch 29 / 50, step 7/28, loss = 1.9485
# epoch 29 / 50, step 8/28, loss = 1.9819
# epoch 29 / 50, step 9/28, loss = 1.9168
# epoch 29 / 50, step 10/28, loss = 1.9305
# epoch 29 / 50, step 11/28, loss = 1.9046
# epoch 29 / 50, step 12/28, loss = 1.9320
# epoch 29 / 50, step 13/28, loss = 1.9499
# epoch 29 / 50, step 14/28, loss = 1.9081
# epoch 29 / 50, step 15/28, loss = 1.9303
# epoch 29 / 50, step 16/28, loss = 1.9064
# epoch 29 / 50, step 17/28, loss = 1.8990
# epoch 29 / 50, step 18/28, loss = 1.9113
# epoch 29 / 50, step 19/28, loss = 1.9535
# epoch 29 / 50, step 20/28, loss = 1.9717
# epoch 29 / 50, step 21/28, loss = 1.9706
# epoch 29 / 50, step 22/28, loss = 1.8753
# epoch 29 / 50, step 23/28, loss = 1.9800
# epoch 29 / 50, step 24/28, loss = 1.9075
# epoch 29 / 50, step 25/28, loss = 1.8861
# epoch 29 / 50, step 26/28, loss = 1.9443
# epoch 29 / 50, step 27/28, loss = 1.9506
# epoch 29 / 50, step 28/28, loss = 1.9026
# epoch 29 / 50, step 1/7, loss = 1.9511
# epoch 29 / 50, step 2/7, loss = 1.9714
# epoch 29 / 50, step 3/7, loss = 1.8943
# epoch 29 / 50, step 4/7, loss = 1.9383
# epoch 29 / 50, step 5/7, loss = 1.9515
# epoch 29 / 50, step 6/7, loss = 1.9337
# epoch 29 / 50, step 7/7, loss = 1.9376
# epoch 30 / 50, step 1/28, loss = 1.9250
# epoch 30 / 50, step 2/28, loss = 1.9564
# epoch 30 / 50, step 3/28, loss = 1.9421
# epoch 30 / 50, step 4/28, loss = 1.9047
# epoch 30 / 50, step 5/28, loss = 1.8989
# epoch 30 / 50, step 6/28, loss = 1.9399
# epoch 30 / 50, step 7/28, loss = 1.9529
# epoch 30 / 50, step 8/28, loss = 1.9441
# epoch 30 / 50, step 9/28, loss = 1.9463
# epoch 30 / 50, step 10/28, loss = 1.9615
# epoch 30 / 50, step 11/28, loss = 1.9096
# epoch 30 / 50, step 12/28, loss = 1.9197
# epoch 30 / 50, step 13/28, loss = 1.9119
# epoch 30 / 50, step 14/28, loss = 1.9314
# epoch 30 / 50, step 15/28, loss = 1.8940
# epoch 30 / 50, step 16/28, loss = 1.9173
# epoch 30 / 50, step 17/28, loss = 1.8993
# epoch 30 / 50, step 18/28, loss = 2.0184
# epoch 30 / 50, step 19/28, loss = 1.9311
# epoch 30 / 50, step 20/28, loss = 1.9628
# epoch 30 / 50, step 21/28, loss = 1.9077
# epoch 30 / 50, step 22/28, loss = 1.9142
# epoch 30 / 50, step 23/28, loss = 1.9164
# epoch 30 / 50, step 24/28, loss = 1.9366
# epoch 30 / 50, step 25/28, loss = 1.9945
# epoch 30 / 50, step 26/28, loss = 1.9382
# epoch 30 / 50, step 27/28, loss = 1.9705
# epoch 30 / 50, step 28/28, loss = 1.8920
# epoch 30 / 50, step 1/7, loss = 1.9520
# epoch 30 / 50, step 2/7, loss = 1.9725
# epoch 30 / 50, step 3/7, loss = 1.8926
# epoch 30 / 50, step 4/7, loss = 1.9382
# epoch 30 / 50, step 5/7, loss = 1.9517
# epoch 30 / 50, step 6/7, loss = 1.9346
# epoch 30 / 50, step 7/7, loss = 1.9387
# epoch 31 / 50, step 1/28, loss = 1.9180
# epoch 31 / 50, step 2/28, loss = 1.9752
# epoch 31 / 50, step 3/28, loss = 1.9495
# epoch 31 / 50, step 4/28, loss = 1.9146
# epoch 31 / 50, step 5/28, loss = 1.9316
# epoch 31 / 50, step 6/28, loss = 1.9346
# epoch 31 / 50, step 7/28, loss = 1.9612
# epoch 31 / 50, step 8/28, loss = 1.9665
# epoch 31 / 50, step 9/28, loss = 1.9303
# epoch 31 / 50, step 10/28, loss = 1.9404
# epoch 31 / 50, step 11/28, loss = 1.9591
# epoch 31 / 50, step 12/28, loss = 1.9425
# epoch 31 / 50, step 13/28, loss = 1.9604
# epoch 31 / 50, step 14/28, loss = 1.9207
# epoch 31 / 50, step 15/28, loss = 1.9027
# epoch 31 / 50, step 16/28, loss = 1.9189
# epoch 31 / 50, step 17/28, loss = 1.9313
# epoch 31 / 50, step 18/28, loss = 1.9305
# epoch 31 / 50, step 19/28, loss = 1.9238
# epoch 31 / 50, step 20/28, loss = 1.8919
# epoch 31 / 50, step 21/28, loss = 1.9879
# epoch 31 / 50, step 22/28, loss = 1.8934
# epoch 31 / 50, step 23/28, loss = 1.9463
# epoch 31 / 50, step 24/28, loss = 1.9184
# epoch 31 / 50, step 25/28, loss = 1.9301
# epoch 31 / 50, step 26/28, loss = 1.9277
# epoch 31 / 50, step 27/28, loss = 1.9336
# epoch 31 / 50, step 28/28, loss = 1.9532
# epoch 31 / 50, step 1/7, loss = 1.9490
# epoch 31 / 50, step 2/7, loss = 1.9706
# epoch 31 / 50, step 3/7, loss = 1.8954
# epoch 31 / 50, step 4/7, loss = 1.9375
# epoch 31 / 50, step 5/7, loss = 1.9527
# epoch 31 / 50, step 6/7, loss = 1.9336
# epoch 31 / 50, step 7/7, loss = 1.9359
# epoch 32 / 50, step 1/28, loss = 1.9126
# epoch 32 / 50, step 2/28, loss = 1.9558
# epoch 32 / 50, step 3/28, loss = 1.9484
# epoch 32 / 50, step 4/28, loss = 1.9206
# epoch 32 / 50, step 5/28, loss = 1.9460
# epoch 32 / 50, step 6/28, loss = 1.8658
# epoch 32 / 50, step 7/28, loss = 1.9490
# epoch 32 / 50, step 8/28, loss = 1.9505
# epoch 32 / 50, step 9/28, loss = 1.9669
# epoch 32 / 50, step 10/28, loss = 1.8688
# epoch 32 / 50, step 11/28, loss = 1.9249
# epoch 32 / 50, step 12/28, loss = 1.9484
# epoch 32 / 50, step 13/28, loss = 1.9415
# epoch 32 / 50, step 14/28, loss = 1.9565
# epoch 32 / 50, step 15/28, loss = 1.9343
# epoch 32 / 50, step 16/28, loss = 1.9157
# epoch 32 / 50, step 17/28, loss = 1.9825
# epoch 32 / 50, step 18/28, loss = 1.9520
# epoch 32 / 50, step 19/28, loss = 1.9248
# epoch 32 / 50, step 20/28, loss = 1.9260
# epoch 32 / 50, step 21/28, loss = 1.9219
# epoch 32 / 50, step 22/28, loss = 1.9506
# epoch 32 / 50, step 23/28, loss = 1.9001
# epoch 32 / 50, step 24/28, loss = 1.8913
# epoch 32 / 50, step 25/28, loss = 1.9132
# epoch 32 / 50, step 26/28, loss = 1.9772
# epoch 32 / 50, step 27/28, loss = 1.9440
# epoch 32 / 50, step 28/28, loss = 2.0110
# epoch 32 / 50, step 1/7, loss = 1.9505
# epoch 32 / 50, step 2/7, loss = 1.9726
# epoch 32 / 50, step 3/7, loss = 1.8938
# epoch 32 / 50, step 4/7, loss = 1.9379
# epoch 32 / 50, step 5/7, loss = 1.9520
# epoch 32 / 50, step 6/7, loss = 1.9345
# epoch 32 / 50, step 7/7, loss = 1.9373
# epoch 33 / 50, step 1/28, loss = 1.9652
# epoch 33 / 50, step 2/28, loss = 1.8866
# epoch 33 / 50, step 3/28, loss = 1.9529
# epoch 33 / 50, step 4/28, loss = 1.9323
# epoch 33 / 50, step 5/28, loss = 1.9535
# epoch 33 / 50, step 6/28, loss = 1.9360
# epoch 33 / 50, step 7/28, loss = 1.8902
# epoch 33 / 50, step 8/28, loss = 1.9458
# epoch 33 / 50, step 9/28, loss = 1.8850
# epoch 33 / 50, step 10/28, loss = 1.9512
# epoch 33 / 50, step 11/28, loss = 1.9280
# epoch 33 / 50, step 12/28, loss = 1.9014
# epoch 33 / 50, step 13/28, loss = 1.9454
# epoch 33 / 50, step 14/28, loss = 1.9506
# epoch 33 / 50, step 15/28, loss = 1.9494
# epoch 33 / 50, step 16/28, loss = 1.9274
# epoch 33 / 50, step 17/28, loss = 1.9807
# epoch 33 / 50, step 18/28, loss = 1.9218
# epoch 33 / 50, step 19/28, loss = 1.9378
# epoch 33 / 50, step 20/28, loss = 1.9317
# epoch 33 / 50, step 21/28, loss = 1.9409
# epoch 33 / 50, step 22/28, loss = 1.9541
# epoch 33 / 50, step 23/28, loss = 1.9222
# epoch 33 / 50, step 24/28, loss = 1.9432
# epoch 33 / 50, step 25/28, loss = 1.9875
# epoch 33 / 50, step 26/28, loss = 1.9170
# epoch 33 / 50, step 27/28, loss = 1.8938
# epoch 33 / 50, step 28/28, loss = 2.0027
# epoch 33 / 50, step 1/7, loss = 1.9490
# epoch 33 / 50, step 2/7, loss = 1.9720
# epoch 33 / 50, step 3/7, loss = 1.8957
# epoch 33 / 50, step 4/7, loss = 1.9373
# epoch 33 / 50, step 5/7, loss = 1.9520
# epoch 33 / 50, step 6/7, loss = 1.9345
# epoch 33 / 50, step 7/7, loss = 1.9366
# epoch 34 / 50, step 1/28, loss = 1.9675
# epoch 34 / 50, step 2/28, loss = 1.9248
# epoch 34 / 50, step 3/28, loss = 1.9087
# epoch 34 / 50, step 4/28, loss = 1.9333
# epoch 34 / 50, step 5/28, loss = 1.9537
# epoch 34 / 50, step 6/28, loss = 1.8997
# epoch 34 / 50, step 7/28, loss = 1.9480
# epoch 34 / 50, step 8/28, loss = 1.9015
# epoch 34 / 50, step 9/28, loss = 1.9283
# epoch 34 / 50, step 10/28, loss = 1.9202
# epoch 34 / 50, step 11/28, loss = 1.9372
# epoch 34 / 50, step 12/28, loss = 1.9517
# epoch 34 / 50, step 13/28, loss = 1.9120
# epoch 34 / 50, step 14/28, loss = 1.9870
# epoch 34 / 50, step 15/28, loss = 1.9368
# epoch 34 / 50, step 16/28, loss = 1.9147
# epoch 34 / 50, step 17/28, loss = 1.9312
# epoch 34 / 50, step 18/28, loss = 1.9851
# epoch 34 / 50, step 19/28, loss = 1.9327
# epoch 34 / 50, step 20/28, loss = 1.9245
# epoch 34 / 50, step 21/28, loss = 1.9224
# epoch 34 / 50, step 22/28, loss = 1.9638
# epoch 34 / 50, step 23/28, loss = 1.9326
# epoch 34 / 50, step 24/28, loss = 1.9194
# epoch 34 / 50, step 25/28, loss = 1.9401
# epoch 34 / 50, step 26/28, loss = 1.9795
# epoch 34 / 50, step 27/28, loss = 1.9104
# epoch 34 / 50, step 28/28, loss = 1.9644
# epoch 34 / 50, step 1/7, loss = 1.9475
# epoch 34 / 50, step 2/7, loss = 1.9705
# epoch 34 / 50, step 3/7, loss = 1.8971
# epoch 34 / 50, step 4/7, loss = 1.9368
# epoch 34 / 50, step 5/7, loss = 1.9522
# epoch 34 / 50, step 6/7, loss = 1.9343
# epoch 34 / 50, step 7/7, loss = 1.9360
# epoch 35 / 50, step 1/28, loss = 1.9007
# epoch 35 / 50, step 2/28, loss = 1.9467
# epoch 35 / 50, step 3/28, loss = 1.9915
# epoch 35 / 50, step 4/28, loss = 1.9363
# epoch 35 / 50, step 5/28, loss = 1.9340
# epoch 35 / 50, step 6/28, loss = 1.9789
# epoch 35 / 50, step 7/28, loss = 1.9133
# ...
# epoch 39 / 50, step 25/28, loss = 1.9666
# epoch 39 / 50, step 26/28, loss = 1.9098
# epoch 39 / 50, step 27/28, loss = 1.9581
# epoch 39 / 50, step 28/28, loss = 1.9284
# epoch 39 / 50, step 1/7, loss = 1.9512
# epoch 39 / 50, step 2/7, loss = 1.9697
# epoch 39 / 50, step 3/7, loss = 1.8953
# epoch 39 / 50, step 4/7, loss = 1.9395
# epoch 39 / 50, step 5/7, loss = 1.9495
# epoch 39 / 50, step 6/7, loss = 1.9322
# epoch 39 / 50, step 7/7, loss = 1.9366
# epoch 40 / 50, step 1/28, loss = 1.9080
# epoch 40 / 50, step 2/28, loss = 1.9047
# epoch 40 / 50, step 3/28, loss = 1.9056
# epoch 40 / 50, step 4/28, loss = 1.9420
# epoch 40 / 50, step 5/28, loss = 1.8790
# epoch 40 / 50, step 6/28, loss = 1.9476
# epoch 40 / 50, step 7/28, loss = 1.9382
# epoch 40 / 50, step 8/28, loss = 1.9178
# epoch 40 / 50, step 9/28, loss = 1.9037
# epoch 40 / 50, step 10/28, loss = 1.9860
# epoch 40 / 50, step 11/28, loss = 1.9228
# epoch 40 / 50, step 12/28, loss = 1.9244
# epoch 40 / 50, step 13/28, loss = 1.9201
# epoch 40 / 50, step 14/28, loss = 1.8934
# epoch 40 / 50, step 15/28, loss = 1.9279
# epoch 40 / 50, step 16/28, loss = 1.9195
# epoch 40 / 50, step 17/28, loss = 1.9937
# epoch 40 / 50, step 18/28, loss = 1.9652
# epoch 40 / 50, step 19/28, loss = 1.9802
# epoch 40 / 50, step 20/28, loss = 1.9082
# epoch 40 / 50, step 21/28, loss = 1.9593
# epoch 40 / 50, step 22/28, loss = 1.9897
# epoch 40 / 50, step 23/28, loss = 1.9249
# epoch 40 / 50, step 24/28, loss = 1.9047
# epoch 40 / 50, step 25/28, loss = 1.9324
# epoch 40 / 50, step 26/28, loss = 1.9834
# epoch 40 / 50, step 27/28, loss = 1.9826
# epoch 40 / 50, step 28/28, loss = 1.8574
# epoch 40 / 50, step 1/7, loss = 1.9533
# epoch 40 / 50, step 2/7, loss = 1.9730
# epoch 40 / 50, step 3/7, loss = 1.8920
# epoch 40 / 50, step 4/7, loss = 1.9399
# epoch 40 / 50, step 5/7, loss = 1.9495
# epoch 40 / 50, step 6/7, loss = 1.9332
# epoch 40 / 50, step 7/7, loss = 1.9383
# epoch 41 / 50, step 1/28, loss = 1.9304
# epoch 41 / 50, step 2/28, loss = 1.9331
# epoch 41 / 50, step 3/28, loss = 1.8731
# epoch 41 / 50, step 4/28, loss = 1.9449
# epoch 41 / 50, step 5/28, loss = 1.8962
# epoch 41 / 50, step 6/28, loss = 1.8901
# epoch 41 / 50, step 7/28, loss = 1.9857
# epoch 41 / 50, step 8/28, loss = 1.9474
# epoch 41 / 50, step 9/28, loss = 1.9225
# epoch 41 / 50, step 10/28, loss = 1.9343
# epoch 41 / 50, step 11/28, loss = 1.9323
# epoch 41 / 50, step 12/28, loss = 1.9565
# epoch 41 / 50, step 13/28, loss = 1.9088
# epoch 41 / 50, step 14/28, loss = 1.9585
# epoch 41 / 50, step 15/28, loss = 1.9557
# epoch 41 / 50, step 16/28, loss = 2.0063
# epoch 41 / 50, step 17/28, loss = 1.9229
# epoch 41 / 50, step 18/28, loss = 1.9465
# epoch 41 / 50, step 19/28, loss = 1.9095
# epoch 41 / 50, step 20/28, loss = 1.9113
# epoch 41 / 50, step 21/28, loss = 1.9067
# epoch 41 / 50, step 22/28, loss = 1.9729
# epoch 41 / 50, step 23/28, loss = 1.9330
# epoch 41 / 50, step 24/28, loss = 1.9150
# epoch 41 / 50, step 25/28, loss = 1.8922
# epoch 41 / 50, step 26/28, loss = 1.9482
# epoch 41 / 50, step 27/28, loss = 1.9224
# epoch 41 / 50, step 28/28, loss = 1.9549
# epoch 41 / 50, step 1/7, loss = 1.9521
# epoch 41 / 50, step 2/7, loss = 1.9711
# epoch 41 / 50, step 3/7, loss = 1.8926
# epoch 41 / 50, step 4/7, loss = 1.9386
# epoch 41 / 50, step 5/7, loss = 1.9494
# epoch 41 / 50, step 6/7, loss = 1.9344
# epoch 41 / 50, step 7/7, loss = 1.9394
# epoch 42 / 50, step 1/28, loss = 1.9048
# epoch 42 / 50, step 2/28, loss = 1.9332
# epoch 42 / 50, step 3/28, loss = 1.9579
# epoch 42 / 50, step 4/28, loss = 1.9079
# epoch 42 / 50, step 5/28, loss = 1.9551
# epoch 42 / 50, step 6/28, loss = 1.9018
# epoch 42 / 50, step 7/28, loss = 1.9272
# epoch 42 / 50, step 8/28, loss = 1.9318
# epoch 42 / 50, step 9/28, loss = 1.9346
# epoch 42 / 50, step 10/28, loss = 1.9216
# epoch 42 / 50, step 11/28, loss = 1.8787
# epoch 42 / 50, step 12/28, loss = 1.9266
# epoch 42 / 50, step 13/28, loss = 1.9514
# epoch 42 / 50, step 14/28, loss = 1.9639
# epoch 42 / 50, step 15/28, loss = 1.9318
# epoch 42 / 50, step 16/28, loss = 1.9364
# epoch 42 / 50, step 17/28, loss = 1.9566
# epoch 42 / 50, step 18/28, loss = 1.9127
# epoch 42 / 50, step 19/28, loss = 1.9541
# epoch 42 / 50, step 20/28, loss = 1.9111
# epoch 42 / 50, step 21/28, loss = 1.9567
# epoch 42 / 50, step 22/28, loss = 1.9168
# epoch 42 / 50, step 23/28, loss = 1.9365
# epoch 42 / 50, step 24/28, loss = 1.9355
# epoch 42 / 50, step 25/28, loss = 1.9464
# epoch 42 / 50, step 26/28, loss = 1.9309
# epoch 42 / 50, step 27/28, loss = 1.9476
# epoch 42 / 50, step 28/28, loss = 2.0100
# epoch 42 / 50, step 1/7, loss = 1.9531
# epoch 42 / 50, step 2/7, loss = 1.9719
# epoch 42 / 50, step 3/7, loss = 1.8911
# epoch 42 / 50, step 4/7, loss = 1.9395
# epoch 42 / 50, step 5/7, loss = 1.9479
# epoch 42 / 50, step 6/7, loss = 1.9329
# epoch 42 / 50, step 7/7, loss = 1.9397
# epoch 43 / 50, step 1/28, loss = 1.9422
# epoch 43 / 50, step 2/28, loss = 2.0003
# epoch 43 / 50, step 3/28, loss = 1.9321
# epoch 43 / 50, step 4/28, loss = 1.9698
# epoch 43 / 50, step 5/28, loss = 1.9297
# epoch 43 / 50, step 6/28, loss = 1.9494
# epoch 43 / 50, step 7/28, loss = 1.9013
# epoch 43 / 50, step 8/28, loss = 1.9234
# epoch 43 / 50, step 9/28, loss = 1.9356
# epoch 43 / 50, step 10/28, loss = 1.9078
# epoch 43 / 50, step 11/28, loss = 1.9005
# epoch 43 / 50, step 12/28, loss = 1.9140
# epoch 43 / 50, step 13/28, loss = 1.9247
# epoch 43 / 50, step 14/28, loss = 1.9625
# epoch 43 / 50, step 15/28, loss = 1.9690
# epoch 43 / 50, step 16/28, loss = 1.9103
# epoch 43 / 50, step 17/28, loss = 1.9771
# epoch 43 / 50, step 18/28, loss = 1.9378
# epoch 43 / 50, step 19/28, loss = 1.9122
# epoch 43 / 50, step 20/28, loss = 1.9369
# epoch 43 / 50, step 21/28, loss = 1.9227
# epoch 43 / 50, step 22/28, loss = 1.9490
# epoch 43 / 50, step 23/28, loss = 1.9634
# epoch 43 / 50, step 24/28, loss = 1.8764
# epoch 43 / 50, step 25/28, loss = 1.9252
# epoch 43 / 50, step 26/28, loss = 1.9583
# epoch 43 / 50, step 27/28, loss = 1.9150
# epoch 43 / 50, step 28/28, loss = 1.9117
# epoch 43 / 50, step 1/7, loss = 1.9508
# epoch 43 / 50, step 2/7, loss = 1.9696
# epoch 43 / 50, step 3/7, loss = 1.8949
# epoch 43 / 50, step 4/7, loss = 1.9388
# epoch 43 / 50, step 5/7, loss = 1.9485
# epoch 43 / 50, step 6/7, loss = 1.9333
# epoch 43 / 50, step 7/7, loss = 1.9380
# epoch 44 / 50, step 1/28, loss = 1.9106
# epoch 44 / 50, step 2/28, loss = 1.9381
# epoch 44 / 50, step 3/28, loss = 1.9554
# epoch 44 / 50, step 4/28, loss = 2.0050
# epoch 44 / 50, step 5/28, loss = 1.9306
# epoch 44 / 50, step 6/28, loss = 1.8991
# epoch 44 / 50, step 7/28, loss = 1.9870
# epoch 44 / 50, step 8/28, loss = 1.9427
# epoch 44 / 50, step 9/28, loss = 1.9614
# epoch 44 / 50, step 10/28, loss = 1.8932
# epoch 44 / 50, step 11/28, loss = 1.9681
# epoch 44 / 50, step 12/28, loss = 1.9126
# epoch 44 / 50, step 13/28, loss = 1.9061
# epoch 44 / 50, step 14/28, loss = 1.8476
# epoch 44 / 50, step 15/28, loss = 1.9079
# epoch 44 / 50, step 16/28, loss = 1.9056
# epoch 44 / 50, step 17/28, loss = 1.9541
# epoch 44 / 50, step 18/28, loss = 1.9307
# epoch 44 / 50, step 19/28, loss = 1.9145
# epoch 44 / 50, step 20/28, loss = 2.0049
# epoch 44 / 50, step 21/28, loss = 1.9438
# epoch 44 / 50, step 22/28, loss = 1.9701
# epoch 44 / 50, step 23/28, loss = 1.9567
# epoch 44 / 50, step 24/28, loss = 1.8711
# epoch 44 / 50, step 25/28, loss = 1.9125
# epoch 44 / 50, step 26/28, loss = 1.9177
# epoch 44 / 50, step 27/28, loss = 1.9079
# epoch 44 / 50, step 28/28, loss = 1.9188
# epoch 44 / 50, step 1/7, loss = 1.9497
# epoch 44 / 50, step 2/7, loss = 1.9720
# epoch 44 / 50, step 3/7, loss = 1.8935
# epoch 44 / 50, step 4/7, loss = 1.9375
# epoch 44 / 50, step 5/7, loss = 1.9509
# epoch 44 / 50, step 6/7, loss = 1.9347
# epoch 44 / 50, step 7/7, loss = 1.9378
# epoch 45 / 50, step 1/28, loss = 1.9065
# epoch 45 / 50, step 2/28, loss = 1.9459
# epoch 45 / 50, step 3/28, loss = 1.9148
# epoch 45 / 50, step 4/28, loss = 1.9026
# epoch 45 / 50, step 5/28, loss = 1.9130
# epoch 45 / 50, step 6/28, loss = 1.9362
# epoch 45 / 50, step 7/28, loss = 1.9124
# epoch 45 / 50, step 8/28, loss = 1.8896
# epoch 45 / 50, step 9/28, loss = 1.9129
# epoch 45 / 50, step 10/28, loss = 1.8867
# epoch 45 / 50, step 11/28, loss = 1.9670
# epoch 45 / 50, step 12/28, loss = 1.9384
# epoch 45 / 50, step 13/28, loss = 1.9733
# epoch 45 / 50, step 14/28, loss = 1.9188
# epoch 45 / 50, step 15/28, loss = 1.9507
# epoch 45 / 50, step 16/28, loss = 1.9464
# epoch 45 / 50, step 17/28, loss = 1.9325
# epoch 45 / 50, step 18/28, loss = 1.8945
# epoch 45 / 50, step 19/28, loss = 1.9576
# epoch 45 / 50, step 20/28, loss = 1.9169
# epoch 45 / 50, step 21/28, loss = 1.9339
# epoch 45 / 50, step 22/28, loss = 1.9559
# epoch 45 / 50, step 23/28, loss = 1.9612
# epoch 45 / 50, step 24/28, loss = 1.9939
# epoch 45 / 50, step 25/28, loss = 1.9643
# epoch 45 / 50, step 26/28, loss = 2.0119
# epoch 45 / 50, step 27/28, loss = 1.9425
# epoch 45 / 50, step 28/28, loss = 1.8872
# epoch 45 / 50, step 1/7, loss = 1.9536
# epoch 45 / 50, step 2/7, loss = 1.9740
# epoch 45 / 50, step 3/7, loss = 1.8906
# epoch 45 / 50, step 4/7, loss = 1.9394
# epoch 45 / 50, step 5/7, loss = 1.9495
# epoch 45 / 50, step 6/7, loss = 1.9343
# epoch 45 / 50, step 7/7, loss = 1.9397
# epoch 46 / 50, step 1/28, loss = 1.9103
# epoch 46 / 50, step 2/28, loss = 1.9164
# epoch 46 / 50, step 3/28, loss = 1.9820
# epoch 46 / 50, step 4/28, loss = 1.9037
# epoch 46 / 50, step 5/28, loss = 1.8661
# epoch 46 / 50, step 6/28, loss = 1.9672
# epoch 46 / 50, step 7/28, loss = 1.9302
# epoch 46 / 50, step 8/28, loss = 1.8977
# epoch 46 / 50, step 9/28, loss = 1.9653
# epoch 46 / 50, step 10/28, loss = 1.9449
# epoch 46 / 50, step 11/28, loss = 1.8917
# epoch 46 / 50, step 12/28, loss = 1.9196
# epoch 46 / 50, step 13/28, loss = 1.9276
# epoch 46 / 50, step 14/28, loss = 1.9295
# epoch 46 / 50, step 15/28, loss = 1.9457
# epoch 46 / 50, step 16/28, loss = 1.9622
# epoch 46 / 50, step 17/28, loss = 1.8995
# epoch 46 / 50, step 18/28, loss = 1.9665
# epoch 46 / 50, step 19/28, loss = 1.9239
# epoch 46 / 50, step 20/28, loss = 1.9635
# epoch 46 / 50, step 21/28, loss = 1.9878
# epoch 46 / 50, step 22/28, loss = 1.9207
# epoch 46 / 50, step 23/28, loss = 1.9835
# epoch 46 / 50, step 24/28, loss = 1.9353
# epoch 46 / 50, step 25/28, loss = 1.9141
# epoch 46 / 50, step 26/28, loss = 1.9477
# epoch 46 / 50, step 27/28, loss = 1.9437
# epoch 46 / 50, step 28/28, loss = 1.9341
# epoch 46 / 50, step 1/7, loss = 1.9519
# epoch 46 / 50, step 2/7, loss = 1.9717
# epoch 46 / 50, step 3/7, loss = 1.8931
# epoch 46 / 50, step 4/7, loss = 1.9389
# epoch 46 / 50, step 5/7, loss = 1.9492
# epoch 46 / 50, step 6/7, loss = 1.9341
# epoch 46 / 50, step 7/7, loss = 1.9388
# epoch 47 / 50, step 1/28, loss = 1.9559
# epoch 47 / 50, step 2/28, loss = 1.9483
# epoch 47 / 50, step 3/28, loss = 1.9024
# epoch 47 / 50, step 4/28, loss = 1.9470
# epoch 47 / 50, step 5/28, loss = 1.9659
# epoch 47 / 50, step 6/28, loss = 1.8955
# epoch 47 / 50, step 7/28, loss = 1.9640
# epoch 47 / 50, step 8/28, loss = 1.9603
# epoch 47 / 50, step 9/28, loss = 1.9510
# epoch 47 / 50, step 10/28, loss = 1.9085
# epoch 47 / 50, step 11/28, loss = 1.9238
# epoch 47 / 50, step 12/28, loss = 1.9225
# epoch 47 / 50, step 13/28, loss = 1.9363
# epoch 47 / 50, step 14/28, loss = 1.9267
# epoch 47 / 50, step 15/28, loss = 1.9017
# epoch 47 / 50, step 16/28, loss = 1.9290
# epoch 47 / 50, step 17/28, loss = 1.9297
# epoch 47 / 50, step 18/28, loss = 1.9218
# epoch 47 / 50, step 19/28, loss = 1.9655
# epoch 47 / 50, step 20/28, loss = 1.9039
# epoch 47 / 50, step 21/28, loss = 1.9339
# epoch 47 / 50, step 22/28, loss = 1.9460
# epoch 47 / 50, step 23/28, loss = 1.9360
# epoch 47 / 50, step 24/28, loss = 1.9096
# epoch 47 / 50, step 25/28, loss = 1.9133
# epoch 47 / 50, step 26/28, loss = 1.9473
# epoch 47 / 50, step 27/28, loss = 1.9135
# epoch 47 / 50, step 28/28, loss = 1.9774
# epoch 47 / 50, step 1/7, loss = 1.9508
# epoch 47 / 50, step 2/7, loss = 1.9703
# epoch 47 / 50, step 3/7, loss = 1.8935
# epoch 47 / 50, step 4/7, loss = 1.9382
# epoch 47 / 50, step 5/7, loss = 1.9494
# epoch 47 / 50, step 6/7, loss = 1.9338
# epoch 47 / 50, step 7/7, loss = 1.9385
# epoch 48 / 50, step 1/28, loss = 1.9121
# epoch 48 / 50, step 2/28, loss = 1.9177
# epoch 48 / 50, step 3/28, loss = 1.9859
# epoch 48 / 50, step 4/28, loss = 1.9215
# epoch 48 / 50, step 5/28, loss = 1.9134
# epoch 48 / 50, step 6/28, loss = 1.9606
# epoch 48 / 50, step 7/28, loss = 1.9296
# epoch 48 / 50, step 8/28, loss = 1.8918
# epoch 48 / 50, step 9/28, loss = 1.9033
# epoch 48 / 50, step 10/28, loss = 1.9551
# epoch 48 / 50, step 11/28, loss = 1.9246
# epoch 48 / 50, step 12/28, loss = 1.9375
# epoch 48 / 50, step 13/28, loss = 1.9115
# epoch 48 / 50, step 14/28, loss = 1.9907
# epoch 48 / 50, step 15/28, loss = 1.9174
# epoch 48 / 50, step 16/28, loss = 1.9807
# epoch 48 / 50, step 17/28, loss = 1.9443
# epoch 48 / 50, step 18/28, loss = 1.8947
# epoch 48 / 50, step 19/28, loss = 1.9194
# epoch 48 / 50, step 20/28, loss = 1.8980
# epoch 48 / 50, step 21/28, loss = 1.9470
# epoch 48 / 50, step 22/28, loss = 1.9324
# epoch 48 / 50, step 23/28, loss = 1.9186
# epoch 48 / 50, step 24/28, loss = 1.9735
# epoch 48 / 50, step 25/28, loss = 1.9696
# epoch 48 / 50, step 26/28, loss = 1.9062
# epoch 48 / 50, step 27/28, loss = 1.9334
# epoch 48 / 50, step 28/28, loss = 1.9250
# epoch 48 / 50, step 1/7, loss = 1.9523
# epoch 48 / 50, step 2/7, loss = 1.9715
# epoch 48 / 50, step 3/7, loss = 1.8925
# epoch 48 / 50, step 4/7, loss = 1.9391
# epoch 48 / 50, step 5/7, loss = 1.9489
# epoch 48 / 50, step 6/7, loss = 1.9337
# epoch 48 / 50, step 7/7, loss = 1.9389
# epoch 49 / 50, step 1/28, loss = 1.9863
# epoch 49 / 50, step 2/28, loss = 1.9199
# epoch 49 / 50, step 3/28, loss = 1.8899
# epoch 49 / 50, step 4/28, loss = 1.9372
# epoch 49 / 50, step 5/28, loss = 1.9329
# epoch 49 / 50, step 6/28, loss = 1.8996
# epoch 49 / 50, step 7/28, loss = 1.9065
# epoch 49 / 50, step 8/28, loss = 1.9085
# epoch 49 / 50, step 9/28, loss = 1.9083
# epoch 49 / 50, step 10/28, loss = 1.9631
# epoch 49 / 50, step 11/28, loss = 1.9554
# epoch 49 / 50, step 12/28, loss = 1.9383
# epoch 49 / 50, step 13/28, loss = 1.9545
# epoch 49 / 50, step 14/28, loss = 1.9325
# epoch 49 / 50, step 15/28, loss = 1.9558
# epoch 49 / 50, step 16/28, loss = 1.8966
# epoch 49 / 50, step 17/28, loss = 1.9391
# epoch 49 / 50, step 18/28, loss = 1.9696
# epoch 49 / 50, step 19/28, loss = 1.9454
# epoch 49 / 50, step 20/28, loss = 1.8859
# epoch 49 / 50, step 21/28, loss = 1.9429
# epoch 49 / 50, step 22/28, loss = 1.9120
# epoch 49 / 50, step 23/28, loss = 1.9252
# epoch 49 / 50, step 24/28, loss = 1.9388
# epoch 49 / 50, step 25/28, loss = 1.9165
# epoch 49 / 50, step 26/28, loss = 1.9338
# epoch 49 / 50, step 27/28, loss = 1.9557
# epoch 49 / 50, step 28/28, loss = 1.9393
# epoch 49 / 50, step 1/7, loss = 1.9504
# epoch 49 / 50, step 2/7, loss = 1.9702
# epoch 49 / 50, step 3/7, loss = 1.8934
# epoch 49 / 50, step 4/7, loss = 1.9376
# epoch 49 / 50, step 5/7, loss = 1.9513
# epoch 49 / 50, step 6/7, loss = 1.9346
# epoch 49 / 50, step 7/7, loss = 1.9383
# epoch 50 / 50, step 1/28, loss = 1.9629
# epoch 50 / 50, step 2/28, loss = 1.9863
# epoch 50 / 50, step 3/28, loss = 1.9083
# epoch 50 / 50, step 4/28, loss = 1.9165
# epoch 50 / 50, step 5/28, loss = 1.9297
# epoch 50 / 50, step 6/28, loss = 1.9374
# epoch 50 / 50, step 7/28, loss = 1.9026
# epoch 50 / 50, step 8/28, loss = 1.9088
# epoch 50 / 50, step 9/28, loss = 1.9081
# epoch 50 / 50, step 10/28, loss = 1.9537
# epoch 50 / 50, step 11/28, loss = 1.9046
# epoch 50 / 50, step 12/28, loss = 1.9144
# epoch 50 / 50, step 13/28, loss = 1.9862
# epoch 50 / 50, step 14/28, loss = 1.9143
# epoch 50 / 50, step 15/28, loss = 1.9057
# epoch 50 / 50, step 16/28, loss = 1.9328
# epoch 50 / 50, step 17/28, loss = 1.9371
# epoch 50 / 50, step 18/28, loss = 1.9289
# epoch 50 / 50, step 19/28, loss = 1.9395
# epoch 50 / 50, step 20/28, loss = 1.9615
# epoch 50 / 50, step 21/28, loss = 1.9533
# epoch 50 / 50, step 22/28, loss = 1.9636
# epoch 50 / 50, step 23/28, loss = 1.9661
# epoch 50 / 50, step 24/28, loss = 1.9488
# epoch 50 / 50, step 25/28, loss = 1.9399
# epoch 50 / 50, step 26/28, loss = 1.8817
# epoch 50 / 50, step 27/28, loss = 1.9213
# epoch 50 / 50, step 28/28, loss = 1.8438
# epoch 50 / 50, step 1/7, loss = 1.9506
# epoch 50 / 50, step 2/7, loss = 1.9713
# epoch 50 / 50, step 3/7, loss = 1.8931
# epoch 50 / 50, step 4/7, loss = 1.9373
# epoch 50 / 50, step 5/7, loss = 1.9514
# epoch 50 / 50, step 6/7, loss = 1.9357
# epoch 50 / 50, step 7/7, loss = 1.9390

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 17.6 and the test accuaracy is 17.80821917808219
#  the maximum accuracy of the test was 17.80821917808219 at the epoch 1
#  the maximum accuracy of the train was 19.2 at the epoch 26
# the accuracy of the training at the best validation accuracy 17.80821917808219 is 15.2

# %%
# Copy the 
shutil.copyfile('./lstm.ipynb', './' + results_dir + 'lstm_copy.ipynb')
# Out:
# './David/Tests/13/lstm_copy.ipynb'
