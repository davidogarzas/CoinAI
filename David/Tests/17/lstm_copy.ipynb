# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Increase to 500 epochs

# %%
filepath = 'David/Tests/17'
script_dir = os.path.dirname('lstm.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs

# Turns negative values to 0
X[X < 0] = 0

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
"""
def find_longest_important_section(data, threshold, exclude_first_n=20000):
    longest_section_length = 0
    longest_section_index = -1
    sections = []

    for i, row in enumerate(data):
        # Exclude the first `exclude_first_n` samples by slicing the row
        valid_indices = np.arange(exclude_first_n, len(row))
        valid_row = row[exclude_first_n:]  # Data after the exclusion point
        
        # Find indices where the data exceeds the threshold
        indices = np.where(valid_row > threshold)[0]

        if len(indices) > 0:
            # Adjust the indices to account for the exclusion offset
            start, end = indices[0] + exclude_first_n, indices[-1] + exclude_first_n
            section_length = end - start + 1
            
            # Save the section length and check if it's the longest
            sections.append((start, end, section_length))
            if section_length > longest_section_length:
                longest_section_length = section_length
                longest_section_index = i
        else:
            # No important section found
            sections.append((None, None, 0))
    
    return longest_section_index, longest_section_length, sections

threshold = 30000

# Find the longest important section
longest_index, longest_length, all_sections = find_longest_important_section(X, threshold)


print(f"Time series with the longest important section: {longest_index}")
print(f"Length of the longest important section: {longest_length}")
"""
# Out:
# '\ndef find_longest_important_section(data, threshold, exclude_first_n=20000):\n    longest_section_length = 0\n    longest_section_index = -1\n    sections = []\n\n    for i, row in enumerate(data):\n        # Exclude the first `exclude_first_n` samples by slicing the row\n        valid_indices = np.arange(exclude_first_n, len(row))\n        valid_row = row[exclude_first_n:]  # Data after the exclusion point\n        \n        # Find indices where the data exceeds the threshold\n        indices = np.where(valid_row > threshold)[0]\n\n        if len(indices) > 0:\n            # Adjust the indices to account for the exclusion offset\n            start, end = indices[0] + exclude_first_n, indices[-1] + exclude_first_n\n            section_length = end - start + 1\n            \n            # Save the section length and check if it\'s the longest\n            sections.append((start, end, section_length))\n            if section_length > longest_section_length:\n                longest_section_length = section_length\n                longest_section_index = i\n        else:\n            # No important section found\n            sections.append((None, None, 0))\n    \n    return longest_section_index, longest_section_length, sections\n\nthreshold = 30000\n\n# Find the longest important section\nlongest_index, longest_length, all_sections = find_longest_important_section(X, threshold)\n\n\nprint(f"Time series with the longest important section: {longest_index}")\nprint(f"Length of the longest important section: {longest_length}")\n'

# %%
"""
def cut_and_pad_time_series(data, threshold, longest_section_length):
    processed_data = []

    for i, row in enumerate(data):
        # Find the first index where the data exceeds the threshold
        indices = np.where(row > threshold)[0]
        
        if len(indices) > 0:
            start = indices[0]
            # Cut the data starting from 'start'
            important_section = row[start:start + longest_section_length]
        else:
            # If no values exceed the threshold, use an empty array
            print(f'No values exceed the threshold. Index {i}')
            important_section = np.array([])
        
        # Pad with zeros if the section is shorter than the longest_section_length
        if len(important_section) < longest_section_length:
            important_section = np.pad(
                important_section, 
                (0, longest_section_length - len(important_section)), 
                mode='constant'
            )
        
        processed_data.append(important_section)
    
    return np.array(processed_data)

# Cut and pad the time series
processed_data = cut_and_pad_time_series(X, threshold, longest_length)

print("Processed Data:")
print(processed_data)
"""
# Out:
# '\ndef cut_and_pad_time_series(data, threshold, longest_section_length):\n    processed_data = []\n\n    for i, row in enumerate(data):\n        # Find the first index where the data exceeds the threshold\n        indices = np.where(row > threshold)[0]\n        \n        if len(indices) > 0:\n            start = indices[0]\n            # Cut the data starting from \'start\'\n            important_section = row[start:start + longest_section_length]\n        else:\n            # If no values exceed the threshold, use an empty array\n            print(f\'No values exceed the threshold. Index {i}\')\n            important_section = np.array([])\n        \n        # Pad with zeros if the section is shorter than the longest_section_length\n        if len(important_section) < longest_section_length:\n            important_section = np.pad(\n                important_section, \n                (0, longest_section_length - len(important_section)), \n                mode=\'constant\'\n            )\n        \n        processed_data.append(important_section)\n    \n    return np.array(processed_data)\n\n# Cut and pad the time series\nprocessed_data = cut_and_pad_time_series(X, threshold, longest_length)\n\nprint("Processed Data:")\nprint(processed_data)\n'

# %%
"""
# Plot the section
plt.figure()
plt.plot(processed_data[longest_index], label='Important Section (Cut and Padded)', color='blue')
plt.axhline(y=threshold, color='red', linestyle='--', label='Threshold')
plt.title(f'Longest Important Section of Time Series {longest_index}')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()
"""
# Out:
# "\n# Plot the section\nplt.figure()\nplt.plot(processed_data[longest_index], label='Important Section (Cut and Padded)', color='blue')\nplt.axhline(y=threshold, color='red', linestyle='--', label='Threshold')\nplt.title(f'Longest Important Section of Time Series {longest_index}')\nplt.xlabel('Time')\nplt.ylabel('Amplitude')\nplt.legend()\nplt.grid(True)\nplt.show()\n"

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 512
num_classes = 7
num_epochs = 500
batch_size = 8
learning_rate = 0.0001
num_layers = 2

input_size = 751  
sequence_length = 1024   
#input_size = 4 
#sequence_length = 28

# %%
# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([8, 769024]) , Labels shape: torch.Size([8])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1])

# %%
# Create Model

# Model 
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        # x -> (batch_size, seq, input_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(p=0.5)  # Inside LSTM clas

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0,c0))

        # Dropout on output of LSTM
        out = self.dropout(out)

        # out: batch_size, seq_length, hidden_size
        # out (N, 6008, 128)
        # : all samples in batch, -1 last time step, : all features in hidden size

        out = out[:, -1, :] 
        
        # out (N, 128)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(751, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 8,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 500, step 1/110, loss = 1.9263
# epoch 1 / 500, step 2/110, loss = 1.9353
# epoch 1 / 500, step 3/110, loss = 1.9457
# epoch 1 / 500, step 4/110, loss = 1.9431
# epoch 1 / 500, step 5/110, loss = 1.9910
# epoch 1 / 500, step 6/110, loss = 1.9207
# epoch 1 / 500, step 7/110, loss = 1.9927
# epoch 1 / 500, step 8/110, loss = 1.9613
# epoch 1 / 500, step 9/110, loss = 1.8948
# epoch 1 / 500, step 10/110, loss = 1.9574
# epoch 1 / 500, step 11/110, loss = 1.9853
# epoch 1 / 500, step 12/110, loss = 1.9872
# epoch 1 / 500, step 13/110, loss = 1.9685
# epoch 1 / 500, step 14/110, loss = 2.0312
# epoch 1 / 500, step 15/110, loss = 1.9573
# epoch 1 / 500, step 16/110, loss = 1.9113
# epoch 1 / 500, step 17/110, loss = 1.9407
# epoch 1 / 500, step 18/110, loss = 1.9629
# epoch 1 / 500, step 19/110, loss = 1.9605
# epoch 1 / 500, step 20/110, loss = 1.9116
# epoch 1 / 500, step 21/110, loss = 1.9306
# epoch 1 / 500, step 22/110, loss = 1.9246
# epoch 1 / 500, step 23/110, loss = 1.9350
# epoch 1 / 500, step 24/110, loss = 1.9535
# epoch 1 / 500, step 25/110, loss = 1.9629
# epoch 1 / 500, step 26/110, loss = 1.9078
# epoch 1 / 500, step 27/110, loss = 2.0009
# epoch 1 / 500, step 28/110, loss = 1.9654
# epoch 1 / 500, step 29/110, loss = 1.9519
# epoch 1 / 500, step 30/110, loss = 1.9046
# epoch 1 / 500, step 31/110, loss = 1.9078
# epoch 1 / 500, step 32/110, loss = 1.9472
# epoch 1 / 500, step 33/110, loss = 1.9676
# epoch 1 / 500, step 34/110, loss = 1.9349
# epoch 1 / 500, step 35/110, loss = 1.9620
# epoch 1 / 500, step 36/110, loss = 1.9406
# epoch 1 / 500, step 37/110, loss = 1.9497
# epoch 1 / 500, step 38/110, loss = 1.9843
# epoch 1 / 500, step 39/110, loss = 1.9619
# epoch 1 / 500, step 40/110, loss = 1.9279
# epoch 1 / 500, step 41/110, loss = 1.9268
# epoch 1 / 500, step 42/110, loss = 1.9444
# epoch 1 / 500, step 43/110, loss = 1.9686
# epoch 1 / 500, step 44/110, loss = 1.9234
# epoch 1 / 500, step 45/110, loss = 1.9738
# epoch 1 / 500, step 46/110, loss = 2.0364
# epoch 1 / 500, step 47/110, loss = 1.9245
# epoch 1 / 500, step 48/110, loss = 1.9062
# epoch 1 / 500, step 49/110, loss = 1.9630
# epoch 1 / 500, step 50/110, loss = 1.9572
# epoch 1 / 500, step 51/110, loss = 1.9312
# epoch 1 / 500, step 52/110, loss = 1.9481
# epoch 1 / 500, step 53/110, loss = 1.9404
# epoch 1 / 500, step 54/110, loss = 1.9881
# epoch 1 / 500, step 55/110, loss = 1.8938
# epoch 1 / 500, step 56/110, loss = 1.9050
# epoch 1 / 500, step 57/110, loss = 1.9095
# epoch 1 / 500, step 58/110, loss = 1.9333
# epoch 1 / 500, step 59/110, loss = 1.9045
# epoch 1 / 500, step 60/110, loss = 2.0182
# epoch 1 / 500, step 61/110, loss = 2.0005
# epoch 1 / 500, step 62/110, loss = 1.9471
# epoch 1 / 500, step 63/110, loss = 1.9603
# epoch 1 / 500, step 64/110, loss = 1.9150
# epoch 1 / 500, step 65/110, loss = 1.9325
# epoch 1 / 500, step 66/110, loss = 1.9518
# epoch 1 / 500, step 67/110, loss = 1.9136
# epoch 1 / 500, step 68/110, loss = 1.9369
# epoch 1 / 500, step 69/110, loss = 1.9522
# epoch 1 / 500, step 70/110, loss = 1.8990
# epoch 1 / 500, step 71/110, loss = 1.9517
# epoch 1 / 500, step 72/110, loss = 1.9435
# epoch 1 / 500, step 73/110, loss = 1.9311
# epoch 1 / 500, step 74/110, loss = 1.9894
# epoch 1 / 500, step 75/110, loss = 2.0416
# epoch 1 / 500, step 76/110, loss = 1.8614
# epoch 1 / 500, step 77/110, loss = 1.9910
# epoch 1 / 500, step 78/110, loss = 1.9939
# epoch 1 / 500, step 79/110, loss = 1.8684
# epoch 1 / 500, step 80/110, loss = 1.8778
# epoch 1 / 500, step 81/110, loss = 1.8884
# epoch 1 / 500, step 82/110, loss = 1.8472
# epoch 1 / 500, step 83/110, loss = 1.9689
# epoch 1 / 500, step 84/110, loss = 1.9053
# epoch 1 / 500, step 85/110, loss = 1.9295
# epoch 1 / 500, step 86/110, loss = 2.0466
# epoch 1 / 500, step 87/110, loss = 1.9850
# epoch 1 / 500, step 88/110, loss = 1.9466
# epoch 1 / 500, step 89/110, loss = 1.9206
# epoch 1 / 500, step 90/110, loss = 1.9479
# epoch 1 / 500, step 91/110, loss = 1.9656
# epoch 1 / 500, step 92/110, loss = 1.9906
# epoch 1 / 500, step 93/110, loss = 1.9245
# epoch 1 / 500, step 94/110, loss = 1.9871
# epoch 1 / 500, step 95/110, loss = 1.9113
# epoch 1 / 500, step 96/110, loss = 1.9342
# epoch 1 / 500, step 97/110, loss = 1.9087
# epoch 1 / 500, step 98/110, loss = 1.9688
# epoch 1 / 500, step 99/110, loss = 1.8545
# epoch 1 / 500, step 100/110, loss = 1.9643
# epoch 1 / 500, step 101/110, loss = 1.9398
# epoch 1 / 500, step 102/110, loss = 1.8523
# epoch 1 / 500, step 103/110, loss = 1.9767
# epoch 1 / 500, step 104/110, loss = 2.0845
# epoch 1 / 500, step 105/110, loss = 1.9589
# epoch 1 / 500, step 106/110, loss = 1.9343
# epoch 1 / 500, step 107/110, loss = 1.9008
# epoch 1 / 500, step 108/110, loss = 1.9815
# epoch 1 / 500, step 109/110, loss = 1.9571
# epoch 1 / 500, step 110/110, loss = 1.9153
# epoch 1 / 500, step 1/28, loss = 1.9250
# epoch 1 / 500, step 2/28, loss = 1.9610
# epoch 1 / 500, step 3/28, loss = 1.9720
# epoch 1 / 500, step 4/28, loss = 1.9049
# epoch 1 / 500, step 5/28, loss = 2.0424
# epoch 1 / 500, step 6/28, loss = 1.9441
# epoch 1 / 500, step 7/28, loss = 1.9007
# epoch 1 / 500, step 8/28, loss = 1.9700
# epoch 1 / 500, step 9/28, loss = 1.9695
# epoch 1 / 500, step 10/28, loss = 1.9000
# epoch 1 / 500, step 11/28, loss = 1.8490
# epoch 1 / 500, step 12/28, loss = 1.8041
# epoch 1 / 500, step 13/28, loss = 1.9482
# epoch 1 / 500, step 14/28, loss = 1.9474
# epoch 1 / 500, step 15/28, loss = 1.8584
# epoch 1 / 500, step 16/28, loss = 2.0084
# epoch 1 / 500, step 17/28, loss = 1.9298
# epoch 1 / 500, step 18/28, loss = 1.9869
# epoch 1 / 500, step 19/28, loss = 2.0446
# epoch 1 / 500, step 20/28, loss = 1.9098
# epoch 1 / 500, step 21/28, loss = 1.8783
# epoch 1 / 500, step 22/28, loss = 1.9260
# epoch 1 / 500, step 23/28, loss = 1.8729
# epoch 1 / 500, step 24/28, loss = 2.0046
# epoch 1 / 500, step 25/28, loss = 1.9012
# epoch 1 / 500, step 26/28, loss = 1.9694
# epoch 1 / 500, step 27/28, loss = 1.9590
# epoch 1 / 500, step 28/28, loss = 1.8365
# epoch 2 / 500, step 1/110, loss = 1.9694
# epoch 2 / 500, step 2/110, loss = 2.0320
# epoch 2 / 500, step 3/110, loss = 2.0026
# epoch 2 / 500, step 4/110, loss = 1.9369
# epoch 2 / 500, step 5/110, loss = 1.9225
# epoch 2 / 500, step 6/110, loss = 2.0464
# epoch 2 / 500, step 7/110, loss = 1.8431
# epoch 2 / 500, step 8/110, loss = 1.9985
# epoch 2 / 500, step 9/110, loss = 1.9250
# epoch 2 / 500, step 10/110, loss = 1.8494
# epoch 2 / 500, step 11/110, loss = 1.9369
# epoch 2 / 500, step 12/110, loss = 1.9641
# epoch 2 / 500, step 13/110, loss = 1.9879
# epoch 2 / 500, step 14/110, loss = 1.8310
# epoch 2 / 500, step 15/110, loss = 1.8748
# epoch 2 / 500, step 16/110, loss = 1.9514
# epoch 2 / 500, step 17/110, loss = 2.0295
# epoch 2 / 500, step 18/110, loss = 1.9217
# epoch 2 / 500, step 19/110, loss = 1.9053
# epoch 2 / 500, step 20/110, loss = 1.9657
# epoch 2 / 500, step 21/110, loss = 1.9584
# epoch 2 / 500, step 22/110, loss = 1.9445
# epoch 2 / 500, step 23/110, loss = 2.0189
# epoch 2 / 500, step 24/110, loss = 1.8155
# epoch 2 / 500, step 25/110, loss = 1.8897
# epoch 2 / 500, step 26/110, loss = 1.9162
# epoch 2 / 500, step 27/110, loss = 1.9842
# epoch 2 / 500, step 28/110, loss = 1.9286
# epoch 2 / 500, step 29/110, loss = 1.9505
# epoch 2 / 500, step 30/110, loss = 2.0203
# epoch 2 / 500, step 31/110, loss = 1.9582
# epoch 2 / 500, step 32/110, loss = 1.8561
# epoch 2 / 500, step 33/110, loss = 1.7886
# epoch 2 / 500, step 34/110, loss = 1.9215
# epoch 2 / 500, step 35/110, loss = 1.9363
# epoch 2 / 500, step 36/110, loss = 1.9518
# epoch 2 / 500, step 37/110, loss = 1.8096
# epoch 2 / 500, step 38/110, loss = 1.9900
# epoch 2 / 500, step 39/110, loss = 1.9208
# epoch 2 / 500, step 40/110, loss = 1.7487
# epoch 2 / 500, step 41/110, loss = 1.9943
# epoch 2 / 500, step 42/110, loss = 1.9428
# epoch 2 / 500, step 43/110, loss = 2.0042
# epoch 2 / 500, step 44/110, loss = 1.8838
# epoch 2 / 500, step 45/110, loss = 1.8376
# epoch 2 / 500, step 46/110, loss = 1.9037
# epoch 2 / 500, step 47/110, loss = 1.8025
# epoch 2 / 500, step 48/110, loss = 1.9569
# epoch 2 / 500, step 49/110, loss = 1.8087
# epoch 2 / 500, step 50/110, loss = 1.9673
# epoch 2 / 500, step 51/110, loss = 2.0264
# epoch 2 / 500, step 52/110, loss = 1.8496
# epoch 2 / 500, step 53/110, loss = 1.8161
# epoch 2 / 500, step 54/110, loss = 1.8122
# epoch 2 / 500, step 55/110, loss = 1.8809
# epoch 2 / 500, step 56/110, loss = 2.0613
# epoch 2 / 500, step 57/110, loss = 1.7757
# epoch 2 / 500, step 58/110, loss = 1.9083
# epoch 2 / 500, step 59/110, loss = 1.8808
# epoch 2 / 500, step 60/110, loss = 2.0173
# epoch 2 / 500, step 61/110, loss = 1.9471
# epoch 2 / 500, step 62/110, loss = 1.9954
# epoch 2 / 500, step 63/110, loss = 1.9649
# epoch 2 / 500, step 64/110, loss = 1.9162
# epoch 2 / 500, step 65/110, loss = 1.8418
# epoch 2 / 500, step 66/110, loss = 1.7617
# epoch 2 / 500, step 67/110, loss = 2.0003
# epoch 2 / 500, step 68/110, loss = 2.0531
# epoch 2 / 500, step 69/110, loss = 1.9880
# epoch 2 / 500, step 70/110, loss = 1.9848
# epoch 2 / 500, step 71/110, loss = 1.8817
# epoch 2 / 500, step 72/110, loss = 1.9236
# epoch 2 / 500, step 73/110, loss = 2.0600
# epoch 2 / 500, step 74/110, loss = 1.8329
# epoch 2 / 500, step 75/110, loss = 1.8568
# epoch 2 / 500, step 76/110, loss = 1.9130
# epoch 2 / 500, step 77/110, loss = 2.0276
# epoch 2 / 500, step 78/110, loss = 1.8392
# epoch 2 / 500, step 79/110, loss = 1.8741
# epoch 2 / 500, step 80/110, loss = 1.8480
# epoch 2 / 500, step 81/110, loss = 1.9215
# epoch 2 / 500, step 82/110, loss = 1.8312
# epoch 2 / 500, step 83/110, loss = 1.9796
# epoch 2 / 500, step 84/110, loss = 1.8958
# epoch 2 / 500, step 85/110, loss = 2.0081
# epoch 2 / 500, step 86/110, loss = 1.9186
# epoch 2 / 500, step 87/110, loss = 1.8554
# epoch 2 / 500, step 88/110, loss = 1.9353
# epoch 2 / 500, step 89/110, loss = 1.7425
# epoch 2 / 500, step 90/110, loss = 1.9369
# epoch 2 / 500, step 91/110, loss = 2.0807
# epoch 2 / 500, step 92/110, loss = 1.9874
# epoch 2 / 500, step 93/110, loss = 1.9457
# epoch 2 / 500, step 94/110, loss = 1.9903
# epoch 2 / 500, step 95/110, loss = 1.8617
# epoch 2 / 500, step 96/110, loss = 2.0258
# epoch 2 / 500, step 97/110, loss = 1.9071
# epoch 2 / 500, step 98/110, loss = 2.0331
# epoch 2 / 500, step 99/110, loss = 1.9352
# epoch 2 / 500, step 100/110, loss = 1.9312
# epoch 2 / 500, step 101/110, loss = 1.8996
# epoch 2 / 500, step 102/110, loss = 1.9485
# epoch 2 / 500, step 103/110, loss = 1.9538
# epoch 2 / 500, step 104/110, loss = 1.8843
# epoch 2 / 500, step 105/110, loss = 1.9358
# epoch 2 / 500, step 106/110, loss = 1.9147
# epoch 2 / 500, step 107/110, loss = 1.9060
# epoch 2 / 500, step 108/110, loss = 1.9598
# epoch 2 / 500, step 109/110, loss = 1.9235
# epoch 2 / 500, step 110/110, loss = 1.9424
# epoch 2 / 500, step 1/28, loss = 1.9320
# epoch 2 / 500, step 2/28, loss = 1.9523
# epoch 2 / 500, step 3/28, loss = 1.9297
# epoch 2 / 500, step 4/28, loss = 1.9597
# epoch 2 / 500, step 5/28, loss = 2.0074
# epoch 2 / 500, step 6/28, loss = 1.9554
# epoch 2 / 500, step 7/28, loss = 1.8876
# epoch 2 / 500, step 8/28, loss = 1.9429
# epoch 2 / 500, step 9/28, loss = 1.9680
# epoch 2 / 500, step 10/28, loss = 1.9134
# epoch 2 / 500, step 11/28, loss = 1.8882
# epoch 2 / 500, step 12/28, loss = 1.7768
# epoch 2 / 500, step 13/28, loss = 1.9104
# epoch 2 / 500, step 14/28, loss = 1.9626
# epoch 2 / 500, step 15/28, loss = 1.7969
# epoch 2 / 500, step 16/28, loss = 2.0126
# epoch 2 / 500, step 17/28, loss = 1.9102
# epoch 2 / 500, step 18/28, loss = 1.9397
# epoch 2 / 500, step 19/28, loss = 2.0075
# epoch 2 / 500, step 20/28, loss = 1.8946
# epoch 2 / 500, step 21/28, loss = 1.9093
# epoch 2 / 500, step 22/28, loss = 1.9640
# epoch 2 / 500, step 23/28, loss = 1.8913
# epoch 2 / 500, step 24/28, loss = 1.9857
# epoch 2 / 500, step 25/28, loss = 1.9184
# epoch 2 / 500, step 26/28, loss = 1.9781
# epoch 2 / 500, step 27/28, loss = 1.9766
# epoch 2 / 500, step 28/28, loss = 1.7776
# epoch 3 / 500, step 1/110, loss = 1.8642
# epoch 3 / 500, step 2/110, loss = 1.9100
# epoch 3 / 500, step 3/110, loss = 1.8484
# epoch 3 / 500, step 4/110, loss = 1.8534
# epoch 3 / 500, step 5/110, loss = 1.8896
# epoch 3 / 500, step 6/110, loss = 2.0896
# epoch 3 / 500, step 7/110, loss = 1.9490
# epoch 3 / 500, step 8/110, loss = 1.9331
# epoch 3 / 500, step 9/110, loss = 1.9503
# epoch 3 / 500, step 10/110, loss = 1.9788
# epoch 3 / 500, step 11/110, loss = 1.8369
# epoch 3 / 500, step 12/110, loss = 1.8594
# epoch 3 / 500, step 13/110, loss = 1.8488
# epoch 3 / 500, step 14/110, loss = 1.9551
# epoch 3 / 500, step 15/110, loss = 1.8612
# epoch 3 / 500, step 16/110, loss = 1.9948
# epoch 3 / 500, step 17/110, loss = 1.9227
# epoch 3 / 500, step 18/110, loss = 1.9708
# epoch 3 / 500, step 19/110, loss = 1.8979
# epoch 3 / 500, step 20/110, loss = 1.8594
# epoch 3 / 500, step 21/110, loss = 1.8041
# epoch 3 / 500, step 22/110, loss = 1.9728
# epoch 3 / 500, step 23/110, loss = 1.9236
# epoch 3 / 500, step 24/110, loss = 1.9023
# epoch 3 / 500, step 25/110, loss = 1.9760
# epoch 3 / 500, step 26/110, loss = 2.0480
# epoch 3 / 500, step 27/110, loss = 1.9822
# epoch 3 / 500, step 28/110, loss = 2.0153
# epoch 3 / 500, step 29/110, loss = 1.9216
# epoch 3 / 500, step 30/110, loss = 1.9855
# epoch 3 / 500, step 31/110, loss = 1.8793
# epoch 3 / 500, step 32/110, loss = 1.8649
# epoch 3 / 500, step 33/110, loss = 1.8679
# epoch 3 / 500, step 34/110, loss = 2.0236
# epoch 3 / 500, step 35/110, loss = 1.8886
# epoch 3 / 500, step 36/110, loss = 1.8835
# epoch 3 / 500, step 37/110, loss = 1.9337
# epoch 3 / 500, step 38/110, loss = 1.9413
# epoch 3 / 500, step 39/110, loss = 1.9250
# epoch 3 / 500, step 40/110, loss = 1.8569
# epoch 3 / 500, step 41/110, loss = 1.8836
# epoch 3 / 500, step 42/110, loss = 1.8420
# epoch 3 / 500, step 43/110, loss = 1.8862
# epoch 3 / 500, step 44/110, loss = 1.8776
# epoch 3 / 500, step 45/110, loss = 1.8401
# epoch 3 / 500, step 46/110, loss = 1.9443
# epoch 3 / 500, step 47/110, loss = 1.8281
# epoch 3 / 500, step 48/110, loss = 1.9834
# epoch 3 / 500, step 49/110, loss = 1.9891
# epoch 3 / 500, step 50/110, loss = 1.9748
# epoch 3 / 500, step 51/110, loss = 2.0300
# epoch 3 / 500, step 52/110, loss = 2.0229
# epoch 3 / 500, step 53/110, loss = 2.0380
# epoch 3 / 500, step 54/110, loss = 1.9821
# epoch 3 / 500, step 55/110, loss = 1.8620
# epoch 3 / 500, step 56/110, loss = 2.0290
# epoch 3 / 500, step 57/110, loss = 1.9602
# epoch 3 / 500, step 58/110, loss = 1.8404
# epoch 3 / 500, step 59/110, loss = 1.8892
# epoch 3 / 500, step 60/110, loss = 1.8562
# epoch 3 / 500, step 61/110, loss = 1.9330
# epoch 3 / 500, step 62/110, loss = 1.8726
# epoch 3 / 500, step 63/110, loss = 1.9038
# epoch 3 / 500, step 64/110, loss = 1.9041
# epoch 3 / 500, step 65/110, loss = 1.9846
# epoch 3 / 500, step 66/110, loss = 1.9428
# epoch 3 / 500, step 67/110, loss = 1.9287
# epoch 3 / 500, step 68/110, loss = 1.8852
# epoch 3 / 500, step 69/110, loss = 2.0580
# epoch 3 / 500, step 70/110, loss = 1.8313
# epoch 3 / 500, step 71/110, loss = 1.8921
# epoch 3 / 500, step 72/110, loss = 1.9247
# epoch 3 / 500, step 73/110, loss = 1.8825
# epoch 3 / 500, step 74/110, loss = 1.9169
# epoch 3 / 500, step 75/110, loss = 1.8500
# epoch 3 / 500, step 76/110, loss = 1.8291
# epoch 3 / 500, step 77/110, loss = 1.9074
# epoch 3 / 500, step 78/110, loss = 1.8029
# epoch 3 / 500, step 79/110, loss = 1.8560
# epoch 3 / 500, step 80/110, loss = 1.8211
# epoch 3 / 500, step 81/110, loss = 1.8666
# epoch 3 / 500, step 82/110, loss = 1.8920
# epoch 3 / 500, step 83/110, loss = 1.8355
# epoch 3 / 500, step 84/110, loss = 1.8410
# epoch 3 / 500, step 85/110, loss = 1.8839
# epoch 3 / 500, step 86/110, loss = 1.9790
# epoch 3 / 500, step 87/110, loss = 1.9047
# epoch 3 / 500, step 88/110, loss = 1.8449
# epoch 3 / 500, step 89/110, loss = 1.8689
# epoch 3 / 500, step 90/110, loss = 1.9287
# epoch 3 / 500, step 91/110, loss = 2.0243
# epoch 3 / 500, step 92/110, loss = 1.8285
# epoch 3 / 500, step 93/110, loss = 1.8099
# epoch 3 / 500, step 94/110, loss = 1.9083
# epoch 3 / 500, step 95/110, loss = 1.8852
# epoch 3 / 500, step 96/110, loss = 2.0442
# epoch 3 / 500, step 97/110, loss = 1.9653
# epoch 3 / 500, step 98/110, loss = 2.0120
# epoch 3 / 500, step 99/110, loss = 1.9801
# epoch 3 / 500, step 100/110, loss = 1.9562
# epoch 3 / 500, step 101/110, loss = 1.9247
# epoch 3 / 500, step 102/110, loss = 1.8935
# epoch 3 / 500, step 103/110, loss = 1.8028
# epoch 3 / 500, step 104/110, loss = 1.9834
# epoch 3 / 500, step 105/110, loss = 1.9988
# epoch 3 / 500, step 106/110, loss = 1.9867
# epoch 3 / 500, step 107/110, loss = 1.9510
# epoch 3 / 500, step 108/110, loss = 1.9588
# epoch 3 / 500, step 109/110, loss = 1.8550
# epoch 3 / 500, step 110/110, loss = 1.8738
# epoch 3 / 500, step 1/28, loss = 1.9387
# epoch 3 / 500, step 2/28, loss = 1.9458
# epoch 3 / 500, step 3/28, loss = 1.9429
# epoch 3 / 500, step 4/28, loss = 1.9100
# epoch 3 / 500, step 5/28, loss = 2.1008
# epoch 3 / 500, step 6/28, loss = 1.9840
# epoch 3 / 500, step 7/28, loss = 1.9241
# epoch 3 / 500, step 8/28, loss = 1.9958
# epoch 3 / 500, step 9/28, loss = 1.9541
# epoch 3 / 500, step 10/28, loss = 1.9042
# epoch 3 / 500, step 11/28, loss = 1.8436
# epoch 3 / 500, step 12/28, loss = 1.7755
# epoch 3 / 500, step 13/28, loss = 1.9517
# epoch 3 / 500, step 14/28, loss = 1.9496
# epoch 3 / 500, step 15/28, loss = 1.8288
# epoch 3 / 500, step 16/28, loss = 1.9759
# epoch 3 / 500, step 17/28, loss = 1.9542
# epoch 3 / 500, step 18/28, loss = 1.9739
# epoch 3 / 500, step 19/28, loss = 2.0568
# epoch 3 / 500, step 20/28, loss = 1.9245
# epoch 3 / 500, step 21/28, loss = 1.9499
# epoch 3 / 500, step 22/28, loss = 1.9111
# epoch 3 / 500, step 23/28, loss = 1.8974
# epoch 3 / 500, step 24/28, loss = 2.0223
# epoch 3 / 500, step 25/28, loss = 1.8779
# epoch 3 / 500, step 26/28, loss = 1.9671
# epoch 3 / 500, step 27/28, loss = 1.9150
# epoch 3 / 500, step 28/28, loss = 1.8731
# epoch 4 / 500, step 1/110, loss = 1.7332
# epoch 4 / 500, step 2/110, loss = 1.8711
# epoch 4 / 500, step 3/110, loss = 1.8335
# epoch 4 / 500, step 4/110, loss = 1.9863
# epoch 4 / 500, step 5/110, loss = 1.9816
# epoch 4 / 500, step 6/110, loss = 1.8295
# epoch 4 / 500, step 7/110, loss = 1.9124
# epoch 4 / 500, step 8/110, loss = 1.8341
# epoch 4 / 500, step 9/110, loss = 1.9262
# epoch 4 / 500, step 10/110, loss = 1.7805
# epoch 4 / 500, step 11/110, loss = 1.9041
# epoch 4 / 500, step 12/110, loss = 1.9520
# epoch 4 / 500, step 13/110, loss = 1.9244
# epoch 4 / 500, step 14/110, loss = 1.9223
# epoch 4 / 500, step 15/110, loss = 2.0000
# epoch 4 / 500, step 16/110, loss = 1.9002
# epoch 4 / 500, step 17/110, loss = 1.9155
# epoch 4 / 500, step 18/110, loss = 1.9152
# epoch 4 / 500, step 19/110, loss = 1.8692
# epoch 4 / 500, step 20/110, loss = 1.8577
# epoch 4 / 500, step 21/110, loss = 1.8948
# epoch 4 / 500, step 22/110, loss = 1.7814
# epoch 4 / 500, step 23/110, loss = 1.8132
# epoch 4 / 500, step 24/110, loss = 1.9209
# epoch 4 / 500, step 25/110, loss = 1.9526
# epoch 4 / 500, step 26/110, loss = 2.0511
# epoch 4 / 500, step 27/110, loss = 1.9876
# epoch 4 / 500, step 28/110, loss = 1.7832
# epoch 4 / 500, step 29/110, loss = 1.7847
# epoch 4 / 500, step 30/110, loss = 1.9769
# epoch 4 / 500, step 31/110, loss = 1.9755
# epoch 4 / 500, step 32/110, loss = 2.0383
# epoch 4 / 500, step 33/110, loss = 1.8684
# epoch 4 / 500, step 34/110, loss = 1.8232
# epoch 4 / 500, step 35/110, loss = 1.8790
# epoch 4 / 500, step 36/110, loss = 1.8470
# epoch 4 / 500, step 37/110, loss = 2.0437
# epoch 4 / 500, step 38/110, loss = 2.0112
# epoch 4 / 500, step 39/110, loss = 1.7327
# epoch 4 / 500, step 40/110, loss = 1.8642
# epoch 4 / 500, step 41/110, loss = 1.9555
# epoch 4 / 500, step 42/110, loss = 2.1495
# epoch 4 / 500, step 43/110, loss = 1.9467
# epoch 4 / 500, step 44/110, loss = 1.7077
# epoch 4 / 500, step 45/110, loss = 1.9617
# epoch 4 / 500, step 46/110, loss = 1.9160
# epoch 4 / 500, step 47/110, loss = 1.8412
# epoch 4 / 500, step 48/110, loss = 1.8636
# epoch 4 / 500, step 49/110, loss = 1.8718
# epoch 4 / 500, step 50/110, loss = 1.8204
# epoch 4 / 500, step 51/110, loss = 1.9504
# epoch 4 / 500, step 52/110, loss = 1.8763
# epoch 4 / 500, step 53/110, loss = 1.8739
# epoch 4 / 500, step 54/110, loss = 1.9992
# epoch 4 / 500, step 55/110, loss = 1.9207
# epoch 4 / 500, step 56/110, loss = 1.6681
# epoch 4 / 500, step 57/110, loss = 1.9672
# epoch 4 / 500, step 58/110, loss = 2.0683
# epoch 4 / 500, step 59/110, loss = 1.9730
# epoch 4 / 500, step 60/110, loss = 1.9935
# epoch 4 / 500, step 61/110, loss = 2.0780
# epoch 4 / 500, step 62/110, loss = 1.9025
# epoch 4 / 500, step 63/110, loss = 1.9443
# epoch 4 / 500, step 64/110, loss = 1.9350
# epoch 4 / 500, step 65/110, loss = 1.9539
# epoch 4 / 500, step 66/110, loss = 1.9264
# epoch 4 / 500, step 67/110, loss = 1.9450
# epoch 4 / 500, step 68/110, loss = 1.9753
# epoch 4 / 500, step 69/110, loss = 1.9503
# epoch 4 / 500, step 70/110, loss = 1.8945
# epoch 4 / 500, step 71/110, loss = 1.9998
# epoch 4 / 500, step 72/110, loss = 1.9569
# epoch 4 / 500, step 73/110, loss = 1.8532
# epoch 4 / 500, step 74/110, loss = 1.7924
# epoch 4 / 500, step 75/110, loss = 1.8659
# epoch 4 / 500, step 76/110, loss = 1.8314
# epoch 4 / 500, step 77/110, loss = 1.9047
# epoch 4 / 500, step 78/110, loss = 1.8343
# epoch 4 / 500, step 79/110, loss = 1.9562
# epoch 4 / 500, step 80/110, loss = 1.8519
# epoch 4 / 500, step 81/110, loss = 1.9223
# epoch 4 / 500, step 82/110, loss = 1.8799
# epoch 4 / 500, step 83/110, loss = 1.9566
# epoch 4 / 500, step 84/110, loss = 1.8587
# epoch 4 / 500, step 85/110, loss = 1.9642
# epoch 4 / 500, step 86/110, loss = 1.8158
# epoch 4 / 500, step 87/110, loss = 1.9298
# epoch 4 / 500, step 88/110, loss = 1.9388
# epoch 4 / 500, step 89/110, loss = 1.8958
# epoch 4 / 500, step 90/110, loss = 1.9058
# epoch 4 / 500, step 91/110, loss = 1.8830
# epoch 4 / 500, step 92/110, loss = 1.8247
# epoch 4 / 500, step 93/110, loss = 1.8924
# epoch 4 / 500, step 94/110, loss = 2.0345
# epoch 4 / 500, step 95/110, loss = 1.8700
# epoch 4 / 500, step 96/110, loss = 1.9283
# epoch 4 / 500, step 97/110, loss = 1.9566
# epoch 4 / 500, step 98/110, loss = 1.8602
# epoch 4 / 500, step 99/110, loss = 1.9885
# epoch 4 / 500, step 100/110, loss = 1.9015
# epoch 4 / 500, step 101/110, loss = 1.9404
# epoch 4 / 500, step 102/110, loss = 1.9566
# epoch 4 / 500, step 103/110, loss = 1.8201
# epoch 4 / 500, step 104/110, loss = 1.9109
# epoch 4 / 500, step 105/110, loss = 1.9926
# epoch 4 / 500, step 106/110, loss = 1.8669
# epoch 4 / 500, step 107/110, loss = 2.0061
# epoch 4 / 500, step 108/110, loss = 1.8895
# epoch 4 / 500, step 109/110, loss = 1.9218
# epoch 4 / 500, step 110/110, loss = 1.9851
# epoch 4 / 500, step 1/28, loss = 1.9450
# epoch 4 / 500, step 2/28, loss = 1.9363
# epoch 4 / 500, step 3/28, loss = 1.9501
# epoch 4 / 500, step 4/28, loss = 1.9235
# epoch 4 / 500, step 5/28, loss = 2.0316
# epoch 4 / 500, step 6/28, loss = 1.9325
# epoch 4 / 500, step 7/28, loss = 1.9050
# epoch 4 / 500, step 8/28, loss = 1.9847
# epoch 4 / 500, step 9/28, loss = 1.9647
# epoch 4 / 500, step 10/28, loss = 1.9212
# epoch 4 / 500, step 11/28, loss = 1.8637
# epoch 4 / 500, step 12/28, loss = 1.8270
# epoch 4 / 500, step 13/28, loss = 1.9289
# epoch 4 / 500, step 14/28, loss = 1.9336
# epoch 4 / 500, step 15/28, loss = 1.8334
# epoch 4 / 500, step 16/28, loss = 1.9484
# epoch 4 / 500, step 17/28, loss = 1.9539
# epoch 4 / 500, step 18/28, loss = 1.9640
# epoch 4 / 500, step 19/28, loss = 2.0284
# epoch 4 / 500, step 20/28, loss = 1.9039
# epoch 4 / 500, step 21/28, loss = 1.9067
# epoch 4 / 500, step 22/28, loss = 1.9344
# epoch 4 / 500, step 23/28, loss = 1.9307
# epoch 4 / 500, step 24/28, loss = 2.0137
# epoch 4 / 500, step 25/28, loss = 1.9175
# epoch 4 / 500, step 26/28, loss = 1.9516
# epoch 4 / 500, step 27/28, loss = 1.9322
# epoch 4 / 500, step 28/28, loss = 1.8521
# epoch 5 / 500, step 1/110, loss = 1.9032
# epoch 5 / 500, step 2/110, loss = 1.8954
# epoch 5 / 500, step 3/110, loss = 1.9044
# epoch 5 / 500, step 4/110, loss = 1.9233
# epoch 5 / 500, step 5/110, loss = 1.8354
# epoch 5 / 500, step 6/110, loss = 1.8335
# epoch 5 / 500, step 7/110, loss = 1.8251
# epoch 5 / 500, step 8/110, loss = 1.9232
# epoch 5 / 500, step 9/110, loss = 1.8812
# epoch 5 / 500, step 10/110, loss = 1.9529
# epoch 5 / 500, step 11/110, loss = 1.9287
# epoch 5 / 500, step 12/110, loss = 1.8739
# epoch 5 / 500, step 13/110, loss = 1.8284
# epoch 5 / 500, step 14/110, loss = 1.8995
# epoch 5 / 500, step 15/110, loss = 1.8617
# epoch 5 / 500, step 16/110, loss = 1.9028
# epoch 5 / 500, step 17/110, loss = 2.0284
# epoch 5 / 500, step 18/110, loss = 1.9045
# epoch 5 / 500, step 19/110, loss = 1.8397
# epoch 5 / 500, step 20/110, loss = 1.9387
# epoch 5 / 500, step 21/110, loss = 1.9591
# epoch 5 / 500, step 22/110, loss = 1.8123
# epoch 5 / 500, step 23/110, loss = 1.8571
# epoch 5 / 500, step 24/110, loss = 1.8544
# epoch 5 / 500, step 25/110, loss = 1.9345
# epoch 5 / 500, step 26/110, loss = 1.8362
# epoch 5 / 500, step 27/110, loss = 1.9193
# epoch 5 / 500, step 28/110, loss = 1.8634
# epoch 5 / 500, step 29/110, loss = 1.8660
# epoch 5 / 500, step 30/110, loss = 1.9198
# epoch 5 / 500, step 31/110, loss = 1.9399
# epoch 5 / 500, step 32/110, loss = 1.9783
# epoch 5 / 500, step 33/110, loss = 1.9365
# epoch 5 / 500, step 34/110, loss = 1.8836
# epoch 5 / 500, step 35/110, loss = 1.9539
# epoch 5 / 500, step 36/110, loss = 1.9582
# epoch 5 / 500, step 37/110, loss = 1.8188
# epoch 5 / 500, step 38/110, loss = 2.0440
# epoch 5 / 500, step 39/110, loss = 1.8635
# epoch 5 / 500, step 40/110, loss = 1.9640
# epoch 5 / 500, step 41/110, loss = 1.9475
# epoch 5 / 500, step 42/110, loss = 1.8987
# epoch 5 / 500, step 43/110, loss = 1.8609
# epoch 5 / 500, step 44/110, loss = 1.8974
# epoch 5 / 500, step 45/110, loss = 1.8591
# epoch 5 / 500, step 46/110, loss = 1.9457
# epoch 5 / 500, step 47/110, loss = 1.9346
# epoch 5 / 500, step 48/110, loss = 1.8482
# epoch 5 / 500, step 49/110, loss = 1.8911
# epoch 5 / 500, step 50/110, loss = 1.9530
# epoch 5 / 500, step 51/110, loss = 1.8963
# epoch 5 / 500, step 52/110, loss = 1.8485
# epoch 5 / 500, step 53/110, loss = 1.8506
# epoch 5 / 500, step 54/110, loss = 1.9500
# epoch 5 / 500, step 55/110, loss = 1.8865
# epoch 5 / 500, step 56/110, loss = 2.0022
# epoch 5 / 500, step 57/110, loss = 1.8066
# epoch 5 / 500, step 58/110, loss = 2.0438
# epoch 5 / 500, step 59/110, loss = 1.9064
# epoch 5 / 500, step 60/110, loss = 1.8726
# epoch 5 / 500, step 61/110, loss = 1.8998
# epoch 5 / 500, step 62/110, loss = 1.9587
# epoch 5 / 500, step 63/110, loss = 1.7584
# epoch 5 / 500, step 64/110, loss = 1.7654
# epoch 5 / 500, step 65/110, loss = 1.9051
# epoch 5 / 500, step 66/110, loss = 1.9859
# epoch 5 / 500, step 67/110, loss = 1.9898
# epoch 5 / 500, step 68/110, loss = 1.8892
# epoch 5 / 500, step 69/110, loss = 1.9609
# epoch 5 / 500, step 70/110, loss = 1.9759
# epoch 5 / 500, step 71/110, loss = 1.8266
# epoch 5 / 500, step 72/110, loss = 1.9108
# epoch 5 / 500, step 73/110, loss = 1.8936
# epoch 5 / 500, step 74/110, loss = 1.8178
# epoch 5 / 500, step 75/110, loss = 2.0163
# epoch 5 / 500, step 76/110, loss = 1.8728
# epoch 5 / 500, step 77/110, loss = 1.9008
# epoch 5 / 500, step 78/110, loss = 1.8840
# epoch 5 / 500, step 79/110, loss = 1.9540
# epoch 5 / 500, step 80/110, loss = 1.9539
# epoch 5 / 500, step 81/110, loss = 1.9804
# epoch 5 / 500, step 82/110, loss = 1.9943
# epoch 5 / 500, step 83/110, loss = 1.9596
# epoch 5 / 500, step 84/110, loss = 1.9392
# epoch 5 / 500, step 85/110, loss = 1.7977
# epoch 5 / 500, step 86/110, loss = 1.9483
# epoch 5 / 500, step 87/110, loss = 1.8895
# epoch 5 / 500, step 88/110, loss = 1.9378
# epoch 5 / 500, step 89/110, loss = 1.8827
# epoch 5 / 500, step 90/110, loss = 1.9746
# epoch 5 / 500, step 91/110, loss = 1.9511
# epoch 5 / 500, step 92/110, loss = 1.8952
# epoch 5 / 500, step 93/110, loss = 1.8928
# epoch 5 / 500, step 94/110, loss = 1.9479
# epoch 5 / 500, step 95/110, loss = 1.9782
# epoch 5 / 500, step 96/110, loss = 1.7707
# epoch 5 / 500, step 97/110, loss = 1.9013
# epoch 5 / 500, step 98/110, loss = 1.8310
# epoch 5 / 500, step 99/110, loss = 1.8480
# epoch 5 / 500, step 100/110, loss = 1.8627
# epoch 5 / 500, step 101/110, loss = 1.7482
# epoch 5 / 500, step 102/110, loss = 1.8623
# epoch 5 / 500, step 103/110, loss = 1.9172
# epoch 5 / 500, step 104/110, loss = 1.9422
# epoch 5 / 500, step 105/110, loss = 1.8534
# epoch 5 / 500, step 106/110, loss = 2.0239
# epoch 5 / 500, step 107/110, loss = 1.7588
# epoch 5 / 500, step 108/110, loss = 1.8521
# epoch 5 / 500, step 109/110, loss = 1.7649
# epoch 5 / 500, step 110/110, loss = 1.7134
# epoch 5 / 500, step 1/28, loss = 1.9871
# epoch 5 / 500, step 2/28, loss = 1.9687
# epoch 5 / 500, step 3/28, loss = 1.8835
# epoch 5 / 500, step 4/28, loss = 1.8576
# epoch 5 / 500, step 5/28, loss = 2.1510
# epoch 5 / 500, step 6/28, loss = 1.9612
# epoch 5 / 500, step 7/28, loss = 1.8470
# epoch 5 / 500, step 8/28, loss = 2.0415
# epoch 5 / 500, step 9/28, loss = 1.9399
# epoch 5 / 500, step 10/28, loss = 1.9606
# epoch 5 / 500, step 11/28, loss = 1.8329
# epoch 5 / 500, step 12/28, loss = 1.6266
# epoch 5 / 500, step 13/28, loss = 1.9559
# epoch 5 / 500, step 14/28, loss = 1.8977
# epoch 5 / 500, step 15/28, loss = 1.7152
# epoch 5 / 500, step 16/28, loss = 1.9167
# epoch 5 / 500, step 17/28, loss = 1.9395
# epoch 5 / 500, step 18/28, loss = 2.0075
# epoch 5 / 500, step 19/28, loss = 2.1260
# epoch 5 / 500, step 20/28, loss = 1.9272
# epoch 5 / 500, step 21/28, loss = 1.9510
# epoch 5 / 500, step 22/28, loss = 1.9265
# epoch 5 / 500, step 23/28, loss = 1.9014
# epoch 5 / 500, step 24/28, loss = 2.0438
# epoch 5 / 500, step 25/28, loss = 1.8819
# epoch 5 / 500, step 26/28, loss = 1.9799
# epoch 5 / 500, step 27/28, loss = 1.9254
# epoch 5 / 500, step 28/28, loss = 1.7475
# epoch 6 / 500, step 1/110, loss = 1.8519
# epoch 6 / 500, step 2/110, loss = 1.8340
# epoch 6 / 500, step 3/110, loss = 1.6801
# epoch 6 / 500, step 4/110, loss = 1.9202
# epoch 6 / 500, step 5/110, loss = 1.8050
# epoch 6 / 500, step 6/110, loss = 1.8400
# epoch 6 / 500, step 7/110, loss = 1.7372
# epoch 6 / 500, step 8/110, loss = 1.7792
# epoch 6 / 500, step 9/110, loss = 1.9654
# epoch 6 / 500, step 10/110, loss = 1.7563
# epoch 6 / 500, step 11/110, loss = 1.9493
# epoch 6 / 500, step 12/110, loss = 1.8747
# epoch 6 / 500, step 13/110, loss = 1.9768
# epoch 6 / 500, step 14/110, loss = 1.9744
# epoch 6 / 500, step 15/110, loss = 1.9984
# epoch 6 / 500, step 16/110, loss = 1.8838
# epoch 6 / 500, step 17/110, loss = 2.0075
# epoch 6 / 500, step 18/110, loss = 2.0143
# epoch 6 / 500, step 19/110, loss = 1.8501
# epoch 6 / 500, step 20/110, loss = 1.9310
# epoch 6 / 500, step 21/110, loss = 1.8934
# epoch 6 / 500, step 22/110, loss = 1.7698
# epoch 6 / 500, step 23/110, loss = 1.9131
# epoch 6 / 500, step 24/110, loss = 1.7460
# epoch 6 / 500, step 25/110, loss = 1.8149
# epoch 6 / 500, step 26/110, loss = 1.9500
# epoch 6 / 500, step 27/110, loss = 1.9021
# epoch 6 / 500, step 28/110, loss = 1.8063
# epoch 6 / 500, step 29/110, loss = 1.7520
# epoch 6 / 500, step 30/110, loss = 1.8709
# epoch 6 / 500, step 31/110, loss = 1.8021
# epoch 6 / 500, step 32/110, loss = 1.9205
# epoch 6 / 500, step 33/110, loss = 1.7804
# epoch 6 / 500, step 34/110, loss = 1.8312
# epoch 6 / 500, step 35/110, loss = 1.8329
# epoch 6 / 500, step 36/110, loss = 1.7695
# epoch 6 / 500, step 37/110, loss = 1.8013
# epoch 6 / 500, step 38/110, loss = 1.9358
# epoch 6 / 500, step 39/110, loss = 1.9039
# epoch 6 / 500, step 40/110, loss = 1.7478
# epoch 6 / 500, step 41/110, loss = 1.8907
# epoch 6 / 500, step 42/110, loss = 1.9417
# epoch 6 / 500, step 43/110, loss = 1.9263
# epoch 6 / 500, step 44/110, loss = 1.8698
# epoch 6 / 500, step 45/110, loss = 1.7700
# epoch 6 / 500, step 46/110, loss = 1.8255
# epoch 6 / 500, step 47/110, loss = 1.7309
# epoch 6 / 500, step 48/110, loss = 1.8413
# epoch 6 / 500, step 49/110, loss = 1.9594
# epoch 6 / 500, step 50/110, loss = 1.7418
# epoch 6 / 500, step 51/110, loss = 1.8134
# epoch 6 / 500, step 52/110, loss = 1.8241
# epoch 6 / 500, step 53/110, loss = 2.0243
# epoch 6 / 500, step 54/110, loss = 1.8026
# epoch 6 / 500, step 55/110, loss = 1.9901
# epoch 6 / 500, step 56/110, loss = 1.7570
# epoch 6 / 500, step 57/110, loss = 1.8264
# epoch 6 / 500, step 58/110, loss = 1.8251
# epoch 6 / 500, step 59/110, loss = 1.9755
# epoch 6 / 500, step 60/110, loss = 1.8548
# epoch 6 / 500, step 61/110, loss = 1.8699
# epoch 6 / 500, step 62/110, loss = 1.6524
# epoch 6 / 500, step 63/110, loss = 1.9198
# epoch 6 / 500, step 64/110, loss = 1.7426
# epoch 6 / 500, step 65/110, loss = 1.6530
# epoch 6 / 500, step 66/110, loss = 1.7846
# epoch 6 / 500, step 67/110, loss = 1.9499
# epoch 6 / 500, step 68/110, loss = 2.0051
# epoch 6 / 500, step 69/110, loss = 1.8694
# epoch 6 / 500, step 70/110, loss = 1.9232
# epoch 6 / 500, step 71/110, loss = 1.9020
# epoch 6 / 500, step 72/110, loss = 1.6235
# epoch 6 / 500, step 73/110, loss = 1.6277
# epoch 6 / 500, step 74/110, loss = 1.8146
# epoch 6 / 500, step 75/110, loss = 1.4062
# epoch 6 / 500, step 76/110, loss = 1.4348
# epoch 6 / 500, step 77/110, loss = 1.7366
# epoch 6 / 500, step 78/110, loss = 2.0540
# epoch 6 / 500, step 79/110, loss = 1.8965
# epoch 6 / 500, step 80/110, loss = 1.8266
# epoch 6 / 500, step 81/110, loss = 1.9147
# epoch 6 / 500, step 82/110, loss = 1.5948
# epoch 6 / 500, step 83/110, loss = 1.7033
# epoch 6 / 500, step 84/110, loss = 1.8487
# epoch 6 / 500, step 85/110, loss = 2.0546
# epoch 6 / 500, step 86/110, loss = 1.9175
# epoch 6 / 500, step 87/110, loss = 1.8112
# epoch 6 / 500, step 88/110, loss = 1.9369
# epoch 6 / 500, step 89/110, loss = 1.8420
# epoch 6 / 500, step 90/110, loss = 1.9950
# epoch 6 / 500, step 91/110, loss = 2.1192
# epoch 6 / 500, step 92/110, loss = 1.5049
# epoch 6 / 500, step 93/110, loss = 1.7897
# epoch 6 / 500, step 94/110, loss = 1.4943
# epoch 6 / 500, step 95/110, loss = 1.6139
# epoch 6 / 500, step 96/110, loss = 2.0206
# epoch 6 / 500, step 97/110, loss = 1.8040
# epoch 6 / 500, step 98/110, loss = 2.0139
# epoch 6 / 500, step 99/110, loss = 1.5276
# epoch 6 / 500, step 100/110, loss = 1.6443
# epoch 6 / 500, step 101/110, loss = 1.9131
# epoch 6 / 500, step 102/110, loss = 1.6838
# epoch 6 / 500, step 103/110, loss = 1.8477
# epoch 6 / 500, step 104/110, loss = 1.6829
# epoch 6 / 500, step 105/110, loss = 1.7144
# epoch 6 / 500, step 106/110, loss = 1.7405
# epoch 6 / 500, step 107/110, loss = 1.8550
# epoch 6 / 500, step 108/110, loss = 1.8792
# epoch 6 / 500, step 109/110, loss = 1.8659
# epoch 6 / 500, step 110/110, loss = 1.8750
# epoch 6 / 500, step 1/28, loss = 2.0323
# epoch 6 / 500, step 2/28, loss = 1.8443
# epoch 6 / 500, step 3/28, loss = 1.4891
# epoch 6 / 500, step 4/28, loss = 1.7827
# epoch 6 / 500, step 5/28, loss = 1.9389
# epoch 6 / 500, step 6/28, loss = 1.6728
# epoch 6 / 500, step 7/28, loss = 1.7649
# epoch 6 / 500, step 8/28, loss = 1.8500
# epoch 6 / 500, step 9/28, loss = 1.7368
# epoch 6 / 500, step 10/28, loss = 1.9564
# epoch 6 / 500, step 11/28, loss = 1.8192
# epoch 6 / 500, step 12/28, loss = 1.4274
# epoch 6 / 500, step 13/28, loss = 1.7198
# epoch 6 / 500, step 14/28, loss = 1.9765
# epoch 6 / 500, step 15/28, loss = 1.4389
# epoch 6 / 500, step 16/28, loss = 1.7008
# epoch 6 / 500, step 17/28, loss = 1.6931
# epoch 6 / 500, step 18/28, loss = 1.8770
# epoch 6 / 500, step 19/28, loss = 1.9784
# epoch 6 / 500, step 20/28, loss = 1.7067
# epoch 6 / 500, step 21/28, loss = 1.8769
# epoch 6 / 500, step 22/28, loss = 1.8258
# epoch 6 / 500, step 23/28, loss = 1.7420
# epoch 6 / 500, step 24/28, loss = 1.8830
# epoch 6 / 500, step 25/28, loss = 1.8060
# epoch 6 / 500, step 26/28, loss = 1.8743
# epoch 6 / 500, step 27/28, loss = 1.8066
# epoch 6 / 500, step 28/28, loss = 1.8101
# epoch 7 / 500, step 1/110, loss = 1.5382
# epoch 7 / 500, step 2/110, loss = 1.5812
# epoch 7 / 500, step 3/110, loss = 1.5072
# epoch 7 / 500, step 4/110, loss = 1.3632
# epoch 7 / 500, step 5/110, loss = 1.7503
# epoch 7 / 500, step 6/110, loss = 1.8060
# epoch 7 / 500, step 7/110, loss = 1.8441
# epoch 7 / 500, step 8/110, loss = 1.7611
# epoch 7 / 500, step 9/110, loss = 1.7355
# epoch 7 / 500, step 10/110, loss = 1.6641
# epoch 7 / 500, step 11/110, loss = 1.7887
# epoch 7 / 500, step 12/110, loss = 1.8375
# epoch 7 / 500, step 13/110, loss = 1.7653
# epoch 7 / 500, step 14/110, loss = 1.7839
# epoch 7 / 500, step 15/110, loss = 1.8295
# epoch 7 / 500, step 16/110, loss = 1.5997
# epoch 7 / 500, step 17/110, loss = 1.8853
# epoch 7 / 500, step 18/110, loss = 1.6961
# epoch 7 / 500, step 19/110, loss = 1.9547
# epoch 7 / 500, step 20/110, loss = 1.6763
# epoch 7 / 500, step 21/110, loss = 1.7744
# epoch 7 / 500, step 22/110, loss = 1.5494
# epoch 7 / 500, step 23/110, loss = 1.4731
# epoch 7 / 500, step 24/110, loss = 1.7561
# epoch 7 / 500, step 25/110, loss = 1.8530
# epoch 7 / 500, step 26/110, loss = 1.8264
# epoch 7 / 500, step 27/110, loss = 1.7310
# epoch 7 / 500, step 28/110, loss = 1.5477
# epoch 7 / 500, step 29/110, loss = 1.9954
# epoch 7 / 500, step 30/110, loss = 1.6886
# epoch 7 / 500, step 31/110, loss = 1.7372
# epoch 7 / 500, step 32/110, loss = 1.7115
# epoch 7 / 500, step 33/110, loss = 1.7685
# epoch 7 / 500, step 34/110, loss = 1.7656
# epoch 7 / 500, step 35/110, loss = 1.7164
# epoch 7 / 500, step 36/110, loss = 2.0606
# epoch 7 / 500, step 37/110, loss = 1.9521
# epoch 7 / 500, step 38/110, loss = 2.0055
# epoch 7 / 500, step 39/110, loss = 2.0568
# epoch 7 / 500, step 40/110, loss = 2.0713
# epoch 7 / 500, step 41/110, loss = 1.9448
# epoch 7 / 500, step 42/110, loss = 1.8564
# epoch 7 / 500, step 43/110, loss = 1.8354
# epoch 7 / 500, step 44/110, loss = 1.8509
# epoch 7 / 500, step 45/110, loss = 1.8785
# epoch 7 / 500, step 46/110, loss = 1.9667
# epoch 7 / 500, step 47/110, loss = 1.8140
# epoch 7 / 500, step 48/110, loss = 1.6770
# epoch 7 / 500, step 49/110, loss = 1.8390
# epoch 7 / 500, step 50/110, loss = 1.8344
# epoch 7 / 500, step 51/110, loss = 1.7230
# epoch 7 / 500, step 52/110, loss = 1.7688
# epoch 7 / 500, step 53/110, loss = 1.8920
# epoch 7 / 500, step 54/110, loss = 2.1091
# epoch 7 / 500, step 55/110, loss = 1.7240
# epoch 7 / 500, step 56/110, loss = 1.8212
# epoch 7 / 500, step 57/110, loss = 1.9174
# epoch 7 / 500, step 58/110, loss = 1.8247
# epoch 7 / 500, step 59/110, loss = 1.8695
# epoch 7 / 500, step 60/110, loss = 1.9611
# epoch 7 / 500, step 61/110, loss = 1.7620
# epoch 7 / 500, step 62/110, loss = 1.8734
# epoch 7 / 500, step 63/110, loss = 1.6225
# epoch 7 / 500, step 64/110, loss = 1.6516
# epoch 7 / 500, step 65/110, loss = 1.8697
# epoch 7 / 500, step 66/110, loss = 1.7105
# epoch 7 / 500, step 67/110, loss = 1.7732
# epoch 7 / 500, step 68/110, loss = 1.9558
# epoch 7 / 500, step 69/110, loss = 1.8613
# epoch 7 / 500, step 70/110, loss = 2.0283
# epoch 7 / 500, step 71/110, loss = 1.9329
# epoch 7 / 500, step 72/110, loss = 1.8281
# epoch 7 / 500, step 73/110, loss = 1.8081
# epoch 7 / 500, step 74/110, loss = 1.6529
# epoch 7 / 500, step 75/110, loss = 1.9420
# epoch 7 / 500, step 76/110, loss = 1.9934
# epoch 7 / 500, step 77/110, loss = 1.8572
# epoch 7 / 500, step 78/110, loss = 1.8035
# epoch 7 / 500, step 79/110, loss = 1.7352
# epoch 7 / 500, step 80/110, loss = 1.5985
# epoch 7 / 500, step 81/110, loss = 1.8069
# epoch 7 / 500, step 82/110, loss = 1.7317
# epoch 7 / 500, step 83/110, loss = 1.8956
# epoch 7 / 500, step 84/110, loss = 1.8088
# epoch 7 / 500, step 85/110, loss = 1.5385
# epoch 7 / 500, step 86/110, loss = 1.8724
# epoch 7 / 500, step 87/110, loss = 1.4476
# epoch 7 / 500, step 88/110, loss = 2.1791
# epoch 7 / 500, step 89/110, loss = 1.4971
# epoch 7 / 500, step 90/110, loss = 1.4952
# epoch 7 / 500, step 91/110, loss = 1.7012
# epoch 7 / 500, step 92/110, loss = 1.9729
# epoch 7 / 500, step 93/110, loss = 1.7535
# epoch 7 / 500, step 94/110, loss = 1.7738
# epoch 7 / 500, step 95/110, loss = 1.7764
# epoch 7 / 500, step 96/110, loss = 1.8180
# epoch 7 / 500, step 97/110, loss = 1.5427
# epoch 7 / 500, step 98/110, loss = 1.7182
# epoch 7 / 500, step 99/110, loss = 1.4997
# epoch 7 / 500, step 100/110, loss = 1.5410
# epoch 7 / 500, step 101/110, loss = 1.7317
# epoch 7 / 500, step 102/110, loss = 1.4698
# epoch 7 / 500, step 103/110, loss = 1.6836
# epoch 7 / 500, step 104/110, loss = 1.7816
# epoch 7 / 500, step 105/110, loss = 1.3771
# epoch 7 / 500, step 106/110, loss = 1.8000
# epoch 7 / 500, step 107/110, loss = 1.4553
# epoch 7 / 500, step 108/110, loss = 1.7109
# epoch 7 / 500, step 109/110, loss = 1.7056
# epoch 7 / 500, step 110/110, loss = 1.4818
# epoch 7 / 500, step 1/28, loss = 2.2004
# epoch 7 / 500, step 2/28, loss = 1.4494
# epoch 7 / 500, step 3/28, loss = 2.0207
# epoch 7 / 500, step 4/28, loss = 1.7104
# epoch 7 / 500, step 5/28, loss = 1.8486
# epoch 7 / 500, step 6/28, loss = 1.7531
# epoch 7 / 500, step 7/28, loss = 1.9571
# epoch 7 / 500, step 8/28, loss = 2.1086
# epoch 7 / 500, step 9/28, loss = 1.6125
# epoch 7 / 500, step 10/28, loss = 1.7392
# epoch 7 / 500, step 11/28, loss = 1.6774
# epoch 7 / 500, step 12/28, loss = 1.1073
# epoch 7 / 500, step 13/28, loss = 1.6174
# epoch 7 / 500, step 14/28, loss = 1.7845
# epoch 7 / 500, step 15/28, loss = 1.2230
# epoch 7 / 500, step 16/28, loss = 1.9728
# epoch 7 / 500, step 17/28, loss = 1.4880
# epoch 7 / 500, step 18/28, loss = 1.6642
# epoch 7 / 500, step 19/28, loss = 1.8827
# epoch 7 / 500, step 20/28, loss = 1.9236
# epoch 7 / 500, step 21/28, loss = 1.4460
# epoch 7 / 500, step 22/28, loss = 1.5296
# epoch 7 / 500, step 23/28, loss = 2.0862
# epoch 7 / 500, step 24/28, loss = 1.8481
# epoch 7 / 500, step 25/28, loss = 1.4541
# epoch 7 / 500, step 26/28, loss = 1.8946
# epoch 7 / 500, step 27/28, loss = 1.9591
# epoch 7 / 500, step 28/28, loss = 1.5965
# epoch 8 / 500, step 1/110, loss = 1.7678
# epoch 8 / 500, step 2/110, loss = 1.6146
# epoch 8 / 500, step 3/110, loss = 1.7186
# epoch 8 / 500, step 4/110, loss = 1.3692
# epoch 8 / 500, step 5/110, loss = 1.8616
# epoch 8 / 500, step 6/110, loss = 1.9440
# epoch 8 / 500, step 7/110, loss = 2.0667
# epoch 8 / 500, step 8/110, loss = 1.4879
# epoch 8 / 500, step 9/110, loss = 1.6491
# epoch 8 / 500, step 10/110, loss = 1.8143
# epoch 8 / 500, step 11/110, loss = 1.7101
# epoch 8 / 500, step 12/110, loss = 1.9087
# epoch 8 / 500, step 13/110, loss = 1.9154
# epoch 8 / 500, step 14/110, loss = 1.4658
# epoch 8 / 500, step 15/110, loss = 1.5609
# epoch 8 / 500, step 16/110, loss = 1.5393
# epoch 8 / 500, step 17/110, loss = 1.6858
# epoch 8 / 500, step 18/110, loss = 2.1772
# epoch 8 / 500, step 19/110, loss = 1.6056
# epoch 8 / 500, step 20/110, loss = 1.8165
# epoch 8 / 500, step 21/110, loss = 1.4677
# epoch 8 / 500, step 22/110, loss = 1.5824
# epoch 8 / 500, step 23/110, loss = 2.0644
# epoch 8 / 500, step 24/110, loss = 1.6574
# epoch 8 / 500, step 25/110, loss = 1.7644
# epoch 8 / 500, step 26/110, loss = 1.8572
# epoch 8 / 500, step 27/110, loss = 1.8370
# epoch 8 / 500, step 28/110, loss = 1.8389
# epoch 8 / 500, step 29/110, loss = 1.6722
# epoch 8 / 500, step 30/110, loss = 1.5995
# epoch 8 / 500, step 31/110, loss = 1.2939
# epoch 8 / 500, step 32/110, loss = 1.8457
# epoch 8 / 500, step 33/110, loss = 1.1212
# epoch 8 / 500, step 34/110, loss = 1.6114
# epoch 8 / 500, step 35/110, loss = 2.0077
# epoch 8 / 500, step 36/110, loss = 1.8544
# epoch 8 / 500, step 37/110, loss = 1.5867
# epoch 8 / 500, step 38/110, loss = 1.3815
# epoch 8 / 500, step 39/110, loss = 1.7818
# epoch 8 / 500, step 40/110, loss = 1.8883
# epoch 8 / 500, step 41/110, loss = 1.9934
# epoch 8 / 500, step 42/110, loss = 1.9390
# epoch 8 / 500, step 43/110, loss = 1.9539
# epoch 8 / 500, step 44/110, loss = 1.8985
# epoch 8 / 500, step 45/110, loss = 1.9438
# epoch 8 / 500, step 46/110, loss = 1.9593
# epoch 8 / 500, step 47/110, loss = 1.7745
# epoch 8 / 500, step 48/110, loss = 1.8945
# epoch 8 / 500, step 49/110, loss = 1.9013
# epoch 8 / 500, step 50/110, loss = 1.8292
# epoch 8 / 500, step 51/110, loss = 1.8636
# epoch 8 / 500, step 52/110, loss = 1.8515
# epoch 8 / 500, step 53/110, loss = 1.7331
# epoch 8 / 500, step 54/110, loss = 1.8182
# epoch 8 / 500, step 55/110, loss = 1.6321
# epoch 8 / 500, step 56/110, loss = 1.6499
# epoch 8 / 500, step 57/110, loss = 1.4872
# epoch 8 / 500, step 58/110, loss = 1.6957
# epoch 8 / 500, step 59/110, loss = 1.7322
# epoch 8 / 500, step 60/110, loss = 1.6188
# epoch 8 / 500, step 61/110, loss = 1.5221
# epoch 8 / 500, step 62/110, loss = 1.3941
# epoch 8 / 500, step 63/110, loss = 1.2877
# epoch 8 / 500, step 64/110, loss = 1.9891
# epoch 8 / 500, step 65/110, loss = 1.5343
# epoch 8 / 500, step 66/110, loss = 1.8594
# epoch 8 / 500, step 67/110, loss = 1.7515
# epoch 8 / 500, step 68/110, loss = 1.5705
# epoch 8 / 500, step 69/110, loss = 1.5353
# epoch 8 / 500, step 70/110, loss = 1.6162
# epoch 8 / 500, step 71/110, loss = 1.7233
# epoch 8 / 500, step 72/110, loss = 1.6457
# epoch 8 / 500, step 73/110, loss = 1.6411
# epoch 8 / 500, step 74/110, loss = 1.7558
# epoch 8 / 500, step 75/110, loss = 1.7387
# epoch 8 / 500, step 76/110, loss = 1.9726
# epoch 8 / 500, step 77/110, loss = 1.1770
# epoch 8 / 500, step 78/110, loss = 1.9301
# epoch 8 / 500, step 79/110, loss = 1.9294
# epoch 8 / 500, step 80/110, loss = 1.6209
# epoch 8 / 500, step 81/110, loss = 1.4889
# epoch 8 / 500, step 82/110, loss = 1.2208
# epoch 8 / 500, step 83/110, loss = 1.8404
# epoch 8 / 500, step 84/110, loss = 1.9547
# epoch 8 / 500, step 85/110, loss = 1.4165
# epoch 8 / 500, step 86/110, loss = 1.4083
# epoch 8 / 500, step 87/110, loss = 1.6411
# epoch 8 / 500, step 88/110, loss = 1.6942
# epoch 8 / 500, step 89/110, loss = 1.4759
# epoch 8 / 500, step 90/110, loss = 1.4257
# epoch 8 / 500, step 91/110, loss = 1.2167
# epoch 8 / 500, step 92/110, loss = 1.9726
# epoch 8 / 500, step 93/110, loss = 1.5474
# epoch 8 / 500, step 94/110, loss = 1.7219
# epoch 8 / 500, step 95/110, loss = 1.7139
# epoch 8 / 500, step 96/110, loss = 1.6906
# epoch 8 / 500, step 97/110, loss = 1.3490
# epoch 8 / 500, step 98/110, loss = 1.2370
# epoch 8 / 500, step 99/110, loss = 1.5465
# epoch 8 / 500, step 100/110, loss = 1.6395
# epoch 8 / 500, step 101/110, loss = 1.4458
# epoch 8 / 500, step 102/110, loss = 1.5908
# epoch 8 / 500, step 103/110, loss = 1.5692
# epoch 8 / 500, step 104/110, loss = 1.6805
# epoch 8 / 500, step 105/110, loss = 1.3871
# epoch 8 / 500, step 106/110, loss = 1.4991
# epoch 8 / 500, step 107/110, loss = 1.6890
# epoch 8 / 500, step 108/110, loss = 1.5234
# epoch 8 / 500, step 109/110, loss = 1.6545
# epoch 8 / 500, step 110/110, loss = 1.4841
# epoch 8 / 500, step 1/28, loss = 1.7524
# epoch 8 / 500, step 2/28, loss = 1.5749
# epoch 8 / 500, step 3/28, loss = 1.2465
# epoch 8 / 500, step 4/28, loss = 1.4754
# epoch 8 / 500, step 5/28, loss = 1.5400
# epoch 8 / 500, step 6/28, loss = 1.2446
# epoch 8 / 500, step 7/28, loss = 1.6541
# epoch 8 / 500, step 8/28, loss = 1.6742
# epoch 8 / 500, step 9/28, loss = 1.7167
# epoch 8 / 500, step 10/28, loss = 1.6687
# epoch 8 / 500, step 11/28, loss = 1.1927
# epoch 8 / 500, step 12/28, loss = 0.8597
# epoch 8 / 500, step 13/28, loss = 1.4780
# epoch 8 / 500, step 14/28, loss = 1.6229
# epoch 8 / 500, step 15/28, loss = 1.1699
# epoch 8 / 500, step 16/28, loss = 1.5477
# epoch 8 / 500, step 17/28, loss = 1.3897
# epoch 8 / 500, step 18/28, loss = 1.6550
# epoch 8 / 500, step 19/28, loss = 1.9719
# epoch 8 / 500, step 20/28, loss = 1.6765
# epoch 8 / 500, step 21/28, loss = 1.4439
# epoch 8 / 500, step 22/28, loss = 1.4629
# epoch 8 / 500, step 23/28, loss = 1.2119
# epoch 8 / 500, step 24/28, loss = 1.4835
# epoch 8 / 500, step 25/28, loss = 1.4176
# epoch 8 / 500, step 26/28, loss = 1.4513
# epoch 8 / 500, step 27/28, loss = 1.8659
# epoch 8 / 500, step 28/28, loss = 1.0243
# epoch 9 / 500, step 1/110, loss = 1.4268
# epoch 9 / 500, step 2/110, loss = 1.4593
# epoch 9 / 500, step 3/110, loss = 1.7155
# epoch 9 / 500, step 4/110, loss = 1.6208
# epoch 9 / 500, step 5/110, loss = 1.1252
# epoch 9 / 500, step 6/110, loss = 1.8150
# epoch 9 / 500, step 7/110, loss = 1.5718
# epoch 9 / 500, step 8/110, loss = 1.5848
# epoch 9 / 500, step 9/110, loss = 1.7174
# epoch 9 / 500, step 10/110, loss = 1.6387
# epoch 9 / 500, step 11/110, loss = 1.6148
# epoch 9 / 500, step 12/110, loss = 1.2981
# epoch 9 / 500, step 13/110, loss = 1.8686
# epoch 9 / 500, step 14/110, loss = 1.9658
# epoch 9 / 500, step 15/110, loss = 1.6145
# epoch 9 / 500, step 16/110, loss = 1.4410
# epoch 9 / 500, step 17/110, loss = 2.0170
# epoch 9 / 500, step 18/110, loss = 1.2994
# epoch 9 / 500, step 19/110, loss = 1.8204
# epoch 9 / 500, step 20/110, loss = 1.1524
# epoch 9 / 500, step 21/110, loss = 1.5332
# epoch 9 / 500, step 22/110, loss = 1.5434
# epoch 9 / 500, step 23/110, loss = 1.3825
# epoch 9 / 500, step 24/110, loss = 1.2485
# epoch 9 / 500, step 25/110, loss = 1.4146
# epoch 9 / 500, step 26/110, loss = 1.2869
# epoch 9 / 500, step 27/110, loss = 1.4755
# epoch 9 / 500, step 28/110, loss = 1.5062
# epoch 9 / 500, step 29/110, loss = 1.5582
# epoch 9 / 500, step 30/110, loss = 1.3293
# epoch 9 / 500, step 31/110, loss = 1.5464
# epoch 9 / 500, step 32/110, loss = 1.8921
# epoch 9 / 500, step 33/110, loss = 2.0834
# epoch 9 / 500, step 34/110, loss = 1.5043
# epoch 9 / 500, step 35/110, loss = 1.4283
# epoch 9 / 500, step 36/110, loss = 1.3321
# epoch 9 / 500, step 37/110, loss = 1.9740
# epoch 9 / 500, step 38/110, loss = 1.6954
# epoch 9 / 500, step 39/110, loss = 1.1129
# epoch 9 / 500, step 40/110, loss = 1.0880
# epoch 9 / 500, step 41/110, loss = 1.1833
# epoch 9 / 500, step 42/110, loss = 1.4169
# epoch 9 / 500, step 43/110, loss = 2.1491
# epoch 9 / 500, step 44/110, loss = 2.1426
# epoch 9 / 500, step 45/110, loss = 1.1894
# ...
# epoch 498 / 500, step 50/110, loss = 0.0006
# epoch 498 / 500, step 51/110, loss = 0.0020
# epoch 498 / 500, step 52/110, loss = 0.0026
# epoch 498 / 500, step 53/110, loss = 0.0116
# epoch 498 / 500, step 54/110, loss = 0.0002
# epoch 498 / 500, step 55/110, loss = 0.0025
# epoch 498 / 500, step 56/110, loss = 0.0131
# epoch 498 / 500, step 57/110, loss = 0.0276
# epoch 498 / 500, step 58/110, loss = 0.0276
# epoch 498 / 500, step 59/110, loss = 0.0098
# epoch 498 / 500, step 60/110, loss = 0.0071
# epoch 498 / 500, step 61/110, loss = 0.0127
# epoch 498 / 500, step 62/110, loss = 0.0143
# epoch 498 / 500, step 63/110, loss = 0.0022
# epoch 498 / 500, step 64/110, loss = 0.0013
# epoch 498 / 500, step 65/110, loss = 0.0010
# epoch 498 / 500, step 66/110, loss = 0.0037
# epoch 498 / 500, step 67/110, loss = 0.0050
# epoch 498 / 500, step 68/110, loss = 0.0241
# epoch 498 / 500, step 69/110, loss = 0.0011
# epoch 498 / 500, step 70/110, loss = 0.0026
# epoch 498 / 500, step 71/110, loss = 0.0007
# epoch 498 / 500, step 72/110, loss = 0.0026
# epoch 498 / 500, step 73/110, loss = 0.0015
# epoch 498 / 500, step 74/110, loss = 0.0033
# epoch 498 / 500, step 75/110, loss = 0.3307
# epoch 498 / 500, step 76/110, loss = 0.0009
# epoch 498 / 500, step 77/110, loss = 0.0040
# epoch 498 / 500, step 78/110, loss = 0.0046
# epoch 498 / 500, step 79/110, loss = 0.0012
# epoch 498 / 500, step 80/110, loss = 0.0001
# epoch 498 / 500, step 81/110, loss = 0.0012
# epoch 498 / 500, step 82/110, loss = 0.0136
# epoch 498 / 500, step 83/110, loss = 0.0004
# epoch 498 / 500, step 84/110, loss = 0.0020
# epoch 498 / 500, step 85/110, loss = 0.0003
# epoch 498 / 500, step 86/110, loss = 0.0006
# epoch 498 / 500, step 87/110, loss = 0.0009
# epoch 498 / 500, step 88/110, loss = 0.0000
# epoch 498 / 500, step 89/110, loss = 0.0118
# epoch 498 / 500, step 90/110, loss = 0.0076
# epoch 498 / 500, step 91/110, loss = 0.3778
# epoch 498 / 500, step 92/110, loss = 0.0030
# epoch 498 / 500, step 93/110, loss = 0.0031
# epoch 498 / 500, step 94/110, loss = 0.0102
# epoch 498 / 500, step 95/110, loss = 0.9567
# epoch 498 / 500, step 96/110, loss = 0.0001
# epoch 498 / 500, step 97/110, loss = 0.8725
# epoch 498 / 500, step 98/110, loss = 0.0001
# epoch 498 / 500, step 99/110, loss = 0.0005
# epoch 498 / 500, step 100/110, loss = 0.0004
# epoch 498 / 500, step 101/110, loss = 0.0010
# epoch 498 / 500, step 102/110, loss = 0.0006
# epoch 498 / 500, step 103/110, loss = 0.0024
# epoch 498 / 500, step 104/110, loss = 0.0005
# epoch 498 / 500, step 105/110, loss = 0.0599
# epoch 498 / 500, step 106/110, loss = 0.0075
# epoch 498 / 500, step 107/110, loss = 0.0044
# epoch 498 / 500, step 108/110, loss = 0.0010
# epoch 498 / 500, step 109/110, loss = 0.0006
# epoch 498 / 500, step 110/110, loss = 0.0006
# epoch 498 / 500, step 1/28, loss = 0.0011
# epoch 498 / 500, step 2/28, loss = 0.0005
# epoch 498 / 500, step 3/28, loss = 0.0180
# epoch 498 / 500, step 4/28, loss = 2.1951
# epoch 498 / 500, step 5/28, loss = 0.0001
# epoch 498 / 500, step 6/28, loss = 0.3169
# epoch 498 / 500, step 7/28, loss = 1.5133
# epoch 498 / 500, step 8/28, loss = 0.0018
# epoch 498 / 500, step 9/28, loss = 0.0029
# epoch 498 / 500, step 10/28, loss = 0.0002
# epoch 498 / 500, step 11/28, loss = 0.0005
# epoch 498 / 500, step 12/28, loss = 0.0002
# epoch 498 / 500, step 13/28, loss = 0.5954
# epoch 498 / 500, step 14/28, loss = 0.0002
# epoch 498 / 500, step 15/28, loss = 0.0029
# epoch 498 / 500, step 16/28, loss = 0.0011
# epoch 498 / 500, step 17/28, loss = 0.0038
# epoch 498 / 500, step 18/28, loss = 0.4404
# epoch 498 / 500, step 19/28, loss = 0.0501
# epoch 498 / 500, step 20/28, loss = 0.0008
# epoch 498 / 500, step 21/28, loss = 0.0062
# epoch 498 / 500, step 22/28, loss = 0.0056
# epoch 498 / 500, step 23/28, loss = 0.4918
# epoch 498 / 500, step 24/28, loss = 0.0008
# epoch 498 / 500, step 25/28, loss = 0.0166
# epoch 498 / 500, step 26/28, loss = 1.2852
# epoch 498 / 500, step 27/28, loss = 0.0017
# epoch 498 / 500, step 28/28, loss = 0.0188
# epoch 499 / 500, step 1/110, loss = 0.0071
# epoch 499 / 500, step 2/110, loss = 0.0010
# epoch 499 / 500, step 3/110, loss = 0.0005
# epoch 499 / 500, step 4/110, loss = 0.0019
# epoch 499 / 500, step 5/110, loss = 0.0004
# epoch 499 / 500, step 6/110, loss = 0.0002
# epoch 499 / 500, step 7/110, loss = 0.0005
# epoch 499 / 500, step 8/110, loss = 0.0089
# epoch 499 / 500, step 9/110, loss = 0.0551
# epoch 499 / 500, step 10/110, loss = 0.0038
# epoch 499 / 500, step 11/110, loss = 0.0005
# epoch 499 / 500, step 12/110, loss = 0.0030
# epoch 499 / 500, step 13/110, loss = 0.0129
# epoch 499 / 500, step 14/110, loss = 0.0073
# epoch 499 / 500, step 15/110, loss = 0.0015
# epoch 499 / 500, step 16/110, loss = 0.0099
# epoch 499 / 500, step 17/110, loss = 0.0006
# epoch 499 / 500, step 18/110, loss = 0.0012
# epoch 499 / 500, step 19/110, loss = 0.0021
# epoch 499 / 500, step 20/110, loss = 0.0823
# epoch 499 / 500, step 21/110, loss = 0.0009
# epoch 499 / 500, step 22/110, loss = 0.0061
# epoch 499 / 500, step 23/110, loss = 0.0002
# epoch 499 / 500, step 24/110, loss = 0.0008
# epoch 499 / 500, step 25/110, loss = 0.0023
# epoch 499 / 500, step 26/110, loss = 0.0147
# epoch 499 / 500, step 27/110, loss = 0.0011
# epoch 499 / 500, step 28/110, loss = 0.0209
# epoch 499 / 500, step 29/110, loss = 0.5218
# epoch 499 / 500, step 30/110, loss = 0.0002
# epoch 499 / 500, step 31/110, loss = 0.0003
# epoch 499 / 500, step 32/110, loss = 0.0141
# epoch 499 / 500, step 33/110, loss = 0.0023
# epoch 499 / 500, step 34/110, loss = 0.0030
# epoch 499 / 500, step 35/110, loss = 0.0012
# epoch 499 / 500, step 36/110, loss = 0.0005
# epoch 499 / 500, step 37/110, loss = 0.0023
# epoch 499 / 500, step 38/110, loss = 0.0028
# epoch 499 / 500, step 39/110, loss = 0.0010
# epoch 499 / 500, step 40/110, loss = 0.0355
# epoch 499 / 500, step 41/110, loss = 0.0234
# epoch 499 / 500, step 42/110, loss = 0.0025
# epoch 499 / 500, step 43/110, loss = 0.0115
# epoch 499 / 500, step 44/110, loss = 0.0022
# epoch 499 / 500, step 45/110, loss = 0.0012
# epoch 499 / 500, step 46/110, loss = 0.0116
# epoch 499 / 500, step 47/110, loss = 0.0425
# epoch 499 / 500, step 48/110, loss = 0.0013
# epoch 499 / 500, step 49/110, loss = 0.0038
# epoch 499 / 500, step 50/110, loss = 0.5884
# epoch 499 / 500, step 51/110, loss = 0.0025
# epoch 499 / 500, step 52/110, loss = 0.0063
# epoch 499 / 500, step 53/110, loss = 0.0031
# epoch 499 / 500, step 54/110, loss = 0.0024
# epoch 499 / 500, step 55/110, loss = 0.0002
# epoch 499 / 500, step 56/110, loss = 0.0042
# epoch 499 / 500, step 57/110, loss = 0.0063
# epoch 499 / 500, step 58/110, loss = 0.0356
# epoch 499 / 500, step 59/110, loss = 0.0004
# epoch 499 / 500, step 60/110, loss = 0.0020
# epoch 499 / 500, step 61/110, loss = 0.0042
# epoch 499 / 500, step 62/110, loss = 0.0031
# epoch 499 / 500, step 63/110, loss = 0.0006
# epoch 499 / 500, step 64/110, loss = 0.0005
# epoch 499 / 500, step 65/110, loss = 0.0008
# epoch 499 / 500, step 66/110, loss = 0.0043
# epoch 499 / 500, step 67/110, loss = 0.0016
# epoch 499 / 500, step 68/110, loss = 0.0019
# epoch 499 / 500, step 69/110, loss = 0.0088
# epoch 499 / 500, step 70/110, loss = 0.0012
# epoch 499 / 500, step 71/110, loss = 0.0179
# epoch 499 / 500, step 72/110, loss = 0.0005
# epoch 499 / 500, step 73/110, loss = 0.0005
# epoch 499 / 500, step 74/110, loss = 0.0001
# epoch 499 / 500, step 75/110, loss = 0.0009
# epoch 499 / 500, step 76/110, loss = 0.0034
# epoch 499 / 500, step 77/110, loss = 0.0002
# epoch 499 / 500, step 78/110, loss = 0.0003
# epoch 499 / 500, step 79/110, loss = 0.0004
# epoch 499 / 500, step 80/110, loss = 0.0042
# epoch 499 / 500, step 81/110, loss = 0.0034
# epoch 499 / 500, step 82/110, loss = 0.0008
# epoch 499 / 500, step 83/110, loss = 0.0006
# epoch 499 / 500, step 84/110, loss = 0.0057
# epoch 499 / 500, step 85/110, loss = 0.0023
# epoch 499 / 500, step 86/110, loss = 0.0094
# epoch 499 / 500, step 87/110, loss = 0.0814
# epoch 499 / 500, step 88/110, loss = 0.0001
# epoch 499 / 500, step 89/110, loss = 0.0005
# epoch 499 / 500, step 90/110, loss = 0.0015
# epoch 499 / 500, step 91/110, loss = 0.0011
# epoch 499 / 500, step 92/110, loss = 0.0008
# epoch 499 / 500, step 93/110, loss = 0.2640
# epoch 499 / 500, step 94/110, loss = 0.0028
# epoch 499 / 500, step 95/110, loss = 0.0016
# epoch 499 / 500, step 96/110, loss = 0.0064
# epoch 499 / 500, step 97/110, loss = 0.0046
# epoch 499 / 500, step 98/110, loss = 0.0010
# epoch 499 / 500, step 99/110, loss = 0.0027
# epoch 499 / 500, step 100/110, loss = 0.0005
# epoch 499 / 500, step 101/110, loss = 0.0007
# epoch 499 / 500, step 102/110, loss = 0.0079
# epoch 499 / 500, step 103/110, loss = 0.0006
# epoch 499 / 500, step 104/110, loss = 0.0472
# epoch 499 / 500, step 105/110, loss = 0.0003
# epoch 499 / 500, step 106/110, loss = 0.0184
# epoch 499 / 500, step 107/110, loss = 0.0014
# epoch 499 / 500, step 108/110, loss = 0.0009
# epoch 499 / 500, step 109/110, loss = 0.0010
# epoch 499 / 500, step 110/110, loss = 0.9400
# epoch 499 / 500, step 1/28, loss = 0.0008
# epoch 499 / 500, step 2/28, loss = 0.0004
# epoch 499 / 500, step 3/28, loss = 0.2331
# epoch 499 / 500, step 4/28, loss = 1.3984
# epoch 499 / 500, step 5/28, loss = 0.0001
# epoch 499 / 500, step 6/28, loss = 0.2099
# epoch 499 / 500, step 7/28, loss = 1.5244
# epoch 499 / 500, step 8/28, loss = 0.0048
# epoch 499 / 500, step 9/28, loss = 0.0025
# epoch 499 / 500, step 10/28, loss = 0.0001
# epoch 499 / 500, step 11/28, loss = 0.0004
# epoch 499 / 500, step 12/28, loss = 0.0003
# epoch 499 / 500, step 13/28, loss = 0.0031
# epoch 499 / 500, step 14/28, loss = 0.0002
# epoch 499 / 500, step 15/28, loss = 0.0017
# epoch 499 / 500, step 16/28, loss = 0.0008
# epoch 499 / 500, step 17/28, loss = 0.0014
# epoch 499 / 500, step 18/28, loss = 0.0337
# epoch 499 / 500, step 19/28, loss = 0.0419
# epoch 499 / 500, step 20/28, loss = 0.0005
# epoch 499 / 500, step 21/28, loss = 0.0002
# epoch 499 / 500, step 22/28, loss = 0.0047
# epoch 499 / 500, step 23/28, loss = 0.5819
# epoch 499 / 500, step 24/28, loss = 0.0010
# epoch 499 / 500, step 25/28, loss = 0.0010
# epoch 499 / 500, step 26/28, loss = 1.2706
# epoch 499 / 500, step 27/28, loss = 0.0012
# epoch 499 / 500, step 28/28, loss = 0.0069
# epoch 500 / 500, step 1/110, loss = 0.0273
# epoch 500 / 500, step 2/110, loss = 0.0016
# epoch 500 / 500, step 3/110, loss = 0.0023
# epoch 500 / 500, step 4/110, loss = 0.0024
# epoch 500 / 500, step 5/110, loss = 0.0031
# epoch 500 / 500, step 6/110, loss = 0.0005
# epoch 500 / 500, step 7/110, loss = 0.0055
# epoch 500 / 500, step 8/110, loss = 0.0001
# epoch 500 / 500, step 9/110, loss = 0.0015
# epoch 500 / 500, step 10/110, loss = 0.0019
# epoch 500 / 500, step 11/110, loss = 0.0023
# epoch 500 / 500, step 12/110, loss = 0.0004
# epoch 500 / 500, step 13/110, loss = 0.0018
# epoch 500 / 500, step 14/110, loss = 0.0008
# epoch 500 / 500, step 15/110, loss = 0.0004
# epoch 500 / 500, step 16/110, loss = 0.0042
# epoch 500 / 500, step 17/110, loss = 0.0039
# epoch 500 / 500, step 18/110, loss = 0.0015
# epoch 500 / 500, step 19/110, loss = 0.0332
# epoch 500 / 500, step 20/110, loss = 0.0010
# epoch 500 / 500, step 21/110, loss = 0.0217
# epoch 500 / 500, step 22/110, loss = 0.0157
# epoch 500 / 500, step 23/110, loss = 0.0539
# epoch 500 / 500, step 24/110, loss = 0.0042
# epoch 500 / 500, step 25/110, loss = 0.0211
# epoch 500 / 500, step 26/110, loss = 0.2064
# epoch 500 / 500, step 27/110, loss = 0.0709
# epoch 500 / 500, step 28/110, loss = 0.0007
# epoch 500 / 500, step 29/110, loss = 0.0008
# epoch 500 / 500, step 30/110, loss = 0.0144
# epoch 500 / 500, step 31/110, loss = 0.0183
# epoch 500 / 500, step 32/110, loss = 0.0012
# epoch 500 / 500, step 33/110, loss = 0.0012
# epoch 500 / 500, step 34/110, loss = 0.0370
# epoch 500 / 500, step 35/110, loss = 0.0057
# epoch 500 / 500, step 36/110, loss = 0.0017
# epoch 500 / 500, step 37/110, loss = 0.0016
# epoch 500 / 500, step 38/110, loss = 0.0005
# epoch 500 / 500, step 39/110, loss = 0.0190
# epoch 500 / 500, step 40/110, loss = 0.0047
# epoch 500 / 500, step 41/110, loss = 0.0648
# epoch 500 / 500, step 42/110, loss = 0.1774
# epoch 500 / 500, step 43/110, loss = 0.0020
# epoch 500 / 500, step 44/110, loss = 0.0059
# epoch 500 / 500, step 45/110, loss = 0.0015
# epoch 500 / 500, step 46/110, loss = 0.1308
# epoch 500 / 500, step 47/110, loss = 0.1971
# epoch 500 / 500, step 48/110, loss = 0.0399
# epoch 500 / 500, step 49/110, loss = 0.0010
# epoch 500 / 500, step 50/110, loss = 0.0073
# epoch 500 / 500, step 51/110, loss = 0.0007
# epoch 500 / 500, step 52/110, loss = 0.0002
# epoch 500 / 500, step 53/110, loss = 0.0025
# epoch 500 / 500, step 54/110, loss = 0.0006
# epoch 500 / 500, step 55/110, loss = 0.0034
# epoch 500 / 500, step 56/110, loss = 0.0245
# epoch 500 / 500, step 57/110, loss = 0.0014
# epoch 500 / 500, step 58/110, loss = 0.0008
# epoch 500 / 500, step 59/110, loss = 0.0024
# epoch 500 / 500, step 60/110, loss = 0.0031
# epoch 500 / 500, step 61/110, loss = 0.0038
# epoch 500 / 500, step 62/110, loss = 0.0025
# epoch 500 / 500, step 63/110, loss = 0.0002
# epoch 500 / 500, step 64/110, loss = 0.0006
# epoch 500 / 500, step 65/110, loss = 1.0646
# epoch 500 / 500, step 66/110, loss = 0.0063
# epoch 500 / 500, step 67/110, loss = 0.0007
# epoch 500 / 500, step 68/110, loss = 0.0010
# epoch 500 / 500, step 69/110, loss = 0.0032
# epoch 500 / 500, step 70/110, loss = 0.0080
# epoch 500 / 500, step 71/110, loss = 0.0194
# epoch 500 / 500, step 72/110, loss = 0.0003
# epoch 500 / 500, step 73/110, loss = 0.0128
# epoch 500 / 500, step 74/110, loss = 0.1917
# epoch 500 / 500, step 75/110, loss = 0.0263
# epoch 500 / 500, step 76/110, loss = 0.0037
# epoch 500 / 500, step 77/110, loss = 0.7897
# epoch 500 / 500, step 78/110, loss = 0.7266
# epoch 500 / 500, step 79/110, loss = 0.0004
# epoch 500 / 500, step 80/110, loss = 0.0043
# epoch 500 / 500, step 81/110, loss = 0.0069
# epoch 500 / 500, step 82/110, loss = 0.0003
# epoch 500 / 500, step 83/110, loss = 0.0536
# epoch 500 / 500, step 84/110, loss = 0.0006
# epoch 500 / 500, step 85/110, loss = 0.3123
# epoch 500 / 500, step 86/110, loss = 0.0019
# epoch 500 / 500, step 87/110, loss = 0.0006
# epoch 500 / 500, step 88/110, loss = 0.0006
# epoch 500 / 500, step 89/110, loss = 0.0003
# epoch 500 / 500, step 90/110, loss = 0.0012
# epoch 500 / 500, step 91/110, loss = 0.0124
# epoch 500 / 500, step 92/110, loss = 0.0002
# epoch 500 / 500, step 93/110, loss = 0.0011
# epoch 500 / 500, step 94/110, loss = 0.4498
# epoch 500 / 500, step 95/110, loss = 0.0017
# epoch 500 / 500, step 96/110, loss = 0.0135
# epoch 500 / 500, step 97/110, loss = 0.0004
# epoch 500 / 500, step 98/110, loss = 0.0009
# epoch 500 / 500, step 99/110, loss = 0.0007
# epoch 500 / 500, step 100/110, loss = 0.0010
# epoch 500 / 500, step 101/110, loss = 0.0032
# epoch 500 / 500, step 102/110, loss = 0.0010
# epoch 500 / 500, step 103/110, loss = 0.0015
# epoch 500 / 500, step 104/110, loss = 0.0046
# epoch 500 / 500, step 105/110, loss = 0.0108
# epoch 500 / 500, step 106/110, loss = 0.0003
# epoch 500 / 500, step 107/110, loss = 0.0006
# epoch 500 / 500, step 108/110, loss = 0.0013
# epoch 500 / 500, step 109/110, loss = 0.0013
# epoch 500 / 500, step 110/110, loss = 0.0002
# epoch 500 / 500, step 1/28, loss = 0.0008
# epoch 500 / 500, step 2/28, loss = 0.0006
# epoch 500 / 500, step 3/28, loss = 0.2723
# epoch 500 / 500, step 4/28, loss = 1.1915
# epoch 500 / 500, step 5/28, loss = 0.0001
# epoch 500 / 500, step 6/28, loss = 0.0016
# epoch 500 / 500, step 7/28, loss = 1.5264
# epoch 500 / 500, step 8/28, loss = 0.0009
# epoch 500 / 500, step 9/28, loss = 0.0015
# epoch 500 / 500, step 10/28, loss = 0.0002
# epoch 500 / 500, step 11/28, loss = 0.0005
# epoch 500 / 500, step 12/28, loss = 0.0003
# epoch 500 / 500, step 13/28, loss = 0.0108
# epoch 500 / 500, step 14/28, loss = 0.0003
# epoch 500 / 500, step 15/28, loss = 0.0014
# epoch 500 / 500, step 16/28, loss = 0.0009
# epoch 500 / 500, step 17/28, loss = 0.0018
# epoch 500 / 500, step 18/28, loss = 0.0050
# epoch 500 / 500, step 19/28, loss = 0.0078
# epoch 500 / 500, step 20/28, loss = 0.0004
# epoch 500 / 500, step 21/28, loss = 0.0007
# epoch 500 / 500, step 22/28, loss = 0.0013
# epoch 500 / 500, step 23/28, loss = 0.6030
# epoch 500 / 500, step 24/28, loss = 0.0003
# epoch 500 / 500, step 25/28, loss = 0.0018
# epoch 500 / 500, step 26/28, loss = 1.3848
# epoch 500 / 500, step 27/28, loss = 0.0011
# epoch 500 / 500, step 28/28, loss = 0.0155

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 500 epochs the trainning accuracy is 98.85714285714286 and the test accuaracy is 97.71689497716895
#  the maximum accuracy of the test was 99.54337899543378 at the epoch 393
#  the maximum accuracy of the train was 100.0 at the epoch 400
# the accuracy of the training at the best validation accuracy 99.54337899543378 is 99.54285714285714

# %%
print(model.state_dict())
torch.save(model.state_dict(), results_dir + "model_weights.pth")

# model.load_state_dict(torch.load(results_dir + "model_weights.pth"))
# Out:
# OrderedDict({'lstm.weight_ih_l0': tensor([[-1.6726e-02,  6.5232e-03, -1.6524e-02,  ..., -3.3969e-02,
#          -3.0792e-02,  4.5145e-02],
#         [ 5.0771e-02,  3.0644e-02, -1.2455e-02,  ...,  2.8822e-02,
#          -5.5223e-03, -3.2234e-02],
#         [-2.8070e-02, -2.2831e-02, -2.6471e-02,  ..., -2.6256e-03,
#          -3.0395e-02,  1.4788e-02],
#         ...,
#         [-3.1410e-02, -2.5537e-02,  1.8493e-02,  ..., -6.4293e-03,
#           1.7492e-05, -2.8867e-02],
#         [-2.8099e-02, -4.4871e-02, -3.9674e-02,  ..., -3.1143e-02,
#           1.2788e-02, -8.3798e-03],
#         [ 1.9885e-02, -2.9048e-02,  5.0955e-02,  ...,  1.8349e-02,
#           4.5107e-02,  3.0270e-02]], device='cuda:0'), 'lstm.weight_hh_l0': tensor([[ 0.0075, -0.0477, -0.0043,  ...,  0.0040, -0.0452,  0.0158],
#         [-0.0018, -0.0207,  0.0017,  ..., -0.0441,  0.0192,  0.0381],
#         [-0.0007,  0.0322, -0.0074,  ...,  0.0005,  0.0294, -0.0305],
#         ...,
#         [ 0.0475,  0.0104, -0.0002,  ..., -0.0539, -0.0596, -0.0213],
#         [-0.0028, -0.0231, -0.0147,  ..., -0.0291,  0.0377, -0.0067],
#         [-0.0546, -0.0280,  0.0260,  ..., -0.0166,  0.0006, -0.0182]],
#        device='cuda:0'), 'lstm.bias_ih_l0': tensor([ 0.0357,  0.0389, -0.0270,  ...,  0.0656,  0.0059,  0.0597],
#        device='cuda:0'), 'lstm.bias_hh_l0': tensor([ 0.0731,  0.0971, -0.0124,  ...,  0.0121,  0.0210, -0.0028],
#        device='cuda:0'), 'lstm.weight_ih_l1': tensor([[-0.0017,  0.0351,  0.0425,  ..., -0.0061, -0.0613, -0.0142],
#         [ 0.0258,  0.0026,  0.0408,  ...,  0.0222, -0.0079, -0.0426],
#         [-0.0643, -0.0189, -0.0078,  ..., -0.0277, -0.0318, -0.0064],
#         ...,
#         [-0.0227, -0.0400,  0.0853,  ...,  0.0251,  0.0280, -0.0273],
#         [ 0.0075, -0.0775, -0.0141,  ...,  0.0013, -0.0072, -0.0438],
#         [ 0.0539, -0.0128,  0.0015,  ...,  0.0496, -0.0125,  0.0069]],
#        device='cuda:0'), 'lstm.weight_hh_l1': tensor([[ 0.0499,  0.0145, -0.0652,  ...,  0.0176,  0.0259,  0.0380],
#         [ 0.0324, -0.0271,  0.0223,  ...,  0.0032,  0.0156, -0.0240],
#         [-0.0116, -0.0491, -0.0372,  ..., -0.0008, -0.0144, -0.0158],
#         ...,
#         [-0.0145,  0.0156, -0.0034,  ..., -0.0144,  0.0133,  0.0482],
#         [-0.0263, -0.0305,  0.0470,  ...,  0.0082,  0.0386,  0.0028],
#         [ 0.0308, -0.0383, -0.0468,  ..., -0.0208,  0.0013, -0.0031]],
#        device='cuda:0'), 'lstm.bias_ih_l1': tensor([ 0.0069, -0.0020,  0.0373,  ...,  0.0051, -0.0189,  0.0300],
#        device='cuda:0'), 'lstm.bias_hh_l1': tensor([ 0.0027,  0.0084, -0.0372,  ..., -0.0224, -0.0098,  0.0411],
#        device='cuda:0'), 'fc.weight': tensor([[-0.0852, -0.0444, -0.0755,  ..., -0.1254, -0.0858,  0.0558],
#         [-0.0696, -0.0159,  0.0816,  ..., -0.1165, -0.0165,  0.0388],
#         [ 0.1252,  0.1381, -0.0785,  ...,  0.0507,  0.0494,  0.0805],
#         ...,
#         [-0.0120, -0.1163, -0.0272,  ..., -0.0909, -0.0811, -0.0511],
#         [ 0.1143, -0.0983,  0.1548,  ...,  0.0605, -0.0820, -0.1631],
#         [-0.0624, -0.0105, -0.0013,  ..., -0.0814,  0.0693,  0.0323]],
#        device='cuda:0'), 'fc.bias': tensor([-0.0396, -0.0261,  0.0210,  0.0646, -0.1402, -0.0617, -0.0408],
#        device='cuda:0')})

# %%
# Copy the 
shutil.copyfile('./lstm.ipynb', './' + results_dir + 'lstm_copy.ipynb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Copy the
# ----> 2 shutil.copyfile('./lstm.ipynb', './' + results_dir + 'lstm_copy.ipynb')
#
# NameError: name 'shutil' is not defined
