# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Remove normalization

# %%
filepath = 'David/Tests/12'
script_dir = os.path.dirname('lstm.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs

# Turns negative values to 0
X[X < 0] = 0

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 50
batch_size = 32
learning_rate = 0.0001
num_layers = 2

input_size = 512 
sequence_length = 1502  
#input_size = 4 
#sequence_length = 28

# %%
# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([32, 769024]) , Labels shape: torch.Size([32])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6, 5, 6, 6, 3, 2, 3, 4, 3,
#         0, 4, 2, 5, 3, 6, 2, 1])

# %%
# Create Model

# Model 
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        # x -> (batch_size, seq, input_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(p=0.5)  # Inside LSTM clas

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0,c0))

        # Dropout on output of LSTM
        out = self.dropout(out)

        # out: batch_size, seq_length, hidden_size
        # out (N, 6008, 128)
        # : all samples in batch, -1 last time step, : all features in hidden size

        out = out[:, -1, :] 
        
        # out (N, 128)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(512, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 5,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/28, loss = 1.9473
# epoch 1 / 50, step 2/28, loss = 1.9744
# epoch 1 / 50, step 3/28, loss = 1.9543
# epoch 1 / 50, step 4/28, loss = 1.9618
# epoch 1 / 50, step 5/28, loss = 1.9751
# epoch 1 / 50, step 6/28, loss = 1.9527
# epoch 1 / 50, step 7/28, loss = 1.9130
# epoch 1 / 50, step 8/28, loss = 1.9770
# epoch 1 / 50, step 9/28, loss = 1.9867
# epoch 1 / 50, step 10/28, loss = 1.9460
# epoch 1 / 50, step 11/28, loss = 1.9877
# epoch 1 / 50, step 12/28, loss = 1.9486
# epoch 1 / 50, step 13/28, loss = 1.9633
# epoch 1 / 50, step 14/28, loss = 1.9361
# epoch 1 / 50, step 15/28, loss = 1.9643
# epoch 1 / 50, step 16/28, loss = 1.9506
# epoch 1 / 50, step 17/28, loss = 1.9308
# epoch 1 / 50, step 18/28, loss = 1.9628
# epoch 1 / 50, step 19/28, loss = 1.9632
# epoch 1 / 50, step 20/28, loss = 1.9266
# epoch 1 / 50, step 21/28, loss = 1.9659
# epoch 1 / 50, step 22/28, loss = 1.9797
# epoch 1 / 50, step 23/28, loss = 1.9507
# epoch 1 / 50, step 24/28, loss = 1.9456
# epoch 1 / 50, step 25/28, loss = 1.9424
# epoch 1 / 50, step 26/28, loss = 1.9574
# epoch 1 / 50, step 27/28, loss = 1.9750
# epoch 1 / 50, step 28/28, loss = 2.0008
# epoch 1 / 50, step 1/7, loss = 1.9432
# epoch 1 / 50, step 2/7, loss = 1.9528
# epoch 1 / 50, step 3/7, loss = 1.9482
# epoch 1 / 50, step 4/7, loss = 1.9511
# epoch 1 / 50, step 5/7, loss = 1.9562
# epoch 1 / 50, step 6/7, loss = 1.9404
# epoch 1 / 50, step 7/7, loss = 1.9327
# epoch 2 / 50, step 1/28, loss = 1.9332
# epoch 2 / 50, step 2/28, loss = 1.9566
# epoch 2 / 50, step 3/28, loss = 1.9552
# epoch 2 / 50, step 4/28, loss = 1.9652
# epoch 2 / 50, step 5/28, loss = 1.9616
# epoch 2 / 50, step 6/28, loss = 1.9762
# epoch 2 / 50, step 7/28, loss = 1.9355
# epoch 2 / 50, step 8/28, loss = 1.9716
# epoch 2 / 50, step 9/28, loss = 1.9445
# epoch 2 / 50, step 10/28, loss = 1.9550
# epoch 2 / 50, step 11/28, loss = 1.9250
# epoch 2 / 50, step 12/28, loss = 1.9122
# epoch 2 / 50, step 13/28, loss = 1.9419
# epoch 2 / 50, step 14/28, loss = 1.8979
# epoch 2 / 50, step 15/28, loss = 1.9297
# epoch 2 / 50, step 16/28, loss = 1.9281
# epoch 2 / 50, step 17/28, loss = 1.9422
# epoch 2 / 50, step 18/28, loss = 1.9739
# epoch 2 / 50, step 19/28, loss = 1.9306
# epoch 2 / 50, step 20/28, loss = 1.9448
# epoch 2 / 50, step 21/28, loss = 1.9256
# epoch 2 / 50, step 22/28, loss = 1.9748
# epoch 2 / 50, step 23/28, loss = 1.9549
# epoch 2 / 50, step 24/28, loss = 1.9811
# epoch 2 / 50, step 25/28, loss = 1.9533
# epoch 2 / 50, step 26/28, loss = 1.9521
# epoch 2 / 50, step 27/28, loss = 1.9424
# epoch 2 / 50, step 28/28, loss = 1.9242
# epoch 2 / 50, step 1/7, loss = 1.9394
# epoch 2 / 50, step 2/7, loss = 1.9481
# epoch 2 / 50, step 3/7, loss = 1.9381
# epoch 2 / 50, step 4/7, loss = 1.9434
# epoch 2 / 50, step 5/7, loss = 1.9549
# epoch 2 / 50, step 6/7, loss = 1.9380
# epoch 2 / 50, step 7/7, loss = 1.9249
# epoch 3 / 50, step 1/28, loss = 1.9481
# epoch 3 / 50, step 2/28, loss = 1.9541
# epoch 3 / 50, step 3/28, loss = 1.9392
# epoch 3 / 50, step 4/28, loss = 1.9709
# epoch 3 / 50, step 5/28, loss = 1.9372
# epoch 3 / 50, step 6/28, loss = 1.9697
# epoch 3 / 50, step 7/28, loss = 1.9476
# epoch 3 / 50, step 8/28, loss = 1.9648
# epoch 3 / 50, step 9/28, loss = 1.9629
# epoch 3 / 50, step 10/28, loss = 1.9261
# epoch 3 / 50, step 11/28, loss = 1.9229
# epoch 3 / 50, step 12/28, loss = 1.9272
# epoch 3 / 50, step 13/28, loss = 1.9331
# epoch 3 / 50, step 14/28, loss = 1.9690
# epoch 3 / 50, step 15/28, loss = 1.9346
# epoch 3 / 50, step 16/28, loss = 1.9586
# epoch 3 / 50, step 17/28, loss = 1.9415
# epoch 3 / 50, step 18/28, loss = 1.9450
# epoch 3 / 50, step 19/28, loss = 1.9404
# epoch 3 / 50, step 20/28, loss = 1.9257
# epoch 3 / 50, step 21/28, loss = 1.9365
# epoch 3 / 50, step 22/28, loss = 1.9808
# epoch 3 / 50, step 23/28, loss = 1.9649
# epoch 3 / 50, step 24/28, loss = 1.9306
# epoch 3 / 50, step 25/28, loss = 1.9351
# epoch 3 / 50, step 26/28, loss = 1.9241
# epoch 3 / 50, step 27/28, loss = 1.9400
# epoch 3 / 50, step 28/28, loss = 1.9389
# epoch 3 / 50, step 1/7, loss = 1.9432
# epoch 3 / 50, step 2/7, loss = 1.9493
# epoch 3 / 50, step 3/7, loss = 1.9324
# epoch 3 / 50, step 4/7, loss = 1.9456
# epoch 3 / 50, step 5/7, loss = 1.9493
# epoch 3 / 50, step 6/7, loss = 1.9311
# epoch 3 / 50, step 7/7, loss = 1.9233
# epoch 4 / 50, step 1/28, loss = 1.9329
# epoch 4 / 50, step 2/28, loss = 1.9457
# epoch 4 / 50, step 3/28, loss = 1.9418
# epoch 4 / 50, step 4/28, loss = 1.9364
# epoch 4 / 50, step 5/28, loss = 1.9226
# epoch 4 / 50, step 6/28, loss = 1.9434
# epoch 4 / 50, step 7/28, loss = 1.9558
# epoch 4 / 50, step 8/28, loss = 1.9421
# epoch 4 / 50, step 9/28, loss = 1.9241
# epoch 4 / 50, step 10/28, loss = 1.9307
# epoch 4 / 50, step 11/28, loss = 1.9776
# epoch 4 / 50, step 12/28, loss = 1.9223
# epoch 4 / 50, step 13/28, loss = 1.9563
# epoch 4 / 50, step 14/28, loss = 1.9592
# epoch 4 / 50, step 15/28, loss = 1.9541
# epoch 4 / 50, step 16/28, loss = 1.9302
# epoch 4 / 50, step 17/28, loss = 1.9275
# epoch 4 / 50, step 18/28, loss = 1.9335
# epoch 4 / 50, step 19/28, loss = 1.9234
# epoch 4 / 50, step 20/28, loss = 1.8981
# epoch 4 / 50, step 21/28, loss = 1.9249
# epoch 4 / 50, step 22/28, loss = 1.9686
# epoch 4 / 50, step 23/28, loss = 1.9515
# epoch 4 / 50, step 24/28, loss = 1.9769
# epoch 4 / 50, step 25/28, loss = 1.9367
# epoch 4 / 50, step 26/28, loss = 1.9483
# epoch 4 / 50, step 27/28, loss = 1.8985
# epoch 4 / 50, step 28/28, loss = 1.8998
# epoch 4 / 50, step 1/7, loss = 1.9422
# epoch 4 / 50, step 2/7, loss = 1.9506
# epoch 4 / 50, step 3/7, loss = 1.9358
# epoch 4 / 50, step 4/7, loss = 1.9466
# epoch 4 / 50, step 5/7, loss = 1.9455
# epoch 4 / 50, step 6/7, loss = 1.9384
# epoch 4 / 50, step 7/7, loss = 1.9264
# epoch 5 / 50, step 1/28, loss = 1.9311
# epoch 5 / 50, step 2/28, loss = 1.9404
# epoch 5 / 50, step 3/28, loss = 1.9751
# epoch 5 / 50, step 4/28, loss = 1.9020
# epoch 5 / 50, step 5/28, loss = 1.9065
# epoch 5 / 50, step 6/28, loss = 1.9450
# epoch 5 / 50, step 7/28, loss = 1.9426
# epoch 5 / 50, step 8/28, loss = 1.9304
# epoch 5 / 50, step 9/28, loss = 1.9391
# epoch 5 / 50, step 10/28, loss = 1.8965
# epoch 5 / 50, step 11/28, loss = 1.9646
# epoch 5 / 50, step 12/28, loss = 1.9504
# epoch 5 / 50, step 13/28, loss = 1.9285
# epoch 5 / 50, step 14/28, loss = 1.9141
# epoch 5 / 50, step 15/28, loss = 1.9177
# epoch 5 / 50, step 16/28, loss = 1.9168
# epoch 5 / 50, step 17/28, loss = 1.9412
# epoch 5 / 50, step 18/28, loss = 1.9291
# epoch 5 / 50, step 19/28, loss = 1.9459
# epoch 5 / 50, step 20/28, loss = 1.9517
# epoch 5 / 50, step 21/28, loss = 1.9163
# epoch 5 / 50, step 22/28, loss = 1.9232
# epoch 5 / 50, step 23/28, loss = 1.9215
# epoch 5 / 50, step 24/28, loss = 1.9077
# epoch 5 / 50, step 25/28, loss = 1.9595
# epoch 5 / 50, step 26/28, loss = 1.9159
# epoch 5 / 50, step 27/28, loss = 1.9009
# epoch 5 / 50, step 28/28, loss = 1.9345
# epoch 5 / 50, step 1/7, loss = 1.9391
# epoch 5 / 50, step 2/7, loss = 1.9497
# epoch 5 / 50, step 3/7, loss = 1.9315
# epoch 5 / 50, step 4/7, loss = 1.9407
# epoch 5 / 50, step 5/7, loss = 1.9480
# epoch 5 / 50, step 6/7, loss = 1.9366
# epoch 5 / 50, step 7/7, loss = 1.9289
# epoch 6 / 50, step 1/28, loss = 1.9071
# epoch 6 / 50, step 2/28, loss = 1.9247
# epoch 6 / 50, step 3/28, loss = 1.9590
# epoch 6 / 50, step 4/28, loss = 1.9178
# epoch 6 / 50, step 5/28, loss = 1.9085
# epoch 6 / 50, step 6/28, loss = 1.9077
# epoch 6 / 50, step 7/28, loss = 1.9319
# epoch 6 / 50, step 8/28, loss = 1.9229
# epoch 6 / 50, step 9/28, loss = 1.9269
# epoch 6 / 50, step 10/28, loss = 1.9185
# epoch 6 / 50, step 11/28, loss = 1.9156
# epoch 6 / 50, step 12/28, loss = 1.9314
# epoch 6 / 50, step 13/28, loss = 1.9529
# epoch 6 / 50, step 14/28, loss = 1.8971
# epoch 6 / 50, step 15/28, loss = 1.8774
# epoch 6 / 50, step 16/28, loss = 1.9372
# epoch 6 / 50, step 17/28, loss = 1.9401
# epoch 6 / 50, step 18/28, loss = 1.9164
# epoch 6 / 50, step 19/28, loss = 1.9400
# epoch 6 / 50, step 20/28, loss = 1.9424
# epoch 6 / 50, step 21/28, loss = 1.9560
# epoch 6 / 50, step 22/28, loss = 1.9110
# epoch 6 / 50, step 23/28, loss = 1.9351
# epoch 6 / 50, step 24/28, loss = 1.9117
# epoch 6 / 50, step 25/28, loss = 1.9270
# epoch 6 / 50, step 26/28, loss = 1.9335
# epoch 6 / 50, step 27/28, loss = 1.9192
# epoch 6 / 50, step 28/28, loss = 1.9256
# epoch 6 / 50, step 1/7, loss = 1.9368
# epoch 6 / 50, step 2/7, loss = 1.9531
# epoch 6 / 50, step 3/7, loss = 1.9233
# epoch 6 / 50, step 4/7, loss = 1.9380
# epoch 6 / 50, step 5/7, loss = 1.9434
# epoch 6 / 50, step 6/7, loss = 1.9372
# epoch 6 / 50, step 7/7, loss = 1.9232
# epoch 7 / 50, step 1/28, loss = 1.9296
# epoch 7 / 50, step 2/28, loss = 1.8975
# epoch 7 / 50, step 3/28, loss = 1.9319
# epoch 7 / 50, step 4/28, loss = 1.9488
# epoch 7 / 50, step 5/28, loss = 1.9250
# epoch 7 / 50, step 6/28, loss = 1.9446
# epoch 7 / 50, step 7/28, loss = 1.9405
# epoch 7 / 50, step 8/28, loss = 1.9010
# epoch 7 / 50, step 9/28, loss = 1.9677
# epoch 7 / 50, step 10/28, loss = 1.9071
# epoch 7 / 50, step 11/28, loss = 1.9232
# epoch 7 / 50, step 12/28, loss = 1.9278
# epoch 7 / 50, step 13/28, loss = 1.9227
# epoch 7 / 50, step 14/28, loss = 1.9366
# epoch 7 / 50, step 15/28, loss = 1.9392
# epoch 7 / 50, step 16/28, loss = 1.9796
# epoch 7 / 50, step 17/28, loss = 1.9150
# epoch 7 / 50, step 18/28, loss = 1.8894
# epoch 7 / 50, step 19/28, loss = 1.8686
# epoch 7 / 50, step 20/28, loss = 1.8929
# epoch 7 / 50, step 21/28, loss = 1.9417
# epoch 7 / 50, step 22/28, loss = 1.9371
# epoch 7 / 50, step 23/28, loss = 1.9168
# epoch 7 / 50, step 24/28, loss = 1.9165
# epoch 7 / 50, step 25/28, loss = 1.9149
# epoch 7 / 50, step 26/28, loss = 1.9092
# epoch 7 / 50, step 27/28, loss = 1.9424
# epoch 7 / 50, step 28/28, loss = 1.8965
# epoch 7 / 50, step 1/7, loss = 1.9406
# epoch 7 / 50, step 2/7, loss = 1.9595
# epoch 7 / 50, step 3/7, loss = 1.9204
# epoch 7 / 50, step 4/7, loss = 1.9400
# epoch 7 / 50, step 5/7, loss = 1.9416
# epoch 7 / 50, step 6/7, loss = 1.9404
# epoch 7 / 50, step 7/7, loss = 1.9290
# epoch 8 / 50, step 1/28, loss = 1.9156
# epoch 8 / 50, step 2/28, loss = 1.8938
# epoch 8 / 50, step 3/28, loss = 1.9020
# epoch 8 / 50, step 4/28, loss = 1.9322
# epoch 8 / 50, step 5/28, loss = 1.9149
# epoch 8 / 50, step 6/28, loss = 1.9351
# epoch 8 / 50, step 7/28, loss = 1.9299
# epoch 8 / 50, step 8/28, loss = 1.9224
# epoch 8 / 50, step 9/28, loss = 1.9332
# epoch 8 / 50, step 10/28, loss = 1.9073
# epoch 8 / 50, step 11/28, loss = 1.9642
# epoch 8 / 50, step 12/28, loss = 1.9185
# epoch 8 / 50, step 13/28, loss = 1.9332
# epoch 8 / 50, step 14/28, loss = 1.9025
# epoch 8 / 50, step 15/28, loss = 1.9753
# epoch 8 / 50, step 16/28, loss = 1.8798
# epoch 8 / 50, step 17/28, loss = 1.9137
# epoch 8 / 50, step 18/28, loss = 1.9431
# epoch 8 / 50, step 19/28, loss = 1.9123
# epoch 8 / 50, step 20/28, loss = 1.8977
# epoch 8 / 50, step 21/28, loss = 1.9305
# epoch 8 / 50, step 22/28, loss = 1.9162
# epoch 8 / 50, step 23/28, loss = 1.9274
# epoch 8 / 50, step 24/28, loss = 1.9002
# epoch 8 / 50, step 25/28, loss = 1.9605
# epoch 8 / 50, step 26/28, loss = 1.8772
# epoch 8 / 50, step 27/28, loss = 1.9255
# epoch 8 / 50, step 28/28, loss = 1.9382
# epoch 8 / 50, step 1/7, loss = 1.9451
# epoch 8 / 50, step 2/7, loss = 1.9684
# epoch 8 / 50, step 3/7, loss = 1.9143
# epoch 8 / 50, step 4/7, loss = 1.9383
# epoch 8 / 50, step 5/7, loss = 1.9425
# epoch 8 / 50, step 6/7, loss = 1.9329
# epoch 8 / 50, step 7/7, loss = 1.9287
# epoch 9 / 50, step 1/28, loss = 1.9150
# epoch 9 / 50, step 2/28, loss = 1.9160
# epoch 9 / 50, step 3/28, loss = 1.8692
# epoch 9 / 50, step 4/28, loss = 1.8755
# epoch 9 / 50, step 5/28, loss = 1.8759
# epoch 9 / 50, step 6/28, loss = 1.9262
# epoch 9 / 50, step 7/28, loss = 1.9407
# epoch 9 / 50, step 8/28, loss = 1.9163
# epoch 9 / 50, step 9/28, loss = 1.9291
# epoch 9 / 50, step 10/28, loss = 1.9144
# epoch 9 / 50, step 11/28, loss = 1.9336
# epoch 9 / 50, step 12/28, loss = 1.9136
# epoch 9 / 50, step 13/28, loss = 1.8389
# epoch 9 / 50, step 14/28, loss = 1.8996
# epoch 9 / 50, step 15/28, loss = 1.9089
# epoch 9 / 50, step 16/28, loss = 1.9413
# epoch 9 / 50, step 17/28, loss = 1.8982
# epoch 9 / 50, step 18/28, loss = 1.9071
# epoch 9 / 50, step 19/28, loss = 1.9377
# epoch 9 / 50, step 20/28, loss = 1.9253
# epoch 9 / 50, step 21/28, loss = 1.9079
# epoch 9 / 50, step 22/28, loss = 1.9036
# epoch 9 / 50, step 23/28, loss = 1.9070
# epoch 9 / 50, step 24/28, loss = 1.9468
# epoch 9 / 50, step 25/28, loss = 1.9282
# epoch 9 / 50, step 26/28, loss = 1.9049
# epoch 9 / 50, step 27/28, loss = 1.8793
# epoch 9 / 50, step 28/28, loss = 1.9890
# epoch 9 / 50, step 1/7, loss = 1.9477
# epoch 9 / 50, step 2/7, loss = 1.9698
# epoch 9 / 50, step 3/7, loss = 1.9111
# epoch 9 / 50, step 4/7, loss = 1.9367
# epoch 9 / 50, step 5/7, loss = 1.9367
# epoch 9 / 50, step 6/7, loss = 1.9339
# epoch 9 / 50, step 7/7, loss = 1.9316
# epoch 10 / 50, step 1/28, loss = 1.9273
# epoch 10 / 50, step 2/28, loss = 1.9367
# epoch 10 / 50, step 3/28, loss = 1.9310
# epoch 10 / 50, step 4/28, loss = 1.9093
# epoch 10 / 50, step 5/28, loss = 1.9310
# epoch 10 / 50, step 6/28, loss = 1.9269
# epoch 10 / 50, step 7/28, loss = 1.8628
# epoch 10 / 50, step 8/28, loss = 1.8910
# epoch 10 / 50, step 9/28, loss = 1.9143
# epoch 10 / 50, step 10/28, loss = 1.9557
# epoch 10 / 50, step 11/28, loss = 1.9177
# epoch 10 / 50, step 12/28, loss = 1.8799
# epoch 10 / 50, step 13/28, loss = 1.9236
# epoch 10 / 50, step 14/28, loss = 1.9129
# epoch 10 / 50, step 15/28, loss = 1.9259
# epoch 10 / 50, step 16/28, loss = 1.9431
# epoch 10 / 50, step 17/28, loss = 1.9056
# epoch 10 / 50, step 18/28, loss = 1.8984
# epoch 10 / 50, step 19/28, loss = 1.8990
# epoch 10 / 50, step 20/28, loss = 1.8973
# epoch 10 / 50, step 21/28, loss = 1.8930
# epoch 10 / 50, step 22/28, loss = 1.9243
# epoch 10 / 50, step 23/28, loss = 1.9292
# epoch 10 / 50, step 24/28, loss = 1.9318
# epoch 10 / 50, step 25/28, loss = 1.9059
# epoch 10 / 50, step 26/28, loss = 1.8985
# epoch 10 / 50, step 27/28, loss = 1.9240
# epoch 10 / 50, step 28/28, loss = 1.8802
# epoch 10 / 50, step 1/7, loss = 1.9512
# epoch 10 / 50, step 2/7, loss = 1.9697
# epoch 10 / 50, step 3/7, loss = 1.9089
# epoch 10 / 50, step 4/7, loss = 1.9327
# epoch 10 / 50, step 5/7, loss = 1.9366
# epoch 10 / 50, step 6/7, loss = 1.9415
# epoch 10 / 50, step 7/7, loss = 1.9372
# epoch 11 / 50, step 1/28, loss = 1.9125
# epoch 11 / 50, step 2/28, loss = 1.8590
# epoch 11 / 50, step 3/28, loss = 1.8858
# epoch 11 / 50, step 4/28, loss = 1.8835
# epoch 11 / 50, step 5/28, loss = 1.8928
# epoch 11 / 50, step 6/28, loss = 1.8951
# epoch 11 / 50, step 7/28, loss = 1.8852
# epoch 11 / 50, step 8/28, loss = 1.9127
# epoch 11 / 50, step 9/28, loss = 1.9248
# epoch 11 / 50, step 10/28, loss = 1.9389
# epoch 11 / 50, step 11/28, loss = 1.8661
# epoch 11 / 50, step 12/28, loss = 1.8905
# epoch 11 / 50, step 13/28, loss = 1.8769
# epoch 11 / 50, step 14/28, loss = 1.9082
# epoch 11 / 50, step 15/28, loss = 1.8943
# epoch 11 / 50, step 16/28, loss = 1.8731
# epoch 11 / 50, step 17/28, loss = 1.9071
# epoch 11 / 50, step 18/28, loss = 1.8874
# epoch 11 / 50, step 19/28, loss = 1.9079
# epoch 11 / 50, step 20/28, loss = 1.9356
# epoch 11 / 50, step 21/28, loss = 1.9006
# epoch 11 / 50, step 22/28, loss = 1.9007
# epoch 11 / 50, step 23/28, loss = 1.9081
# epoch 11 / 50, step 24/28, loss = 1.9268
# epoch 11 / 50, step 25/28, loss = 1.9449
# epoch 11 / 50, step 26/28, loss = 1.9457
# epoch 11 / 50, step 27/28, loss = 1.9355
# epoch 11 / 50, step 28/28, loss = 1.9703
# epoch 11 / 50, step 1/7, loss = 1.9484
# epoch 11 / 50, step 2/7, loss = 1.9674
# epoch 11 / 50, step 3/7, loss = 1.9029
# epoch 11 / 50, step 4/7, loss = 1.9344
# epoch 11 / 50, step 5/7, loss = 1.9409
# epoch 11 / 50, step 6/7, loss = 1.9383
# epoch 11 / 50, step 7/7, loss = 1.9383
# epoch 12 / 50, step 1/28, loss = 1.8874
# epoch 12 / 50, step 2/28, loss = 1.9171
# epoch 12 / 50, step 3/28, loss = 1.9180
# epoch 12 / 50, step 4/28, loss = 1.8994
# epoch 12 / 50, step 5/28, loss = 1.8828
# epoch 12 / 50, step 6/28, loss = 1.9098
# epoch 12 / 50, step 7/28, loss = 1.9518
# epoch 12 / 50, step 8/28, loss = 1.9275
# epoch 12 / 50, step 9/28, loss = 1.9412
# epoch 12 / 50, step 10/28, loss = 1.9099
# epoch 12 / 50, step 11/28, loss = 1.9130
# epoch 12 / 50, step 12/28, loss = 1.8965
# epoch 12 / 50, step 13/28, loss = 1.8932
# epoch 12 / 50, step 14/28, loss = 1.9074
# epoch 12 / 50, step 15/28, loss = 1.9207
# epoch 12 / 50, step 16/28, loss = 1.9168
# epoch 12 / 50, step 17/28, loss = 1.9001
# epoch 12 / 50, step 18/28, loss = 1.8837
# epoch 12 / 50, step 19/28, loss = 1.9157
# epoch 12 / 50, step 20/28, loss = 1.9122
# epoch 12 / 50, step 21/28, loss = 1.8813
# epoch 12 / 50, step 22/28, loss = 1.8655
# epoch 12 / 50, step 23/28, loss = 1.9140
# epoch 12 / 50, step 24/28, loss = 1.9002
# epoch 12 / 50, step 25/28, loss = 1.8756
# epoch 12 / 50, step 26/28, loss = 1.9465
# epoch 12 / 50, step 27/28, loss = 1.8839
# epoch 12 / 50, step 28/28, loss = 1.9208
# epoch 12 / 50, step 1/7, loss = 1.9452
# epoch 12 / 50, step 2/7, loss = 1.9701
# epoch 12 / 50, step 3/7, loss = 1.9028
# epoch 12 / 50, step 4/7, loss = 1.9342
# epoch 12 / 50, step 5/7, loss = 1.9417
# epoch 12 / 50, step 6/7, loss = 1.9324
# epoch 12 / 50, step 7/7, loss = 1.9337
# epoch 13 / 50, step 1/28, loss = 1.8656
# epoch 13 / 50, step 2/28, loss = 1.8740
# epoch 13 / 50, step 3/28, loss = 1.8824
# epoch 13 / 50, step 4/28, loss = 1.9680
# epoch 13 / 50, step 5/28, loss = 1.8734
# epoch 13 / 50, step 6/28, loss = 1.9168
# epoch 13 / 50, step 7/28, loss = 1.8877
# epoch 13 / 50, step 8/28, loss = 1.8784
# epoch 13 / 50, step 9/28, loss = 1.9574
# epoch 13 / 50, step 10/28, loss = 1.9173
# epoch 13 / 50, step 11/28, loss = 1.9073
# epoch 13 / 50, step 12/28, loss = 1.9104
# epoch 13 / 50, step 13/28, loss = 1.8972
# epoch 13 / 50, step 14/28, loss = 1.9236
# epoch 13 / 50, step 15/28, loss = 1.9251
# epoch 13 / 50, step 16/28, loss = 1.8900
# epoch 13 / 50, step 17/28, loss = 1.9589
# epoch 13 / 50, step 18/28, loss = 1.8853
# epoch 13 / 50, step 19/28, loss = 1.8034
# epoch 13 / 50, step 20/28, loss = 1.8899
# epoch 13 / 50, step 21/28, loss = 1.9062
# epoch 13 / 50, step 22/28, loss = 1.9154
# epoch 13 / 50, step 23/28, loss = 1.9345
# epoch 13 / 50, step 24/28, loss = 1.8916
# epoch 13 / 50, step 25/28, loss = 1.9348
# epoch 13 / 50, step 26/28, loss = 1.8426
# epoch 13 / 50, step 27/28, loss = 1.8716
# epoch 13 / 50, step 28/28, loss = 1.8759
# epoch 13 / 50, step 1/7, loss = 1.9515
# epoch 13 / 50, step 2/7, loss = 1.9713
# epoch 13 / 50, step 3/7, loss = 1.9009
# epoch 13 / 50, step 4/7, loss = 1.9377
# epoch 13 / 50, step 5/7, loss = 1.9469
# epoch 13 / 50, step 6/7, loss = 1.9261
# epoch 13 / 50, step 7/7, loss = 1.9325
# epoch 14 / 50, step 1/28, loss = 1.9489
# epoch 14 / 50, step 2/28, loss = 1.8816
# epoch 14 / 50, step 3/28, loss = 1.9076
# epoch 14 / 50, step 4/28, loss = 1.9251
# epoch 14 / 50, step 5/28, loss = 1.8949
# epoch 14 / 50, step 6/28, loss = 1.8561
# epoch 14 / 50, step 7/28, loss = 1.8546
# epoch 14 / 50, step 8/28, loss = 1.9376
# epoch 14 / 50, step 9/28, loss = 1.8357
# epoch 14 / 50, step 10/28, loss = 1.9312
# epoch 14 / 50, step 11/28, loss = 1.8780
# epoch 14 / 50, step 12/28, loss = 1.9001
# epoch 14 / 50, step 13/28, loss = 1.9460
# epoch 14 / 50, step 14/28, loss = 1.9166
# epoch 14 / 50, step 15/28, loss = 1.8916
# epoch 14 / 50, step 16/28, loss = 1.8467
# epoch 14 / 50, step 17/28, loss = 1.9015
# epoch 14 / 50, step 18/28, loss = 1.9024
# epoch 14 / 50, step 19/28, loss = 1.9602
# epoch 14 / 50, step 20/28, loss = 1.9429
# epoch 14 / 50, step 21/28, loss = 1.9243
# epoch 14 / 50, step 22/28, loss = 1.8770
# epoch 14 / 50, step 23/28, loss = 1.9315
# epoch 14 / 50, step 24/28, loss = 1.9226
# epoch 14 / 50, step 25/28, loss = 1.8460
# epoch 14 / 50, step 26/28, loss = 1.8921
# epoch 14 / 50, step 27/28, loss = 1.9090
# epoch 14 / 50, step 28/28, loss = 1.9836
# epoch 14 / 50, step 1/7, loss = 1.9409
# epoch 14 / 50, step 2/7, loss = 1.9842
# epoch 14 / 50, step 3/7, loss = 1.8864
# epoch 14 / 50, step 4/7, loss = 1.9373
# epoch 14 / 50, step 5/7, loss = 1.9514
# epoch 14 / 50, step 6/7, loss = 1.9221
# epoch 14 / 50, step 7/7, loss = 1.9310
# epoch 15 / 50, step 1/28, loss = 1.8993
# epoch 15 / 50, step 2/28, loss = 1.9027
# epoch 15 / 50, step 3/28, loss = 1.8725
# epoch 15 / 50, step 4/28, loss = 1.9308
# epoch 15 / 50, step 5/28, loss = 1.9020
# epoch 15 / 50, step 6/28, loss = 1.8747
# epoch 15 / 50, step 7/28, loss = 1.8950
# epoch 15 / 50, step 8/28, loss = 1.8728
# epoch 15 / 50, step 9/28, loss = 1.8865
# epoch 15 / 50, step 10/28, loss = 1.9366
# epoch 15 / 50, step 11/28, loss = 1.9236
# epoch 15 / 50, step 12/28, loss = 1.9224
# epoch 15 / 50, step 13/28, loss = 1.8976
# epoch 15 / 50, step 14/28, loss = 1.8613
# epoch 15 / 50, step 15/28, loss = 1.9248
# epoch 15 / 50, step 16/28, loss = 1.9107
# epoch 15 / 50, step 17/28, loss = 1.9513
# epoch 15 / 50, step 18/28, loss = 1.8666
# epoch 15 / 50, step 19/28, loss = 1.8820
# epoch 15 / 50, step 20/28, loss = 1.8707
# epoch 15 / 50, step 21/28, loss = 1.9259
# epoch 15 / 50, step 22/28, loss = 1.8887
# epoch 15 / 50, step 23/28, loss = 1.9210
# epoch 15 / 50, step 24/28, loss = 1.8838
# epoch 15 / 50, step 25/28, loss = 1.8670
# epoch 15 / 50, step 26/28, loss = 1.8302
# epoch 15 / 50, step 27/28, loss = 1.9029
# epoch 15 / 50, step 28/28, loss = 1.9656
# epoch 15 / 50, step 1/7, loss = 1.9393
# epoch 15 / 50, step 2/7, loss = 1.9853
# epoch 15 / 50, step 3/7, loss = 1.8919
# epoch 15 / 50, step 4/7, loss = 1.9379
# epoch 15 / 50, step 5/7, loss = 1.9512
# epoch 15 / 50, step 6/7, loss = 1.9240
# epoch 15 / 50, step 7/7, loss = 1.9321
# epoch 16 / 50, step 1/28, loss = 1.9012
# epoch 16 / 50, step 2/28, loss = 1.8829
# epoch 16 / 50, step 3/28, loss = 1.9502
# epoch 16 / 50, step 4/28, loss = 1.9602
# epoch 16 / 50, step 5/28, loss = 1.9255
# epoch 16 / 50, step 6/28, loss = 1.8328
# epoch 16 / 50, step 7/28, loss = 1.8968
# epoch 16 / 50, step 8/28, loss = 1.8764
# epoch 16 / 50, step 9/28, loss = 1.9103
# epoch 16 / 50, step 10/28, loss = 1.8705
# epoch 16 / 50, step 11/28, loss = 1.8757
# epoch 16 / 50, step 12/28, loss = 1.8957
# epoch 16 / 50, step 13/28, loss = 1.8064
# epoch 16 / 50, step 14/28, loss = 1.8785
# epoch 16 / 50, step 15/28, loss = 1.8570
# epoch 16 / 50, step 16/28, loss = 1.8930
# epoch 16 / 50, step 17/28, loss = 1.9483
# epoch 16 / 50, step 18/28, loss = 1.8827
# epoch 16 / 50, step 19/28, loss = 1.9261
# epoch 16 / 50, step 20/28, loss = 1.8511
# epoch 16 / 50, step 21/28, loss = 1.9263
# epoch 16 / 50, step 22/28, loss = 1.9104
# epoch 16 / 50, step 23/28, loss = 1.9107
# epoch 16 / 50, step 24/28, loss = 1.8967
# epoch 16 / 50, step 25/28, loss = 1.8861
# epoch 16 / 50, step 26/28, loss = 1.9002
# epoch 16 / 50, step 27/28, loss = 1.8653
# epoch 16 / 50, step 28/28, loss = 1.9939
# epoch 16 / 50, step 1/7, loss = 1.9222
# epoch 16 / 50, step 2/7, loss = 1.9981
# epoch 16 / 50, step 3/7, loss = 1.8934
# epoch 16 / 50, step 4/7, loss = 1.9450
# epoch 16 / 50, step 5/7, loss = 1.9604
# epoch 16 / 50, step 6/7, loss = 1.9264
# epoch 16 / 50, step 7/7, loss = 1.9309
# epoch 17 / 50, step 1/28, loss = 1.8775
# epoch 17 / 50, step 2/28, loss = 1.8581
# epoch 17 / 50, step 3/28, loss = 1.9206
# epoch 17 / 50, step 4/28, loss = 1.9508
# epoch 17 / 50, step 5/28, loss = 1.8922
# epoch 17 / 50, step 6/28, loss = 1.8732
# epoch 17 / 50, step 7/28, loss = 1.8976
# epoch 17 / 50, step 8/28, loss = 1.9013
# epoch 17 / 50, step 9/28, loss = 1.8932
# epoch 17 / 50, step 10/28, loss = 1.9194
# epoch 17 / 50, step 11/28, loss = 1.8955
# epoch 17 / 50, step 12/28, loss = 1.8253
# epoch 17 / 50, step 13/28, loss = 1.8337
# epoch 17 / 50, step 14/28, loss = 1.8205
# epoch 17 / 50, step 15/28, loss = 1.8732
# epoch 17 / 50, step 16/28, loss = 1.9185
# epoch 17 / 50, step 17/28, loss = 1.8556
# epoch 17 / 50, step 18/28, loss = 1.9072
# epoch 17 / 50, step 19/28, loss = 1.8834
# epoch 17 / 50, step 20/28, loss = 1.8530
# epoch 17 / 50, step 21/28, loss = 1.9041
# epoch 17 / 50, step 22/28, loss = 1.8824
# epoch 17 / 50, step 23/28, loss = 1.8567
# epoch 17 / 50, step 24/28, loss = 1.8805
# epoch 17 / 50, step 25/28, loss = 1.9136
# epoch 17 / 50, step 26/28, loss = 1.9465
# epoch 17 / 50, step 27/28, loss = 1.8704
# epoch 17 / 50, step 28/28, loss = 1.8530
# epoch 17 / 50, step 1/7, loss = 1.9395
# epoch 17 / 50, step 2/7, loss = 1.9931
# epoch 17 / 50, step 3/7, loss = 1.8971
# epoch 17 / 50, step 4/7, loss = 1.9331
# epoch 17 / 50, step 5/7, loss = 1.9488
# epoch 17 / 50, step 6/7, loss = 1.9252
# epoch 17 / 50, step 7/7, loss = 1.9410
# epoch 18 / 50, step 1/28, loss = 1.8830
# epoch 18 / 50, step 2/28, loss = 1.8470
# epoch 18 / 50, step 3/28, loss = 1.8866
# epoch 18 / 50, step 4/28, loss = 1.8828
# epoch 18 / 50, step 5/28, loss = 1.8647
# epoch 18 / 50, step 6/28, loss = 1.8533
# epoch 18 / 50, step 7/28, loss = 1.9216
# epoch 18 / 50, step 8/28, loss = 1.8477
# epoch 18 / 50, step 9/28, loss = 1.9310
# epoch 18 / 50, step 10/28, loss = 1.8483
# epoch 18 / 50, step 11/28, loss = 1.8365
# epoch 18 / 50, step 12/28, loss = 1.8791
# epoch 18 / 50, step 13/28, loss = 1.8551
# epoch 18 / 50, step 14/28, loss = 1.9098
# epoch 18 / 50, step 15/28, loss = 1.9011
# epoch 18 / 50, step 16/28, loss = 1.8507
# epoch 18 / 50, step 17/28, loss = 1.8888
# epoch 18 / 50, step 18/28, loss = 1.8494
# epoch 18 / 50, step 19/28, loss = 1.9005
# epoch 18 / 50, step 20/28, loss = 1.9567
# epoch 18 / 50, step 21/28, loss = 1.8532
# epoch 18 / 50, step 22/28, loss = 1.8871
# epoch 18 / 50, step 23/28, loss = 1.8986
# epoch 18 / 50, step 24/28, loss = 1.9274
# epoch 18 / 50, step 25/28, loss = 1.9544
# epoch 18 / 50, step 26/28, loss = 1.8183
# epoch 18 / 50, step 27/28, loss = 1.9648
# epoch 18 / 50, step 28/28, loss = 1.8039
# epoch 18 / 50, step 1/7, loss = 1.9369
# epoch 18 / 50, step 2/7, loss = 1.9993
# epoch 18 / 50, step 3/7, loss = 1.8936
# epoch 18 / 50, step 4/7, loss = 1.9362
# epoch 18 / 50, step 5/7, loss = 1.9496
# epoch 18 / 50, step 6/7, loss = 1.9315
# epoch 18 / 50, step 7/7, loss = 1.9224
# epoch 19 / 50, step 1/28, loss = 1.8529
# epoch 19 / 50, step 2/28, loss = 1.8625
# epoch 19 / 50, step 3/28, loss = 1.8787
# epoch 19 / 50, step 4/28, loss = 1.8443
# epoch 19 / 50, step 5/28, loss = 1.8512
# epoch 19 / 50, step 6/28, loss = 1.8588
# epoch 19 / 50, step 7/28, loss = 1.9007
# epoch 19 / 50, step 8/28, loss = 1.9054
# epoch 19 / 50, step 9/28, loss = 1.9146
# epoch 19 / 50, step 10/28, loss = 1.8890
# epoch 19 / 50, step 11/28, loss = 1.9408
# epoch 19 / 50, step 12/28, loss = 1.9112
# epoch 19 / 50, step 13/28, loss = 1.8666
# epoch 19 / 50, step 14/28, loss = 1.8669
# epoch 19 / 50, step 15/28, loss = 1.9817
# epoch 19 / 50, step 16/28, loss = 1.8872
# epoch 19 / 50, step 17/28, loss = 1.8993
# epoch 19 / 50, step 18/28, loss = 1.8725
# epoch 19 / 50, step 19/28, loss = 1.9086
# epoch 19 / 50, step 20/28, loss = 1.8920
# epoch 19 / 50, step 21/28, loss = 1.9122
# epoch 19 / 50, step 22/28, loss = 1.8460
# epoch 19 / 50, step 23/28, loss = 1.8715
# epoch 19 / 50, step 24/28, loss = 1.8562
# epoch 19 / 50, step 25/28, loss = 1.8811
# epoch 19 / 50, step 26/28, loss = 1.9034
# epoch 19 / 50, step 27/28, loss = 1.8572
# epoch 19 / 50, step 28/28, loss = 1.8047
# epoch 19 / 50, step 1/7, loss = 1.9426
# epoch 19 / 50, step 2/7, loss = 1.9916
# epoch 19 / 50, step 3/7, loss = 1.8801
# epoch 19 / 50, step 4/7, loss = 1.9357
# epoch 19 / 50, step 5/7, loss = 1.9375
# epoch 19 / 50, step 6/7, loss = 1.9260
# epoch 19 / 50, step 7/7, loss = 1.9273
# epoch 20 / 50, step 1/28, loss = 1.8325
# epoch 20 / 50, step 2/28, loss = 1.8807
# epoch 20 / 50, step 3/28, loss = 1.8558
# epoch 20 / 50, step 4/28, loss = 1.9073
# epoch 20 / 50, step 5/28, loss = 1.9120
# epoch 20 / 50, step 6/28, loss = 1.9064
# epoch 20 / 50, step 7/28, loss = 1.8901
# epoch 20 / 50, step 8/28, loss = 1.8929
# epoch 20 / 50, step 9/28, loss = 1.8520
# epoch 20 / 50, step 10/28, loss = 1.8822
# epoch 20 / 50, step 11/28, loss = 1.8832
# epoch 20 / 50, step 12/28, loss = 1.9363
# epoch 20 / 50, step 13/28, loss = 1.8704
# epoch 20 / 50, step 14/28, loss = 1.8623
# epoch 20 / 50, step 15/28, loss = 1.8567
# epoch 20 / 50, step 16/28, loss = 1.8404
# epoch 20 / 50, step 17/28, loss = 1.8900
# epoch 20 / 50, step 18/28, loss = 1.8823
# epoch 20 / 50, step 19/28, loss = 1.9062
# epoch 20 / 50, step 20/28, loss = 1.8114
# epoch 20 / 50, step 21/28, loss = 1.8385
# epoch 20 / 50, step 22/28, loss = 1.8540
# epoch 20 / 50, step 23/28, loss = 1.9407
# epoch 20 / 50, step 24/28, loss = 1.9325
# epoch 20 / 50, step 25/28, loss = 1.8853
# epoch 20 / 50, step 26/28, loss = 1.8785
# epoch 20 / 50, step 27/28, loss = 1.9080
# epoch 20 / 50, step 28/28, loss = 1.9407
# epoch 20 / 50, step 1/7, loss = 1.9353
# epoch 20 / 50, step 2/7, loss = 1.9745
# epoch 20 / 50, step 3/7, loss = 1.8890
# epoch 20 / 50, step 4/7, loss = 1.9493
# epoch 20 / 50, step 5/7, loss = 1.9496
# epoch 20 / 50, step 6/7, loss = 1.9190
# epoch 20 / 50, step 7/7, loss = 1.9244
# epoch 21 / 50, step 1/28, loss = 1.9384
# epoch 21 / 50, step 2/28, loss = 1.9064
# epoch 21 / 50, step 3/28, loss = 1.8606
# epoch 21 / 50, step 4/28, loss = 1.9337
# epoch 21 / 50, step 5/28, loss = 1.9120
# epoch 21 / 50, step 6/28, loss = 1.8888
# epoch 21 / 50, step 7/28, loss = 1.8889
# epoch 21 / 50, step 8/28, loss = 1.8476
# epoch 21 / 50, step 9/28, loss = 1.9008
# epoch 21 / 50, step 10/28, loss = 1.8601
# epoch 21 / 50, step 11/28, loss = 1.8853
# epoch 21 / 50, step 12/28, loss = 1.8699
# epoch 21 / 50, step 13/28, loss = 1.8883
# epoch 21 / 50, step 14/28, loss = 1.8521
# epoch 21 / 50, step 15/28, loss = 1.8833
# epoch 21 / 50, step 16/28, loss = 1.8480
# epoch 21 / 50, step 17/28, loss = 1.8358
# epoch 21 / 50, step 18/28, loss = 1.8757
# epoch 21 / 50, step 19/28, loss = 1.7909
# epoch 21 / 50, step 20/28, loss = 1.8455
# epoch 21 / 50, step 21/28, loss = 1.8920
# epoch 21 / 50, step 22/28, loss = 1.8928
# epoch 21 / 50, step 23/28, loss = 1.8421
# epoch 21 / 50, step 24/28, loss = 1.8102
# epoch 21 / 50, step 25/28, loss = 1.8615
# epoch 21 / 50, step 26/28, loss = 1.8243
# epoch 21 / 50, step 27/28, loss = 1.9248
# epoch 21 / 50, step 28/28, loss = 1.9731
# epoch 21 / 50, step 1/7, loss = 1.9367
# epoch 21 / 50, step 2/7, loss = 1.9973
# epoch 21 / 50, step 3/7, loss = 1.8795
# epoch 21 / 50, step 4/7, loss = 1.9482
# epoch 21 / 50, step 5/7, loss = 1.9395
# epoch 21 / 50, step 6/7, loss = 1.9127
# epoch 21 / 50, step 7/7, loss = 1.9235
# epoch 22 / 50, step 1/28, loss = 1.8750
# epoch 22 / 50, step 2/28, loss = 1.8749
# epoch 22 / 50, step 3/28, loss = 1.8871
# epoch 22 / 50, step 4/28, loss = 1.8227
# epoch 22 / 50, step 5/28, loss = 1.8567
# epoch 22 / 50, step 6/28, loss = 1.8545
# epoch 22 / 50, step 7/28, loss = 1.8758
# epoch 22 / 50, step 8/28, loss = 1.8057
# epoch 22 / 50, step 9/28, loss = 1.8275
# epoch 22 / 50, step 10/28, loss = 1.8005
# epoch 22 / 50, step 11/28, loss = 1.9245
# epoch 22 / 50, step 12/28, loss = 1.8707
# epoch 22 / 50, step 13/28, loss = 1.8630
# epoch 22 / 50, step 14/28, loss = 1.8942
# epoch 22 / 50, step 15/28, loss = 1.8436
# epoch 22 / 50, step 16/28, loss = 1.8795
# epoch 22 / 50, step 17/28, loss = 1.9669
# epoch 22 / 50, step 18/28, loss = 1.9445
# epoch 22 / 50, step 19/28, loss = 1.8822
# epoch 22 / 50, step 20/28, loss = 1.8698
# epoch 22 / 50, step 21/28, loss = 1.8545
# epoch 22 / 50, step 22/28, loss = 1.9241
# epoch 22 / 50, step 23/28, loss = 1.8436
# epoch 22 / 50, step 24/28, loss = 1.8205
# epoch 22 / 50, step 25/28, loss = 1.8830
# epoch 22 / 50, step 26/28, loss = 1.8782
# epoch 22 / 50, step 27/28, loss = 1.8739
# epoch 22 / 50, step 28/28, loss = 1.8579
# epoch 22 / 50, step 1/7, loss = 1.9526
# epoch 22 / 50, step 2/7, loss = 2.0011
# epoch 22 / 50, step 3/7, loss = 1.8934
# epoch 22 / 50, step 4/7, loss = 1.9395
# epoch 22 / 50, step 5/7, loss = 1.9364
# epoch 22 / 50, step 6/7, loss = 1.9353
# epoch 22 / 50, step 7/7, loss = 1.9213
# epoch 23 / 50, step 1/28, loss = 1.8306
# epoch 23 / 50, step 2/28, loss = 1.8592
# epoch 23 / 50, step 3/28, loss = 1.8088
# epoch 23 / 50, step 4/28, loss = 1.8866
# epoch 23 / 50, step 5/28, loss = 1.8884
# epoch 23 / 50, step 6/28, loss = 1.8680
# epoch 23 / 50, step 7/28, loss = 1.8590
# epoch 23 / 50, step 8/28, loss = 1.8920
# epoch 23 / 50, step 9/28, loss = 1.7550
# epoch 23 / 50, step 10/28, loss = 1.7763
# epoch 23 / 50, step 11/28, loss = 1.9124
# epoch 23 / 50, step 12/28, loss = 1.8889
# epoch 23 / 50, step 13/28, loss = 1.8895
# epoch 23 / 50, step 14/28, loss = 1.8746
# epoch 23 / 50, step 15/28, loss = 1.9278
# epoch 23 / 50, step 16/28, loss = 1.8556
# epoch 23 / 50, step 17/28, loss = 1.8516
# epoch 23 / 50, step 18/28, loss = 1.9792
# epoch 23 / 50, step 19/28, loss = 1.8498
# epoch 23 / 50, step 20/28, loss = 1.8564
# epoch 23 / 50, step 21/28, loss = 1.8422
# epoch 23 / 50, step 22/28, loss = 1.7932
# epoch 23 / 50, step 23/28, loss = 1.8435
# epoch 23 / 50, step 24/28, loss = 1.8411
# epoch 23 / 50, step 25/28, loss = 1.8574
# epoch 23 / 50, step 26/28, loss = 1.8223
# epoch 23 / 50, step 27/28, loss = 1.8345
# epoch 23 / 50, step 28/28, loss = 1.9102
# epoch 23 / 50, step 1/7, loss = 1.9338
# epoch 23 / 50, step 2/7, loss = 2.0067
# epoch 23 / 50, step 3/7, loss = 1.8735
# epoch 23 / 50, step 4/7, loss = 1.9287
# epoch 23 / 50, step 5/7, loss = 1.9474
# epoch 23 / 50, step 6/7, loss = 1.9312
# epoch 23 / 50, step 7/7, loss = 1.9201
# epoch 24 / 50, step 1/28, loss = 1.8315
# epoch 24 / 50, step 2/28, loss = 1.9089
# epoch 24 / 50, step 3/28, loss = 1.7906
# epoch 24 / 50, step 4/28, loss = 1.8868
# epoch 24 / 50, step 5/28, loss = 1.8656
# epoch 24 / 50, step 6/28, loss = 1.9236
# epoch 24 / 50, step 7/28, loss = 1.8601
# epoch 24 / 50, step 8/28, loss = 1.8870
# epoch 24 / 50, step 9/28, loss = 1.8346
# epoch 24 / 50, step 10/28, loss = 1.8868
# epoch 24 / 50, step 11/28, loss = 1.8296
# epoch 24 / 50, step 12/28, loss = 1.7761
# epoch 24 / 50, step 13/28, loss = 1.8282
# epoch 24 / 50, step 14/28, loss = 1.8746
# epoch 24 / 50, step 15/28, loss = 1.8001
# epoch 24 / 50, step 16/28, loss = 1.8827
# epoch 24 / 50, step 17/28, loss = 1.8696
# epoch 24 / 50, step 18/28, loss = 1.7847
# epoch 24 / 50, step 19/28, loss = 1.7516
# epoch 24 / 50, step 20/28, loss = 1.8283
# epoch 24 / 50, step 21/28, loss = 1.8601
# epoch 24 / 50, step 22/28, loss = 1.8494
# epoch 24 / 50, step 23/28, loss = 1.8934
# epoch 24 / 50, step 24/28, loss = 1.7506
# epoch 24 / 50, step 25/28, loss = 1.8193
# epoch 24 / 50, step 26/28, loss = 1.9156
# epoch 24 / 50, step 27/28, loss = 1.8081
# epoch 24 / 50, step 28/28, loss = 1.7755
# epoch 24 / 50, step 1/7, loss = 1.9439
# epoch 24 / 50, step 2/7, loss = 2.0491
# epoch 24 / 50, step 3/7, loss = 1.8468
# epoch 24 / 50, step 4/7, loss = 1.9279
# epoch 24 / 50, step 5/7, loss = 1.9713
# epoch 24 / 50, step 6/7, loss = 1.9315
# epoch 24 / 50, step 7/7, loss = 1.9228
# epoch 25 / 50, step 1/28, loss = 1.8050
# epoch 25 / 50, step 2/28, loss = 1.7977
# epoch 25 / 50, step 3/28, loss = 1.8441
# epoch 25 / 50, step 4/28, loss = 1.8524
# epoch 25 / 50, step 5/28, loss = 1.9034
# epoch 25 / 50, step 6/28, loss = 1.7482
# epoch 25 / 50, step 7/28, loss = 1.8043
# epoch 25 / 50, step 8/28, loss = 1.9225
# epoch 25 / 50, step 9/28, loss = 1.8372
# epoch 25 / 50, step 10/28, loss = 1.8114
# epoch 25 / 50, step 11/28, loss = 1.8840
# epoch 25 / 50, step 12/28, loss = 1.9391
# epoch 25 / 50, step 13/28, loss = 1.8912
# epoch 25 / 50, step 14/28, loss = 1.7615
# epoch 25 / 50, step 15/28, loss = 1.9219
# epoch 25 / 50, step 16/28, loss = 1.8800
# epoch 25 / 50, step 17/28, loss = 1.8294
# epoch 25 / 50, step 18/28, loss = 1.8245
# epoch 25 / 50, step 19/28, loss = 1.8128
# epoch 25 / 50, step 20/28, loss = 1.7473
# epoch 25 / 50, step 21/28, loss = 1.8382
# epoch 25 / 50, step 22/28, loss = 1.7774
# epoch 25 / 50, step 23/28, loss = 1.8148
# epoch 25 / 50, step 24/28, loss = 1.9242
# epoch 25 / 50, step 25/28, loss = 1.8744
# epoch 25 / 50, step 26/28, loss = 1.8724
# epoch 25 / 50, step 27/28, loss = 1.8720
# epoch 25 / 50, step 28/28, loss = 1.9885
# epoch 25 / 50, step 1/7, loss = 1.8939
# epoch 25 / 50, step 2/7, loss = 2.0111
# epoch 25 / 50, step 3/7, loss = 1.8596
# epoch 25 / 50, step 4/7, loss = 1.9289
# epoch 25 / 50, step 5/7, loss = 1.9494
# epoch 25 / 50, step 6/7, loss = 1.9184
# epoch 25 / 50, step 7/7, loss = 1.9390
# epoch 26 / 50, step 1/28, loss = 1.7176
# epoch 26 / 50, step 2/28, loss = 1.8691
# epoch 26 / 50, step 3/28, loss = 1.8734
# epoch 26 / 50, step 4/28, loss = 1.8988
# epoch 26 / 50, step 5/28, loss = 1.8682
# epoch 26 / 50, step 6/28, loss = 1.8462
# epoch 26 / 50, step 7/28, loss = 1.8271
# epoch 26 / 50, step 8/28, loss = 1.8676
# epoch 26 / 50, step 9/28, loss = 1.8004
# epoch 26 / 50, step 10/28, loss = 1.9144
# epoch 26 / 50, step 11/28, loss = 1.8177
# epoch 26 / 50, step 12/28, loss = 1.8144
# epoch 26 / 50, step 13/28, loss = 1.8174
# epoch 26 / 50, step 14/28, loss = 1.7768
# epoch 26 / 50, step 15/28, loss = 1.8237
# epoch 26 / 50, step 16/28, loss = 1.8082
# epoch 26 / 50, step 17/28, loss = 1.8269
# epoch 26 / 50, step 18/28, loss = 1.8064
# epoch 26 / 50, step 19/28, loss = 1.8409
# epoch 26 / 50, step 20/28, loss = 1.8084
# epoch 26 / 50, step 21/28, loss = 1.8458
# epoch 26 / 50, step 22/28, loss = 1.8235
# epoch 26 / 50, step 23/28, loss = 1.8394
# epoch 26 / 50, step 24/28, loss = 1.8082
# epoch 26 / 50, step 25/28, loss = 1.9210
# epoch 26 / 50, step 26/28, loss = 1.8268
# epoch 26 / 50, step 27/28, loss = 1.8543
# epoch 26 / 50, step 28/28, loss = 1.7812
# epoch 26 / 50, step 1/7, loss = 1.9720
# epoch 26 / 50, step 2/7, loss = 2.0409
# epoch 26 / 50, step 3/7, loss = 1.8619
# epoch 26 / 50, step 4/7, loss = 1.9220
# epoch 26 / 50, step 5/7, loss = 1.9823
# epoch 26 / 50, step 6/7, loss = 1.9038
# epoch 26 / 50, step 7/7, loss = 1.9832
# epoch 27 / 50, step 1/28, loss = 2.0248
# epoch 27 / 50, step 2/28, loss = 1.7700
# epoch 27 / 50, step 3/28, loss = 1.7682
# epoch 27 / 50, step 4/28, loss = 1.7371
# epoch 27 / 50, step 5/28, loss = 1.8699
# epoch 27 / 50, step 6/28, loss = 1.8591
# epoch 27 / 50, step 7/28, loss = 1.8218
# epoch 27 / 50, step 8/28, loss = 1.7329
# epoch 27 / 50, step 9/28, loss = 1.8822
# epoch 27 / 50, step 10/28, loss = 1.9356
# epoch 27 / 50, step 11/28, loss = 1.8598
# epoch 27 / 50, step 12/28, loss = 1.8136
# epoch 27 / 50, step 13/28, loss = 1.7445
# epoch 27 / 50, step 14/28, loss = 1.8756
# epoch 27 / 50, step 15/28, loss = 1.7879
# epoch 27 / 50, step 16/28, loss = 1.7905
# epoch 27 / 50, step 17/28, loss = 1.7760
# epoch 27 / 50, step 18/28, loss = 1.7888
# epoch 27 / 50, step 19/28, loss = 1.8407
# epoch 27 / 50, step 20/28, loss = 1.8000
# epoch 27 / 50, step 21/28, loss = 1.7844
# epoch 27 / 50, step 22/28, loss = 1.8488
# epoch 27 / 50, step 23/28, loss = 1.7988
# epoch 27 / 50, step 24/28, loss = 1.8078
# epoch 27 / 50, step 25/28, loss = 1.8121
# epoch 27 / 50, step 26/28, loss = 1.7765
# epoch 27 / 50, step 27/28, loss = 1.7530
# epoch 27 / 50, step 28/28, loss = 1.6893
# epoch 27 / 50, step 1/7, loss = 1.9798
# epoch 27 / 50, step 2/7, loss = 2.0539
# epoch 27 / 50, step 3/7, loss = 1.9032
# epoch 27 / 50, step 4/7, loss = 1.9618
# epoch 27 / 50, step 5/7, loss = 2.0105
# epoch 27 / 50, step 6/7, loss = 1.9472
# epoch 27 / 50, step 7/7, loss = 2.0194
# epoch 28 / 50, step 1/28, loss = 1.7398
# epoch 28 / 50, step 2/28, loss = 1.7562
# epoch 28 / 50, step 3/28, loss = 1.8909
# epoch 28 / 50, step 4/28, loss = 1.8331
# epoch 28 / 50, step 5/28, loss = 1.8102
# epoch 28 / 50, step 6/28, loss = 1.5999
# epoch 28 / 50, step 7/28, loss = 1.7073
# epoch 28 / 50, step 8/28, loss = 1.9297
# epoch 28 / 50, step 9/28, loss = 1.9940
# epoch 28 / 50, step 10/28, loss = 1.8715
# epoch 28 / 50, step 11/28, loss = 1.8443
# epoch 28 / 50, step 12/28, loss = 1.8622
# epoch 28 / 50, step 13/28, loss = 1.8406
# epoch 28 / 50, step 14/28, loss = 1.8345
# epoch 28 / 50, step 15/28, loss = 1.7767
# epoch 28 / 50, step 16/28, loss = 1.8484
# epoch 28 / 50, step 17/28, loss = 1.7666
# epoch 28 / 50, step 18/28, loss = 1.8558
# epoch 28 / 50, step 19/28, loss = 1.9502
# epoch 28 / 50, step 20/28, loss = 1.8987
# epoch 28 / 50, step 21/28, loss = 1.8816
# epoch 28 / 50, step 22/28, loss = 1.8151
# epoch 28 / 50, step 23/28, loss = 1.8438
# epoch 28 / 50, step 24/28, loss = 1.7993
# epoch 28 / 50, step 25/28, loss = 1.7699
# epoch 28 / 50, step 26/28, loss = 1.7991
# epoch 28 / 50, step 27/28, loss = 1.8827
# epoch 28 / 50, step 28/28, loss = 1.8591
# epoch 28 / 50, step 1/7, loss = 1.9329
# epoch 28 / 50, step 2/7, loss = 1.9190
# epoch 28 / 50, step 3/7, loss = 1.8964
# epoch 28 / 50, step 4/7, loss = 1.9135
# epoch 28 / 50, step 5/7, loss = 1.9225
# epoch 28 / 50, step 6/7, loss = 1.9332
# epoch 28 / 50, step 7/7, loss = 1.9330
# epoch 29 / 50, step 1/28, loss = 1.8729
# epoch 29 / 50, step 2/28, loss = 1.8688
# epoch 29 / 50, step 3/28, loss = 1.8502
# epoch 29 / 50, step 4/28, loss = 1.8036
# epoch 29 / 50, step 5/28, loss = 1.8447
# epoch 29 / 50, step 6/28, loss = 1.8906
# epoch 29 / 50, step 7/28, loss = 1.8440
# epoch 29 / 50, step 8/28, loss = 1.8371
# epoch 29 / 50, step 9/28, loss = 1.8286
# epoch 29 / 50, step 10/28, loss = 1.7443
# epoch 29 / 50, step 11/28, loss = 1.8290
# epoch 29 / 50, step 12/28, loss = 1.7484
# epoch 29 / 50, step 13/28, loss = 1.8697
# epoch 29 / 50, step 14/28, loss = 1.6563
# epoch 29 / 50, step 15/28, loss = 1.7979
# epoch 29 / 50, step 16/28, loss = 1.6651
# epoch 29 / 50, step 17/28, loss = 1.7104
# epoch 29 / 50, step 18/28, loss = 1.6774
# epoch 29 / 50, step 19/28, loss = 1.8723
# epoch 29 / 50, step 20/28, loss = 1.8645
# epoch 29 / 50, step 21/28, loss = 1.8832
# epoch 29 / 50, step 22/28, loss = 1.6553
# epoch 29 / 50, step 23/28, loss = 1.9112
# epoch 29 / 50, step 24/28, loss = 1.7689
# epoch 29 / 50, step 25/28, loss = 1.7700
# epoch 29 / 50, step 26/28, loss = 1.7413
# epoch 29 / 50, step 27/28, loss = 1.8523
# epoch 29 / 50, step 28/28, loss = 1.7843
# epoch 29 / 50, step 1/7, loss = 1.9772
# epoch 29 / 50, step 2/7, loss = 1.9944
# epoch 29 / 50, step 3/7, loss = 1.8909
# epoch 29 / 50, step 4/7, loss = 1.8906
# epoch 29 / 50, step 5/7, loss = 1.9314
# epoch 29 / 50, step 6/7, loss = 1.8653
# epoch 29 / 50, step 7/7, loss = 2.0142
# epoch 30 / 50, step 1/28, loss = 1.7345
# epoch 30 / 50, step 2/28, loss = 1.7982
# epoch 30 / 50, step 3/28, loss = 1.7645
# epoch 30 / 50, step 4/28, loss = 1.7323
# epoch 30 / 50, step 5/28, loss = 1.7497
# epoch 30 / 50, step 6/28, loss = 1.8082
# epoch 30 / 50, step 7/28, loss = 1.7950
# epoch 30 / 50, step 8/28, loss = 1.7081
# epoch 30 / 50, step 9/28, loss = 1.8181
# epoch 30 / 50, step 10/28, loss = 1.7386
# epoch 30 / 50, step 11/28, loss = 1.6363
# epoch 30 / 50, step 12/28, loss = 1.7476
# epoch 30 / 50, step 13/28, loss = 1.7630
# epoch 30 / 50, step 14/28, loss = 1.8452
# epoch 30 / 50, step 15/28, loss = 1.8081
# epoch 30 / 50, step 16/28, loss = 1.7105
# epoch 30 / 50, step 17/28, loss = 1.6347
# epoch 30 / 50, step 18/28, loss = 2.0711
# epoch 30 / 50, step 19/28, loss = 1.8160
# epoch 30 / 50, step 20/28, loss = 1.8995
# epoch 30 / 50, step 21/28, loss = 1.7767
# epoch 30 / 50, step 22/28, loss = 1.7468
# epoch 30 / 50, step 23/28, loss = 1.7595
# epoch 30 / 50, step 24/28, loss = 1.9189
# epoch 30 / 50, step 25/28, loss = 1.8918
# epoch 30 / 50, step 26/28, loss = 1.8157
# epoch 30 / 50, step 27/28, loss = 1.7989
# epoch 30 / 50, step 28/28, loss = 1.8185
# epoch 30 / 50, step 1/7, loss = 1.8709
# epoch 30 / 50, step 2/7, loss = 1.9386
# epoch 30 / 50, step 3/7, loss = 1.9098
# epoch 30 / 50, step 4/7, loss = 1.8863
# epoch 30 / 50, step 5/7, loss = 1.9123
# epoch 30 / 50, step 6/7, loss = 1.8934
# epoch 30 / 50, step 7/7, loss = 1.9155
# epoch 31 / 50, step 1/28, loss = 1.8698
# epoch 31 / 50, step 2/28, loss = 1.8375
# epoch 31 / 50, step 3/28, loss = 1.8250
# epoch 31 / 50, step 4/28, loss = 1.7717
# epoch 31 / 50, step 5/28, loss = 1.8172
# epoch 31 / 50, step 6/28, loss = 1.9061
# epoch 31 / 50, step 7/28, loss = 1.7317
# epoch 31 / 50, step 8/28, loss = 1.8569
# epoch 31 / 50, step 9/28, loss = 1.7666
# epoch 31 / 50, step 10/28, loss = 1.8319
# epoch 31 / 50, step 11/28, loss = 1.7945
# epoch 31 / 50, step 12/28, loss = 1.7503
# epoch 31 / 50, step 13/28, loss = 1.8033
# epoch 31 / 50, step 14/28, loss = 1.7964
# epoch 31 / 50, step 15/28, loss = 1.7330
# epoch 31 / 50, step 16/28, loss = 1.7766
# epoch 31 / 50, step 17/28, loss = 1.8267
# epoch 31 / 50, step 18/28, loss = 1.7345
# epoch 31 / 50, step 19/28, loss = 1.8263
# epoch 31 / 50, step 20/28, loss = 1.6433
# epoch 31 / 50, step 21/28, loss = 1.7587
# epoch 31 / 50, step 22/28, loss = 1.6967
# epoch 31 / 50, step 23/28, loss = 1.8232
# epoch 31 / 50, step 24/28, loss = 1.7055
# epoch 31 / 50, step 25/28, loss = 1.7700
# epoch 31 / 50, step 26/28, loss = 1.6869
# epoch 31 / 50, step 27/28, loss = 1.8081
# epoch 31 / 50, step 28/28, loss = 1.8466
# epoch 31 / 50, step 1/7, loss = 1.8577
# epoch 31 / 50, step 2/7, loss = 1.9616
# epoch 31 / 50, step 3/7, loss = 1.9243
# epoch 31 / 50, step 4/7, loss = 1.8066
# epoch 31 / 50, step 5/7, loss = 1.9099
# epoch 31 / 50, step 6/7, loss = 1.8193
# epoch 31 / 50, step 7/7, loss = 1.9434
# epoch 32 / 50, step 1/28, loss = 1.8096
# epoch 32 / 50, step 2/28, loss = 1.7849
# epoch 32 / 50, step 3/28, loss = 1.7333
# epoch 32 / 50, step 4/28, loss = 1.7269
# epoch 32 / 50, step 5/28, loss = 1.7287
# epoch 32 / 50, step 6/28, loss = 1.5387
# epoch 32 / 50, step 7/28, loss = 1.7853
# epoch 32 / 50, step 8/28, loss = 1.6496
# epoch 32 / 50, step 9/28, loss = 1.7895
# epoch 32 / 50, step 10/28, loss = 1.6524
# epoch 32 / 50, step 11/28, loss = 1.6886
# epoch 32 / 50, step 12/28, loss = 1.7287
# epoch 32 / 50, step 13/28, loss = 1.8371
# epoch 32 / 50, step 14/28, loss = 1.7044
# epoch 32 / 50, step 15/28, loss = 1.6617
# epoch 32 / 50, step 16/28, loss = 1.7662
# epoch 32 / 50, step 17/28, loss = 1.7455
# epoch 32 / 50, step 18/28, loss = 1.7683
# epoch 32 / 50, step 19/28, loss = 1.8994
# epoch 32 / 50, step 20/28, loss = 1.6935
# epoch 32 / 50, step 21/28, loss = 1.6510
# epoch 32 / 50, step 22/28, loss = 1.7900
# epoch 32 / 50, step 23/28, loss = 1.7445
# epoch 32 / 50, step 24/28, loss = 1.7433
# epoch 32 / 50, step 25/28, loss = 1.7499
# epoch 32 / 50, step 26/28, loss = 1.8130
# epoch 32 / 50, step 27/28, loss = 1.7882
# epoch 32 / 50, step 28/28, loss = 1.8385
# epoch 32 / 50, step 1/7, loss = 1.8465
# epoch 32 / 50, step 2/7, loss = 1.9110
# epoch 32 / 50, step 3/7, loss = 1.9203
# epoch 32 / 50, step 4/7, loss = 1.8003
# epoch 32 / 50, step 5/7, loss = 1.8389
# epoch 32 / 50, step 6/7, loss = 1.8231
# epoch 32 / 50, step 7/7, loss = 1.8201
# epoch 33 / 50, step 1/28, loss = 1.7823
# epoch 33 / 50, step 2/28, loss = 1.6907
# epoch 33 / 50, step 3/28, loss = 1.7284
# epoch 33 / 50, step 4/28, loss = 1.6545
# epoch 33 / 50, step 5/28, loss = 1.6813
# epoch 33 / 50, step 6/28, loss = 1.7286
# epoch 33 / 50, step 7/28, loss = 1.5568
# epoch 33 / 50, step 8/28, loss = 1.8131
# epoch 33 / 50, step 9/28, loss = 1.5327
# epoch 33 / 50, step 10/28, loss = 1.9224
# epoch 33 / 50, step 11/28, loss = 1.8017
# epoch 33 / 50, step 12/28, loss = 1.6826
# epoch 33 / 50, step 13/28, loss = 1.6174
# epoch 33 / 50, step 14/28, loss = 1.7353
# epoch 33 / 50, step 15/28, loss = 1.8764
# epoch 33 / 50, step 16/28, loss = 1.7135
# epoch 33 / 50, step 17/28, loss = 1.6936
# epoch 33 / 50, step 18/28, loss = 1.7190
# epoch 33 / 50, step 19/28, loss = 1.7276
# epoch 33 / 50, step 20/28, loss = 1.6430
# epoch 33 / 50, step 21/28, loss = 1.7206
# epoch 33 / 50, step 22/28, loss = 1.7093
# epoch 33 / 50, step 23/28, loss = 1.7542
# epoch 33 / 50, step 24/28, loss = 1.7418
# epoch 33 / 50, step 25/28, loss = 1.7571
# epoch 33 / 50, step 26/28, loss = 1.7608
# epoch 33 / 50, step 27/28, loss = 1.5999
# epoch 33 / 50, step 28/28, loss = 1.7528
# epoch 33 / 50, step 1/7, loss = 2.2402
# epoch 33 / 50, step 2/7, loss = 2.2998
# epoch 33 / 50, step 3/7, loss = 1.9772
# epoch 33 / 50, step 4/7, loss = 2.2062
# epoch 33 / 50, step 5/7, loss = 1.9750
# epoch 33 / 50, step 6/7, loss = 2.0459
# epoch 33 / 50, step 7/7, loss = 2.3055
# epoch 34 / 50, step 1/28, loss = 1.6337
# epoch 34 / 50, step 2/28, loss = 1.7354
# epoch 34 / 50, step 3/28, loss = 1.6524
# epoch 34 / 50, step 4/28, loss = 1.6417
# epoch 34 / 50, step 5/28, loss = 1.6849
# epoch 34 / 50, step 6/28, loss = 1.6490
# epoch 34 / 50, step 7/28, loss = 1.7652
# epoch 34 / 50, step 8/28, loss = 1.7081
# epoch 34 / 50, step 9/28, loss = 1.6910
# epoch 34 / 50, step 10/28, loss = 1.7318
# epoch 34 / 50, step 11/28, loss = 1.8175
# epoch 34 / 50, step 12/28, loss = 1.7968
# epoch 34 / 50, step 13/28, loss = 1.6789
# epoch 34 / 50, step 14/28, loss = 1.7913
# epoch 34 / 50, step 15/28, loss = 1.6265
# epoch 34 / 50, step 16/28, loss = 1.7262
# epoch 34 / 50, step 17/28, loss = 1.6783
# epoch 34 / 50, step 18/28, loss = 1.8566
# epoch 34 / 50, step 19/28, loss = 1.8586
# epoch 34 / 50, step 20/28, loss = 1.6376
# epoch 34 / 50, step 21/28, loss = 1.6749
# epoch 34 / 50, step 22/28, loss = 1.8312
# epoch 34 / 50, step 23/28, loss = 1.7914
# epoch 34 / 50, step 24/28, loss = 1.7071
# epoch 34 / 50, step 25/28, loss = 1.7456
# epoch 34 / 50, step 26/28, loss = 1.7365
# epoch 34 / 50, step 27/28, loss = 1.6586
# epoch 34 / 50, step 28/28, loss = 1.9103
# epoch 34 / 50, step 1/7, loss = 1.8445
# epoch 34 / 50, step 2/7, loss = 1.9812
# epoch 34 / 50, step 3/7, loss = 1.8819
# epoch 34 / 50, step 4/7, loss = 1.9346
# epoch 34 / 50, step 5/7, loss = 1.8927
# epoch 34 / 50, step 6/7, loss = 1.8396
# epoch 34 / 50, step 7/7, loss = 1.9463
# epoch 35 / 50, step 1/28, loss = 1.6530
# epoch 35 / 50, step 2/28, loss = 1.7033
# epoch 35 / 50, step 3/28, loss = 1.6927
# epoch 35 / 50, step 4/28, loss = 1.7366
# epoch 35 / 50, step 5/28, loss = 1.6568
# epoch 35 / 50, step 6/28, loss = 1.7606
# epoch 35 / 50, step 7/28, loss = 1.6980
# ...
# epoch 39 / 50, step 25/28, loss = 1.5920
# epoch 39 / 50, step 26/28, loss = 1.5792
# epoch 39 / 50, step 27/28, loss = 1.5219
# epoch 39 / 50, step 28/28, loss = 1.9704
# epoch 39 / 50, step 1/7, loss = 1.7313
# epoch 39 / 50, step 2/7, loss = 1.9046
# epoch 39 / 50, step 3/7, loss = 1.7415
# epoch 39 / 50, step 4/7, loss = 1.8199
# epoch 39 / 50, step 5/7, loss = 1.9829
# epoch 39 / 50, step 6/7, loss = 1.6492
# epoch 39 / 50, step 7/7, loss = 1.9480
# epoch 40 / 50, step 1/28, loss = 1.3683
# epoch 40 / 50, step 2/28, loss = 1.3669
# epoch 40 / 50, step 3/28, loss = 1.8114
# epoch 40 / 50, step 4/28, loss = 1.7215
# epoch 40 / 50, step 5/28, loss = 1.4720
# epoch 40 / 50, step 6/28, loss = 1.8162
# epoch 40 / 50, step 7/28, loss = 1.7555
# epoch 40 / 50, step 8/28, loss = 1.5848
# epoch 40 / 50, step 9/28, loss = 1.3929
# epoch 40 / 50, step 10/28, loss = 1.6590
# epoch 40 / 50, step 11/28, loss = 1.4786
# epoch 40 / 50, step 12/28, loss = 1.8156
# epoch 40 / 50, step 13/28, loss = 1.6314
# epoch 40 / 50, step 14/28, loss = 1.5114
# epoch 40 / 50, step 15/28, loss = 1.5207
# epoch 40 / 50, step 16/28, loss = 1.5689
# epoch 40 / 50, step 17/28, loss = 1.7513
# epoch 40 / 50, step 18/28, loss = 1.6222
# epoch 40 / 50, step 19/28, loss = 1.5175
# epoch 40 / 50, step 20/28, loss = 1.4669
# epoch 40 / 50, step 21/28, loss = 1.7233
# epoch 40 / 50, step 22/28, loss = 1.6453
# epoch 40 / 50, step 23/28, loss = 1.7899
# epoch 40 / 50, step 24/28, loss = 1.5180
# epoch 40 / 50, step 25/28, loss = 1.5915
# epoch 40 / 50, step 26/28, loss = 1.6536
# epoch 40 / 50, step 27/28, loss = 1.5092
# epoch 40 / 50, step 28/28, loss = 0.8908
# epoch 40 / 50, step 1/7, loss = 1.6879
# epoch 40 / 50, step 2/7, loss = 1.7171
# epoch 40 / 50, step 3/7, loss = 1.6129
# epoch 40 / 50, step 4/7, loss = 1.6212
# epoch 40 / 50, step 5/7, loss = 1.8171
# epoch 40 / 50, step 6/7, loss = 1.6458
# epoch 40 / 50, step 7/7, loss = 1.8013
# epoch 41 / 50, step 1/28, loss = 1.5173
# epoch 41 / 50, step 2/28, loss = 1.4275
# epoch 41 / 50, step 3/28, loss = 1.5319
# epoch 41 / 50, step 4/28, loss = 1.3890
# epoch 41 / 50, step 5/28, loss = 1.4508
# epoch 41 / 50, step 6/28, loss = 1.2123
# epoch 41 / 50, step 7/28, loss = 1.5299
# epoch 41 / 50, step 8/28, loss = 1.7492
# epoch 41 / 50, step 9/28, loss = 1.5433
# epoch 41 / 50, step 10/28, loss = 1.6278
# epoch 41 / 50, step 11/28, loss = 1.4671
# epoch 41 / 50, step 12/28, loss = 1.6015
# epoch 41 / 50, step 13/28, loss = 1.4826
# epoch 41 / 50, step 14/28, loss = 1.5533
# epoch 41 / 50, step 15/28, loss = 1.7471
# epoch 41 / 50, step 16/28, loss = 1.8128
# epoch 41 / 50, step 17/28, loss = 1.7289
# epoch 41 / 50, step 18/28, loss = 1.5664
# epoch 41 / 50, step 19/28, loss = 1.5344
# epoch 41 / 50, step 20/28, loss = 1.4316
# epoch 41 / 50, step 21/28, loss = 1.8168
# epoch 41 / 50, step 22/28, loss = 1.5513
# epoch 41 / 50, step 23/28, loss = 1.4618
# epoch 41 / 50, step 24/28, loss = 1.4702
# epoch 41 / 50, step 25/28, loss = 1.5483
# epoch 41 / 50, step 26/28, loss = 1.6183
# epoch 41 / 50, step 27/28, loss = 1.5112
# epoch 41 / 50, step 28/28, loss = 1.1935
# epoch 41 / 50, step 1/7, loss = 1.6519
# epoch 41 / 50, step 2/7, loss = 1.7996
# epoch 41 / 50, step 3/7, loss = 1.5963
# epoch 41 / 50, step 4/7, loss = 1.6719
# epoch 41 / 50, step 5/7, loss = 1.7448
# epoch 41 / 50, step 6/7, loss = 1.6188
# epoch 41 / 50, step 7/7, loss = 1.7570
# epoch 42 / 50, step 1/28, loss = 1.5986
# epoch 42 / 50, step 2/28, loss = 1.4466
# epoch 42 / 50, step 3/28, loss = 1.4993
# epoch 42 / 50, step 4/28, loss = 1.4002
# epoch 42 / 50, step 5/28, loss = 1.4862
# epoch 42 / 50, step 6/28, loss = 1.4356
# epoch 42 / 50, step 7/28, loss = 1.4981
# epoch 42 / 50, step 8/28, loss = 1.5622
# epoch 42 / 50, step 9/28, loss = 1.4922
# epoch 42 / 50, step 10/28, loss = 1.4174
# epoch 42 / 50, step 11/28, loss = 1.4255
# epoch 42 / 50, step 12/28, loss = 1.4716
# epoch 42 / 50, step 13/28, loss = 1.4770
# epoch 42 / 50, step 14/28, loss = 1.7924
# epoch 42 / 50, step 15/28, loss = 1.8561
# epoch 42 / 50, step 16/28, loss = 1.4061
# epoch 42 / 50, step 17/28, loss = 1.5846
# epoch 42 / 50, step 18/28, loss = 1.3744
# epoch 42 / 50, step 19/28, loss = 1.6064
# epoch 42 / 50, step 20/28, loss = 1.5699
# epoch 42 / 50, step 21/28, loss = 1.7831
# epoch 42 / 50, step 22/28, loss = 1.5910
# epoch 42 / 50, step 23/28, loss = 1.6515
# epoch 42 / 50, step 24/28, loss = 1.6073
# epoch 42 / 50, step 25/28, loss = 1.8394
# epoch 42 / 50, step 26/28, loss = 1.5519
# epoch 42 / 50, step 27/28, loss = 1.7174
# epoch 42 / 50, step 28/28, loss = 1.5029
# epoch 42 / 50, step 1/7, loss = 1.6953
# epoch 42 / 50, step 2/7, loss = 1.8679
# epoch 42 / 50, step 3/7, loss = 1.6056
# epoch 42 / 50, step 4/7, loss = 1.7212
# epoch 42 / 50, step 5/7, loss = 1.8848
# epoch 42 / 50, step 6/7, loss = 1.4958
# epoch 42 / 50, step 7/7, loss = 1.7157
# epoch 43 / 50, step 1/28, loss = 1.3941
# epoch 43 / 50, step 2/28, loss = 1.5655
# epoch 43 / 50, step 3/28, loss = 1.5863
# epoch 43 / 50, step 4/28, loss = 1.4229
# epoch 43 / 50, step 5/28, loss = 1.7132
# epoch 43 / 50, step 6/28, loss = 1.6857
# epoch 43 / 50, step 7/28, loss = 1.4359
# epoch 43 / 50, step 8/28, loss = 1.5028
# epoch 43 / 50, step 9/28, loss = 1.2725
# epoch 43 / 50, step 10/28, loss = 1.4621
# epoch 43 / 50, step 11/28, loss = 1.4149
# epoch 43 / 50, step 12/28, loss = 1.4403
# epoch 43 / 50, step 13/28, loss = 1.5674
# epoch 43 / 50, step 14/28, loss = 1.7050
# epoch 43 / 50, step 15/28, loss = 1.5378
# epoch 43 / 50, step 16/28, loss = 1.3693
# epoch 43 / 50, step 17/28, loss = 1.5087
# epoch 43 / 50, step 18/28, loss = 1.5746
# epoch 43 / 50, step 19/28, loss = 1.4230
# epoch 43 / 50, step 20/28, loss = 1.7457
# epoch 43 / 50, step 21/28, loss = 1.4506
# epoch 43 / 50, step 22/28, loss = 1.6219
# epoch 43 / 50, step 23/28, loss = 1.5763
# epoch 43 / 50, step 24/28, loss = 1.2718
# epoch 43 / 50, step 25/28, loss = 1.4123
# epoch 43 / 50, step 26/28, loss = 1.6408
# epoch 43 / 50, step 27/28, loss = 1.5491
# epoch 43 / 50, step 28/28, loss = 1.3406
# epoch 43 / 50, step 1/7, loss = 1.6715
# epoch 43 / 50, step 2/7, loss = 1.8747
# epoch 43 / 50, step 3/7, loss = 1.6090
# epoch 43 / 50, step 4/7, loss = 1.8595
# epoch 43 / 50, step 5/7, loss = 1.8415
# epoch 43 / 50, step 6/7, loss = 1.6546
# epoch 43 / 50, step 7/7, loss = 1.7603
# epoch 44 / 50, step 1/28, loss = 1.4474
# epoch 44 / 50, step 2/28, loss = 1.4183
# epoch 44 / 50, step 3/28, loss = 1.5709
# epoch 44 / 50, step 4/28, loss = 1.5329
# epoch 44 / 50, step 5/28, loss = 1.2816
# epoch 44 / 50, step 6/28, loss = 1.4178
# epoch 44 / 50, step 7/28, loss = 1.5493
# epoch 44 / 50, step 8/28, loss = 1.6295
# epoch 44 / 50, step 9/28, loss = 1.3286
# epoch 44 / 50, step 10/28, loss = 1.1908
# epoch 44 / 50, step 11/28, loss = 1.6372
# epoch 44 / 50, step 12/28, loss = 1.5826
# epoch 44 / 50, step 13/28, loss = 1.4512
# epoch 44 / 50, step 14/28, loss = 1.3460
# epoch 44 / 50, step 15/28, loss = 1.4003
# epoch 44 / 50, step 16/28, loss = 1.4194
# epoch 44 / 50, step 17/28, loss = 1.6464
# epoch 44 / 50, step 18/28, loss = 1.4991
# epoch 44 / 50, step 19/28, loss = 1.6113
# epoch 44 / 50, step 20/28, loss = 1.4760
# epoch 44 / 50, step 21/28, loss = 1.4497
# epoch 44 / 50, step 22/28, loss = 1.5321
# epoch 44 / 50, step 23/28, loss = 1.6216
# epoch 44 / 50, step 24/28, loss = 1.3425
# epoch 44 / 50, step 25/28, loss = 1.4134
# epoch 44 / 50, step 26/28, loss = 1.5104
# epoch 44 / 50, step 27/28, loss = 1.7383
# epoch 44 / 50, step 28/28, loss = 1.5946
# epoch 44 / 50, step 1/7, loss = 1.6365
# epoch 44 / 50, step 2/7, loss = 1.9758
# epoch 44 / 50, step 3/7, loss = 1.7333
# epoch 44 / 50, step 4/7, loss = 1.7375
# epoch 44 / 50, step 5/7, loss = 1.7432
# epoch 44 / 50, step 6/7, loss = 1.4046
# epoch 44 / 50, step 7/7, loss = 1.8466
# epoch 45 / 50, step 1/28, loss = 1.4412
# epoch 45 / 50, step 2/28, loss = 1.2289
# epoch 45 / 50, step 3/28, loss = 1.1961
# epoch 45 / 50, step 4/28, loss = 1.4174
# epoch 45 / 50, step 5/28, loss = 1.4268
# epoch 45 / 50, step 6/28, loss = 2.0186
# epoch 45 / 50, step 7/28, loss = 1.3413
# epoch 45 / 50, step 8/28, loss = 1.5032
# epoch 45 / 50, step 9/28, loss = 1.5378
# epoch 45 / 50, step 10/28, loss = 1.4391
# epoch 45 / 50, step 11/28, loss = 1.6908
# epoch 45 / 50, step 12/28, loss = 1.5172
# epoch 45 / 50, step 13/28, loss = 1.5803
# epoch 45 / 50, step 14/28, loss = 1.5763
# epoch 45 / 50, step 15/28, loss = 1.5802
# epoch 45 / 50, step 16/28, loss = 1.4620
# epoch 45 / 50, step 17/28, loss = 1.8061
# epoch 45 / 50, step 18/28, loss = 1.2411
# epoch 45 / 50, step 19/28, loss = 1.6470
# epoch 45 / 50, step 20/28, loss = 1.6860
# epoch 45 / 50, step 21/28, loss = 1.3415
# epoch 45 / 50, step 22/28, loss = 1.5829
# epoch 45 / 50, step 23/28, loss = 1.3618
# epoch 45 / 50, step 24/28, loss = 1.4251
# epoch 45 / 50, step 25/28, loss = 1.8324
# epoch 45 / 50, step 26/28, loss = 1.9078
# epoch 45 / 50, step 27/28, loss = 1.7564
# epoch 45 / 50, step 28/28, loss = 0.7836
# epoch 45 / 50, step 1/7, loss = 1.9100
# epoch 45 / 50, step 2/7, loss = 2.0939
# epoch 45 / 50, step 3/7, loss = 1.9240
# epoch 45 / 50, step 4/7, loss = 1.7487
# epoch 45 / 50, step 5/7, loss = 1.7471
# epoch 45 / 50, step 6/7, loss = 1.8339
# epoch 45 / 50, step 7/7, loss = 2.1373
# epoch 46 / 50, step 1/28, loss = 1.3117
# epoch 46 / 50, step 2/28, loss = 1.3872
# epoch 46 / 50, step 3/28, loss = 1.3660
# epoch 46 / 50, step 4/28, loss = 1.6175
# epoch 46 / 50, step 5/28, loss = 1.4141
# epoch 46 / 50, step 6/28, loss = 1.7161
# epoch 46 / 50, step 7/28, loss = 1.3738
# epoch 46 / 50, step 8/28, loss = 1.6864
# epoch 46 / 50, step 9/28, loss = 1.7019
# epoch 46 / 50, step 10/28, loss = 1.5013
# epoch 46 / 50, step 11/28, loss = 1.3265
# epoch 46 / 50, step 12/28, loss = 1.2488
# epoch 46 / 50, step 13/28, loss = 1.6681
# epoch 46 / 50, step 14/28, loss = 1.5732
# epoch 46 / 50, step 15/28, loss = 1.4373
# epoch 46 / 50, step 16/28, loss = 1.5613
# epoch 46 / 50, step 17/28, loss = 1.5747
# epoch 46 / 50, step 18/28, loss = 1.6079
# epoch 46 / 50, step 19/28, loss = 1.7352
# epoch 46 / 50, step 20/28, loss = 1.5415
# epoch 46 / 50, step 21/28, loss = 1.6258
# epoch 46 / 50, step 22/28, loss = 1.3531
# epoch 46 / 50, step 23/28, loss = 1.5945
# epoch 46 / 50, step 24/28, loss = 1.4878
# epoch 46 / 50, step 25/28, loss = 1.4036
# epoch 46 / 50, step 26/28, loss = 1.5269
# epoch 46 / 50, step 27/28, loss = 1.4869
# epoch 46 / 50, step 28/28, loss = 1.5083
# epoch 46 / 50, step 1/7, loss = 1.6986
# epoch 46 / 50, step 2/7, loss = 2.0260
# epoch 46 / 50, step 3/7, loss = 1.6136
# epoch 46 / 50, step 4/7, loss = 1.8810
# epoch 46 / 50, step 5/7, loss = 1.9723
# epoch 46 / 50, step 6/7, loss = 1.4788
# epoch 46 / 50, step 7/7, loss = 1.7972
# epoch 47 / 50, step 1/28, loss = 1.8543
# epoch 47 / 50, step 2/28, loss = 1.4679
# epoch 47 / 50, step 3/28, loss = 1.3588
# epoch 47 / 50, step 4/28, loss = 1.3612
# epoch 47 / 50, step 5/28, loss = 1.5603
# epoch 47 / 50, step 6/28, loss = 1.5624
# epoch 47 / 50, step 7/28, loss = 1.4436
# epoch 47 / 50, step 8/28, loss = 1.3635
# epoch 47 / 50, step 9/28, loss = 1.4201
# epoch 47 / 50, step 10/28, loss = 1.4616
# epoch 47 / 50, step 11/28, loss = 1.3891
# epoch 47 / 50, step 12/28, loss = 1.4360
# epoch 47 / 50, step 13/28, loss = 1.5049
# epoch 47 / 50, step 14/28, loss = 1.5118
# epoch 47 / 50, step 15/28, loss = 1.5145
# epoch 47 / 50, step 16/28, loss = 1.4167
# epoch 47 / 50, step 17/28, loss = 1.2710
# epoch 47 / 50, step 18/28, loss = 1.3299
# epoch 47 / 50, step 19/28, loss = 1.4615
# epoch 47 / 50, step 20/28, loss = 1.4528
# epoch 47 / 50, step 21/28, loss = 1.1793
# epoch 47 / 50, step 22/28, loss = 1.2637
# epoch 47 / 50, step 23/28, loss = 1.6056
# epoch 47 / 50, step 24/28, loss = 1.3119
# epoch 47 / 50, step 25/28, loss = 1.6673
# epoch 47 / 50, step 26/28, loss = 1.7481
# epoch 47 / 50, step 27/28, loss = 1.4328
# epoch 47 / 50, step 28/28, loss = 1.3548
# epoch 47 / 50, step 1/7, loss = 1.4689
# epoch 47 / 50, step 2/7, loss = 1.8245
# epoch 47 / 50, step 3/7, loss = 1.4899
# epoch 47 / 50, step 4/7, loss = 1.5940
# epoch 47 / 50, step 5/7, loss = 1.6975
# epoch 47 / 50, step 6/7, loss = 1.4922
# epoch 47 / 50, step 7/7, loss = 1.7275
# epoch 48 / 50, step 1/28, loss = 1.4254
# epoch 48 / 50, step 2/28, loss = 1.5704
# epoch 48 / 50, step 3/28, loss = 1.6329
# epoch 48 / 50, step 4/28, loss = 1.3955
# epoch 48 / 50, step 5/28, loss = 1.4619
# epoch 48 / 50, step 6/28, loss = 1.2720
# epoch 48 / 50, step 7/28, loss = 1.3118
# epoch 48 / 50, step 8/28, loss = 1.4752
# epoch 48 / 50, step 9/28, loss = 1.3029
# epoch 48 / 50, step 10/28, loss = 1.4500
# epoch 48 / 50, step 11/28, loss = 1.4334
# epoch 48 / 50, step 12/28, loss = 1.5985
# epoch 48 / 50, step 13/28, loss = 1.4897
# epoch 48 / 50, step 14/28, loss = 1.9337
# epoch 48 / 50, step 15/28, loss = 1.3963
# epoch 48 / 50, step 16/28, loss = 1.7224
# epoch 48 / 50, step 17/28, loss = 1.6355
# epoch 48 / 50, step 18/28, loss = 1.4149
# epoch 48 / 50, step 19/28, loss = 1.6465
# epoch 48 / 50, step 20/28, loss = 1.5596
# epoch 48 / 50, step 21/28, loss = 1.6894
# epoch 48 / 50, step 22/28, loss = 1.5741
# epoch 48 / 50, step 23/28, loss = 1.6098
# epoch 48 / 50, step 24/28, loss = 1.6312
# epoch 48 / 50, step 25/28, loss = 1.5256
# epoch 48 / 50, step 26/28, loss = 1.4670
# epoch 48 / 50, step 27/28, loss = 1.4956
# epoch 48 / 50, step 28/28, loss = 1.2898
# epoch 48 / 50, step 1/7, loss = 1.3924
# epoch 48 / 50, step 2/7, loss = 1.9047
# epoch 48 / 50, step 3/7, loss = 1.6413
# epoch 48 / 50, step 4/7, loss = 1.5666
# epoch 48 / 50, step 5/7, loss = 1.6774
# epoch 48 / 50, step 6/7, loss = 1.5786
# epoch 48 / 50, step 7/7, loss = 1.6946
# epoch 49 / 50, step 1/28, loss = 1.6177
# epoch 49 / 50, step 2/28, loss = 1.4269
# epoch 49 / 50, step 3/28, loss = 1.5440
# epoch 49 / 50, step 4/28, loss = 1.3996
# epoch 49 / 50, step 5/28, loss = 1.4470
# epoch 49 / 50, step 6/28, loss = 1.2702
# epoch 49 / 50, step 7/28, loss = 1.6651
# epoch 49 / 50, step 8/28, loss = 1.4565
# epoch 49 / 50, step 9/28, loss = 1.1906
# epoch 49 / 50, step 10/28, loss = 1.3815
# epoch 49 / 50, step 11/28, loss = 1.5605
# epoch 49 / 50, step 12/28, loss = 1.4370
# epoch 49 / 50, step 13/28, loss = 1.6334
# epoch 49 / 50, step 14/28, loss = 1.5188
# epoch 49 / 50, step 15/28, loss = 1.4390
# epoch 49 / 50, step 16/28, loss = 1.5728
# epoch 49 / 50, step 17/28, loss = 1.3601
# epoch 49 / 50, step 18/28, loss = 1.6543
# epoch 49 / 50, step 19/28, loss = 1.5937
# epoch 49 / 50, step 20/28, loss = 1.5121
# epoch 49 / 50, step 21/28, loss = 1.4618
# epoch 49 / 50, step 22/28, loss = 1.3248
# epoch 49 / 50, step 23/28, loss = 1.6466
# epoch 49 / 50, step 24/28, loss = 1.2908
# epoch 49 / 50, step 25/28, loss = 1.4577
# epoch 49 / 50, step 26/28, loss = 1.5091
# epoch 49 / 50, step 27/28, loss = 1.4900
# epoch 49 / 50, step 28/28, loss = 1.5895
# epoch 49 / 50, step 1/7, loss = 1.5615
# epoch 49 / 50, step 2/7, loss = 1.8113
# epoch 49 / 50, step 3/7, loss = 1.3156
# epoch 49 / 50, step 4/7, loss = 1.6961
# epoch 49 / 50, step 5/7, loss = 1.5533
# epoch 49 / 50, step 6/7, loss = 1.4954
# epoch 49 / 50, step 7/7, loss = 1.7207
# epoch 50 / 50, step 1/28, loss = 1.4476
# epoch 50 / 50, step 2/28, loss = 1.5245
# epoch 50 / 50, step 3/28, loss = 1.2846
# epoch 50 / 50, step 4/28, loss = 1.3440
# epoch 50 / 50, step 5/28, loss = 1.3258
# epoch 50 / 50, step 6/28, loss = 1.2952
# epoch 50 / 50, step 7/28, loss = 1.4266
# epoch 50 / 50, step 8/28, loss = 1.5982
# epoch 50 / 50, step 9/28, loss = 1.2324
# epoch 50 / 50, step 10/28, loss = 1.6329
# epoch 50 / 50, step 11/28, loss = 1.2091
# epoch 50 / 50, step 12/28, loss = 1.1835
# epoch 50 / 50, step 13/28, loss = 1.5954
# epoch 50 / 50, step 14/28, loss = 1.2041
# epoch 50 / 50, step 15/28, loss = 1.2456
# epoch 50 / 50, step 16/28, loss = 1.3391
# epoch 50 / 50, step 17/28, loss = 1.4081
# epoch 50 / 50, step 18/28, loss = 1.0257
# epoch 50 / 50, step 19/28, loss = 1.2648
# epoch 50 / 50, step 20/28, loss = 1.4872
# epoch 50 / 50, step 21/28, loss = 1.2546
# epoch 50 / 50, step 22/28, loss = 1.5886
# epoch 50 / 50, step 23/28, loss = 1.5465
# epoch 50 / 50, step 24/28, loss = 1.3396
# epoch 50 / 50, step 25/28, loss = 1.6162
# epoch 50 / 50, step 26/28, loss = 1.3056
# epoch 50 / 50, step 27/28, loss = 1.4911
# epoch 50 / 50, step 28/28, loss = 0.8688
# epoch 50 / 50, step 1/7, loss = 1.5459
# epoch 50 / 50, step 2/7, loss = 1.6560
# epoch 50 / 50, step 3/7, loss = 1.4534
# epoch 50 / 50, step 4/7, loss = 1.5791
# epoch 50 / 50, step 5/7, loss = 1.6382
# epoch 50 / 50, step 6/7, loss = 1.5058
# epoch 50 / 50, step 7/7, loss = 1.7095

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 49.48571428571429 and the test accuaracy is 34.70319634703196
#  the maximum accuracy of the test was 41.0958904109589 at the epoch 46
#  the maximum accuracy of the train was 49.48571428571429 at the epoch 49
# the accuracy of the training at the best validation accuracy 41.0958904109589 is 48.34285714285714

# %%
# Copy the 
shutil.copyfile('./lstm.ipynb', './' + results_dir + 'lstm_copy.ipynb')
# Out:
# './David/Tests/12/lstm_copy.ipynb'
