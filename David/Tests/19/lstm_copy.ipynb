# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Increase learning rate to 0.0001%
# - Increase batch size to 32
# - Decrease epochs to 250

# %%
filepath = 'David/Tests/19'
script_dir = os.path.dirname('lstm.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs

# Turns negative values to 0
X[X < 0] = 0

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
"""
def find_longest_important_section(data, threshold, exclude_first_n=20000):
    longest_section_length = 0
    longest_section_index = -1
    sections = []

    for i, row in enumerate(data):
        # Exclude the first `exclude_first_n` samples by slicing the row
        valid_indices = np.arange(exclude_first_n, len(row))
        valid_row = row[exclude_first_n:]  # Data after the exclusion point
        
        # Find indices where the data exceeds the threshold
        indices = np.where(valid_row > threshold)[0]

        if len(indices) > 0:
            # Adjust the indices to account for the exclusion offset
            start, end = indices[0] + exclude_first_n, indices[-1] + exclude_first_n
            section_length = end - start + 1
            
            # Save the section length and check if it's the longest
            sections.append((start, end, section_length))
            if section_length > longest_section_length:
                longest_section_length = section_length
                longest_section_index = i
        else:
            # No important section found
            sections.append((None, None, 0))
    
    return longest_section_index, longest_section_length, sections

threshold = 30000

# Find the longest important section
longest_index, longest_length, all_sections = find_longest_important_section(X, threshold)


print(f"Time series with the longest important section: {longest_index}")
print(f"Length of the longest important section: {longest_length}")
"""
# Out:
# '\ndef find_longest_important_section(data, threshold, exclude_first_n=20000):\n    longest_section_length = 0\n    longest_section_index = -1\n    sections = []\n\n    for i, row in enumerate(data):\n        # Exclude the first `exclude_first_n` samples by slicing the row\n        valid_indices = np.arange(exclude_first_n, len(row))\n        valid_row = row[exclude_first_n:]  # Data after the exclusion point\n        \n        # Find indices where the data exceeds the threshold\n        indices = np.where(valid_row > threshold)[0]\n\n        if len(indices) > 0:\n            # Adjust the indices to account for the exclusion offset\n            start, end = indices[0] + exclude_first_n, indices[-1] + exclude_first_n\n            section_length = end - start + 1\n            \n            # Save the section length and check if it\'s the longest\n            sections.append((start, end, section_length))\n            if section_length > longest_section_length:\n                longest_section_length = section_length\n                longest_section_index = i\n        else:\n            # No important section found\n            sections.append((None, None, 0))\n    \n    return longest_section_index, longest_section_length, sections\n\nthreshold = 30000\n\n# Find the longest important section\nlongest_index, longest_length, all_sections = find_longest_important_section(X, threshold)\n\n\nprint(f"Time series with the longest important section: {longest_index}")\nprint(f"Length of the longest important section: {longest_length}")\n'

# %%
"""
def cut_and_pad_time_series(data, threshold, longest_section_length):
    processed_data = []

    for i, row in enumerate(data):
        # Find the first index where the data exceeds the threshold
        indices = np.where(row > threshold)[0]
        
        if len(indices) > 0:
            start = indices[0]
            # Cut the data starting from 'start'
            important_section = row[start:start + longest_section_length]
        else:
            # If no values exceed the threshold, use an empty array
            print(f'No values exceed the threshold. Index {i}')
            important_section = np.array([])
        
        # Pad with zeros if the section is shorter than the longest_section_length
        if len(important_section) < longest_section_length:
            important_section = np.pad(
                important_section, 
                (0, longest_section_length - len(important_section)), 
                mode='constant'
            )
        
        processed_data.append(important_section)
    
    return np.array(processed_data)

# Cut and pad the time series
processed_data = cut_and_pad_time_series(X, threshold, longest_length)

print("Processed Data:")
print(processed_data)
"""
# Out:
# '\ndef cut_and_pad_time_series(data, threshold, longest_section_length):\n    processed_data = []\n\n    for i, row in enumerate(data):\n        # Find the first index where the data exceeds the threshold\n        indices = np.where(row > threshold)[0]\n        \n        if len(indices) > 0:\n            start = indices[0]\n            # Cut the data starting from \'start\'\n            important_section = row[start:start + longest_section_length]\n        else:\n            # If no values exceed the threshold, use an empty array\n            print(f\'No values exceed the threshold. Index {i}\')\n            important_section = np.array([])\n        \n        # Pad with zeros if the section is shorter than the longest_section_length\n        if len(important_section) < longest_section_length:\n            important_section = np.pad(\n                important_section, \n                (0, longest_section_length - len(important_section)), \n                mode=\'constant\'\n            )\n        \n        processed_data.append(important_section)\n    \n    return np.array(processed_data)\n\n# Cut and pad the time series\nprocessed_data = cut_and_pad_time_series(X, threshold, longest_length)\n\nprint("Processed Data:")\nprint(processed_data)\n'

# %%
"""
# Plot the section
plt.figure()
plt.plot(processed_data[longest_index], label='Important Section (Cut and Padded)', color='blue')
plt.axhline(y=threshold, color='red', linestyle='--', label='Threshold')
plt.title(f'Longest Important Section of Time Series {longest_index}')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()
"""
# Out:
# "\n# Plot the section\nplt.figure()\nplt.plot(processed_data[longest_index], label='Important Section (Cut and Padded)', color='blue')\nplt.axhline(y=threshold, color='red', linestyle='--', label='Threshold')\nplt.title(f'Longest Important Section of Time Series {longest_index}')\nplt.xlabel('Time')\nplt.ylabel('Amplitude')\nplt.legend()\nplt.grid(True)\nplt.show()\n"

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 512
num_classes = 7
num_epochs = 250
batch_size = 32
learning_rate = 0.0001
num_layers = 2

input_size = 751  
sequence_length = 1024   
#input_size = 4 
#sequence_length = 28

# %%
# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([32, 769024]) , Labels shape: torch.Size([32])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6, 5, 6, 6, 3, 2, 3, 4, 3,
#         0, 4, 2, 5, 3, 6, 2, 1])

# %%
# Create Model

# Model 
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        # x -> (batch_size, seq, input_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(p=0.5)  # Inside LSTM clas

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0,c0))

        # Dropout on output of LSTM
        out = self.dropout(out)

        # out: batch_size, seq_length, hidden_size
        # out (N, 6008, 128)
        # : all samples in batch, -1 last time step, : all features in hidden size

        out = out[:, -1, :] 
        
        # out (N, 128)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(751, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 8,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 250, step 1/28, loss = 1.9474
# epoch 1 / 250, step 2/28, loss = 1.9588
# epoch 1 / 250, step 3/28, loss = 1.9544
# epoch 1 / 250, step 4/28, loss = 1.9635
# epoch 1 / 250, step 5/28, loss = 1.9489
# epoch 1 / 250, step 6/28, loss = 1.9514
# epoch 1 / 250, step 7/28, loss = 1.9557
# epoch 1 / 250, step 8/28, loss = 1.9470
# epoch 1 / 250, step 9/28, loss = 1.9461
# epoch 1 / 250, step 10/28, loss = 1.9464
# epoch 1 / 250, step 11/28, loss = 1.9469
# epoch 1 / 250, step 12/28, loss = 1.9585
# epoch 1 / 250, step 13/28, loss = 1.9520
# epoch 1 / 250, step 14/28, loss = 1.9232
# epoch 1 / 250, step 15/28, loss = 1.9448
# epoch 1 / 250, step 16/28, loss = 1.9407
# epoch 1 / 250, step 17/28, loss = 1.9449
# epoch 1 / 250, step 18/28, loss = 1.9349
# epoch 1 / 250, step 19/28, loss = 1.9452
# epoch 1 / 250, step 20/28, loss = 1.9313
# epoch 1 / 250, step 21/28, loss = 1.9484
# epoch 1 / 250, step 22/28, loss = 1.9693
# epoch 1 / 250, step 23/28, loss = 1.9623
# epoch 1 / 250, step 24/28, loss = 1.9199
# epoch 1 / 250, step 25/28, loss = 1.9245
# epoch 1 / 250, step 26/28, loss = 1.9263
# epoch 1 / 250, step 27/28, loss = 1.9320
# epoch 1 / 250, step 28/28, loss = 1.9758
# epoch 1 / 250, step 1/7, loss = 1.9392
# epoch 1 / 250, step 2/7, loss = 1.9612
# epoch 1 / 250, step 3/7, loss = 1.9002
# epoch 1 / 250, step 4/7, loss = 1.9367
# epoch 1 / 250, step 5/7, loss = 1.9545
# epoch 1 / 250, step 6/7, loss = 1.9394
# epoch 1 / 250, step 7/7, loss = 1.9374
# epoch 2 / 250, step 1/28, loss = 1.9225
# epoch 2 / 250, step 2/28, loss = 1.9420
# epoch 2 / 250, step 3/28, loss = 1.9325
# epoch 2 / 250, step 4/28, loss = 1.8953
# epoch 2 / 250, step 5/28, loss = 1.9100
# epoch 2 / 250, step 6/28, loss = 1.9431
# epoch 2 / 250, step 7/28, loss = 1.9116
# epoch 2 / 250, step 8/28, loss = 1.9508
# epoch 2 / 250, step 9/28, loss = 1.9147
# epoch 2 / 250, step 10/28, loss = 1.9101
# epoch 2 / 250, step 11/28, loss = 1.9244
# epoch 2 / 250, step 12/28, loss = 1.8990
# epoch 2 / 250, step 13/28, loss = 1.8677
# epoch 2 / 250, step 14/28, loss = 1.9056
# epoch 2 / 250, step 15/28, loss = 1.9259
# epoch 2 / 250, step 16/28, loss = 1.9605
# epoch 2 / 250, step 17/28, loss = 1.8974
# epoch 2 / 250, step 18/28, loss = 1.9274
# epoch 2 / 250, step 19/28, loss = 1.9248
# epoch 2 / 250, step 20/28, loss = 1.9291
# epoch 2 / 250, step 21/28, loss = 1.9098
# epoch 2 / 250, step 22/28, loss = 1.9296
# epoch 2 / 250, step 23/28, loss = 1.9092
# epoch 2 / 250, step 24/28, loss = 1.9627
# epoch 2 / 250, step 25/28, loss = 1.9535
# epoch 2 / 250, step 26/28, loss = 1.9462
# epoch 2 / 250, step 27/28, loss = 1.8941
# epoch 2 / 250, step 28/28, loss = 1.9981
# epoch 2 / 250, step 1/7, loss = 1.9374
# epoch 2 / 250, step 2/7, loss = 1.9914
# epoch 2 / 250, step 3/7, loss = 1.8799
# epoch 2 / 250, step 4/7, loss = 1.9301
# epoch 2 / 250, step 5/7, loss = 1.9804
# epoch 2 / 250, step 6/7, loss = 1.9259
# epoch 2 / 250, step 7/7, loss = 1.9294
# epoch 3 / 250, step 1/28, loss = 1.8948
# epoch 3 / 250, step 2/28, loss = 1.9254
# epoch 3 / 250, step 3/28, loss = 1.8762
# epoch 3 / 250, step 4/28, loss = 1.9419
# epoch 3 / 250, step 5/28, loss = 1.9267
# epoch 3 / 250, step 6/28, loss = 1.9054
# epoch 3 / 250, step 7/28, loss = 2.0158
# epoch 3 / 250, step 8/28, loss = 1.8922
# epoch 3 / 250, step 9/28, loss = 1.9218
# epoch 3 / 250, step 10/28, loss = 1.9192
# epoch 3 / 250, step 11/28, loss = 1.8733
# epoch 3 / 250, step 12/28, loss = 1.8643
# epoch 3 / 250, step 13/28, loss = 1.9559
# epoch 3 / 250, step 14/28, loss = 1.9125
# epoch 3 / 250, step 15/28, loss = 1.8944
# epoch 3 / 250, step 16/28, loss = 1.9071
# epoch 3 / 250, step 17/28, loss = 1.9164
# epoch 3 / 250, step 18/28, loss = 1.9416
# epoch 3 / 250, step 19/28, loss = 1.8635
# epoch 3 / 250, step 20/28, loss = 1.8727
# epoch 3 / 250, step 21/28, loss = 1.9014
# epoch 3 / 250, step 22/28, loss = 1.9063
# epoch 3 / 250, step 23/28, loss = 1.9105
# epoch 3 / 250, step 24/28, loss = 1.9329
# epoch 3 / 250, step 25/28, loss = 1.9675
# epoch 3 / 250, step 26/28, loss = 1.8959
# epoch 3 / 250, step 27/28, loss = 1.9781
# epoch 3 / 250, step 28/28, loss = 1.8420
# epoch 3 / 250, step 1/7, loss = 1.9328
# epoch 3 / 250, step 2/7, loss = 1.9862
# epoch 3 / 250, step 3/7, loss = 1.8779
# epoch 3 / 250, step 4/7, loss = 1.9284
# epoch 3 / 250, step 5/7, loss = 1.9733
# epoch 3 / 250, step 6/7, loss = 1.9409
# epoch 3 / 250, step 7/7, loss = 1.9375
# epoch 4 / 250, step 1/28, loss = 1.8599
# epoch 4 / 250, step 2/28, loss = 1.8793
# epoch 4 / 250, step 3/28, loss = 1.9040
# epoch 4 / 250, step 4/28, loss = 1.9184
# epoch 4 / 250, step 5/28, loss = 1.8569
# epoch 4 / 250, step 6/28, loss = 1.8398
# epoch 4 / 250, step 7/28, loss = 1.9230
# epoch 4 / 250, step 8/28, loss = 1.9424
# epoch 4 / 250, step 9/28, loss = 1.8465
# epoch 4 / 250, step 10/28, loss = 1.9040
# epoch 4 / 250, step 11/28, loss = 1.9035
# epoch 4 / 250, step 12/28, loss = 1.9285
# epoch 4 / 250, step 13/28, loss = 1.8969
# epoch 4 / 250, step 14/28, loss = 1.8375
# epoch 4 / 250, step 15/28, loss = 1.9687
# epoch 4 / 250, step 16/28, loss = 1.9689
# epoch 4 / 250, step 17/28, loss = 1.9261
# epoch 4 / 250, step 18/28, loss = 1.9062
# epoch 4 / 250, step 19/28, loss = 1.8366
# epoch 4 / 250, step 20/28, loss = 1.9103
# epoch 4 / 250, step 21/28, loss = 1.9395
# epoch 4 / 250, step 22/28, loss = 1.9280
# epoch 4 / 250, step 23/28, loss = 1.8948
# epoch 4 / 250, step 24/28, loss = 1.9448
# epoch 4 / 250, step 25/28, loss = 1.9391
# epoch 4 / 250, step 26/28, loss = 1.8522
# epoch 4 / 250, step 27/28, loss = 1.9238
# epoch 4 / 250, step 28/28, loss = 1.9452
# epoch 4 / 250, step 1/7, loss = 1.9302
# epoch 4 / 250, step 2/7, loss = 2.0011
# epoch 4 / 250, step 3/7, loss = 1.8716
# epoch 4 / 250, step 4/7, loss = 1.9258
# epoch 4 / 250, step 5/7, loss = 1.9763
# epoch 4 / 250, step 6/7, loss = 1.9260
# epoch 4 / 250, step 7/7, loss = 1.9412
# epoch 5 / 250, step 1/28, loss = 1.8859
# epoch 5 / 250, step 2/28, loss = 1.8911
# epoch 5 / 250, step 3/28, loss = 1.8892
# epoch 5 / 250, step 4/28, loss = 1.8938
# epoch 5 / 250, step 5/28, loss = 1.9438
# epoch 5 / 250, step 6/28, loss = 1.8515
# epoch 5 / 250, step 7/28, loss = 1.8874
# epoch 5 / 250, step 8/28, loss = 1.9278
# epoch 5 / 250, step 9/28, loss = 1.9510
# epoch 5 / 250, step 10/28, loss = 1.8824
# epoch 5 / 250, step 11/28, loss = 1.9083
# epoch 5 / 250, step 12/28, loss = 1.8922
# epoch 5 / 250, step 13/28, loss = 1.8945
# epoch 5 / 250, step 14/28, loss = 1.9327
# epoch 5 / 250, step 15/28, loss = 1.8594
# epoch 5 / 250, step 16/28, loss = 1.9025
# epoch 5 / 250, step 17/28, loss = 1.9234
# epoch 5 / 250, step 18/28, loss = 1.9322
# epoch 5 / 250, step 19/28, loss = 1.8932
# epoch 5 / 250, step 20/28, loss = 1.9382
# epoch 5 / 250, step 21/28, loss = 1.9172
# epoch 5 / 250, step 22/28, loss = 1.9144
# epoch 5 / 250, step 23/28, loss = 1.9129
# epoch 5 / 250, step 24/28, loss = 1.8809
# epoch 5 / 250, step 25/28, loss = 1.8549
# epoch 5 / 250, step 26/28, loss = 1.8922
# epoch 5 / 250, step 27/28, loss = 1.8644
# epoch 5 / 250, step 28/28, loss = 1.8347
# epoch 5 / 250, step 1/7, loss = 1.9329
# epoch 5 / 250, step 2/7, loss = 1.9763
# epoch 5 / 250, step 3/7, loss = 1.8840
# epoch 5 / 250, step 4/7, loss = 1.9262
# epoch 5 / 250, step 5/7, loss = 1.9674
# epoch 5 / 250, step 6/7, loss = 1.9224
# epoch 5 / 250, step 7/7, loss = 1.9402
# epoch 6 / 250, step 1/28, loss = 1.8228
# epoch 6 / 250, step 2/28, loss = 1.8340
# epoch 6 / 250, step 3/28, loss = 1.8724
# epoch 6 / 250, step 4/28, loss = 1.9072
# epoch 6 / 250, step 5/28, loss = 1.9280
# epoch 6 / 250, step 6/28, loss = 1.9004
# epoch 6 / 250, step 7/28, loss = 1.8250
# epoch 6 / 250, step 8/28, loss = 1.8809
# epoch 6 / 250, step 9/28, loss = 1.8633
# epoch 6 / 250, step 10/28, loss = 1.9395
# epoch 6 / 250, step 11/28, loss = 1.9053
# epoch 6 / 250, step 12/28, loss = 1.8631
# epoch 6 / 250, step 13/28, loss = 1.9308
# epoch 6 / 250, step 14/28, loss = 1.9312
# epoch 6 / 250, step 15/28, loss = 1.8996
# epoch 6 / 250, step 16/28, loss = 1.8663
# epoch 6 / 250, step 17/28, loss = 1.9277
# epoch 6 / 250, step 18/28, loss = 1.8677
# epoch 6 / 250, step 19/28, loss = 1.8140
# epoch 6 / 250, step 20/28, loss = 1.8989
# epoch 6 / 250, step 21/28, loss = 1.8838
# epoch 6 / 250, step 22/28, loss = 1.8993
# epoch 6 / 250, step 23/28, loss = 1.9027
# epoch 6 / 250, step 24/28, loss = 1.8531
# epoch 6 / 250, step 25/28, loss = 1.9024
# epoch 6 / 250, step 26/28, loss = 1.9356
# epoch 6 / 250, step 27/28, loss = 1.9471
# epoch 6 / 250, step 28/28, loss = 1.8960
# epoch 6 / 250, step 1/7, loss = 1.9425
# epoch 6 / 250, step 2/7, loss = 1.9745
# epoch 6 / 250, step 3/7, loss = 1.8756
# epoch 6 / 250, step 4/7, loss = 1.9294
# epoch 6 / 250, step 5/7, loss = 1.9625
# epoch 6 / 250, step 6/7, loss = 1.9217
# epoch 6 / 250, step 7/7, loss = 1.9380
# epoch 7 / 250, step 1/28, loss = 1.7769
# epoch 7 / 250, step 2/28, loss = 1.8978
# epoch 7 / 250, step 3/28, loss = 1.9185
# epoch 7 / 250, step 4/28, loss = 1.9047
# epoch 7 / 250, step 5/28, loss = 1.8103
# epoch 7 / 250, step 6/28, loss = 1.8424
# epoch 7 / 250, step 7/28, loss = 1.8908
# epoch 7 / 250, step 8/28, loss = 1.8673
# epoch 7 / 250, step 9/28, loss = 1.8552
# epoch 7 / 250, step 10/28, loss = 1.8609
# epoch 7 / 250, step 11/28, loss = 1.8259
# epoch 7 / 250, step 12/28, loss = 1.8624
# epoch 7 / 250, step 13/28, loss = 1.7969
# epoch 7 / 250, step 14/28, loss = 1.8708
# epoch 7 / 250, step 15/28, loss = 1.9159
# epoch 7 / 250, step 16/28, loss = 1.8511
# epoch 7 / 250, step 17/28, loss = 1.8934
# epoch 7 / 250, step 18/28, loss = 1.9225
# epoch 7 / 250, step 19/28, loss = 1.9440
# epoch 7 / 250, step 20/28, loss = 1.8981
# epoch 7 / 250, step 21/28, loss = 1.9474
# epoch 7 / 250, step 22/28, loss = 1.8861
# epoch 7 / 250, step 23/28, loss = 1.8717
# epoch 7 / 250, step 24/28, loss = 1.9446
# epoch 7 / 250, step 25/28, loss = 1.8341
# epoch 7 / 250, step 26/28, loss = 1.9193
# epoch 7 / 250, step 27/28, loss = 1.8740
# epoch 7 / 250, step 28/28, loss = 1.8982
# epoch 7 / 250, step 1/7, loss = 1.9428
# epoch 7 / 250, step 2/7, loss = 1.9879
# epoch 7 / 250, step 3/7, loss = 1.8590
# epoch 7 / 250, step 4/7, loss = 1.9233
# epoch 7 / 250, step 5/7, loss = 1.9689
# epoch 7 / 250, step 6/7, loss = 1.9116
# epoch 7 / 250, step 7/7, loss = 1.9262
# epoch 8 / 250, step 1/28, loss = 1.8362
# epoch 8 / 250, step 2/28, loss = 1.8686
# epoch 8 / 250, step 3/28, loss = 1.9173
# epoch 8 / 250, step 4/28, loss = 1.8539
# epoch 8 / 250, step 5/28, loss = 1.9161
# epoch 8 / 250, step 6/28, loss = 1.8706
# epoch 8 / 250, step 7/28, loss = 1.8678
# epoch 8 / 250, step 8/28, loss = 1.8254
# epoch 8 / 250, step 9/28, loss = 1.8560
# epoch 8 / 250, step 10/28, loss = 1.8665
# epoch 8 / 250, step 11/28, loss = 1.8722
# epoch 8 / 250, step 12/28, loss = 1.8584
# epoch 8 / 250, step 13/28, loss = 1.8589
# epoch 8 / 250, step 14/28, loss = 1.8464
# epoch 8 / 250, step 15/28, loss = 1.8227
# epoch 8 / 250, step 16/28, loss = 1.8119
# epoch 8 / 250, step 17/28, loss = 1.8877
# epoch 8 / 250, step 18/28, loss = 1.8697
# epoch 8 / 250, step 19/28, loss = 1.8762
# epoch 8 / 250, step 20/28, loss = 1.8845
# epoch 8 / 250, step 21/28, loss = 1.9070
# epoch 8 / 250, step 22/28, loss = 1.7721
# epoch 8 / 250, step 23/28, loss = 1.8805
# epoch 8 / 250, step 24/28, loss = 1.9265
# epoch 8 / 250, step 25/28, loss = 1.8737
# epoch 8 / 250, step 26/28, loss = 1.8618
# epoch 8 / 250, step 27/28, loss = 1.8661
# epoch 8 / 250, step 28/28, loss = 1.8108
# epoch 8 / 250, step 1/7, loss = 1.9313
# epoch 8 / 250, step 2/7, loss = 2.0026
# epoch 8 / 250, step 3/7, loss = 1.8395
# epoch 8 / 250, step 4/7, loss = 1.9141
# epoch 8 / 250, step 5/7, loss = 1.9615
# epoch 8 / 250, step 6/7, loss = 1.9107
# epoch 8 / 250, step 7/7, loss = 1.9138
# epoch 9 / 250, step 1/28, loss = 1.8795
# epoch 9 / 250, step 2/28, loss = 1.8601
# epoch 9 / 250, step 3/28, loss = 1.8580
# epoch 9 / 250, step 4/28, loss = 1.9197
# epoch 9 / 250, step 5/28, loss = 1.7867
# epoch 9 / 250, step 6/28, loss = 1.8831
# epoch 9 / 250, step 7/28, loss = 1.8245
# epoch 9 / 250, step 8/28, loss = 1.8599
# epoch 9 / 250, step 9/28, loss = 1.8458
# epoch 9 / 250, step 10/28, loss = 1.8450
# epoch 9 / 250, step 11/28, loss = 1.8351
# epoch 9 / 250, step 12/28, loss = 1.8912
# epoch 9 / 250, step 13/28, loss = 1.8709
# epoch 9 / 250, step 14/28, loss = 1.8393
# epoch 9 / 250, step 15/28, loss = 1.7900
# epoch 9 / 250, step 16/28, loss = 1.8052
# epoch 9 / 250, step 17/28, loss = 1.8419
# epoch 9 / 250, step 18/28, loss = 1.8596
# epoch 9 / 250, step 19/28, loss = 1.8618
# epoch 9 / 250, step 20/28, loss = 1.7853
# epoch 9 / 250, step 21/28, loss = 1.8205
# epoch 9 / 250, step 22/28, loss = 1.7851
# epoch 9 / 250, step 23/28, loss = 1.8216
# epoch 9 / 250, step 24/28, loss = 1.8455
# epoch 9 / 250, step 25/28, loss = 1.8692
# epoch 9 / 250, step 26/28, loss = 1.8484
# epoch 9 / 250, step 27/28, loss = 1.9172
# epoch 9 / 250, step 28/28, loss = 1.8200
# epoch 9 / 250, step 1/7, loss = 1.9506
# epoch 9 / 250, step 2/7, loss = 2.0007
# epoch 9 / 250, step 3/7, loss = 1.8264
# epoch 9 / 250, step 4/7, loss = 1.8968
# epoch 9 / 250, step 5/7, loss = 1.9998
# epoch 9 / 250, step 6/7, loss = 1.9009
# epoch 9 / 250, step 7/7, loss = 1.9211
# epoch 10 / 250, step 1/28, loss = 1.8142
# epoch 10 / 250, step 2/28, loss = 1.8646
# epoch 10 / 250, step 3/28, loss = 1.9315
# epoch 10 / 250, step 4/28, loss = 1.7658
# epoch 10 / 250, step 5/28, loss = 1.8620
# epoch 10 / 250, step 6/28, loss = 1.8930
# epoch 10 / 250, step 7/28, loss = 1.8307
# epoch 10 / 250, step 8/28, loss = 1.7929
# epoch 10 / 250, step 9/28, loss = 1.8556
# epoch 10 / 250, step 10/28, loss = 1.7459
# epoch 10 / 250, step 11/28, loss = 1.7628
# epoch 10 / 250, step 12/28, loss = 1.7506
# epoch 10 / 250, step 13/28, loss = 1.8143
# epoch 10 / 250, step 14/28, loss = 1.9576
# epoch 10 / 250, step 15/28, loss = 1.8183
# epoch 10 / 250, step 16/28, loss = 1.7736
# epoch 10 / 250, step 17/28, loss = 1.7692
# epoch 10 / 250, step 18/28, loss = 1.8483
# epoch 10 / 250, step 19/28, loss = 1.8571
# epoch 10 / 250, step 20/28, loss = 1.7887
# epoch 10 / 250, step 21/28, loss = 1.7987
# epoch 10 / 250, step 22/28, loss = 1.8320
# epoch 10 / 250, step 23/28, loss = 1.8065
# epoch 10 / 250, step 24/28, loss = 1.9012
# epoch 10 / 250, step 25/28, loss = 1.7019
# epoch 10 / 250, step 26/28, loss = 1.7460
# epoch 10 / 250, step 27/28, loss = 1.7796
# epoch 10 / 250, step 28/28, loss = 1.7334
# epoch 10 / 250, step 1/7, loss = 1.9275
# epoch 10 / 250, step 2/7, loss = 2.0631
# epoch 10 / 250, step 3/7, loss = 1.8439
# epoch 10 / 250, step 4/7, loss = 1.9411
# epoch 10 / 250, step 5/7, loss = 2.1985
# epoch 10 / 250, step 6/7, loss = 1.9675
# epoch 10 / 250, step 7/7, loss = 2.0043
# epoch 11 / 250, step 1/28, loss = 1.7383
# epoch 11 / 250, step 2/28, loss = 1.7507
# epoch 11 / 250, step 3/28, loss = 1.7787
# epoch 11 / 250, step 4/28, loss = 1.7541
# epoch 11 / 250, step 5/28, loss = 1.7214
# epoch 11 / 250, step 6/28, loss = 1.7080
# epoch 11 / 250, step 7/28, loss = 1.8735
# epoch 11 / 250, step 8/28, loss = 1.8078
# epoch 11 / 250, step 9/28, loss = 1.7960
# epoch 11 / 250, step 10/28, loss = 1.7760
# epoch 11 / 250, step 11/28, loss = 1.8119
# epoch 11 / 250, step 12/28, loss = 1.7916
# epoch 11 / 250, step 13/28, loss = 1.8010
# epoch 11 / 250, step 14/28, loss = 1.7617
# epoch 11 / 250, step 15/28, loss = 1.7916
# epoch 11 / 250, step 16/28, loss = 1.8245
# epoch 11 / 250, step 17/28, loss = 1.7925
# epoch 11 / 250, step 18/28, loss = 1.7928
# epoch 11 / 250, step 19/28, loss = 1.8378
# epoch 11 / 250, step 20/28, loss = 1.7742
# epoch 11 / 250, step 21/28, loss = 1.7925
# epoch 11 / 250, step 22/28, loss = 1.9830
# epoch 11 / 250, step 23/28, loss = 1.8562
# epoch 11 / 250, step 24/28, loss = 1.8385
# epoch 11 / 250, step 25/28, loss = 1.8518
# epoch 11 / 250, step 26/28, loss = 1.7534
# epoch 11 / 250, step 27/28, loss = 1.7222
# epoch 11 / 250, step 28/28, loss = 1.7847
# epoch 11 / 250, step 1/7, loss = 1.8782
# epoch 11 / 250, step 2/7, loss = 2.0026
# epoch 11 / 250, step 3/7, loss = 1.8015
# epoch 11 / 250, step 4/7, loss = 1.8781
# epoch 11 / 250, step 5/7, loss = 2.1202
# epoch 11 / 250, step 6/7, loss = 1.9254
# epoch 11 / 250, step 7/7, loss = 1.9002
# epoch 12 / 250, step 1/28, loss = 1.7370
# epoch 12 / 250, step 2/28, loss = 1.7147
# epoch 12 / 250, step 3/28, loss = 1.6323
# epoch 12 / 250, step 4/28, loss = 2.0011
# epoch 12 / 250, step 5/28, loss = 1.6427
# epoch 12 / 250, step 6/28, loss = 1.7151
# epoch 12 / 250, step 7/28, loss = 1.7850
# epoch 12 / 250, step 8/28, loss = 1.7725
# epoch 12 / 250, step 9/28, loss = 1.6860
# epoch 12 / 250, step 10/28, loss = 1.6858
# epoch 12 / 250, step 11/28, loss = 1.7214
# epoch 12 / 250, step 12/28, loss = 1.8449
# epoch 12 / 250, step 13/28, loss = 1.7572
# epoch 12 / 250, step 14/28, loss = 1.8189
# epoch 12 / 250, step 15/28, loss = 1.6339
# epoch 12 / 250, step 16/28, loss = 1.7429
# epoch 12 / 250, step 17/28, loss = 1.7609
# epoch 12 / 250, step 18/28, loss = 1.6309
# epoch 12 / 250, step 19/28, loss = 1.7196
# epoch 12 / 250, step 20/28, loss = 1.8024
# epoch 12 / 250, step 21/28, loss = 1.8128
# epoch 12 / 250, step 22/28, loss = 1.8564
# epoch 12 / 250, step 23/28, loss = 1.6977
# epoch 12 / 250, step 24/28, loss = 1.8092
# epoch 12 / 250, step 25/28, loss = 1.6554
# epoch 12 / 250, step 26/28, loss = 1.7747
# epoch 12 / 250, step 27/28, loss = 1.7431
# epoch 12 / 250, step 28/28, loss = 1.6969
# epoch 12 / 250, step 1/7, loss = 1.9000
# epoch 12 / 250, step 2/7, loss = 2.1296
# epoch 12 / 250, step 3/7, loss = 1.8478
# epoch 12 / 250, step 4/7, loss = 1.9864
# epoch 12 / 250, step 5/7, loss = 2.3414
# epoch 12 / 250, step 6/7, loss = 2.2316
# epoch 12 / 250, step 7/7, loss = 2.0625
# epoch 13 / 250, step 1/28, loss = 1.6596
# epoch 13 / 250, step 2/28, loss = 1.6283
# epoch 13 / 250, step 3/28, loss = 1.6867
# epoch 13 / 250, step 4/28, loss = 1.7634
# epoch 13 / 250, step 5/28, loss = 1.6975
# epoch 13 / 250, step 6/28, loss = 1.6213
# epoch 13 / 250, step 7/28, loss = 1.5960
# epoch 13 / 250, step 8/28, loss = 1.5743
# epoch 13 / 250, step 9/28, loss = 1.7280
# epoch 13 / 250, step 10/28, loss = 1.7287
# epoch 13 / 250, step 11/28, loss = 1.6567
# epoch 13 / 250, step 12/28, loss = 1.7899
# epoch 13 / 250, step 13/28, loss = 1.8205
# epoch 13 / 250, step 14/28, loss = 2.0057
# epoch 13 / 250, step 15/28, loss = 1.8020
# epoch 13 / 250, step 16/28, loss = 1.7775
# epoch 13 / 250, step 17/28, loss = 1.7805
# epoch 13 / 250, step 18/28, loss = 1.9025
# epoch 13 / 250, step 19/28, loss = 1.5721
# epoch 13 / 250, step 20/28, loss = 1.7083
# epoch 13 / 250, step 21/28, loss = 1.5314
# epoch 13 / 250, step 22/28, loss = 1.6036
# epoch 13 / 250, step 23/28, loss = 1.6046
# epoch 13 / 250, step 24/28, loss = 1.6205
# epoch 13 / 250, step 25/28, loss = 1.6218
# epoch 13 / 250, step 26/28, loss = 1.7459
# epoch 13 / 250, step 27/28, loss = 1.6744
# epoch 13 / 250, step 28/28, loss = 1.3304
# epoch 13 / 250, step 1/7, loss = 2.0103
# epoch 13 / 250, step 2/7, loss = 2.0478
# epoch 13 / 250, step 3/7, loss = 1.6862
# epoch 13 / 250, step 4/7, loss = 2.0105
# epoch 13 / 250, step 5/7, loss = 1.8293
# epoch 13 / 250, step 6/7, loss = 2.0603
# epoch 13 / 250, step 7/7, loss = 2.2921
# epoch 14 / 250, step 1/28, loss = 1.5814
# epoch 14 / 250, step 2/28, loss = 1.5784
# epoch 14 / 250, step 3/28, loss = 1.7348
# epoch 14 / 250, step 4/28, loss = 2.2486
# epoch 14 / 250, step 5/28, loss = 1.7781
# epoch 14 / 250, step 6/28, loss = 1.8324
# epoch 14 / 250, step 7/28, loss = 1.8545
# epoch 14 / 250, step 8/28, loss = 1.8881
# epoch 14 / 250, step 9/28, loss = 1.8348
# epoch 14 / 250, step 10/28, loss = 1.9647
# epoch 14 / 250, step 11/28, loss = 1.9606
# epoch 14 / 250, step 12/28, loss = 1.8936
# epoch 14 / 250, step 13/28, loss = 1.8491
# epoch 14 / 250, step 14/28, loss = 1.8870
# epoch 14 / 250, step 15/28, loss = 1.8301
# epoch 14 / 250, step 16/28, loss = 1.9039
# epoch 14 / 250, step 17/28, loss = 1.8359
# epoch 14 / 250, step 18/28, loss = 1.7367
# epoch 14 / 250, step 19/28, loss = 1.7917
# epoch 14 / 250, step 20/28, loss = 1.7957
# epoch 14 / 250, step 21/28, loss = 1.7479
# epoch 14 / 250, step 22/28, loss = 1.7740
# epoch 14 / 250, step 23/28, loss = 1.7476
# epoch 14 / 250, step 24/28, loss = 1.7751
# epoch 14 / 250, step 25/28, loss = 1.7539
# epoch 14 / 250, step 26/28, loss = 1.8270
# epoch 14 / 250, step 27/28, loss = 1.9012
# epoch 14 / 250, step 28/28, loss = 1.6953
# epoch 14 / 250, step 1/7, loss = 1.8671
# epoch 14 / 250, step 2/7, loss = 1.8889
# epoch 14 / 250, step 3/7, loss = 1.8157
# epoch 14 / 250, step 4/7, loss = 1.8472
# epoch 14 / 250, step 5/7, loss = 1.9060
# epoch 14 / 250, step 6/7, loss = 1.8236
# epoch 14 / 250, step 7/7, loss = 1.8845
# epoch 15 / 250, step 1/28, loss = 1.8172
# epoch 15 / 250, step 2/28, loss = 1.7963
# epoch 15 / 250, step 3/28, loss = 1.6861
# epoch 15 / 250, step 4/28, loss = 1.6712
# epoch 15 / 250, step 5/28, loss = 1.7007
# epoch 15 / 250, step 6/28, loss = 1.6547
# epoch 15 / 250, step 7/28, loss = 1.7632
# epoch 15 / 250, step 8/28, loss = 1.7385
# epoch 15 / 250, step 9/28, loss = 1.7250
# epoch 15 / 250, step 10/28, loss = 1.6393
# epoch 15 / 250, step 11/28, loss = 1.7791
# epoch 15 / 250, step 12/28, loss = 1.7011
# epoch 15 / 250, step 13/28, loss = 1.7842
# epoch 15 / 250, step 14/28, loss = 1.7159
# epoch 15 / 250, step 15/28, loss = 1.6959
# epoch 15 / 250, step 16/28, loss = 1.7628
# epoch 15 / 250, step 17/28, loss = 1.8296
# epoch 15 / 250, step 18/28, loss = 1.7612
# epoch 15 / 250, step 19/28, loss = 1.6198
# epoch 15 / 250, step 20/28, loss = 1.7535
# epoch 15 / 250, step 21/28, loss = 1.6224
# epoch 15 / 250, step 22/28, loss = 1.6396
# epoch 15 / 250, step 23/28, loss = 1.6783
# epoch 15 / 250, step 24/28, loss = 1.7146
# epoch 15 / 250, step 25/28, loss = 1.5576
# epoch 15 / 250, step 26/28, loss = 1.7486
# epoch 15 / 250, step 27/28, loss = 1.7134
# epoch 15 / 250, step 28/28, loss = 1.5482
# epoch 15 / 250, step 1/7, loss = 1.7142
# epoch 15 / 250, step 2/7, loss = 1.8060
# epoch 15 / 250, step 3/7, loss = 1.5953
# epoch 15 / 250, step 4/7, loss = 1.7284
# epoch 15 / 250, step 5/7, loss = 1.9479
# epoch 15 / 250, step 6/7, loss = 1.7770
# epoch 15 / 250, step 7/7, loss = 1.7915
# epoch 16 / 250, step 1/28, loss = 1.5353
# epoch 16 / 250, step 2/28, loss = 1.5372
# epoch 16 / 250, step 3/28, loss = 1.4253
# epoch 16 / 250, step 4/28, loss = 1.4936
# epoch 16 / 250, step 5/28, loss = 1.4227
# epoch 16 / 250, step 6/28, loss = 1.7134
# epoch 16 / 250, step 7/28, loss = 1.7027
# epoch 16 / 250, step 8/28, loss = 1.7230
# epoch 16 / 250, step 9/28, loss = 1.8444
# epoch 16 / 250, step 10/28, loss = 1.8833
# epoch 16 / 250, step 11/28, loss = 1.5980
# epoch 16 / 250, step 12/28, loss = 1.5519
# epoch 16 / 250, step 13/28, loss = 1.6463
# epoch 16 / 250, step 14/28, loss = 1.7318
# epoch 16 / 250, step 15/28, loss = 1.5484
# epoch 16 / 250, step 16/28, loss = 1.6436
# epoch 16 / 250, step 17/28, loss = 1.6205
# epoch 16 / 250, step 18/28, loss = 1.7914
# epoch 16 / 250, step 19/28, loss = 1.6452
# epoch 16 / 250, step 20/28, loss = 1.6944
# epoch 16 / 250, step 21/28, loss = 1.6411
# epoch 16 / 250, step 22/28, loss = 1.6875
# epoch 16 / 250, step 23/28, loss = 1.6407
# epoch 16 / 250, step 24/28, loss = 1.6770
# epoch 16 / 250, step 25/28, loss = 1.7273
# epoch 16 / 250, step 26/28, loss = 1.7859
# epoch 16 / 250, step 27/28, loss = 1.6085
# epoch 16 / 250, step 28/28, loss = 1.8309
# epoch 16 / 250, step 1/7, loss = 1.7336
# epoch 16 / 250, step 2/7, loss = 1.9235
# epoch 16 / 250, step 3/7, loss = 1.7146
# epoch 16 / 250, step 4/7, loss = 1.7938
# epoch 16 / 250, step 5/7, loss = 1.9261
# epoch 16 / 250, step 6/7, loss = 2.0068
# epoch 16 / 250, step 7/7, loss = 1.7916
# epoch 17 / 250, step 1/28, loss = 1.6072
# epoch 17 / 250, step 2/28, loss = 1.5538
# epoch 17 / 250, step 3/28, loss = 1.5295
# epoch 17 / 250, step 4/28, loss = 1.4739
# epoch 17 / 250, step 5/28, loss = 1.5607
# epoch 17 / 250, step 6/28, loss = 1.7430
# epoch 17 / 250, step 7/28, loss = 1.5841
# epoch 17 / 250, step 8/28, loss = 1.4025
# epoch 17 / 250, step 9/28, loss = 1.3449
# epoch 17 / 250, step 10/28, loss = 1.5728
# epoch 17 / 250, step 11/28, loss = 1.5159
# epoch 17 / 250, step 12/28, loss = 1.5902
# epoch 17 / 250, step 13/28, loss = 1.6500
# epoch 17 / 250, step 14/28, loss = 1.5455
# epoch 17 / 250, step 15/28, loss = 1.3684
# epoch 17 / 250, step 16/28, loss = 1.5687
# epoch 17 / 250, step 17/28, loss = 1.4960
# epoch 17 / 250, step 18/28, loss = 1.5570
# epoch 17 / 250, step 19/28, loss = 1.5237
# epoch 17 / 250, step 20/28, loss = 1.4122
# epoch 17 / 250, step 21/28, loss = 1.4383
# epoch 17 / 250, step 22/28, loss = 1.5342
# epoch 17 / 250, step 23/28, loss = 1.7470
# epoch 17 / 250, step 24/28, loss = 1.7152
# epoch 17 / 250, step 25/28, loss = 1.6823
# epoch 17 / 250, step 26/28, loss = 1.4638
# epoch 17 / 250, step 27/28, loss = 1.3817
# epoch 17 / 250, step 28/28, loss = 1.3563
# epoch 17 / 250, step 1/7, loss = 1.8001
# epoch 17 / 250, step 2/7, loss = 1.8155
# epoch 17 / 250, step 3/7, loss = 1.4879
# epoch 17 / 250, step 4/7, loss = 1.5733
# epoch 17 / 250, step 5/7, loss = 1.5329
# epoch 17 / 250, step 6/7, loss = 1.7305
# epoch 17 / 250, step 7/7, loss = 1.8016
# epoch 18 / 250, step 1/28, loss = 1.4932
# epoch 18 / 250, step 2/28, loss = 1.4997
# epoch 18 / 250, step 3/28, loss = 1.2070
# epoch 18 / 250, step 4/28, loss = 1.2194
# epoch 18 / 250, step 5/28, loss = 1.5334
# epoch 18 / 250, step 6/28, loss = 1.2624
# epoch 18 / 250, step 7/28, loss = 1.1901
# epoch 18 / 250, step 8/28, loss = 1.7061
# epoch 18 / 250, step 9/28, loss = 1.4963
# epoch 18 / 250, step 10/28, loss = 1.4808
# epoch 18 / 250, step 11/28, loss = 1.5188
# epoch 18 / 250, step 12/28, loss = 1.4946
# epoch 18 / 250, step 13/28, loss = 2.2012
# epoch 18 / 250, step 14/28, loss = 1.2874
# epoch 18 / 250, step 15/28, loss = 1.5302
# epoch 18 / 250, step 16/28, loss = 1.3922
# epoch 18 / 250, step 17/28, loss = 1.6928
# epoch 18 / 250, step 18/28, loss = 1.6176
# epoch 18 / 250, step 19/28, loss = 1.6647
# epoch 18 / 250, step 20/28, loss = 1.9362
# epoch 18 / 250, step 21/28, loss = 1.5498
# epoch 18 / 250, step 22/28, loss = 1.4819
# epoch 18 / 250, step 23/28, loss = 1.5926
# epoch 18 / 250, step 24/28, loss = 1.4237
# epoch 18 / 250, step 25/28, loss = 1.5350
# epoch 18 / 250, step 26/28, loss = 1.5495
# epoch 18 / 250, step 27/28, loss = 1.1022
# epoch 18 / 250, step 28/28, loss = 1.3104
# epoch 18 / 250, step 1/7, loss = 1.6102
# epoch 18 / 250, step 2/7, loss = 1.7969
# epoch 18 / 250, step 3/7, loss = 1.3582
# epoch 18 / 250, step 4/7, loss = 1.7319
# epoch 18 / 250, step 5/7, loss = 1.9618
# epoch 18 / 250, step 6/7, loss = 1.7956
# epoch 18 / 250, step 7/7, loss = 1.6508
# epoch 19 / 250, step 1/28, loss = 1.4432
# epoch 19 / 250, step 2/28, loss = 1.5109
# epoch 19 / 250, step 3/28, loss = 1.4881
# epoch 19 / 250, step 4/28, loss = 1.2552
# epoch 19 / 250, step 5/28, loss = 1.3752
# epoch 19 / 250, step 6/28, loss = 1.6065
# epoch 19 / 250, step 7/28, loss = 1.5637
# epoch 19 / 250, step 8/28, loss = 1.4439
# epoch 19 / 250, step 9/28, loss = 1.6446
# epoch 19 / 250, step 10/28, loss = 1.3988
# epoch 19 / 250, step 11/28, loss = 1.4995
# epoch 19 / 250, step 12/28, loss = 1.3299
# epoch 19 / 250, step 13/28, loss = 1.4120
# epoch 19 / 250, step 14/28, loss = 1.2939
# epoch 19 / 250, step 15/28, loss = 1.3451
# epoch 19 / 250, step 16/28, loss = 1.2342
# epoch 19 / 250, step 17/28, loss = 1.3874
# epoch 19 / 250, step 18/28, loss = 1.4162
# epoch 19 / 250, step 19/28, loss = 1.2804
# epoch 19 / 250, step 20/28, loss = 1.3972
# epoch 19 / 250, step 21/28, loss = 1.0987
# epoch 19 / 250, step 22/28, loss = 1.2079
# epoch 19 / 250, step 23/28, loss = 1.3927
# epoch 19 / 250, step 24/28, loss = 1.0912
# epoch 19 / 250, step 25/28, loss = 1.4507
# epoch 19 / 250, step 26/28, loss = 1.9219
# epoch 19 / 250, step 27/28, loss = 1.9274
# epoch 19 / 250, step 28/28, loss = 2.7276
# epoch 19 / 250, step 1/7, loss = 2.4443
# epoch 19 / 250, step 2/7, loss = 2.5864
# epoch 19 / 250, step 3/7, loss = 2.2620
# epoch 19 / 250, step 4/7, loss = 2.4865
# epoch 19 / 250, step 5/7, loss = 2.4443
# epoch 19 / 250, step 6/7, loss = 2.1524
# epoch 19 / 250, step 7/7, loss = 2.3078
# epoch 20 / 250, step 1/28, loss = 2.0979
# epoch 20 / 250, step 2/28, loss = 1.6972
# epoch 20 / 250, step 3/28, loss = 2.1322
# epoch 20 / 250, step 4/28, loss = 1.5527
# epoch 20 / 250, step 5/28, loss = 1.9476
# epoch 20 / 250, step 6/28, loss = 1.5718
# epoch 20 / 250, step 7/28, loss = 1.7132
# epoch 20 / 250, step 8/28, loss = 1.7923
# epoch 20 / 250, step 9/28, loss = 1.4983
# epoch 20 / 250, step 10/28, loss = 1.5930
# epoch 20 / 250, step 11/28, loss = 1.4540
# epoch 20 / 250, step 12/28, loss = 1.5955
# epoch 20 / 250, step 13/28, loss = 1.5379
# epoch 20 / 250, step 14/28, loss = 1.4648
# epoch 20 / 250, step 15/28, loss = 1.4983
# epoch 20 / 250, step 16/28, loss = 1.4625
# epoch 20 / 250, step 17/28, loss = 1.3423
# epoch 20 / 250, step 18/28, loss = 1.7959
# epoch 20 / 250, step 19/28, loss = 1.5957
# epoch 20 / 250, step 20/28, loss = 1.5865
# epoch 20 / 250, step 21/28, loss = 1.4614
# epoch 20 / 250, step 22/28, loss = 1.3321
# epoch 20 / 250, step 23/28, loss = 1.6089
# epoch 20 / 250, step 24/28, loss = 1.6058
# epoch 20 / 250, step 25/28, loss = 1.5596
# epoch 20 / 250, step 26/28, loss = 1.4381
# epoch 20 / 250, step 27/28, loss = 1.5512
# epoch 20 / 250, step 28/28, loss = 1.3985
# epoch 20 / 250, step 1/7, loss = 1.6454
# epoch 20 / 250, step 2/7, loss = 1.8705
# epoch 20 / 250, step 3/7, loss = 1.4348
# epoch 20 / 250, step 4/7, loss = 1.5524
# epoch 20 / 250, step 5/7, loss = 2.1998
# epoch 20 / 250, step 6/7, loss = 1.6313
# epoch 20 / 250, step 7/7, loss = 1.7037
# epoch 21 / 250, step 1/28, loss = 1.5857
# epoch 21 / 250, step 2/28, loss = 1.3257
# epoch 21 / 250, step 3/28, loss = 1.3597
# epoch 21 / 250, step 4/28, loss = 1.5945
# epoch 21 / 250, step 5/28, loss = 1.4077
# epoch 21 / 250, step 6/28, loss = 1.4094
# epoch 21 / 250, step 7/28, loss = 1.4086
# epoch 21 / 250, step 8/28, loss = 1.3103
# epoch 21 / 250, step 9/28, loss = 1.3643
# epoch 21 / 250, step 10/28, loss = 1.3601
# epoch 21 / 250, step 11/28, loss = 1.3832
# epoch 21 / 250, step 12/28, loss = 1.5195
# epoch 21 / 250, step 13/28, loss = 1.2253
# epoch 21 / 250, step 14/28, loss = 1.5101
# epoch 21 / 250, step 15/28, loss = 1.5695
# epoch 21 / 250, step 16/28, loss = 1.4765
# epoch 21 / 250, step 17/28, loss = 1.0926
# epoch 21 / 250, step 18/28, loss = 1.3987
# epoch 21 / 250, step 19/28, loss = 1.2381
# epoch 21 / 250, step 20/28, loss = 1.4039
# epoch 21 / 250, step 21/28, loss = 1.3791
# epoch 21 / 250, step 22/28, loss = 1.5216
# epoch 21 / 250, step 23/28, loss = 1.2900
# epoch 21 / 250, step 24/28, loss = 1.4512
# epoch 21 / 250, step 25/28, loss = 1.5797
# epoch 21 / 250, step 26/28, loss = 1.5711
# epoch 21 / 250, step 27/28, loss = 1.4756
# epoch 21 / 250, step 28/28, loss = 1.4697
# epoch 21 / 250, step 1/7, loss = 1.4947
# epoch 21 / 250, step 2/7, loss = 1.4427
# epoch 21 / 250, step 3/7, loss = 1.1325
# epoch 21 / 250, step 4/7, loss = 1.3563
# epoch 21 / 250, step 5/7, loss = 1.4344
# epoch 21 / 250, step 6/7, loss = 1.4022
# epoch 21 / 250, step 7/7, loss = 1.5282
# epoch 22 / 250, step 1/28, loss = 1.0954
# epoch 22 / 250, step 2/28, loss = 1.2103
# epoch 22 / 250, step 3/28, loss = 1.3093
# epoch 22 / 250, step 4/28, loss = 1.2024
# epoch 22 / 250, step 5/28, loss = 1.5624
# epoch 22 / 250, step 6/28, loss = 1.3473
# epoch 22 / 250, step 7/28, loss = 1.2583
# epoch 22 / 250, step 8/28, loss = 1.3643
# epoch 22 / 250, step 9/28, loss = 1.1023
# epoch 22 / 250, step 10/28, loss = 1.1366
# epoch 22 / 250, step 11/28, loss = 1.3304
# epoch 22 / 250, step 12/28, loss = 1.2449
# epoch 22 / 250, step 13/28, loss = 1.2452
# epoch 22 / 250, step 14/28, loss = 1.0121
# epoch 22 / 250, step 15/28, loss = 1.6355
# epoch 22 / 250, step 16/28, loss = 1.1325
# epoch 22 / 250, step 17/28, loss = 1.9737
# epoch 22 / 250, step 18/28, loss = 1.6429
# epoch 22 / 250, step 19/28, loss = 1.1246
# epoch 22 / 250, step 20/28, loss = 1.1304
# epoch 22 / 250, step 21/28, loss = 1.0643
# epoch 22 / 250, step 22/28, loss = 1.4247
# epoch 22 / 250, step 23/28, loss = 1.2210
# epoch 22 / 250, step 24/28, loss = 1.4150
# epoch 22 / 250, step 25/28, loss = 1.5966
# epoch 22 / 250, step 26/28, loss = 1.4594
# epoch 22 / 250, step 27/28, loss = 1.5600
# epoch 22 / 250, step 28/28, loss = 1.1195
# epoch 22 / 250, step 1/7, loss = 1.5211
# epoch 22 / 250, step 2/7, loss = 1.9171
# epoch 22 / 250, step 3/7, loss = 1.4105
# epoch 22 / 250, step 4/7, loss = 1.3937
# epoch 22 / 250, step 5/7, loss = 1.9369
# epoch 22 / 250, step 6/7, loss = 1.8416
# epoch 22 / 250, step 7/7, loss = 1.4722
# epoch 23 / 250, step 1/28, loss = 1.1312
# epoch 23 / 250, step 2/28, loss = 1.4501
# epoch 23 / 250, step 3/28, loss = 1.3884
# epoch 23 / 250, step 4/28, loss = 1.3125
# epoch 23 / 250, step 5/28, loss = 1.3724
# epoch 23 / 250, step 6/28, loss = 1.7563
# epoch 23 / 250, step 7/28, loss = 1.3341
# epoch 23 / 250, step 8/28, loss = 1.2079
# epoch 23 / 250, step 9/28, loss = 1.4186
# epoch 23 / 250, step 10/28, loss = 1.3613
# epoch 23 / 250, step 11/28, loss = 1.4681
# epoch 23 / 250, step 12/28, loss = 1.5578
# epoch 23 / 250, step 13/28, loss = 1.4795
# epoch 23 / 250, step 14/28, loss = 1.4390
# epoch 23 / 250, step 15/28, loss = 1.3311
# epoch 23 / 250, step 16/28, loss = 1.3614
# epoch 23 / 250, step 17/28, loss = 1.2730
# epoch 23 / 250, step 18/28, loss = 1.2032
# epoch 23 / 250, step 19/28, loss = 1.2419
# epoch 23 / 250, step 20/28, loss = 1.4345
# epoch 23 / 250, step 21/28, loss = 1.4014
# epoch 23 / 250, step 22/28, loss = 1.1518
# epoch 23 / 250, step 23/28, loss = 1.5606
# epoch 23 / 250, step 24/28, loss = 0.9803
# epoch 23 / 250, step 25/28, loss = 1.1738
# epoch 23 / 250, step 26/28, loss = 1.1696
# epoch 23 / 250, step 27/28, loss = 0.9208
# epoch 23 / 250, step 28/28, loss = 1.1648
# epoch 23 / 250, step 1/7, loss = 1.4376
# epoch 23 / 250, step 2/7, loss = 1.6739
# epoch 23 / 250, step 3/7, loss = 0.9306
# epoch 23 / 250, step 4/7, loss = 1.3814
# epoch 23 / 250, step 5/7, loss = 1.4196
# epoch 23 / 250, step 6/7, loss = 1.6846
# epoch 23 / 250, step 7/7, loss = 1.4656
# epoch 24 / 250, step 1/28, loss = 1.0410
# epoch 24 / 250, step 2/28, loss = 1.1789
# epoch 24 / 250, step 3/28, loss = 1.0108
# epoch 24 / 250, step 4/28, loss = 1.3607
# epoch 24 / 250, step 5/28, loss = 1.1617
# epoch 24 / 250, step 6/28, loss = 1.3851
# epoch 24 / 250, step 7/28, loss = 1.1274
# epoch 24 / 250, step 8/28, loss = 1.0348
# epoch 24 / 250, step 9/28, loss = 0.9575
# epoch 24 / 250, step 10/28, loss = 1.1061
# epoch 24 / 250, step 11/28, loss = 1.1086
# epoch 24 / 250, step 12/28, loss = 1.3210
# epoch 24 / 250, step 13/28, loss = 1.1098
# epoch 24 / 250, step 14/28, loss = 1.2138
# epoch 24 / 250, step 15/28, loss = 0.9973
# epoch 24 / 250, step 16/28, loss = 0.8092
# epoch 24 / 250, step 17/28, loss = 1.2483
# epoch 24 / 250, step 18/28, loss = 1.2972
# epoch 24 / 250, step 19/28, loss = 1.1978
# epoch 24 / 250, step 20/28, loss = 1.3499
# epoch 24 / 250, step 21/28, loss = 1.1205
# epoch 24 / 250, step 22/28, loss = 1.0452
# epoch 24 / 250, step 23/28, loss = 1.2639
# epoch 24 / 250, step 24/28, loss = 1.0313
# epoch 24 / 250, step 25/28, loss = 0.7403
# epoch 24 / 250, step 26/28, loss = 0.9210
# epoch 24 / 250, step 27/28, loss = 1.3004
# epoch 24 / 250, step 28/28, loss = 0.9272
# epoch 24 / 250, step 1/7, loss = 1.1239
# epoch 24 / 250, step 2/7, loss = 1.6550
# epoch 24 / 250, step 3/7, loss = 0.9370
# epoch 24 / 250, step 4/7, loss = 1.2667
# epoch 24 / 250, step 5/7, loss = 1.3434
# epoch 24 / 250, step 6/7, loss = 1.2269
# epoch 24 / 250, step 7/7, loss = 1.3117
# epoch 25 / 250, step 1/28, loss = 1.0838
# epoch 25 / 250, step 2/28, loss = 0.9159
# epoch 25 / 250, step 3/28, loss = 1.0875
# epoch 25 / 250, step 4/28, loss = 1.0863
# epoch 25 / 250, step 5/28, loss = 1.0068
# epoch 25 / 250, step 6/28, loss = 1.0327
# epoch 25 / 250, step 7/28, loss = 0.9371
# epoch 25 / 250, step 8/28, loss = 0.8529
# epoch 25 / 250, step 9/28, loss = 0.8120
# epoch 25 / 250, step 10/28, loss = 1.1530
# epoch 25 / 250, step 11/28, loss = 1.1186
# epoch 25 / 250, step 12/28, loss = 0.9526
# epoch 25 / 250, step 13/28, loss = 0.9630
# epoch 25 / 250, step 14/28, loss = 1.1322
# epoch 25 / 250, step 15/28, loss = 1.1292
# epoch 25 / 250, step 16/28, loss = 1.1949
# epoch 25 / 250, step 17/28, loss = 0.9952
# epoch 25 / 250, step 18/28, loss = 1.0981
# epoch 25 / 250, step 19/28, loss = 0.9935
# epoch 25 / 250, step 20/28, loss = 1.2280
# epoch 25 / 250, step 21/28, loss = 0.6487
# epoch 25 / 250, step 22/28, loss = 0.8338
# epoch 25 / 250, step 23/28, loss = 1.3171
# epoch 25 / 250, step 24/28, loss = 1.1385
# epoch 25 / 250, step 25/28, loss = 1.0677
# epoch 25 / 250, step 26/28, loss = 1.3288
# epoch 25 / 250, step 27/28, loss = 1.5851
# epoch 25 / 250, step 28/28, loss = 0.9939
# epoch 25 / 250, step 1/7, loss = 1.5191
# epoch 25 / 250, step 2/7, loss = 1.6129
# epoch 25 / 250, step 3/7, loss = 1.4593
# epoch 25 / 250, step 4/7, loss = 1.4182
# epoch 25 / 250, step 5/7, loss = 1.7385
# epoch 25 / 250, step 6/7, loss = 1.6565
# epoch 25 / 250, step 7/7, loss = 1.5111
# epoch 26 / 250, step 1/28, loss = 1.2469
# epoch 26 / 250, step 2/28, loss = 1.1462
# epoch 26 / 250, step 3/28, loss = 1.0790
# epoch 26 / 250, step 4/28, loss = 1.1286
# epoch 26 / 250, step 5/28, loss = 1.1662
# epoch 26 / 250, step 6/28, loss = 0.9785
# epoch 26 / 250, step 7/28, loss = 1.2165
# epoch 26 / 250, step 8/28, loss = 0.9514
# epoch 26 / 250, step 9/28, loss = 1.2712
# epoch 26 / 250, step 10/28, loss = 1.3059
# epoch 26 / 250, step 11/28, loss = 1.0821
# epoch 26 / 250, step 12/28, loss = 0.8881
# epoch 26 / 250, step 13/28, loss = 0.8555
# epoch 26 / 250, step 14/28, loss = 1.0211
# epoch 26 / 250, step 15/28, loss = 0.8702
# epoch 26 / 250, step 16/28, loss = 0.7664
# epoch 26 / 250, step 17/28, loss = 0.8244
# epoch 26 / 250, step 18/28, loss = 1.3838
# epoch 26 / 250, step 19/28, loss = 0.7853
# epoch 26 / 250, step 20/28, loss = 0.8505
# epoch 26 / 250, step 21/28, loss = 1.0983
# epoch 26 / 250, step 22/28, loss = 0.7322
# epoch 26 / 250, step 23/28, loss = 1.2113
# epoch 26 / 250, step 24/28, loss = 0.8303
# epoch 26 / 250, step 25/28, loss = 0.9671
# epoch 26 / 250, step 26/28, loss = 0.8022
# epoch 26 / 250, step 27/28, loss = 1.2047
# epoch 26 / 250, step 28/28, loss = 0.8096
# epoch 26 / 250, step 1/7, loss = 1.7437
# epoch 26 / 250, step 2/7, loss = 1.6336
# epoch 26 / 250, step 3/7, loss = 0.8581
# epoch 26 / 250, step 4/7, loss = 1.3200
# epoch 26 / 250, step 5/7, loss = 1.1440
# epoch 26 / 250, step 6/7, loss = 1.4824
# epoch 26 / 250, step 7/7, loss = 1.3790
# epoch 27 / 250, step 1/28, loss = 0.7992
# epoch 27 / 250, step 2/28, loss = 1.1177
# epoch 27 / 250, step 3/28, loss = 0.7164
# epoch 27 / 250, step 4/28, loss = 0.9510
# epoch 27 / 250, step 5/28, loss = 0.6848
# epoch 27 / 250, step 6/28, loss = 1.0281
# epoch 27 / 250, step 7/28, loss = 0.7405
# epoch 27 / 250, step 8/28, loss = 0.9941
# epoch 27 / 250, step 9/28, loss = 0.8367
# epoch 27 / 250, step 10/28, loss = 1.2030
# epoch 27 / 250, step 11/28, loss = 0.9522
# epoch 27 / 250, step 12/28, loss = 0.5985
# epoch 27 / 250, step 13/28, loss = 0.8607
# epoch 27 / 250, step 14/28, loss = 0.6987
# epoch 27 / 250, step 15/28, loss = 0.7203
# epoch 27 / 250, step 16/28, loss = 0.8132
# epoch 27 / 250, step 17/28, loss = 0.9202
# epoch 27 / 250, step 18/28, loss = 0.8788
# epoch 27 / 250, step 19/28, loss = 0.9838
# epoch 27 / 250, step 20/28, loss = 0.7782
# epoch 27 / 250, step 21/28, loss = 0.9310
# epoch 27 / 250, step 22/28, loss = 0.9376
# epoch 27 / 250, step 23/28, loss = 1.1640
# epoch 27 / 250, step 24/28, loss = 0.7376
# epoch 27 / 250, step 25/28, loss = 1.1160
# epoch 27 / 250, step 26/28, loss = 0.7925
# epoch 27 / 250, step 27/28, loss = 1.3610
# epoch 27 / 250, step 28/28, loss = 0.8470
# epoch 27 / 250, step 1/7, loss = 1.3320
# epoch 27 / 250, step 2/7, loss = 1.6778
# epoch 27 / 250, step 3/7, loss = 1.5836
# epoch 27 / 250, step 4/7, loss = 1.3917
# epoch 27 / 250, step 5/7, loss = 1.1256
# epoch 27 / 250, step 6/7, loss = 1.2766
# epoch 27 / 250, step 7/7, loss = 1.2962
# epoch 28 / 250, step 1/28, loss = 0.9874
# epoch 28 / 250, step 2/28, loss = 1.0590
# epoch 28 / 250, step 3/28, loss = 0.8858
# epoch 28 / 250, step 4/28, loss = 1.0719
# epoch 28 / 250, step 5/28, loss = 0.9089
# epoch 28 / 250, step 6/28, loss = 1.2723
# epoch 28 / 250, step 7/28, loss = 0.9191
# epoch 28 / 250, step 8/28, loss = 1.4161
# epoch 28 / 250, step 9/28, loss = 1.0625
# epoch 28 / 250, step 10/28, loss = 1.0173
# epoch 28 / 250, step 11/28, loss = 1.0534
# epoch 28 / 250, step 12/28, loss = 1.2268
# epoch 28 / 250, step 13/28, loss = 1.1006
# epoch 28 / 250, step 14/28, loss = 1.0183
# epoch 28 / 250, step 15/28, loss = 1.1895
# epoch 28 / 250, step 16/28, loss = 0.8819
# epoch 28 / 250, step 17/28, loss = 0.9439
# epoch 28 / 250, step 18/28, loss = 0.9601
# epoch 28 / 250, step 19/28, loss = 1.1848
# epoch 28 / 250, step 20/28, loss = 1.0880
# epoch 28 / 250, step 21/28, loss = 1.0046
# epoch 28 / 250, step 22/28, loss = 1.1100
# epoch 28 / 250, step 23/28, loss = 0.9504
# epoch 28 / 250, step 24/28, loss = 1.1371
# epoch 28 / 250, step 25/28, loss = 1.2326
# epoch 28 / 250, step 26/28, loss = 1.1771
# epoch 28 / 250, step 27/28, loss = 1.0103
# epoch 28 / 250, step 28/28, loss = 0.6653
# epoch 28 / 250, step 1/7, loss = 1.1823
# epoch 28 / 250, step 2/7, loss = 1.2974
# epoch 28 / 250, step 3/7, loss = 0.7088
# epoch 28 / 250, step 4/7, loss = 1.4905
# epoch 28 / 250, step 5/7, loss = 0.8418
# epoch 28 / 250, step 6/7, loss = 1.0682
# epoch 28 / 250, step 7/7, loss = 1.4081
# epoch 29 / 250, step 1/28, loss = 0.4735
# epoch 29 / 250, step 2/28, loss = 0.8123
# epoch 29 / 250, step 3/28, loss = 0.8330
# epoch 29 / 250, step 4/28, loss = 1.1002
# epoch 29 / 250, step 5/28, loss = 0.6964
# epoch 29 / 250, step 6/28, loss = 1.1285
# epoch 29 / 250, step 7/28, loss = 0.7989
# epoch 29 / 250, step 8/28, loss = 1.1816
# epoch 29 / 250, step 9/28, loss = 0.9527
# epoch 29 / 250, step 10/28, loss = 1.0230
# epoch 29 / 250, step 11/28, loss = 0.9567
# epoch 29 / 250, step 12/28, loss = 1.1725
# epoch 29 / 250, step 13/28, loss = 1.2112
# epoch 29 / 250, step 14/28, loss = 1.0937
# epoch 29 / 250, step 15/28, loss = 1.0661
# epoch 29 / 250, step 16/28, loss = 0.6048
# epoch 29 / 250, step 17/28, loss = 0.8901
# epoch 29 / 250, step 18/28, loss = 1.0612
# epoch 29 / 250, step 19/28, loss = 1.0038
# epoch 29 / 250, step 20/28, loss = 0.9442
# epoch 29 / 250, step 21/28, loss = 1.1208
# epoch 29 / 250, step 22/28, loss = 0.9317
# epoch 29 / 250, step 23/28, loss = 1.2902
# epoch 29 / 250, step 24/28, loss = 1.1801
# epoch 29 / 250, step 25/28, loss = 1.2441
# epoch 29 / 250, step 26/28, loss = 0.9718
# epoch 29 / 250, step 27/28, loss = 0.9604
# epoch 29 / 250, step 28/28, loss = 0.7618
# epoch 29 / 250, step 1/7, loss = 2.3493
# epoch 29 / 250, step 2/7, loss = 2.1893
# epoch 29 / 250, step 3/7, loss = 1.6784
# epoch 29 / 250, step 4/7, loss = 2.0403
# epoch 29 / 250, step 5/7, loss = 2.0143
# epoch 29 / 250, step 6/7, loss = 2.4141
# epoch 29 / 250, step 7/7, loss = 2.5437
# epoch 30 / 250, step 1/28, loss = 1.2251
# epoch 30 / 250, step 2/28, loss = 1.8953
# epoch 30 / 250, step 3/28, loss = 1.3436
# epoch 30 / 250, step 4/28, loss = 1.3585
# epoch 30 / 250, step 5/28, loss = 1.0485
# epoch 30 / 250, step 6/28, loss = 1.0244
# epoch 30 / 250, step 7/28, loss = 1.5171
# epoch 30 / 250, step 8/28, loss = 1.7743
# epoch 30 / 250, step 9/28, loss = 1.3766
# epoch 30 / 250, step 10/28, loss = 1.3454
# epoch 30 / 250, step 11/28, loss = 1.1573
# epoch 30 / 250, step 12/28, loss = 1.4492
# epoch 30 / 250, step 13/28, loss = 1.3129
# epoch 30 / 250, step 14/28, loss = 1.4197
# epoch 30 / 250, step 15/28, loss = 1.2270
# epoch 30 / 250, step 16/28, loss = 1.0933
# epoch 30 / 250, step 17/28, loss = 1.1753
# epoch 30 / 250, step 18/28, loss = 1.0723
# epoch 30 / 250, step 19/28, loss = 1.1579
# epoch 30 / 250, step 20/28, loss = 1.0822
# epoch 30 / 250, step 21/28, loss = 1.2853
# epoch 30 / 250, step 22/28, loss = 1.1809
# epoch 30 / 250, step 23/28, loss = 1.2168
# epoch 30 / 250, step 24/28, loss = 1.3528
# epoch 30 / 250, step 25/28, loss = 1.1862
# epoch 30 / 250, step 26/28, loss = 1.0161
# epoch 30 / 250, step 27/28, loss = 1.1334
# epoch 30 / 250, step 28/28, loss = 1.0727
# epoch 30 / 250, step 1/7, loss = 1.1691
# epoch 30 / 250, step 2/7, loss = 1.4267
# epoch 30 / 250, step 3/7, loss = 1.1314
# epoch 30 / 250, step 4/7, loss = 1.5020
# epoch 30 / 250, step 5/7, loss = 1.6698
# epoch 30 / 250, step 6/7, loss = 1.8669
# epoch 30 / 250, step 7/7, loss = 1.4463
# epoch 31 / 250, step 1/28, loss = 0.9128
# epoch 31 / 250, step 2/28, loss = 0.9944
# epoch 31 / 250, step 3/28, loss = 1.0549
# epoch 31 / 250, step 4/28, loss = 1.1450
# epoch 31 / 250, step 5/28, loss = 0.9353
# epoch 31 / 250, step 6/28, loss = 0.9841
# epoch 31 / 250, step 7/28, loss = 0.7992
# epoch 31 / 250, step 8/28, loss = 0.8688
# epoch 31 / 250, step 9/28, loss = 0.9956
# epoch 31 / 250, step 10/28, loss = 1.0437
# epoch 31 / 250, step 11/28, loss = 0.8781
# epoch 31 / 250, step 12/28, loss = 1.0688
# epoch 31 / 250, step 13/28, loss = 0.7171
# epoch 31 / 250, step 14/28, loss = 0.5289
# epoch 31 / 250, step 15/28, loss = 0.8786
# epoch 31 / 250, step 16/28, loss = 0.9681
# epoch 31 / 250, step 17/28, loss = 0.6178
# epoch 31 / 250, step 18/28, loss = 0.9748
# epoch 31 / 250, step 19/28, loss = 0.8883
# epoch 31 / 250, step 20/28, loss = 1.2658
# epoch 31 / 250, step 21/28, loss = 0.8246
# epoch 31 / 250, step 22/28, loss = 0.8720
# epoch 31 / 250, step 23/28, loss = 0.7708
# epoch 31 / 250, step 24/28, loss = 0.9855
# epoch 31 / 250, step 25/28, loss = 0.7322
# epoch 31 / 250, step 26/28, loss = 0.8047
# epoch 31 / 250, step 27/28, loss = 0.6793
# epoch 31 / 250, step 28/28, loss = 0.9347
# epoch 31 / 250, step 1/7, loss = 1.9192
# epoch 31 / 250, step 2/7, loss = 0.9406
# epoch 31 / 250, step 3/7, loss = 0.8510
# epoch 31 / 250, step 4/7, loss = 1.0417
# epoch 31 / 250, step 5/7, loss = 0.7598
# epoch 31 / 250, step 6/7, loss = 1.6787
# epoch 31 / 250, step 7/7, loss = 1.7006
# epoch 32 / 250, step 1/28, loss = 0.6013
# epoch 32 / 250, step 2/28, loss = 0.9692
# epoch 32 / 250, step 3/28, loss = 1.0155
# epoch 32 / 250, step 4/28, loss = 0.9858
# epoch 32 / 250, step 5/28, loss = 0.9297
# epoch 32 / 250, step 6/28, loss = 1.1639
# epoch 32 / 250, step 7/28, loss = 1.1383
# epoch 32 / 250, step 8/28, loss = 0.7669
# epoch 32 / 250, step 9/28, loss = 0.7096
# epoch 32 / 250, step 10/28, loss = 0.8364
# epoch 32 / 250, step 11/28, loss = 0.8879
# epoch 32 / 250, step 12/28, loss = 1.0356
# epoch 32 / 250, step 13/28, loss = 0.8466
# epoch 32 / 250, step 14/28, loss = 1.1222
# epoch 32 / 250, step 15/28, loss = 0.7547
# epoch 32 / 250, step 16/28, loss = 1.0364
# epoch 32 / 250, step 17/28, loss = 0.7452
# epoch 32 / 250, step 18/28, loss = 0.6677
# epoch 32 / 250, step 19/28, loss = 0.9104
# epoch 32 / 250, step 20/28, loss = 0.8801
# epoch 32 / 250, step 21/28, loss = 0.8010
# epoch 32 / 250, step 22/28, loss = 1.0089
# epoch 32 / 250, step 23/28, loss = 1.2963
# epoch 32 / 250, step 24/28, loss = 0.9548
# epoch 32 / 250, step 25/28, loss = 0.7417
# epoch 32 / 250, step 26/28, loss = 0.7558
# epoch 32 / 250, step 27/28, loss = 1.0919
# epoch 32 / 250, step 28/28, loss = 0.8603
# epoch 32 / 250, step 1/7, loss = 1.1810
# epoch 32 / 250, step 2/7, loss = 0.9133
# epoch 32 / 250, step 3/7, loss = 0.8598
# epoch 32 / 250, step 4/7, loss = 1.3716
# epoch 32 / 250, step 5/7, loss = 1.3788
# epoch 32 / 250, step 6/7, loss = 1.1084
# epoch 32 / 250, step 7/7, loss = 1.1637
# epoch 33 / 250, step 1/28, loss = 0.7659
# epoch 33 / 250, step 2/28, loss = 0.7869
# epoch 33 / 250, step 3/28, loss = 1.4623
# epoch 33 / 250, step 4/28, loss = 1.1731
# epoch 33 / 250, step 5/28, loss = 0.8113
# epoch 33 / 250, step 6/28, loss = 0.9357
# epoch 33 / 250, step 7/28, loss = 1.6918
# epoch 33 / 250, step 8/28, loss = 0.8935
# epoch 33 / 250, step 9/28, loss = 1.1446
# epoch 33 / 250, step 10/28, loss = 1.0732
# epoch 33 / 250, step 11/28, loss = 0.8570
# epoch 33 / 250, step 12/28, loss = 0.9057
# epoch 33 / 250, step 13/28, loss = 0.8971
# epoch 33 / 250, step 14/28, loss = 1.2223
# epoch 33 / 250, step 15/28, loss = 0.8648
# epoch 33 / 250, step 16/28, loss = 1.0366
# epoch 33 / 250, step 17/28, loss = 0.8104
# epoch 33 / 250, step 18/28, loss = 0.8434
# epoch 33 / 250, step 19/28, loss = 0.8623
# epoch 33 / 250, step 20/28, loss = 0.7800
# epoch 33 / 250, step 21/28, loss = 0.9766
# epoch 33 / 250, step 22/28, loss = 0.9514
# epoch 33 / 250, step 23/28, loss = 1.0419
# epoch 33 / 250, step 24/28, loss = 0.6253
# epoch 33 / 250, step 25/28, loss = 0.6850
# epoch 33 / 250, step 26/28, loss = 0.8971
# epoch 33 / 250, step 27/28, loss = 0.9309
# epoch 33 / 250, step 28/28, loss = 0.4737
# epoch 33 / 250, step 1/7, loss = 1.1178
# epoch 33 / 250, step 2/7, loss = 1.2131
# epoch 33 / 250, step 3/7, loss = 0.9865
# epoch 33 / 250, step 4/7, loss = 1.3409
# epoch 33 / 250, step 5/7, loss = 1.1602
# epoch 33 / 250, step 6/7, loss = 1.2294
# epoch 33 / 250, step 7/7, loss = 1.4060
# epoch 34 / 250, step 1/28, loss = 0.6960
# epoch 34 / 250, step 2/28, loss = 0.9370
# epoch 34 / 250, step 3/28, loss = 0.8138
# epoch 34 / 250, step 4/28, loss = 0.9478
# epoch 34 / 250, step 5/28, loss = 0.7564
# epoch 34 / 250, step 6/28, loss = 1.1161
# epoch 34 / 250, step 7/28, loss = 1.3628
# epoch 34 / 250, step 8/28, loss = 0.9583
# epoch 34 / 250, step 9/28, loss = 0.9201
# epoch 34 / 250, step 10/28, loss = 0.8291
# epoch 34 / 250, step 11/28, loss = 0.7719
# epoch 34 / 250, step 12/28, loss = 0.6918
# epoch 34 / 250, step 13/28, loss = 0.8064
# ...
# epoch 240 / 250, step 9/28, loss = 0.0691
# epoch 240 / 250, step 10/28, loss = 0.1134
# epoch 240 / 250, step 11/28, loss = 0.3382
# epoch 240 / 250, step 12/28, loss = 0.3535
# epoch 240 / 250, step 13/28, loss = 0.5949
# epoch 240 / 250, step 14/28, loss = 0.2858
# epoch 240 / 250, step 15/28, loss = 0.4965
# epoch 240 / 250, step 16/28, loss = 0.2747
# epoch 240 / 250, step 17/28, loss = 0.6187
# epoch 240 / 250, step 18/28, loss = 0.0332
# epoch 240 / 250, step 19/28, loss = 0.0499
# epoch 240 / 250, step 20/28, loss = 0.1207
# epoch 240 / 250, step 21/28, loss = 0.0206
# epoch 240 / 250, step 22/28, loss = 0.2904
# epoch 240 / 250, step 23/28, loss = 0.4243
# epoch 240 / 250, step 24/28, loss = 0.3847
# epoch 240 / 250, step 25/28, loss = 0.1244
# epoch 240 / 250, step 26/28, loss = 0.1838
# epoch 240 / 250, step 27/28, loss = 0.3682
# epoch 240 / 250, step 28/28, loss = 0.1184
# epoch 240 / 250, step 1/7, loss = 0.4460
# epoch 240 / 250, step 2/7, loss = 0.2576
# epoch 240 / 250, step 3/7, loss = 0.2250
# epoch 240 / 250, step 4/7, loss = 0.5213
# epoch 240 / 250, step 5/7, loss = 0.3257
# epoch 240 / 250, step 6/7, loss = 0.8398
# epoch 240 / 250, step 7/7, loss = 0.4997
# epoch 241 / 250, step 1/28, loss = 0.3839
# epoch 241 / 250, step 2/28, loss = 0.2147
# epoch 241 / 250, step 3/28, loss = 0.1186
# epoch 241 / 250, step 4/28, loss = 0.1685
# epoch 241 / 250, step 5/28, loss = 0.2099
# epoch 241 / 250, step 6/28, loss = 0.1467
# epoch 241 / 250, step 7/28, loss = 0.0733
# epoch 241 / 250, step 8/28, loss = 0.0754
# epoch 241 / 250, step 9/28, loss = 0.1178
# epoch 241 / 250, step 10/28, loss = 0.1936
# epoch 241 / 250, step 11/28, loss = 0.1118
# epoch 241 / 250, step 12/28, loss = 0.0783
# epoch 241 / 250, step 13/28, loss = 0.1995
# epoch 241 / 250, step 14/28, loss = 0.2559
# epoch 241 / 250, step 15/28, loss = 0.1530
# epoch 241 / 250, step 16/28, loss = 0.1384
# epoch 241 / 250, step 17/28, loss = 0.2841
# epoch 241 / 250, step 18/28, loss = 0.2953
# epoch 241 / 250, step 19/28, loss = 0.0503
# epoch 241 / 250, step 20/28, loss = 0.2301
# epoch 241 / 250, step 21/28, loss = 0.3133
# epoch 241 / 250, step 22/28, loss = 0.1875
# epoch 241 / 250, step 23/28, loss = 0.1425
# epoch 241 / 250, step 24/28, loss = 0.0356
# epoch 241 / 250, step 25/28, loss = 0.0938
# epoch 241 / 250, step 26/28, loss = 0.1191
# epoch 241 / 250, step 27/28, loss = 0.1265
# epoch 241 / 250, step 28/28, loss = 0.0175
# epoch 241 / 250, step 1/7, loss = 0.4610
# epoch 241 / 250, step 2/7, loss = 0.5279
# epoch 241 / 250, step 3/7, loss = 0.4524
# epoch 241 / 250, step 4/7, loss = 0.7585
# epoch 241 / 250, step 5/7, loss = 0.6184
# epoch 241 / 250, step 6/7, loss = 1.0716
# epoch 241 / 250, step 7/7, loss = 0.2616
# epoch 242 / 250, step 1/28, loss = 0.0593
# epoch 242 / 250, step 2/28, loss = 0.1564
# epoch 242 / 250, step 3/28, loss = 0.2076
# epoch 242 / 250, step 4/28, loss = 0.1694
# epoch 242 / 250, step 5/28, loss = 0.1260
# epoch 242 / 250, step 6/28, loss = 0.0883
# epoch 242 / 250, step 7/28, loss = 0.0876
# epoch 242 / 250, step 8/28, loss = 0.0486
# epoch 242 / 250, step 9/28, loss = 0.1582
# epoch 242 / 250, step 10/28, loss = 0.0858
# epoch 242 / 250, step 11/28, loss = 0.0318
# epoch 242 / 250, step 12/28, loss = 0.1402
# epoch 242 / 250, step 13/28, loss = 0.1801
# epoch 242 / 250, step 14/28, loss = 0.1002
# epoch 242 / 250, step 15/28, loss = 0.2346
# epoch 242 / 250, step 16/28, loss = 0.0421
# epoch 242 / 250, step 17/28, loss = 0.1914
# epoch 242 / 250, step 18/28, loss = 0.2954
# epoch 242 / 250, step 19/28, loss = 0.3461
# epoch 242 / 250, step 20/28, loss = 0.0397
# epoch 242 / 250, step 21/28, loss = 0.1287
# epoch 242 / 250, step 22/28, loss = 0.0759
# epoch 242 / 250, step 23/28, loss = 0.0409
# epoch 242 / 250, step 24/28, loss = 0.1410
# epoch 242 / 250, step 25/28, loss = 0.1076
# epoch 242 / 250, step 26/28, loss = 0.0533
# epoch 242 / 250, step 27/28, loss = 0.1879
# epoch 242 / 250, step 28/28, loss = 0.0119
# epoch 242 / 250, step 1/7, loss = 0.3277
# epoch 242 / 250, step 2/7, loss = 0.4503
# epoch 242 / 250, step 3/7, loss = 0.2128
# epoch 242 / 250, step 4/7, loss = 0.6151
# epoch 242 / 250, step 5/7, loss = 0.4358
# epoch 242 / 250, step 6/7, loss = 0.4333
# epoch 242 / 250, step 7/7, loss = 0.3383
# epoch 243 / 250, step 1/28, loss = 0.1624
# epoch 243 / 250, step 2/28, loss = 0.0664
# epoch 243 / 250, step 3/28, loss = 0.1649
# epoch 243 / 250, step 4/28, loss = 0.0416
# epoch 243 / 250, step 5/28, loss = 0.0101
# epoch 243 / 250, step 6/28, loss = 0.0106
# epoch 243 / 250, step 7/28, loss = 0.0832
# epoch 243 / 250, step 8/28, loss = 0.1215
# epoch 243 / 250, step 9/28, loss = 0.1520
# epoch 243 / 250, step 10/28, loss = 0.0849
# epoch 243 / 250, step 11/28, loss = 0.0563
# epoch 243 / 250, step 12/28, loss = 0.1674
# epoch 243 / 250, step 13/28, loss = 0.0233
# epoch 243 / 250, step 14/28, loss = 0.1223
# epoch 243 / 250, step 15/28, loss = 0.0416
# epoch 243 / 250, step 16/28, loss = 0.2372
# epoch 243 / 250, step 17/28, loss = 0.0761
# epoch 243 / 250, step 18/28, loss = 0.0867
# epoch 243 / 250, step 19/28, loss = 0.0753
# epoch 243 / 250, step 20/28, loss = 0.1988
# epoch 243 / 250, step 21/28, loss = 0.0273
# epoch 243 / 250, step 22/28, loss = 0.1970
# epoch 243 / 250, step 23/28, loss = 0.0121
# epoch 243 / 250, step 24/28, loss = 0.3007
# epoch 243 / 250, step 25/28, loss = 0.0124
# epoch 243 / 250, step 26/28, loss = 0.1131
# epoch 243 / 250, step 27/28, loss = 0.1652
# epoch 243 / 250, step 28/28, loss = 0.0253
# epoch 243 / 250, step 1/7, loss = 0.5213
# epoch 243 / 250, step 2/7, loss = 0.4533
# epoch 243 / 250, step 3/7, loss = 0.2160
# epoch 243 / 250, step 4/7, loss = 0.5496
# epoch 243 / 250, step 5/7, loss = 0.3625
# epoch 243 / 250, step 6/7, loss = 0.8371
# epoch 243 / 250, step 7/7, loss = 0.4296
# epoch 244 / 250, step 1/28, loss = 0.0291
# epoch 244 / 250, step 2/28, loss = 0.2190
# epoch 244 / 250, step 3/28, loss = 0.0685
# epoch 244 / 250, step 4/28, loss = 0.1541
# epoch 244 / 250, step 5/28, loss = 0.0264
# epoch 244 / 250, step 6/28, loss = 0.0204
# epoch 244 / 250, step 7/28, loss = 0.2730
# epoch 244 / 250, step 8/28, loss = 0.0144
# epoch 244 / 250, step 9/28, loss = 0.0696
# epoch 244 / 250, step 10/28, loss = 0.3555
# epoch 244 / 250, step 11/28, loss = 0.1225
# epoch 244 / 250, step 12/28, loss = 0.0803
# epoch 244 / 250, step 13/28, loss = 0.1117
# epoch 244 / 250, step 14/28, loss = 0.0659
# epoch 244 / 250, step 15/28, loss = 0.0176
# epoch 244 / 250, step 16/28, loss = 0.1120
# epoch 244 / 250, step 17/28, loss = 0.0426
# epoch 244 / 250, step 18/28, loss = 0.1129
# epoch 244 / 250, step 19/28, loss = 0.2610
# epoch 244 / 250, step 20/28, loss = 0.1446
# epoch 244 / 250, step 21/28, loss = 0.1239
# epoch 244 / 250, step 22/28, loss = 0.0237
# epoch 244 / 250, step 23/28, loss = 0.0481
# epoch 244 / 250, step 24/28, loss = 0.0218
# epoch 244 / 250, step 25/28, loss = 0.1265
# epoch 244 / 250, step 26/28, loss = 0.0442
# epoch 244 / 250, step 27/28, loss = 0.0114
# epoch 244 / 250, step 28/28, loss = 0.1274
# epoch 244 / 250, step 1/7, loss = 0.3971
# epoch 244 / 250, step 2/7, loss = 0.3534
# epoch 244 / 250, step 3/7, loss = 0.0642
# epoch 244 / 250, step 4/7, loss = 0.7673
# epoch 244 / 250, step 5/7, loss = 0.2937
# epoch 244 / 250, step 6/7, loss = 0.8224
# epoch 244 / 250, step 7/7, loss = 0.7252
# epoch 245 / 250, step 1/28, loss = 0.0167
# epoch 245 / 250, step 2/28, loss = 0.0215
# epoch 245 / 250, step 3/28, loss = 0.3179
# epoch 245 / 250, step 4/28, loss = 0.0641
# epoch 245 / 250, step 5/28, loss = 0.0779
# epoch 245 / 250, step 6/28, loss = 0.0073
# epoch 245 / 250, step 7/28, loss = 0.4917
# epoch 245 / 250, step 8/28, loss = 0.1915
# epoch 245 / 250, step 9/28, loss = 0.1391
# epoch 245 / 250, step 10/28, loss = 0.0224
# epoch 245 / 250, step 11/28, loss = 0.0718
# epoch 245 / 250, step 12/28, loss = 0.2281
# epoch 245 / 250, step 13/28, loss = 0.1209
# epoch 245 / 250, step 14/28, loss = 0.0455
# epoch 245 / 250, step 15/28, loss = 0.0871
# epoch 245 / 250, step 16/28, loss = 0.0268
# epoch 245 / 250, step 17/28, loss = 0.0805
# epoch 245 / 250, step 18/28, loss = 0.2691
# epoch 245 / 250, step 19/28, loss = 0.0211
# epoch 245 / 250, step 20/28, loss = 0.0241
# epoch 245 / 250, step 21/28, loss = 0.1277
# epoch 245 / 250, step 22/28, loss = 0.0622
# epoch 245 / 250, step 23/28, loss = 0.0619
# epoch 245 / 250, step 24/28, loss = 0.1110
# epoch 245 / 250, step 25/28, loss = 0.0953
# epoch 245 / 250, step 26/28, loss = 0.1163
# epoch 245 / 250, step 27/28, loss = 0.2556
# epoch 245 / 250, step 28/28, loss = 0.0249
# epoch 245 / 250, step 1/7, loss = 0.2445
# epoch 245 / 250, step 2/7, loss = 0.2259
# epoch 245 / 250, step 3/7, loss = 0.4299
# epoch 245 / 250, step 4/7, loss = 0.5339
# epoch 245 / 250, step 5/7, loss = 0.1774
# epoch 245 / 250, step 6/7, loss = 0.6887
# epoch 245 / 250, step 7/7, loss = 0.1554
# epoch 246 / 250, step 1/28, loss = 0.0411
# epoch 246 / 250, step 2/28, loss = 0.1219
# epoch 246 / 250, step 3/28, loss = 0.0154
# epoch 246 / 250, step 4/28, loss = 0.2358
# epoch 246 / 250, step 5/28, loss = 0.4785
# epoch 246 / 250, step 6/28, loss = 0.0637
# epoch 246 / 250, step 7/28, loss = 0.0932
# epoch 246 / 250, step 8/28, loss = 0.0766
# epoch 246 / 250, step 9/28, loss = 0.1052
# epoch 246 / 250, step 10/28, loss = 0.0215
# epoch 246 / 250, step 11/28, loss = 0.0264
# epoch 246 / 250, step 12/28, loss = 0.1096
# epoch 246 / 250, step 13/28, loss = 0.1866
# epoch 246 / 250, step 14/28, loss = 0.1924
# epoch 246 / 250, step 15/28, loss = 0.1062
# epoch 246 / 250, step 16/28, loss = 0.0369
# epoch 246 / 250, step 17/28, loss = 0.0347
# epoch 246 / 250, step 18/28, loss = 0.1501
# epoch 246 / 250, step 19/28, loss = 0.1019
# epoch 246 / 250, step 20/28, loss = 0.0507
# epoch 246 / 250, step 21/28, loss = 0.0766
# epoch 246 / 250, step 22/28, loss = 0.0194
# epoch 246 / 250, step 23/28, loss = 0.2174
# epoch 246 / 250, step 24/28, loss = 0.1623
# epoch 246 / 250, step 25/28, loss = 0.0280
# epoch 246 / 250, step 26/28, loss = 0.0232
# epoch 246 / 250, step 27/28, loss = 0.0988
# epoch 246 / 250, step 28/28, loss = 0.0099
# epoch 246 / 250, step 1/7, loss = 0.1470
# epoch 246 / 250, step 2/7, loss = 0.1936
# epoch 246 / 250, step 3/7, loss = 0.5027
# epoch 246 / 250, step 4/7, loss = 0.6561
# epoch 246 / 250, step 5/7, loss = 0.2739
# epoch 246 / 250, step 6/7, loss = 0.4530
# epoch 246 / 250, step 7/7, loss = 0.3137
# epoch 247 / 250, step 1/28, loss = 0.1186
# epoch 247 / 250, step 2/28, loss = 0.1301
# epoch 247 / 250, step 3/28, loss = 0.0973
# epoch 247 / 250, step 4/28, loss = 0.1205
# epoch 247 / 250, step 5/28, loss = 0.1019
# epoch 247 / 250, step 6/28, loss = 0.2474
# epoch 247 / 250, step 7/28, loss = 0.2272
# epoch 247 / 250, step 8/28, loss = 0.4248
# epoch 247 / 250, step 9/28, loss = 0.0351
# epoch 247 / 250, step 10/28, loss = 0.4047
# epoch 247 / 250, step 11/28, loss = 0.4373
# epoch 247 / 250, step 12/28, loss = 0.7739
# epoch 247 / 250, step 13/28, loss = 0.5557
# epoch 247 / 250, step 14/28, loss = 0.1219
# epoch 247 / 250, step 15/28, loss = 0.4747
# epoch 247 / 250, step 16/28, loss = 0.2704
# epoch 247 / 250, step 17/28, loss = 0.4541
# epoch 247 / 250, step 18/28, loss = 0.0503
# epoch 247 / 250, step 19/28, loss = 0.2461
# epoch 247 / 250, step 20/28, loss = 0.2845
# epoch 247 / 250, step 21/28, loss = 0.2352
# epoch 247 / 250, step 22/28, loss = 0.2408
# epoch 247 / 250, step 23/28, loss = 0.1035
# epoch 247 / 250, step 24/28, loss = 0.1900
# epoch 247 / 250, step 25/28, loss = 0.1083
# epoch 247 / 250, step 26/28, loss = 0.2353
# epoch 247 / 250, step 27/28, loss = 0.0788
# epoch 247 / 250, step 28/28, loss = 0.1908
# epoch 247 / 250, step 1/7, loss = 0.4084
# epoch 247 / 250, step 2/7, loss = 0.3425
# epoch 247 / 250, step 3/7, loss = 0.1522
# epoch 247 / 250, step 4/7, loss = 0.5033
# epoch 247 / 250, step 5/7, loss = 0.2309
# epoch 247 / 250, step 6/7, loss = 0.8149
# epoch 247 / 250, step 7/7, loss = 0.5538
# epoch 248 / 250, step 1/28, loss = 0.0620
# epoch 248 / 250, step 2/28, loss = 0.2393
# epoch 248 / 250, step 3/28, loss = 0.1942
# epoch 248 / 250, step 4/28, loss = 0.1122
# epoch 248 / 250, step 5/28, loss = 0.1485
# epoch 248 / 250, step 6/28, loss = 0.1837
# epoch 248 / 250, step 7/28, loss = 0.2221
# epoch 248 / 250, step 8/28, loss = 0.2425
# epoch 248 / 250, step 9/28, loss = 0.1752
# epoch 248 / 250, step 10/28, loss = 0.2124
# epoch 248 / 250, step 11/28, loss = 0.0782
# epoch 248 / 250, step 12/28, loss = 0.0395
# epoch 248 / 250, step 13/28, loss = 0.1037
# epoch 248 / 250, step 14/28, loss = 0.1668
# epoch 248 / 250, step 15/28, loss = 0.0797
# epoch 248 / 250, step 16/28, loss = 0.3371
# epoch 248 / 250, step 17/28, loss = 0.2226
# epoch 248 / 250, step 18/28, loss = 0.0350
# epoch 248 / 250, step 19/28, loss = 0.0367
# epoch 248 / 250, step 20/28, loss = 0.1113
# epoch 248 / 250, step 21/28, loss = 0.1276
# epoch 248 / 250, step 22/28, loss = 0.1614
# epoch 248 / 250, step 23/28, loss = 0.0464
# epoch 248 / 250, step 24/28, loss = 0.0739
# epoch 248 / 250, step 25/28, loss = 0.2690
# epoch 248 / 250, step 26/28, loss = 0.2808
# epoch 248 / 250, step 27/28, loss = 0.2270
# epoch 248 / 250, step 28/28, loss = 0.1082
# epoch 248 / 250, step 1/7, loss = 0.1521
# epoch 248 / 250, step 2/7, loss = 0.3809
# epoch 248 / 250, step 3/7, loss = 0.2657
# epoch 248 / 250, step 4/7, loss = 0.5470
# epoch 248 / 250, step 5/7, loss = 0.0620
# epoch 248 / 250, step 6/7, loss = 0.7214
# epoch 248 / 250, step 7/7, loss = 0.4777
# epoch 249 / 250, step 1/28, loss = 0.1688
# epoch 249 / 250, step 2/28, loss = 0.0564
# epoch 249 / 250, step 3/28, loss = 0.1040
# epoch 249 / 250, step 4/28, loss = 0.2013
# epoch 249 / 250, step 5/28, loss = 0.0578
# epoch 249 / 250, step 6/28, loss = 0.0942
# epoch 249 / 250, step 7/28, loss = 0.0673
# epoch 249 / 250, step 8/28, loss = 0.0564
# epoch 249 / 250, step 9/28, loss = 0.1087
# epoch 249 / 250, step 10/28, loss = 0.0570
# epoch 249 / 250, step 11/28, loss = 0.1064
# epoch 249 / 250, step 12/28, loss = 0.0938
# epoch 249 / 250, step 13/28, loss = 0.0446
# epoch 249 / 250, step 14/28, loss = 0.0604
# epoch 249 / 250, step 15/28, loss = 0.1168
# epoch 249 / 250, step 16/28, loss = 0.0417
# epoch 249 / 250, step 17/28, loss = 0.1565
# epoch 249 / 250, step 18/28, loss = 0.0698
# epoch 249 / 250, step 19/28, loss = 0.0357
# epoch 249 / 250, step 20/28, loss = 0.0457
# epoch 249 / 250, step 21/28, loss = 0.1345
# epoch 249 / 250, step 22/28, loss = 0.0538
# epoch 249 / 250, step 23/28, loss = 0.2699
# epoch 249 / 250, step 24/28, loss = 0.0180
# epoch 249 / 250, step 25/28, loss = 0.0308
# epoch 249 / 250, step 26/28, loss = 0.1424
# epoch 249 / 250, step 27/28, loss = 0.3299
# epoch 249 / 250, step 28/28, loss = 0.4191
# epoch 249 / 250, step 1/7, loss = 0.0914
# epoch 249 / 250, step 2/7, loss = 0.5624
# epoch 249 / 250, step 3/7, loss = 0.0448
# epoch 249 / 250, step 4/7, loss = 0.9948
# epoch 249 / 250, step 5/7, loss = 0.2907
# epoch 249 / 250, step 6/7, loss = 0.9983
# epoch 249 / 250, step 7/7, loss = 0.4790
# epoch 250 / 250, step 1/28, loss = 0.0646
# epoch 250 / 250, step 2/28, loss = 0.1453
# epoch 250 / 250, step 3/28, loss = 0.2534
# epoch 250 / 250, step 4/28, loss = 0.0520
# epoch 250 / 250, step 5/28, loss = 0.2477
# epoch 250 / 250, step 6/28, loss = 0.0273
# epoch 250 / 250, step 7/28, loss = 0.0668
# epoch 250 / 250, step 8/28, loss = 0.0261
# epoch 250 / 250, step 9/28, loss = 0.0924
# epoch 250 / 250, step 10/28, loss = 0.0678
# epoch 250 / 250, step 11/28, loss = 0.1053
# epoch 250 / 250, step 12/28, loss = 0.0117
# epoch 250 / 250, step 13/28, loss = 0.0205
# epoch 250 / 250, step 14/28, loss = 0.1466
# epoch 250 / 250, step 15/28, loss = 0.0360
# epoch 250 / 250, step 16/28, loss = 0.0731
# epoch 250 / 250, step 17/28, loss = 0.0895
# epoch 250 / 250, step 18/28, loss = 0.3313
# epoch 250 / 250, step 19/28, loss = 0.2058
# epoch 250 / 250, step 20/28, loss = 0.0959
# epoch 250 / 250, step 21/28, loss = 0.0593
# epoch 250 / 250, step 22/28, loss = 0.0501
# epoch 250 / 250, step 23/28, loss = 0.0619
# epoch 250 / 250, step 24/28, loss = 0.1473
# epoch 250 / 250, step 25/28, loss = 0.1910
# epoch 250 / 250, step 26/28, loss = 0.1701
# epoch 250 / 250, step 27/28, loss = 0.0105
# epoch 250 / 250, step 28/28, loss = 0.0068
# epoch 250 / 250, step 1/7, loss = 0.0659
# epoch 250 / 250, step 2/7, loss = 0.2731
# epoch 250 / 250, step 3/7, loss = 0.0212
# epoch 250 / 250, step 4/7, loss = 0.4482
# epoch 250 / 250, step 5/7, loss = 0.0971
# epoch 250 / 250, step 6/7, loss = 0.5026
# epoch 250 / 250, step 7/7, loss = 0.3572

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 250 epochs the trainning accuracy is 96.68571428571428 and the test accuaracy is 93.15068493150685
#  the maximum accuracy of the test was 94.52054794520548 at the epoch 192
#  the maximum accuracy of the train was 99.54285714285714 at the epoch 209
# the accuracy of the training at the best validation accuracy 94.52054794520548 is 98.17142857142858

# %%
print(model.state_dict())
torch.save(model.state_dict(), results_dir + "model_weights.pth")

# model.load_state_dict(torch.load(results_dir + "model_weights.pth"))
# Out:
# OrderedDict({'lstm.weight_ih_l0': tensor([[-0.0198, -0.0126, -0.0296,  ..., -0.0258, -0.0372,  0.0147],
#         [ 0.0303,  0.0312, -0.0129,  ...,  0.0214, -0.0110, -0.0312],
#         [-0.0243, -0.0206, -0.0191,  ..., -0.0008, -0.0289,  0.0128],
#         ...,
#         [-0.0025, -0.0372, -0.0070,  ..., -0.0258, -0.0084, -0.0214],
#         [-0.0251, -0.0161, -0.0182,  ..., -0.0215,  0.0230, -0.0118],
#         [ 0.0234, -0.0351,  0.0363,  ...,  0.0097,  0.0416,  0.0270]],
#        device='cuda:0'), 'lstm.weight_hh_l0': tensor([[-0.0103, -0.0636, -0.0173,  ..., -0.0004, -0.0380,  0.0437],
#         [-0.0143, -0.0132, -0.0015,  ..., -0.0349,  0.0307,  0.0422],
#         [ 0.0111,  0.0265, -0.0065,  ...,  0.0103,  0.0320, -0.0404],
#         ...,
#         [ 0.0094,  0.0323, -0.0380,  ..., -0.0292, -0.0367,  0.0035],
#         [ 0.0279, -0.0426,  0.0317,  ..., -0.0223,  0.0412, -0.0139],
#         [-0.0348, -0.0322,  0.0191,  ...,  0.0111,  0.0318, -0.0119]],
#        device='cuda:0'), 'lstm.bias_ih_l0': tensor([ 0.0091, -0.0262, -0.0222,  ...,  0.0473,  0.0473,  0.0251],
#        device='cuda:0'), 'lstm.bias_hh_l0': tensor([ 0.0465,  0.0320, -0.0075,  ..., -0.0063,  0.0624, -0.0375],
#        device='cuda:0'), 'lstm.weight_ih_l1': tensor([[-0.0182,  0.0179,  0.0036,  ..., -0.0211, -0.0368,  0.0262],
#         [ 0.0067, -0.0298,  0.0063,  ...,  0.0014, -0.0096, -0.0068],
#         [-0.0296,  0.0111,  0.0057,  ..., -0.0330, -0.0365,  0.0050],
#         ...,
#         [-0.0205, -0.0443,  0.0087,  ...,  0.0212,  0.0443, -0.0162],
#         [-0.0134, -0.0474, -0.0501,  ...,  0.0206, -0.0057, -0.0130],
#         [ 0.0381,  0.0014, -0.0270,  ...,  0.0486, -0.0258,  0.0041]],
#        device='cuda:0'), 'lstm.weight_hh_l1': tensor([[ 0.0259, -0.0080, -0.0529,  ...,  0.0070,  0.0027,  0.0060],
#         [-0.0024, -0.0141,  0.0509,  ...,  0.0130,  0.0291, -0.0213],
#         [-0.0450, -0.0386, -0.0382,  ..., -0.0068,  0.0158, -0.0063],
#         ...,
#         [-0.0260,  0.0131, -0.0198,  ..., -0.0371, -0.0095,  0.0282],
#         [-0.0083, -0.0540, -0.0029,  ...,  0.0036, -0.0006, -0.0004],
#         [ 0.0423, -0.0254, -0.0415,  ..., -0.0132,  0.0079, -0.0041]],
#        device='cuda:0'), 'lstm.bias_ih_l1': tensor([ 0.0254, -0.0008,  0.0416,  ...,  0.0390,  0.0215,  0.0326],
#        device='cuda:0'), 'lstm.bias_hh_l1': tensor([ 0.0212,  0.0096, -0.0329,  ...,  0.0116,  0.0307,  0.0437],
#        device='cuda:0'), 'fc.weight': tensor([[-0.0033, -0.0330, -0.0945,  ..., -0.0601, -0.0299, -0.0006],
#         [-0.0114,  0.0097,  0.0437,  ..., -0.0547,  0.0336,  0.0392],
#         [ 0.0617,  0.0498, -0.0158,  ...,  0.0288,  0.0550,  0.0656],
#         ...,
#         [-0.0308, -0.0529, -0.0437,  ..., -0.0522, -0.0749, -0.0325],
#         [ 0.0458, -0.0571,  0.0380,  ...,  0.0065, -0.0672, -0.0868],
#         [-0.0312, -0.0321,  0.0271,  ..., -0.0041,  0.0752,  0.0233]],
#        device='cuda:0'), 'fc.bias': tensor([ 0.0626, -0.0024,  0.0100,  0.0276, -0.0393,  0.0021, -0.0485],
#        device='cuda:0')})

# %%
# Copy the 
shutil.copyfile('./lstm.ipynb', './' + results_dir + 'lstm_copy.ipynb')
# Out:
# './David/Tests/19/lstm_copy.ipynb'
