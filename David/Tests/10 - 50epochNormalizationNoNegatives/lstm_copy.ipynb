# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - Normalize from 0 to 1

# %%
filepath = 'Tests/10 - 50epochNormalizationNoNegatives'
script_dir = os.path.dirname('lstm.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs

# Turns negative values to 0
X[X < 0] = 0

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 50
batch_size = 16
learning_rate = 0.0001
num_layers = 2

input_size = 512 
sequence_length = 1502  
#input_size = 4 
#sequence_length = 28

# %%
# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [1.9083970e-04 1.1450381e-04 0.0000000e+00 ... 3.4351143e-04 3.8167938e-05
#  2.2900762e-04]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([1.9084e-04, 1.1450e-04, 0.0000e+00,  ..., 3.4351e-04, 3.8168e-05,
#         2.2901e-04]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([16, 769024]) , Labels shape: torch.Size([16])
# Input range after standardization: Min = 0.0, Max = 0.9999999403953552
# tensor([0.0000, 0.0000, 0.0004,  ..., 0.0000, 0.0000, 0.0000])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6])

# %%
# Create Model

# Model 
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(LSTM, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        
        # x -> (batch_size, seq, input_size)
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        self.fc = nn.Linear(hidden_size, num_classes)
        self.dropout = nn.Dropout(p=0.5)  # Inside LSTM clas

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out, _ = self.lstm(x, (h0,c0))

        # Dropout on output of LSTM
        out = self.dropout(out)

        # out: batch_size, seq_length, hidden_size
        # out (N, 6008, 128)
        # : all samples in batch, -1 last time step, : all features in hidden size

        out = out[:, -1, :] 
        
        # out (N, 128)
        out = self.fc(out)
        return out

# %%
model = LSTM(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# LSTM(
#   (lstm): LSTM(512, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 5,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/55, loss = 1.9555
# epoch 1 / 50, step 2/55, loss = 1.9287
# epoch 1 / 50, step 3/55, loss = 1.9702
# epoch 1 / 50, step 4/55, loss = 1.9824
# epoch 1 / 50, step 5/55, loss = 1.9444
# epoch 1 / 50, step 6/55, loss = 1.9128
# epoch 1 / 50, step 7/55, loss = 1.9317
# epoch 1 / 50, step 8/55, loss = 1.9644
# epoch 1 / 50, step 9/55, loss = 1.9496
# epoch 1 / 50, step 10/55, loss = 1.9621
# epoch 1 / 50, step 11/55, loss = 1.9335
# epoch 1 / 50, step 12/55, loss = 1.9511
# epoch 1 / 50, step 13/55, loss = 1.9561
# epoch 1 / 50, step 14/55, loss = 1.9110
# epoch 1 / 50, step 15/55, loss = 1.9294
# epoch 1 / 50, step 16/55, loss = 1.9750
# epoch 1 / 50, step 17/55, loss = 1.9611
# epoch 1 / 50, step 18/55, loss = 1.9286
# epoch 1 / 50, step 19/55, loss = 1.9565
# epoch 1 / 50, step 20/55, loss = 1.9425
# epoch 1 / 50, step 21/55, loss = 1.9872
# epoch 1 / 50, step 22/55, loss = 1.9422
# epoch 1 / 50, step 23/55, loss = 1.9376
# epoch 1 / 50, step 24/55, loss = 1.9215
# epoch 1 / 50, step 25/55, loss = 1.9359
# epoch 1 / 50, step 26/55, loss = 1.9685
# epoch 1 / 50, step 27/55, loss = 1.9152
# epoch 1 / 50, step 28/55, loss = 1.9430
# epoch 1 / 50, step 29/55, loss = 1.9531
# epoch 1 / 50, step 30/55, loss = 1.9656
# epoch 1 / 50, step 31/55, loss = 1.9646
# epoch 1 / 50, step 32/55, loss = 1.9283
# epoch 1 / 50, step 33/55, loss = 1.9693
# epoch 1 / 50, step 34/55, loss = 1.9645
# epoch 1 / 50, step 35/55, loss = 1.9854
# epoch 1 / 50, step 36/55, loss = 1.9608
# epoch 1 / 50, step 37/55, loss = 1.9743
# epoch 1 / 50, step 38/55, loss = 1.9761
# epoch 1 / 50, step 39/55, loss = 1.9467
# epoch 1 / 50, step 40/55, loss = 1.9564
# epoch 1 / 50, step 41/55, loss = 1.9503
# epoch 1 / 50, step 42/55, loss = 1.9563
# epoch 1 / 50, step 43/55, loss = 1.9929
# epoch 1 / 50, step 44/55, loss = 1.9353
# epoch 1 / 50, step 45/55, loss = 1.9539
# epoch 1 / 50, step 46/55, loss = 1.9398
# epoch 1 / 50, step 47/55, loss = 1.9391
# epoch 1 / 50, step 48/55, loss = 1.9588
# epoch 1 / 50, step 49/55, loss = 1.9292
# epoch 1 / 50, step 50/55, loss = 1.9306
# epoch 1 / 50, step 51/55, loss = 1.9750
# epoch 1 / 50, step 52/55, loss = 1.9663
# epoch 1 / 50, step 53/55, loss = 1.9624
# epoch 1 / 50, step 54/55, loss = 1.9360
# epoch 1 / 50, step 55/55, loss = 1.9525
# epoch 1 / 50, step 1/14, loss = 1.9339
# epoch 1 / 50, step 2/14, loss = 1.9390
# epoch 1 / 50, step 3/14, loss = 1.9318
# epoch 1 / 50, step 4/14, loss = 1.9674
# epoch 1 / 50, step 5/14, loss = 1.9569
# epoch 1 / 50, step 6/14, loss = 1.9310
# epoch 1 / 50, step 7/14, loss = 1.9358
# epoch 1 / 50, step 8/14, loss = 1.9519
# epoch 1 / 50, step 9/14, loss = 1.9690
# epoch 1 / 50, step 10/14, loss = 1.9550
# epoch 1 / 50, step 11/14, loss = 1.9437
# epoch 1 / 50, step 12/14, loss = 1.9326
# epoch 1 / 50, step 13/14, loss = 1.9172
# epoch 1 / 50, step 14/14, loss = 1.9570
# epoch 2 / 50, step 1/55, loss = 1.9444
# epoch 2 / 50, step 2/55, loss = 1.9633
# epoch 2 / 50, step 3/55, loss = 1.9532
# epoch 2 / 50, step 4/55, loss = 1.9682
# epoch 2 / 50, step 5/55, loss = 1.9354
# epoch 2 / 50, step 6/55, loss = 1.9772
# epoch 2 / 50, step 7/55, loss = 1.9542
# epoch 2 / 50, step 8/55, loss = 1.9379
# epoch 2 / 50, step 9/55, loss = 1.9688
# epoch 2 / 50, step 10/55, loss = 1.9339
# epoch 2 / 50, step 11/55, loss = 1.9559
# epoch 2 / 50, step 12/55, loss = 1.9373
# epoch 2 / 50, step 13/55, loss = 1.9490
# epoch 2 / 50, step 14/55, loss = 1.9473
# epoch 2 / 50, step 15/55, loss = 1.9718
# epoch 2 / 50, step 16/55, loss = 2.0133
# epoch 2 / 50, step 17/55, loss = 1.9723
# epoch 2 / 50, step 18/55, loss = 1.9532
# epoch 2 / 50, step 19/55, loss = 1.9237
# epoch 2 / 50, step 20/55, loss = 1.9531
# epoch 2 / 50, step 21/55, loss = 1.9635
# epoch 2 / 50, step 22/55, loss = 1.9348
# epoch 2 / 50, step 23/55, loss = 1.9201
# epoch 2 / 50, step 24/55, loss = 1.9513
# epoch 2 / 50, step 25/55, loss = 1.9411
# epoch 2 / 50, step 26/55, loss = 1.9691
# epoch 2 / 50, step 27/55, loss = 1.9354
# epoch 2 / 50, step 28/55, loss = 1.9174
# epoch 2 / 50, step 29/55, loss = 1.9471
# epoch 2 / 50, step 30/55, loss = 1.9303
# epoch 2 / 50, step 31/55, loss = 1.9444
# epoch 2 / 50, step 32/55, loss = 1.9569
# epoch 2 / 50, step 33/55, loss = 1.9275
# epoch 2 / 50, step 34/55, loss = 1.9456
# epoch 2 / 50, step 35/55, loss = 1.9401
# epoch 2 / 50, step 36/55, loss = 1.9498
# epoch 2 / 50, step 37/55, loss = 1.9521
# epoch 2 / 50, step 38/55, loss = 1.9343
# epoch 2 / 50, step 39/55, loss = 1.9487
# epoch 2 / 50, step 40/55, loss = 1.9513
# epoch 2 / 50, step 41/55, loss = 1.9226
# epoch 2 / 50, step 42/55, loss = 1.9576
# epoch 2 / 50, step 43/55, loss = 1.9472
# epoch 2 / 50, step 44/55, loss = 1.9022
# epoch 2 / 50, step 45/55, loss = 1.9434
# epoch 2 / 50, step 46/55, loss = 1.9313
# epoch 2 / 50, step 47/55, loss = 1.9680
# epoch 2 / 50, step 48/55, loss = 1.9522
# epoch 2 / 50, step 49/55, loss = 1.9511
# epoch 2 / 50, step 50/55, loss = 1.9548
# epoch 2 / 50, step 51/55, loss = 1.9549
# epoch 2 / 50, step 52/55, loss = 1.9408
# epoch 2 / 50, step 53/55, loss = 1.9581
# epoch 2 / 50, step 54/55, loss = 1.9474
# epoch 2 / 50, step 55/55, loss = 1.9664
# epoch 2 / 50, step 1/14, loss = 1.9340
# epoch 2 / 50, step 2/14, loss = 1.9402
# epoch 2 / 50, step 3/14, loss = 1.9379
# epoch 2 / 50, step 4/14, loss = 1.9634
# epoch 2 / 50, step 5/14, loss = 1.9526
# epoch 2 / 50, step 6/14, loss = 1.9206
# epoch 2 / 50, step 7/14, loss = 1.9373
# epoch 2 / 50, step 8/14, loss = 1.9468
# epoch 2 / 50, step 9/14, loss = 1.9630
# epoch 2 / 50, step 10/14, loss = 1.9546
# epoch 2 / 50, step 11/14, loss = 1.9373
# epoch 2 / 50, step 12/14, loss = 1.9342
# epoch 2 / 50, step 13/14, loss = 1.9197
# epoch 2 / 50, step 14/14, loss = 1.9512
# epoch 3 / 50, step 1/55, loss = 1.9152
# epoch 3 / 50, step 2/55, loss = 1.9364
# epoch 3 / 50, step 3/55, loss = 1.9396
# epoch 3 / 50, step 4/55, loss = 1.9606
# epoch 3 / 50, step 5/55, loss = 1.9346
# epoch 3 / 50, step 6/55, loss = 1.9498
# epoch 3 / 50, step 7/55, loss = 1.9372
# epoch 3 / 50, step 8/55, loss = 1.9433
# epoch 3 / 50, step 9/55, loss = 1.9296
# epoch 3 / 50, step 10/55, loss = 1.9393
# epoch 3 / 50, step 11/55, loss = 1.9342
# epoch 3 / 50, step 12/55, loss = 1.9568
# epoch 3 / 50, step 13/55, loss = 1.9217
# epoch 3 / 50, step 14/55, loss = 1.9710
# epoch 3 / 50, step 15/55, loss = 1.9253
# epoch 3 / 50, step 16/55, loss = 1.9496
# epoch 3 / 50, step 17/55, loss = 1.9445
# epoch 3 / 50, step 18/55, loss = 1.9544
# epoch 3 / 50, step 19/55, loss = 1.9188
# epoch 3 / 50, step 20/55, loss = 1.9102
# epoch 3 / 50, step 21/55, loss = 1.9865
# epoch 3 / 50, step 22/55, loss = 1.9336
# epoch 3 / 50, step 23/55, loss = 1.9406
# epoch 3 / 50, step 24/55, loss = 1.9404
# epoch 3 / 50, step 25/55, loss = 1.9527
# epoch 3 / 50, step 26/55, loss = 1.9575
# epoch 3 / 50, step 27/55, loss = 1.9421
# epoch 3 / 50, step 28/55, loss = 1.9355
# epoch 3 / 50, step 29/55, loss = 1.9421
# epoch 3 / 50, step 30/55, loss = 1.9156
# epoch 3 / 50, step 31/55, loss = 1.9438
# epoch 3 / 50, step 32/55, loss = 1.9460
# epoch 3 / 50, step 33/55, loss = 1.9403
# epoch 3 / 50, step 34/55, loss = 1.9315
# epoch 3 / 50, step 35/55, loss = 1.9442
# epoch 3 / 50, step 36/55, loss = 1.9268
# epoch 3 / 50, step 37/55, loss = 1.9535
# epoch 3 / 50, step 38/55, loss = 1.9340
# epoch 3 / 50, step 39/55, loss = 1.9451
# epoch 3 / 50, step 40/55, loss = 1.9502
# epoch 3 / 50, step 41/55, loss = 1.9294
# epoch 3 / 50, step 42/55, loss = 1.9748
# epoch 3 / 50, step 43/55, loss = 1.9474
# epoch 3 / 50, step 44/55, loss = 1.9899
# epoch 3 / 50, step 45/55, loss = 1.9604
# epoch 3 / 50, step 46/55, loss = 1.9373
# epoch 3 / 50, step 47/55, loss = 1.9168
# epoch 3 / 50, step 48/55, loss = 1.9547
# epoch 3 / 50, step 49/55, loss = 1.9023
# epoch 3 / 50, step 50/55, loss = 1.9523
# epoch 3 / 50, step 51/55, loss = 1.9687
# epoch 3 / 50, step 52/55, loss = 1.9265
# epoch 3 / 50, step 53/55, loss = 1.9434
# epoch 3 / 50, step 54/55, loss = 1.9403
# epoch 3 / 50, step 55/55, loss = 1.9329
# epoch 3 / 50, step 1/14, loss = 1.9348
# epoch 3 / 50, step 2/14, loss = 1.9433
# epoch 3 / 50, step 3/14, loss = 1.9476
# epoch 3 / 50, step 4/14, loss = 1.9584
# epoch 3 / 50, step 5/14, loss = 1.9464
# epoch 3 / 50, step 6/14, loss = 1.9059
# epoch 3 / 50, step 7/14, loss = 1.9404
# epoch 3 / 50, step 8/14, loss = 1.9398
# epoch 3 / 50, step 9/14, loss = 1.9542
# epoch 3 / 50, step 10/14, loss = 1.9547
# epoch 3 / 50, step 11/14, loss = 1.9281
# epoch 3 / 50, step 12/14, loss = 1.9374
# epoch 3 / 50, step 13/14, loss = 1.9242
# epoch 3 / 50, step 14/14, loss = 1.9432
# epoch 4 / 50, step 1/55, loss = 1.9350
# epoch 4 / 50, step 2/55, loss = 1.9298
# epoch 4 / 50, step 3/55, loss = 1.9320
# epoch 4 / 50, step 4/55, loss = 1.9490
# epoch 4 / 50, step 5/55, loss = 1.9006
# epoch 4 / 50, step 6/55, loss = 1.9244
# epoch 4 / 50, step 7/55, loss = 1.9683
# epoch 4 / 50, step 8/55, loss = 1.9284
# epoch 4 / 50, step 9/55, loss = 1.9382
# epoch 4 / 50, step 10/55, loss = 1.9645
# epoch 4 / 50, step 11/55, loss = 1.9590
# epoch 4 / 50, step 12/55, loss = 1.9149
# epoch 4 / 50, step 13/55, loss = 1.9245
# epoch 4 / 50, step 14/55, loss = 1.9702
# epoch 4 / 50, step 15/55, loss = 1.9956
# epoch 4 / 50, step 16/55, loss = 1.9690
# epoch 4 / 50, step 17/55, loss = 1.9126
# epoch 4 / 50, step 18/55, loss = 1.9764
# epoch 4 / 50, step 19/55, loss = 1.9270
# epoch 4 / 50, step 20/55, loss = 1.9398
# epoch 4 / 50, step 21/55, loss = 1.9246
# epoch 4 / 50, step 22/55, loss = 1.9626
# epoch 4 / 50, step 23/55, loss = 1.9197
# epoch 4 / 50, step 24/55, loss = 1.9658
# epoch 4 / 50, step 25/55, loss = 1.9401
# epoch 4 / 50, step 26/55, loss = 1.9333
# epoch 4 / 50, step 27/55, loss = 1.9580
# epoch 4 / 50, step 28/55, loss = 1.9415
# epoch 4 / 50, step 29/55, loss = 1.9240
# epoch 4 / 50, step 30/55, loss = 1.9487
# epoch 4 / 50, step 31/55, loss = 1.9258
# epoch 4 / 50, step 32/55, loss = 1.9499
# epoch 4 / 50, step 33/55, loss = 1.8975
# epoch 4 / 50, step 34/55, loss = 1.9639
# epoch 4 / 50, step 35/55, loss = 1.9526
# epoch 4 / 50, step 36/55, loss = 1.9427
# epoch 4 / 50, step 37/55, loss = 1.9344
# epoch 4 / 50, step 38/55, loss = 1.9057
# epoch 4 / 50, step 39/55, loss = 1.9936
# epoch 4 / 50, step 40/55, loss = 1.9330
# epoch 4 / 50, step 41/55, loss = 1.9345
# epoch 4 / 50, step 42/55, loss = 1.9317
# epoch 4 / 50, step 43/55, loss = 1.9324
# epoch 4 / 50, step 44/55, loss = 1.9565
# epoch 4 / 50, step 45/55, loss = 1.9615
# epoch 4 / 50, step 46/55, loss = 1.9067
# epoch 4 / 50, step 47/55, loss = 1.9372
# epoch 4 / 50, step 48/55, loss = 1.9478
# epoch 4 / 50, step 49/55, loss = 1.9420
# epoch 4 / 50, step 50/55, loss = 1.9225
# epoch 4 / 50, step 51/55, loss = 1.9258
# epoch 4 / 50, step 52/55, loss = 1.9474
# epoch 4 / 50, step 53/55, loss = 1.9435
# epoch 4 / 50, step 54/55, loss = 1.9274
# epoch 4 / 50, step 55/55, loss = 1.9368
# epoch 4 / 50, step 1/14, loss = 1.9342
# epoch 4 / 50, step 2/14, loss = 1.9451
# epoch 4 / 50, step 3/14, loss = 1.9564
# epoch 4 / 50, step 4/14, loss = 1.9549
# epoch 4 / 50, step 5/14, loss = 1.9435
# epoch 4 / 50, step 6/14, loss = 1.8887
# epoch 4 / 50, step 7/14, loss = 1.9436
# epoch 4 / 50, step 8/14, loss = 1.9304
# epoch 4 / 50, step 9/14, loss = 1.9471
# epoch 4 / 50, step 10/14, loss = 1.9583
# epoch 4 / 50, step 11/14, loss = 1.9221
# epoch 4 / 50, step 12/14, loss = 1.9421
# epoch 4 / 50, step 13/14, loss = 1.9298
# epoch 4 / 50, step 14/14, loss = 1.9365
# epoch 5 / 50, step 1/55, loss = 1.9573
# epoch 5 / 50, step 2/55, loss = 1.8991
# epoch 5 / 50, step 3/55, loss = 1.8752
# epoch 5 / 50, step 4/55, loss = 1.9509
# epoch 5 / 50, step 5/55, loss = 1.9412
# epoch 5 / 50, step 6/55, loss = 1.9003
# epoch 5 / 50, step 7/55, loss = 1.9139
# epoch 5 / 50, step 8/55, loss = 1.9618
# epoch 5 / 50, step 9/55, loss = 1.9417
# epoch 5 / 50, step 10/55, loss = 1.9422
# epoch 5 / 50, step 11/55, loss = 1.9541
# epoch 5 / 50, step 12/55, loss = 1.9197
# epoch 5 / 50, step 13/55, loss = 1.9460
# epoch 5 / 50, step 14/55, loss = 1.9572
# epoch 5 / 50, step 15/55, loss = 1.9330
# epoch 5 / 50, step 16/55, loss = 1.9147
# epoch 5 / 50, step 17/55, loss = 1.8974
# epoch 5 / 50, step 18/55, loss = 1.9447
# epoch 5 / 50, step 19/55, loss = 1.9515
# epoch 5 / 50, step 20/55, loss = 1.9181
# epoch 5 / 50, step 21/55, loss = 1.9451
# epoch 5 / 50, step 22/55, loss = 1.9374
# epoch 5 / 50, step 23/55, loss = 1.9325
# epoch 5 / 50, step 24/55, loss = 1.9225
# epoch 5 / 50, step 25/55, loss = 1.9540
# epoch 5 / 50, step 26/55, loss = 1.9325
# epoch 5 / 50, step 27/55, loss = 1.9108
# epoch 5 / 50, step 28/55, loss = 1.9788
# epoch 5 / 50, step 29/55, loss = 1.9366
# epoch 5 / 50, step 30/55, loss = 1.9014
# epoch 5 / 50, step 31/55, loss = 1.9429
# epoch 5 / 50, step 32/55, loss = 1.9326
# epoch 5 / 50, step 33/55, loss = 1.9544
# epoch 5 / 50, step 34/55, loss = 1.8905
# epoch 5 / 50, step 35/55, loss = 1.9501
# epoch 5 / 50, step 36/55, loss = 1.9744
# epoch 5 / 50, step 37/55, loss = 1.9540
# epoch 5 / 50, step 38/55, loss = 1.9333
# epoch 5 / 50, step 39/55, loss = 2.0185
# epoch 5 / 50, step 40/55, loss = 1.9441
# epoch 5 / 50, step 41/55, loss = 1.9474
# epoch 5 / 50, step 42/55, loss = 1.9188
# epoch 5 / 50, step 43/55, loss = 1.8990
# epoch 5 / 50, step 44/55, loss = 1.9421
# epoch 5 / 50, step 45/55, loss = 1.9349
# epoch 5 / 50, step 46/55, loss = 1.9478
# epoch 5 / 50, step 47/55, loss = 1.9826
# epoch 5 / 50, step 48/55, loss = 1.8621
# epoch 5 / 50, step 49/55, loss = 1.9519
# epoch 5 / 50, step 50/55, loss = 1.9693
# epoch 5 / 50, step 51/55, loss = 1.9283
# epoch 5 / 50, step 52/55, loss = 1.8876
# epoch 5 / 50, step 53/55, loss = 1.9535
# epoch 5 / 50, step 54/55, loss = 1.9464
# epoch 5 / 50, step 55/55, loss = 1.9125
# epoch 5 / 50, step 1/14, loss = 1.9404
# epoch 5 / 50, step 2/14, loss = 1.9528
# epoch 5 / 50, step 3/14, loss = 1.9782
# epoch 5 / 50, step 4/14, loss = 1.9507
# epoch 5 / 50, step 5/14, loss = 1.9367
# epoch 5 / 50, step 6/14, loss = 1.8647
# epoch 5 / 50, step 7/14, loss = 1.9514
# epoch 5 / 50, step 8/14, loss = 1.9233
# epoch 5 / 50, step 9/14, loss = 1.9352
# epoch 5 / 50, step 10/14, loss = 1.9631
# epoch 5 / 50, step 11/14, loss = 1.9093
# epoch 5 / 50, step 12/14, loss = 1.9505
# epoch 5 / 50, step 13/14, loss = 1.9386
# epoch 5 / 50, step 14/14, loss = 1.9275
# epoch 6 / 50, step 1/55, loss = 1.9054
# epoch 6 / 50, step 2/55, loss = 1.9632
# epoch 6 / 50, step 3/55, loss = 1.8902
# epoch 6 / 50, step 4/55, loss = 1.9535
# epoch 6 / 50, step 5/55, loss = 1.9099
# epoch 6 / 50, step 6/55, loss = 1.9280
# epoch 6 / 50, step 7/55, loss = 1.9414
# epoch 6 / 50, step 8/55, loss = 1.9149
# epoch 6 / 50, step 9/55, loss = 1.8886
# epoch 6 / 50, step 10/55, loss = 1.9401
# epoch 6 / 50, step 11/55, loss = 1.9729
# epoch 6 / 50, step 12/55, loss = 1.9560
# epoch 6 / 50, step 13/55, loss = 1.8889
# epoch 6 / 50, step 14/55, loss = 1.8888
# epoch 6 / 50, step 15/55, loss = 2.0159
# epoch 6 / 50, step 16/55, loss = 1.9145
# epoch 6 / 50, step 17/55, loss = 1.8156
# epoch 6 / 50, step 18/55, loss = 1.9541
# epoch 6 / 50, step 19/55, loss = 1.9801
# epoch 6 / 50, step 20/55, loss = 1.8957
# epoch 6 / 50, step 21/55, loss = 1.9419
# epoch 6 / 50, step 22/55, loss = 1.9325
# epoch 6 / 50, step 23/55, loss = 1.9379
# epoch 6 / 50, step 24/55, loss = 1.9119
# epoch 6 / 50, step 25/55, loss = 1.8709
# epoch 6 / 50, step 26/55, loss = 1.8806
# epoch 6 / 50, step 27/55, loss = 1.9969
# epoch 6 / 50, step 28/55, loss = 1.9417
# epoch 6 / 50, step 29/55, loss = 1.9434
# epoch 6 / 50, step 30/55, loss = 1.9737
# epoch 6 / 50, step 31/55, loss = 1.9360
# epoch 6 / 50, step 32/55, loss = 1.9507
# epoch 6 / 50, step 33/55, loss = 1.9187
# epoch 6 / 50, step 34/55, loss = 1.9216
# epoch 6 / 50, step 35/55, loss = 1.9617
# epoch 6 / 50, step 36/55, loss = 1.9492
# epoch 6 / 50, step 37/55, loss = 1.9705
# epoch 6 / 50, step 38/55, loss = 1.9570
# epoch 6 / 50, step 39/55, loss = 1.9703
# epoch 6 / 50, step 40/55, loss = 1.9136
# epoch 6 / 50, step 41/55, loss = 1.9200
# epoch 6 / 50, step 42/55, loss = 1.9612
# epoch 6 / 50, step 43/55, loss = 1.9422
# epoch 6 / 50, step 44/55, loss = 1.9548
# epoch 6 / 50, step 45/55, loss = 1.9313
# epoch 6 / 50, step 46/55, loss = 1.9939
# epoch 6 / 50, step 47/55, loss = 1.8963
# epoch 6 / 50, step 48/55, loss = 1.9743
# epoch 6 / 50, step 49/55, loss = 1.9402
# epoch 6 / 50, step 50/55, loss = 2.0074
# epoch 6 / 50, step 51/55, loss = 1.9398
# epoch 6 / 50, step 52/55, loss = 1.9503
# epoch 6 / 50, step 53/55, loss = 1.9175
# epoch 6 / 50, step 54/55, loss = 1.8641
# epoch 6 / 50, step 55/55, loss = 1.8779
# epoch 6 / 50, step 1/14, loss = 1.9409
# epoch 6 / 50, step 2/14, loss = 1.9496
# epoch 6 / 50, step 3/14, loss = 1.9790
# epoch 6 / 50, step 4/14, loss = 1.9480
# epoch 6 / 50, step 5/14, loss = 1.9399
# epoch 6 / 50, step 6/14, loss = 1.8616
# epoch 6 / 50, step 7/14, loss = 1.9513
# epoch 6 / 50, step 8/14, loss = 1.9186
# epoch 6 / 50, step 9/14, loss = 1.9368
# epoch 6 / 50, step 10/14, loss = 1.9643
# epoch 6 / 50, step 11/14, loss = 1.9125
# epoch 6 / 50, step 12/14, loss = 1.9539
# epoch 6 / 50, step 13/14, loss = 1.9426
# epoch 6 / 50, step 14/14, loss = 1.9272
# epoch 7 / 50, step 1/55, loss = 1.9887
# epoch 7 / 50, step 2/55, loss = 1.9446
# epoch 7 / 50, step 3/55, loss = 1.9412
# epoch 7 / 50, step 4/55, loss = 1.9171
# epoch 7 / 50, step 5/55, loss = 1.9174
# epoch 7 / 50, step 6/55, loss = 1.9091
# epoch 7 / 50, step 7/55, loss = 1.9911
# epoch 7 / 50, step 8/55, loss = 1.9926
# epoch 7 / 50, step 9/55, loss = 1.8645
# epoch 7 / 50, step 10/55, loss = 1.9947
# epoch 7 / 50, step 11/55, loss = 1.9197
# epoch 7 / 50, step 12/55, loss = 1.9441
# epoch 7 / 50, step 13/55, loss = 1.8967
# epoch 7 / 50, step 14/55, loss = 1.9198
# epoch 7 / 50, step 15/55, loss = 1.9331
# epoch 7 / 50, step 16/55, loss = 1.9356
# epoch 7 / 50, step 17/55, loss = 1.9441
# epoch 7 / 50, step 18/55, loss = 1.8974
# epoch 7 / 50, step 19/55, loss = 1.9801
# epoch 7 / 50, step 20/55, loss = 1.8998
# epoch 7 / 50, step 21/55, loss = 1.8531
# epoch 7 / 50, step 22/55, loss = 1.9414
# epoch 7 / 50, step 23/55, loss = 1.9132
# epoch 7 / 50, step 24/55, loss = 1.9129
# epoch 7 / 50, step 25/55, loss = 1.9327
# epoch 7 / 50, step 26/55, loss = 1.9348
# epoch 7 / 50, step 27/55, loss = 1.9135
# epoch 7 / 50, step 28/55, loss = 1.9166
# epoch 7 / 50, step 29/55, loss = 1.8937
# epoch 7 / 50, step 30/55, loss = 1.9014
# epoch 7 / 50, step 31/55, loss = 1.9926
# epoch 7 / 50, step 32/55, loss = 1.9519
# epoch 7 / 50, step 33/55, loss = 1.9466
# epoch 7 / 50, step 34/55, loss = 1.9735
# epoch 7 / 50, step 35/55, loss = 1.9275
# epoch 7 / 50, step 36/55, loss = 1.9266
# epoch 7 / 50, step 37/55, loss = 1.8709
# epoch 7 / 50, step 38/55, loss = 1.9545
# epoch 7 / 50, step 39/55, loss = 1.9348
# epoch 7 / 50, step 40/55, loss = 1.8756
# epoch 7 / 50, step 41/55, loss = 1.8936
# epoch 7 / 50, step 42/55, loss = 1.9139
# epoch 7 / 50, step 43/55, loss = 1.9453
# epoch 7 / 50, step 44/55, loss = 1.9950
# epoch 7 / 50, step 45/55, loss = 1.8881
# epoch 7 / 50, step 46/55, loss = 1.9742
# epoch 7 / 50, step 47/55, loss = 1.9093
# epoch 7 / 50, step 48/55, loss = 1.9430
# epoch 7 / 50, step 49/55, loss = 1.9637
# epoch 7 / 50, step 50/55, loss = 1.9518
# epoch 7 / 50, step 51/55, loss = 2.0354
# epoch 7 / 50, step 52/55, loss = 1.9576
# epoch 7 / 50, step 53/55, loss = 1.8638
# epoch 7 / 50, step 54/55, loss = 1.9533
# epoch 7 / 50, step 55/55, loss = 2.0245
# epoch 7 / 50, step 1/14, loss = 1.9473
# epoch 7 / 50, step 2/14, loss = 1.9561
# epoch 7 / 50, step 3/14, loss = 1.9934
# epoch 7 / 50, step 4/14, loss = 1.9454
# epoch 7 / 50, step 5/14, loss = 1.9352
# epoch 7 / 50, step 6/14, loss = 1.8514
# epoch 7 / 50, step 7/14, loss = 1.9559
# epoch 7 / 50, step 8/14, loss = 1.9203
# epoch 7 / 50, step 9/14, loss = 1.9270
# epoch 7 / 50, step 10/14, loss = 1.9669
# epoch 7 / 50, step 11/14, loss = 1.9069
# epoch 7 / 50, step 12/14, loss = 1.9568
# epoch 7 / 50, step 13/14, loss = 1.9478
# epoch 7 / 50, step 14/14, loss = 1.9260
# epoch 8 / 50, step 1/55, loss = 1.9447
# epoch 8 / 50, step 2/55, loss = 1.9280
# epoch 8 / 50, step 3/55, loss = 1.8994
# epoch 8 / 50, step 4/55, loss = 1.9673
# epoch 8 / 50, step 5/55, loss = 1.9844
# epoch 8 / 50, step 6/55, loss = 1.8865
# epoch 8 / 50, step 7/55, loss = 1.9094
# epoch 8 / 50, step 8/55, loss = 1.9397
# epoch 8 / 50, step 9/55, loss = 1.8916
# epoch 8 / 50, step 10/55, loss = 1.9675
# epoch 8 / 50, step 11/55, loss = 1.9462
# epoch 8 / 50, step 12/55, loss = 1.9829
# epoch 8 / 50, step 13/55, loss = 1.9376
# epoch 8 / 50, step 14/55, loss = 1.9882
# epoch 8 / 50, step 15/55, loss = 1.9600
# epoch 8 / 50, step 16/55, loss = 1.8982
# epoch 8 / 50, step 17/55, loss = 1.9459
# epoch 8 / 50, step 18/55, loss = 1.9031
# epoch 8 / 50, step 19/55, loss = 1.9537
# epoch 8 / 50, step 20/55, loss = 2.0125
# epoch 8 / 50, step 21/55, loss = 1.9516
# epoch 8 / 50, step 22/55, loss = 1.9810
# epoch 8 / 50, step 23/55, loss = 1.8938
# epoch 8 / 50, step 24/55, loss = 1.8173
# epoch 8 / 50, step 25/55, loss = 1.9493
# epoch 8 / 50, step 26/55, loss = 1.9159
# epoch 8 / 50, step 27/55, loss = 1.9286
# epoch 8 / 50, step 28/55, loss = 1.9408
# epoch 8 / 50, step 29/55, loss = 1.8949
# epoch 8 / 50, step 30/55, loss = 1.9450
# epoch 8 / 50, step 31/55, loss = 1.8887
# epoch 8 / 50, step 32/55, loss = 1.9615
# epoch 8 / 50, step 33/55, loss = 1.9741
# epoch 8 / 50, step 34/55, loss = 1.9942
# epoch 8 / 50, step 35/55, loss = 1.9490
# epoch 8 / 50, step 36/55, loss = 1.9263
# epoch 8 / 50, step 37/55, loss = 1.9406
# epoch 8 / 50, step 38/55, loss = 1.9011
# epoch 8 / 50, step 39/55, loss = 1.9210
# epoch 8 / 50, step 40/55, loss = 1.9071
# epoch 8 / 50, step 41/55, loss = 1.9179
# epoch 8 / 50, step 42/55, loss = 1.9440
# epoch 8 / 50, step 43/55, loss = 1.9414
# epoch 8 / 50, step 44/55, loss = 2.0002
# epoch 8 / 50, step 45/55, loss = 1.9251
# epoch 8 / 50, step 46/55, loss = 1.9057
# epoch 8 / 50, step 47/55, loss = 1.9773
# epoch 8 / 50, step 48/55, loss = 1.9070
# epoch 8 / 50, step 49/55, loss = 1.9131
# epoch 8 / 50, step 50/55, loss = 1.8986
# epoch 8 / 50, step 51/55, loss = 1.9488
# epoch 8 / 50, step 52/55, loss = 1.8859
# epoch 8 / 50, step 53/55, loss = 1.9303
# epoch 8 / 50, step 54/55, loss = 1.9620
# epoch 8 / 50, step 55/55, loss = 1.9648
# epoch 8 / 50, step 1/14, loss = 1.9438
# epoch 8 / 50, step 2/14, loss = 1.9501
# epoch 8 / 50, step 3/14, loss = 1.9822
# epoch 8 / 50, step 4/14, loss = 1.9460
# epoch 8 / 50, step 5/14, loss = 1.9395
# epoch 8 / 50, step 6/14, loss = 1.8579
# epoch 8 / 50, step 7/14, loss = 1.9508
# epoch 8 / 50, step 8/14, loss = 1.9215
# epoch 8 / 50, step 9/14, loss = 1.9352
# epoch 8 / 50, step 10/14, loss = 1.9635
# epoch 8 / 50, step 11/14, loss = 1.9117
# epoch 8 / 50, step 12/14, loss = 1.9522
# epoch 8 / 50, step 13/14, loss = 1.9416
# epoch 8 / 50, step 14/14, loss = 1.9296
# epoch 9 / 50, step 1/55, loss = 1.9018
# epoch 9 / 50, step 2/55, loss = 1.8931
# epoch 9 / 50, step 3/55, loss = 1.9447
# epoch 9 / 50, step 4/55, loss = 1.9254
# epoch 9 / 50, step 5/55, loss = 1.8774
# epoch 9 / 50, step 6/55, loss = 1.9584
# epoch 9 / 50, step 7/55, loss = 1.9109
# epoch 9 / 50, step 8/55, loss = 1.9178
# epoch 9 / 50, step 9/55, loss = 1.9376
# epoch 9 / 50, step 10/55, loss = 1.9459
# epoch 9 / 50, step 11/55, loss = 2.0244
# epoch 9 / 50, step 12/55, loss = 1.8827
# epoch 9 / 50, step 13/55, loss = 2.0081
# epoch 9 / 50, step 14/55, loss = 1.8824
# epoch 9 / 50, step 15/55, loss = 1.9050
# epoch 9 / 50, step 16/55, loss = 1.8961
# epoch 9 / 50, step 17/55, loss = 1.9481
# epoch 9 / 50, step 18/55, loss = 1.9406
# epoch 9 / 50, step 19/55, loss = 1.9024
# epoch 9 / 50, step 20/55, loss = 1.9660
# epoch 9 / 50, step 21/55, loss = 1.9580
# epoch 9 / 50, step 22/55, loss = 1.9566
# epoch 9 / 50, step 23/55, loss = 1.9166
# epoch 9 / 50, step 24/55, loss = 1.9202
# epoch 9 / 50, step 25/55, loss = 1.9770
# epoch 9 / 50, step 26/55, loss = 1.8992
# epoch 9 / 50, step 27/55, loss = 1.9247
# epoch 9 / 50, step 28/55, loss = 1.9500
# epoch 9 / 50, step 29/55, loss = 1.9446
# epoch 9 / 50, step 30/55, loss = 1.9726
# epoch 9 / 50, step 31/55, loss = 1.8925
# epoch 9 / 50, step 32/55, loss = 1.9522
# epoch 9 / 50, step 33/55, loss = 1.9527
# epoch 9 / 50, step 34/55, loss = 1.8585
# epoch 9 / 50, step 35/55, loss = 1.8696
# epoch 9 / 50, step 36/55, loss = 1.9433
# epoch 9 / 50, step 37/55, loss = 1.9032
# epoch 9 / 50, step 38/55, loss = 2.0217
# epoch 9 / 50, step 39/55, loss = 1.9649
# epoch 9 / 50, step 40/55, loss = 1.8330
# epoch 9 / 50, step 41/55, loss = 1.9296
# epoch 9 / 50, step 42/55, loss = 1.9381
# epoch 9 / 50, step 43/55, loss = 1.9963
# epoch 9 / 50, step 44/55, loss = 1.9760
# epoch 9 / 50, step 45/55, loss = 1.8902
# epoch 9 / 50, step 46/55, loss = 1.9282
# epoch 9 / 50, step 47/55, loss = 1.9535
# epoch 9 / 50, step 48/55, loss = 1.9352
# epoch 9 / 50, step 49/55, loss = 2.0077
# epoch 9 / 50, step 50/55, loss = 1.9492
# epoch 9 / 50, step 51/55, loss = 1.9632
# epoch 9 / 50, step 52/55, loss = 1.9797
# epoch 9 / 50, step 53/55, loss = 1.9959
# epoch 9 / 50, step 54/55, loss = 1.9079
# epoch 9 / 50, step 55/55, loss = 1.9342
# epoch 9 / 50, step 1/14, loss = 1.9455
# epoch 9 / 50, step 2/14, loss = 1.9528
# epoch 9 / 50, step 3/14, loss = 1.9866
# epoch 9 / 50, step 4/14, loss = 1.9436
# epoch 9 / 50, step 5/14, loss = 1.9379
# epoch 9 / 50, step 6/14, loss = 1.8551
# epoch 9 / 50, step 7/14, loss = 1.9532
# epoch 9 / 50, step 8/14, loss = 1.9200
# epoch 9 / 50, step 9/14, loss = 1.9304
# epoch 9 / 50, step 10/14, loss = 1.9641
# epoch 9 / 50, step 11/14, loss = 1.9104
# epoch 9 / 50, step 12/14, loss = 1.9541
# epoch 9 / 50, step 13/14, loss = 1.9476
# epoch 9 / 50, step 14/14, loss = 1.9285
# epoch 10 / 50, step 1/55, loss = 1.9423
# epoch 10 / 50, step 2/55, loss = 1.8758
# epoch 10 / 50, step 3/55, loss = 1.8726
# epoch 10 / 50, step 4/55, loss = 1.9089
# epoch 10 / 50, step 5/55, loss = 1.9850
# epoch 10 / 50, step 6/55, loss = 1.9361
# epoch 10 / 50, step 7/55, loss = 1.9280
# epoch 10 / 50, step 8/55, loss = 1.8685
# epoch 10 / 50, step 9/55, loss = 1.9342
# epoch 10 / 50, step 10/55, loss = 1.9633
# epoch 10 / 50, step 11/55, loss = 1.9542
# epoch 10 / 50, step 12/55, loss = 1.9158
# epoch 10 / 50, step 13/55, loss = 1.9589
# epoch 10 / 50, step 14/55, loss = 1.8904
# epoch 10 / 50, step 15/55, loss = 1.9513
# epoch 10 / 50, step 16/55, loss = 1.9689
# epoch 10 / 50, step 17/55, loss = 1.8714
# epoch 10 / 50, step 18/55, loss = 1.9462
# epoch 10 / 50, step 19/55, loss = 1.9320
# epoch 10 / 50, step 20/55, loss = 1.9020
# epoch 10 / 50, step 21/55, loss = 1.9349
# epoch 10 / 50, step 22/55, loss = 1.9553
# epoch 10 / 50, step 23/55, loss = 1.8972
# epoch 10 / 50, step 24/55, loss = 1.9883
# epoch 10 / 50, step 25/55, loss = 1.9947
# epoch 10 / 50, step 26/55, loss = 1.9251
# epoch 10 / 50, step 27/55, loss = 2.0162
# epoch 10 / 50, step 28/55, loss = 1.9139
# epoch 10 / 50, step 29/55, loss = 1.9135
# epoch 10 / 50, step 30/55, loss = 1.9228
# epoch 10 / 50, step 31/55, loss = 1.9139
# epoch 10 / 50, step 32/55, loss = 1.9403
# epoch 10 / 50, step 33/55, loss = 1.8902
# epoch 10 / 50, step 34/55, loss = 1.8989
# epoch 10 / 50, step 35/55, loss = 1.9574
# epoch 10 / 50, step 36/55, loss = 1.9096
# epoch 10 / 50, step 37/55, loss = 1.9467
# epoch 10 / 50, step 38/55, loss = 1.8808
# epoch 10 / 50, step 39/55, loss = 1.9944
# epoch 10 / 50, step 40/55, loss = 1.8472
# epoch 10 / 50, step 41/55, loss = 1.9653
# epoch 10 / 50, step 42/55, loss = 1.9040
# epoch 10 / 50, step 43/55, loss = 1.9437
# epoch 10 / 50, step 44/55, loss = 1.9148
# epoch 10 / 50, step 45/55, loss = 1.8581
# epoch 10 / 50, step 46/55, loss = 1.8965
# epoch 10 / 50, step 47/55, loss = 1.9979
# epoch 10 / 50, step 48/55, loss = 1.9829
# epoch 10 / 50, step 49/55, loss = 1.9587
# epoch 10 / 50, step 50/55, loss = 1.9773
# epoch 10 / 50, step 51/55, loss = 1.8971
# epoch 10 / 50, step 52/55, loss = 1.9349
# epoch 10 / 50, step 53/55, loss = 1.9326
# epoch 10 / 50, step 54/55, loss = 1.9962
# epoch 10 / 50, step 55/55, loss = 1.9955
# epoch 10 / 50, step 1/14, loss = 1.9489
# epoch 10 / 50, step 2/14, loss = 1.9540
# epoch 10 / 50, step 3/14, loss = 1.9909
# epoch 10 / 50, step 4/14, loss = 1.9428
# epoch 10 / 50, step 5/14, loss = 1.9373
# epoch 10 / 50, step 6/14, loss = 1.8523
# epoch 10 / 50, step 7/14, loss = 1.9539
# epoch 10 / 50, step 8/14, loss = 1.9223
# epoch 10 / 50, step 9/14, loss = 1.9305
# epoch 10 / 50, step 10/14, loss = 1.9634
# epoch 10 / 50, step 11/14, loss = 1.9083
# epoch 10 / 50, step 12/14, loss = 1.9542
# epoch 10 / 50, step 13/14, loss = 1.9462
# epoch 10 / 50, step 14/14, loss = 1.9289
# epoch 11 / 50, step 1/55, loss = 1.9905
# epoch 11 / 50, step 2/55, loss = 1.9336
# epoch 11 / 50, step 3/55, loss = 1.9524
# epoch 11 / 50, step 4/55, loss = 2.0258
# epoch 11 / 50, step 5/55, loss = 1.9225
# epoch 11 / 50, step 6/55, loss = 1.9561
# epoch 11 / 50, step 7/55, loss = 2.0183
# epoch 11 / 50, step 8/55, loss = 1.9509
# epoch 11 / 50, step 9/55, loss = 1.9193
# epoch 11 / 50, step 10/55, loss = 1.9720
# epoch 11 / 50, step 11/55, loss = 1.9154
# epoch 11 / 50, step 12/55, loss = 1.9294
# epoch 11 / 50, step 13/55, loss = 1.9386
# epoch 11 / 50, step 14/55, loss = 1.9495
# epoch 11 / 50, step 15/55, loss = 1.9495
# epoch 11 / 50, step 16/55, loss = 1.9198
# epoch 11 / 50, step 17/55, loss = 1.9073
# epoch 11 / 50, step 18/55, loss = 1.9320
# epoch 11 / 50, step 19/55, loss = 1.9591
# epoch 11 / 50, step 20/55, loss = 1.9340
# epoch 11 / 50, step 21/55, loss = 1.9294
# epoch 11 / 50, step 22/55, loss = 1.9291
# epoch 11 / 50, step 23/55, loss = 1.9686
# epoch 11 / 50, step 24/55, loss = 1.9193
# epoch 11 / 50, step 25/55, loss = 1.9416
# epoch 11 / 50, step 26/55, loss = 1.9453
# epoch 11 / 50, step 27/55, loss = 1.9010
# epoch 11 / 50, step 28/55, loss = 1.9178
# epoch 11 / 50, step 29/55, loss = 1.9469
# epoch 11 / 50, step 30/55, loss = 1.9499
# epoch 11 / 50, step 31/55, loss = 1.9749
# epoch 11 / 50, step 32/55, loss = 1.8723
# epoch 11 / 50, step 33/55, loss = 1.8746
# epoch 11 / 50, step 34/55, loss = 1.9084
# epoch 11 / 50, step 35/55, loss = 1.8515
# epoch 11 / 50, step 36/55, loss = 1.9557
# epoch 11 / 50, step 37/55, loss = 1.9517
# epoch 11 / 50, step 38/55, loss = 1.8941
# epoch 11 / 50, step 39/55, loss = 1.8969
# epoch 11 / 50, step 40/55, loss = 1.9918
# epoch 11 / 50, step 41/55, loss = 1.9700
# epoch 11 / 50, step 42/55, loss = 1.8961
# epoch 11 / 50, step 43/55, loss = 1.9010
# epoch 11 / 50, step 44/55, loss = 1.9634
# epoch 11 / 50, step 45/55, loss = 1.9577
# epoch 11 / 50, step 46/55, loss = 1.9524
# epoch 11 / 50, step 47/55, loss = 1.9969
# epoch 11 / 50, step 48/55, loss = 1.8977
# epoch 11 / 50, step 49/55, loss = 1.8989
# epoch 11 / 50, step 50/55, loss = 1.9587
# epoch 11 / 50, step 51/55, loss = 1.9172
# epoch 11 / 50, step 52/55, loss = 1.8894
# epoch 11 / 50, step 53/55, loss = 1.9004
# epoch 11 / 50, step 54/55, loss = 1.9089
# epoch 11 / 50, step 55/55, loss = 1.9028
# epoch 11 / 50, step 1/14, loss = 1.9447
# epoch 11 / 50, step 2/14, loss = 1.9522
# epoch 11 / 50, step 3/14, loss = 1.9852
# epoch 11 / 50, step 4/14, loss = 1.9441
# epoch 11 / 50, step 5/14, loss = 1.9373
# epoch 11 / 50, step 6/14, loss = 1.8579
# epoch 11 / 50, step 7/14, loss = 1.9525
# epoch 11 / 50, step 8/14, loss = 1.9205
# epoch 11 / 50, step 9/14, loss = 1.9287
# epoch 11 / 50, step 10/14, loss = 1.9637
# epoch 11 / 50, step 11/14, loss = 1.9103
# epoch 11 / 50, step 12/14, loss = 1.9528
# epoch 11 / 50, step 13/14, loss = 1.9483
# epoch 11 / 50, step 14/14, loss = 1.9286
# epoch 12 / 50, step 1/55, loss = 1.9074
# epoch 12 / 50, step 2/55, loss = 1.9338
# epoch 12 / 50, step 3/55, loss = 1.9150
# epoch 12 / 50, step 4/55, loss = 1.9226
# epoch 12 / 50, step 5/55, loss = 1.8804
# epoch 12 / 50, step 6/55, loss = 1.9547
# epoch 12 / 50, step 7/55, loss = 1.9278
# epoch 12 / 50, step 8/55, loss = 1.9225
# epoch 12 / 50, step 9/55, loss = 1.9243
# epoch 12 / 50, step 10/55, loss = 1.9334
# epoch 12 / 50, step 11/55, loss = 1.9623
# epoch 12 / 50, step 12/55, loss = 1.8783
# epoch 12 / 50, step 13/55, loss = 1.9294
# epoch 12 / 50, step 14/55, loss = 1.9624
# epoch 12 / 50, step 15/55, loss = 1.8849
# epoch 12 / 50, step 16/55, loss = 1.8821
# epoch 12 / 50, step 17/55, loss = 1.9122
# epoch 12 / 50, step 18/55, loss = 1.8075
# epoch 12 / 50, step 19/55, loss = 1.9273
# epoch 12 / 50, step 20/55, loss = 1.9431
# epoch 12 / 50, step 21/55, loss = 2.0167
# epoch 12 / 50, step 22/55, loss = 1.8812
# epoch 12 / 50, step 23/55, loss = 1.9246
# epoch 12 / 50, step 24/55, loss = 1.9694
# epoch 12 / 50, step 25/55, loss = 1.9786
# epoch 12 / 50, step 26/55, loss = 1.9641
# epoch 12 / 50, step 27/55, loss = 1.9204
# epoch 12 / 50, step 28/55, loss = 1.9470
# epoch 12 / 50, step 29/55, loss = 1.8938
# epoch 12 / 50, step 30/55, loss = 2.0248
# epoch 12 / 50, step 31/55, loss = 1.9565
# epoch 12 / 50, step 32/55, loss = 2.0063
# epoch 12 / 50, step 33/55, loss = 1.9706
# epoch 12 / 50, step 34/55, loss = 1.9033
# epoch 12 / 50, step 35/55, loss = 1.9867
# epoch 12 / 50, step 36/55, loss = 2.0018
# epoch 12 / 50, step 37/55, loss = 2.0020
# epoch 12 / 50, step 38/55, loss = 1.8906
# epoch 12 / 50, step 39/55, loss = 1.9638
# epoch 12 / 50, step 40/55, loss = 1.9460
# epoch 12 / 50, step 41/55, loss = 1.8913
# epoch 12 / 50, step 42/55, loss = 1.9051
# epoch 12 / 50, step 43/55, loss = 2.0057
# epoch 12 / 50, step 44/55, loss = 1.9861
# epoch 12 / 50, step 45/55, loss = 1.8579
# epoch 12 / 50, step 46/55, loss = 1.8910
# epoch 12 / 50, step 47/55, loss = 1.8809
# epoch 12 / 50, step 48/55, loss = 1.9653
# epoch 12 / 50, step 49/55, loss = 1.9609
# epoch 12 / 50, step 50/55, loss = 1.9019
# epoch 12 / 50, step 51/55, loss = 1.8941
# epoch 12 / 50, step 52/55, loss = 1.9301
# epoch 12 / 50, step 53/55, loss = 1.9338
# epoch 12 / 50, step 54/55, loss = 1.9850
# epoch 12 / 50, step 55/55, loss = 1.8714
# epoch 12 / 50, step 1/14, loss = 1.9455
# epoch 12 / 50, step 2/14, loss = 1.9524
# epoch 12 / 50, step 3/14, loss = 1.9851
# epoch 12 / 50, step 4/14, loss = 1.9442
# epoch 12 / 50, step 5/14, loss = 1.9368
# epoch 12 / 50, step 6/14, loss = 1.8588
# epoch 12 / 50, step 7/14, loss = 1.9521
# epoch 12 / 50, step 8/14, loss = 1.9221
# epoch 12 / 50, step 9/14, loss = 1.9283
# epoch 12 / 50, step 10/14, loss = 1.9628
# epoch 12 / 50, step 11/14, loss = 1.9094
# epoch 12 / 50, step 12/14, loss = 1.9515
# epoch 12 / 50, step 13/14, loss = 1.9477
# epoch 12 / 50, step 14/14, loss = 1.9294
# epoch 13 / 50, step 1/55, loss = 1.9344
# epoch 13 / 50, step 2/55, loss = 1.9624
# epoch 13 / 50, step 3/55, loss = 1.8794
# epoch 13 / 50, step 4/55, loss = 1.8706
# epoch 13 / 50, step 5/55, loss = 1.9016
# epoch 13 / 50, step 6/55, loss = 1.9455
# epoch 13 / 50, step 7/55, loss = 1.9423
# epoch 13 / 50, step 8/55, loss = 1.9932
# epoch 13 / 50, step 9/55, loss = 1.9751
# epoch 13 / 50, step 10/55, loss = 1.9007
# epoch 13 / 50, step 11/55, loss = 1.8933
# epoch 13 / 50, step 12/55, loss = 1.9293
# epoch 13 / 50, step 13/55, loss = 1.8636
# epoch 13 / 50, step 14/55, loss = 1.9946
# epoch 13 / 50, step 15/55, loss = 1.9433
# epoch 13 / 50, step 16/55, loss = 1.9740
# epoch 13 / 50, step 17/55, loss = 1.9243
# epoch 13 / 50, step 18/55, loss = 1.9299
# epoch 13 / 50, step 19/55, loss = 1.9637
# epoch 13 / 50, step 20/55, loss = 1.9000
# epoch 13 / 50, step 21/55, loss = 1.9669
# epoch 13 / 50, step 22/55, loss = 1.9622
# epoch 13 / 50, step 23/55, loss = 1.8726
# epoch 13 / 50, step 24/55, loss = 1.9569
# epoch 13 / 50, step 25/55, loss = 1.9352
# epoch 13 / 50, step 26/55, loss = 1.9295
# epoch 13 / 50, step 27/55, loss = 1.9770
# epoch 13 / 50, step 28/55, loss = 1.8953
# epoch 13 / 50, step 29/55, loss = 1.9522
# epoch 13 / 50, step 30/55, loss = 1.9514
# epoch 13 / 50, step 31/55, loss = 1.8115
# epoch 13 / 50, step 32/55, loss = 1.9358
# epoch 13 / 50, step 33/55, loss = 1.9403
# epoch 13 / 50, step 34/55, loss = 1.8931
# epoch 13 / 50, step 35/55, loss = 1.9500
# epoch 13 / 50, step 36/55, loss = 1.9073
# epoch 13 / 50, step 37/55, loss = 1.9360
# epoch 13 / 50, step 38/55, loss = 1.9697
# epoch 13 / 50, step 39/55, loss = 1.8816
# epoch 13 / 50, step 40/55, loss = 1.9234
# epoch 13 / 50, step 41/55, loss = 2.0121
# epoch 13 / 50, step 42/55, loss = 1.9282
# epoch 13 / 50, step 43/55, loss = 2.0235
# epoch 13 / 50, step 44/55, loss = 1.8569
# epoch 13 / 50, step 45/55, loss = 1.8928
# epoch 13 / 50, step 46/55, loss = 1.9101
# epoch 13 / 50, step 47/55, loss = 1.9504
# epoch 13 / 50, step 48/55, loss = 1.9543
# epoch 13 / 50, step 49/55, loss = 1.9323
# epoch 13 / 50, step 50/55, loss = 1.8994
# epoch 13 / 50, step 51/55, loss = 1.9013
# epoch 13 / 50, step 52/55, loss = 1.9670
# epoch 13 / 50, step 53/55, loss = 1.9835
# epoch 13 / 50, step 54/55, loss = 1.9040
# epoch 13 / 50, step 55/55, loss = 1.9235
# epoch 13 / 50, step 1/14, loss = 1.9461
# epoch 13 / 50, step 2/14, loss = 1.9563
# epoch 13 / 50, step 3/14, loss = 1.9894
# epoch 13 / 50, step 4/14, loss = 1.9433
# epoch 13 / 50, step 5/14, loss = 1.9352
# epoch 13 / 50, step 6/14, loss = 1.8540
# epoch 13 / 50, step 7/14, loss = 1.9552
# epoch 13 / 50, step 8/14, loss = 1.9199
# epoch 13 / 50, step 9/14, loss = 1.9233
# epoch 13 / 50, step 10/14, loss = 1.9644
# epoch 13 / 50, step 11/14, loss = 1.9061
# epoch 13 / 50, step 12/14, loss = 1.9530
# epoch 13 / 50, step 13/14, loss = 1.9546
# epoch 13 / 50, step 14/14, loss = 1.9279
# epoch 14 / 50, step 1/55, loss = 1.9083
# epoch 14 / 50, step 2/55, loss = 1.9381
# epoch 14 / 50, step 3/55, loss = 1.9229
# epoch 14 / 50, step 4/55, loss = 1.9221
# epoch 14 / 50, step 5/55, loss = 1.9757
# epoch 14 / 50, step 6/55, loss = 1.9038
# epoch 14 / 50, step 7/55, loss = 1.9421
# epoch 14 / 50, step 8/55, loss = 1.8774
# epoch 14 / 50, step 9/55, loss = 1.9184
# epoch 14 / 50, step 10/55, loss = 1.8845
# epoch 14 / 50, step 11/55, loss = 1.9081
# epoch 14 / 50, step 12/55, loss = 1.9117
# epoch 14 / 50, step 13/55, loss = 1.9705
# epoch 14 / 50, step 14/55, loss = 1.9906
# epoch 14 / 50, step 15/55, loss = 1.9614
# epoch 14 / 50, step 16/55, loss = 1.8928
# epoch 14 / 50, step 17/55, loss = 1.8956
# epoch 14 / 50, step 18/55, loss = 1.9592
# epoch 14 / 50, step 19/55, loss = 1.9521
# epoch 14 / 50, step 20/55, loss = 1.8381
# epoch 14 / 50, step 21/55, loss = 2.0149
# epoch 14 / 50, step 22/55, loss = 1.9953
# epoch 14 / 50, step 23/55, loss = 1.9474
# epoch 14 / 50, step 24/55, loss = 1.9180
# epoch 14 / 50, step 25/55, loss = 1.9192
# epoch 14 / 50, step 26/55, loss = 1.9153
# epoch 14 / 50, step 27/55, loss = 1.9530
# epoch 14 / 50, step 28/55, loss = 1.8773
# epoch 14 / 50, step 29/55, loss = 1.9701
# epoch 14 / 50, step 30/55, loss = 1.9405
# epoch 14 / 50, step 31/55, loss = 1.9240
# epoch 14 / 50, step 32/55, loss = 1.8844
# epoch 14 / 50, step 33/55, loss = 1.9345
# epoch 14 / 50, step 34/55, loss = 1.8877
# epoch 14 / 50, step 35/55, loss = 1.9355
# epoch 14 / 50, step 36/55, loss = 1.8750
# epoch 14 / 50, step 37/55, loss = 1.9520
# epoch 14 / 50, step 38/55, loss = 1.9233
# epoch 14 / 50, step 39/55, loss = 1.9577
# epoch 14 / 50, step 40/55, loss = 1.9596
# epoch 14 / 50, step 41/55, loss = 1.8709
# epoch 14 / 50, step 42/55, loss = 1.9454
# epoch 14 / 50, step 43/55, loss = 1.9045
# epoch 14 / 50, step 44/55, loss = 1.9520
# epoch 14 / 50, step 45/55, loss = 1.9957
# epoch 14 / 50, step 46/55, loss = 1.9276
# epoch 14 / 50, step 47/55, loss = 1.8779
# epoch 14 / 50, step 48/55, loss = 1.9018
# epoch 14 / 50, step 49/55, loss = 1.9721
# epoch 14 / 50, step 50/55, loss = 1.9379
# epoch 14 / 50, step 51/55, loss = 1.9253
# epoch 14 / 50, step 52/55, loss = 2.0171
# epoch 14 / 50, step 53/55, loss = 1.9283
# epoch 14 / 50, step 54/55, loss = 1.9327
# epoch 14 / 50, step 55/55, loss = 1.9746
# epoch 14 / 50, step 1/14, loss = 1.9474
# epoch 14 / 50, step 2/14, loss = 1.9604
# epoch 14 / 50, step 3/14, loss = 1.9936
# epoch 14 / 50, step 4/14, loss = 1.9427
# epoch 14 / 50, step 5/14, loss = 1.9326
# epoch 14 / 50, step 6/14, loss = 1.8529
# epoch 14 / 50, step 7/14, loss = 1.9586
# epoch 14 / 50, step 8/14, loss = 1.9178
# epoch 14 / 50, step 9/14, loss = 1.9161
# epoch 14 / 50, step 10/14, loss = 1.9657
# epoch 14 / 50, step 11/14, loss = 1.9019
# epoch 14 / 50, step 12/14, loss = 1.9553
# epoch 14 / 50, step 13/14, loss = 1.9629
# epoch 14 / 50, step 14/14, loss = 1.9259
# epoch 15 / 50, step 1/55, loss = 1.8717
# epoch 15 / 50, step 2/55, loss = 1.9062
# epoch 15 / 50, step 3/55, loss = 1.9745
# epoch 15 / 50, step 4/55, loss = 1.8260
# epoch 15 / 50, step 5/55, loss = 1.9121
# epoch 15 / 50, step 6/55, loss = 1.9040
# epoch 15 / 50, step 7/55, loss = 1.9482
# epoch 15 / 50, step 8/55, loss = 1.9051
# epoch 15 / 50, step 9/55, loss = 1.9379
# epoch 15 / 50, step 10/55, loss = 1.9275
# epoch 15 / 50, step 11/55, loss = 1.9502
# epoch 15 / 50, step 12/55, loss = 1.9308
# epoch 15 / 50, step 13/55, loss = 2.0040
# epoch 15 / 50, step 14/55, loss = 1.9132
# epoch 15 / 50, step 15/55, loss = 1.9707
# epoch 15 / 50, step 16/55, loss = 1.9506
# epoch 15 / 50, step 17/55, loss = 1.8591
# epoch 15 / 50, step 18/55, loss = 1.8524
# epoch 15 / 50, step 19/55, loss = 1.9568
# epoch 15 / 50, step 20/55, loss = 1.8986
# epoch 15 / 50, step 21/55, loss = 1.9866
# epoch 15 / 50, step 22/55, loss = 1.9415
# epoch 15 / 50, step 23/55, loss = 1.9788
# epoch 15 / 50, step 24/55, loss = 1.8980
# epoch 15 / 50, step 25/55, loss = 1.9498
# epoch 15 / 50, step 26/55, loss = 1.9900
# epoch 15 / 50, step 27/55, loss = 1.9328
# epoch 15 / 50, step 28/55, loss = 1.8416
# epoch 15 / 50, step 29/55, loss = 1.8622
# epoch 15 / 50, step 30/55, loss = 1.9184
# epoch 15 / 50, step 31/55, loss = 1.9760
# epoch 15 / 50, step 32/55, loss = 1.8743
# epoch 15 / 50, step 33/55, loss = 1.9357
# epoch 15 / 50, step 34/55, loss = 1.9375
# epoch 15 / 50, step 35/55, loss = 1.9884
# epoch 15 / 50, step 36/55, loss = 1.9731
# epoch 15 / 50, step 37/55, loss = 1.9145
# epoch 15 / 50, step 38/55, loss = 1.9448
# epoch 15 / 50, step 39/55, loss = 1.9297
# epoch 15 / 50, step 40/55, loss = 1.8706
# epoch 15 / 50, step 41/55, loss = 1.9780
# epoch 15 / 50, step 42/55, loss = 1.9822
# epoch 15 / 50, step 43/55, loss = 1.9322
# epoch 15 / 50, step 44/55, loss = 1.9580
# epoch 15 / 50, step 45/55, loss = 1.8770
# epoch 15 / 50, step 46/55, loss = 1.9405
# epoch 15 / 50, step 47/55, loss = 1.9578
# epoch 15 / 50, step 48/55, loss = 1.9892
# epoch 15 / 50, step 49/55, loss = 2.0162
# epoch 15 / 50, step 50/55, loss = 1.9237
# epoch 15 / 50, step 51/55, loss = 1.9237
# epoch 15 / 50, step 52/55, loss = 2.0331
# epoch 15 / 50, step 53/55, loss = 1.8776
# epoch 15 / 50, step 54/55, loss = 1.8897
# epoch 15 / 50, step 55/55, loss = 1.8490
# epoch 15 / 50, step 1/14, loss = 1.9443
# epoch 15 / 50, step 2/14, loss = 1.9556
# epoch 15 / 50, step 3/14, loss = 1.9902
# epoch 15 / 50, step 4/14, loss = 1.9454
# epoch 15 / 50, step 5/14, loss = 1.9341
# epoch 15 / 50, step 6/14, loss = 1.8547
# epoch 15 / 50, step 7/14, loss = 1.9550
# epoch 15 / 50, step 8/14, loss = 1.9184
# epoch 15 / 50, step 9/14, loss = 1.9194
# epoch 15 / 50, step 10/14, loss = 1.9667
# epoch 15 / 50, step 11/14, loss = 1.9048
# epoch 15 / 50, step 12/14, loss = 1.9524
# epoch 15 / 50, step 13/14, loss = 1.9565
# epoch 15 / 50, step 14/14, loss = 1.9268
# epoch 16 / 50, step 1/55, loss = 1.9770
# epoch 16 / 50, step 2/55, loss = 1.9923
# epoch 16 / 50, step 3/55, loss = 2.0255
# epoch 16 / 50, step 4/55, loss = 1.9706
# epoch 16 / 50, step 5/55, loss = 1.9378
# epoch 16 / 50, step 6/55, loss = 1.9548
# epoch 16 / 50, step 7/55, loss = 1.9004
# epoch 16 / 50, step 8/55, loss = 1.9282
# epoch 16 / 50, step 9/55, loss = 1.9216
# epoch 16 / 50, step 10/55, loss = 1.9153
# epoch 16 / 50, step 11/55, loss = 1.9526
# epoch 16 / 50, step 12/55, loss = 1.8574
# epoch 16 / 50, step 13/55, loss = 1.8720
# epoch 16 / 50, step 14/55, loss = 1.9631
# epoch 16 / 50, step 15/55, loss = 1.9843
# epoch 16 / 50, step 16/55, loss = 1.9135
# epoch 16 / 50, step 17/55, loss = 1.9467
# epoch 16 / 50, step 18/55, loss = 1.8835
# epoch 16 / 50, step 19/55, loss = 1.8601
# epoch 16 / 50, step 20/55, loss = 1.9556
# epoch 16 / 50, step 21/55, loss = 1.9661
# epoch 16 / 50, step 22/55, loss = 1.8900
# epoch 16 / 50, step 23/55, loss = 1.9051
# epoch 16 / 50, step 24/55, loss = 1.8946
# epoch 16 / 50, step 25/55, loss = 1.9582
# epoch 16 / 50, step 26/55, loss = 1.9123
# epoch 16 / 50, step 27/55, loss = 1.9868
# epoch 16 / 50, step 28/55, loss = 1.8988
# epoch 16 / 50, step 29/55, loss = 1.9291
# epoch 16 / 50, step 30/55, loss = 1.9171
# epoch 16 / 50, step 31/55, loss = 1.8713
# epoch 16 / 50, step 32/55, loss = 1.8721
# epoch 16 / 50, step 33/55, loss = 1.8700
# epoch 16 / 50, step 34/55, loss = 1.9286
# epoch 16 / 50, step 35/55, loss = 1.9723
# epoch 16 / 50, step 36/55, loss = 1.8932
# epoch 16 / 50, step 37/55, loss = 1.9909
# epoch 16 / 50, step 38/55, loss = 1.9498
# epoch 16 / 50, step 39/55, loss = 1.8989
# epoch 16 / 50, step 40/55, loss = 1.8877
# epoch 16 / 50, step 41/55, loss = 1.9373
# epoch 16 / 50, step 42/55, loss = 2.0311
# epoch 16 / 50, step 43/55, loss = 1.8674
# epoch 16 / 50, step 44/55, loss = 1.9175
# epoch 16 / 50, step 45/55, loss = 1.9619
# epoch 16 / 50, step 46/55, loss = 1.9611
# epoch 16 / 50, step 47/55, loss = 1.9514
# epoch 16 / 50, step 48/55, loss = 1.9087
# epoch 16 / 50, step 49/55, loss = 1.9572
# epoch 16 / 50, step 50/55, loss = 1.9751
# epoch 16 / 50, step 51/55, loss = 1.9183
# epoch 16 / 50, step 52/55, loss = 1.8897
# epoch 16 / 50, step 53/55, loss = 1.9225
# epoch 16 / 50, step 54/55, loss = 1.9057
# epoch 16 / 50, step 55/55, loss = 1.9439
# epoch 16 / 50, step 1/14, loss = 1.9441
# epoch 16 / 50, step 2/14, loss = 1.9553
# epoch 16 / 50, step 3/14, loss = 1.9899
# epoch 16 / 50, step 4/14, loss = 1.9431
# epoch 16 / 50, step 5/14, loss = 1.9353
# epoch 16 / 50, step 6/14, loss = 1.8534
# epoch 16 / 50, step 7/14, loss = 1.9555
# epoch 16 / 50, step 8/14, loss = 1.9159
# epoch 16 / 50, step 9/14, loss = 1.9180
# epoch 16 / 50, step 10/14, loss = 1.9667
# epoch 16 / 50, step 11/14, loss = 1.9054
# epoch 16 / 50, step 12/14, loss = 1.9526
# epoch 16 / 50, step 13/14, loss = 1.9610
# epoch 16 / 50, step 14/14, loss = 1.9274
# epoch 17 / 50, step 1/55, loss = 1.9807
# epoch 17 / 50, step 2/55, loss = 1.8880
# epoch 17 / 50, step 3/55, loss = 1.8768
# epoch 17 / 50, step 4/55, loss = 1.9813
# epoch 17 / 50, step 5/55, loss = 2.0103
# epoch 17 / 50, step 6/55, loss = 1.9883
# epoch 17 / 50, step 7/55, loss = 1.8882
# epoch 17 / 50, step 8/55, loss = 1.9331
# epoch 17 / 50, step 9/55, loss = 1.8760
# epoch 17 / 50, step 10/55, loss = 1.8543
# epoch 17 / 50, step 11/55, loss = 1.8830
# epoch 17 / 50, step 12/55, loss = 1.9378
# epoch 17 / 50, step 13/55, loss = 1.9043
# epoch 17 / 50, step 14/55, loss = 1.9403
# epoch 17 / 50, step 15/55, loss = 1.9715
# epoch 17 / 50, step 16/55, loss = 1.9422
# epoch 17 / 50, step 17/55, loss = 1.9406
# epoch 17 / 50, step 18/55, loss = 1.9538
# epoch 17 / 50, step 19/55, loss = 1.8890
# epoch 17 / 50, step 20/55, loss = 1.9605
# epoch 17 / 50, step 21/55, loss = 2.0002
# epoch 17 / 50, step 22/55, loss = 1.9062
# epoch 17 / 50, step 23/55, loss = 2.0281
# epoch 17 / 50, step 24/55, loss = 1.9409
# epoch 17 / 50, step 25/55, loss = 1.9516
# epoch 17 / 50, step 26/55, loss = 1.8798
# epoch 17 / 50, step 27/55, loss = 1.8958
# epoch 17 / 50, step 28/55, loss = 1.9554
# epoch 17 / 50, step 29/55, loss = 1.8604
# epoch 17 / 50, step 30/55, loss = 1.9840
# epoch 17 / 50, step 31/55, loss = 1.9071
# epoch 17 / 50, step 32/55, loss = 1.9575
# epoch 17 / 50, step 33/55, loss = 1.9788
# epoch 17 / 50, step 34/55, loss = 1.9539
# epoch 17 / 50, step 35/55, loss = 1.9320
# epoch 17 / 50, step 36/55, loss = 1.9019
# epoch 17 / 50, step 37/55, loss = 1.9458
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 31
#      28 n_samples_train = 0
#      30 # Training loop
# ---> 31 for i, (inputs, labels) in enumerate(train_loader):
#      33     inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
#      34     labels = labels.to(device)
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\_utils\fetch.py:55, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
# ---> 55 return self.collate_fn(data)
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\_utils\collate.py:398, in default_collate(batch)
#     337 def default_collate(batch):
#     338     r"""
#     339     Take in a batch of data and put the elements within the batch into a tensor with an additional outer dimension - batch size.
#     340
#    (...)
#     396         >>> default_collate(batch)  # Handle `CustomType` automatically
#     397     """
# --> 398     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\_utils\collate.py:212, in collate(batch, collate_fn_map)
#     208 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     210 if isinstance(elem, tuple):
#     211     return [
# --> 212         collate(samples, collate_fn_map=collate_fn_map)
#     213         for samples in transposed
#     214     ]  # Backwards compatibility.
#     215 else:
#     216     try:
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\_utils\collate.py:155, in collate(batch, collate_fn_map)
#     153 if collate_fn_map is not None:
#     154     if elem_type in collate_fn_map:
# --> 155         return collate_fn_map[elem_type](batch, collate_fn_map=collate_fn_map)
#     157     for collate_type in collate_fn_map:
#     158         if isinstance(elem, collate_type):
#
# File d:\Installations\anaconda3\envs\pytorch\Lib\site-packages\torch\utils\data\_utils\collate.py:272, in collate_tensor_fn(batch, collate_fn_map)
#     270     storage = elem._typed_storage()._new_shared(numel, device=elem.device)
#     271     out = elem.new(storage).resize_(len(batch), *list(elem.size()))
# --> 272 return torch.stack(batch, 0, out=out)
#
# KeyboardInterrupt:

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 50.74285714285714 and the test accuaracy is 36.986301369863014
#  the maximum accuracy of the test was 42.009132420091326 at the epoch 47
#  the maximum accuracy of the train was 53.142857142857146 at the epoch 48
# the accuracy of the training at the best validation accuracy 42.009132420091326 is 50.05714285714286

# %%
# Copy the 
shutil.copyfile('./lstm.ipynb', './' + results_dir + 'lstm_copy.ipynb')
# Out:
# './Tests/9 - 20epochNoNormalizationNoNegatives/lstm_copy.ipynb'
