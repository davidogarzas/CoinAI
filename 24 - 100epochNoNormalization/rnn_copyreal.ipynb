# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - learning rate 0.0005 a 0.001

# %%
filepath = '24 - 100epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 128
num_classes = 7
num_epochs = 200
batch_size = 16
learning_rate = 0.001
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([16, 769024]) , Labels shape: torch.Size([16])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1, 3, 0, 3, 5, 5, 1, 6, 6])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 128, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=128, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 200, step 1/55, loss = 2.2437
# epoch 1 / 200, step 2/55, loss = 2.0364
# epoch 1 / 200, step 3/55, loss = 2.0824
# epoch 1 / 200, step 4/55, loss = 1.9975
# epoch 1 / 200, step 5/55, loss = 1.8912
# epoch 1 / 200, step 6/55, loss = 2.2078
# epoch 1 / 200, step 7/55, loss = 1.9894
# epoch 1 / 200, step 8/55, loss = 1.9720
# epoch 1 / 200, step 9/55, loss = 2.1499
# epoch 1 / 200, step 10/55, loss = 1.9680
# epoch 1 / 200, step 11/55, loss = 2.2340
# epoch 1 / 200, step 12/55, loss = 2.1515
# epoch 1 / 200, step 13/55, loss = 2.1165
# epoch 1 / 200, step 14/55, loss = 1.8419
# epoch 1 / 200, step 15/55, loss = 2.0207
# epoch 1 / 200, step 16/55, loss = 2.1248
# epoch 1 / 200, step 17/55, loss = 2.1692
# epoch 1 / 200, step 18/55, loss = 2.1784
# epoch 1 / 200, step 19/55, loss = 1.8804
# epoch 1 / 200, step 20/55, loss = 1.9506
# epoch 1 / 200, step 21/55, loss = 2.1733
# epoch 1 / 200, step 22/55, loss = 1.8517
# epoch 1 / 200, step 23/55, loss = 2.0615
# epoch 1 / 200, step 24/55, loss = 1.9749
# epoch 1 / 200, step 25/55, loss = 1.7941
# epoch 1 / 200, step 26/55, loss = 2.0043
# epoch 1 / 200, step 27/55, loss = 1.9637
# epoch 1 / 200, step 28/55, loss = 1.9178
# epoch 1 / 200, step 29/55, loss = 1.8264
# epoch 1 / 200, step 30/55, loss = 2.0723
# epoch 1 / 200, step 31/55, loss = 2.1021
# epoch 1 / 200, step 32/55, loss = 2.1919
# epoch 1 / 200, step 33/55, loss = 2.0811
# epoch 1 / 200, step 34/55, loss = 2.2077
# epoch 1 / 200, step 35/55, loss = 2.0595
# epoch 1 / 200, step 36/55, loss = 1.9757
# epoch 1 / 200, step 37/55, loss = 1.8432
# epoch 1 / 200, step 38/55, loss = 2.1083
# epoch 1 / 200, step 39/55, loss = 2.2182
# epoch 1 / 200, step 40/55, loss = 2.0815
# epoch 1 / 200, step 41/55, loss = 1.6849
# epoch 1 / 200, step 42/55, loss = 1.9248
# epoch 1 / 200, step 43/55, loss = 2.0843
# epoch 1 / 200, step 44/55, loss = 2.0471
# epoch 1 / 200, step 45/55, loss = 1.9923
# epoch 1 / 200, step 46/55, loss = 2.1235
# epoch 1 / 200, step 47/55, loss = 2.1093
# epoch 1 / 200, step 48/55, loss = 2.0197
# epoch 1 / 200, step 49/55, loss = 2.1966
# epoch 1 / 200, step 50/55, loss = 2.2762
# epoch 1 / 200, step 51/55, loss = 2.0759
# epoch 1 / 200, step 52/55, loss = 2.0106
# epoch 1 / 200, step 53/55, loss = 1.9794
# epoch 1 / 200, step 54/55, loss = 1.9816
# epoch 1 / 200, step 55/55, loss = 1.8967
# epoch 1 / 200, step 1/14, loss = 1.9735
# epoch 1 / 200, step 2/14, loss = 2.0090
# epoch 1 / 200, step 3/14, loss = 2.0379
# epoch 1 / 200, step 4/14, loss = 2.0434
# epoch 1 / 200, step 5/14, loss = 1.9726
# epoch 1 / 200, step 6/14, loss = 1.8416
# epoch 1 / 200, step 7/14, loss = 1.9609
# epoch 1 / 200, step 8/14, loss = 1.8577
# epoch 1 / 200, step 9/14, loss = 1.9017
# epoch 1 / 200, step 10/14, loss = 2.0310
# epoch 1 / 200, step 11/14, loss = 1.8750
# epoch 1 / 200, step 12/14, loss = 1.9602
# epoch 1 / 200, step 13/14, loss = 2.0303
# epoch 1 / 200, step 14/14, loss = 1.8957
# epoch 2 / 200, step 1/55, loss = 2.0208
# epoch 2 / 200, step 2/55, loss = 2.1412
# epoch 2 / 200, step 3/55, loss = 2.0741
# epoch 2 / 200, step 4/55, loss = 1.9842
# epoch 2 / 200, step 5/55, loss = 1.9937
# epoch 2 / 200, step 6/55, loss = 2.2534
# epoch 2 / 200, step 7/55, loss = 1.9729
# epoch 2 / 200, step 8/55, loss = 2.0350
# epoch 2 / 200, step 9/55, loss = 2.0145
# epoch 2 / 200, step 10/55, loss = 2.1690
# epoch 2 / 200, step 11/55, loss = 1.9406
# epoch 2 / 200, step 12/55, loss = 1.8166
# epoch 2 / 200, step 13/55, loss = 1.9848
# epoch 2 / 200, step 14/55, loss = 2.1108
# epoch 2 / 200, step 15/55, loss = 2.0744
# epoch 2 / 200, step 16/55, loss = 1.9150
# epoch 2 / 200, step 17/55, loss = 2.1949
# epoch 2 / 200, step 18/55, loss = 1.9261
# epoch 2 / 200, step 19/55, loss = 2.0759
# epoch 2 / 200, step 20/55, loss = 2.0383
# epoch 2 / 200, step 21/55, loss = 2.0128
# epoch 2 / 200, step 22/55, loss = 1.8789
# epoch 2 / 200, step 23/55, loss = 2.2645
# epoch 2 / 200, step 24/55, loss = 1.9022
# epoch 2 / 200, step 25/55, loss = 2.1600
# epoch 2 / 200, step 26/55, loss = 1.9981
# epoch 2 / 200, step 27/55, loss = 2.0269
# epoch 2 / 200, step 28/55, loss = 1.9436
# epoch 2 / 200, step 29/55, loss = 1.9759
# epoch 2 / 200, step 30/55, loss = 1.8085
# epoch 2 / 200, step 31/55, loss = 1.9352
# epoch 2 / 200, step 32/55, loss = 1.9105
# epoch 2 / 200, step 33/55, loss = 2.0424
# epoch 2 / 200, step 34/55, loss = 2.0680
# epoch 2 / 200, step 35/55, loss = 2.1132
# epoch 2 / 200, step 36/55, loss = 2.2369
# epoch 2 / 200, step 37/55, loss = 2.1912
# epoch 2 / 200, step 38/55, loss = 1.9776
# epoch 2 / 200, step 39/55, loss = 2.1120
# epoch 2 / 200, step 40/55, loss = 2.0922
# epoch 2 / 200, step 41/55, loss = 2.0971
# epoch 2 / 200, step 42/55, loss = 2.0643
# epoch 2 / 200, step 43/55, loss = 1.8159
# epoch 2 / 200, step 44/55, loss = 2.0307
# epoch 2 / 200, step 45/55, loss = 2.0199
# epoch 2 / 200, step 46/55, loss = 2.2157
# epoch 2 / 200, step 47/55, loss = 1.9771
# epoch 2 / 200, step 48/55, loss = 1.9492
# epoch 2 / 200, step 49/55, loss = 1.9183
# epoch 2 / 200, step 50/55, loss = 2.0640
# epoch 2 / 200, step 51/55, loss = 1.9565
# epoch 2 / 200, step 52/55, loss = 1.9729
# epoch 2 / 200, step 53/55, loss = 2.1441
# epoch 2 / 200, step 54/55, loss = 1.7955
# epoch 2 / 200, step 55/55, loss = 2.0921
# epoch 2 / 200, step 1/14, loss = 1.8565
# epoch 2 / 200, step 2/14, loss = 1.9104
# epoch 2 / 200, step 3/14, loss = 1.9797
# epoch 2 / 200, step 4/14, loss = 2.0837
# epoch 2 / 200, step 5/14, loss = 1.9986
# epoch 2 / 200, step 6/14, loss = 1.8517
# epoch 2 / 200, step 7/14, loss = 1.9522
# epoch 2 / 200, step 8/14, loss = 1.8733
# epoch 2 / 200, step 9/14, loss = 1.9545
# epoch 2 / 200, step 10/14, loss = 2.1062
# epoch 2 / 200, step 11/14, loss = 1.9213
# epoch 2 / 200, step 12/14, loss = 1.9906
# epoch 2 / 200, step 13/14, loss = 2.0283
# epoch 2 / 200, step 14/14, loss = 1.9353
# epoch 3 / 200, step 1/55, loss = 1.8787
# epoch 3 / 200, step 2/55, loss = 2.0676
# epoch 3 / 200, step 3/55, loss = 2.1020
# epoch 3 / 200, step 4/55, loss = 2.0100
# epoch 3 / 200, step 5/55, loss = 2.0478
# epoch 3 / 200, step 6/55, loss = 1.7581
# epoch 3 / 200, step 7/55, loss = 2.1242
# epoch 3 / 200, step 8/55, loss = 1.9188
# epoch 3 / 200, step 9/55, loss = 2.0563
# epoch 3 / 200, step 10/55, loss = 1.9624
# epoch 3 / 200, step 11/55, loss = 1.7834
# epoch 3 / 200, step 12/55, loss = 1.9542
# epoch 3 / 200, step 13/55, loss = 1.9570
# epoch 3 / 200, step 14/55, loss = 2.1209
# epoch 3 / 200, step 15/55, loss = 1.8910
# epoch 3 / 200, step 16/55, loss = 1.8650
# epoch 3 / 200, step 17/55, loss = 1.9375
# epoch 3 / 200, step 18/55, loss = 2.0960
# epoch 3 / 200, step 19/55, loss = 2.2118
# epoch 3 / 200, step 20/55, loss = 2.1338
# epoch 3 / 200, step 21/55, loss = 1.8533
# epoch 3 / 200, step 22/55, loss = 2.1083
# epoch 3 / 200, step 23/55, loss = 2.0629
# epoch 3 / 200, step 24/55, loss = 2.0830
# epoch 3 / 200, step 25/55, loss = 1.8325
# epoch 3 / 200, step 26/55, loss = 1.8613
# epoch 3 / 200, step 27/55, loss = 2.1458
# epoch 3 / 200, step 28/55, loss = 2.0630
# epoch 3 / 200, step 29/55, loss = 1.9833
# epoch 3 / 200, step 30/55, loss = 1.9255
# epoch 3 / 200, step 31/55, loss = 1.8980
# epoch 3 / 200, step 32/55, loss = 1.8725
# epoch 3 / 200, step 33/55, loss = 2.0356
# epoch 3 / 200, step 34/55, loss = 2.0600
# epoch 3 / 200, step 35/55, loss = 1.9961
# epoch 3 / 200, step 36/55, loss = 2.1247
# epoch 3 / 200, step 37/55, loss = 2.0498
# epoch 3 / 200, step 38/55, loss = 1.8088
# epoch 3 / 200, step 39/55, loss = 2.2275
# epoch 3 / 200, step 40/55, loss = 1.7442
# epoch 3 / 200, step 41/55, loss = 2.0488
# epoch 3 / 200, step 42/55, loss = 1.8655
# epoch 3 / 200, step 43/55, loss = 1.9630
# epoch 3 / 200, step 44/55, loss = 2.0705
# epoch 3 / 200, step 45/55, loss = 2.0012
# epoch 3 / 200, step 46/55, loss = 1.9053
# epoch 3 / 200, step 47/55, loss = 2.2038
# epoch 3 / 200, step 48/55, loss = 1.9739
# epoch 3 / 200, step 49/55, loss = 2.0712
# epoch 3 / 200, step 50/55, loss = 1.9329
# epoch 3 / 200, step 51/55, loss = 2.1317
# epoch 3 / 200, step 52/55, loss = 2.1366
# epoch 3 / 200, step 53/55, loss = 1.8911
# epoch 3 / 200, step 54/55, loss = 1.9739
# epoch 3 / 200, step 55/55, loss = 1.9341
# epoch 3 / 200, step 1/14, loss = 1.9769
# epoch 3 / 200, step 2/14, loss = 2.0679
# epoch 3 / 200, step 3/14, loss = 1.9771
# epoch 3 / 200, step 4/14, loss = 1.9800
# epoch 3 / 200, step 5/14, loss = 1.9160
# epoch 3 / 200, step 6/14, loss = 1.9608
# epoch 3 / 200, step 7/14, loss = 2.0318
# epoch 3 / 200, step 8/14, loss = 1.9722
# epoch 3 / 200, step 9/14, loss = 1.8938
# epoch 3 / 200, step 10/14, loss = 1.9426
# epoch 3 / 200, step 11/14, loss = 1.8376
# epoch 3 / 200, step 12/14, loss = 2.0142
# epoch 3 / 200, step 13/14, loss = 2.1071
# epoch 3 / 200, step 14/14, loss = 1.9116
# epoch 4 / 200, step 1/55, loss = 2.2119
# epoch 4 / 200, step 2/55, loss = 1.8640
# epoch 4 / 200, step 3/55, loss = 1.9613
# epoch 4 / 200, step 4/55, loss = 1.8958
# epoch 4 / 200, step 5/55, loss = 1.8071
# epoch 4 / 200, step 6/55, loss = 1.9980
# epoch 4 / 200, step 7/55, loss = 2.0646
# epoch 4 / 200, step 8/55, loss = 2.0574
# epoch 4 / 200, step 9/55, loss = 2.0317
# epoch 4 / 200, step 10/55, loss = 1.9051
# epoch 4 / 200, step 11/55, loss = 2.1717
# epoch 4 / 200, step 12/55, loss = 2.1823
# epoch 4 / 200, step 13/55, loss = 2.0724
# epoch 4 / 200, step 14/55, loss = 1.9848
# epoch 4 / 200, step 15/55, loss = 1.9110
# epoch 4 / 200, step 16/55, loss = 2.0064
# epoch 4 / 200, step 17/55, loss = 1.9932
# epoch 4 / 200, step 18/55, loss = 2.0594
# epoch 4 / 200, step 19/55, loss = 2.1340
# epoch 4 / 200, step 20/55, loss = 2.0523
# epoch 4 / 200, step 21/55, loss = 1.8612
# epoch 4 / 200, step 22/55, loss = 2.0799
# epoch 4 / 200, step 23/55, loss = 2.0498
# epoch 4 / 200, step 24/55, loss = 2.0395
# epoch 4 / 200, step 25/55, loss = 1.9060
# epoch 4 / 200, step 26/55, loss = 2.3301
# epoch 4 / 200, step 27/55, loss = 2.0003
# epoch 4 / 200, step 28/55, loss = 2.1501
# epoch 4 / 200, step 29/55, loss = 1.9374
# epoch 4 / 200, step 30/55, loss = 2.0912
# epoch 4 / 200, step 31/55, loss = 1.9390
# epoch 4 / 200, step 32/55, loss = 1.9639
# epoch 4 / 200, step 33/55, loss = 2.0052
# epoch 4 / 200, step 34/55, loss = 1.9155
# epoch 4 / 200, step 35/55, loss = 1.8623
# epoch 4 / 200, step 36/55, loss = 1.8761
# epoch 4 / 200, step 37/55, loss = 2.1542
# epoch 4 / 200, step 38/55, loss = 1.8853
# epoch 4 / 200, step 39/55, loss = 2.0076
# epoch 4 / 200, step 40/55, loss = 1.9643
# epoch 4 / 200, step 41/55, loss = 2.0051
# epoch 4 / 200, step 42/55, loss = 2.1657
# epoch 4 / 200, step 43/55, loss = 1.9392
# epoch 4 / 200, step 44/55, loss = 2.3359
# epoch 4 / 200, step 45/55, loss = 2.0094
# epoch 4 / 200, step 46/55, loss = 2.1695
# epoch 4 / 200, step 47/55, loss = 2.1378
# epoch 4 / 200, step 48/55, loss = 1.8794
# epoch 4 / 200, step 49/55, loss = 2.0642
# epoch 4 / 200, step 50/55, loss = 2.0447
# epoch 4 / 200, step 51/55, loss = 2.0211
# epoch 4 / 200, step 52/55, loss = 1.8557
# epoch 4 / 200, step 53/55, loss = 2.0799
# epoch 4 / 200, step 54/55, loss = 1.9353
# epoch 4 / 200, step 55/55, loss = 2.1087
# epoch 4 / 200, step 1/14, loss = 2.0154
# epoch 4 / 200, step 2/14, loss = 2.0496
# epoch 4 / 200, step 3/14, loss = 1.9374
# epoch 4 / 200, step 4/14, loss = 1.8591
# epoch 4 / 200, step 5/14, loss = 1.9353
# epoch 4 / 200, step 6/14, loss = 1.9770
# epoch 4 / 200, step 7/14, loss = 2.0390
# epoch 4 / 200, step 8/14, loss = 1.9384
# epoch 4 / 200, step 9/14, loss = 1.8989
# epoch 4 / 200, step 10/14, loss = 1.8791
# epoch 4 / 200, step 11/14, loss = 1.9582
# epoch 4 / 200, step 12/14, loss = 1.9937
# epoch 4 / 200, step 13/14, loss = 2.1636
# epoch 4 / 200, step 14/14, loss = 1.9794
# epoch 5 / 200, step 1/55, loss = 1.7882
# epoch 5 / 200, step 2/55, loss = 1.9053
# epoch 5 / 200, step 3/55, loss = 2.0180
# epoch 5 / 200, step 4/55, loss = 1.8388
# epoch 5 / 200, step 5/55, loss = 2.0740
# epoch 5 / 200, step 6/55, loss = 2.2074
# epoch 5 / 200, step 7/55, loss = 2.1668
# epoch 5 / 200, step 8/55, loss = 2.0030
# epoch 5 / 200, step 9/55, loss = 1.9314
# epoch 5 / 200, step 10/55, loss = 1.9374
# epoch 5 / 200, step 11/55, loss = 1.9145
# epoch 5 / 200, step 12/55, loss = 2.0055
# epoch 5 / 200, step 13/55, loss = 1.9410
# epoch 5 / 200, step 14/55, loss = 1.9336
# epoch 5 / 200, step 15/55, loss = 2.1004
# epoch 5 / 200, step 16/55, loss = 1.9207
# epoch 5 / 200, step 17/55, loss = 1.7491
# epoch 5 / 200, step 18/55, loss = 2.0981
# epoch 5 / 200, step 19/55, loss = 1.9342
# epoch 5 / 200, step 20/55, loss = 2.1091
# epoch 5 / 200, step 21/55, loss = 2.2345
# epoch 5 / 200, step 22/55, loss = 2.0058
# epoch 5 / 200, step 23/55, loss = 1.8950
# epoch 5 / 200, step 24/55, loss = 1.9847
# epoch 5 / 200, step 25/55, loss = 2.2151
# epoch 5 / 200, step 26/55, loss = 1.8217
# epoch 5 / 200, step 27/55, loss = 1.9332
# epoch 5 / 200, step 28/55, loss = 1.9187
# epoch 5 / 200, step 29/55, loss = 2.1186
# epoch 5 / 200, step 30/55, loss = 2.1168
# epoch 5 / 200, step 31/55, loss = 2.0981
# epoch 5 / 200, step 32/55, loss = 1.8927
# epoch 5 / 200, step 33/55, loss = 2.0078
# epoch 5 / 200, step 34/55, loss = 1.9618
# epoch 5 / 200, step 35/55, loss = 2.1010
# epoch 5 / 200, step 36/55, loss = 1.8943
# epoch 5 / 200, step 37/55, loss = 2.0346
# epoch 5 / 200, step 38/55, loss = 1.9037
# epoch 5 / 200, step 39/55, loss = 1.9710
# epoch 5 / 200, step 40/55, loss = 1.9762
# epoch 5 / 200, step 41/55, loss = 2.1914
# epoch 5 / 200, step 42/55, loss = 1.9878
# epoch 5 / 200, step 43/55, loss = 1.8706
# epoch 5 / 200, step 44/55, loss = 1.9627
# epoch 5 / 200, step 45/55, loss = 2.0130
# epoch 5 / 200, step 46/55, loss = 1.9797
# epoch 5 / 200, step 47/55, loss = 1.8470
# epoch 5 / 200, step 48/55, loss = 1.8765
# epoch 5 / 200, step 49/55, loss = 1.9925
# epoch 5 / 200, step 50/55, loss = 1.8378
# epoch 5 / 200, step 51/55, loss = 1.9742
# epoch 5 / 200, step 52/55, loss = 2.1515
# epoch 5 / 200, step 53/55, loss = 2.2290
# epoch 5 / 200, step 54/55, loss = 2.0942
# epoch 5 / 200, step 55/55, loss = 1.9222
# epoch 5 / 200, step 1/14, loss = 2.0851
# epoch 5 / 200, step 2/14, loss = 2.0299
# epoch 5 / 200, step 3/14, loss = 2.0632
# epoch 5 / 200, step 4/14, loss = 1.8671
# epoch 5 / 200, step 5/14, loss = 1.9223
# epoch 5 / 200, step 6/14, loss = 1.8805
# epoch 5 / 200, step 7/14, loss = 1.9948
# epoch 5 / 200, step 8/14, loss = 2.0510
# epoch 5 / 200, step 9/14, loss = 1.8756
# epoch 5 / 200, step 10/14, loss = 1.8941
# epoch 5 / 200, step 11/14, loss = 1.9387
# epoch 5 / 200, step 12/14, loss = 1.9551
# epoch 5 / 200, step 13/14, loss = 2.0552
# epoch 5 / 200, step 14/14, loss = 2.0350
# epoch 6 / 200, step 1/55, loss = 2.0113
# epoch 6 / 200, step 2/55, loss = 2.1271
# epoch 6 / 200, step 3/55, loss = 2.0443
# epoch 6 / 200, step 4/55, loss = 2.0031
# epoch 6 / 200, step 5/55, loss = 1.8703
# epoch 6 / 200, step 6/55, loss = 1.9547
# epoch 6 / 200, step 7/55, loss = 1.9035
# epoch 6 / 200, step 8/55, loss = 1.9311
# epoch 6 / 200, step 9/55, loss = 2.2116
# epoch 6 / 200, step 10/55, loss = 1.9860
# epoch 6 / 200, step 11/55, loss = 2.0059
# epoch 6 / 200, step 12/55, loss = 2.0780
# epoch 6 / 200, step 13/55, loss = 2.0738
# epoch 6 / 200, step 14/55, loss = 1.9072
# epoch 6 / 200, step 15/55, loss = 1.8301
# epoch 6 / 200, step 16/55, loss = 1.9574
# epoch 6 / 200, step 17/55, loss = 1.9894
# epoch 6 / 200, step 18/55, loss = 2.0142
# epoch 6 / 200, step 19/55, loss = 1.9444
# epoch 6 / 200, step 20/55, loss = 1.9188
# epoch 6 / 200, step 21/55, loss = 2.0494
# epoch 6 / 200, step 22/55, loss = 1.8335
# epoch 6 / 200, step 23/55, loss = 2.4244
# epoch 6 / 200, step 24/55, loss = 2.0654
# epoch 6 / 200, step 25/55, loss = 2.1732
# epoch 6 / 200, step 26/55, loss = 1.9131
# epoch 6 / 200, step 27/55, loss = 1.9503
# epoch 6 / 200, step 28/55, loss = 2.0705
# epoch 6 / 200, step 29/55, loss = 1.9929
# epoch 6 / 200, step 30/55, loss = 2.0341
# epoch 6 / 200, step 31/55, loss = 1.9382
# epoch 6 / 200, step 32/55, loss = 1.8784
# epoch 6 / 200, step 33/55, loss = 1.9750
# epoch 6 / 200, step 34/55, loss = 1.8609
# epoch 6 / 200, step 35/55, loss = 1.9115
# epoch 6 / 200, step 36/55, loss = 1.7356
# epoch 6 / 200, step 37/55, loss = 1.8910
# epoch 6 / 200, step 38/55, loss = 1.9550
# epoch 6 / 200, step 39/55, loss = 2.0353
# epoch 6 / 200, step 40/55, loss = 1.9981
# epoch 6 / 200, step 41/55, loss = 2.2288
# epoch 6 / 200, step 42/55, loss = 2.0318
# epoch 6 / 200, step 43/55, loss = 1.9378
# epoch 6 / 200, step 44/55, loss = 2.0354
# epoch 6 / 200, step 45/55, loss = 2.1753
# epoch 6 / 200, step 46/55, loss = 2.2551
# epoch 6 / 200, step 47/55, loss = 1.9258
# epoch 6 / 200, step 48/55, loss = 2.0194
# epoch 6 / 200, step 49/55, loss = 2.0949
# epoch 6 / 200, step 50/55, loss = 2.0868
# epoch 6 / 200, step 51/55, loss = 1.9765
# epoch 6 / 200, step 52/55, loss = 1.8738
# epoch 6 / 200, step 53/55, loss = 2.0141
# epoch 6 / 200, step 54/55, loss = 2.1525
# epoch 6 / 200, step 55/55, loss = 1.9901
# epoch 6 / 200, step 1/14, loss = 1.9895
# epoch 6 / 200, step 2/14, loss = 2.0133
# epoch 6 / 200, step 3/14, loss = 1.9764
# epoch 6 / 200, step 4/14, loss = 1.8601
# epoch 6 / 200, step 5/14, loss = 1.9118
# epoch 6 / 200, step 6/14, loss = 1.8931
# epoch 6 / 200, step 7/14, loss = 1.9830
# epoch 6 / 200, step 8/14, loss = 1.9558
# epoch 6 / 200, step 9/14, loss = 1.8826
# epoch 6 / 200, step 10/14, loss = 1.9082
# epoch 6 / 200, step 11/14, loss = 1.9543
# epoch 6 / 200, step 12/14, loss = 1.9717
# epoch 6 / 200, step 13/14, loss = 2.0807
# epoch 6 / 200, step 14/14, loss = 1.9880
# epoch 7 / 200, step 1/55, loss = 1.9822
# epoch 7 / 200, step 2/55, loss = 2.0390
# epoch 7 / 200, step 3/55, loss = 2.0110
# epoch 7 / 200, step 4/55, loss = 1.9385
# epoch 7 / 200, step 5/55, loss = 1.9004
# epoch 7 / 200, step 6/55, loss = 1.8894
# epoch 7 / 200, step 7/55, loss = 1.9252
# epoch 7 / 200, step 8/55, loss = 1.9477
# epoch 7 / 200, step 9/55, loss = 2.0701
# epoch 7 / 200, step 10/55, loss = 1.8176
# epoch 7 / 200, step 11/55, loss = 1.9862
# epoch 7 / 200, step 12/55, loss = 2.0864
# epoch 7 / 200, step 13/55, loss = 1.9515
# epoch 7 / 200, step 14/55, loss = 1.8778
# epoch 7 / 200, step 15/55, loss = 1.9331
# epoch 7 / 200, step 16/55, loss = 1.9290
# epoch 7 / 200, step 17/55, loss = 1.9648
# epoch 7 / 200, step 18/55, loss = 2.0592
# epoch 7 / 200, step 19/55, loss = 1.9657
# epoch 7 / 200, step 20/55, loss = 1.9110
# epoch 7 / 200, step 21/55, loss = 2.0863
# epoch 7 / 200, step 22/55, loss = 2.0056
# epoch 7 / 200, step 23/55, loss = 1.9723
# epoch 7 / 200, step 24/55, loss = 1.8037
# epoch 7 / 200, step 25/55, loss = 2.1587
# epoch 7 / 200, step 26/55, loss = 1.9735
# epoch 7 / 200, step 27/55, loss = 1.8840
# epoch 7 / 200, step 28/55, loss = 1.8481
# epoch 7 / 200, step 29/55, loss = 1.8396
# epoch 7 / 200, step 30/55, loss = 1.8961
# epoch 7 / 200, step 31/55, loss = 1.8401
# epoch 7 / 200, step 32/55, loss = 1.8868
# epoch 7 / 200, step 33/55, loss = 2.0612
# epoch 7 / 200, step 34/55, loss = 1.9616
# epoch 7 / 200, step 35/55, loss = 1.9259
# epoch 7 / 200, step 36/55, loss = 1.8711
# epoch 7 / 200, step 37/55, loss = 2.1534
# epoch 7 / 200, step 38/55, loss = 1.9056
# epoch 7 / 200, step 39/55, loss = 1.9440
# epoch 7 / 200, step 40/55, loss = 2.1583
# epoch 7 / 200, step 41/55, loss = 2.0331
# epoch 7 / 200, step 42/55, loss = 2.1068
# epoch 7 / 200, step 43/55, loss = 1.9592
# epoch 7 / 200, step 44/55, loss = 1.9209
# epoch 7 / 200, step 45/55, loss = 1.9802
# epoch 7 / 200, step 46/55, loss = 1.9704
# epoch 7 / 200, step 47/55, loss = 2.0684
# epoch 7 / 200, step 48/55, loss = 2.0528
# epoch 7 / 200, step 49/55, loss = 1.7952
# epoch 7 / 200, step 50/55, loss = 1.9186
# epoch 7 / 200, step 51/55, loss = 1.9501
# epoch 7 / 200, step 52/55, loss = 1.9285
# epoch 7 / 200, step 53/55, loss = 1.8461
# epoch 7 / 200, step 54/55, loss = 1.8832
# epoch 7 / 200, step 55/55, loss = 2.1640
# epoch 7 / 200, step 1/14, loss = 1.9749
# epoch 7 / 200, step 2/14, loss = 2.0127
# epoch 7 / 200, step 3/14, loss = 2.0332
# epoch 7 / 200, step 4/14, loss = 2.0240
# epoch 7 / 200, step 5/14, loss = 1.8727
# epoch 7 / 200, step 6/14, loss = 1.8966
# epoch 7 / 200, step 7/14, loss = 2.0048
# epoch 7 / 200, step 8/14, loss = 1.9529
# epoch 7 / 200, step 9/14, loss = 1.9400
# epoch 7 / 200, step 10/14, loss = 1.9887
# epoch 7 / 200, step 11/14, loss = 1.8390
# epoch 7 / 200, step 12/14, loss = 1.9809
# epoch 7 / 200, step 13/14, loss = 2.0469
# epoch 7 / 200, step 14/14, loss = 1.8741
# epoch 8 / 200, step 1/55, loss = 1.8499
# epoch 8 / 200, step 2/55, loss = 2.0106
# epoch 8 / 200, step 3/55, loss = 1.9210
# epoch 8 / 200, step 4/55, loss = 1.9070
# epoch 8 / 200, step 5/55, loss = 1.9990
# epoch 8 / 200, step 6/55, loss = 2.0238
# epoch 8 / 200, step 7/55, loss = 2.0383
# epoch 8 / 200, step 8/55, loss = 2.0466
# epoch 8 / 200, step 9/55, loss = 1.9489
# epoch 8 / 200, step 10/55, loss = 1.8491
# epoch 8 / 200, step 11/55, loss = 1.8046
# epoch 8 / 200, step 12/55, loss = 2.0275
# epoch 8 / 200, step 13/55, loss = 2.0969
# epoch 8 / 200, step 14/55, loss = 1.9887
# epoch 8 / 200, step 15/55, loss = 1.9313
# epoch 8 / 200, step 16/55, loss = 1.8527
# epoch 8 / 200, step 17/55, loss = 1.9761
# epoch 8 / 200, step 18/55, loss = 1.7940
# epoch 8 / 200, step 19/55, loss = 2.1084
# epoch 8 / 200, step 20/55, loss = 2.0637
# epoch 8 / 200, step 21/55, loss = 1.9816
# epoch 8 / 200, step 22/55, loss = 2.1960
# epoch 8 / 200, step 23/55, loss = 1.8418
# epoch 8 / 200, step 24/55, loss = 1.9410
# epoch 8 / 200, step 25/55, loss = 2.0724
# epoch 8 / 200, step 26/55, loss = 2.1755
# epoch 8 / 200, step 27/55, loss = 1.7941
# epoch 8 / 200, step 28/55, loss = 1.9714
# epoch 8 / 200, step 29/55, loss = 1.9064
# epoch 8 / 200, step 30/55, loss = 2.1745
# epoch 8 / 200, step 31/55, loss = 1.8801
# epoch 8 / 200, step 32/55, loss = 2.0607
# epoch 8 / 200, step 33/55, loss = 1.8781
# epoch 8 / 200, step 34/55, loss = 2.0296
# epoch 8 / 200, step 35/55, loss = 2.0631
# epoch 8 / 200, step 36/55, loss = 2.0806
# epoch 8 / 200, step 37/55, loss = 2.0296
# epoch 8 / 200, step 38/55, loss = 1.9513
# epoch 8 / 200, step 39/55, loss = 2.0631
# epoch 8 / 200, step 40/55, loss = 2.0257
# epoch 8 / 200, step 41/55, loss = 1.8917
# epoch 8 / 200, step 42/55, loss = 1.8642
# epoch 8 / 200, step 43/55, loss = 2.0907
# epoch 8 / 200, step 44/55, loss = 1.8805
# epoch 8 / 200, step 45/55, loss = 1.9996
# epoch 8 / 200, step 46/55, loss = 1.7738
# epoch 8 / 200, step 47/55, loss = 2.1225
# epoch 8 / 200, step 48/55, loss = 2.0324
# epoch 8 / 200, step 49/55, loss = 2.0565
# epoch 8 / 200, step 50/55, loss = 2.0839
# epoch 8 / 200, step 51/55, loss = 1.8778
# epoch 8 / 200, step 52/55, loss = 2.1227
# epoch 8 / 200, step 53/55, loss = 1.9610
# epoch 8 / 200, step 54/55, loss = 1.9945
# epoch 8 / 200, step 55/55, loss = 1.8620
# epoch 8 / 200, step 1/14, loss = 1.9561
# epoch 8 / 200, step 2/14, loss = 1.8862
# epoch 8 / 200, step 3/14, loss = 1.9805
# epoch 8 / 200, step 4/14, loss = 2.0173
# epoch 8 / 200, step 5/14, loss = 1.9628
# epoch 8 / 200, step 6/14, loss = 1.8639
# epoch 8 / 200, step 7/14, loss = 1.9176
# epoch 8 / 200, step 8/14, loss = 1.9623
# epoch 8 / 200, step 9/14, loss = 1.9798
# epoch 8 / 200, step 10/14, loss = 2.0163
# epoch 8 / 200, step 11/14, loss = 1.9612
# epoch 8 / 200, step 12/14, loss = 1.9382
# epoch 8 / 200, step 13/14, loss = 1.9214
# epoch 8 / 200, step 14/14, loss = 1.9688
# epoch 9 / 200, step 1/55, loss = 2.1086
# epoch 9 / 200, step 2/55, loss = 1.9843
# epoch 9 / 200, step 3/55, loss = 1.8453
# epoch 9 / 200, step 4/55, loss = 2.1085
# epoch 9 / 200, step 5/55, loss = 1.9100
# epoch 9 / 200, step 6/55, loss = 1.9603
# epoch 9 / 200, step 7/55, loss = 1.8655
# epoch 9 / 200, step 8/55, loss = 1.9275
# epoch 9 / 200, step 9/55, loss = 1.9373
# epoch 9 / 200, step 10/55, loss = 1.8728
# epoch 9 / 200, step 11/55, loss = 2.1552
# epoch 9 / 200, step 12/55, loss = 2.0728
# epoch 9 / 200, step 13/55, loss = 1.9468
# epoch 9 / 200, step 14/55, loss = 1.8510
# epoch 9 / 200, step 15/55, loss = 2.0263
# epoch 9 / 200, step 16/55, loss = 1.9497
# epoch 9 / 200, step 17/55, loss = 2.0488
# epoch 9 / 200, step 18/55, loss = 1.9680
# epoch 9 / 200, step 19/55, loss = 1.9927
# epoch 9 / 200, step 20/55, loss = 2.0296
# epoch 9 / 200, step 21/55, loss = 2.0103
# epoch 9 / 200, step 22/55, loss = 1.9903
# epoch 9 / 200, step 23/55, loss = 1.9066
# epoch 9 / 200, step 24/55, loss = 1.8517
# epoch 9 / 200, step 25/55, loss = 1.9519
# epoch 9 / 200, step 26/55, loss = 1.8937
# epoch 9 / 200, step 27/55, loss = 1.9626
# epoch 9 / 200, step 28/55, loss = 2.0790
# epoch 9 / 200, step 29/55, loss = 2.0525
# epoch 9 / 200, step 30/55, loss = 2.0272
# epoch 9 / 200, step 31/55, loss = 1.9585
# epoch 9 / 200, step 32/55, loss = 1.9202
# epoch 9 / 200, step 33/55, loss = 1.8981
# epoch 9 / 200, step 34/55, loss = 2.0449
# epoch 9 / 200, step 35/55, loss = 1.8597
# epoch 9 / 200, step 36/55, loss = 2.0321
# epoch 9 / 200, step 37/55, loss = 1.9320
# epoch 9 / 200, step 38/55, loss = 2.0474
# epoch 9 / 200, step 39/55, loss = 2.1036
# epoch 9 / 200, step 40/55, loss = 2.0753
# epoch 9 / 200, step 41/55, loss = 1.9443
# epoch 9 / 200, step 42/55, loss = 2.1878
# epoch 9 / 200, step 43/55, loss = 1.9622
# epoch 9 / 200, step 44/55, loss = 2.0626
# epoch 9 / 200, step 45/55, loss = 1.9845
# epoch 9 / 200, step 46/55, loss = 1.9596
# epoch 9 / 200, step 47/55, loss = 1.9370
# epoch 9 / 200, step 48/55, loss = 1.9457
# epoch 9 / 200, step 49/55, loss = 1.9743
# epoch 9 / 200, step 50/55, loss = 2.0173
# epoch 9 / 200, step 51/55, loss = 2.0120
# epoch 9 / 200, step 52/55, loss = 1.8981
# epoch 9 / 200, step 53/55, loss = 1.9812
# epoch 9 / 200, step 54/55, loss = 1.8403
# epoch 9 / 200, step 55/55, loss = 1.9446
# epoch 9 / 200, step 1/14, loss = 2.0135
# epoch 9 / 200, step 2/14, loss = 1.9902
# epoch 9 / 200, step 3/14, loss = 1.9942
# epoch 9 / 200, step 4/14, loss = 1.9215
# epoch 9 / 200, step 5/14, loss = 1.9047
# epoch 9 / 200, step 6/14, loss = 1.9077
# epoch 9 / 200, step 7/14, loss = 1.9629
# epoch 9 / 200, step 8/14, loss = 2.0311
# epoch 9 / 200, step 9/14, loss = 1.9054
# epoch 9 / 200, step 10/14, loss = 1.9067
# epoch 9 / 200, step 11/14, loss = 1.9211
# epoch 9 / 200, step 12/14, loss = 1.9170
# epoch 9 / 200, step 13/14, loss = 1.9856
# epoch 9 / 200, step 14/14, loss = 1.9749
# epoch 10 / 200, step 1/55, loss = 2.0021
# epoch 10 / 200, step 2/55, loss = 1.9101
# epoch 10 / 200, step 3/55, loss = 2.0249
# epoch 10 / 200, step 4/55, loss = 2.0002
# epoch 10 / 200, step 5/55, loss = 1.9916
# epoch 10 / 200, step 6/55, loss = 1.9980
# epoch 10 / 200, step 7/55, loss = 1.9457
# epoch 10 / 200, step 8/55, loss = 1.9681
# epoch 10 / 200, step 9/55, loss = 1.8831
# epoch 10 / 200, step 10/55, loss = 1.8176
# epoch 10 / 200, step 11/55, loss = 1.9850
# epoch 10 / 200, step 12/55, loss = 1.9136
# epoch 10 / 200, step 13/55, loss = 1.9193
# epoch 10 / 200, step 14/55, loss = 1.9019
# epoch 10 / 200, step 15/55, loss = 1.9192
# epoch 10 / 200, step 16/55, loss = 1.9920
# epoch 10 / 200, step 17/55, loss = 2.0913
# epoch 10 / 200, step 18/55, loss = 1.8507
# epoch 10 / 200, step 19/55, loss = 1.7779
# epoch 10 / 200, step 20/55, loss = 1.8803
# epoch 10 / 200, step 21/55, loss = 1.9469
# epoch 10 / 200, step 22/55, loss = 2.0194
# epoch 10 / 200, step 23/55, loss = 2.0589
# epoch 10 / 200, step 24/55, loss = 1.9052
# epoch 10 / 200, step 25/55, loss = 2.0014
# epoch 10 / 200, step 26/55, loss = 1.8629
# epoch 10 / 200, step 27/55, loss = 1.9401
# epoch 10 / 200, step 28/55, loss = 2.0940
# epoch 10 / 200, step 29/55, loss = 1.8778
# epoch 10 / 200, step 30/55, loss = 1.9592
# epoch 10 / 200, step 31/55, loss = 1.8945
# epoch 10 / 200, step 32/55, loss = 2.0028
# epoch 10 / 200, step 33/55, loss = 2.0610
# epoch 10 / 200, step 34/55, loss = 2.0514
# epoch 10 / 200, step 35/55, loss = 1.9456
# epoch 10 / 200, step 36/55, loss = 1.9575
# epoch 10 / 200, step 37/55, loss = 1.8528
# epoch 10 / 200, step 38/55, loss = 2.0198
# epoch 10 / 200, step 39/55, loss = 1.8963
# epoch 10 / 200, step 40/55, loss = 1.9480
# epoch 10 / 200, step 41/55, loss = 1.9170
# epoch 10 / 200, step 42/55, loss = 1.8515
# epoch 10 / 200, step 43/55, loss = 2.0521
# epoch 10 / 200, step 44/55, loss = 1.7679
# epoch 10 / 200, step 45/55, loss = 1.9931
# epoch 10 / 200, step 46/55, loss = 1.8687
# epoch 10 / 200, step 47/55, loss = 1.8045
# epoch 10 / 200, step 48/55, loss = 1.9265
# epoch 10 / 200, step 49/55, loss = 2.0741
# epoch 10 / 200, step 50/55, loss = 1.8093
# epoch 10 / 200, step 51/55, loss = 1.9445
# epoch 10 / 200, step 52/55, loss = 2.0409
# epoch 10 / 200, step 53/55, loss = 2.0235
# epoch 10 / 200, step 54/55, loss = 1.9473
# epoch 10 / 200, step 55/55, loss = 1.7095
# epoch 10 / 200, step 1/14, loss = 2.0286
# epoch 10 / 200, step 2/14, loss = 1.9776
# epoch 10 / 200, step 3/14, loss = 1.9582
# epoch 10 / 200, step 4/14, loss = 1.8955
# epoch 10 / 200, step 5/14, loss = 1.9881
# epoch 10 / 200, step 6/14, loss = 1.8530
# epoch 10 / 200, step 7/14, loss = 2.0394
# epoch 10 / 200, step 8/14, loss = 1.9428
# epoch 10 / 200, step 9/14, loss = 2.0152
# epoch 10 / 200, step 10/14, loss = 1.9033
# epoch 10 / 200, step 11/14, loss = 1.9505
# epoch 10 / 200, step 12/14, loss = 1.9921
# epoch 10 / 200, step 13/14, loss = 2.1615
# epoch 10 / 200, step 14/14, loss = 1.9311
# epoch 11 / 200, step 1/55, loss = 2.1054
# epoch 11 / 200, step 2/55, loss = 2.1856
# epoch 11 / 200, step 3/55, loss = 1.8819
# epoch 11 / 200, step 4/55, loss = 1.9466
# epoch 11 / 200, step 5/55, loss = 2.0438
# epoch 11 / 200, step 6/55, loss = 1.9685
# epoch 11 / 200, step 7/55, loss = 1.9259
# epoch 11 / 200, step 8/55, loss = 1.8176
# epoch 11 / 200, step 9/55, loss = 2.0183
# epoch 11 / 200, step 10/55, loss = 1.9481
# epoch 11 / 200, step 11/55, loss = 1.8796
# epoch 11 / 200, step 12/55, loss = 2.0237
# epoch 11 / 200, step 13/55, loss = 2.1227
# epoch 11 / 200, step 14/55, loss = 2.0858
# epoch 11 / 200, step 15/55, loss = 2.1718
# epoch 11 / 200, step 16/55, loss = 1.9979
# epoch 11 / 200, step 17/55, loss = 1.9199
# epoch 11 / 200, step 18/55, loss = 1.8865
# epoch 11 / 200, step 19/55, loss = 2.1135
# epoch 11 / 200, step 20/55, loss = 1.8123
# epoch 11 / 200, step 21/55, loss = 1.9836
# epoch 11 / 200, step 22/55, loss = 2.1480
# epoch 11 / 200, step 23/55, loss = 1.9898
# epoch 11 / 200, step 24/55, loss = 2.0643
# epoch 11 / 200, step 25/55, loss = 1.8951
# epoch 11 / 200, step 26/55, loss = 2.0512
# epoch 11 / 200, step 27/55, loss = 1.8561
# epoch 11 / 200, step 28/55, loss = 1.9004
# epoch 11 / 200, step 29/55, loss = 1.9677
# epoch 11 / 200, step 30/55, loss = 2.0173
# epoch 11 / 200, step 31/55, loss = 2.0587
# epoch 11 / 200, step 32/55, loss = 1.9642
# epoch 11 / 200, step 33/55, loss = 2.0329
# epoch 11 / 200, step 34/55, loss = 2.1623
# epoch 11 / 200, step 35/55, loss = 1.9454
# epoch 11 / 200, step 36/55, loss = 1.8747
# epoch 11 / 200, step 37/55, loss = 1.9295
# epoch 11 / 200, step 38/55, loss = 1.9745
# epoch 11 / 200, step 39/55, loss = 1.8883
# epoch 11 / 200, step 40/55, loss = 1.8238
# epoch 11 / 200, step 41/55, loss = 2.0027
# epoch 11 / 200, step 42/55, loss = 2.0326
# epoch 11 / 200, step 43/55, loss = 1.9668
# epoch 11 / 200, step 44/55, loss = 1.8042
# epoch 11 / 200, step 45/55, loss = 2.0772
# epoch 11 / 200, step 46/55, loss = 2.1255
# epoch 11 / 200, step 47/55, loss = 1.9175
# epoch 11 / 200, step 48/55, loss = 1.8568
# epoch 11 / 200, step 49/55, loss = 1.9302
# epoch 11 / 200, step 50/55, loss = 2.0090
# epoch 11 / 200, step 51/55, loss = 2.0122
# epoch 11 / 200, step 52/55, loss = 2.0473
# epoch 11 / 200, step 53/55, loss = 1.9548
# epoch 11 / 200, step 54/55, loss = 1.9602
# epoch 11 / 200, step 55/55, loss = 1.8993
# epoch 11 / 200, step 1/14, loss = 1.9745
# epoch 11 / 200, step 2/14, loss = 1.9389
# epoch 11 / 200, step 3/14, loss = 1.9900
# epoch 11 / 200, step 4/14, loss = 1.9395
# epoch 11 / 200, step 5/14, loss = 1.9565
# epoch 11 / 200, step 6/14, loss = 1.8383
# epoch 11 / 200, step 7/14, loss = 1.9630
# epoch 11 / 200, step 8/14, loss = 1.9112
# epoch 11 / 200, step 9/14, loss = 1.9977
# epoch 11 / 200, step 10/14, loss = 1.9649
# epoch 11 / 200, step 11/14, loss = 1.9327
# epoch 11 / 200, step 12/14, loss = 1.9936
# epoch 11 / 200, step 13/14, loss = 2.0404
# epoch 11 / 200, step 14/14, loss = 1.9258
# epoch 12 / 200, step 1/55, loss = 1.9795
# epoch 12 / 200, step 2/55, loss = 1.9760
# epoch 12 / 200, step 3/55, loss = 1.9754
# epoch 12 / 200, step 4/55, loss = 2.1301
# epoch 12 / 200, step 5/55, loss = 1.8927
# epoch 12 / 200, step 6/55, loss = 1.8497
# epoch 12 / 200, step 7/55, loss = 1.9646
# epoch 12 / 200, step 8/55, loss = 1.9333
# epoch 12 / 200, step 9/55, loss = 1.8357
# epoch 12 / 200, step 10/55, loss = 1.9656
# epoch 12 / 200, step 11/55, loss = 1.9432
# epoch 12 / 200, step 12/55, loss = 1.9962
# epoch 12 / 200, step 13/55, loss = 1.9991
# epoch 12 / 200, step 14/55, loss = 2.0658
# epoch 12 / 200, step 15/55, loss = 2.0617
# epoch 12 / 200, step 16/55, loss = 1.8736
# epoch 12 / 200, step 17/55, loss = 1.8442
# epoch 12 / 200, step 18/55, loss = 1.8494
# epoch 12 / 200, step 19/55, loss = 1.9428
# epoch 12 / 200, step 20/55, loss = 1.8833
# epoch 12 / 200, step 21/55, loss = 2.0257
# epoch 12 / 200, step 22/55, loss = 2.0322
# epoch 12 / 200, step 23/55, loss = 2.0434
# epoch 12 / 200, step 24/55, loss = 1.9104
# epoch 12 / 200, step 25/55, loss = 2.0212
# epoch 12 / 200, step 26/55, loss = 1.9987
# epoch 12 / 200, step 27/55, loss = 2.0739
# epoch 12 / 200, step 28/55, loss = 1.9005
# epoch 12 / 200, step 29/55, loss = 2.0139
# epoch 12 / 200, step 30/55, loss = 1.9320
# epoch 12 / 200, step 31/55, loss = 1.9715
# epoch 12 / 200, step 32/55, loss = 1.9607
# epoch 12 / 200, step 33/55, loss = 1.8789
# epoch 12 / 200, step 34/55, loss = 1.9646
# epoch 12 / 200, step 35/55, loss = 1.8279
# epoch 12 / 200, step 36/55, loss = 1.9935
# epoch 12 / 200, step 37/55, loss = 1.9731
# epoch 12 / 200, step 38/55, loss = 1.9357
# epoch 12 / 200, step 39/55, loss = 1.8814
# epoch 12 / 200, step 40/55, loss = 2.1272
# epoch 12 / 200, step 41/55, loss = 2.1246
# epoch 12 / 200, step 42/55, loss = 1.9134
# epoch 12 / 200, step 43/55, loss = 1.9885
# epoch 12 / 200, step 44/55, loss = 1.9958
# epoch 12 / 200, step 45/55, loss = 2.0195
# epoch 12 / 200, step 46/55, loss = 2.0218
# epoch 12 / 200, step 47/55, loss = 2.0098
# epoch 12 / 200, step 48/55, loss = 1.8730
# epoch 12 / 200, step 49/55, loss = 1.9404
# epoch 12 / 200, step 50/55, loss = 2.0510
# epoch 12 / 200, step 51/55, loss = 2.0029
# epoch 12 / 200, step 52/55, loss = 1.8944
# epoch 12 / 200, step 53/55, loss = 1.9505
# epoch 12 / 200, step 54/55, loss = 1.9304
# epoch 12 / 200, step 55/55, loss = 1.9144
# epoch 12 / 200, step 1/14, loss = 1.8963
# epoch 12 / 200, step 2/14, loss = 1.9477
# epoch 12 / 200, step 3/14, loss = 1.9005
# epoch 12 / 200, step 4/14, loss = 2.0358
# epoch 12 / 200, step 5/14, loss = 1.9549
# epoch 12 / 200, step 6/14, loss = 1.8579
# epoch 12 / 200, step 7/14, loss = 1.9655
# epoch 12 / 200, step 8/14, loss = 1.8738
# epoch 12 / 200, step 9/14, loss = 1.9935
# epoch 12 / 200, step 10/14, loss = 1.9971
# epoch 12 / 200, step 11/14, loss = 1.8883
# epoch 12 / 200, step 12/14, loss = 1.9780
# epoch 12 / 200, step 13/14, loss = 2.0351
# epoch 12 / 200, step 14/14, loss = 1.8876
# epoch 13 / 200, step 1/55, loss = 2.0047
# epoch 13 / 200, step 2/55, loss = 1.9130
# epoch 13 / 200, step 3/55, loss = 2.0384
# epoch 13 / 200, step 4/55, loss = 2.0558
# epoch 13 / 200, step 5/55, loss = 1.8986
# epoch 13 / 200, step 6/55, loss = 1.8980
# epoch 13 / 200, step 7/55, loss = 1.9392
# epoch 13 / 200, step 8/55, loss = 1.9854
# epoch 13 / 200, step 9/55, loss = 2.0750
# epoch 13 / 200, step 10/55, loss = 1.9256
# epoch 13 / 200, step 11/55, loss = 2.0804
# epoch 13 / 200, step 12/55, loss = 1.9260
# epoch 13 / 200, step 13/55, loss = 1.8766
# epoch 13 / 200, step 14/55, loss = 1.9845
# epoch 13 / 200, step 15/55, loss = 1.9577
# epoch 13 / 200, step 16/55, loss = 2.0081
# epoch 13 / 200, step 17/55, loss = 2.0865
# epoch 13 / 200, step 18/55, loss = 1.9276
# epoch 13 / 200, step 19/55, loss = 2.0499
# epoch 13 / 200, step 20/55, loss = 1.8815
# epoch 13 / 200, step 21/55, loss = 2.0487
# epoch 13 / 200, step 22/55, loss = 1.8844
# epoch 13 / 200, step 23/55, loss = 2.0321
# epoch 13 / 200, step 24/55, loss = 1.9606
# epoch 13 / 200, step 25/55, loss = 1.9982
# epoch 13 / 200, step 26/55, loss = 1.9373
# epoch 13 / 200, step 27/55, loss = 1.8391
# epoch 13 / 200, step 28/55, loss = 1.9496
# epoch 13 / 200, step 29/55, loss = 2.1234
# epoch 13 / 200, step 30/55, loss = 2.0223
# epoch 13 / 200, step 31/55, loss = 2.0490
# epoch 13 / 200, step 32/55, loss = 1.9692
# epoch 13 / 200, step 33/55, loss = 1.9158
# epoch 13 / 200, step 34/55, loss = 1.9619
# epoch 13 / 200, step 35/55, loss = 2.0359
# epoch 13 / 200, step 36/55, loss = 1.8525
# epoch 13 / 200, step 37/55, loss = 1.9033
# epoch 13 / 200, step 38/55, loss = 1.8925
# epoch 13 / 200, step 39/55, loss = 1.9271
# epoch 13 / 200, step 40/55, loss = 1.9114
# epoch 13 / 200, step 41/55, loss = 1.8869
# epoch 13 / 200, step 42/55, loss = 1.9705
# epoch 13 / 200, step 43/55, loss = 1.9558
# epoch 13 / 200, step 44/55, loss = 2.0374
# epoch 13 / 200, step 45/55, loss = 1.9175
# epoch 13 / 200, step 46/55, loss = 2.0242
# epoch 13 / 200, step 47/55, loss = 1.8622
# epoch 13 / 200, step 48/55, loss = 1.9375
# epoch 13 / 200, step 49/55, loss = 2.0554
# epoch 13 / 200, step 50/55, loss = 2.0703
# epoch 13 / 200, step 51/55, loss = 1.9074
# epoch 13 / 200, step 52/55, loss = 1.9507
# epoch 13 / 200, step 53/55, loss = 1.9599
# epoch 13 / 200, step 54/55, loss = 2.0449
# epoch 13 / 200, step 55/55, loss = 2.0439
# epoch 13 / 200, step 1/14, loss = 1.9586
# epoch 13 / 200, step 2/14, loss = 1.9944
# epoch 13 / 200, step 3/14, loss = 2.0875
# epoch 13 / 200, step 4/14, loss = 2.0041
# epoch 13 / 200, step 5/14, loss = 1.9242
# epoch 13 / 200, step 6/14, loss = 1.7079
# epoch 13 / 200, step 7/14, loss = 1.9891
# epoch 13 / 200, step 8/14, loss = 1.9276
# epoch 13 / 200, step 9/14, loss = 1.9015
# epoch 13 / 200, step 10/14, loss = 2.0803
# epoch 13 / 200, step 11/14, loss = 1.9408
# epoch 13 / 200, step 12/14, loss = 1.9723
# epoch 13 / 200, step 13/14, loss = 2.0424
# epoch 13 / 200, step 14/14, loss = 1.9697
# epoch 14 / 200, step 1/55, loss = 1.9388
# epoch 14 / 200, step 2/55, loss = 1.8563
# epoch 14 / 200, step 3/55, loss = 2.1072
# epoch 14 / 200, step 4/55, loss = 1.9830
# epoch 14 / 200, step 5/55, loss = 2.0538
# epoch 14 / 200, step 6/55, loss = 2.0676
# epoch 14 / 200, step 7/55, loss = 1.8415
# epoch 14 / 200, step 8/55, loss = 1.9129
# epoch 14 / 200, step 9/55, loss = 1.8881
# epoch 14 / 200, step 10/55, loss = 1.8268
# epoch 14 / 200, step 11/55, loss = 1.8957
# epoch 14 / 200, step 12/55, loss = 1.8876
# epoch 14 / 200, step 13/55, loss = 1.9715
# epoch 14 / 200, step 14/55, loss = 2.0055
# epoch 14 / 200, step 15/55, loss = 1.9514
# epoch 14 / 200, step 16/55, loss = 2.0156
# epoch 14 / 200, step 17/55, loss = 1.8174
# epoch 14 / 200, step 18/55, loss = 2.0465
# epoch 14 / 200, step 19/55, loss = 1.9552
# epoch 14 / 200, step 20/55, loss = 1.9631
# epoch 14 / 200, step 21/55, loss = 1.7841
# epoch 14 / 200, step 22/55, loss = 2.0157
# epoch 14 / 200, step 23/55, loss = 1.9829
# epoch 14 / 200, step 24/55, loss = 2.0928
# epoch 14 / 200, step 25/55, loss = 1.9417
# epoch 14 / 200, step 26/55, loss = 1.9556
# epoch 14 / 200, step 27/55, loss = 1.9542
# epoch 14 / 200, step 28/55, loss = 2.0117
# epoch 14 / 200, step 29/55, loss = 1.8726
# epoch 14 / 200, step 30/55, loss = 1.9061
# epoch 14 / 200, step 31/55, loss = 1.7532
# epoch 14 / 200, step 32/55, loss = 1.9119
# epoch 14 / 200, step 33/55, loss = 1.8577
# epoch 14 / 200, step 34/55, loss = 1.8769
# epoch 14 / 200, step 35/55, loss = 1.8590
# epoch 14 / 200, step 36/55, loss = 1.9895
# epoch 14 / 200, step 37/55, loss = 1.9220
# epoch 14 / 200, step 38/55, loss = 2.0632
# epoch 14 / 200, step 39/55, loss = 2.0004
# epoch 14 / 200, step 40/55, loss = 1.9317
# epoch 14 / 200, step 41/55, loss = 1.9642
# epoch 14 / 200, step 42/55, loss = 1.9242
# epoch 14 / 200, step 43/55, loss = 1.9282
# epoch 14 / 200, step 44/55, loss = 1.9622
# epoch 14 / 200, step 45/55, loss = 1.9890
# epoch 14 / 200, step 46/55, loss = 1.9459
# epoch 14 / 200, step 47/55, loss = 1.8007
# epoch 14 / 200, step 48/55, loss = 1.9270
# epoch 14 / 200, step 49/55, loss = 2.0041
# epoch 14 / 200, step 50/55, loss = 2.1097
# epoch 14 / 200, step 51/55, loss = 1.9159
# epoch 14 / 200, step 52/55, loss = 1.9090
# epoch 14 / 200, step 53/55, loss = 2.0642
# epoch 14 / 200, step 54/55, loss = 1.9458
# epoch 14 / 200, step 55/55, loss = 1.8852
# epoch 14 / 200, step 1/14, loss = 1.9442
# epoch 14 / 200, step 2/14, loss = 1.9502
# epoch 14 / 200, step 3/14, loss = 2.0147
# epoch 14 / 200, step 4/14, loss = 2.0112
# epoch 14 / 200, step 5/14, loss = 1.9217
# epoch 14 / 200, step 6/14, loss = 1.7888
# epoch 14 / 200, step 7/14, loss = 1.9595
# epoch 14 / 200, step 8/14, loss = 1.9572
# epoch 14 / 200, step 9/14, loss = 1.9133
# epoch 14 / 200, step 10/14, loss = 2.0137
# epoch 14 / 200, step 11/14, loss = 1.8951
# epoch 14 / 200, step 12/14, loss = 1.9211
# epoch 14 / 200, step 13/14, loss = 1.9993
# epoch 14 / 200, step 14/14, loss = 1.9439
# epoch 15 / 200, step 1/55, loss = 2.0594
# epoch 15 / 200, step 2/55, loss = 1.9599
# epoch 15 / 200, step 3/55, loss = 2.0362
# epoch 15 / 200, step 4/55, loss = 2.0602
# epoch 15 / 200, step 5/55, loss = 2.0144
# epoch 15 / 200, step 6/55, loss = 1.9978
# epoch 15 / 200, step 7/55, loss = 1.8763
# epoch 15 / 200, step 8/55, loss = 1.9181
# epoch 15 / 200, step 9/55, loss = 1.9406
# epoch 15 / 200, step 10/55, loss = 1.8995
# epoch 15 / 200, step 11/55, loss = 1.9960
# epoch 15 / 200, step 12/55, loss = 1.9320
# epoch 15 / 200, step 13/55, loss = 1.7927
# epoch 15 / 200, step 14/55, loss = 1.8351
# epoch 15 / 200, step 15/55, loss = 2.1172
# epoch 15 / 200, step 16/55, loss = 2.0189
# epoch 15 / 200, step 17/55, loss = 1.9457
# epoch 15 / 200, step 18/55, loss = 1.9995
# epoch 15 / 200, step 19/55, loss = 2.1250
# epoch 15 / 200, step 20/55, loss = 1.8003
# epoch 15 / 200, step 21/55, loss = 1.8978
# epoch 15 / 200, step 22/55, loss = 2.0581
# epoch 15 / 200, step 23/55, loss = 2.0816
# epoch 15 / 200, step 24/55, loss = 1.7824
# epoch 15 / 200, step 25/55, loss = 1.8743
# epoch 15 / 200, step 26/55, loss = 2.0882
# epoch 15 / 200, step 27/55, loss = 1.9827
# epoch 15 / 200, step 28/55, loss = 2.0961
# epoch 15 / 200, step 29/55, loss = 1.9664
# epoch 15 / 200, step 30/55, loss = 2.0355
# epoch 15 / 200, step 31/55, loss = 2.0723
# epoch 15 / 200, step 32/55, loss = 1.9459
# epoch 15 / 200, step 33/55, loss = 1.8260
# epoch 15 / 200, step 34/55, loss = 1.9148
# epoch 15 / 200, step 35/55, loss = 2.0382
# epoch 15 / 200, step 36/55, loss = 1.9735
# epoch 15 / 200, step 37/55, loss = 1.9503
# epoch 15 / 200, step 38/55, loss = 1.8839
# epoch 15 / 200, step 39/55, loss = 1.8979
# epoch 15 / 200, step 40/55, loss = 2.0066
# epoch 15 / 200, step 41/55, loss = 2.0006
# epoch 15 / 200, step 42/55, loss = 1.9235
# epoch 15 / 200, step 43/55, loss = 1.9006
# epoch 15 / 200, step 44/55, loss = 1.9557
# epoch 15 / 200, step 45/55, loss = 1.8981
# epoch 15 / 200, step 46/55, loss = 1.9040
# epoch 15 / 200, step 47/55, loss = 2.0377
# epoch 15 / 200, step 48/55, loss = 1.9616
# epoch 15 / 200, step 49/55, loss = 1.8852
# epoch 15 / 200, step 50/55, loss = 1.9528
# epoch 15 / 200, step 51/55, loss = 2.0456
# epoch 15 / 200, step 52/55, loss = 1.8707
# epoch 15 / 200, step 53/55, loss = 2.0374
# epoch 15 / 200, step 54/55, loss = 1.9436
# epoch 15 / 200, step 55/55, loss = 1.9046
# epoch 15 / 200, step 1/14, loss = 1.9650
# epoch 15 / 200, step 2/14, loss = 1.9216
# epoch 15 / 200, step 3/14, loss = 2.0083
# epoch 15 / 200, step 4/14, loss = 1.9808
# epoch 15 / 200, step 5/14, loss = 1.9476
# epoch 15 / 200, step 6/14, loss = 1.8122
# epoch 15 / 200, step 7/14, loss = 1.9476
# epoch 15 / 200, step 8/14, loss = 1.9228
# epoch 15 / 200, step 9/14, loss = 1.9485
# epoch 15 / 200, step 10/14, loss = 2.0049
# epoch 15 / 200, step 11/14, loss = 1.9380
# epoch 15 / 200, step 12/14, loss = 1.9848
# epoch 15 / 200, step 13/14, loss = 2.0078
# epoch 15 / 200, step 14/14, loss = 1.9377
# epoch 16 / 200, step 1/55, loss = 2.0268
# epoch 16 / 200, step 2/55, loss = 1.9688
# epoch 16 / 200, step 3/55, loss = 1.8807
# epoch 16 / 200, step 4/55, loss = 2.0326
# epoch 16 / 200, step 5/55, loss = 2.0748
# epoch 16 / 200, step 6/55, loss = 2.0330
# epoch 16 / 200, step 7/55, loss = 1.9052
# epoch 16 / 200, step 8/55, loss = 2.0506
# epoch 16 / 200, step 9/55, loss = 1.8833
# epoch 16 / 200, step 10/55, loss = 2.0565
# epoch 16 / 200, step 11/55, loss = 1.9616
# epoch 16 / 200, step 12/55, loss = 1.9762
# epoch 16 / 200, step 13/55, loss = 1.9725
# epoch 16 / 200, step 14/55, loss = 1.9808
# epoch 16 / 200, step 15/55, loss = 1.9446
# epoch 16 / 200, step 16/55, loss = 1.9218
# epoch 16 / 200, step 17/55, loss = 1.9030
# epoch 16 / 200, step 18/55, loss = 1.9654
# epoch 16 / 200, step 19/55, loss = 2.0030
# epoch 16 / 200, step 20/55, loss = 1.9537
# epoch 16 / 200, step 21/55, loss = 1.9900
# epoch 16 / 200, step 22/55, loss = 2.1148
# epoch 16 / 200, step 23/55, loss = 1.9069
# epoch 16 / 200, step 24/55, loss = 1.9150
# epoch 16 / 200, step 25/55, loss = 2.0252
# epoch 16 / 200, step 26/55, loss = 1.9423
# epoch 16 / 200, step 27/55, loss = 1.9285
# epoch 16 / 200, step 28/55, loss = 1.8964
# epoch 16 / 200, step 29/55, loss = 2.0140
# epoch 16 / 200, step 30/55, loss = 1.9254
# epoch 16 / 200, step 31/55, loss = 1.9773
# epoch 16 / 200, step 32/55, loss = 2.0070
# epoch 16 / 200, step 33/55, loss = 2.0032
# epoch 16 / 200, step 34/55, loss = 1.9304
# epoch 16 / 200, step 35/55, loss = 1.9408
# epoch 16 / 200, step 36/55, loss = 1.8299
# epoch 16 / 200, step 37/55, loss = 2.0737
# epoch 16 / 200, step 38/55, loss = 1.8981
# epoch 16 / 200, step 39/55, loss = 1.8349
# epoch 16 / 200, step 40/55, loss = 1.9553
# epoch 16 / 200, step 41/55, loss = 1.9958
# epoch 16 / 200, step 42/55, loss = 1.8342
# epoch 16 / 200, step 43/55, loss = 1.9676
# epoch 16 / 200, step 44/55, loss = 1.8741
# epoch 16 / 200, step 45/55, loss = 2.0534
# epoch 16 / 200, step 46/55, loss = 2.0635
# epoch 16 / 200, step 47/55, loss = 2.0127
# epoch 16 / 200, step 48/55, loss = 1.7888
# epoch 16 / 200, step 49/55, loss = 1.8297
# epoch 16 / 200, step 50/55, loss = 1.9648
# epoch 16 / 200, step 51/55, loss = 1.9552
# epoch 16 / 200, step 52/55, loss = 1.9795
# epoch 16 / 200, step 53/55, loss = 1.9753
# epoch 16 / 200, step 54/55, loss = 1.9509
# epoch 16 / 200, step 55/55, loss = 1.8596
# epoch 16 / 200, step 1/14, loss = 1.9907
# epoch 16 / 200, step 2/14, loss = 2.0143
# epoch 16 / 200, step 3/14, loss = 2.1214
# epoch 16 / 200, step 4/14, loss = 2.0029
# epoch 16 / 200, step 5/14, loss = 1.8992
# epoch 16 / 200, step 6/14, loss = 1.7653
# epoch 16 / 200, step 7/14, loss = 2.0175
# epoch 16 / 200, step 8/14, loss = 1.9158
# epoch 16 / 200, step 9/14, loss = 1.8749
# epoch 16 / 200, step 10/14, loss = 2.0608
# epoch 16 / 200, step 11/14, loss = 1.9108
# epoch 16 / 200, step 12/14, loss = 2.0196
# epoch 16 / 200, step 13/14, loss = 2.1078
# epoch 16 / 200, step 14/14, loss = 1.9191
# epoch 17 / 200, step 1/55, loss = 1.9318
# epoch 17 / 200, step 2/55, loss = 2.0322
# epoch 17 / 200, step 3/55, loss = 1.9706
# epoch 17 / 200, step 4/55, loss = 1.9482
# epoch 17 / 200, step 5/55, loss = 1.8281
# epoch 17 / 200, step 6/55, loss = 1.9403
# epoch 17 / 200, step 7/55, loss = 1.9434
# epoch 17 / 200, step 8/55, loss = 1.8637
# epoch 17 / 200, step 9/55, loss = 2.0491
# epoch 17 / 200, step 10/55, loss = 1.9743
# epoch 17 / 200, step 11/55, loss = 1.8439
# epoch 17 / 200, step 12/55, loss = 1.9138
# epoch 17 / 200, step 13/55, loss = 2.0633
# epoch 17 / 200, step 14/55, loss = 1.8876
# epoch 17 / 200, step 15/55, loss = 1.9257
# epoch 17 / 200, step 16/55, loss = 2.0822
# epoch 17 / 200, step 17/55, loss = 1.9794
# epoch 17 / 200, step 18/55, loss = 2.0128
# epoch 17 / 200, step 19/55, loss = 1.9329
# epoch 17 / 200, step 20/55, loss = 1.9594
# epoch 17 / 200, step 21/55, loss = 1.9951
# epoch 17 / 200, step 22/55, loss = 2.0369
# epoch 17 / 200, step 23/55, loss = 2.0765
# epoch 17 / 200, step 24/55, loss = 2.1012
# epoch 17 / 200, step 25/55, loss = 1.8623
# epoch 17 / 200, step 26/55, loss = 1.9579
# epoch 17 / 200, step 27/55, loss = 2.0386
# epoch 17 / 200, step 28/55, loss = 1.8746
# epoch 17 / 200, step 29/55, loss = 1.8876
# epoch 17 / 200, step 30/55, loss = 1.9579
# epoch 17 / 200, step 31/55, loss = 1.9652
# epoch 17 / 200, step 32/55, loss = 1.9216
# epoch 17 / 200, step 33/55, loss = 1.8945
# epoch 17 / 200, step 34/55, loss = 1.9656
# epoch 17 / 200, step 35/55, loss = 2.0539
# epoch 17 / 200, step 36/55, loss = 1.8946
# epoch 17 / 200, step 37/55, loss = 1.9059
# epoch 17 / 200, step 38/55, loss = 2.0195
# epoch 17 / 200, step 39/55, loss = 1.9586
# epoch 17 / 200, step 40/55, loss = 2.0005
# epoch 17 / 200, step 41/55, loss = 1.9267
# epoch 17 / 200, step 42/55, loss = 1.9339
# epoch 17 / 200, step 43/55, loss = 2.0515
# epoch 17 / 200, step 44/55, loss = 1.8231
# epoch 17 / 200, step 45/55, loss = 2.0132
# epoch 17 / 200, step 46/55, loss = 1.9620
# epoch 17 / 200, step 47/55, loss = 1.8552
# epoch 17 / 200, step 48/55, loss = 1.9280
# epoch 17 / 200, step 49/55, loss = 1.9484
# epoch 17 / 200, step 50/55, loss = 1.9843
# epoch 17 / 200, step 51/55, loss = 2.0677
# epoch 17 / 200, step 52/55, loss = 1.9228
# epoch 17 / 200, step 53/55, loss = 2.0927
# epoch 17 / 200, step 54/55, loss = 2.0601
# epoch 17 / 200, step 55/55, loss = 2.0139
# epoch 17 / 200, step 1/14, loss = 1.9975
# epoch 17 / 200, step 2/14, loss = 1.9403
# epoch 17 / 200, step 3/14, loss = 1.9812
# epoch 17 / 200, step 4/14, loss = 1.9536
# epoch 17 / 200, step 5/14, loss = 1.9385
# ...
# epoch 195 / 200, step 41/55, loss = 2.0313
# epoch 195 / 200, step 42/55, loss = 1.9998
# epoch 195 / 200, step 43/55, loss = 2.0497
# epoch 195 / 200, step 44/55, loss = 1.9401
# epoch 195 / 200, step 45/55, loss = 1.9176
# epoch 195 / 200, step 46/55, loss = 1.9011
# epoch 195 / 200, step 47/55, loss = 1.9508
# epoch 195 / 200, step 48/55, loss = 1.9329
# epoch 195 / 200, step 49/55, loss = 1.9355
# epoch 195 / 200, step 50/55, loss = 1.9114
# epoch 195 / 200, step 51/55, loss = 2.0129
# epoch 195 / 200, step 52/55, loss = 1.9510
# epoch 195 / 200, step 53/55, loss = 1.8141
# epoch 195 / 200, step 54/55, loss = 1.9185
# epoch 195 / 200, step 55/55, loss = 1.8930
# epoch 195 / 200, step 1/14, loss = 2.0132
# epoch 195 / 200, step 2/14, loss = 1.8972
# epoch 195 / 200, step 3/14, loss = 1.9599
# epoch 195 / 200, step 4/14, loss = 1.9638
# epoch 195 / 200, step 5/14, loss = 1.9806
# epoch 195 / 200, step 6/14, loss = 1.9433
# epoch 195 / 200, step 7/14, loss = 1.9536
# epoch 195 / 200, step 8/14, loss = 1.9659
# epoch 195 / 200, step 9/14, loss = 2.0860
# epoch 195 / 200, step 10/14, loss = 1.9337
# epoch 195 / 200, step 11/14, loss = 1.9324
# epoch 195 / 200, step 12/14, loss = 1.9933
# epoch 195 / 200, step 13/14, loss = 2.0132
# epoch 195 / 200, step 14/14, loss = 1.9230
# epoch 196 / 200, step 1/55, loss = 1.8628
# epoch 196 / 200, step 2/55, loss = 1.8583
# epoch 196 / 200, step 3/55, loss = 2.0370
# epoch 196 / 200, step 4/55, loss = 1.9866
# epoch 196 / 200, step 5/55, loss = 2.0174
# epoch 196 / 200, step 6/55, loss = 2.0563
# epoch 196 / 200, step 7/55, loss = 1.8334
# epoch 196 / 200, step 8/55, loss = 2.0431
# epoch 196 / 200, step 9/55, loss = 2.0129
# epoch 196 / 200, step 10/55, loss = 1.8989
# epoch 196 / 200, step 11/55, loss = 1.8927
# epoch 196 / 200, step 12/55, loss = 1.9191
# epoch 196 / 200, step 13/55, loss = 1.9777
# epoch 196 / 200, step 14/55, loss = 1.7771
# epoch 196 / 200, step 15/55, loss = 2.0268
# epoch 196 / 200, step 16/55, loss = 2.0105
# epoch 196 / 200, step 17/55, loss = 2.0558
# epoch 196 / 200, step 18/55, loss = 1.8839
# epoch 196 / 200, step 19/55, loss = 2.0002
# epoch 196 / 200, step 20/55, loss = 1.7981
# epoch 196 / 200, step 21/55, loss = 2.1134
# epoch 196 / 200, step 22/55, loss = 2.0208
# epoch 196 / 200, step 23/55, loss = 1.9365
# epoch 196 / 200, step 24/55, loss = 1.9212
# epoch 196 / 200, step 25/55, loss = 1.9284
# epoch 196 / 200, step 26/55, loss = 1.9184
# epoch 196 / 200, step 27/55, loss = 1.8118
# epoch 196 / 200, step 28/55, loss = 1.8490
# epoch 196 / 200, step 29/55, loss = 2.0911
# epoch 196 / 200, step 30/55, loss = 1.9244
# epoch 196 / 200, step 31/55, loss = 2.0896
# epoch 196 / 200, step 32/55, loss = 2.0034
# epoch 196 / 200, step 33/55, loss = 1.9360
# epoch 196 / 200, step 34/55, loss = 1.9489
# epoch 196 / 200, step 35/55, loss = 1.9314
# epoch 196 / 200, step 36/55, loss = 1.8579
# epoch 196 / 200, step 37/55, loss = 1.8920
# epoch 196 / 200, step 38/55, loss = 1.8001
# epoch 196 / 200, step 39/55, loss = 1.8723
# epoch 196 / 200, step 40/55, loss = 1.9861
# epoch 196 / 200, step 41/55, loss = 1.9328
# epoch 196 / 200, step 42/55, loss = 1.9056
# epoch 196 / 200, step 43/55, loss = 1.8245
# epoch 196 / 200, step 44/55, loss = 2.0423
# epoch 196 / 200, step 45/55, loss = 1.9318
# epoch 196 / 200, step 46/55, loss = 2.1202
# epoch 196 / 200, step 47/55, loss = 1.9073
# epoch 196 / 200, step 48/55, loss = 2.0801
# epoch 196 / 200, step 49/55, loss = 2.0658
# epoch 196 / 200, step 50/55, loss = 1.7705
# epoch 196 / 200, step 51/55, loss = 1.9925
# epoch 196 / 200, step 52/55, loss = 1.8742
# epoch 196 / 200, step 53/55, loss = 1.9182
# epoch 196 / 200, step 54/55, loss = 1.8628
# epoch 196 / 200, step 55/55, loss = 1.9926
# epoch 196 / 200, step 1/14, loss = 1.9429
# epoch 196 / 200, step 2/14, loss = 1.9306
# epoch 196 / 200, step 3/14, loss = 2.0464
# epoch 196 / 200, step 4/14, loss = 2.0073
# epoch 196 / 200, step 5/14, loss = 1.9081
# epoch 196 / 200, step 6/14, loss = 1.7855
# epoch 196 / 200, step 7/14, loss = 1.9624
# epoch 196 / 200, step 8/14, loss = 1.9193
# epoch 196 / 200, step 9/14, loss = 1.9289
# epoch 196 / 200, step 10/14, loss = 2.0484
# epoch 196 / 200, step 11/14, loss = 1.9059
# epoch 196 / 200, step 12/14, loss = 1.9618
# epoch 196 / 200, step 13/14, loss = 2.0150
# epoch 196 / 200, step 14/14, loss = 1.9037
# epoch 197 / 200, step 1/55, loss = 1.9312
# epoch 197 / 200, step 2/55, loss = 1.9503
# epoch 197 / 200, step 3/55, loss = 1.9637
# epoch 197 / 200, step 4/55, loss = 1.9927
# epoch 197 / 200, step 5/55, loss = 2.1423
# epoch 197 / 200, step 6/55, loss = 2.0258
# epoch 197 / 200, step 7/55, loss = 2.0632
# epoch 197 / 200, step 8/55, loss = 1.9151
# epoch 197 / 200, step 9/55, loss = 1.9363
# epoch 197 / 200, step 10/55, loss = 1.9448
# epoch 197 / 200, step 11/55, loss = 1.9477
# epoch 197 / 200, step 12/55, loss = 1.9623
# epoch 197 / 200, step 13/55, loss = 1.9883
# epoch 197 / 200, step 14/55, loss = 1.8986
# epoch 197 / 200, step 15/55, loss = 1.8288
# epoch 197 / 200, step 16/55, loss = 1.9516
# epoch 197 / 200, step 17/55, loss = 1.9061
# epoch 197 / 200, step 18/55, loss = 1.9222
# epoch 197 / 200, step 19/55, loss = 1.9996
# epoch 197 / 200, step 20/55, loss = 2.0461
# epoch 197 / 200, step 21/55, loss = 2.0652
# epoch 197 / 200, step 22/55, loss = 1.9175
# epoch 197 / 200, step 23/55, loss = 1.9083
# epoch 197 / 200, step 24/55, loss = 1.8931
# epoch 197 / 200, step 25/55, loss = 1.9447
# epoch 197 / 200, step 26/55, loss = 1.9471
# epoch 197 / 200, step 27/55, loss = 1.9724
# epoch 197 / 200, step 28/55, loss = 2.0062
# epoch 197 / 200, step 29/55, loss = 1.9215
# epoch 197 / 200, step 30/55, loss = 1.8549
# epoch 197 / 200, step 31/55, loss = 1.9108
# epoch 197 / 200, step 32/55, loss = 1.8948
# epoch 197 / 200, step 33/55, loss = 1.9597
# epoch 197 / 200, step 34/55, loss = 1.9127
# epoch 197 / 200, step 35/55, loss = 1.9081
# epoch 197 / 200, step 36/55, loss = 2.0256
# epoch 197 / 200, step 37/55, loss = 1.9112
# epoch 197 / 200, step 38/55, loss = 1.9714
# epoch 197 / 200, step 39/55, loss = 1.9053
# epoch 197 / 200, step 40/55, loss = 1.8834
# epoch 197 / 200, step 41/55, loss = 1.9010
# epoch 197 / 200, step 42/55, loss = 2.0182
# epoch 197 / 200, step 43/55, loss = 1.9945
# epoch 197 / 200, step 44/55, loss = 2.0988
# epoch 197 / 200, step 45/55, loss = 1.9031
# epoch 197 / 200, step 46/55, loss = 1.9666
# epoch 197 / 200, step 47/55, loss = 2.0891
# epoch 197 / 200, step 48/55, loss = 1.8606
# epoch 197 / 200, step 49/55, loss = 2.0004
# epoch 197 / 200, step 50/55, loss = 2.2986
# epoch 197 / 200, step 51/55, loss = 1.8450
# epoch 197 / 200, step 52/55, loss = 1.8550
# epoch 197 / 200, step 53/55, loss = 1.9394
# epoch 197 / 200, step 54/55, loss = 1.9024
# epoch 197 / 200, step 55/55, loss = 1.9235
# epoch 197 / 200, step 1/14, loss = 1.9699
# epoch 197 / 200, step 2/14, loss = 1.9746
# epoch 197 / 200, step 3/14, loss = 2.0852
# epoch 197 / 200, step 4/14, loss = 1.9926
# epoch 197 / 200, step 5/14, loss = 1.8915
# epoch 197 / 200, step 6/14, loss = 1.7669
# epoch 197 / 200, step 7/14, loss = 1.9934
# epoch 197 / 200, step 8/14, loss = 1.9172
# epoch 197 / 200, step 9/14, loss = 1.8910
# epoch 197 / 200, step 10/14, loss = 2.0557
# epoch 197 / 200, step 11/14, loss = 1.9129
# epoch 197 / 200, step 12/14, loss = 1.9889
# epoch 197 / 200, step 13/14, loss = 2.0721
# epoch 197 / 200, step 14/14, loss = 1.9102
# epoch 198 / 200, step 1/55, loss = 1.8269
# epoch 198 / 200, step 2/55, loss = 1.9961
# epoch 198 / 200, step 3/55, loss = 1.9511
# epoch 198 / 200, step 4/55, loss = 1.8821
# epoch 198 / 200, step 5/55, loss = 1.8455
# epoch 198 / 200, step 6/55, loss = 2.0204
# epoch 198 / 200, step 7/55, loss = 1.9799
# epoch 198 / 200, step 8/55, loss = 2.0501
# epoch 198 / 200, step 9/55, loss = 2.0082
# epoch 198 / 200, step 10/55, loss = 2.0401
# epoch 198 / 200, step 11/55, loss = 2.0705
# epoch 198 / 200, step 12/55, loss = 2.0979
# epoch 198 / 200, step 13/55, loss = 1.8188
# epoch 198 / 200, step 14/55, loss = 1.9650
# epoch 198 / 200, step 15/55, loss = 1.9733
# epoch 198 / 200, step 16/55, loss = 1.9805
# epoch 198 / 200, step 17/55, loss = 1.9664
# epoch 198 / 200, step 18/55, loss = 1.9832
# epoch 198 / 200, step 19/55, loss = 1.9149
# epoch 198 / 200, step 20/55, loss = 1.9522
# epoch 198 / 200, step 21/55, loss = 1.9635
# epoch 198 / 200, step 22/55, loss = 1.8999
# epoch 198 / 200, step 23/55, loss = 2.0082
# epoch 198 / 200, step 24/55, loss = 1.9081
# epoch 198 / 200, step 25/55, loss = 1.9119
# epoch 198 / 200, step 26/55, loss = 1.9763
# epoch 198 / 200, step 27/55, loss = 2.1008
# epoch 198 / 200, step 28/55, loss = 1.8647
# epoch 198 / 200, step 29/55, loss = 1.9579
# epoch 198 / 200, step 30/55, loss = 2.0350
# epoch 198 / 200, step 31/55, loss = 1.9483
# epoch 198 / 200, step 32/55, loss = 1.9989
# epoch 198 / 200, step 33/55, loss = 2.0023
# epoch 198 / 200, step 34/55, loss = 1.9296
# epoch 198 / 200, step 35/55, loss = 2.0719
# epoch 198 / 200, step 36/55, loss = 1.9202
# epoch 198 / 200, step 37/55, loss = 1.9501
# epoch 198 / 200, step 38/55, loss = 2.0344
# epoch 198 / 200, step 39/55, loss = 1.9658
# epoch 198 / 200, step 40/55, loss = 1.9594
# epoch 198 / 200, step 41/55, loss = 2.0322
# epoch 198 / 200, step 42/55, loss = 1.9361
# epoch 198 / 200, step 43/55, loss = 1.7497
# epoch 198 / 200, step 44/55, loss = 1.9033
# epoch 198 / 200, step 45/55, loss = 2.0067
# epoch 198 / 200, step 46/55, loss = 1.9712
# epoch 198 / 200, step 47/55, loss = 1.9118
# epoch 198 / 200, step 48/55, loss = 1.8383
# epoch 198 / 200, step 49/55, loss = 2.0013
# epoch 198 / 200, step 50/55, loss = 1.8095
# epoch 198 / 200, step 51/55, loss = 2.0566
# epoch 198 / 200, step 52/55, loss = 1.9657
# epoch 198 / 200, step 53/55, loss = 1.8808
# epoch 198 / 200, step 54/55, loss = 1.8435
# epoch 198 / 200, step 55/55, loss = 2.0169
# epoch 198 / 200, step 1/14, loss = 1.9760
# epoch 198 / 200, step 2/14, loss = 1.9869
# epoch 198 / 200, step 3/14, loss = 2.1084
# epoch 198 / 200, step 4/14, loss = 2.0710
# epoch 198 / 200, step 5/14, loss = 1.9060
# epoch 198 / 200, step 6/14, loss = 1.7592
# epoch 198 / 200, step 7/14, loss = 2.0198
# epoch 198 / 200, step 8/14, loss = 1.9188
# epoch 198 / 200, step 9/14, loss = 1.9724
# epoch 198 / 200, step 10/14, loss = 2.1010
# epoch 198 / 200, step 11/14, loss = 1.8786
# epoch 198 / 200, step 12/14, loss = 2.0154
# epoch 198 / 200, step 13/14, loss = 2.0778
# epoch 198 / 200, step 14/14, loss = 1.8950
# epoch 199 / 200, step 1/55, loss = 1.9742
# epoch 199 / 200, step 2/55, loss = 2.0525
# epoch 199 / 200, step 3/55, loss = 1.9059
# epoch 199 / 200, step 4/55, loss = 2.0947
# epoch 199 / 200, step 5/55, loss = 1.9990
# epoch 199 / 200, step 6/55, loss = 1.9697
# epoch 199 / 200, step 7/55, loss = 1.9517
# epoch 199 / 200, step 8/55, loss = 1.9310
# epoch 199 / 200, step 9/55, loss = 1.8606
# epoch 199 / 200, step 10/55, loss = 1.9903
# epoch 199 / 200, step 11/55, loss = 1.9000
# epoch 199 / 200, step 12/55, loss = 2.0691
# epoch 199 / 200, step 13/55, loss = 1.9822
# epoch 199 / 200, step 14/55, loss = 2.0258
# epoch 199 / 200, step 15/55, loss = 2.0789
# epoch 199 / 200, step 16/55, loss = 2.0976
# epoch 199 / 200, step 17/55, loss = 1.9289
# epoch 199 / 200, step 18/55, loss = 1.8782
# epoch 199 / 200, step 19/55, loss = 2.0138
# epoch 199 / 200, step 20/55, loss = 1.9185
# epoch 199 / 200, step 21/55, loss = 1.8263
# epoch 199 / 200, step 22/55, loss = 1.8843
# epoch 199 / 200, step 23/55, loss = 2.0205
# epoch 199 / 200, step 24/55, loss = 1.9701
# epoch 199 / 200, step 25/55, loss = 1.9686
# epoch 199 / 200, step 26/55, loss = 1.9548
# epoch 199 / 200, step 27/55, loss = 1.9479
# epoch 199 / 200, step 28/55, loss = 2.0615
# epoch 199 / 200, step 29/55, loss = 1.8426
# epoch 199 / 200, step 30/55, loss = 1.9028
# epoch 199 / 200, step 31/55, loss = 1.8876
# epoch 199 / 200, step 32/55, loss = 1.9305
# epoch 199 / 200, step 33/55, loss = 2.0212
# epoch 199 / 200, step 34/55, loss = 2.1025
# epoch 199 / 200, step 35/55, loss = 1.9290
# epoch 199 / 200, step 36/55, loss = 2.1423
# epoch 199 / 200, step 37/55, loss = 2.0419
# epoch 199 / 200, step 38/55, loss = 2.0577
# epoch 199 / 200, step 39/55, loss = 1.8954
# epoch 199 / 200, step 40/55, loss = 1.9641
# epoch 199 / 200, step 41/55, loss = 1.8830
# epoch 199 / 200, step 42/55, loss = 1.9846
# epoch 199 / 200, step 43/55, loss = 1.9118
# epoch 199 / 200, step 44/55, loss = 2.0532
# epoch 199 / 200, step 45/55, loss = 2.0109
# epoch 199 / 200, step 46/55, loss = 1.9161
# epoch 199 / 200, step 47/55, loss = 1.9743
# epoch 199 / 200, step 48/55, loss = 1.9036
# epoch 199 / 200, step 49/55, loss = 1.9101
# epoch 199 / 200, step 50/55, loss = 1.9270
# epoch 199 / 200, step 51/55, loss = 1.9547
# epoch 199 / 200, step 52/55, loss = 1.9258
# epoch 199 / 200, step 53/55, loss = 1.9384
# epoch 199 / 200, step 54/55, loss = 1.9426
# epoch 199 / 200, step 55/55, loss = 1.9701
# epoch 199 / 200, step 1/14, loss = 1.9607
# epoch 199 / 200, step 2/14, loss = 1.9573
# epoch 199 / 200, step 3/14, loss = 1.9823
# epoch 199 / 200, step 4/14, loss = 2.0040
# epoch 199 / 200, step 5/14, loss = 1.9023
# epoch 199 / 200, step 6/14, loss = 1.8986
# epoch 199 / 200, step 7/14, loss = 1.9597
# epoch 199 / 200, step 8/14, loss = 1.9956
# epoch 199 / 200, step 9/14, loss = 1.9407
# epoch 199 / 200, step 10/14, loss = 1.9671
# epoch 199 / 200, step 11/14, loss = 1.8741
# epoch 199 / 200, step 12/14, loss = 1.9259
# epoch 199 / 200, step 13/14, loss = 1.9832
# epoch 199 / 200, step 14/14, loss = 1.9206
# epoch 200 / 200, step 1/55, loss = 1.9699
# epoch 200 / 200, step 2/55, loss = 1.9543
# epoch 200 / 200, step 3/55, loss = 1.8753
# epoch 200 / 200, step 4/55, loss = 1.9486
# epoch 200 / 200, step 5/55, loss = 1.8408
# epoch 200 / 200, step 6/55, loss = 1.9101
# epoch 200 / 200, step 7/55, loss = 2.0098
# epoch 200 / 200, step 8/55, loss = 2.0730
# epoch 200 / 200, step 9/55, loss = 1.9606
# epoch 200 / 200, step 10/55, loss = 2.0573
# epoch 200 / 200, step 11/55, loss = 1.9529
# epoch 200 / 200, step 12/55, loss = 1.9929
# epoch 200 / 200, step 13/55, loss = 1.9544
# epoch 200 / 200, step 14/55, loss = 1.9013
# epoch 200 / 200, step 15/55, loss = 1.9731
# epoch 200 / 200, step 16/55, loss = 1.9898
# epoch 200 / 200, step 17/55, loss = 1.8768
# epoch 200 / 200, step 18/55, loss = 1.8932
# epoch 200 / 200, step 19/55, loss = 1.9023
# epoch 200 / 200, step 20/55, loss = 1.9172
# epoch 200 / 200, step 21/55, loss = 2.0181
# epoch 200 / 200, step 22/55, loss = 2.0311
# epoch 200 / 200, step 23/55, loss = 1.8267
# epoch 200 / 200, step 24/55, loss = 1.9884
# epoch 200 / 200, step 25/55, loss = 1.9457
# epoch 200 / 200, step 26/55, loss = 2.0331
# epoch 200 / 200, step 27/55, loss = 2.0261
# epoch 200 / 200, step 28/55, loss = 1.9502
# epoch 200 / 200, step 29/55, loss = 1.9849
# epoch 200 / 200, step 30/55, loss = 1.9651
# epoch 200 / 200, step 31/55, loss = 1.9738
# epoch 200 / 200, step 32/55, loss = 1.9765
# epoch 200 / 200, step 33/55, loss = 1.8924
# epoch 200 / 200, step 34/55, loss = 1.8623
# epoch 200 / 200, step 35/55, loss = 1.9314
# epoch 200 / 200, step 36/55, loss = 1.9568
# epoch 200 / 200, step 37/55, loss = 1.9202
# epoch 200 / 200, step 38/55, loss = 2.0869
# epoch 200 / 200, step 39/55, loss = 1.9759
# epoch 200 / 200, step 40/55, loss = 1.9481
# epoch 200 / 200, step 41/55, loss = 2.0131
# epoch 200 / 200, step 42/55, loss = 2.0304
# epoch 200 / 200, step 43/55, loss = 1.8388
# epoch 200 / 200, step 44/55, loss = 1.9807
# epoch 200 / 200, step 45/55, loss = 1.9241
# epoch 200 / 200, step 46/55, loss = 1.9914
# epoch 200 / 200, step 47/55, loss = 1.9557
# epoch 200 / 200, step 48/55, loss = 2.1440
# epoch 200 / 200, step 49/55, loss = 1.9551
# epoch 200 / 200, step 50/55, loss = 2.0167
# epoch 200 / 200, step 51/55, loss = 1.9248
# epoch 200 / 200, step 52/55, loss = 1.9338
# epoch 200 / 200, step 53/55, loss = 1.9614
# epoch 200 / 200, step 54/55, loss = 1.8886
# epoch 200 / 200, step 55/55, loss = 2.0126
# epoch 200 / 200, step 1/14, loss = 1.9703
# epoch 200 / 200, step 2/14, loss = 1.9083
# epoch 200 / 200, step 3/14, loss = 2.0008
# epoch 200 / 200, step 4/14, loss = 1.9678
# epoch 200 / 200, step 5/14, loss = 1.9564
# epoch 200 / 200, step 6/14, loss = 1.8029
# epoch 200 / 200, step 7/14, loss = 1.9410
# epoch 200 / 200, step 8/14, loss = 1.9520
# epoch 200 / 200, step 9/14, loss = 1.9975
# epoch 200 / 200, step 10/14, loss = 1.9958
# epoch 200 / 200, step 11/14, loss = 1.9383
# epoch 200 / 200, step 12/14, loss = 1.9662
# epoch 200 / 200, step 13/14, loss = 1.9954
# epoch 200 / 200, step 14/14, loss = 1.9463

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 200 epochs the trainning accuracy is 15.885714285714286 and the test accuaracy is 17.80821917808219
#  the maximum accuracy of the test was 18.72146118721461 at the epoch 18
#  the maximum accuracy of the train was 19.885714285714286 at the epoch 70
# the accuracy of the training at the best validation accuracy 18.72146118721461 is 17.37142857142857

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
