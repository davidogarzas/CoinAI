# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - learning rate de 0.001 a 0.005

# %%
filepath = '28 - 50epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 512
num_classes = 7
num_epochs = 50
batch_size = 8
learning_rate = 0.005
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([8, 769024]) , Labels shape: torch.Size([8])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 512, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=512, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 50, step 1/110, loss = 2.1335
# epoch 1 / 50, step 2/110, loss = 2.0264
# epoch 1 / 50, step 3/110, loss = 2.1314
# epoch 1 / 50, step 4/110, loss = 3.3656
# epoch 1 / 50, step 5/110, loss = 2.9059
# epoch 1 / 50, step 6/110, loss = 2.4220
# epoch 1 / 50, step 7/110, loss = 3.7922
# epoch 1 / 50, step 8/110, loss = 3.1308
# epoch 1 / 50, step 9/110, loss = 2.8244
# epoch 1 / 50, step 10/110, loss = 3.1901
# epoch 1 / 50, step 11/110, loss = 2.9144
# epoch 1 / 50, step 12/110, loss = 2.1147
# epoch 1 / 50, step 13/110, loss = 2.7584
# epoch 1 / 50, step 14/110, loss = 2.4635
# epoch 1 / 50, step 15/110, loss = 2.6788
# epoch 1 / 50, step 16/110, loss = 2.4375
# epoch 1 / 50, step 17/110, loss = 2.5368
# epoch 1 / 50, step 18/110, loss = 1.9811
# epoch 1 / 50, step 19/110, loss = 2.6148
# epoch 1 / 50, step 20/110, loss = 2.7529
# epoch 1 / 50, step 21/110, loss = 2.0313
# epoch 1 / 50, step 22/110, loss = 2.1331
# epoch 1 / 50, step 23/110, loss = 3.1832
# epoch 1 / 50, step 24/110, loss = 2.6232
# epoch 1 / 50, step 25/110, loss = 2.5290
# epoch 1 / 50, step 26/110, loss = 1.7680
# epoch 1 / 50, step 27/110, loss = 2.4135
# epoch 1 / 50, step 28/110, loss = 2.1894
# epoch 1 / 50, step 29/110, loss = 2.4962
# epoch 1 / 50, step 30/110, loss = 2.3711
# epoch 1 / 50, step 31/110, loss = 2.7752
# epoch 1 / 50, step 32/110, loss = 2.4967
# epoch 1 / 50, step 33/110, loss = 2.2028
# epoch 1 / 50, step 34/110, loss = 2.5466
# epoch 1 / 50, step 35/110, loss = 3.0532
# epoch 1 / 50, step 36/110, loss = 2.3664
# epoch 1 / 50, step 37/110, loss = 2.4964
# epoch 1 / 50, step 38/110, loss = 2.9576
# epoch 1 / 50, step 39/110, loss = 2.5293
# epoch 1 / 50, step 40/110, loss = 3.5246
# epoch 1 / 50, step 41/110, loss = 2.7305
# epoch 1 / 50, step 42/110, loss = 2.1537
# epoch 1 / 50, step 43/110, loss = 2.3508
# epoch 1 / 50, step 44/110, loss = 2.4008
# epoch 1 / 50, step 45/110, loss = 2.3312
# epoch 1 / 50, step 46/110, loss = 3.4125
# epoch 1 / 50, step 47/110, loss = 2.9494
# epoch 1 / 50, step 48/110, loss = 2.8515
# epoch 1 / 50, step 49/110, loss = 2.3625
# epoch 1 / 50, step 50/110, loss = 2.2661
# epoch 1 / 50, step 51/110, loss = 2.6175
# epoch 1 / 50, step 52/110, loss = 2.5193
# epoch 1 / 50, step 53/110, loss = 2.2505
# epoch 1 / 50, step 54/110, loss = 2.1996
# epoch 1 / 50, step 55/110, loss = 2.6588
# epoch 1 / 50, step 56/110, loss = 2.1175
# epoch 1 / 50, step 57/110, loss = 2.6652
# epoch 1 / 50, step 58/110, loss = 2.8237
# epoch 1 / 50, step 59/110, loss = 2.5089
# epoch 1 / 50, step 60/110, loss = 2.1463
# epoch 1 / 50, step 61/110, loss = 2.2530
# epoch 1 / 50, step 62/110, loss = 2.0723
# epoch 1 / 50, step 63/110, loss = 2.8369
# epoch 1 / 50, step 64/110, loss = 2.2669
# epoch 1 / 50, step 65/110, loss = 2.0789
# epoch 1 / 50, step 66/110, loss = 2.1601
# epoch 1 / 50, step 67/110, loss = 2.0452
# epoch 1 / 50, step 68/110, loss = 2.0060
# epoch 1 / 50, step 69/110, loss = 1.8070
# epoch 1 / 50, step 70/110, loss = 2.3092
# epoch 1 / 50, step 71/110, loss = 2.6183
# epoch 1 / 50, step 72/110, loss = 2.9691
# epoch 1 / 50, step 73/110, loss = 2.5335
# epoch 1 / 50, step 74/110, loss = 2.3554
# epoch 1 / 50, step 75/110, loss = 2.1623
# epoch 1 / 50, step 76/110, loss = 2.8497
# epoch 1 / 50, step 77/110, loss = 2.2201
# epoch 1 / 50, step 78/110, loss = 2.2508
# epoch 1 / 50, step 79/110, loss = 2.3475
# epoch 1 / 50, step 80/110, loss = 2.1774
# epoch 1 / 50, step 81/110, loss = 1.6998
# epoch 1 / 50, step 82/110, loss = 2.9775
# epoch 1 / 50, step 83/110, loss = 2.6757
# epoch 1 / 50, step 84/110, loss = 2.3164
# epoch 1 / 50, step 85/110, loss = 2.6217
# epoch 1 / 50, step 86/110, loss = 3.2192
# epoch 1 / 50, step 87/110, loss = 1.9453
# epoch 1 / 50, step 88/110, loss = 2.4751
# epoch 1 / 50, step 89/110, loss = 1.9391
# epoch 1 / 50, step 90/110, loss = 2.7909
# epoch 1 / 50, step 91/110, loss = 2.0893
# epoch 1 / 50, step 92/110, loss = 1.9632
# epoch 1 / 50, step 93/110, loss = 2.3975
# epoch 1 / 50, step 94/110, loss = 3.2513
# epoch 1 / 50, step 95/110, loss = 2.6017
# epoch 1 / 50, step 96/110, loss = 2.5223
# epoch 1 / 50, step 97/110, loss = 2.8090
# epoch 1 / 50, step 98/110, loss = 2.0317
# epoch 1 / 50, step 99/110, loss = 2.4743
# epoch 1 / 50, step 100/110, loss = 1.9454
# epoch 1 / 50, step 101/110, loss = 2.2344
# epoch 1 / 50, step 102/110, loss = 2.4755
# epoch 1 / 50, step 103/110, loss = 2.2474
# epoch 1 / 50, step 104/110, loss = 2.5876
# epoch 1 / 50, step 105/110, loss = 2.3512
# epoch 1 / 50, step 106/110, loss = 3.4740
# epoch 1 / 50, step 107/110, loss = 2.8023
# epoch 1 / 50, step 108/110, loss = 2.3418
# epoch 1 / 50, step 109/110, loss = 3.4240
# epoch 1 / 50, step 110/110, loss = 5.4667
# epoch 1 / 50, step 1/28, loss = 2.8151
# epoch 1 / 50, step 2/28, loss = 3.2681
# epoch 1 / 50, step 3/28, loss = 2.6476
# epoch 1 / 50, step 4/28, loss = 1.9852
# epoch 1 / 50, step 5/28, loss = 2.6158
# epoch 1 / 50, step 6/28, loss = 3.1395
# epoch 1 / 50, step 7/28, loss = 2.8113
# epoch 1 / 50, step 8/28, loss = 2.5560
# epoch 1 / 50, step 9/28, loss = 2.6125
# epoch 1 / 50, step 10/28, loss = 2.8474
# epoch 1 / 50, step 11/28, loss = 2.9994
# epoch 1 / 50, step 12/28, loss = 3.4745
# epoch 1 / 50, step 13/28, loss = 3.0502
# epoch 1 / 50, step 14/28, loss = 2.0150
# epoch 1 / 50, step 15/28, loss = 3.4916
# epoch 1 / 50, step 16/28, loss = 2.3010
# epoch 1 / 50, step 17/28, loss = 3.1450
# epoch 1 / 50, step 18/28, loss = 3.3802
# epoch 1 / 50, step 19/28, loss = 2.4983
# epoch 1 / 50, step 20/28, loss = 2.2948
# epoch 1 / 50, step 21/28, loss = 3.0384
# epoch 1 / 50, step 22/28, loss = 2.0713
# epoch 1 / 50, step 23/28, loss = 2.6069
# epoch 1 / 50, step 24/28, loss = 2.9306
# epoch 1 / 50, step 25/28, loss = 2.6397
# epoch 1 / 50, step 26/28, loss = 2.2646
# epoch 1 / 50, step 27/28, loss = 1.9894
# epoch 1 / 50, step 28/28, loss = 3.8586
# epoch 2 / 50, step 1/110, loss = 2.9310
# epoch 2 / 50, step 2/110, loss = 3.2865
# epoch 2 / 50, step 3/110, loss = 2.1812
# epoch 2 / 50, step 4/110, loss = 2.9259
# epoch 2 / 50, step 5/110, loss = 2.7792
# epoch 2 / 50, step 6/110, loss = 2.1520
# epoch 2 / 50, step 7/110, loss = 2.0278
# epoch 2 / 50, step 8/110, loss = 2.5057
# epoch 2 / 50, step 9/110, loss = 2.0067
# epoch 2 / 50, step 10/110, loss = 2.8628
# epoch 2 / 50, step 11/110, loss = 2.2742
# epoch 2 / 50, step 12/110, loss = 2.6394
# epoch 2 / 50, step 13/110, loss = 2.6389
# epoch 2 / 50, step 14/110, loss = 2.8378
# epoch 2 / 50, step 15/110, loss = 3.5630
# epoch 2 / 50, step 16/110, loss = 2.9867
# epoch 2 / 50, step 17/110, loss = 3.1299
# epoch 2 / 50, step 18/110, loss = 2.3511
# epoch 2 / 50, step 19/110, loss = 2.9170
# epoch 2 / 50, step 20/110, loss = 2.6934
# epoch 2 / 50, step 21/110, loss = 2.3095
# epoch 2 / 50, step 22/110, loss = 3.3433
# epoch 2 / 50, step 23/110, loss = 2.5413
# epoch 2 / 50, step 24/110, loss = 2.9309
# epoch 2 / 50, step 25/110, loss = 2.4327
# epoch 2 / 50, step 26/110, loss = 2.4013
# epoch 2 / 50, step 27/110, loss = 2.3399
# epoch 2 / 50, step 28/110, loss = 2.6515
# epoch 2 / 50, step 29/110, loss = 2.7972
# epoch 2 / 50, step 30/110, loss = 2.3163
# epoch 2 / 50, step 31/110, loss = 2.4079
# epoch 2 / 50, step 32/110, loss = 2.3409
# epoch 2 / 50, step 33/110, loss = 3.4347
# epoch 2 / 50, step 34/110, loss = 3.5622
# epoch 2 / 50, step 35/110, loss = 4.2200
# epoch 2 / 50, step 36/110, loss = 3.1797
# epoch 2 / 50, step 37/110, loss = 3.8551
# epoch 2 / 50, step 38/110, loss = 2.8143
# epoch 2 / 50, step 39/110, loss = 3.0925
# epoch 2 / 50, step 40/110, loss = 2.5621
# epoch 2 / 50, step 41/110, loss = 3.8437
# epoch 2 / 50, step 42/110, loss = 3.1822
# epoch 2 / 50, step 43/110, loss = 2.6743
# epoch 2 / 50, step 44/110, loss = 2.1311
# epoch 2 / 50, step 45/110, loss = 2.7523
# epoch 2 / 50, step 46/110, loss = 2.6183
# epoch 2 / 50, step 47/110, loss = 3.3794
# epoch 2 / 50, step 48/110, loss = 2.6091
# epoch 2 / 50, step 49/110, loss = 2.7483
# epoch 2 / 50, step 50/110, loss = 2.4455
# epoch 2 / 50, step 51/110, loss = 2.7204
# epoch 2 / 50, step 52/110, loss = 2.4528
# epoch 2 / 50, step 53/110, loss = 1.4472
# epoch 2 / 50, step 54/110, loss = 1.7990
# epoch 2 / 50, step 55/110, loss = 3.2430
# epoch 2 / 50, step 56/110, loss = 2.3274
# epoch 2 / 50, step 57/110, loss = 2.9146
# epoch 2 / 50, step 58/110, loss = 3.1175
# epoch 2 / 50, step 59/110, loss = 2.8238
# epoch 2 / 50, step 60/110, loss = 2.5150
# epoch 2 / 50, step 61/110, loss = 2.3419
# epoch 2 / 50, step 62/110, loss = 2.8069
# epoch 2 / 50, step 63/110, loss = 2.1183
# epoch 2 / 50, step 64/110, loss = 3.2100
# epoch 2 / 50, step 65/110, loss = 2.3835
# epoch 2 / 50, step 66/110, loss = 2.4345
# epoch 2 / 50, step 67/110, loss = 1.9311
# epoch 2 / 50, step 68/110, loss = 2.9808
# epoch 2 / 50, step 69/110, loss = 4.1947
# epoch 2 / 50, step 70/110, loss = 2.1858
# epoch 2 / 50, step 71/110, loss = 2.8336
# epoch 2 / 50, step 72/110, loss = 2.9589
# epoch 2 / 50, step 73/110, loss = 3.0812
# epoch 2 / 50, step 74/110, loss = 3.3760
# epoch 2 / 50, step 75/110, loss = 3.2504
# epoch 2 / 50, step 76/110, loss = 2.2288
# epoch 2 / 50, step 77/110, loss = 2.5836
# epoch 2 / 50, step 78/110, loss = 2.8866
# epoch 2 / 50, step 79/110, loss = 2.4554
# epoch 2 / 50, step 80/110, loss = 2.5323
# epoch 2 / 50, step 81/110, loss = 2.2015
# epoch 2 / 50, step 82/110, loss = 2.7348
# epoch 2 / 50, step 83/110, loss = 3.0826
# epoch 2 / 50, step 84/110, loss = 2.7769
# epoch 2 / 50, step 85/110, loss = 2.3389
# epoch 2 / 50, step 86/110, loss = 2.1359
# epoch 2 / 50, step 87/110, loss = 2.9301
# epoch 2 / 50, step 88/110, loss = 3.0808
# epoch 2 / 50, step 89/110, loss = 4.8430
# epoch 2 / 50, step 90/110, loss = 1.6188
# epoch 2 / 50, step 91/110, loss = 1.8667
# epoch 2 / 50, step 92/110, loss = 1.3482
# epoch 2 / 50, step 93/110, loss = 4.0592
# epoch 2 / 50, step 94/110, loss = 2.5779
# epoch 2 / 50, step 95/110, loss = 2.2387
# epoch 2 / 50, step 96/110, loss = 3.0256
# epoch 2 / 50, step 97/110, loss = 3.0297
# epoch 2 / 50, step 98/110, loss = 2.5685
# epoch 2 / 50, step 99/110, loss = 3.5985
# epoch 2 / 50, step 100/110, loss = 2.9162
# epoch 2 / 50, step 101/110, loss = 2.5849
# epoch 2 / 50, step 102/110, loss = 2.8698
# epoch 2 / 50, step 103/110, loss = 4.1398
# epoch 2 / 50, step 104/110, loss = 2.6778
# epoch 2 / 50, step 105/110, loss = 2.8101
# epoch 2 / 50, step 106/110, loss = 2.2933
# epoch 2 / 50, step 107/110, loss = 2.6876
# epoch 2 / 50, step 108/110, loss = 3.5920
# epoch 2 / 50, step 109/110, loss = 2.6754
# epoch 2 / 50, step 110/110, loss = 3.2821
# epoch 2 / 50, step 1/28, loss = 2.2749
# epoch 2 / 50, step 2/28, loss = 2.2316
# epoch 2 / 50, step 3/28, loss = 2.3537
# epoch 2 / 50, step 4/28, loss = 2.4268
# epoch 2 / 50, step 5/28, loss = 1.9873
# epoch 2 / 50, step 6/28, loss = 2.2911
# epoch 2 / 50, step 7/28, loss = 1.7940
# epoch 2 / 50, step 8/28, loss = 1.7721
# epoch 2 / 50, step 9/28, loss = 2.4040
# epoch 2 / 50, step 10/28, loss = 1.8092
# epoch 2 / 50, step 11/28, loss = 2.0395
# epoch 2 / 50, step 12/28, loss = 1.6893
# epoch 2 / 50, step 13/28, loss = 2.2582
# epoch 2 / 50, step 14/28, loss = 2.1155
# epoch 2 / 50, step 15/28, loss = 1.7381
# epoch 2 / 50, step 16/28, loss = 2.6786
# epoch 2 / 50, step 17/28, loss = 2.0678
# epoch 2 / 50, step 18/28, loss = 2.0510
# epoch 2 / 50, step 19/28, loss = 2.2936
# epoch 2 / 50, step 20/28, loss = 1.6564
# epoch 2 / 50, step 21/28, loss = 2.0252
# epoch 2 / 50, step 22/28, loss = 2.4720
# epoch 2 / 50, step 23/28, loss = 2.0103
# epoch 2 / 50, step 24/28, loss = 2.1697
# epoch 2 / 50, step 25/28, loss = 2.1964
# epoch 2 / 50, step 26/28, loss = 2.4411
# epoch 2 / 50, step 27/28, loss = 2.7519
# epoch 2 / 50, step 28/28, loss = 1.5208
# epoch 3 / 50, step 1/110, loss = 2.3148
# epoch 3 / 50, step 2/110, loss = 3.0787
# epoch 3 / 50, step 3/110, loss = 1.8889
# epoch 3 / 50, step 4/110, loss = 2.5476
# epoch 3 / 50, step 5/110, loss = 2.2444
# epoch 3 / 50, step 6/110, loss = 2.6717
# epoch 3 / 50, step 7/110, loss = 2.3745
# epoch 3 / 50, step 8/110, loss = 3.0517
# epoch 3 / 50, step 9/110, loss = 2.8478
# epoch 3 / 50, step 10/110, loss = 2.3184
# epoch 3 / 50, step 11/110, loss = 3.0544
# epoch 3 / 50, step 12/110, loss = 2.4221
# epoch 3 / 50, step 13/110, loss = 2.3250
# epoch 3 / 50, step 14/110, loss = 2.0808
# epoch 3 / 50, step 15/110, loss = 2.8553
# epoch 3 / 50, step 16/110, loss = 2.9075
# epoch 3 / 50, step 17/110, loss = 3.0944
# epoch 3 / 50, step 18/110, loss = 3.0220
# epoch 3 / 50, step 19/110, loss = 2.1399
# epoch 3 / 50, step 20/110, loss = 2.6342
# epoch 3 / 50, step 21/110, loss = 2.3884
# epoch 3 / 50, step 22/110, loss = 3.4384
# epoch 3 / 50, step 23/110, loss = 2.9248
# epoch 3 / 50, step 24/110, loss = 2.6339
# epoch 3 / 50, step 25/110, loss = 2.3998
# epoch 3 / 50, step 26/110, loss = 2.3898
# epoch 3 / 50, step 27/110, loss = 2.4985
# epoch 3 / 50, step 28/110, loss = 3.0031
# epoch 3 / 50, step 29/110, loss = 2.8749
# epoch 3 / 50, step 30/110, loss = 3.0066
# epoch 3 / 50, step 31/110, loss = 2.1448
# epoch 3 / 50, step 32/110, loss = 2.9407
# epoch 3 / 50, step 33/110, loss = 2.5183
# epoch 3 / 50, step 34/110, loss = 2.6496
# epoch 3 / 50, step 35/110, loss = 3.6876
# epoch 3 / 50, step 36/110, loss = 1.3984
# epoch 3 / 50, step 37/110, loss = 2.2739
# epoch 3 / 50, step 38/110, loss = 2.9704
# epoch 3 / 50, step 39/110, loss = 2.8909
# epoch 3 / 50, step 40/110, loss = 1.9095
# epoch 3 / 50, step 41/110, loss = 2.9014
# epoch 3 / 50, step 42/110, loss = 3.0563
# epoch 3 / 50, step 43/110, loss = 2.0232
# epoch 3 / 50, step 44/110, loss = 1.9413
# epoch 3 / 50, step 45/110, loss = 1.2520
# epoch 3 / 50, step 46/110, loss = 3.6973
# epoch 3 / 50, step 47/110, loss = 3.5497
# epoch 3 / 50, step 48/110, loss = 2.5759
# epoch 3 / 50, step 49/110, loss = 2.2481
# epoch 3 / 50, step 50/110, loss = 2.7796
# epoch 3 / 50, step 51/110, loss = 3.6170
# epoch 3 / 50, step 52/110, loss = 2.1383
# epoch 3 / 50, step 53/110, loss = 3.0029
# epoch 3 / 50, step 54/110, loss = 3.4341
# epoch 3 / 50, step 55/110, loss = 1.8293
# epoch 3 / 50, step 56/110, loss = 3.1234
# epoch 3 / 50, step 57/110, loss = 3.8265
# epoch 3 / 50, step 58/110, loss = 3.4009
# epoch 3 / 50, step 59/110, loss = 2.6466
# epoch 3 / 50, step 60/110, loss = 4.3085
# epoch 3 / 50, step 61/110, loss = 1.8857
# epoch 3 / 50, step 62/110, loss = 2.4065
# epoch 3 / 50, step 63/110, loss = 3.2834
# epoch 3 / 50, step 64/110, loss = 2.4118
# epoch 3 / 50, step 65/110, loss = 2.0321
# epoch 3 / 50, step 66/110, loss = 2.4439
# epoch 3 / 50, step 67/110, loss = 1.9784
# epoch 3 / 50, step 68/110, loss = 2.0526
# epoch 3 / 50, step 69/110, loss = 3.9414
# epoch 3 / 50, step 70/110, loss = 2.6858
# epoch 3 / 50, step 71/110, loss = 2.6037
# epoch 3 / 50, step 72/110, loss = 2.5041
# epoch 3 / 50, step 73/110, loss = 3.5704
# epoch 3 / 50, step 74/110, loss = 2.7823
# epoch 3 / 50, step 75/110, loss = 2.7218
# epoch 3 / 50, step 76/110, loss = 2.8762
# epoch 3 / 50, step 77/110, loss = 1.9094
# epoch 3 / 50, step 78/110, loss = 2.9623
# epoch 3 / 50, step 79/110, loss = 3.1375
# epoch 3 / 50, step 80/110, loss = 1.7190
# epoch 3 / 50, step 81/110, loss = 4.3237
# epoch 3 / 50, step 82/110, loss = 2.7342
# epoch 3 / 50, step 83/110, loss = 2.3809
# epoch 3 / 50, step 84/110, loss = 2.4998
# epoch 3 / 50, step 85/110, loss = 2.3760
# epoch 3 / 50, step 86/110, loss = 2.7388
# epoch 3 / 50, step 87/110, loss = 2.7020
# epoch 3 / 50, step 88/110, loss = 2.2617
# epoch 3 / 50, step 89/110, loss = 2.8645
# epoch 3 / 50, step 90/110, loss = 2.1436
# epoch 3 / 50, step 91/110, loss = 3.4333
# epoch 3 / 50, step 92/110, loss = 2.7918
# epoch 3 / 50, step 93/110, loss = 2.6184
# epoch 3 / 50, step 94/110, loss = 2.4315
# epoch 3 / 50, step 95/110, loss = 2.2592
# epoch 3 / 50, step 96/110, loss = 2.2259
# epoch 3 / 50, step 97/110, loss = 2.9518
# epoch 3 / 50, step 98/110, loss = 2.0410
# epoch 3 / 50, step 99/110, loss = 4.4526
# epoch 3 / 50, step 100/110, loss = 2.4215
# epoch 3 / 50, step 101/110, loss = 2.8561
# epoch 3 / 50, step 102/110, loss = 2.4427
# epoch 3 / 50, step 103/110, loss = 3.8161
# epoch 3 / 50, step 104/110, loss = 2.2557
# epoch 3 / 50, step 105/110, loss = 3.6385
# epoch 3 / 50, step 106/110, loss = 2.7569
# epoch 3 / 50, step 107/110, loss = 3.0801
# epoch 3 / 50, step 108/110, loss = 2.6544
# epoch 3 / 50, step 109/110, loss = 3.0896
# epoch 3 / 50, step 110/110, loss = 4.4460
# epoch 3 / 50, step 1/28, loss = 3.2009
# epoch 3 / 50, step 2/28, loss = 3.0698
# epoch 3 / 50, step 3/28, loss = 1.5312
# epoch 3 / 50, step 4/28, loss = 3.3793
# epoch 3 / 50, step 5/28, loss = 3.1979
# epoch 3 / 50, step 6/28, loss = 3.4603
# epoch 3 / 50, step 7/28, loss = 2.0160
# epoch 3 / 50, step 8/28, loss = 2.1249
# epoch 3 / 50, step 9/28, loss = 2.9792
# epoch 3 / 50, step 10/28, loss = 2.6568
# epoch 3 / 50, step 11/28, loss = 2.2115
# epoch 3 / 50, step 12/28, loss = 2.1607
# epoch 3 / 50, step 13/28, loss = 2.5478
# epoch 3 / 50, step 14/28, loss = 2.6105
# epoch 3 / 50, step 15/28, loss = 2.0808
# epoch 3 / 50, step 16/28, loss = 3.4596
# epoch 3 / 50, step 17/28, loss = 2.8363
# epoch 3 / 50, step 18/28, loss = 2.1832
# epoch 3 / 50, step 19/28, loss = 3.1877
# epoch 3 / 50, step 20/28, loss = 2.4291
# epoch 3 / 50, step 21/28, loss = 3.0989
# epoch 3 / 50, step 22/28, loss = 3.4887
# epoch 3 / 50, step 23/28, loss = 2.8387
# epoch 3 / 50, step 24/28, loss = 2.6865
# epoch 3 / 50, step 25/28, loss = 2.1789
# epoch 3 / 50, step 26/28, loss = 3.4003
# epoch 3 / 50, step 27/28, loss = 3.2463
# epoch 3 / 50, step 28/28, loss = 2.3428
# epoch 4 / 50, step 1/110, loss = 3.5869
# epoch 4 / 50, step 2/110, loss = 2.8058
# epoch 4 / 50, step 3/110, loss = 2.4350
# epoch 4 / 50, step 4/110, loss = 2.4575
# epoch 4 / 50, step 5/110, loss = 2.3043
# epoch 4 / 50, step 6/110, loss = 1.8334
# epoch 4 / 50, step 7/110, loss = 3.1727
# epoch 4 / 50, step 8/110, loss = 2.2935
# epoch 4 / 50, step 9/110, loss = 3.9735
# epoch 4 / 50, step 10/110, loss = 3.0892
# epoch 4 / 50, step 11/110, loss = 4.5272
# epoch 4 / 50, step 12/110, loss = 2.7225
# epoch 4 / 50, step 13/110, loss = 2.6583
# epoch 4 / 50, step 14/110, loss = 3.6933
# epoch 4 / 50, step 15/110, loss = 4.2015
# epoch 4 / 50, step 16/110, loss = 2.7780
# epoch 4 / 50, step 17/110, loss = 3.8893
# epoch 4 / 50, step 18/110, loss = 3.0129
# epoch 4 / 50, step 19/110, loss = 2.3840
# epoch 4 / 50, step 20/110, loss = 2.6225
# epoch 4 / 50, step 21/110, loss = 2.3741
# epoch 4 / 50, step 22/110, loss = 2.3168
# epoch 4 / 50, step 23/110, loss = 3.0095
# epoch 4 / 50, step 24/110, loss = 2.7262
# epoch 4 / 50, step 25/110, loss = 3.6192
# epoch 4 / 50, step 26/110, loss = 3.2693
# epoch 4 / 50, step 27/110, loss = 3.0243
# epoch 4 / 50, step 28/110, loss = 3.6865
# epoch 4 / 50, step 29/110, loss = 2.9784
# epoch 4 / 50, step 30/110, loss = 2.2928
# epoch 4 / 50, step 31/110, loss = 3.9892
# epoch 4 / 50, step 32/110, loss = 2.6191
# epoch 4 / 50, step 33/110, loss = 4.0240
# epoch 4 / 50, step 34/110, loss = 2.8012
# epoch 4 / 50, step 35/110, loss = 2.0976
# epoch 4 / 50, step 36/110, loss = 4.0179
# epoch 4 / 50, step 37/110, loss = 2.3262
# epoch 4 / 50, step 38/110, loss = 3.0429
# epoch 4 / 50, step 39/110, loss = 2.2447
# epoch 4 / 50, step 40/110, loss = 3.3450
# epoch 4 / 50, step 41/110, loss = 2.8244
# epoch 4 / 50, step 42/110, loss = 3.6452
# epoch 4 / 50, step 43/110, loss = 3.1147
# epoch 4 / 50, step 44/110, loss = 3.1368
# epoch 4 / 50, step 45/110, loss = 3.0582
# epoch 4 / 50, step 46/110, loss = 3.4728
# epoch 4 / 50, step 47/110, loss = 3.0646
# epoch 4 / 50, step 48/110, loss = 2.5884
# epoch 4 / 50, step 49/110, loss = 3.2395
# epoch 4 / 50, step 50/110, loss = 3.1690
# epoch 4 / 50, step 51/110, loss = 2.4393
# epoch 4 / 50, step 52/110, loss = 2.9227
# epoch 4 / 50, step 53/110, loss = 2.8998
# epoch 4 / 50, step 54/110, loss = 3.5436
# epoch 4 / 50, step 55/110, loss = 3.4644
# epoch 4 / 50, step 56/110, loss = 2.0579
# epoch 4 / 50, step 57/110, loss = 3.1206
# epoch 4 / 50, step 58/110, loss = 2.4230
# epoch 4 / 50, step 59/110, loss = 1.8556
# epoch 4 / 50, step 60/110, loss = 2.9029
# epoch 4 / 50, step 61/110, loss = 3.3283
# epoch 4 / 50, step 62/110, loss = 2.3737
# epoch 4 / 50, step 63/110, loss = 2.0881
# epoch 4 / 50, step 64/110, loss = 2.3604
# epoch 4 / 50, step 65/110, loss = 2.5363
# epoch 4 / 50, step 66/110, loss = 3.2772
# epoch 4 / 50, step 67/110, loss = 3.3002
# epoch 4 / 50, step 68/110, loss = 2.7793
# epoch 4 / 50, step 69/110, loss = 2.3571
# epoch 4 / 50, step 70/110, loss = 3.5777
# epoch 4 / 50, step 71/110, loss = 2.5049
# epoch 4 / 50, step 72/110, loss = 2.9294
# epoch 4 / 50, step 73/110, loss = 2.4480
# epoch 4 / 50, step 74/110, loss = 2.2413
# epoch 4 / 50, step 75/110, loss = 2.1048
# epoch 4 / 50, step 76/110, loss = 3.0500
# epoch 4 / 50, step 77/110, loss = 1.5208
# epoch 4 / 50, step 78/110, loss = 3.2228
# epoch 4 / 50, step 79/110, loss = 3.6401
# epoch 4 / 50, step 80/110, loss = 3.1632
# epoch 4 / 50, step 81/110, loss = 2.6600
# epoch 4 / 50, step 82/110, loss = 2.5294
# epoch 4 / 50, step 83/110, loss = 2.3829
# epoch 4 / 50, step 84/110, loss = 3.6602
# epoch 4 / 50, step 85/110, loss = 1.9498
# epoch 4 / 50, step 86/110, loss = 2.0688
# epoch 4 / 50, step 87/110, loss = 1.7620
# epoch 4 / 50, step 88/110, loss = 3.3780
# epoch 4 / 50, step 89/110, loss = 2.5448
# epoch 4 / 50, step 90/110, loss = 2.8830
# epoch 4 / 50, step 91/110, loss = 2.8043
# epoch 4 / 50, step 92/110, loss = 2.3455
# epoch 4 / 50, step 93/110, loss = 2.3890
# epoch 4 / 50, step 94/110, loss = 2.4324
# epoch 4 / 50, step 95/110, loss = 3.4765
# epoch 4 / 50, step 96/110, loss = 2.7502
# epoch 4 / 50, step 97/110, loss = 2.1004
# epoch 4 / 50, step 98/110, loss = 3.2947
# epoch 4 / 50, step 99/110, loss = 4.1310
# epoch 4 / 50, step 100/110, loss = 4.7127
# epoch 4 / 50, step 101/110, loss = 3.0377
# epoch 4 / 50, step 102/110, loss = 2.5235
# epoch 4 / 50, step 103/110, loss = 2.4817
# epoch 4 / 50, step 104/110, loss = 2.6569
# epoch 4 / 50, step 105/110, loss = 3.2985
# epoch 4 / 50, step 106/110, loss = 2.4590
# epoch 4 / 50, step 107/110, loss = 1.4438
# epoch 4 / 50, step 108/110, loss = 4.5980
# epoch 4 / 50, step 109/110, loss = 4.9197
# epoch 4 / 50, step 110/110, loss = 4.1831
# epoch 4 / 50, step 1/28, loss = 2.2894
# epoch 4 / 50, step 2/28, loss = 2.4173
# epoch 4 / 50, step 3/28, loss = 3.0737
# epoch 4 / 50, step 4/28, loss = 2.3879
# epoch 4 / 50, step 5/28, loss = 1.7160
# epoch 4 / 50, step 6/28, loss = 1.9725
# epoch 4 / 50, step 7/28, loss = 2.3512
# epoch 4 / 50, step 8/28, loss = 2.2494
# epoch 4 / 50, step 9/28, loss = 2.6105
# epoch 4 / 50, step 10/28, loss = 2.4689
# epoch 4 / 50, step 11/28, loss = 2.8915
# epoch 4 / 50, step 12/28, loss = 2.3644
# epoch 4 / 50, step 13/28, loss = 2.8351
# epoch 4 / 50, step 14/28, loss = 2.3459
# epoch 4 / 50, step 15/28, loss = 2.4117
# epoch 4 / 50, step 16/28, loss = 2.4253
# epoch 4 / 50, step 17/28, loss = 2.4675
# epoch 4 / 50, step 18/28, loss = 3.0132
# epoch 4 / 50, step 19/28, loss = 2.3033
# epoch 4 / 50, step 20/28, loss = 1.8627
# epoch 4 / 50, step 21/28, loss = 2.3667
# epoch 4 / 50, step 22/28, loss = 2.3747
# epoch 4 / 50, step 23/28, loss = 2.3444
# epoch 4 / 50, step 24/28, loss = 2.5286
# epoch 4 / 50, step 25/28, loss = 3.1652
# epoch 4 / 50, step 26/28, loss = 2.3860
# epoch 4 / 50, step 27/28, loss = 2.7359
# epoch 4 / 50, step 28/28, loss = 2.1116
# epoch 5 / 50, step 1/110, loss = 2.9944
# epoch 5 / 50, step 2/110, loss = 2.8898
# epoch 5 / 50, step 3/110, loss = 2.9369
# epoch 5 / 50, step 4/110, loss = 3.0270
# epoch 5 / 50, step 5/110, loss = 3.6360
# epoch 5 / 50, step 6/110, loss = 2.9193
# epoch 5 / 50, step 7/110, loss = 2.9625
# epoch 5 / 50, step 8/110, loss = 4.1492
# epoch 5 / 50, step 9/110, loss = 3.8614
# epoch 5 / 50, step 10/110, loss = 2.5768
# epoch 5 / 50, step 11/110, loss = 2.6311
# epoch 5 / 50, step 12/110, loss = 2.6826
# epoch 5 / 50, step 13/110, loss = 1.9436
# epoch 5 / 50, step 14/110, loss = 1.9748
# epoch 5 / 50, step 15/110, loss = 3.4730
# epoch 5 / 50, step 16/110, loss = 3.4789
# epoch 5 / 50, step 17/110, loss = 2.2988
# epoch 5 / 50, step 18/110, loss = 2.9862
# epoch 5 / 50, step 19/110, loss = 1.7230
# epoch 5 / 50, step 20/110, loss = 3.2979
# epoch 5 / 50, step 21/110, loss = 2.6902
# epoch 5 / 50, step 22/110, loss = 2.4755
# epoch 5 / 50, step 23/110, loss = 2.4904
# epoch 5 / 50, step 24/110, loss = 2.8093
# epoch 5 / 50, step 25/110, loss = 2.7696
# epoch 5 / 50, step 26/110, loss = 3.2925
# epoch 5 / 50, step 27/110, loss = 4.6250
# epoch 5 / 50, step 28/110, loss = 1.8845
# epoch 5 / 50, step 29/110, loss = 2.0447
# epoch 5 / 50, step 30/110, loss = 3.0413
# epoch 5 / 50, step 31/110, loss = 2.2612
# epoch 5 / 50, step 32/110, loss = 2.7085
# epoch 5 / 50, step 33/110, loss = 2.6840
# epoch 5 / 50, step 34/110, loss = 2.8741
# epoch 5 / 50, step 35/110, loss = 2.2566
# epoch 5 / 50, step 36/110, loss = 3.0108
# epoch 5 / 50, step 37/110, loss = 2.9865
# epoch 5 / 50, step 38/110, loss = 2.6481
# epoch 5 / 50, step 39/110, loss = 3.5121
# epoch 5 / 50, step 40/110, loss = 3.1065
# epoch 5 / 50, step 41/110, loss = 3.7035
# epoch 5 / 50, step 42/110, loss = 2.4373
# epoch 5 / 50, step 43/110, loss = 3.9028
# epoch 5 / 50, step 44/110, loss = 2.4263
# epoch 5 / 50, step 45/110, loss = 2.7664
# epoch 5 / 50, step 46/110, loss = 3.3109
# epoch 5 / 50, step 47/110, loss = 2.3785
# epoch 5 / 50, step 48/110, loss = 2.9765
# epoch 5 / 50, step 49/110, loss = 2.3884
# epoch 5 / 50, step 50/110, loss = 3.3115
# epoch 5 / 50, step 51/110, loss = 5.5406
# epoch 5 / 50, step 52/110, loss = 3.9636
# epoch 5 / 50, step 53/110, loss = 3.7850
# epoch 5 / 50, step 54/110, loss = 2.8753
# epoch 5 / 50, step 55/110, loss = 2.7166
# epoch 5 / 50, step 56/110, loss = 3.5097
# epoch 5 / 50, step 57/110, loss = 2.8469
# epoch 5 / 50, step 58/110, loss = 1.5768
# epoch 5 / 50, step 59/110, loss = 3.0104
# epoch 5 / 50, step 60/110, loss = 2.7814
# epoch 5 / 50, step 61/110, loss = 4.4846
# epoch 5 / 50, step 62/110, loss = 3.6292
# epoch 5 / 50, step 63/110, loss = 3.7610
# epoch 5 / 50, step 64/110, loss = 2.4570
# epoch 5 / 50, step 65/110, loss = 3.1957
# epoch 5 / 50, step 66/110, loss = 3.0699
# epoch 5 / 50, step 67/110, loss = 2.5892
# epoch 5 / 50, step 68/110, loss = 2.6734
# epoch 5 / 50, step 69/110, loss = 2.7815
# epoch 5 / 50, step 70/110, loss = 2.7955
# epoch 5 / 50, step 71/110, loss = 2.7000
# epoch 5 / 50, step 72/110, loss = 2.8677
# epoch 5 / 50, step 73/110, loss = 2.3564
# epoch 5 / 50, step 74/110, loss = 1.9857
# epoch 5 / 50, step 75/110, loss = 2.7296
# epoch 5 / 50, step 76/110, loss = 3.3447
# epoch 5 / 50, step 77/110, loss = 2.2065
# epoch 5 / 50, step 78/110, loss = 2.1051
# epoch 5 / 50, step 79/110, loss = 3.3755
# epoch 5 / 50, step 80/110, loss = 2.4848
# epoch 5 / 50, step 81/110, loss = 2.6504
# epoch 5 / 50, step 82/110, loss = 2.8568
# epoch 5 / 50, step 83/110, loss = 3.0674
# epoch 5 / 50, step 84/110, loss = 2.8302
# epoch 5 / 50, step 85/110, loss = 2.4631
# epoch 5 / 50, step 86/110, loss = 2.4553
# epoch 5 / 50, step 87/110, loss = 3.0701
# epoch 5 / 50, step 88/110, loss = 3.3332
# epoch 5 / 50, step 89/110, loss = 2.6234
# epoch 5 / 50, step 90/110, loss = 2.6783
# epoch 5 / 50, step 91/110, loss = 2.5106
# epoch 5 / 50, step 92/110, loss = 3.3226
# epoch 5 / 50, step 93/110, loss = 3.5694
# epoch 5 / 50, step 94/110, loss = 3.2010
# epoch 5 / 50, step 95/110, loss = 2.3699
# epoch 5 / 50, step 96/110, loss = 2.4100
# epoch 5 / 50, step 97/110, loss = 2.7221
# epoch 5 / 50, step 98/110, loss = 2.6365
# epoch 5 / 50, step 99/110, loss = 3.4581
# epoch 5 / 50, step 100/110, loss = 2.5648
# epoch 5 / 50, step 101/110, loss = 2.4397
# epoch 5 / 50, step 102/110, loss = 2.7496
# epoch 5 / 50, step 103/110, loss = 2.7204
# epoch 5 / 50, step 104/110, loss = 2.6936
# epoch 5 / 50, step 105/110, loss = 2.1825
# epoch 5 / 50, step 106/110, loss = 2.2850
# epoch 5 / 50, step 107/110, loss = 1.7091
# epoch 5 / 50, step 108/110, loss = 3.1618
# epoch 5 / 50, step 109/110, loss = 3.1164
# epoch 5 / 50, step 110/110, loss = 1.5971
# epoch 5 / 50, step 1/28, loss = 2.9514
# epoch 5 / 50, step 2/28, loss = 2.7757
# epoch 5 / 50, step 3/28, loss = 1.8594
# epoch 5 / 50, step 4/28, loss = 2.2970
# epoch 5 / 50, step 5/28, loss = 2.6911
# epoch 5 / 50, step 6/28, loss = 3.0416
# epoch 5 / 50, step 7/28, loss = 2.3795
# epoch 5 / 50, step 8/28, loss = 2.3812
# epoch 5 / 50, step 9/28, loss = 2.9010
# epoch 5 / 50, step 10/28, loss = 2.7682
# epoch 5 / 50, step 11/28, loss = 2.4198
# epoch 5 / 50, step 12/28, loss = 2.4738
# epoch 5 / 50, step 13/28, loss = 2.7731
# epoch 5 / 50, step 14/28, loss = 1.7445
# epoch 5 / 50, step 15/28, loss = 2.8078
# epoch 5 / 50, step 16/28, loss = 2.9169
# epoch 5 / 50, step 17/28, loss = 3.0027
# epoch 5 / 50, step 18/28, loss = 2.8244
# epoch 5 / 50, step 19/28, loss = 2.5937
# epoch 5 / 50, step 20/28, loss = 2.6059
# epoch 5 / 50, step 21/28, loss = 2.9150
# epoch 5 / 50, step 22/28, loss = 3.0562
# epoch 5 / 50, step 23/28, loss = 2.4705
# epoch 5 / 50, step 24/28, loss = 2.3682
# epoch 5 / 50, step 25/28, loss = 1.9237
# epoch 5 / 50, step 26/28, loss = 2.3678
# epoch 5 / 50, step 27/28, loss = 2.7961
# epoch 5 / 50, step 28/28, loss = 3.0024
# epoch 6 / 50, step 1/110, loss = 3.1347
# epoch 6 / 50, step 2/110, loss = 3.4929
# epoch 6 / 50, step 3/110, loss = 3.3587
# epoch 6 / 50, step 4/110, loss = 2.7647
# epoch 6 / 50, step 5/110, loss = 2.1648
# epoch 6 / 50, step 6/110, loss = 3.4219
# epoch 6 / 50, step 7/110, loss = 2.5896
# epoch 6 / 50, step 8/110, loss = 2.2571
# epoch 6 / 50, step 9/110, loss = 1.6500
# epoch 6 / 50, step 10/110, loss = 2.1173
# epoch 6 / 50, step 11/110, loss = 1.7327
# epoch 6 / 50, step 12/110, loss = 2.9800
# epoch 6 / 50, step 13/110, loss = 2.4476
# epoch 6 / 50, step 14/110, loss = 3.0527
# epoch 6 / 50, step 15/110, loss = 3.0423
# epoch 6 / 50, step 16/110, loss = 2.3653
# epoch 6 / 50, step 17/110, loss = 1.8517
# epoch 6 / 50, step 18/110, loss = 2.4275
# epoch 6 / 50, step 19/110, loss = 2.3798
# epoch 6 / 50, step 20/110, loss = 3.2708
# epoch 6 / 50, step 21/110, loss = 1.8662
# epoch 6 / 50, step 22/110, loss = 2.4112
# epoch 6 / 50, step 23/110, loss = 2.7482
# epoch 6 / 50, step 24/110, loss = 2.8509
# epoch 6 / 50, step 25/110, loss = 2.6108
# epoch 6 / 50, step 26/110, loss = 1.9407
# epoch 6 / 50, step 27/110, loss = 2.6662
# epoch 6 / 50, step 28/110, loss = 3.1318
# epoch 6 / 50, step 29/110, loss = 2.0456
# epoch 6 / 50, step 30/110, loss = 3.7569
# epoch 6 / 50, step 31/110, loss = 3.1213
# epoch 6 / 50, step 32/110, loss = 3.4230
# epoch 6 / 50, step 33/110, loss = 3.0760
# epoch 6 / 50, step 34/110, loss = 2.9907
# epoch 6 / 50, step 35/110, loss = 2.9491
# epoch 6 / 50, step 36/110, loss = 2.6262
# epoch 6 / 50, step 37/110, loss = 2.9190
# epoch 6 / 50, step 38/110, loss = 3.7665
# epoch 6 / 50, step 39/110, loss = 3.6067
# epoch 6 / 50, step 40/110, loss = 2.4661
# epoch 6 / 50, step 41/110, loss = 3.4298
# epoch 6 / 50, step 42/110, loss = 3.6216
# epoch 6 / 50, step 43/110, loss = 2.1247
# epoch 6 / 50, step 44/110, loss = 2.8452
# epoch 6 / 50, step 45/110, loss = 2.0708
# epoch 6 / 50, step 46/110, loss = 2.0134
# epoch 6 / 50, step 47/110, loss = 3.2675
# epoch 6 / 50, step 48/110, loss = 4.1744
# epoch 6 / 50, step 49/110, loss = 2.8797
# epoch 6 / 50, step 50/110, loss = 4.3236
# epoch 6 / 50, step 51/110, loss = 3.9808
# epoch 6 / 50, step 52/110, loss = 2.0702
# epoch 6 / 50, step 53/110, loss = 2.9321
# epoch 6 / 50, step 54/110, loss = 2.9323
# epoch 6 / 50, step 55/110, loss = 3.5480
# epoch 6 / 50, step 56/110, loss = 3.5930
# epoch 6 / 50, step 57/110, loss = 3.6052
# epoch 6 / 50, step 58/110, loss = 2.5795
# epoch 6 / 50, step 59/110, loss = 2.9988
# epoch 6 / 50, step 60/110, loss = 2.5532
# epoch 6 / 50, step 61/110, loss = 1.9264
# epoch 6 / 50, step 62/110, loss = 2.5577
# epoch 6 / 50, step 63/110, loss = 2.6069
# epoch 6 / 50, step 64/110, loss = 2.6281
# epoch 6 / 50, step 65/110, loss = 4.1004
# epoch 6 / 50, step 66/110, loss = 3.4477
# epoch 6 / 50, step 67/110, loss = 2.8682
# epoch 6 / 50, step 68/110, loss = 3.0687
# epoch 6 / 50, step 69/110, loss = 3.2772
# epoch 6 / 50, step 70/110, loss = 2.6507
# epoch 6 / 50, step 71/110, loss = 2.2709
# epoch 6 / 50, step 72/110, loss = 2.7570
# epoch 6 / 50, step 73/110, loss = 1.6128
# epoch 6 / 50, step 74/110, loss = 2.8842
# epoch 6 / 50, step 75/110, loss = 2.3041
# epoch 6 / 50, step 76/110, loss = 2.0511
# epoch 6 / 50, step 77/110, loss = 3.4452
# epoch 6 / 50, step 78/110, loss = 2.0003
# epoch 6 / 50, step 79/110, loss = 1.7820
# epoch 6 / 50, step 80/110, loss = 2.4613
# epoch 6 / 50, step 81/110, loss = 2.2569
# epoch 6 / 50, step 82/110, loss = 2.6384
# epoch 6 / 50, step 83/110, loss = 2.6273
# epoch 6 / 50, step 84/110, loss = 2.4468
# epoch 6 / 50, step 85/110, loss = 2.6446
# epoch 6 / 50, step 86/110, loss = 2.3898
# epoch 6 / 50, step 87/110, loss = 2.5734
# epoch 6 / 50, step 88/110, loss = 2.7737
# epoch 6 / 50, step 89/110, loss = 3.1087
# epoch 6 / 50, step 90/110, loss = 2.2097
# epoch 6 / 50, step 91/110, loss = 3.2062
# epoch 6 / 50, step 92/110, loss = 2.8520
# epoch 6 / 50, step 93/110, loss = 2.3610
# epoch 6 / 50, step 94/110, loss = 2.6466
# epoch 6 / 50, step 95/110, loss = 2.1337
# epoch 6 / 50, step 96/110, loss = 2.7653
# epoch 6 / 50, step 97/110, loss = 3.0032
# epoch 6 / 50, step 98/110, loss = 2.6786
# epoch 6 / 50, step 99/110, loss = 2.8629
# epoch 6 / 50, step 100/110, loss = 2.6648
# epoch 6 / 50, step 101/110, loss = 2.2108
# epoch 6 / 50, step 102/110, loss = 2.8117
# epoch 6 / 50, step 103/110, loss = 3.0202
# epoch 6 / 50, step 104/110, loss = 2.6152
# epoch 6 / 50, step 105/110, loss = 4.3998
# epoch 6 / 50, step 106/110, loss = 2.8528
# epoch 6 / 50, step 107/110, loss = 2.3314
# epoch 6 / 50, step 108/110, loss = 1.6226
# epoch 6 / 50, step 109/110, loss = 2.6435
# epoch 6 / 50, step 110/110, loss = 3.5187
# epoch 6 / 50, step 1/28, loss = 2.1450
# epoch 6 / 50, step 2/28, loss = 2.2091
# epoch 6 / 50, step 3/28, loss = 1.5986
# epoch 6 / 50, step 4/28, loss = 2.1437
# epoch 6 / 50, step 5/28, loss = 2.2199
# epoch 6 / 50, step 6/28, loss = 2.1574
# epoch 6 / 50, step 7/28, loss = 1.8358
# epoch 6 / 50, step 8/28, loss = 2.0127
# epoch 6 / 50, step 9/28, loss = 2.1126
# epoch 6 / 50, step 10/28, loss = 2.2153
# epoch 6 / 50, step 11/28, loss = 1.9813
# epoch 6 / 50, step 12/28, loss = 1.8531
# epoch 6 / 50, step 13/28, loss = 2.1123
# epoch 6 / 50, step 14/28, loss = 1.9531
# epoch 6 / 50, step 15/28, loss = 1.8655
# epoch 6 / 50, step 16/28, loss = 2.1245
# epoch 6 / 50, step 17/28, loss = 2.1873
# epoch 6 / 50, step 18/28, loss = 2.1545
# epoch 6 / 50, step 19/28, loss = 2.2763
# epoch 6 / 50, step 20/28, loss = 1.9124
# epoch 6 / 50, step 21/28, loss = 2.2719
# epoch 6 / 50, step 22/28, loss = 2.1873
# epoch 6 / 50, step 23/28, loss = 2.0761
# epoch 6 / 50, step 24/28, loss = 2.1782
# epoch 6 / 50, step 25/28, loss = 2.0564
# epoch 6 / 50, step 26/28, loss = 2.2396
# epoch 6 / 50, step 27/28, loss = 2.0687
# epoch 6 / 50, step 28/28, loss = 2.0155
# epoch 7 / 50, step 1/110, loss = 2.2525
# epoch 7 / 50, step 2/110, loss = 2.6271
# epoch 7 / 50, step 3/110, loss = 2.2325
# epoch 7 / 50, step 4/110, loss = 2.0896
# epoch 7 / 50, step 5/110, loss = 2.1852
# epoch 7 / 50, step 6/110, loss = 2.2619
# epoch 7 / 50, step 7/110, loss = 2.2047
# epoch 7 / 50, step 8/110, loss = 2.7670
# epoch 7 / 50, step 9/110, loss = 2.0380
# epoch 7 / 50, step 10/110, loss = 2.4725
# epoch 7 / 50, step 11/110, loss = 5.0027
# epoch 7 / 50, step 12/110, loss = 2.7501
# epoch 7 / 50, step 13/110, loss = 2.6913
# epoch 7 / 50, step 14/110, loss = 2.9867
# epoch 7 / 50, step 15/110, loss = 2.2696
# epoch 7 / 50, step 16/110, loss = 2.5468
# epoch 7 / 50, step 17/110, loss = 2.6125
# epoch 7 / 50, step 18/110, loss = 2.9986
# epoch 7 / 50, step 19/110, loss = 2.6697
# epoch 7 / 50, step 20/110, loss = 2.5662
# epoch 7 / 50, step 21/110, loss = 2.6186
# epoch 7 / 50, step 22/110, loss = 2.4244
# epoch 7 / 50, step 23/110, loss = 2.9998
# epoch 7 / 50, step 24/110, loss = 4.3068
# epoch 7 / 50, step 25/110, loss = 3.4310
# epoch 7 / 50, step 26/110, loss = 3.3776
# epoch 7 / 50, step 27/110, loss = 2.7755
# epoch 7 / 50, step 28/110, loss = 1.6305
# epoch 7 / 50, step 29/110, loss = 1.8900
# epoch 7 / 50, step 30/110, loss = 3.3971
# epoch 7 / 50, step 31/110, loss = 3.1173
# epoch 7 / 50, step 32/110, loss = 4.0386
# epoch 7 / 50, step 33/110, loss = 2.6756
# epoch 7 / 50, step 34/110, loss = 3.5431
# epoch 7 / 50, step 35/110, loss = 4.0692
# epoch 7 / 50, step 36/110, loss = 1.7943
# epoch 7 / 50, step 37/110, loss = 2.9006
# epoch 7 / 50, step 38/110, loss = 2.5536
# epoch 7 / 50, step 39/110, loss = 2.5487
# epoch 7 / 50, step 40/110, loss = 3.2532
# epoch 7 / 50, step 41/110, loss = 3.2523
# epoch 7 / 50, step 42/110, loss = 3.1518
# epoch 7 / 50, step 43/110, loss = 2.0336
# epoch 7 / 50, step 44/110, loss = 3.0484
# epoch 7 / 50, step 45/110, loss = 1.2295
# epoch 7 / 50, step 46/110, loss = 2.7033
# epoch 7 / 50, step 47/110, loss = 2.4506
# epoch 7 / 50, step 48/110, loss = 2.6694
# epoch 7 / 50, step 49/110, loss = 2.8583
# epoch 7 / 50, step 50/110, loss = 2.5393
# epoch 7 / 50, step 51/110, loss = 2.0803
# epoch 7 / 50, step 52/110, loss = 3.0025
# epoch 7 / 50, step 53/110, loss = 2.3982
# epoch 7 / 50, step 54/110, loss = 1.7604
# epoch 7 / 50, step 55/110, loss = 2.9661
# epoch 7 / 50, step 56/110, loss = 1.9654
# epoch 7 / 50, step 57/110, loss = 3.1605
# epoch 7 / 50, step 58/110, loss = 2.2302
# epoch 7 / 50, step 59/110, loss = 2.7639
# epoch 7 / 50, step 60/110, loss = 2.4629
# epoch 7 / 50, step 61/110, loss = 3.4650
# epoch 7 / 50, step 62/110, loss = 1.8247
# epoch 7 / 50, step 63/110, loss = 3.0554
# epoch 7 / 50, step 64/110, loss = 3.1130
# epoch 7 / 50, step 65/110, loss = 2.1819
# epoch 7 / 50, step 66/110, loss = 3.2093
# epoch 7 / 50, step 67/110, loss = 2.7631
# epoch 7 / 50, step 68/110, loss = 1.9092
# epoch 7 / 50, step 69/110, loss = 2.5936
# epoch 7 / 50, step 70/110, loss = 2.3347
# epoch 7 / 50, step 71/110, loss = 2.7988
# epoch 7 / 50, step 72/110, loss = 2.7425
# epoch 7 / 50, step 73/110, loss = 2.2823
# epoch 7 / 50, step 74/110, loss = 2.5334
# epoch 7 / 50, step 75/110, loss = 1.8797
# epoch 7 / 50, step 76/110, loss = 3.0223
# epoch 7 / 50, step 77/110, loss = 2.9583
# epoch 7 / 50, step 78/110, loss = 2.6162
# epoch 7 / 50, step 79/110, loss = 2.3920
# epoch 7 / 50, step 80/110, loss = 3.3435
# epoch 7 / 50, step 81/110, loss = 3.2918
# epoch 7 / 50, step 82/110, loss = 1.5635
# epoch 7 / 50, step 83/110, loss = 2.9052
# epoch 7 / 50, step 84/110, loss = 2.9893
# epoch 7 / 50, step 85/110, loss = 2.2522
# epoch 7 / 50, step 86/110, loss = 2.6604
# epoch 7 / 50, step 87/110, loss = 4.3272
# epoch 7 / 50, step 88/110, loss = 2.3762
# epoch 7 / 50, step 89/110, loss = 1.9404
# epoch 7 / 50, step 90/110, loss = 3.9493
# epoch 7 / 50, step 91/110, loss = 2.9622
# epoch 7 / 50, step 92/110, loss = 2.9755
# epoch 7 / 50, step 93/110, loss = 3.8484
# epoch 7 / 50, step 94/110, loss = 4.4068
# epoch 7 / 50, step 95/110, loss = 3.6009
# epoch 7 / 50, step 96/110, loss = 2.5255
# epoch 7 / 50, step 97/110, loss = 2.9326
# epoch 7 / 50, step 98/110, loss = 2.4992
# epoch 7 / 50, step 99/110, loss = 2.0996
# epoch 7 / 50, step 100/110, loss = 3.4793
# epoch 7 / 50, step 101/110, loss = 2.4919
# epoch 7 / 50, step 102/110, loss = 2.9124
# epoch 7 / 50, step 103/110, loss = 2.0293
# epoch 7 / 50, step 104/110, loss = 2.3102
# epoch 7 / 50, step 105/110, loss = 2.7244
# epoch 7 / 50, step 106/110, loss = 3.3661
# epoch 7 / 50, step 107/110, loss = 2.9048
# epoch 7 / 50, step 108/110, loss = 2.5153
# epoch 7 / 50, step 109/110, loss = 3.3267
# epoch 7 / 50, step 110/110, loss = 1.8661
# epoch 7 / 50, step 1/28, loss = 2.5549
# epoch 7 / 50, step 2/28, loss = 2.2154
# epoch 7 / 50, step 3/28, loss = 2.0490
# epoch 7 / 50, step 4/28, loss = 2.5941
# epoch 7 / 50, step 5/28, loss = 2.7270
# epoch 7 / 50, step 6/28, loss = 2.4051
# epoch 7 / 50, step 7/28, loss = 2.9642
# epoch 7 / 50, step 8/28, loss = 2.9113
# epoch 7 / 50, step 9/28, loss = 2.1478
# epoch 7 / 50, step 10/28, loss = 3.0663
# epoch 7 / 50, step 11/28, loss = 2.5871
# epoch 7 / 50, step 12/28, loss = 3.1140
# epoch 7 / 50, step 13/28, loss = 2.1684
# epoch 7 / 50, step 14/28, loss = 2.6886
# epoch 7 / 50, step 15/28, loss = 3.0101
# epoch 7 / 50, step 16/28, loss = 2.1247
# epoch 7 / 50, step 17/28, loss = 2.6233
# epoch 7 / 50, step 18/28, loss = 2.2368
# epoch 7 / 50, step 19/28, loss = 2.2626
# epoch 7 / 50, step 20/28, loss = 3.6125
# epoch 7 / 50, step 21/28, loss = 2.8202
# epoch 7 / 50, step 22/28, loss = 2.7294
# epoch 7 / 50, step 23/28, loss = 2.9049
# epoch 7 / 50, step 24/28, loss = 2.2352
# epoch 7 / 50, step 25/28, loss = 2.1830
# epoch 7 / 50, step 26/28, loss = 2.7952
# epoch 7 / 50, step 27/28, loss = 2.2718
# epoch 7 / 50, step 28/28, loss = 3.2697
# epoch 8 / 50, step 1/110, loss = 4.1057
# epoch 8 / 50, step 2/110, loss = 3.2399
# epoch 8 / 50, step 3/110, loss = 3.1484
# epoch 8 / 50, step 4/110, loss = 1.8250
# epoch 8 / 50, step 5/110, loss = 2.4670
# epoch 8 / 50, step 6/110, loss = 3.1795
# epoch 8 / 50, step 7/110, loss = 3.4304
# epoch 8 / 50, step 8/110, loss = 2.4990
# epoch 8 / 50, step 9/110, loss = 2.5436
# epoch 8 / 50, step 10/110, loss = 3.0946
# epoch 8 / 50, step 11/110, loss = 2.9058
# epoch 8 / 50, step 12/110, loss = 2.6975
# epoch 8 / 50, step 13/110, loss = 2.2998
# epoch 8 / 50, step 14/110, loss = 1.9642
# epoch 8 / 50, step 15/110, loss = 3.4424
# epoch 8 / 50, step 16/110, loss = 4.5271
# epoch 8 / 50, step 17/110, loss = 3.5006
# epoch 8 / 50, step 18/110, loss = 2.7207
# epoch 8 / 50, step 19/110, loss = 2.9814
# epoch 8 / 50, step 20/110, loss = 3.4041
# epoch 8 / 50, step 21/110, loss = 1.8142
# epoch 8 / 50, step 22/110, loss = 3.1358
# epoch 8 / 50, step 23/110, loss = 3.2717
# epoch 8 / 50, step 24/110, loss = 2.9696
# epoch 8 / 50, step 25/110, loss = 2.9112
# epoch 8 / 50, step 26/110, loss = 3.6151
# epoch 8 / 50, step 27/110, loss = 2.9874
# epoch 8 / 50, step 28/110, loss = 3.0881
# epoch 8 / 50, step 29/110, loss = 3.0953
# epoch 8 / 50, step 30/110, loss = 2.9402
# epoch 8 / 50, step 31/110, loss = 3.0271
# epoch 8 / 50, step 32/110, loss = 2.7961
# epoch 8 / 50, step 33/110, loss = 2.5275
# epoch 8 / 50, step 34/110, loss = 2.3562
# epoch 8 / 50, step 35/110, loss = 2.6564
# epoch 8 / 50, step 36/110, loss = 1.7136
# epoch 8 / 50, step 37/110, loss = 3.0608
# epoch 8 / 50, step 38/110, loss = 2.3832
# epoch 8 / 50, step 39/110, loss = 2.9449
# epoch 8 / 50, step 40/110, loss = 2.8697
# epoch 8 / 50, step 41/110, loss = 2.9773
# epoch 8 / 50, step 42/110, loss = 1.8533
# epoch 8 / 50, step 43/110, loss = 2.3216
# epoch 8 / 50, step 44/110, loss = 2.9672
# epoch 8 / 50, step 45/110, loss = 3.3571
# epoch 8 / 50, step 46/110, loss = 3.3489
# epoch 8 / 50, step 47/110, loss = 2.6201
# epoch 8 / 50, step 48/110, loss = 2.7700
# epoch 8 / 50, step 49/110, loss = 3.9220
# epoch 8 / 50, step 50/110, loss = 2.6000
# epoch 8 / 50, step 51/110, loss = 2.9029
# epoch 8 / 50, step 52/110, loss = 3.7181
# epoch 8 / 50, step 53/110, loss = 2.3785
# epoch 8 / 50, step 54/110, loss = 2.6675
# epoch 8 / 50, step 55/110, loss = 2.5991
# epoch 8 / 50, step 56/110, loss = 2.5982
# epoch 8 / 50, step 57/110, loss = 2.1486
# epoch 8 / 50, step 58/110, loss = 2.5524
# epoch 8 / 50, step 59/110, loss = 2.9038
# epoch 8 / 50, step 60/110, loss = 2.2675
# epoch 8 / 50, step 61/110, loss = 2.1773
# epoch 8 / 50, step 62/110, loss = 2.7731
# epoch 8 / 50, step 63/110, loss = 2.3343
# epoch 8 / 50, step 64/110, loss = 2.1747
# epoch 8 / 50, step 65/110, loss = 1.4717
# epoch 8 / 50, step 66/110, loss = 2.0576
# epoch 8 / 50, step 67/110, loss = 2.3286
# epoch 8 / 50, step 68/110, loss = 3.0381
# epoch 8 / 50, step 69/110, loss = 2.4581
# epoch 8 / 50, step 70/110, loss = 1.9279
# epoch 8 / 50, step 71/110, loss = 3.5869
# epoch 8 / 50, step 72/110, loss = 2.0657
# epoch 8 / 50, step 73/110, loss = 2.6618
# epoch 8 / 50, step 74/110, loss = 1.9323
# epoch 8 / 50, step 75/110, loss = 2.3607
# epoch 8 / 50, step 76/110, loss = 1.9523
# epoch 8 / 50, step 77/110, loss = 3.9198
# epoch 8 / 50, step 78/110, loss = 4.4936
# epoch 8 / 50, step 79/110, loss = 3.0534
# epoch 8 / 50, step 80/110, loss = 2.5217
# epoch 8 / 50, step 81/110, loss = 1.6445
# epoch 8 / 50, step 82/110, loss = 2.2453
# epoch 8 / 50, step 83/110, loss = 3.4508
# epoch 8 / 50, step 84/110, loss = 2.5845
# epoch 8 / 50, step 85/110, loss = 2.0784
# epoch 8 / 50, step 86/110, loss = 2.8456
# epoch 8 / 50, step 87/110, loss = 2.9917
# epoch 8 / 50, step 88/110, loss = 4.2926
# epoch 8 / 50, step 89/110, loss = 3.2479
# epoch 8 / 50, step 90/110, loss = 2.2975
# epoch 8 / 50, step 91/110, loss = 3.0316
# epoch 8 / 50, step 92/110, loss = 2.5262
# epoch 8 / 50, step 93/110, loss = 2.7016
# epoch 8 / 50, step 94/110, loss = 2.5863
# epoch 8 / 50, step 95/110, loss = 3.1779
# epoch 8 / 50, step 96/110, loss = 2.8097
# epoch 8 / 50, step 97/110, loss = 2.8301
# epoch 8 / 50, step 98/110, loss = 3.1131
# epoch 8 / 50, step 99/110, loss = 3.6408
# epoch 8 / 50, step 100/110, loss = 2.3950
# epoch 8 / 50, step 101/110, loss = 2.3365
# epoch 8 / 50, step 102/110, loss = 1.9783
# epoch 8 / 50, step 103/110, loss = 2.7649
# epoch 8 / 50, step 104/110, loss = 1.9760
# epoch 8 / 50, step 105/110, loss = 2.1456
# epoch 8 / 50, step 106/110, loss = 4.2332
# epoch 8 / 50, step 107/110, loss = 2.3757
# epoch 8 / 50, step 108/110, loss = 4.0305
# epoch 8 / 50, step 109/110, loss = 2.3484
# epoch 8 / 50, step 110/110, loss = 2.2962
# epoch 8 / 50, step 1/28, loss = 1.8624
# epoch 8 / 50, step 2/28, loss = 2.0965
# epoch 8 / 50, step 3/28, loss = 2.7089
# epoch 8 / 50, step 4/28, loss = 2.0861
# epoch 8 / 50, step 5/28, loss = 2.5766
# epoch 8 / 50, step 6/28, loss = 1.8283
# epoch 8 / 50, step 7/28, loss = 2.3826
# epoch 8 / 50, step 8/28, loss = 2.6885
# epoch 8 / 50, step 9/28, loss = 1.8398
# epoch 8 / 50, step 10/28, loss = 2.3818
# epoch 8 / 50, step 11/28, loss = 2.1207
# epoch 8 / 50, step 12/28, loss = 1.9712
# epoch 8 / 50, step 13/28, loss = 2.1310
# epoch 8 / 50, step 14/28, loss = 2.6467
# epoch 8 / 50, step 15/28, loss = 1.9410
# epoch 8 / 50, step 16/28, loss = 1.7742
# epoch 8 / 50, step 17/28, loss = 2.0255
# epoch 8 / 50, step 18/28, loss = 2.2941
# epoch 8 / 50, step 19/28, loss = 2.5075
# epoch 8 / 50, step 20/28, loss = 2.3655
# epoch 8 / 50, step 21/28, loss = 2.0251
# epoch 8 / 50, step 22/28, loss = 1.7028
# epoch 8 / 50, step 23/28, loss = 2.2493
# epoch 8 / 50, step 24/28, loss = 2.7587
# epoch 8 / 50, step 25/28, loss = 2.5484
# epoch 8 / 50, step 26/28, loss = 2.5116
# epoch 8 / 50, step 27/28, loss = 1.8659
# epoch 8 / 50, step 28/28, loss = 1.9814
# epoch 9 / 50, step 1/110, loss = 2.2911
# epoch 9 / 50, step 2/110, loss = 3.5160
# epoch 9 / 50, step 3/110, loss = 1.9967
# epoch 9 / 50, step 4/110, loss = 2.5713
# epoch 9 / 50, step 5/110, loss = 2.6096
# epoch 9 / 50, step 6/110, loss = 2.6020
# epoch 9 / 50, step 7/110, loss = 4.0039
# epoch 9 / 50, step 8/110, loss = 3.2037
# epoch 9 / 50, step 9/110, loss = 2.4690
# epoch 9 / 50, step 10/110, loss = 3.2259
# epoch 9 / 50, step 11/110, loss = 2.7157
# epoch 9 / 50, step 12/110, loss = 2.4944
# epoch 9 / 50, step 13/110, loss = 2.2406
# epoch 9 / 50, step 14/110, loss = 2.3686
# epoch 9 / 50, step 15/110, loss = 2.9381
# epoch 9 / 50, step 16/110, loss = 3.1865
# epoch 9 / 50, step 17/110, loss = 2.8905
# epoch 9 / 50, step 18/110, loss = 2.9323
# epoch 9 / 50, step 19/110, loss = 2.8001
# epoch 9 / 50, step 20/110, loss = 2.7591
# epoch 9 / 50, step 21/110, loss = 2.7718
# epoch 9 / 50, step 22/110, loss = 2.9434
# epoch 9 / 50, step 23/110, loss = 3.5660
# epoch 9 / 50, step 24/110, loss = 3.1757
# epoch 9 / 50, step 25/110, loss = 3.0449
# epoch 9 / 50, step 26/110, loss = 3.2058
# epoch 9 / 50, step 27/110, loss = 3.2056
# epoch 9 / 50, step 28/110, loss = 1.9137
# epoch 9 / 50, step 29/110, loss = 2.3671
# epoch 9 / 50, step 30/110, loss = 2.3735
# epoch 9 / 50, step 31/110, loss = 2.8763
# epoch 9 / 50, step 32/110, loss = 2.5249
# epoch 9 / 50, step 33/110, loss = 2.4256
# epoch 9 / 50, step 34/110, loss = 3.2507
# epoch 9 / 50, step 35/110, loss = 2.2792
# epoch 9 / 50, step 36/110, loss = 2.6278
# epoch 9 / 50, step 37/110, loss = 2.7436
# epoch 9 / 50, step 38/110, loss = 2.9348
# epoch 9 / 50, step 39/110, loss = 3.5265
# epoch 9 / 50, step 40/110, loss = 2.8554
# epoch 9 / 50, step 41/110, loss = 2.1616
# epoch 9 / 50, step 42/110, loss = 3.2649
# epoch 9 / 50, step 43/110, loss = 3.2650
# epoch 9 / 50, step 44/110, loss = 2.1852
# epoch 9 / 50, step 45/110, loss = 2.4917
# epoch 9 / 50, step 46/110, loss = 2.6743
# epoch 9 / 50, step 47/110, loss = 2.7841
# epoch 9 / 50, step 48/110, loss = 2.6114
# epoch 9 / 50, step 49/110, loss = 2.5908
# epoch 9 / 50, step 50/110, loss = 2.3165
# epoch 9 / 50, step 51/110, loss = 3.1496
# epoch 9 / 50, step 52/110, loss = 2.2869
# epoch 9 / 50, step 53/110, loss = 4.6581
# epoch 9 / 50, step 54/110, loss = 2.9290
# epoch 9 / 50, step 55/110, loss = 3.4901
# epoch 9 / 50, step 56/110, loss = 2.6220
# epoch 9 / 50, step 57/110, loss = 2.2153
# epoch 9 / 50, step 58/110, loss = 1.9272
# epoch 9 / 50, step 59/110, loss = 3.2707
# epoch 9 / 50, step 60/110, loss = 3.4823
# epoch 9 / 50, step 61/110, loss = 2.4800
# epoch 9 / 50, step 62/110, loss = 2.4339
# epoch 9 / 50, step 63/110, loss = 2.4748
# epoch 9 / 50, step 64/110, loss = 2.7957
# epoch 9 / 50, step 65/110, loss = 2.4602
# epoch 9 / 50, step 66/110, loss = 3.2693
# epoch 9 / 50, step 67/110, loss = 2.5153
# epoch 9 / 50, step 68/110, loss = 2.4499
# epoch 9 / 50, step 69/110, loss = 5.4755
# epoch 9 / 50, step 70/110, loss = 2.5827
# epoch 9 / 50, step 71/110, loss = 3.1004
# epoch 9 / 50, step 72/110, loss = 3.0587
# epoch 9 / 50, step 73/110, loss = 3.1137
# ...
# epoch 48 / 50, step 32/110, loss = 2.9425
# epoch 48 / 50, step 33/110, loss = 2.0803
# epoch 48 / 50, step 34/110, loss = 2.7202
# epoch 48 / 50, step 35/110, loss = 2.8769
# epoch 48 / 50, step 36/110, loss = 1.7497
# epoch 48 / 50, step 37/110, loss = 2.6916
# epoch 48 / 50, step 38/110, loss = 2.3934
# epoch 48 / 50, step 39/110, loss = 2.7401
# epoch 48 / 50, step 40/110, loss = 2.3433
# epoch 48 / 50, step 41/110, loss = 2.7373
# epoch 48 / 50, step 42/110, loss = 2.0665
# epoch 48 / 50, step 43/110, loss = 2.3303
# epoch 48 / 50, step 44/110, loss = 2.2456
# epoch 48 / 50, step 45/110, loss = 2.4343
# epoch 48 / 50, step 46/110, loss = 2.7257
# epoch 48 / 50, step 47/110, loss = 3.0202
# epoch 48 / 50, step 48/110, loss = 3.5230
# epoch 48 / 50, step 49/110, loss = 1.9167
# epoch 48 / 50, step 50/110, loss = 1.9432
# epoch 48 / 50, step 51/110, loss = 3.0895
# epoch 48 / 50, step 52/110, loss = 2.2948
# epoch 48 / 50, step 53/110, loss = 3.4748
# epoch 48 / 50, step 54/110, loss = 2.8666
# epoch 48 / 50, step 55/110, loss = 3.8822
# epoch 48 / 50, step 56/110, loss = 2.4154
# epoch 48 / 50, step 57/110, loss = 2.6321
# epoch 48 / 50, step 58/110, loss = 2.8776
# epoch 48 / 50, step 59/110, loss = 3.4693
# epoch 48 / 50, step 60/110, loss = 3.1723
# epoch 48 / 50, step 61/110, loss = 2.9497
# epoch 48 / 50, step 62/110, loss = 2.7692
# epoch 48 / 50, step 63/110, loss = 3.1166
# epoch 48 / 50, step 64/110, loss = 3.2900
# epoch 48 / 50, step 65/110, loss = 2.5661
# epoch 48 / 50, step 66/110, loss = 2.4654
# epoch 48 / 50, step 67/110, loss = 2.4058
# epoch 48 / 50, step 68/110, loss = 3.1643
# epoch 48 / 50, step 69/110, loss = 1.9204
# epoch 48 / 50, step 70/110, loss = 3.8333
# epoch 48 / 50, step 71/110, loss = 2.2539
# epoch 48 / 50, step 72/110, loss = 2.1127
# epoch 48 / 50, step 73/110, loss = 3.5828
# epoch 48 / 50, step 74/110, loss = 2.4886
# epoch 48 / 50, step 75/110, loss = 2.3058
# epoch 48 / 50, step 76/110, loss = 2.8027
# epoch 48 / 50, step 77/110, loss = 3.1405
# epoch 48 / 50, step 78/110, loss = 2.3743
# epoch 48 / 50, step 79/110, loss = 2.2459
# epoch 48 / 50, step 80/110, loss = 2.1123
# epoch 48 / 50, step 81/110, loss = 1.8392
# epoch 48 / 50, step 82/110, loss = 2.1892
# epoch 48 / 50, step 83/110, loss = 3.0793
# epoch 48 / 50, step 84/110, loss = 2.6685
# epoch 48 / 50, step 85/110, loss = 2.2690
# epoch 48 / 50, step 86/110, loss = 2.5430
# epoch 48 / 50, step 87/110, loss = 2.9792
# epoch 48 / 50, step 88/110, loss = 2.2373
# epoch 48 / 50, step 89/110, loss = 2.2376
# epoch 48 / 50, step 90/110, loss = 1.7199
# epoch 48 / 50, step 91/110, loss = 2.3370
# epoch 48 / 50, step 92/110, loss = 1.8241
# epoch 48 / 50, step 93/110, loss = 3.2289
# epoch 48 / 50, step 94/110, loss = 2.6189
# epoch 48 / 50, step 95/110, loss = 2.9543
# epoch 48 / 50, step 96/110, loss = 2.5753
# epoch 48 / 50, step 97/110, loss = 2.6816
# epoch 48 / 50, step 98/110, loss = 2.5951
# epoch 48 / 50, step 99/110, loss = 2.9643
# epoch 48 / 50, step 100/110, loss = 4.2025
# epoch 48 / 50, step 101/110, loss = 1.8281
# epoch 48 / 50, step 102/110, loss = 3.6634
# epoch 48 / 50, step 103/110, loss = 2.8595
# epoch 48 / 50, step 104/110, loss = 2.2243
# epoch 48 / 50, step 105/110, loss = 2.8647
# epoch 48 / 50, step 106/110, loss = 3.1478
# epoch 48 / 50, step 107/110, loss = 3.5306
# epoch 48 / 50, step 108/110, loss = 2.3148
# epoch 48 / 50, step 109/110, loss = 2.3722
# epoch 48 / 50, step 110/110, loss = 3.5596
# epoch 48 / 50, step 1/28, loss = 2.3438
# epoch 48 / 50, step 2/28, loss = 2.5019
# epoch 48 / 50, step 3/28, loss = 2.5188
# epoch 48 / 50, step 4/28, loss = 2.0539
# epoch 48 / 50, step 5/28, loss = 2.5020
# epoch 48 / 50, step 6/28, loss = 2.1602
# epoch 48 / 50, step 7/28, loss = 2.9181
# epoch 48 / 50, step 8/28, loss = 2.9038
# epoch 48 / 50, step 9/28, loss = 2.1075
# epoch 48 / 50, step 10/28, loss = 3.1689
# epoch 48 / 50, step 11/28, loss = 2.9560
# epoch 48 / 50, step 12/28, loss = 3.2746
# epoch 48 / 50, step 13/28, loss = 2.5949
# epoch 48 / 50, step 14/28, loss = 2.3306
# epoch 48 / 50, step 15/28, loss = 3.2112
# epoch 48 / 50, step 16/28, loss = 1.6562
# epoch 48 / 50, step 17/28, loss = 2.8268
# epoch 48 / 50, step 18/28, loss = 3.0779
# epoch 48 / 50, step 19/28, loss = 2.2360
# epoch 48 / 50, step 20/28, loss = 2.9379
# epoch 48 / 50, step 21/28, loss = 2.9174
# epoch 48 / 50, step 22/28, loss = 2.0717
# epoch 48 / 50, step 23/28, loss = 2.6587
# epoch 48 / 50, step 24/28, loss = 2.7239
# epoch 48 / 50, step 25/28, loss = 2.7608
# epoch 48 / 50, step 26/28, loss = 2.2739
# epoch 48 / 50, step 27/28, loss = 1.8721
# epoch 48 / 50, step 28/28, loss = 3.5575
# epoch 49 / 50, step 1/110, loss = 2.4844
# epoch 49 / 50, step 2/110, loss = 4.1361
# epoch 49 / 50, step 3/110, loss = 3.3866
# epoch 49 / 50, step 4/110, loss = 3.3770
# epoch 49 / 50, step 5/110, loss = 3.1045
# epoch 49 / 50, step 6/110, loss = 3.3103
# epoch 49 / 50, step 7/110, loss = 2.6879
# epoch 49 / 50, step 8/110, loss = 3.3125
# epoch 49 / 50, step 9/110, loss = 1.3321
# epoch 49 / 50, step 10/110, loss = 3.4557
# epoch 49 / 50, step 11/110, loss = 3.2782
# epoch 49 / 50, step 12/110, loss = 4.3028
# epoch 49 / 50, step 13/110, loss = 4.0561
# epoch 49 / 50, step 14/110, loss = 3.3506
# epoch 49 / 50, step 15/110, loss = 3.2780
# epoch 49 / 50, step 16/110, loss = 3.7526
# epoch 49 / 50, step 17/110, loss = 3.1728
# epoch 49 / 50, step 18/110, loss = 1.4570
# epoch 49 / 50, step 19/110, loss = 2.3066
# epoch 49 / 50, step 20/110, loss = 2.3988
# epoch 49 / 50, step 21/110, loss = 3.3047
# epoch 49 / 50, step 22/110, loss = 4.0301
# epoch 49 / 50, step 23/110, loss = 2.3877
# epoch 49 / 50, step 24/110, loss = 2.7661
# epoch 49 / 50, step 25/110, loss = 2.9155
# epoch 49 / 50, step 26/110, loss = 2.2377
# epoch 49 / 50, step 27/110, loss = 1.9202
# epoch 49 / 50, step 28/110, loss = 2.3882
# epoch 49 / 50, step 29/110, loss = 2.7753
# epoch 49 / 50, step 30/110, loss = 1.5907
# epoch 49 / 50, step 31/110, loss = 2.5620
# epoch 49 / 50, step 32/110, loss = 2.6480
# epoch 49 / 50, step 33/110, loss = 3.8661
# epoch 49 / 50, step 34/110, loss = 2.8502
# epoch 49 / 50, step 35/110, loss = 4.5650
# epoch 49 / 50, step 36/110, loss = 2.8204
# epoch 49 / 50, step 37/110, loss = 2.6196
# epoch 49 / 50, step 38/110, loss = 2.8218
# epoch 49 / 50, step 39/110, loss = 2.4509
# epoch 49 / 50, step 40/110, loss = 2.4271
# epoch 49 / 50, step 41/110, loss = 3.6493
# epoch 49 / 50, step 42/110, loss = 3.9820
# epoch 49 / 50, step 43/110, loss = 2.6500
# epoch 49 / 50, step 44/110, loss = 2.1949
# epoch 49 / 50, step 45/110, loss = 3.3098
# epoch 49 / 50, step 46/110, loss = 2.0485
# epoch 49 / 50, step 47/110, loss = 3.0374
# epoch 49 / 50, step 48/110, loss = 2.4366
# epoch 49 / 50, step 49/110, loss = 3.5262
# epoch 49 / 50, step 50/110, loss = 3.6234
# epoch 49 / 50, step 51/110, loss = 2.7766
# epoch 49 / 50, step 52/110, loss = 2.0169
# epoch 49 / 50, step 53/110, loss = 2.0758
# epoch 49 / 50, step 54/110, loss = 3.8195
# epoch 49 / 50, step 55/110, loss = 2.5948
# epoch 49 / 50, step 56/110, loss = 2.7982
# epoch 49 / 50, step 57/110, loss = 2.4466
# epoch 49 / 50, step 58/110, loss = 2.6972
# epoch 49 / 50, step 59/110, loss = 2.5947
# epoch 49 / 50, step 60/110, loss = 2.2456
# epoch 49 / 50, step 61/110, loss = 2.5372
# epoch 49 / 50, step 62/110, loss = 4.2305
# epoch 49 / 50, step 63/110, loss = 2.5089
# epoch 49 / 50, step 64/110, loss = 3.4743
# epoch 49 / 50, step 65/110, loss = 3.2970
# epoch 49 / 50, step 66/110, loss = 4.3187
# epoch 49 / 50, step 67/110, loss = 3.1610
# epoch 49 / 50, step 68/110, loss = 2.6777
# epoch 49 / 50, step 69/110, loss = 2.6281
# epoch 49 / 50, step 70/110, loss = 2.3822
# epoch 49 / 50, step 71/110, loss = 3.1431
# epoch 49 / 50, step 72/110, loss = 3.7748
# epoch 49 / 50, step 73/110, loss = 3.2327
# epoch 49 / 50, step 74/110, loss = 2.6472
# epoch 49 / 50, step 75/110, loss = 2.5669
# epoch 49 / 50, step 76/110, loss = 2.2913
# epoch 49 / 50, step 77/110, loss = 2.7533
# epoch 49 / 50, step 78/110, loss = 2.8657
# epoch 49 / 50, step 79/110, loss = 2.6317
# epoch 49 / 50, step 80/110, loss = 2.8100
# epoch 49 / 50, step 81/110, loss = 2.4726
# epoch 49 / 50, step 82/110, loss = 2.9588
# epoch 49 / 50, step 83/110, loss = 2.9078
# epoch 49 / 50, step 84/110, loss = 2.9925
# epoch 49 / 50, step 85/110, loss = 3.3033
# epoch 49 / 50, step 86/110, loss = 3.2018
# epoch 49 / 50, step 87/110, loss = 1.9393
# epoch 49 / 50, step 88/110, loss = 2.0884
# epoch 49 / 50, step 89/110, loss = 2.8169
# epoch 49 / 50, step 90/110, loss = 3.4723
# epoch 49 / 50, step 91/110, loss = 2.3033
# epoch 49 / 50, step 92/110, loss = 3.2002
# epoch 49 / 50, step 93/110, loss = 4.1969
# epoch 49 / 50, step 94/110, loss = 3.0935
# epoch 49 / 50, step 95/110, loss = 2.6036
# epoch 49 / 50, step 96/110, loss = 3.7288
# epoch 49 / 50, step 97/110, loss = 1.6996
# epoch 49 / 50, step 98/110, loss = 2.6175
# epoch 49 / 50, step 99/110, loss = 4.0264
# epoch 49 / 50, step 100/110, loss = 2.6992
# epoch 49 / 50, step 101/110, loss = 2.5881
# epoch 49 / 50, step 102/110, loss = 2.1118
# epoch 49 / 50, step 103/110, loss = 3.7876
# epoch 49 / 50, step 104/110, loss = 4.5158
# epoch 49 / 50, step 105/110, loss = 3.1177
# epoch 49 / 50, step 106/110, loss = 2.6942
# epoch 49 / 50, step 107/110, loss = 2.0735
# epoch 49 / 50, step 108/110, loss = 2.1197
# epoch 49 / 50, step 109/110, loss = 4.1379
# epoch 49 / 50, step 110/110, loss = 3.6074
# epoch 49 / 50, step 1/28, loss = 3.2512
# epoch 49 / 50, step 2/28, loss = 3.7614
# epoch 49 / 50, step 3/28, loss = 2.5102
# epoch 49 / 50, step 4/28, loss = 2.4682
# epoch 49 / 50, step 5/28, loss = 3.0748
# epoch 49 / 50, step 6/28, loss = 3.8597
# epoch 49 / 50, step 7/28, loss = 2.2969
# epoch 49 / 50, step 8/28, loss = 2.2159
# epoch 49 / 50, step 9/28, loss = 3.2235
# epoch 49 / 50, step 10/28, loss = 2.4927
# epoch 49 / 50, step 11/28, loss = 2.6585
# epoch 49 / 50, step 12/28, loss = 2.6471
# epoch 49 / 50, step 13/28, loss = 3.3522
# epoch 49 / 50, step 14/28, loss = 2.0284
# epoch 49 / 50, step 15/28, loss = 2.8264
# epoch 49 / 50, step 16/28, loss = 3.3809
# epoch 49 / 50, step 17/28, loss = 3.2269
# epoch 49 / 50, step 18/28, loss = 3.3279
# epoch 49 / 50, step 19/28, loss = 3.2119
# epoch 49 / 50, step 20/28, loss = 1.6417
# epoch 49 / 50, step 21/28, loss = 3.0276
# epoch 49 / 50, step 22/28, loss = 2.6470
# epoch 49 / 50, step 23/28, loss = 2.5371
# epoch 49 / 50, step 24/28, loss = 3.1890
# epoch 49 / 50, step 25/28, loss = 2.5649
# epoch 49 / 50, step 26/28, loss = 2.6818
# epoch 49 / 50, step 27/28, loss = 2.7537
# epoch 49 / 50, step 28/28, loss = 3.0345
# epoch 50 / 50, step 1/110, loss = 4.7474
# epoch 50 / 50, step 2/110, loss = 3.0577
# epoch 50 / 50, step 3/110, loss = 3.6021
# epoch 50 / 50, step 4/110, loss = 2.7990
# epoch 50 / 50, step 5/110, loss = 2.7501
# epoch 50 / 50, step 6/110, loss = 3.1740
# epoch 50 / 50, step 7/110, loss = 1.8203
# epoch 50 / 50, step 8/110, loss = 3.2516
# epoch 50 / 50, step 9/110, loss = 3.1215
# epoch 50 / 50, step 10/110, loss = 2.5874
# epoch 50 / 50, step 11/110, loss = 2.5948
# epoch 50 / 50, step 12/110, loss = 2.3132
# epoch 50 / 50, step 13/110, loss = 2.4130
# epoch 50 / 50, step 14/110, loss = 3.6881
# epoch 50 / 50, step 15/110, loss = 2.2796
# epoch 50 / 50, step 16/110, loss = 3.1240
# epoch 50 / 50, step 17/110, loss = 3.0637
# epoch 50 / 50, step 18/110, loss = 2.4991
# epoch 50 / 50, step 19/110, loss = 1.8206
# epoch 50 / 50, step 20/110, loss = 2.2797
# epoch 50 / 50, step 21/110, loss = 2.8377
# epoch 50 / 50, step 22/110, loss = 3.8821
# epoch 50 / 50, step 23/110, loss = 3.4225
# epoch 50 / 50, step 24/110, loss = 2.4012
# epoch 50 / 50, step 25/110, loss = 3.9856
# epoch 50 / 50, step 26/110, loss = 3.5395
# epoch 50 / 50, step 27/110, loss = 2.8361
# epoch 50 / 50, step 28/110, loss = 2.7640
# epoch 50 / 50, step 29/110, loss = 3.3827
# epoch 50 / 50, step 30/110, loss = 3.6769
# epoch 50 / 50, step 31/110, loss = 3.2459
# epoch 50 / 50, step 32/110, loss = 2.6896
# epoch 50 / 50, step 33/110, loss = 3.0948
# epoch 50 / 50, step 34/110, loss = 2.8792
# epoch 50 / 50, step 35/110, loss = 2.0736
# epoch 50 / 50, step 36/110, loss = 2.1318
# epoch 50 / 50, step 37/110, loss = 2.9123
# epoch 50 / 50, step 38/110, loss = 2.9932
# epoch 50 / 50, step 39/110, loss = 2.8627
# epoch 50 / 50, step 40/110, loss = 2.2481
# epoch 50 / 50, step 41/110, loss = 3.5447
# epoch 50 / 50, step 42/110, loss = 3.2495
# epoch 50 / 50, step 43/110, loss = 2.7496
# epoch 50 / 50, step 44/110, loss = 3.2874
# epoch 50 / 50, step 45/110, loss = 2.4910
# epoch 50 / 50, step 46/110, loss = 2.7772
# epoch 50 / 50, step 47/110, loss = 2.6994
# epoch 50 / 50, step 48/110, loss = 2.2772
# epoch 50 / 50, step 49/110, loss = 1.9919
# epoch 50 / 50, step 50/110, loss = 3.8232
# epoch 50 / 50, step 51/110, loss = 3.6941
# epoch 50 / 50, step 52/110, loss = 2.4023
# epoch 50 / 50, step 53/110, loss = 4.4459
# epoch 50 / 50, step 54/110, loss = 3.1608
# epoch 50 / 50, step 55/110, loss = 2.5707
# epoch 50 / 50, step 56/110, loss = 2.7567
# epoch 50 / 50, step 57/110, loss = 2.7165
# epoch 50 / 50, step 58/110, loss = 3.7205
# epoch 50 / 50, step 59/110, loss = 4.2699
# epoch 50 / 50, step 60/110, loss = 3.2475
# epoch 50 / 50, step 61/110, loss = 4.0788
# epoch 50 / 50, step 62/110, loss = 2.5872
# epoch 50 / 50, step 63/110, loss = 3.9024
# epoch 50 / 50, step 64/110, loss = 2.6180
# epoch 50 / 50, step 65/110, loss = 2.7330
# epoch 50 / 50, step 66/110, loss = 2.3676
# epoch 50 / 50, step 67/110, loss = 1.9257
# epoch 50 / 50, step 68/110, loss = 2.8417
# epoch 50 / 50, step 69/110, loss = 2.6454
# epoch 50 / 50, step 70/110, loss = 2.8916
# epoch 50 / 50, step 71/110, loss = 3.7259
# epoch 50 / 50, step 72/110, loss = 2.2050
# epoch 50 / 50, step 73/110, loss = 2.8917
# epoch 50 / 50, step 74/110, loss = 2.7712
# epoch 50 / 50, step 75/110, loss = 2.5014
# epoch 50 / 50, step 76/110, loss = 2.3833
# epoch 50 / 50, step 77/110, loss = 2.3389
# epoch 50 / 50, step 78/110, loss = 2.9051
# epoch 50 / 50, step 79/110, loss = 3.0199
# epoch 50 / 50, step 80/110, loss = 2.6436
# epoch 50 / 50, step 81/110, loss = 2.9460
# epoch 50 / 50, step 82/110, loss = 2.9582
# epoch 50 / 50, step 83/110, loss = 3.3769
# epoch 50 / 50, step 84/110, loss = 3.0542
# epoch 50 / 50, step 85/110, loss = 1.7849
# epoch 50 / 50, step 86/110, loss = 3.5977
# epoch 50 / 50, step 87/110, loss = 1.7061
# epoch 50 / 50, step 88/110, loss = 3.2950
# epoch 50 / 50, step 89/110, loss = 2.0036
# epoch 50 / 50, step 90/110, loss = 1.9065
# epoch 50 / 50, step 91/110, loss = 3.4417
# epoch 50 / 50, step 92/110, loss = 3.9735
# epoch 50 / 50, step 93/110, loss = 2.8300
# epoch 50 / 50, step 94/110, loss = 2.5828
# epoch 50 / 50, step 95/110, loss = 2.9673
# epoch 50 / 50, step 96/110, loss = 3.1126
# epoch 50 / 50, step 97/110, loss = 2.2970
# epoch 50 / 50, step 98/110, loss = 3.0264
# epoch 50 / 50, step 99/110, loss = 2.1461
# epoch 50 / 50, step 100/110, loss = 3.0553
# epoch 50 / 50, step 101/110, loss = 3.1602
# epoch 50 / 50, step 102/110, loss = 2.2932
# epoch 50 / 50, step 103/110, loss = 2.2075
# epoch 50 / 50, step 104/110, loss = 3.2491
# epoch 50 / 50, step 105/110, loss = 2.3040
# epoch 50 / 50, step 106/110, loss = 3.5962
# epoch 50 / 50, step 107/110, loss = 3.7552
# epoch 50 / 50, step 108/110, loss = 3.2353
# epoch 50 / 50, step 109/110, loss = 2.7907
# epoch 50 / 50, step 110/110, loss = 3.7698
# epoch 50 / 50, step 1/28, loss = 2.3306
# epoch 50 / 50, step 2/28, loss = 2.7218
# epoch 50 / 50, step 3/28, loss = 2.8702
# epoch 50 / 50, step 4/28, loss = 1.9160
# epoch 50 / 50, step 5/28, loss = 2.0877
# epoch 50 / 50, step 6/28, loss = 2.5909
# epoch 50 / 50, step 7/28, loss = 2.4839
# epoch 50 / 50, step 8/28, loss = 2.1970
# epoch 50 / 50, step 9/28, loss = 2.2399
# epoch 50 / 50, step 10/28, loss = 2.2237
# epoch 50 / 50, step 11/28, loss = 2.6171
# epoch 50 / 50, step 12/28, loss = 2.8528
# epoch 50 / 50, step 13/28, loss = 2.6325
# epoch 50 / 50, step 14/28, loss = 2.1264
# epoch 50 / 50, step 15/28, loss = 2.8111
# epoch 50 / 50, step 16/28, loss = 2.1765
# epoch 50 / 50, step 17/28, loss = 2.4522
# epoch 50 / 50, step 18/28, loss = 2.7541
# epoch 50 / 50, step 19/28, loss = 2.1820
# epoch 50 / 50, step 20/28, loss = 1.8382
# epoch 50 / 50, step 21/28, loss = 2.2813
# epoch 50 / 50, step 22/28, loss = 1.7360
# epoch 50 / 50, step 23/28, loss = 2.3146
# epoch 50 / 50, step 24/28, loss = 2.5292
# epoch 50 / 50, step 25/28, loss = 2.5522
# epoch 50 / 50, step 26/28, loss = 2.2116
# epoch 50 / 50, step 27/28, loss = 1.9292
# epoch 50 / 50, step 28/28, loss = 2.8209

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 50 epochs the trainning accuracy is 13.142857142857142 and the test accuaracy is 15.525114155251142
#  the maximum accuracy of the test was 19.17808219178082 at the epoch 5
#  the maximum accuracy of the train was 16.8 at the epoch 16
# the accuracy of the training at the best validation accuracy 19.17808219178082 is 16.0

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
