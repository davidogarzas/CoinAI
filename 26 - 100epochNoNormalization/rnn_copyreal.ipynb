# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
import numpy as np
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import os
import shutil

# %% [markdown]
# - Changes:
# - hidden_size de 128 a 256

# %%
filepath = '26 - 100epochNoNormalization'  #cambiar nombre para archivo ej: 8 - 50epochNoNormalization'
script_dir = os.path.dirname('rnn_real.ipynb')
results_dir = os.path.join(script_dir, filepath + '/')

if not os.path.isdir(results_dir):
    os.makedirs(results_dir)

# %%
# Load Data

# Uncomment to save .npy file if not yet saved
#data =  np.loadtxt('./test_series.csv',delimiter=',',dtype=np.float32)
#np.save('test_series', data)
xy = np.load('./coin_data.npy')

X = xy[:,1:] # Indexes inputs
# Turns negative values to 0
X[X < 0] = 0
#X = X.astype(np.float32)
#print(type(X[0,0]))

y = xy[:,0] # Indexes Labels
#label_encoder = LabelEncoder()
#y = label_encoder.fit_transform(y)
#print(type(y[0]))

# %%
print(f'XY Shape: {xy.shape}')
print(f'xy[0]: {xy[0]}')
print(f'X[0]: {X[0]}')
print(f'y[0]: {y[0]}')

coin_1 = 0
coin_2 = 0
coin_5 = 0
coin_20 = 0
coin_50 = 0
coin_100 = 0
coin_200 = 0
for i in range(xy.shape[0]):
    if xy[i,0] == 0:
        coin_1 += 1
    elif xy[i,0] == 1:
        coin_2 += 1
    elif xy[i,0] == 2:
        coin_5 += 1
    elif xy[i,0] == 3:
        coin_20 += 1
    elif xy[i,0] == 4:
        coin_50 += 1
    elif xy[i,0] == 5:
        coin_100 += 1
    elif xy[i,0] == 6:
        coin_200 += 1
print(f'coin 1: {coin_1}')
print(f'coin 2: {coin_2}')
print(f'coin 5: {coin_5}')
print(f'coin 20: {coin_20}')
print(f'coin 50: {coin_50}')
print(f'coin 100: {coin_100}')
print(f'coin 200: {coin_200}')
# Out:
# XY Shape: (1094, 769025)
# xy[0]: [   5.    0.    0. ... 1040.  912.  640.]
# X[0]: [   0.    0.    0. ... 1040.  912.  640.]
# y[0]: 5.0
# coin 1: 151
# coin 2: 170
# coin 5: 130
# coin 20: 137
# coin 50: 130
# coin 100: 180
# coin 200: 196

# %%
# Handle Class Imbalance
#class_counts = torch.tensor([count_coin_1, count_coin_2, ..., count_coin_N], dtype=torch.float32)
#class_weights = 1.0 / class_counts  # Inverse frequency
#class_weights /= class_weights.sum()  # Normalize if necessary
#class_weights = class_weights.to(device)
#criterion = nn.CrossEntropyLoss(weight=class_weights)

# %%
# Set random seed for reproducibility
torch.manual_seed(7)  # Set the seed for generating random numbers in PyTorch
np.random.seed(7)     # Set the seed for generating random numbers in NumPy

# %%
# Define Hyper Parameters

hidden_size = 256
num_classes = 7
num_epochs = 100
batch_size = 8
learning_rate = 0.001
num_layers = 2

input_size = 751 
sequence_length = 1024  
#input_size = 4 
#sequence_length = 28     


# Device config
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# Random State So it is reproducible
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# Graph before normalization
print(f'Before normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("Before Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()

# Scale and split data
sc = MinMaxScaler(feature_range=(0,1))

# Per sample scaling
#X_train = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_train])
#X_test = np.array([sc.fit_transform(sample.reshape(-1, 1)).flatten() for sample in X_test])

# Graph after scaling
#print(f'After normalization X_train[0]: {X_train[0]}')
#plt.figure()
#plt.title("After Per Sample Normalization X_train[0]")
#plt.plot(X_train[0])
#plt.show()

# Global scaling
# sc.fit_transform on X_train and sc.transform on X_test to avoid data leakage
#X_train = sc.fit_transform(X_train)
#X_test = sc.transform(X_test)

# Graph after scaling
print(f'After normalization X_train[0]: {X_train[0]}')
plt.figure()
plt.title("After Normalization X_train[0]")
plt.plot(X_train[0])
plt.show()
# Out:
# Before normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# After normalization X_train[0]: [0. 0. 0. ... 0. 0. 0.]

# %%
print(f'X_train[0]: {X_train[0]}')
print(f'y_train[0]: {y_train[0]}')
print(f'X_test[0]: {X_test[0]}')
print(f'y_test[0]: {y_test[0]}')

train_coin_1 = 0
train_coin_2 = 0
train_coin_5 = 0
train_coin_20 = 0
train_coin_50 = 0
train_coin_100 = 0
train_coin_200 = 0

for i in range(y_train.shape[0]):
    if y_train[i] == 0:
        train_coin_1 += 1
    elif y_train[i] == 1:
        train_coin_2 += 1
    elif y_train[i] == 2:
        train_coin_5 += 1
    elif y_train[i] == 3:
        train_coin_20 += 1
    elif y_train[i] == 4:
        train_coin_50 += 1
    elif y_train[i] == 5:
        train_coin_100 += 1
    elif y_train[i] == 6:
        train_coin_200 += 1
        
print(f'coin 1: {train_coin_1}')
print(f'coin 2: {train_coin_2}')
print(f'coin 5: {train_coin_5}')
print(f'coin 20: {train_coin_20}')
print(f'coin 50: {train_coin_50}')
print(f'coin 100: {train_coin_100}')
print(f'coin 200: {train_coin_200}')

test_coin_1 = 0
test_coin_2 = 0
test_coin_5 = 0
test_coin_20 = 0
test_coin_50 = 0
test_coin_100 = 0
test_coin_200 = 0
for i in range(y_test.shape[0]):
    if y_test[i] == 0:
        test_coin_1 += 1
    elif y_test[i] == 1:
        test_coin_2 += 1
    elif y_test[i] == 2:
        test_coin_5 += 1
    elif y_test[i] == 3:
        test_coin_20 += 1
    elif y_test[i] == 4:
        test_coin_50 += 1
    elif y_test[i] == 5:
        test_coin_100 += 1
    elif y_test[i] == 6:
        test_coin_200 += 1
print(f'coin 1: {test_coin_1}')
print(f'coin 2: {test_coin_2}')
print(f'coin 5: {test_coin_5}')
print(f'coin 20: {test_coin_20}')
print(f'coin 50: {test_coin_50}')
print(f'coin 100: {test_coin_100}')
print(f'coin 200: {test_coin_200}')
# Out:
# X_train[0]: [0. 0. 0. ... 0. 0. 0.]
# y_train[0]: 6.0
# X_test[0]: [160.  96.   0. ... 288.  32. 192.]
# y_test[0]: 4.0
# coin 1: 118
# coin 2: 138
# coin 5: 104
# coin 20: 112
# coin 50: 100
# coin 100: 146
# coin 200: 157
# coin 1: 33
# coin 2: 32
# coin 5: 26
# coin 20: 25
# coin 50: 30
# coin 100: 34
# coin 200: 39

# %%
# Creates TrainCoinDataSet
class TrainCoinDataSet(Dataset):

    def __init__(self, X_train, y_train):
        # Data Loading
        self.x = torch.from_numpy(X_train.astype(np.float32))
        self.y = torch.from_numpy(y_train).type(torch.LongTensor)
        self.n_samples = y_train.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples
    
class TestCoinDataSet(Dataset):

    def __init__(self, X_test, y_test):
        # Data Loading
        self.x = torch.from_numpy(X_test.astype(np.float32))
        self.y = torch.from_numpy(y_test).type(torch.LongTensor)
        self.n_samples = y_test.shape[0] # n_samples
        print(self.n_samples)

    def __getitem__(self, index):
        # Allows indexing
        return self.x[index], self.y[index]

    def __len__(self):
        # Allows calling length
        return self.n_samples

# %%
# Creates Dataset
train_data = TrainCoinDataSet(X_train, y_train)
test_data = TestCoinDataSet(X_test, y_test)
# Out:
# 875
# 219

# %%
print(train_data[0])
print(test_data[0])
# Out:
# (tensor([0., 0., 0.,  ..., 0., 0., 0.]), tensor(6))
# (tensor([160.,  96.,   0.,  ..., 288.,  32., 192.]), tensor(4))

# %%
# Defines Train and Test Datasets sizes
#train_size = int(0.8 * len(dataset))  # 80% of the data will be used for training
#test_size = len(dataset) - train_size  # Remaining 20% will be used for test

# Split dataset into training set and test set
#train_data, test_data = random_split(dataset, [train_size, test_size])

# Creates Dataloaders for train and test datasets
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False)

examples = iter(train_loader)
samples, labels = next(examples)

# %%
print(f'Input shape: {samples.shape} , Labels shape: {labels.shape}')
print(f"Input range after standardization: Min = {samples[0].min()}, Max = {samples[0].max()}")
print(samples[0])
print(labels[0])
print(f'Input dtype: {samples[0,0].dtype}')
print(f'Label dtype: {labels[0].dtype}')
print(f'Labels: {labels}')
# Out:
# Input shape: torch.Size([8, 769024]) , Labels shape: torch.Size([8])
# Input range after standardization: Min = 0.0, Max = 1023000.0
# tensor([  0.,   0., 384.,  ...,   0.,   0.,   0.])
# tensor(5)
# Input dtype: torch.float32
# Label dtype: torch.int64
# Labels: tensor([5, 3, 4, 2, 2, 2, 1, 1])

# %%
# Create Model

# Model 
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super(RNN, self).__init__()
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, dropout=0.5)
        #x -> (batch_size, seq, input_size) 
        self.fc = nn.Linear(hidden_size, num_classes)   
        self.dropout = nn.Dropout(p=0.5)

    def forward(self,x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(device)

        out,_ = self.rnn(x, h0)
        #Dropout on output
        out= self.dropout(out)

        # out: batch_size, seq_lenght, hidden_size
        #out (N,28, 128)
        out = out[:, -1, :]
        #out (N, 128)

        out= self.fc(out)
        return out

# %%
model = RNN(input_size, hidden_size, num_layers, num_classes).to(device)

# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Learning Rate Scheduler (Reduce by factor of 0.1 every 10 epochs)
#scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# Reduces learning rate if loss plateaus
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

# %%
print(model)
# Out:
# RNN(
#   (rnn): RNN(751, 256, num_layers=2, batch_first=True, dropout=0.5)
#   (fc): Linear(in_features=256, out_features=7, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
# Training loop

history = {'train_loss': [], 'val_loss': [], 'train_acc':[], 'val_acc': []}
all_preds = []
all_labels = []

train_loss_steps = []
train_acc_steps = []
running_loss_train_steps = 0.0
n_correct_train_steps = 0
n_samples_train_steps = 0

plot_steps, print_steps = 20,1

running_loss_train = 0.0
n_correct_train = 0
n_samples_train = 0

running_loss_val = 0.0
n_correct_val = 0
n_samples_val = 0

for epoch in range(num_epochs):
    
    model.train()
    running_loss_train = 0.0
    n_correct_train = 0
    n_samples_train = 0

    # Training loop
    for i, (inputs, labels) in enumerate(train_loader):
        
        inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
        labels = labels.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, labels)

        # Backward
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # For Epoch Graph
        running_loss_train += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train += (predictions == labels).sum().item()
        n_samples_train += labels.shape[0]

        # For Steps Graph
        running_loss_train_steps += loss.item()
        _, predictions = torch.max(outputs, 1)
        n_correct_train_steps += (predictions == labels).sum().item()
        n_samples_train_steps += labels.shape[0]
        
        if (i+1) % print_steps == 0:
            print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(train_loader)}, loss = {loss.item():.4f}')

        if (i+1) % plot_steps == 0:
            train_loss_steps.append(running_loss_train_steps / len(train_loader))
            train_acc_steps.append(100 * n_correct_train_steps / n_samples_train_steps)
            running_loss_train_steps = 0.0
            n_correct_train_steps = 0
            n_samples_train_steps = 0


    history['train_loss'].append(running_loss_train / len(train_loader))
    history['train_acc'].append(100 * n_correct_train / n_samples_train)

    # Test loop

    running_loss_val = 0.0
    n_correct_val = 0
    n_samples_val = 0

    model.eval()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            
            inputs = inputs.reshape(-1, sequence_length, input_size).to(device)
            labels = labels.to(device)
            
            # Forward
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Accumulate loss
            running_loss_val += loss.item()
            _, predictions = torch.max(outputs, 1)
            n_correct_val += (predictions == labels).sum().item()
            n_samples_val += labels.shape[0]

            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            if (i+1) % print_steps == 0:
                print(f'epoch {epoch+1} / {num_epochs}, step {i+1}/{len(test_loader)}, loss = {loss.item():.4f}')

        history['val_loss'].append(running_loss_val / len(test_loader))
        history['val_acc'].append(100 * n_correct_val / n_samples_val)
# Out:
# epoch 1 / 100, step 1/110, loss = 1.9549
# epoch 1 / 100, step 2/110, loss = 1.9367
# epoch 1 / 100, step 3/110, loss = 2.0105
# epoch 1 / 100, step 4/110, loss = 2.1553
# epoch 1 / 100, step 5/110, loss = 1.5466
# epoch 1 / 100, step 6/110, loss = 2.2364
# epoch 1 / 100, step 7/110, loss = 1.9401
# epoch 1 / 100, step 8/110, loss = 2.0592
# epoch 1 / 100, step 9/110, loss = 1.9480
# epoch 1 / 100, step 10/110, loss = 2.0178
# epoch 1 / 100, step 11/110, loss = 1.9252
# epoch 1 / 100, step 12/110, loss = 1.6887
# epoch 1 / 100, step 13/110, loss = 2.5597
# epoch 1 / 100, step 14/110, loss = 1.6830
# epoch 1 / 100, step 15/110, loss = 2.4621
# epoch 1 / 100, step 16/110, loss = 2.1030
# epoch 1 / 100, step 17/110, loss = 2.1294
# epoch 1 / 100, step 18/110, loss = 1.9851
# epoch 1 / 100, step 19/110, loss = 2.0425
# epoch 1 / 100, step 20/110, loss = 2.2105
# epoch 1 / 100, step 21/110, loss = 2.2131
# epoch 1 / 100, step 22/110, loss = 2.5619
# epoch 1 / 100, step 23/110, loss = 1.9038
# epoch 1 / 100, step 24/110, loss = 2.0411
# epoch 1 / 100, step 25/110, loss = 2.1980
# epoch 1 / 100, step 26/110, loss = 1.8340
# epoch 1 / 100, step 27/110, loss = 1.7674
# epoch 1 / 100, step 28/110, loss = 1.7076
# epoch 1 / 100, step 29/110, loss = 2.0416
# epoch 1 / 100, step 30/110, loss = 2.4344
# epoch 1 / 100, step 31/110, loss = 2.3970
# epoch 1 / 100, step 32/110, loss = 2.4439
# epoch 1 / 100, step 33/110, loss = 2.0039
# epoch 1 / 100, step 34/110, loss = 2.1596
# epoch 1 / 100, step 35/110, loss = 2.1508
# epoch 1 / 100, step 36/110, loss = 2.3926
# epoch 1 / 100, step 37/110, loss = 2.2092
# epoch 1 / 100, step 38/110, loss = 2.1302
# epoch 1 / 100, step 39/110, loss = 1.7531
# epoch 1 / 100, step 40/110, loss = 1.8078
# epoch 1 / 100, step 41/110, loss = 2.6316
# epoch 1 / 100, step 42/110, loss = 2.1098
# epoch 1 / 100, step 43/110, loss = 2.4094
# epoch 1 / 100, step 44/110, loss = 2.3591
# epoch 1 / 100, step 45/110, loss = 2.1334
# epoch 1 / 100, step 46/110, loss = 2.1812
# epoch 1 / 100, step 47/110, loss = 1.8766
# epoch 1 / 100, step 48/110, loss = 2.1041
# epoch 1 / 100, step 49/110, loss = 2.1191
# epoch 1 / 100, step 50/110, loss = 1.8754
# epoch 1 / 100, step 51/110, loss = 2.2156
# epoch 1 / 100, step 52/110, loss = 2.1800
# epoch 1 / 100, step 53/110, loss = 2.0701
# epoch 1 / 100, step 54/110, loss = 1.9395
# epoch 1 / 100, step 55/110, loss = 1.9552
# epoch 1 / 100, step 56/110, loss = 2.6365
# epoch 1 / 100, step 57/110, loss = 2.0443
# epoch 1 / 100, step 58/110, loss = 2.1408
# epoch 1 / 100, step 59/110, loss = 1.9975
# epoch 1 / 100, step 60/110, loss = 1.7194
# epoch 1 / 100, step 61/110, loss = 2.2003
# epoch 1 / 100, step 62/110, loss = 1.9317
# epoch 1 / 100, step 63/110, loss = 1.8832
# epoch 1 / 100, step 64/110, loss = 1.7969
# epoch 1 / 100, step 65/110, loss = 2.0426
# epoch 1 / 100, step 66/110, loss = 2.1533
# epoch 1 / 100, step 67/110, loss = 2.2397
# epoch 1 / 100, step 68/110, loss = 2.0992
# epoch 1 / 100, step 69/110, loss = 2.2023
# epoch 1 / 100, step 70/110, loss = 2.1176
# epoch 1 / 100, step 71/110, loss = 2.2506
# epoch 1 / 100, step 72/110, loss = 2.5576
# epoch 1 / 100, step 73/110, loss = 2.1314
# epoch 1 / 100, step 74/110, loss = 2.1098
# epoch 1 / 100, step 75/110, loss = 2.2476
# epoch 1 / 100, step 76/110, loss = 2.3204
# epoch 1 / 100, step 77/110, loss = 2.1627
# epoch 1 / 100, step 78/110, loss = 2.3897
# epoch 1 / 100, step 79/110, loss = 2.1722
# epoch 1 / 100, step 80/110, loss = 2.0962
# epoch 1 / 100, step 81/110, loss = 2.0192
# epoch 1 / 100, step 82/110, loss = 1.7223
# epoch 1 / 100, step 83/110, loss = 1.7009
# epoch 1 / 100, step 84/110, loss = 2.1934
# epoch 1 / 100, step 85/110, loss = 2.3092
# epoch 1 / 100, step 86/110, loss = 2.2790
# epoch 1 / 100, step 87/110, loss = 2.2955
# epoch 1 / 100, step 88/110, loss = 2.2206
# epoch 1 / 100, step 89/110, loss = 2.2140
# epoch 1 / 100, step 90/110, loss = 1.8526
# epoch 1 / 100, step 91/110, loss = 2.3372
# epoch 1 / 100, step 92/110, loss = 1.9456
# epoch 1 / 100, step 93/110, loss = 1.7238
# epoch 1 / 100, step 94/110, loss = 1.9202
# epoch 1 / 100, step 95/110, loss = 1.9811
# epoch 1 / 100, step 96/110, loss = 1.8640
# epoch 1 / 100, step 97/110, loss = 1.8644
# epoch 1 / 100, step 98/110, loss = 2.0677
# epoch 1 / 100, step 99/110, loss = 2.0844
# epoch 1 / 100, step 100/110, loss = 1.9727
# epoch 1 / 100, step 101/110, loss = 1.9474
# epoch 1 / 100, step 102/110, loss = 1.6028
# epoch 1 / 100, step 103/110, loss = 1.6793
# epoch 1 / 100, step 104/110, loss = 2.2942
# epoch 1 / 100, step 105/110, loss = 2.1639
# epoch 1 / 100, step 106/110, loss = 2.5812
# epoch 1 / 100, step 107/110, loss = 1.9442
# epoch 1 / 100, step 108/110, loss = 2.5972
# epoch 1 / 100, step 109/110, loss = 2.0645
# epoch 1 / 100, step 110/110, loss = 1.3850
# epoch 1 / 100, step 1/28, loss = 2.1526
# epoch 1 / 100, step 2/28, loss = 2.0962
# epoch 1 / 100, step 3/28, loss = 1.9818
# epoch 1 / 100, step 4/28, loss = 1.7950
# epoch 1 / 100, step 5/28, loss = 2.1706
# epoch 1 / 100, step 6/28, loss = 2.0378
# epoch 1 / 100, step 7/28, loss = 2.0742
# epoch 1 / 100, step 8/28, loss = 2.1660
# epoch 1 / 100, step 9/28, loss = 2.1955
# epoch 1 / 100, step 10/28, loss = 2.2828
# epoch 1 / 100, step 11/28, loss = 2.0266
# epoch 1 / 100, step 12/28, loss = 1.8090
# epoch 1 / 100, step 13/28, loss = 2.2872
# epoch 1 / 100, step 14/28, loss = 1.6083
# epoch 1 / 100, step 15/28, loss = 2.1469
# epoch 1 / 100, step 16/28, loss = 2.1920
# epoch 1 / 100, step 17/28, loss = 2.3222
# epoch 1 / 100, step 18/28, loss = 2.4297
# epoch 1 / 100, step 19/28, loss = 2.1566
# epoch 1 / 100, step 20/28, loss = 2.1957
# epoch 1 / 100, step 21/28, loss = 2.1846
# epoch 1 / 100, step 22/28, loss = 2.3205
# epoch 1 / 100, step 23/28, loss = 1.8964
# epoch 1 / 100, step 24/28, loss = 2.1018
# epoch 1 / 100, step 25/28, loss = 1.8800
# epoch 1 / 100, step 26/28, loss = 1.8814
# epoch 1 / 100, step 27/28, loss = 2.2834
# epoch 1 / 100, step 28/28, loss = 2.2045
# epoch 2 / 100, step 1/110, loss = 2.3939
# epoch 2 / 100, step 2/110, loss = 1.9197
# epoch 2 / 100, step 3/110, loss = 2.2461
# epoch 2 / 100, step 4/110, loss = 2.2721
# epoch 2 / 100, step 5/110, loss = 1.9904
# epoch 2 / 100, step 6/110, loss = 1.8416
# epoch 2 / 100, step 7/110, loss = 2.1809
# epoch 2 / 100, step 8/110, loss = 2.1750
# epoch 2 / 100, step 9/110, loss = 2.1051
# epoch 2 / 100, step 10/110, loss = 1.8324
# epoch 2 / 100, step 11/110, loss = 2.5292
# epoch 2 / 100, step 12/110, loss = 2.0740
# epoch 2 / 100, step 13/110, loss = 2.0048
# epoch 2 / 100, step 14/110, loss = 2.1797
# epoch 2 / 100, step 15/110, loss = 2.3424
# epoch 2 / 100, step 16/110, loss = 2.1236
# epoch 2 / 100, step 17/110, loss = 2.1848
# epoch 2 / 100, step 18/110, loss = 2.1032
# epoch 2 / 100, step 19/110, loss = 2.0715
# epoch 2 / 100, step 20/110, loss = 2.2122
# epoch 2 / 100, step 21/110, loss = 2.2510
# epoch 2 / 100, step 22/110, loss = 1.9945
# epoch 2 / 100, step 23/110, loss = 2.0370
# epoch 2 / 100, step 24/110, loss = 1.9609
# epoch 2 / 100, step 25/110, loss = 1.6736
# epoch 2 / 100, step 26/110, loss = 1.8385
# epoch 2 / 100, step 27/110, loss = 2.2342
# epoch 2 / 100, step 28/110, loss = 1.9328
# epoch 2 / 100, step 29/110, loss = 2.0778
# epoch 2 / 100, step 30/110, loss = 2.0415
# epoch 2 / 100, step 31/110, loss = 2.1684
# epoch 2 / 100, step 32/110, loss = 1.7788
# epoch 2 / 100, step 33/110, loss = 2.1882
# epoch 2 / 100, step 34/110, loss = 2.1150
# epoch 2 / 100, step 35/110, loss = 1.9564
# epoch 2 / 100, step 36/110, loss = 2.0909
# epoch 2 / 100, step 37/110, loss = 1.8694
# epoch 2 / 100, step 38/110, loss = 1.9825
# epoch 2 / 100, step 39/110, loss = 2.1599
# epoch 2 / 100, step 40/110, loss = 1.9762
# epoch 2 / 100, step 41/110, loss = 1.8434
# epoch 2 / 100, step 42/110, loss = 1.9013
# epoch 2 / 100, step 43/110, loss = 2.2318
# epoch 2 / 100, step 44/110, loss = 2.0113
# epoch 2 / 100, step 45/110, loss = 1.9420
# epoch 2 / 100, step 46/110, loss = 2.2764
# epoch 2 / 100, step 47/110, loss = 2.3044
# epoch 2 / 100, step 48/110, loss = 1.9733
# epoch 2 / 100, step 49/110, loss = 1.9043
# epoch 2 / 100, step 50/110, loss = 1.9830
# epoch 2 / 100, step 51/110, loss = 1.8743
# epoch 2 / 100, step 52/110, loss = 2.4340
# epoch 2 / 100, step 53/110, loss = 1.4482
# epoch 2 / 100, step 54/110, loss = 1.4724
# epoch 2 / 100, step 55/110, loss = 1.9323
# epoch 2 / 100, step 56/110, loss = 1.9954
# epoch 2 / 100, step 57/110, loss = 2.1623
# epoch 2 / 100, step 58/110, loss = 1.6466
# epoch 2 / 100, step 59/110, loss = 2.0774
# epoch 2 / 100, step 60/110, loss = 2.4636
# epoch 2 / 100, step 61/110, loss = 2.2180
# epoch 2 / 100, step 62/110, loss = 2.0794
# epoch 2 / 100, step 63/110, loss = 2.1298
# epoch 2 / 100, step 64/110, loss = 2.1558
# epoch 2 / 100, step 65/110, loss = 2.1674
# epoch 2 / 100, step 66/110, loss = 1.8318
# epoch 2 / 100, step 67/110, loss = 2.0929
# epoch 2 / 100, step 68/110, loss = 2.2120
# epoch 2 / 100, step 69/110, loss = 2.3871
# epoch 2 / 100, step 70/110, loss = 1.7384
# epoch 2 / 100, step 71/110, loss = 1.9813
# epoch 2 / 100, step 72/110, loss = 2.0045
# epoch 2 / 100, step 73/110, loss = 1.9265
# epoch 2 / 100, step 74/110, loss = 1.7830
# epoch 2 / 100, step 75/110, loss = 1.9213
# epoch 2 / 100, step 76/110, loss = 2.1177
# epoch 2 / 100, step 77/110, loss = 2.2036
# epoch 2 / 100, step 78/110, loss = 2.0411
# epoch 2 / 100, step 79/110, loss = 2.0749
# epoch 2 / 100, step 80/110, loss = 2.0144
# epoch 2 / 100, step 81/110, loss = 2.3688
# epoch 2 / 100, step 82/110, loss = 2.2508
# epoch 2 / 100, step 83/110, loss = 1.6938
# epoch 2 / 100, step 84/110, loss = 1.8445
# epoch 2 / 100, step 85/110, loss = 1.9008
# epoch 2 / 100, step 86/110, loss = 1.8446
# epoch 2 / 100, step 87/110, loss = 1.9365
# epoch 2 / 100, step 88/110, loss = 1.8350
# epoch 2 / 100, step 89/110, loss = 1.9355
# epoch 2 / 100, step 90/110, loss = 1.8789
# epoch 2 / 100, step 91/110, loss = 2.2004
# epoch 2 / 100, step 92/110, loss = 1.7300
# epoch 2 / 100, step 93/110, loss = 1.8358
# epoch 2 / 100, step 94/110, loss = 1.8413
# epoch 2 / 100, step 95/110, loss = 1.8975
# epoch 2 / 100, step 96/110, loss = 1.8125
# epoch 2 / 100, step 97/110, loss = 2.4137
# epoch 2 / 100, step 98/110, loss = 2.1377
# epoch 2 / 100, step 99/110, loss = 1.9687
# epoch 2 / 100, step 100/110, loss = 2.2304
# epoch 2 / 100, step 101/110, loss = 2.0410
# epoch 2 / 100, step 102/110, loss = 2.0603
# epoch 2 / 100, step 103/110, loss = 2.3242
# epoch 2 / 100, step 104/110, loss = 2.0829
# epoch 2 / 100, step 105/110, loss = 2.4324
# epoch 2 / 100, step 106/110, loss = 1.9627
# epoch 2 / 100, step 107/110, loss = 2.0787
# epoch 2 / 100, step 108/110, loss = 2.1338
# epoch 2 / 100, step 109/110, loss = 1.7695
# epoch 2 / 100, step 110/110, loss = 2.2188
# epoch 2 / 100, step 1/28, loss = 1.9809
# epoch 2 / 100, step 2/28, loss = 2.0317
# epoch 2 / 100, step 3/28, loss = 2.1757
# epoch 2 / 100, step 4/28, loss = 2.0689
# epoch 2 / 100, step 5/28, loss = 1.9300
# epoch 2 / 100, step 6/28, loss = 2.0701
# epoch 2 / 100, step 7/28, loss = 2.0146
# epoch 2 / 100, step 8/28, loss = 1.9351
# epoch 2 / 100, step 9/28, loss = 1.8207
# epoch 2 / 100, step 10/28, loss = 1.8525
# epoch 2 / 100, step 11/28, loss = 2.0188
# epoch 2 / 100, step 12/28, loss = 2.1297
# epoch 2 / 100, step 13/28, loss = 1.9115
# epoch 2 / 100, step 14/28, loss = 2.1373
# epoch 2 / 100, step 15/28, loss = 2.0090
# epoch 2 / 100, step 16/28, loss = 1.9964
# epoch 2 / 100, step 17/28, loss = 1.9059
# epoch 2 / 100, step 18/28, loss = 1.8320
# epoch 2 / 100, step 19/28, loss = 1.9320
# epoch 2 / 100, step 20/28, loss = 1.9151
# epoch 2 / 100, step 21/28, loss = 1.9137
# epoch 2 / 100, step 22/28, loss = 1.8928
# epoch 2 / 100, step 23/28, loss = 2.0432
# epoch 2 / 100, step 24/28, loss = 2.0025
# epoch 2 / 100, step 25/28, loss = 2.0199
# epoch 2 / 100, step 26/28, loss = 2.2413
# epoch 2 / 100, step 27/28, loss = 1.9557
# epoch 2 / 100, step 28/28, loss = 1.9757
# epoch 3 / 100, step 1/110, loss = 1.8718
# epoch 3 / 100, step 2/110, loss = 2.1003
# epoch 3 / 100, step 3/110, loss = 2.2800
# epoch 3 / 100, step 4/110, loss = 2.1130
# epoch 3 / 100, step 5/110, loss = 2.2631
# epoch 3 / 100, step 6/110, loss = 1.9131
# epoch 3 / 100, step 7/110, loss = 1.7568
# epoch 3 / 100, step 8/110, loss = 2.1598
# epoch 3 / 100, step 9/110, loss = 2.0313
# epoch 3 / 100, step 10/110, loss = 2.3889
# epoch 3 / 100, step 11/110, loss = 2.1682
# epoch 3 / 100, step 12/110, loss = 2.0099
# epoch 3 / 100, step 13/110, loss = 2.2629
# epoch 3 / 100, step 14/110, loss = 2.4826
# epoch 3 / 100, step 15/110, loss = 1.9598
# epoch 3 / 100, step 16/110, loss = 1.7055
# epoch 3 / 100, step 17/110, loss = 2.7442
# epoch 3 / 100, step 18/110, loss = 2.1892
# epoch 3 / 100, step 19/110, loss = 2.1325
# epoch 3 / 100, step 20/110, loss = 1.9732
# epoch 3 / 100, step 21/110, loss = 2.4121
# epoch 3 / 100, step 22/110, loss = 2.2353
# epoch 3 / 100, step 23/110, loss = 1.9089
# epoch 3 / 100, step 24/110, loss = 1.9816
# epoch 3 / 100, step 25/110, loss = 1.9727
# epoch 3 / 100, step 26/110, loss = 2.1235
# epoch 3 / 100, step 27/110, loss = 1.7352
# epoch 3 / 100, step 28/110, loss = 1.9786
# epoch 3 / 100, step 29/110, loss = 2.1131
# epoch 3 / 100, step 30/110, loss = 1.9603
# epoch 3 / 100, step 31/110, loss = 2.2312
# epoch 3 / 100, step 32/110, loss = 2.1269
# epoch 3 / 100, step 33/110, loss = 2.2519
# epoch 3 / 100, step 34/110, loss = 2.0825
# epoch 3 / 100, step 35/110, loss = 1.8982
# epoch 3 / 100, step 36/110, loss = 2.3689
# epoch 3 / 100, step 37/110, loss = 2.0045
# epoch 3 / 100, step 38/110, loss = 1.8310
# epoch 3 / 100, step 39/110, loss = 2.3095
# epoch 3 / 100, step 40/110, loss = 2.1018
# epoch 3 / 100, step 41/110, loss = 2.2663
# epoch 3 / 100, step 42/110, loss = 2.3331
# epoch 3 / 100, step 43/110, loss = 1.8669
# epoch 3 / 100, step 44/110, loss = 2.0806
# epoch 3 / 100, step 45/110, loss = 1.9092
# epoch 3 / 100, step 46/110, loss = 1.9994
# epoch 3 / 100, step 47/110, loss = 2.0775
# epoch 3 / 100, step 48/110, loss = 2.1960
# epoch 3 / 100, step 49/110, loss = 2.2137
# epoch 3 / 100, step 50/110, loss = 1.9598
# epoch 3 / 100, step 51/110, loss = 2.4166
# epoch 3 / 100, step 52/110, loss = 2.1870
# epoch 3 / 100, step 53/110, loss = 2.2704
# epoch 3 / 100, step 54/110, loss = 1.7983
# epoch 3 / 100, step 55/110, loss = 2.1058
# epoch 3 / 100, step 56/110, loss = 1.9402
# epoch 3 / 100, step 57/110, loss = 2.2660
# epoch 3 / 100, step 58/110, loss = 2.5380
# epoch 3 / 100, step 59/110, loss = 2.1681
# epoch 3 / 100, step 60/110, loss = 1.7539
# epoch 3 / 100, step 61/110, loss = 2.6625
# epoch 3 / 100, step 62/110, loss = 2.0899
# epoch 3 / 100, step 63/110, loss = 2.0689
# epoch 3 / 100, step 64/110, loss = 1.8062
# epoch 3 / 100, step 65/110, loss = 2.3065
# epoch 3 / 100, step 66/110, loss = 1.6177
# epoch 3 / 100, step 67/110, loss = 2.0168
# epoch 3 / 100, step 68/110, loss = 2.0344
# epoch 3 / 100, step 69/110, loss = 2.1893
# epoch 3 / 100, step 70/110, loss = 1.7405
# epoch 3 / 100, step 71/110, loss = 2.0172
# epoch 3 / 100, step 72/110, loss = 2.3238
# epoch 3 / 100, step 73/110, loss = 2.2884
# epoch 3 / 100, step 74/110, loss = 2.3444
# epoch 3 / 100, step 75/110, loss = 2.2940
# epoch 3 / 100, step 76/110, loss = 2.1921
# epoch 3 / 100, step 77/110, loss = 1.7397
# epoch 3 / 100, step 78/110, loss = 2.2512
# epoch 3 / 100, step 79/110, loss = 2.1936
# epoch 3 / 100, step 80/110, loss = 2.0511
# epoch 3 / 100, step 81/110, loss = 1.9516
# epoch 3 / 100, step 82/110, loss = 2.1970
# epoch 3 / 100, step 83/110, loss = 1.9026
# epoch 3 / 100, step 84/110, loss = 1.9312
# epoch 3 / 100, step 85/110, loss = 1.5965
# epoch 3 / 100, step 86/110, loss = 1.9366
# epoch 3 / 100, step 87/110, loss = 1.8221
# epoch 3 / 100, step 88/110, loss = 1.9573
# epoch 3 / 100, step 89/110, loss = 1.7747
# epoch 3 / 100, step 90/110, loss = 2.4405
# epoch 3 / 100, step 91/110, loss = 2.0191
# epoch 3 / 100, step 92/110, loss = 1.6587
# epoch 3 / 100, step 93/110, loss = 2.0591
# epoch 3 / 100, step 94/110, loss = 2.2216
# epoch 3 / 100, step 95/110, loss = 2.3228
# epoch 3 / 100, step 96/110, loss = 2.2300
# epoch 3 / 100, step 97/110, loss = 1.7395
# epoch 3 / 100, step 98/110, loss = 2.1197
# epoch 3 / 100, step 99/110, loss = 2.2086
# epoch 3 / 100, step 100/110, loss = 1.8848
# epoch 3 / 100, step 101/110, loss = 1.9617
# epoch 3 / 100, step 102/110, loss = 1.9247
# epoch 3 / 100, step 103/110, loss = 1.8653
# epoch 3 / 100, step 104/110, loss = 1.8501
# epoch 3 / 100, step 105/110, loss = 1.9958
# epoch 3 / 100, step 106/110, loss = 2.0525
# epoch 3 / 100, step 107/110, loss = 2.0465
# epoch 3 / 100, step 108/110, loss = 1.9982
# epoch 3 / 100, step 109/110, loss = 1.8548
# epoch 3 / 100, step 110/110, loss = 1.9632
# epoch 3 / 100, step 1/28, loss = 2.0612
# epoch 3 / 100, step 2/28, loss = 2.1474
# epoch 3 / 100, step 3/28, loss = 1.9963
# epoch 3 / 100, step 4/28, loss = 2.1507
# epoch 3 / 100, step 5/28, loss = 2.1100
# epoch 3 / 100, step 6/28, loss = 2.2336
# epoch 3 / 100, step 7/28, loss = 1.8803
# epoch 3 / 100, step 8/28, loss = 1.9318
# epoch 3 / 100, step 9/28, loss = 1.9558
# epoch 3 / 100, step 10/28, loss = 1.8509
# epoch 3 / 100, step 11/28, loss = 1.8401
# epoch 3 / 100, step 12/28, loss = 1.8212
# epoch 3 / 100, step 13/28, loss = 1.9841
# epoch 3 / 100, step 14/28, loss = 2.1452
# epoch 3 / 100, step 15/28, loss = 1.7681
# epoch 3 / 100, step 16/28, loss = 2.2198
# epoch 3 / 100, step 17/28, loss = 1.9200
# epoch 3 / 100, step 18/28, loss = 1.8408
# epoch 3 / 100, step 19/28, loss = 2.1967
# epoch 3 / 100, step 20/28, loss = 1.7841
# epoch 3 / 100, step 21/28, loss = 1.9170
# epoch 3 / 100, step 22/28, loss = 1.9893
# epoch 3 / 100, step 23/28, loss = 2.0324
# epoch 3 / 100, step 24/28, loss = 2.1099
# epoch 3 / 100, step 25/28, loss = 1.9851
# epoch 3 / 100, step 26/28, loss = 2.3347
# epoch 3 / 100, step 27/28, loss = 2.0449
# epoch 3 / 100, step 28/28, loss = 1.7343
# epoch 4 / 100, step 1/110, loss = 2.0842
# epoch 4 / 100, step 2/110, loss = 2.1581
# epoch 4 / 100, step 3/110, loss = 1.8854
# epoch 4 / 100, step 4/110, loss = 2.2251
# epoch 4 / 100, step 5/110, loss = 2.1929
# epoch 4 / 100, step 6/110, loss = 1.9556
# epoch 4 / 100, step 7/110, loss = 1.9059
# epoch 4 / 100, step 8/110, loss = 1.9692
# epoch 4 / 100, step 9/110, loss = 1.8445
# epoch 4 / 100, step 10/110, loss = 1.8993
# epoch 4 / 100, step 11/110, loss = 2.3614
# epoch 4 / 100, step 12/110, loss = 2.1017
# epoch 4 / 100, step 13/110, loss = 1.9570
# epoch 4 / 100, step 14/110, loss = 1.9440
# epoch 4 / 100, step 15/110, loss = 2.1714
# epoch 4 / 100, step 16/110, loss = 2.1566
# epoch 4 / 100, step 17/110, loss = 1.8520
# epoch 4 / 100, step 18/110, loss = 1.9962
# epoch 4 / 100, step 19/110, loss = 1.8580
# epoch 4 / 100, step 20/110, loss = 2.3271
# epoch 4 / 100, step 21/110, loss = 2.0750
# epoch 4 / 100, step 22/110, loss = 2.1010
# epoch 4 / 100, step 23/110, loss = 2.3467
# epoch 4 / 100, step 24/110, loss = 2.1370
# epoch 4 / 100, step 25/110, loss = 2.0177
# epoch 4 / 100, step 26/110, loss = 1.8363
# epoch 4 / 100, step 27/110, loss = 2.0840
# epoch 4 / 100, step 28/110, loss = 1.7277
# epoch 4 / 100, step 29/110, loss = 1.9991
# epoch 4 / 100, step 30/110, loss = 2.2583
# epoch 4 / 100, step 31/110, loss = 2.4667
# epoch 4 / 100, step 32/110, loss = 1.9359
# epoch 4 / 100, step 33/110, loss = 2.4972
# epoch 4 / 100, step 34/110, loss = 2.2441
# epoch 4 / 100, step 35/110, loss = 2.4054
# epoch 4 / 100, step 36/110, loss = 1.7396
# epoch 4 / 100, step 37/110, loss = 2.2632
# epoch 4 / 100, step 38/110, loss = 2.4764
# epoch 4 / 100, step 39/110, loss = 2.1058
# epoch 4 / 100, step 40/110, loss = 2.1700
# epoch 4 / 100, step 41/110, loss = 2.2484
# epoch 4 / 100, step 42/110, loss = 2.2542
# epoch 4 / 100, step 43/110, loss = 2.1531
# epoch 4 / 100, step 44/110, loss = 2.1109
# epoch 4 / 100, step 45/110, loss = 1.9290
# epoch 4 / 100, step 46/110, loss = 1.8045
# epoch 4 / 100, step 47/110, loss = 1.7770
# epoch 4 / 100, step 48/110, loss = 2.1346
# epoch 4 / 100, step 49/110, loss = 1.9974
# epoch 4 / 100, step 50/110, loss = 2.4743
# epoch 4 / 100, step 51/110, loss = 2.0488
# epoch 4 / 100, step 52/110, loss = 1.9998
# epoch 4 / 100, step 53/110, loss = 2.2890
# epoch 4 / 100, step 54/110, loss = 1.7733
# epoch 4 / 100, step 55/110, loss = 1.6802
# epoch 4 / 100, step 56/110, loss = 2.1422
# epoch 4 / 100, step 57/110, loss = 1.9349
# epoch 4 / 100, step 58/110, loss = 1.8868
# epoch 4 / 100, step 59/110, loss = 2.2035
# epoch 4 / 100, step 60/110, loss = 2.3752
# epoch 4 / 100, step 61/110, loss = 1.9158
# epoch 4 / 100, step 62/110, loss = 2.5312
# epoch 4 / 100, step 63/110, loss = 2.1531
# epoch 4 / 100, step 64/110, loss = 2.2841
# epoch 4 / 100, step 65/110, loss = 2.1415
# epoch 4 / 100, step 66/110, loss = 2.1080
# epoch 4 / 100, step 67/110, loss = 2.0923
# epoch 4 / 100, step 68/110, loss = 1.5789
# epoch 4 / 100, step 69/110, loss = 2.1254
# epoch 4 / 100, step 70/110, loss = 1.7238
# epoch 4 / 100, step 71/110, loss = 2.3114
# epoch 4 / 100, step 72/110, loss = 2.0091
# epoch 4 / 100, step 73/110, loss = 2.1431
# epoch 4 / 100, step 74/110, loss = 2.1077
# epoch 4 / 100, step 75/110, loss = 2.0177
# epoch 4 / 100, step 76/110, loss = 2.1481
# epoch 4 / 100, step 77/110, loss = 2.0545
# epoch 4 / 100, step 78/110, loss = 2.0482
# epoch 4 / 100, step 79/110, loss = 2.0888
# epoch 4 / 100, step 80/110, loss = 2.0814
# epoch 4 / 100, step 81/110, loss = 1.9548
# epoch 4 / 100, step 82/110, loss = 1.9767
# epoch 4 / 100, step 83/110, loss = 2.2961
# epoch 4 / 100, step 84/110, loss = 2.2462
# epoch 4 / 100, step 85/110, loss = 1.6462
# epoch 4 / 100, step 86/110, loss = 1.8854
# epoch 4 / 100, step 87/110, loss = 2.2322
# epoch 4 / 100, step 88/110, loss = 1.8244
# epoch 4 / 100, step 89/110, loss = 2.1068
# epoch 4 / 100, step 90/110, loss = 2.0017
# epoch 4 / 100, step 91/110, loss = 2.0096
# epoch 4 / 100, step 92/110, loss = 2.0909
# epoch 4 / 100, step 93/110, loss = 2.1807
# epoch 4 / 100, step 94/110, loss = 2.0697
# epoch 4 / 100, step 95/110, loss = 1.9445
# epoch 4 / 100, step 96/110, loss = 1.9405
# epoch 4 / 100, step 97/110, loss = 1.8313
# epoch 4 / 100, step 98/110, loss = 1.8524
# epoch 4 / 100, step 99/110, loss = 1.9168
# epoch 4 / 100, step 100/110, loss = 1.9244
# epoch 4 / 100, step 101/110, loss = 2.2034
# epoch 4 / 100, step 102/110, loss = 2.0154
# epoch 4 / 100, step 103/110, loss = 2.2386
# epoch 4 / 100, step 104/110, loss = 2.2503
# epoch 4 / 100, step 105/110, loss = 1.8842
# epoch 4 / 100, step 106/110, loss = 1.9126
# epoch 4 / 100, step 107/110, loss = 2.1461
# epoch 4 / 100, step 108/110, loss = 2.0213
# epoch 4 / 100, step 109/110, loss = 1.7193
# epoch 4 / 100, step 110/110, loss = 1.8219
# epoch 4 / 100, step 1/28, loss = 1.8813
# epoch 4 / 100, step 2/28, loss = 1.9028
# epoch 4 / 100, step 3/28, loss = 2.0142
# epoch 4 / 100, step 4/28, loss = 1.9747
# epoch 4 / 100, step 5/28, loss = 1.9889
# epoch 4 / 100, step 6/28, loss = 1.8337
# epoch 4 / 100, step 7/28, loss = 1.9179
# epoch 4 / 100, step 8/28, loss = 2.1078
# epoch 4 / 100, step 9/28, loss = 1.8860
# epoch 4 / 100, step 10/28, loss = 1.9903
# epoch 4 / 100, step 11/28, loss = 1.8758
# epoch 4 / 100, step 12/28, loss = 1.7109
# epoch 4 / 100, step 13/28, loss = 1.9616
# epoch 4 / 100, step 14/28, loss = 2.0521
# epoch 4 / 100, step 15/28, loss = 1.7442
# epoch 4 / 100, step 16/28, loss = 1.9545
# epoch 4 / 100, step 17/28, loss = 1.8840
# epoch 4 / 100, step 18/28, loss = 1.9577
# epoch 4 / 100, step 19/28, loss = 2.0974
# epoch 4 / 100, step 20/28, loss = 1.9539
# epoch 4 / 100, step 21/28, loss = 1.8831
# epoch 4 / 100, step 22/28, loss = 1.9351
# epoch 4 / 100, step 23/28, loss = 1.9457
# epoch 4 / 100, step 24/28, loss = 2.0737
# epoch 4 / 100, step 25/28, loss = 2.0261
# epoch 4 / 100, step 26/28, loss = 2.2213
# epoch 4 / 100, step 27/28, loss = 1.9863
# epoch 4 / 100, step 28/28, loss = 1.7061
# epoch 5 / 100, step 1/110, loss = 2.0694
# epoch 5 / 100, step 2/110, loss = 1.5458
# epoch 5 / 100, step 3/110, loss = 2.1735
# epoch 5 / 100, step 4/110, loss = 1.7159
# epoch 5 / 100, step 5/110, loss = 2.0995
# epoch 5 / 100, step 6/110, loss = 1.8640
# epoch 5 / 100, step 7/110, loss = 2.0688
# epoch 5 / 100, step 8/110, loss = 2.2985
# epoch 5 / 100, step 9/110, loss = 1.7839
# epoch 5 / 100, step 10/110, loss = 2.1071
# epoch 5 / 100, step 11/110, loss = 2.3042
# epoch 5 / 100, step 12/110, loss = 1.8850
# epoch 5 / 100, step 13/110, loss = 2.0965
# epoch 5 / 100, step 14/110, loss = 1.7256
# epoch 5 / 100, step 15/110, loss = 2.2203
# epoch 5 / 100, step 16/110, loss = 2.0457
# epoch 5 / 100, step 17/110, loss = 2.0278
# epoch 5 / 100, step 18/110, loss = 2.1307
# epoch 5 / 100, step 19/110, loss = 2.0069
# epoch 5 / 100, step 20/110, loss = 1.8287
# epoch 5 / 100, step 21/110, loss = 2.0124
# epoch 5 / 100, step 22/110, loss = 2.1947
# epoch 5 / 100, step 23/110, loss = 2.2280
# epoch 5 / 100, step 24/110, loss = 2.1395
# epoch 5 / 100, step 25/110, loss = 1.9858
# epoch 5 / 100, step 26/110, loss = 1.8639
# epoch 5 / 100, step 27/110, loss = 1.9571
# epoch 5 / 100, step 28/110, loss = 1.9563
# epoch 5 / 100, step 29/110, loss = 2.2187
# epoch 5 / 100, step 30/110, loss = 1.8925
# epoch 5 / 100, step 31/110, loss = 2.0766
# epoch 5 / 100, step 32/110, loss = 2.2189
# epoch 5 / 100, step 33/110, loss = 2.1400
# epoch 5 / 100, step 34/110, loss = 2.1335
# epoch 5 / 100, step 35/110, loss = 1.9158
# epoch 5 / 100, step 36/110, loss = 2.0817
# epoch 5 / 100, step 37/110, loss = 1.7906
# epoch 5 / 100, step 38/110, loss = 2.1970
# epoch 5 / 100, step 39/110, loss = 2.0730
# epoch 5 / 100, step 40/110, loss = 1.9225
# epoch 5 / 100, step 41/110, loss = 2.1847
# epoch 5 / 100, step 42/110, loss = 1.7537
# epoch 5 / 100, step 43/110, loss = 2.1398
# epoch 5 / 100, step 44/110, loss = 1.9237
# epoch 5 / 100, step 45/110, loss = 1.8070
# epoch 5 / 100, step 46/110, loss = 1.7309
# epoch 5 / 100, step 47/110, loss = 1.8882
# epoch 5 / 100, step 48/110, loss = 2.0194
# epoch 5 / 100, step 49/110, loss = 1.9662
# epoch 5 / 100, step 50/110, loss = 2.3764
# epoch 5 / 100, step 51/110, loss = 2.3951
# epoch 5 / 100, step 52/110, loss = 2.1676
# epoch 5 / 100, step 53/110, loss = 1.9522
# epoch 5 / 100, step 54/110, loss = 1.6993
# epoch 5 / 100, step 55/110, loss = 1.9460
# epoch 5 / 100, step 56/110, loss = 2.2557
# epoch 5 / 100, step 57/110, loss = 1.9563
# epoch 5 / 100, step 58/110, loss = 2.2925
# epoch 5 / 100, step 59/110, loss = 1.8012
# epoch 5 / 100, step 60/110, loss = 1.9579
# epoch 5 / 100, step 61/110, loss = 1.9514
# epoch 5 / 100, step 62/110, loss = 2.1761
# epoch 5 / 100, step 63/110, loss = 1.9551
# epoch 5 / 100, step 64/110, loss = 1.9674
# epoch 5 / 100, step 65/110, loss = 1.9699
# epoch 5 / 100, step 66/110, loss = 1.9335
# epoch 5 / 100, step 67/110, loss = 2.1426
# epoch 5 / 100, step 68/110, loss = 1.9408
# epoch 5 / 100, step 69/110, loss = 1.7590
# epoch 5 / 100, step 70/110, loss = 2.3747
# epoch 5 / 100, step 71/110, loss = 2.1242
# epoch 5 / 100, step 72/110, loss = 2.2424
# epoch 5 / 100, step 73/110, loss = 2.0438
# epoch 5 / 100, step 74/110, loss = 1.9882
# epoch 5 / 100, step 75/110, loss = 1.8855
# epoch 5 / 100, step 76/110, loss = 1.8077
# epoch 5 / 100, step 77/110, loss = 1.8480
# epoch 5 / 100, step 78/110, loss = 2.5899
# epoch 5 / 100, step 79/110, loss = 1.7904
# epoch 5 / 100, step 80/110, loss = 2.3566
# epoch 5 / 100, step 81/110, loss = 1.7424
# epoch 5 / 100, step 82/110, loss = 2.0999
# epoch 5 / 100, step 83/110, loss = 1.7345
# epoch 5 / 100, step 84/110, loss = 2.4396
# epoch 5 / 100, step 85/110, loss = 2.2639
# epoch 5 / 100, step 86/110, loss = 2.1411
# epoch 5 / 100, step 87/110, loss = 2.1978
# epoch 5 / 100, step 88/110, loss = 1.7837
# epoch 5 / 100, step 89/110, loss = 2.1378
# epoch 5 / 100, step 90/110, loss = 2.1366
# epoch 5 / 100, step 91/110, loss = 2.1119
# epoch 5 / 100, step 92/110, loss = 2.3667
# epoch 5 / 100, step 93/110, loss = 2.3359
# epoch 5 / 100, step 94/110, loss = 2.0281
# epoch 5 / 100, step 95/110, loss = 1.7672
# epoch 5 / 100, step 96/110, loss = 2.0225
# epoch 5 / 100, step 97/110, loss = 2.0307
# epoch 5 / 100, step 98/110, loss = 1.9945
# epoch 5 / 100, step 99/110, loss = 1.8183
# epoch 5 / 100, step 100/110, loss = 1.8097
# epoch 5 / 100, step 101/110, loss = 1.4030
# epoch 5 / 100, step 102/110, loss = 2.1800
# epoch 5 / 100, step 103/110, loss = 2.2256
# epoch 5 / 100, step 104/110, loss = 2.1738
# epoch 5 / 100, step 105/110, loss = 2.3099
# epoch 5 / 100, step 106/110, loss = 2.0402
# epoch 5 / 100, step 107/110, loss = 2.3178
# epoch 5 / 100, step 108/110, loss = 2.0960
# epoch 5 / 100, step 109/110, loss = 1.7129
# epoch 5 / 100, step 110/110, loss = 1.8391
# epoch 5 / 100, step 1/28, loss = 1.9428
# epoch 5 / 100, step 2/28, loss = 1.9611
# epoch 5 / 100, step 3/28, loss = 1.9086
# epoch 5 / 100, step 4/28, loss = 2.0352
# epoch 5 / 100, step 5/28, loss = 2.1787
# epoch 5 / 100, step 6/28, loss = 1.9454
# epoch 5 / 100, step 7/28, loss = 1.9081
# epoch 5 / 100, step 8/28, loss = 2.0795
# epoch 5 / 100, step 9/28, loss = 1.9213
# epoch 5 / 100, step 10/28, loss = 2.0570
# epoch 5 / 100, step 11/28, loss = 1.8200
# epoch 5 / 100, step 12/28, loss = 1.6894
# epoch 5 / 100, step 13/28, loss = 1.9293
# epoch 5 / 100, step 14/28, loss = 2.0746
# epoch 5 / 100, step 15/28, loss = 1.7234
# epoch 5 / 100, step 16/28, loss = 1.9895
# epoch 5 / 100, step 17/28, loss = 1.9460
# epoch 5 / 100, step 18/28, loss = 1.9308
# epoch 5 / 100, step 19/28, loss = 2.1987
# epoch 5 / 100, step 20/28, loss = 2.0374
# epoch 5 / 100, step 21/28, loss = 1.9700
# epoch 5 / 100, step 22/28, loss = 2.0060
# epoch 5 / 100, step 23/28, loss = 1.9918
# epoch 5 / 100, step 24/28, loss = 2.1546
# epoch 5 / 100, step 25/28, loss = 1.9621
# epoch 5 / 100, step 26/28, loss = 2.2827
# epoch 5 / 100, step 27/28, loss = 2.0075
# epoch 5 / 100, step 28/28, loss = 1.7674
# epoch 6 / 100, step 1/110, loss = 2.0482
# epoch 6 / 100, step 2/110, loss = 1.7840
# epoch 6 / 100, step 3/110, loss = 1.8657
# epoch 6 / 100, step 4/110, loss = 2.1120
# epoch 6 / 100, step 5/110, loss = 2.2028
# epoch 6 / 100, step 6/110, loss = 1.8381
# epoch 6 / 100, step 7/110, loss = 1.8648
# epoch 6 / 100, step 8/110, loss = 2.1158
# epoch 6 / 100, step 9/110, loss = 1.8446
# epoch 6 / 100, step 10/110, loss = 2.0500
# epoch 6 / 100, step 11/110, loss = 2.2243
# epoch 6 / 100, step 12/110, loss = 1.8931
# epoch 6 / 100, step 13/110, loss = 1.9086
# epoch 6 / 100, step 14/110, loss = 2.2278
# epoch 6 / 100, step 15/110, loss = 1.9839
# epoch 6 / 100, step 16/110, loss = 2.2066
# epoch 6 / 100, step 17/110, loss = 2.1195
# epoch 6 / 100, step 18/110, loss = 1.9961
# epoch 6 / 100, step 19/110, loss = 1.8565
# epoch 6 / 100, step 20/110, loss = 1.8104
# epoch 6 / 100, step 21/110, loss = 2.1789
# epoch 6 / 100, step 22/110, loss = 2.5655
# epoch 6 / 100, step 23/110, loss = 2.1961
# epoch 6 / 100, step 24/110, loss = 2.0094
# epoch 6 / 100, step 25/110, loss = 2.1066
# epoch 6 / 100, step 26/110, loss = 2.1122
# epoch 6 / 100, step 27/110, loss = 1.7670
# epoch 6 / 100, step 28/110, loss = 1.9126
# epoch 6 / 100, step 29/110, loss = 2.0780
# epoch 6 / 100, step 30/110, loss = 1.9456
# epoch 6 / 100, step 31/110, loss = 2.0663
# epoch 6 / 100, step 32/110, loss = 2.0524
# epoch 6 / 100, step 33/110, loss = 1.9684
# epoch 6 / 100, step 34/110, loss = 2.3484
# epoch 6 / 100, step 35/110, loss = 2.2761
# epoch 6 / 100, step 36/110, loss = 2.0877
# epoch 6 / 100, step 37/110, loss = 1.8361
# epoch 6 / 100, step 38/110, loss = 1.9158
# epoch 6 / 100, step 39/110, loss = 2.0922
# epoch 6 / 100, step 40/110, loss = 1.9145
# epoch 6 / 100, step 41/110, loss = 2.1110
# epoch 6 / 100, step 42/110, loss = 1.8990
# epoch 6 / 100, step 43/110, loss = 1.8385
# epoch 6 / 100, step 44/110, loss = 2.1448
# epoch 6 / 100, step 45/110, loss = 2.3360
# epoch 6 / 100, step 46/110, loss = 2.0156
# epoch 6 / 100, step 47/110, loss = 1.7556
# epoch 6 / 100, step 48/110, loss = 1.9077
# epoch 6 / 100, step 49/110, loss = 2.0393
# epoch 6 / 100, step 50/110, loss = 1.8680
# epoch 6 / 100, step 51/110, loss = 1.9249
# epoch 6 / 100, step 52/110, loss = 2.0855
# epoch 6 / 100, step 53/110, loss = 1.9839
# epoch 6 / 100, step 54/110, loss = 2.1951
# epoch 6 / 100, step 55/110, loss = 1.7733
# epoch 6 / 100, step 56/110, loss = 2.0005
# epoch 6 / 100, step 57/110, loss = 2.3469
# epoch 6 / 100, step 58/110, loss = 2.1363
# epoch 6 / 100, step 59/110, loss = 1.7865
# epoch 6 / 100, step 60/110, loss = 1.9747
# epoch 6 / 100, step 61/110, loss = 1.9130
# epoch 6 / 100, step 62/110, loss = 2.0329
# epoch 6 / 100, step 63/110, loss = 2.5203
# epoch 6 / 100, step 64/110, loss = 1.9610
# epoch 6 / 100, step 65/110, loss = 1.9338
# epoch 6 / 100, step 66/110, loss = 1.9260
# epoch 6 / 100, step 67/110, loss = 2.0771
# epoch 6 / 100, step 68/110, loss = 2.2531
# epoch 6 / 100, step 69/110, loss = 1.7615
# epoch 6 / 100, step 70/110, loss = 1.9148
# epoch 6 / 100, step 71/110, loss = 2.1380
# epoch 6 / 100, step 72/110, loss = 1.9252
# epoch 6 / 100, step 73/110, loss = 2.0685
# epoch 6 / 100, step 74/110, loss = 1.7846
# epoch 6 / 100, step 75/110, loss = 2.0181
# epoch 6 / 100, step 76/110, loss = 2.2277
# epoch 6 / 100, step 77/110, loss = 2.2059
# epoch 6 / 100, step 78/110, loss = 1.7750
# epoch 6 / 100, step 79/110, loss = 2.0611
# epoch 6 / 100, step 80/110, loss = 2.2167
# epoch 6 / 100, step 81/110, loss = 1.6154
# epoch 6 / 100, step 82/110, loss = 2.1571
# epoch 6 / 100, step 83/110, loss = 1.9179
# epoch 6 / 100, step 84/110, loss = 2.4144
# epoch 6 / 100, step 85/110, loss = 2.0130
# epoch 6 / 100, step 86/110, loss = 1.8017
# epoch 6 / 100, step 87/110, loss = 2.0946
# epoch 6 / 100, step 88/110, loss = 2.2104
# epoch 6 / 100, step 89/110, loss = 2.0005
# epoch 6 / 100, step 90/110, loss = 1.6869
# epoch 6 / 100, step 91/110, loss = 2.0081
# epoch 6 / 100, step 92/110, loss = 1.7530
# epoch 6 / 100, step 93/110, loss = 2.2287
# epoch 6 / 100, step 94/110, loss = 1.7966
# epoch 6 / 100, step 95/110, loss = 2.3327
# epoch 6 / 100, step 96/110, loss = 2.0687
# epoch 6 / 100, step 97/110, loss = 2.1199
# epoch 6 / 100, step 98/110, loss = 2.0597
# epoch 6 / 100, step 99/110, loss = 2.0526
# epoch 6 / 100, step 100/110, loss = 2.0655
# epoch 6 / 100, step 101/110, loss = 2.1735
# epoch 6 / 100, step 102/110, loss = 1.7708
# epoch 6 / 100, step 103/110, loss = 2.0362
# epoch 6 / 100, step 104/110, loss = 1.9882
# epoch 6 / 100, step 105/110, loss = 2.0885
# epoch 6 / 100, step 106/110, loss = 2.0014
# epoch 6 / 100, step 107/110, loss = 2.3281
# epoch 6 / 100, step 108/110, loss = 1.8277
# epoch 6 / 100, step 109/110, loss = 2.2437
# epoch 6 / 100, step 110/110, loss = 2.2493
# epoch 6 / 100, step 1/28, loss = 1.9496
# epoch 6 / 100, step 2/28, loss = 1.9767
# epoch 6 / 100, step 3/28, loss = 1.9066
# epoch 6 / 100, step 4/28, loss = 1.9882
# epoch 6 / 100, step 5/28, loss = 2.1103
# epoch 6 / 100, step 6/28, loss = 1.9273
# epoch 6 / 100, step 7/28, loss = 1.8575
# epoch 6 / 100, step 8/28, loss = 2.0507
# epoch 6 / 100, step 9/28, loss = 1.9749
# epoch 6 / 100, step 10/28, loss = 2.0029
# epoch 6 / 100, step 11/28, loss = 1.8533
# epoch 6 / 100, step 12/28, loss = 1.6431
# epoch 6 / 100, step 13/28, loss = 2.0087
# epoch 6 / 100, step 14/28, loss = 1.9735
# epoch 6 / 100, step 15/28, loss = 1.7197
# epoch 6 / 100, step 16/28, loss = 2.0365
# epoch 6 / 100, step 17/28, loss = 1.9707
# epoch 6 / 100, step 18/28, loss = 2.0293
# epoch 6 / 100, step 19/28, loss = 2.1863
# epoch 6 / 100, step 20/28, loss = 1.9189
# epoch 6 / 100, step 21/28, loss = 1.9602
# epoch 6 / 100, step 22/28, loss = 2.0309
# epoch 6 / 100, step 23/28, loss = 1.9098
# epoch 6 / 100, step 24/28, loss = 2.1224
# epoch 6 / 100, step 25/28, loss = 1.9980
# epoch 6 / 100, step 26/28, loss = 2.1964
# epoch 6 / 100, step 27/28, loss = 2.0482
# epoch 6 / 100, step 28/28, loss = 1.7357
# epoch 7 / 100, step 1/110, loss = 1.8028
# epoch 7 / 100, step 2/110, loss = 1.9540
# epoch 7 / 100, step 3/110, loss = 2.0690
# epoch 7 / 100, step 4/110, loss = 2.2012
# epoch 7 / 100, step 5/110, loss = 2.1868
# epoch 7 / 100, step 6/110, loss = 2.1648
# epoch 7 / 100, step 7/110, loss = 2.0186
# epoch 7 / 100, step 8/110, loss = 1.9726
# epoch 7 / 100, step 9/110, loss = 2.1465
# epoch 7 / 100, step 10/110, loss = 1.9856
# epoch 7 / 100, step 11/110, loss = 2.1106
# epoch 7 / 100, step 12/110, loss = 1.7915
# epoch 7 / 100, step 13/110, loss = 1.8085
# epoch 7 / 100, step 14/110, loss = 1.9860
# epoch 7 / 100, step 15/110, loss = 2.0718
# epoch 7 / 100, step 16/110, loss = 1.8952
# epoch 7 / 100, step 17/110, loss = 2.0447
# epoch 7 / 100, step 18/110, loss = 2.2418
# epoch 7 / 100, step 19/110, loss = 1.8306
# epoch 7 / 100, step 20/110, loss = 1.6864
# epoch 7 / 100, step 21/110, loss = 2.3338
# epoch 7 / 100, step 22/110, loss = 2.2067
# epoch 7 / 100, step 23/110, loss = 2.0998
# epoch 7 / 100, step 24/110, loss = 1.9341
# epoch 7 / 100, step 25/110, loss = 1.7583
# epoch 7 / 100, step 26/110, loss = 1.9564
# epoch 7 / 100, step 27/110, loss = 2.3363
# epoch 7 / 100, step 28/110, loss = 2.2367
# epoch 7 / 100, step 29/110, loss = 1.9937
# epoch 7 / 100, step 30/110, loss = 1.9746
# epoch 7 / 100, step 31/110, loss = 1.8644
# epoch 7 / 100, step 32/110, loss = 2.1185
# epoch 7 / 100, step 33/110, loss = 2.2454
# epoch 7 / 100, step 34/110, loss = 2.3859
# epoch 7 / 100, step 35/110, loss = 1.9106
# epoch 7 / 100, step 36/110, loss = 1.8856
# epoch 7 / 100, step 37/110, loss = 2.0019
# epoch 7 / 100, step 38/110, loss = 2.1300
# epoch 7 / 100, step 39/110, loss = 1.9533
# epoch 7 / 100, step 40/110, loss = 2.2081
# epoch 7 / 100, step 41/110, loss = 2.2249
# epoch 7 / 100, step 42/110, loss = 1.8738
# epoch 7 / 100, step 43/110, loss = 1.9035
# epoch 7 / 100, step 44/110, loss = 2.1689
# epoch 7 / 100, step 45/110, loss = 1.8555
# epoch 7 / 100, step 46/110, loss = 1.7644
# epoch 7 / 100, step 47/110, loss = 2.1966
# epoch 7 / 100, step 48/110, loss = 1.6266
# epoch 7 / 100, step 49/110, loss = 1.8936
# epoch 7 / 100, step 50/110, loss = 2.0338
# epoch 7 / 100, step 51/110, loss = 2.1903
# epoch 7 / 100, step 52/110, loss = 2.0508
# epoch 7 / 100, step 53/110, loss = 2.0424
# epoch 7 / 100, step 54/110, loss = 2.0315
# epoch 7 / 100, step 55/110, loss = 2.0639
# epoch 7 / 100, step 56/110, loss = 2.1952
# epoch 7 / 100, step 57/110, loss = 1.9686
# epoch 7 / 100, step 58/110, loss = 1.7046
# epoch 7 / 100, step 59/110, loss = 2.2679
# epoch 7 / 100, step 60/110, loss = 1.7490
# epoch 7 / 100, step 61/110, loss = 1.9759
# epoch 7 / 100, step 62/110, loss = 2.1687
# epoch 7 / 100, step 63/110, loss = 1.9927
# epoch 7 / 100, step 64/110, loss = 1.7449
# epoch 7 / 100, step 65/110, loss = 2.1558
# epoch 7 / 100, step 66/110, loss = 2.0728
# epoch 7 / 100, step 67/110, loss = 2.1128
# epoch 7 / 100, step 68/110, loss = 2.0203
# epoch 7 / 100, step 69/110, loss = 1.7489
# epoch 7 / 100, step 70/110, loss = 1.8970
# epoch 7 / 100, step 71/110, loss = 2.0104
# epoch 7 / 100, step 72/110, loss = 1.9067
# epoch 7 / 100, step 73/110, loss = 2.0263
# epoch 7 / 100, step 74/110, loss = 2.0968
# epoch 7 / 100, step 75/110, loss = 1.7043
# epoch 7 / 100, step 76/110, loss = 1.8130
# epoch 7 / 100, step 77/110, loss = 2.1437
# epoch 7 / 100, step 78/110, loss = 2.0214
# epoch 7 / 100, step 79/110, loss = 1.8680
# epoch 7 / 100, step 80/110, loss = 2.1581
# epoch 7 / 100, step 81/110, loss = 1.9683
# epoch 7 / 100, step 82/110, loss = 2.1493
# epoch 7 / 100, step 83/110, loss = 2.1153
# epoch 7 / 100, step 84/110, loss = 1.9908
# epoch 7 / 100, step 85/110, loss = 2.2628
# epoch 7 / 100, step 86/110, loss = 1.9365
# epoch 7 / 100, step 87/110, loss = 2.1090
# epoch 7 / 100, step 88/110, loss = 2.2010
# epoch 7 / 100, step 89/110, loss = 2.1004
# epoch 7 / 100, step 90/110, loss = 1.9214
# epoch 7 / 100, step 91/110, loss = 2.1895
# epoch 7 / 100, step 92/110, loss = 2.0272
# epoch 7 / 100, step 93/110, loss = 1.9371
# epoch 7 / 100, step 94/110, loss = 1.9249
# epoch 7 / 100, step 95/110, loss = 2.2086
# epoch 7 / 100, step 96/110, loss = 2.2197
# epoch 7 / 100, step 97/110, loss = 2.1314
# epoch 7 / 100, step 98/110, loss = 2.1346
# epoch 7 / 100, step 99/110, loss = 2.0702
# epoch 7 / 100, step 100/110, loss = 1.9828
# epoch 7 / 100, step 101/110, loss = 1.7675
# epoch 7 / 100, step 102/110, loss = 2.1892
# epoch 7 / 100, step 103/110, loss = 2.0983
# epoch 7 / 100, step 104/110, loss = 1.7659
# epoch 7 / 100, step 105/110, loss = 2.2549
# epoch 7 / 100, step 106/110, loss = 2.0706
# epoch 7 / 100, step 107/110, loss = 2.0692
# epoch 7 / 100, step 108/110, loss = 2.0271
# epoch 7 / 100, step 109/110, loss = 1.7915
# epoch 7 / 100, step 110/110, loss = 2.3665
# epoch 7 / 100, step 1/28, loss = 1.9821
# epoch 7 / 100, step 2/28, loss = 2.0223
# epoch 7 / 100, step 3/28, loss = 1.9598
# epoch 7 / 100, step 4/28, loss = 1.9116
# epoch 7 / 100, step 5/28, loss = 1.7804
# epoch 7 / 100, step 6/28, loss = 2.0137
# epoch 7 / 100, step 7/28, loss = 1.9450
# epoch 7 / 100, step 8/28, loss = 1.9009
# epoch 7 / 100, step 9/28, loss = 1.9726
# epoch 7 / 100, step 10/28, loss = 1.9192
# epoch 7 / 100, step 11/28, loss = 2.0140
# epoch 7 / 100, step 12/28, loss = 2.0142
# epoch 7 / 100, step 13/28, loss = 2.0278
# epoch 7 / 100, step 14/28, loss = 1.8812
# epoch 7 / 100, step 15/28, loss = 2.0204
# epoch 7 / 100, step 16/28, loss = 2.0011
# epoch 7 / 100, step 17/28, loss = 1.9835
# epoch 7 / 100, step 18/28, loss = 2.0247
# epoch 7 / 100, step 19/28, loss = 1.9137
# epoch 7 / 100, step 20/28, loss = 1.8223
# epoch 7 / 100, step 21/28, loss = 1.9455
# epoch 7 / 100, step 22/28, loss = 1.9256
# epoch 7 / 100, step 23/28, loss = 1.9511
# epoch 7 / 100, step 24/28, loss = 1.9049
# epoch 7 / 100, step 25/28, loss = 1.9855
# epoch 7 / 100, step 26/28, loss = 2.0661
# epoch 7 / 100, step 27/28, loss = 1.9301
# epoch 7 / 100, step 28/28, loss = 1.9912
# epoch 8 / 100, step 1/110, loss = 2.0662
# epoch 8 / 100, step 2/110, loss = 1.9124
# epoch 8 / 100, step 3/110, loss = 2.1284
# epoch 8 / 100, step 4/110, loss = 1.8612
# epoch 8 / 100, step 5/110, loss = 1.9164
# epoch 8 / 100, step 6/110, loss = 1.9423
# epoch 8 / 100, step 7/110, loss = 2.1399
# epoch 8 / 100, step 8/110, loss = 2.0827
# epoch 8 / 100, step 9/110, loss = 2.2762
# epoch 8 / 100, step 10/110, loss = 2.2914
# epoch 8 / 100, step 11/110, loss = 1.9660
# epoch 8 / 100, step 12/110, loss = 1.9720
# epoch 8 / 100, step 13/110, loss = 2.1988
# epoch 8 / 100, step 14/110, loss = 2.1080
# epoch 8 / 100, step 15/110, loss = 2.3616
# epoch 8 / 100, step 16/110, loss = 2.1353
# epoch 8 / 100, step 17/110, loss = 2.0871
# epoch 8 / 100, step 18/110, loss = 1.9384
# epoch 8 / 100, step 19/110, loss = 2.1713
# epoch 8 / 100, step 20/110, loss = 1.9776
# epoch 8 / 100, step 21/110, loss = 1.7423
# epoch 8 / 100, step 22/110, loss = 2.1246
# epoch 8 / 100, step 23/110, loss = 1.8746
# epoch 8 / 100, step 24/110, loss = 1.9100
# epoch 8 / 100, step 25/110, loss = 1.9874
# epoch 8 / 100, step 26/110, loss = 2.0768
# epoch 8 / 100, step 27/110, loss = 1.9381
# epoch 8 / 100, step 28/110, loss = 1.9972
# epoch 8 / 100, step 29/110, loss = 1.8631
# epoch 8 / 100, step 30/110, loss = 1.8977
# epoch 8 / 100, step 31/110, loss = 2.0327
# epoch 8 / 100, step 32/110, loss = 2.2151
# epoch 8 / 100, step 33/110, loss = 2.0813
# epoch 8 / 100, step 34/110, loss = 1.9844
# epoch 8 / 100, step 35/110, loss = 2.0429
# epoch 8 / 100, step 36/110, loss = 2.0526
# epoch 8 / 100, step 37/110, loss = 1.9193
# epoch 8 / 100, step 38/110, loss = 2.3519
# epoch 8 / 100, step 39/110, loss = 2.0487
# epoch 8 / 100, step 40/110, loss = 2.1814
# epoch 8 / 100, step 41/110, loss = 1.9954
# epoch 8 / 100, step 42/110, loss = 1.5716
# epoch 8 / 100, step 43/110, loss = 1.7784
# epoch 8 / 100, step 44/110, loss = 1.7561
# epoch 8 / 100, step 45/110, loss = 2.1852
# epoch 8 / 100, step 46/110, loss = 2.1572
# epoch 8 / 100, step 47/110, loss = 2.1975
# epoch 8 / 100, step 48/110, loss = 2.0909
# epoch 8 / 100, step 49/110, loss = 1.7747
# epoch 8 / 100, step 50/110, loss = 2.2152
# epoch 8 / 100, step 51/110, loss = 1.9286
# epoch 8 / 100, step 52/110, loss = 2.1280
# epoch 8 / 100, step 53/110, loss = 2.1311
# epoch 8 / 100, step 54/110, loss = 1.9804
# epoch 8 / 100, step 55/110, loss = 1.7833
# epoch 8 / 100, step 56/110, loss = 2.2235
# epoch 8 / 100, step 57/110, loss = 1.9216
# epoch 8 / 100, step 58/110, loss = 2.1160
# epoch 8 / 100, step 59/110, loss = 2.1295
# epoch 8 / 100, step 60/110, loss = 1.9549
# epoch 8 / 100, step 61/110, loss = 1.8312
# epoch 8 / 100, step 62/110, loss = 1.9902
# epoch 8 / 100, step 63/110, loss = 2.0140
# epoch 8 / 100, step 64/110, loss = 2.0523
# epoch 8 / 100, step 65/110, loss = 1.8628
# epoch 8 / 100, step 66/110, loss = 2.1015
# epoch 8 / 100, step 67/110, loss = 2.0404
# epoch 8 / 100, step 68/110, loss = 2.2036
# epoch 8 / 100, step 69/110, loss = 2.0136
# epoch 8 / 100, step 70/110, loss = 2.2758
# epoch 8 / 100, step 71/110, loss = 1.9992
# epoch 8 / 100, step 72/110, loss = 1.8396
# epoch 8 / 100, step 73/110, loss = 2.1574
# epoch 8 / 100, step 74/110, loss = 1.9227
# epoch 8 / 100, step 75/110, loss = 2.0763
# epoch 8 / 100, step 76/110, loss = 2.0875
# epoch 8 / 100, step 77/110, loss = 2.1558
# epoch 8 / 100, step 78/110, loss = 2.0900
# epoch 8 / 100, step 79/110, loss = 2.1189
# epoch 8 / 100, step 80/110, loss = 1.8788
# epoch 8 / 100, step 81/110, loss = 1.9305
# epoch 8 / 100, step 82/110, loss = 1.8448
# epoch 8 / 100, step 83/110, loss = 2.0670
# epoch 8 / 100, step 84/110, loss = 2.2362
# epoch 8 / 100, step 85/110, loss = 1.7898
# epoch 8 / 100, step 86/110, loss = 1.7799
# epoch 8 / 100, step 87/110, loss = 2.4293
# epoch 8 / 100, step 88/110, loss = 1.7333
# epoch 8 / 100, step 89/110, loss = 1.8566
# epoch 8 / 100, step 90/110, loss = 2.0927
# epoch 8 / 100, step 91/110, loss = 2.1148
# epoch 8 / 100, step 92/110, loss = 1.7648
# epoch 8 / 100, step 93/110, loss = 2.0631
# epoch 8 / 100, step 94/110, loss = 1.7960
# epoch 8 / 100, step 95/110, loss = 2.0224
# epoch 8 / 100, step 96/110, loss = 2.1779
# epoch 8 / 100, step 97/110, loss = 2.2670
# epoch 8 / 100, step 98/110, loss = 2.2355
# epoch 8 / 100, step 99/110, loss = 2.0258
# epoch 8 / 100, step 100/110, loss = 1.8487
# epoch 8 / 100, step 101/110, loss = 2.1925
# epoch 8 / 100, step 102/110, loss = 1.8920
# epoch 8 / 100, step 103/110, loss = 2.1139
# epoch 8 / 100, step 104/110, loss = 1.9065
# epoch 8 / 100, step 105/110, loss = 2.0585
# epoch 8 / 100, step 106/110, loss = 2.1193
# epoch 8 / 100, step 107/110, loss = 2.2883
# epoch 8 / 100, step 108/110, loss = 1.8693
# epoch 8 / 100, step 109/110, loss = 1.9350
# epoch 8 / 100, step 110/110, loss = 2.8941
# epoch 8 / 100, step 1/28, loss = 1.9918
# epoch 8 / 100, step 2/28, loss = 2.1000
# epoch 8 / 100, step 3/28, loss = 2.0236
# epoch 8 / 100, step 4/28, loss = 2.0605
# epoch 8 / 100, step 5/28, loss = 2.0413
# epoch 8 / 100, step 6/28, loss = 2.0343
# epoch 8 / 100, step 7/28, loss = 1.8426
# epoch 8 / 100, step 8/28, loss = 1.9520
# epoch 8 / 100, step 9/28, loss = 2.0366
# epoch 8 / 100, step 10/28, loss = 1.9215
# epoch 8 / 100, step 11/28, loss = 1.9175
# epoch 8 / 100, step 12/28, loss = 1.6854
# epoch 8 / 100, step 13/28, loss = 2.0873
# epoch 8 / 100, step 14/28, loss = 2.0485
# epoch 8 / 100, step 15/28, loss = 1.7146
# epoch 8 / 100, step 16/28, loss = 2.1476
# epoch 8 / 100, step 17/28, loss = 1.9661
# epoch 8 / 100, step 18/28, loss = 2.0605
# epoch 8 / 100, step 19/28, loss = 2.2241
# epoch 8 / 100, step 20/28, loss = 1.7253
# epoch 8 / 100, step 21/28, loss = 1.9336
# epoch 8 / 100, step 22/28, loss = 1.9839
# epoch 8 / 100, step 23/28, loss = 1.9441
# epoch 8 / 100, step 24/28, loss = 2.1556
# epoch 8 / 100, step 25/28, loss = 2.1275
# epoch 8 / 100, step 26/28, loss = 2.2802
# epoch 8 / 100, step 27/28, loss = 2.0726
# epoch 8 / 100, step 28/28, loss = 1.6659
# epoch 9 / 100, step 1/110, loss = 2.2671
# epoch 9 / 100, step 2/110, loss = 1.9596
# epoch 9 / 100, step 3/110, loss = 1.8947
# epoch 9 / 100, step 4/110, loss = 2.0087
# epoch 9 / 100, step 5/110, loss = 2.0094
# epoch 9 / 100, step 6/110, loss = 2.0125
# epoch 9 / 100, step 7/110, loss = 2.1625
# epoch 9 / 100, step 8/110, loss = 1.8225
# epoch 9 / 100, step 9/110, loss = 2.4208
# epoch 9 / 100, step 10/110, loss = 1.8766
# epoch 9 / 100, step 11/110, loss = 1.9825
# epoch 9 / 100, step 12/110, loss = 2.0903
# epoch 9 / 100, step 13/110, loss = 2.0538
# epoch 9 / 100, step 14/110, loss = 1.9020
# epoch 9 / 100, step 15/110, loss = 2.0250
# epoch 9 / 100, step 16/110, loss = 1.8207
# epoch 9 / 100, step 17/110, loss = 2.1282
# epoch 9 / 100, step 18/110, loss = 2.0757
# epoch 9 / 100, step 19/110, loss = 2.1049
# epoch 9 / 100, step 20/110, loss = 1.9944
# epoch 9 / 100, step 21/110, loss = 2.1778
# epoch 9 / 100, step 22/110, loss = 1.9401
# epoch 9 / 100, step 23/110, loss = 2.0264
# epoch 9 / 100, step 24/110, loss = 2.2732
# epoch 9 / 100, step 25/110, loss = 2.1644
# epoch 9 / 100, step 26/110, loss = 1.8636
# epoch 9 / 100, step 27/110, loss = 1.8651
# epoch 9 / 100, step 28/110, loss = 1.9607
# epoch 9 / 100, step 29/110, loss = 1.9639
# epoch 9 / 100, step 30/110, loss = 1.9101
# epoch 9 / 100, step 31/110, loss = 1.8151
# epoch 9 / 100, step 32/110, loss = 2.0496
# epoch 9 / 100, step 33/110, loss = 1.9616
# epoch 9 / 100, step 34/110, loss = 2.0259
# epoch 9 / 100, step 35/110, loss = 2.0753
# epoch 9 / 100, step 36/110, loss = 1.7869
# epoch 9 / 100, step 37/110, loss = 2.0006
# epoch 9 / 100, step 38/110, loss = 2.0025
# epoch 9 / 100, step 39/110, loss = 1.9767
# epoch 9 / 100, step 40/110, loss = 2.1008
# epoch 9 / 100, step 41/110, loss = 2.1502
# epoch 9 / 100, step 42/110, loss = 1.9117
# epoch 9 / 100, step 43/110, loss = 2.2369
# epoch 9 / 100, step 44/110, loss = 2.2845
# epoch 9 / 100, step 45/110, loss = 2.1342
# ...
# epoch 98 / 100, step 44/110, loss = 2.0992
# epoch 98 / 100, step 45/110, loss = 1.9520
# epoch 98 / 100, step 46/110, loss = 2.1049
# epoch 98 / 100, step 47/110, loss = 2.0979
# epoch 98 / 100, step 48/110, loss = 2.3652
# epoch 98 / 100, step 49/110, loss = 2.0019
# epoch 98 / 100, step 50/110, loss = 2.0068
# epoch 98 / 100, step 51/110, loss = 2.0060
# epoch 98 / 100, step 52/110, loss = 2.1936
# epoch 98 / 100, step 53/110, loss = 1.9171
# epoch 98 / 100, step 54/110, loss = 1.9295
# epoch 98 / 100, step 55/110, loss = 2.0256
# epoch 98 / 100, step 56/110, loss = 1.7443
# epoch 98 / 100, step 57/110, loss = 1.7927
# epoch 98 / 100, step 58/110, loss = 2.4203
# epoch 98 / 100, step 59/110, loss = 1.9798
# epoch 98 / 100, step 60/110, loss = 1.8534
# epoch 98 / 100, step 61/110, loss = 1.7597
# epoch 98 / 100, step 62/110, loss = 1.8516
# epoch 98 / 100, step 63/110, loss = 2.1978
# epoch 98 / 100, step 64/110, loss = 2.1171
# epoch 98 / 100, step 65/110, loss = 1.8753
# epoch 98 / 100, step 66/110, loss = 2.0009
# epoch 98 / 100, step 67/110, loss = 2.0413
# epoch 98 / 100, step 68/110, loss = 2.0317
# epoch 98 / 100, step 69/110, loss = 2.0944
# epoch 98 / 100, step 70/110, loss = 1.8849
# epoch 98 / 100, step 71/110, loss = 2.0287
# epoch 98 / 100, step 72/110, loss = 2.1760
# epoch 98 / 100, step 73/110, loss = 2.1162
# epoch 98 / 100, step 74/110, loss = 1.6420
# epoch 98 / 100, step 75/110, loss = 2.0224
# epoch 98 / 100, step 76/110, loss = 1.8217
# epoch 98 / 100, step 77/110, loss = 1.8673
# epoch 98 / 100, step 78/110, loss = 1.7758
# epoch 98 / 100, step 79/110, loss = 2.0066
# epoch 98 / 100, step 80/110, loss = 2.0167
# epoch 98 / 100, step 81/110, loss = 2.2596
# epoch 98 / 100, step 82/110, loss = 1.9092
# epoch 98 / 100, step 83/110, loss = 2.0718
# epoch 98 / 100, step 84/110, loss = 1.7276
# epoch 98 / 100, step 85/110, loss = 1.7778
# epoch 98 / 100, step 86/110, loss = 2.3728
# epoch 98 / 100, step 87/110, loss = 2.0039
# epoch 98 / 100, step 88/110, loss = 2.6889
# epoch 98 / 100, step 89/110, loss = 1.7877
# epoch 98 / 100, step 90/110, loss = 2.2130
# epoch 98 / 100, step 91/110, loss = 1.9901
# epoch 98 / 100, step 92/110, loss = 2.0457
# epoch 98 / 100, step 93/110, loss = 2.1502
# epoch 98 / 100, step 94/110, loss = 2.0370
# epoch 98 / 100, step 95/110, loss = 1.8852
# epoch 98 / 100, step 96/110, loss = 1.9469
# epoch 98 / 100, step 97/110, loss = 1.9316
# epoch 98 / 100, step 98/110, loss = 2.1741
# epoch 98 / 100, step 99/110, loss = 1.7607
# epoch 98 / 100, step 100/110, loss = 2.1852
# epoch 98 / 100, step 101/110, loss = 2.0770
# epoch 98 / 100, step 102/110, loss = 2.1043
# epoch 98 / 100, step 103/110, loss = 1.8459
# epoch 98 / 100, step 104/110, loss = 2.1976
# epoch 98 / 100, step 105/110, loss = 1.9942
# epoch 98 / 100, step 106/110, loss = 2.0725
# epoch 98 / 100, step 107/110, loss = 2.0669
# epoch 98 / 100, step 108/110, loss = 2.0843
# epoch 98 / 100, step 109/110, loss = 1.9422
# epoch 98 / 100, step 110/110, loss = 2.1182
# epoch 98 / 100, step 1/28, loss = 1.8936
# epoch 98 / 100, step 2/28, loss = 1.9129
# epoch 98 / 100, step 3/28, loss = 1.9341
# epoch 98 / 100, step 4/28, loss = 1.8752
# epoch 98 / 100, step 5/28, loss = 1.9381
# epoch 98 / 100, step 6/28, loss = 1.8049
# epoch 98 / 100, step 7/28, loss = 1.9241
# epoch 98 / 100, step 8/28, loss = 2.0526
# epoch 98 / 100, step 9/28, loss = 1.9183
# epoch 98 / 100, step 10/28, loss = 2.0689
# epoch 98 / 100, step 11/28, loss = 1.9621
# epoch 98 / 100, step 12/28, loss = 1.8145
# epoch 98 / 100, step 13/28, loss = 2.0111
# epoch 98 / 100, step 14/28, loss = 1.8861
# epoch 98 / 100, step 15/28, loss = 1.8832
# epoch 98 / 100, step 16/28, loss = 1.8742
# epoch 98 / 100, step 17/28, loss = 1.9915
# epoch 98 / 100, step 18/28, loss = 2.1091
# epoch 98 / 100, step 19/28, loss = 2.0128
# epoch 98 / 100, step 20/28, loss = 1.9448
# epoch 98 / 100, step 21/28, loss = 1.9819
# epoch 98 / 100, step 22/28, loss = 1.9433
# epoch 98 / 100, step 23/28, loss = 1.9119
# epoch 98 / 100, step 24/28, loss = 2.0371
# epoch 98 / 100, step 25/28, loss = 2.0317
# epoch 98 / 100, step 26/28, loss = 2.0830
# epoch 98 / 100, step 27/28, loss = 1.9483
# epoch 98 / 100, step 28/28, loss = 1.8961
# epoch 99 / 100, step 1/110, loss = 1.9941
# epoch 99 / 100, step 2/110, loss = 1.6610
# epoch 99 / 100, step 3/110, loss = 1.9599
# epoch 99 / 100, step 4/110, loss = 2.0624
# epoch 99 / 100, step 5/110, loss = 1.8009
# epoch 99 / 100, step 6/110, loss = 1.9186
# epoch 99 / 100, step 7/110, loss = 1.9052
# epoch 99 / 100, step 8/110, loss = 1.9766
# epoch 99 / 100, step 9/110, loss = 1.9535
# epoch 99 / 100, step 10/110, loss = 1.9977
# epoch 99 / 100, step 11/110, loss = 1.8175
# epoch 99 / 100, step 12/110, loss = 1.9346
# epoch 99 / 100, step 13/110, loss = 1.9876
# epoch 99 / 100, step 14/110, loss = 2.0400
# epoch 99 / 100, step 15/110, loss = 1.7387
# epoch 99 / 100, step 16/110, loss = 2.0649
# epoch 99 / 100, step 17/110, loss = 2.0540
# epoch 99 / 100, step 18/110, loss = 1.9351
# epoch 99 / 100, step 19/110, loss = 2.2036
# epoch 99 / 100, step 20/110, loss = 2.1859
# epoch 99 / 100, step 21/110, loss = 2.1126
# epoch 99 / 100, step 22/110, loss = 1.9718
# epoch 99 / 100, step 23/110, loss = 2.0092
# epoch 99 / 100, step 24/110, loss = 1.9599
# epoch 99 / 100, step 25/110, loss = 2.5179
# epoch 99 / 100, step 26/110, loss = 1.7813
# epoch 99 / 100, step 27/110, loss = 1.9792
# epoch 99 / 100, step 28/110, loss = 2.0149
# epoch 99 / 100, step 29/110, loss = 2.0029
# epoch 99 / 100, step 30/110, loss = 1.6227
# epoch 99 / 100, step 31/110, loss = 2.0147
# epoch 99 / 100, step 32/110, loss = 2.0198
# epoch 99 / 100, step 33/110, loss = 1.7454
# epoch 99 / 100, step 34/110, loss = 1.7913
# epoch 99 / 100, step 35/110, loss = 2.2071
# epoch 99 / 100, step 36/110, loss = 1.8648
# epoch 99 / 100, step 37/110, loss = 2.1843
# epoch 99 / 100, step 38/110, loss = 1.9690
# epoch 99 / 100, step 39/110, loss = 2.0429
# epoch 99 / 100, step 40/110, loss = 1.9058
# epoch 99 / 100, step 41/110, loss = 2.0854
# epoch 99 / 100, step 42/110, loss = 2.0281
# epoch 99 / 100, step 43/110, loss = 1.9713
# epoch 99 / 100, step 44/110, loss = 2.0874
# epoch 99 / 100, step 45/110, loss = 2.2108
# epoch 99 / 100, step 46/110, loss = 2.1019
# epoch 99 / 100, step 47/110, loss = 2.0837
# epoch 99 / 100, step 48/110, loss = 2.1627
# epoch 99 / 100, step 49/110, loss = 2.1140
# epoch 99 / 100, step 50/110, loss = 1.8745
# epoch 99 / 100, step 51/110, loss = 1.9061
# epoch 99 / 100, step 52/110, loss = 2.0056
# epoch 99 / 100, step 53/110, loss = 2.0672
# epoch 99 / 100, step 54/110, loss = 2.1209
# epoch 99 / 100, step 55/110, loss = 2.0903
# epoch 99 / 100, step 56/110, loss = 2.1627
# epoch 99 / 100, step 57/110, loss = 2.0549
# epoch 99 / 100, step 58/110, loss = 2.0711
# epoch 99 / 100, step 59/110, loss = 1.9606
# epoch 99 / 100, step 60/110, loss = 2.0817
# epoch 99 / 100, step 61/110, loss = 1.9772
# epoch 99 / 100, step 62/110, loss = 2.2844
# epoch 99 / 100, step 63/110, loss = 2.0943
# epoch 99 / 100, step 64/110, loss = 1.9529
# epoch 99 / 100, step 65/110, loss = 1.9887
# epoch 99 / 100, step 66/110, loss = 1.8417
# epoch 99 / 100, step 67/110, loss = 1.8746
# epoch 99 / 100, step 68/110, loss = 2.1347
# epoch 99 / 100, step 69/110, loss = 2.0207
# epoch 99 / 100, step 70/110, loss = 2.0522
# epoch 99 / 100, step 71/110, loss = 1.8512
# epoch 99 / 100, step 72/110, loss = 2.0753
# epoch 99 / 100, step 73/110, loss = 1.8329
# epoch 99 / 100, step 74/110, loss = 2.2211
# epoch 99 / 100, step 75/110, loss = 2.0199
# epoch 99 / 100, step 76/110, loss = 1.9418
# epoch 99 / 100, step 77/110, loss = 1.8414
# epoch 99 / 100, step 78/110, loss = 2.2475
# epoch 99 / 100, step 79/110, loss = 1.8621
# epoch 99 / 100, step 80/110, loss = 2.0426
# epoch 99 / 100, step 81/110, loss = 2.3825
# epoch 99 / 100, step 82/110, loss = 2.0505
# epoch 99 / 100, step 83/110, loss = 1.9774
# epoch 99 / 100, step 84/110, loss = 2.0665
# epoch 99 / 100, step 85/110, loss = 2.0287
# epoch 99 / 100, step 86/110, loss = 2.0254
# epoch 99 / 100, step 87/110, loss = 2.1295
# epoch 99 / 100, step 88/110, loss = 1.9012
# epoch 99 / 100, step 89/110, loss = 1.7706
# epoch 99 / 100, step 90/110, loss = 1.9220
# epoch 99 / 100, step 91/110, loss = 1.9716
# epoch 99 / 100, step 92/110, loss = 2.0047
# epoch 99 / 100, step 93/110, loss = 1.7420
# epoch 99 / 100, step 94/110, loss = 2.2788
# epoch 99 / 100, step 95/110, loss = 1.8650
# epoch 99 / 100, step 96/110, loss = 2.0227
# epoch 99 / 100, step 97/110, loss = 2.0367
# epoch 99 / 100, step 98/110, loss = 1.6820
# epoch 99 / 100, step 99/110, loss = 2.0108
# epoch 99 / 100, step 100/110, loss = 2.0337
# epoch 99 / 100, step 101/110, loss = 2.0612
# epoch 99 / 100, step 102/110, loss = 1.8614
# epoch 99 / 100, step 103/110, loss = 1.9062
# epoch 99 / 100, step 104/110, loss = 2.0277
# epoch 99 / 100, step 105/110, loss = 2.3862
# epoch 99 / 100, step 106/110, loss = 1.8989
# epoch 99 / 100, step 107/110, loss = 1.9285
# epoch 99 / 100, step 108/110, loss = 1.7712
# epoch 99 / 100, step 109/110, loss = 1.9120
# epoch 99 / 100, step 110/110, loss = 2.2568
# epoch 99 / 100, step 1/28, loss = 2.0877
# epoch 99 / 100, step 2/28, loss = 2.1651
# epoch 99 / 100, step 3/28, loss = 1.9401
# epoch 99 / 100, step 4/28, loss = 1.9310
# epoch 99 / 100, step 5/28, loss = 1.9494
# epoch 99 / 100, step 6/28, loss = 2.2013
# epoch 99 / 100, step 7/28, loss = 1.8631
# epoch 99 / 100, step 8/28, loss = 1.8645
# epoch 99 / 100, step 9/28, loss = 2.0426
# epoch 99 / 100, step 10/28, loss = 1.9261
# epoch 99 / 100, step 11/28, loss = 1.9442
# epoch 99 / 100, step 12/28, loss = 1.8997
# epoch 99 / 100, step 13/28, loss = 2.1112
# epoch 99 / 100, step 14/28, loss = 1.8123
# epoch 99 / 100, step 15/28, loss = 1.9607
# epoch 99 / 100, step 16/28, loss = 2.1673
# epoch 99 / 100, step 17/28, loss = 2.0604
# epoch 99 / 100, step 18/28, loss = 2.0838
# epoch 99 / 100, step 19/28, loss = 2.0687
# epoch 99 / 100, step 20/28, loss = 1.7254
# epoch 99 / 100, step 21/28, loss = 2.0006
# epoch 99 / 100, step 22/28, loss = 2.0028
# epoch 99 / 100, step 23/28, loss = 1.9522
# epoch 99 / 100, step 24/28, loss = 2.0277
# epoch 99 / 100, step 25/28, loss = 1.9258
# epoch 99 / 100, step 26/28, loss = 2.1300
# epoch 99 / 100, step 27/28, loss = 2.0413
# epoch 99 / 100, step 28/28, loss = 1.9618
# epoch 100 / 100, step 1/110, loss = 1.8759
# epoch 100 / 100, step 2/110, loss = 2.2151
# epoch 100 / 100, step 3/110, loss = 1.5866
# epoch 100 / 100, step 4/110, loss = 2.1625
# epoch 100 / 100, step 5/110, loss = 1.9907
# epoch 100 / 100, step 6/110, loss = 2.0913
# epoch 100 / 100, step 7/110, loss = 1.9079
# epoch 100 / 100, step 8/110, loss = 1.8133
# epoch 100 / 100, step 9/110, loss = 1.7967
# epoch 100 / 100, step 10/110, loss = 2.1036
# epoch 100 / 100, step 11/110, loss = 1.9233
# epoch 100 / 100, step 12/110, loss = 2.2707
# epoch 100 / 100, step 13/110, loss = 1.8430
# epoch 100 / 100, step 14/110, loss = 2.2236
# epoch 100 / 100, step 15/110, loss = 1.8188
# epoch 100 / 100, step 16/110, loss = 1.9528
# epoch 100 / 100, step 17/110, loss = 1.6271
# epoch 100 / 100, step 18/110, loss = 1.9547
# epoch 100 / 100, step 19/110, loss = 2.0011
# epoch 100 / 100, step 20/110, loss = 2.1345
# epoch 100 / 100, step 21/110, loss = 2.0536
# epoch 100 / 100, step 22/110, loss = 2.0519
# epoch 100 / 100, step 23/110, loss = 2.0792
# epoch 100 / 100, step 24/110, loss = 2.1797
# epoch 100 / 100, step 25/110, loss = 1.9557
# epoch 100 / 100, step 26/110, loss = 2.0079
# epoch 100 / 100, step 27/110, loss = 1.8914
# epoch 100 / 100, step 28/110, loss = 2.1090
# epoch 100 / 100, step 29/110, loss = 2.0639
# epoch 100 / 100, step 30/110, loss = 2.0105
# epoch 100 / 100, step 31/110, loss = 1.7698
# epoch 100 / 100, step 32/110, loss = 2.0760
# epoch 100 / 100, step 33/110, loss = 2.2196
# epoch 100 / 100, step 34/110, loss = 1.9580
# epoch 100 / 100, step 35/110, loss = 1.8099
# epoch 100 / 100, step 36/110, loss = 2.2583
# epoch 100 / 100, step 37/110, loss = 2.1300
# epoch 100 / 100, step 38/110, loss = 2.0738
# epoch 100 / 100, step 39/110, loss = 1.9914
# epoch 100 / 100, step 40/110, loss = 1.9558
# epoch 100 / 100, step 41/110, loss = 2.3238
# epoch 100 / 100, step 42/110, loss = 1.8544
# epoch 100 / 100, step 43/110, loss = 1.8172
# epoch 100 / 100, step 44/110, loss = 1.9540
# epoch 100 / 100, step 45/110, loss = 1.8127
# epoch 100 / 100, step 46/110, loss = 1.9412
# epoch 100 / 100, step 47/110, loss = 2.1243
# epoch 100 / 100, step 48/110, loss = 2.0964
# epoch 100 / 100, step 49/110, loss = 1.9595
# epoch 100 / 100, step 50/110, loss = 2.2159
# epoch 100 / 100, step 51/110, loss = 1.8293
# epoch 100 / 100, step 52/110, loss = 2.3091
# epoch 100 / 100, step 53/110, loss = 2.0777
# epoch 100 / 100, step 54/110, loss = 2.2545
# epoch 100 / 100, step 55/110, loss = 2.1603
# epoch 100 / 100, step 56/110, loss = 2.0902
# epoch 100 / 100, step 57/110, loss = 2.0232
# epoch 100 / 100, step 58/110, loss = 1.8463
# epoch 100 / 100, step 59/110, loss = 2.0275
# epoch 100 / 100, step 60/110, loss = 1.7169
# epoch 100 / 100, step 61/110, loss = 1.9779
# epoch 100 / 100, step 62/110, loss = 2.1707
# epoch 100 / 100, step 63/110, loss = 2.0760
# epoch 100 / 100, step 64/110, loss = 2.1319
# epoch 100 / 100, step 65/110, loss = 2.0295
# epoch 100 / 100, step 66/110, loss = 1.8028
# epoch 100 / 100, step 67/110, loss = 2.0432
# epoch 100 / 100, step 68/110, loss = 2.0409
# epoch 100 / 100, step 69/110, loss = 2.2204
# epoch 100 / 100, step 70/110, loss = 1.9090
# epoch 100 / 100, step 71/110, loss = 2.1024
# epoch 100 / 100, step 72/110, loss = 2.1083
# epoch 100 / 100, step 73/110, loss = 2.0450
# epoch 100 / 100, step 74/110, loss = 2.0758
# epoch 100 / 100, step 75/110, loss = 2.0956
# epoch 100 / 100, step 76/110, loss = 2.0604
# epoch 100 / 100, step 77/110, loss = 1.9664
# epoch 100 / 100, step 78/110, loss = 2.3591
# epoch 100 / 100, step 79/110, loss = 1.9575
# epoch 100 / 100, step 80/110, loss = 2.2196
# epoch 100 / 100, step 81/110, loss = 1.9072
# epoch 100 / 100, step 82/110, loss = 2.0088
# epoch 100 / 100, step 83/110, loss = 1.9793
# epoch 100 / 100, step 84/110, loss = 2.0804
# epoch 100 / 100, step 85/110, loss = 1.9763
# epoch 100 / 100, step 86/110, loss = 1.9807
# epoch 100 / 100, step 87/110, loss = 1.9102
# epoch 100 / 100, step 88/110, loss = 2.0306
# epoch 100 / 100, step 89/110, loss = 1.9667
# epoch 100 / 100, step 90/110, loss = 2.1719
# epoch 100 / 100, step 91/110, loss = 1.9532
# epoch 100 / 100, step 92/110, loss = 2.3106
# epoch 100 / 100, step 93/110, loss = 2.0783
# epoch 100 / 100, step 94/110, loss = 1.9405
# epoch 100 / 100, step 95/110, loss = 1.8914
# epoch 100 / 100, step 96/110, loss = 1.9414
# epoch 100 / 100, step 97/110, loss = 2.0219
# epoch 100 / 100, step 98/110, loss = 1.9732
# epoch 100 / 100, step 99/110, loss = 1.9982
# epoch 100 / 100, step 100/110, loss = 1.7869
# epoch 100 / 100, step 101/110, loss = 1.9014
# epoch 100 / 100, step 102/110, loss = 1.7097
# epoch 100 / 100, step 103/110, loss = 1.8845
# epoch 100 / 100, step 104/110, loss = 1.8681
# epoch 100 / 100, step 105/110, loss = 1.8844
# epoch 100 / 100, step 106/110, loss = 2.2947
# epoch 100 / 100, step 107/110, loss = 2.0937
# epoch 100 / 100, step 108/110, loss = 2.1673
# epoch 100 / 100, step 109/110, loss = 2.3761
# epoch 100 / 100, step 110/110, loss = 2.1062
# epoch 100 / 100, step 1/28, loss = 1.9192
# epoch 100 / 100, step 2/28, loss = 1.9745
# epoch 100 / 100, step 3/28, loss = 2.0612
# epoch 100 / 100, step 4/28, loss = 1.8421
# epoch 100 / 100, step 5/28, loss = 2.2950
# epoch 100 / 100, step 6/28, loss = 1.9618
# epoch 100 / 100, step 7/28, loss = 2.0413
# epoch 100 / 100, step 8/28, loss = 2.2445
# epoch 100 / 100, step 9/28, loss = 1.9002
# epoch 100 / 100, step 10/28, loss = 1.9919
# epoch 100 / 100, step 11/28, loss = 1.8150
# epoch 100 / 100, step 12/28, loss = 1.7181
# epoch 100 / 100, step 13/28, loss = 2.0012
# epoch 100 / 100, step 14/28, loss = 2.0206
# epoch 100 / 100, step 15/28, loss = 1.8478
# epoch 100 / 100, step 16/28, loss = 1.9429
# epoch 100 / 100, step 17/28, loss = 1.9785
# epoch 100 / 100, step 18/28, loss = 2.0605
# epoch 100 / 100, step 19/28, loss = 2.2283
# epoch 100 / 100, step 20/28, loss = 2.1178
# epoch 100 / 100, step 21/28, loss = 1.9091
# epoch 100 / 100, step 22/28, loss = 1.8776
# epoch 100 / 100, step 23/28, loss = 1.8722
# epoch 100 / 100, step 24/28, loss = 2.2145
# epoch 100 / 100, step 25/28, loss = 1.9230
# epoch 100 / 100, step 26/28, loss = 2.2078
# epoch 100 / 100, step 27/28, loss = 1.8875
# epoch 100 / 100, step 28/28, loss = 1.8822

# %%
fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(train_loss_steps, label='Train Loss')
ax [0].set_xlabel('Step')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(train_acc_steps, label='Train Accuracy')
ax [1].set_xlabel('Step')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/StepGraph.png')
plt.show() 

fig , ax = plt.subplots(1,2,sharex=True)

ax [0].plot(history['train_loss'], label='Train Loss')
ax [0].plot(history['val_loss'], label='Test Loss')
ax [0].set_xlabel('Epoch')
ax [0].set_ylabel('Loss')
ax [0].legend()

ax [1].plot(history['train_acc'], label='Train acc')
ax [1].plot(history['val_acc'], label='Test acc')
ax [1].set_xlabel('Epoch')
ax [1].set_ylabel('Accuracy')
ax [1].legend()

plt.savefig(results_dir + '/EpochGraph.png')
plt.show()

# %%
"""
Plot a confusion matrix using true and predicted labels.

Parameters:
    all_labels: List of true labels.
    all_preds: List of predicted labels.
    class_names: List of class names for labeling the confusion matrix.
"""
class_names = ['C1','C2','C5','C20','C50','C100','C200']
cm = confusion_matrix(all_labels, all_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Validation Confusion Matrix")
disp.figure_.savefig(results_dir + 'Confusion_Matrix.png')
plt.show()

# %%
print(f"after {num_epochs} epochs the trainning accuracy is {history["train_acc"][-1]} and the test accuaracy is {history["val_acc"][-1]} ")

test_accuracy_max= max(history["val_acc"])
train_accuracy_max=max(history["train_acc"])

idx_max_test_accuracy=history["val_acc"].index(test_accuracy_max)

idx_max_train_accuracy=history["train_acc"].index(train_accuracy_max)

print(f" the maximum accuracy of the test was {max(history["val_acc"])} at the epoch {idx_max_test_accuracy}")

print(f" the maximum accuracy of the train was {max(history["train_acc"])} at the epoch {idx_max_train_accuracy}")

print(f"the accuracy of the training at the best validation accuracy {max(history["val_acc"])} is {history["train_acc"][idx_max_test_accuracy]}  ")
# Out:
# after 100 epochs the trainning accuracy is 15.428571428571429 and the test accuaracy is 17.80821917808219
#  the maximum accuracy of the test was 19.17808219178082 at the epoch 19
#  the maximum accuracy of the train was 18.057142857142857 at the epoch 12
# the accuracy of the training at the best validation accuracy 19.17808219178082 is 16.114285714285714

# %%
# Copy the 
shutil.copyfile('./rnn_real.ipynb', './' + results_dir + 'rnn_copyreal.ipynb')
torch.save(model.state_dict(), results_dir + "model_weights.pth")
